# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/forage/plsda/forage.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '1.4':'20.81']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '1.4':'20.81'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '1.4':'20.81'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-09 05:26:14,011 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-09 05:26:14,018 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-09 05:26:14,040 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-09 05:26:14,076 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import mlp_optimized

mlp_model = mlp_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, 
                          aim='classification', 
                          hidden_layer_sizes=(64,32),
                          activation='tanh',
                          learning_rate='adaptive',
                          max_iter=10,
                          random_state=1)
mlp_model[0]
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal              CM Cal  \
# 0   MLP      0.985185         0.978947              1.0  [[40, 0], [2, 93]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred             CM Pred
# 0            1.0               1.0               1.0  [[18, 0], [0, 42]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('Al', 1.40, 1.63),
('Si', 1.63, 1.86),
('P', 1.86, 2.16),
('S', 2.16, 2.44),
('Rh L + Ar', 2.44, 3.10),
('K', 3.10, 3.46),
('Ca ka', 3.46, 3.86),
('Ca kb', 3.86, 4.37),
('Ti ka', 4.37, 4.66),
('Ti kb', 4.66, 5.08),
('background1', 5.08, 5.72),
('Mn', 5.72, 6.10),
('Fe ka', 6.10, 6.76),
('Fe kb', 6.76, 7.20),
('Ni', 7.20, 7.69),
('Cu', 7.69, 8.45),
('Zn', 8.45, 8.81),
('background2', 8.81, 13.10),
('sum Fe' , 13.10, 13.63),
('background3', 13.63, 18.0),
('Compton scattering', 18.0, 19.70),
('Rayleight scattering', 19.70, 20.80)
]

# %% [markdown]
# ## SHAP

# %%
shap_global_importance = pd.read_csv('shap_forage.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP                  Zone
# 0     3.70       0.034479                 Ca ka
# 1     6.40       0.030021                 Fe ka
# 2     3.36       0.020017                     K
# 3     1.74       0.008024                    Si
# 4     4.00       0.006471                 Ca kb
# 5     4.50       0.004159                 Ti ka
# 6     2.56       0.002085             Rh L + Ar
# 7    17.43       0.000544           background3
# 8     5.92       0.000510                    Mn
# 9    10.55       0.000498           background2
# 10    2.00       0.000441                     P
# 11   18.35       0.000407    Compton scattering
# 12   13.39       0.000406                sum Fe
# 13    7.00       0.000330                 Fe kb
# 14    2.32       0.000226                     S
# 15    7.24       0.000096                    Ni
# 16    4.92       0.000025                 Ti kb
# 17    1.40       0.000000                    Al
# 18   19.71       0.000000  Rayleight scattering
# 19    5.64       0.000000           background1
# 20    7.73       0.000000                    Cu
# 21    8.53       0.000000                    Zn
# 22   20.81       0.000000                   NaN

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zona 'Al': VE = 92.81%, dim = 12 variáveis
# Zona 'Si': VE = 99.42%, dim = 12 variáveis
# Zona 'P': VE = 94.16%, dim = 16 variáveis
# Zona 'S': VE = 89.31%, dim = 15 variáveis
# Zona 'Rh L + Ar': VE = 95.85%, dim = 34 variáveis
# Zona 'K': VE = 98.44%, dim = 19 variáveis
# Zona 'Ca ka': VE = 89.46%, dim = 21 variáveis
# Zona 'Ca kb': VE = 96.25%, dim = 26 variáveis
# Zona 'Ti ka': VE = 98.15%, dim = 15 variáveis
# Zona 'Ti kb': VE = 76.25%, dim = 22 variáveis
# Zona 'background1': VE = 66.63%, dim = 33 variáveis
# Zona 'Mn': VE = 94.16%, dim = 20 variáveis
# Zona 'Fe ka': VE = 99.38%, dim = 34 variáveis
# Zona 'Fe kb': VE = 94.04%, dim = 23 variáveis
# Zona 'Ni': VE = 77.76%, dim = 25 variáveis
# Zona 'Cu': VE = 84.25%, dim = 39 variáveis
# Zona 'Zn': VE = 82.20%, dim = 19 variáveis
# Zona 'background2': VE = 86.56%, dim = 215 variáveis
# Zona 'sum Fe': VE = 88.47%, dim = 27 variáveis
# Zona 'background3': VE = 87.92%, dim = 219 variáveis
# Zona 'Compton scattering': VE = 88.73%, dim = 85 variáveis
# Zona 'Rayleight scattering': VE = 84.44%, dim = 55 variáveis
#
# Scores DataFrame shape: (135, 22)

# %%
y_pred = mlp_model[4]['MLP'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(mlp_model[4]['MLP'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graphv3_pca(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 101
# Removida: Si > -1.67 -> K > -6.69 (1.1759) | Mantida: K > -6.69 -> Si > -1.67 (1.2063)
# Removida: Si > -2.51 -> Ca ka <= 3.95 (2.3506) | Mantida: Ca ka <= 3.95 -> Si > -2.51 (4.5494)
# Removida: Si > -2.51 -> Si > -1.67 (4.7914) | Mantida: Si > -1.67 -> Si > -2.51 (5.8676)
# Removida: K <= 6.26 -> Si > -1.67 (1.2224) | Mantida: Si > -1.67 -> K <= 6.26 (4.6818)
# Removida: Ca ka <= 1.77 -> K <= 6.26 (0.8722) | Mantida: K <= 6.26 -> Ca ka <= 1.77 (6.4170)
# Removida: K > -1.46 -> Ca ka <= 1.77 (2.9502) | Mantida: Ca ka <= 1.77 -> K > -1.46 (4.3745)
# Removida: Si > -0.72 -> K > -1.46 (1.7586) | Mantida: K > -1.46 -> Si > -0.72 (2.8194)
# Removida: Ca ka > -4.65 -> Si > -0.72 (1.9960) | Mantida: Si > -0.72 -> Ca ka > -4.65 (4.0344)
# Removida: Ti ka > -0.70 -> Ca kb <= 1.57 (0.5143) | Mantida: Ca kb <= 1.57 -> Ti ka > -0.70 (1.4595)
# Removida: Fe kb > -0.91 -> Ca kb <= 1.57 (0.5157) | Mantida: Ca kb <= 1.57 -> Fe kb > -0.91 (0.9543)
# Removida: Fe kb > -0.44 -> Ca kb <= 1.57 (0.4483) | Mantida: Ca kb <= 1.57 -> Fe kb > -0.44 (0.4654)
# Removida: Fe kb > -0.63 -> Ti ka > -0.86 (1.0042) | Mantida: Ti ka > -0.86 -> Fe kb > -0.63 (1.0466)
# Removida: Fe kb > -0.91 -> Rh L + Ar > -0.77 (0.3976) | Mantida: Rh L + Ar > -0.77 -> Fe kb > -0.91 (0.4051)
# Removida: Fe kb > -0.91 -> Fe kb > -0.44 (0.3959) | Mantida: Fe kb > -0.44 -> Fe kb > -0.91 (0.4815)
# Removida: K <= 2.15 -> Rh L + Ar > -0.77 (0.7424) | Mantida: Rh L + Ar > -0.77 -> K <= 2.15 (0.8769)
# Removida: Si <= 3.71 -> Rh L + Ar > -0.77 (0.5158) | Mantida: Rh L + Ar > -0.77 -> Si <= 3.71 (0.6758)
# Removida: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (0.3707) | Mantida: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (0.4329)
# Removida: K <= 2.15 -> Ca kb <= 0.62 (0.4177) | Mantida: Ca kb <= 0.62 -> K <= 2.15 (0.7535)
# Removida: Rh L + Ar > -0.16 -> Ti ka > -0.52 (0.4576) | Mantida: Ti ka > -0.52 -> Rh L + Ar > -0.16 (0.8558)
# Removida: Rh L + Ar > -1.66 -> Ti ka > -0.52 (0.4218) | Mantida: Ti ka > -0.52 -> Rh L + Ar > -1.66 (0.4424)
# Removida: Ti ka > -0.52 -> Si <= 3.71 (0.4361) | Mantida: Si <= 3.71 -> Ti ka > -0.52 (0.9343)
# Removida: background3 > 0.14 -> Rh L + Ar > -0.16 (0.2584) | Mantida: Rh L + Ar > -0.16 -> background3 > 0.14 (0.6101)
# Removida: Si <= 3.71 -> Ca kb <= 0.62 (0.3886) | Mantida: Ca kb <= 0.62 -> Si <= 3.71 (0.3897)
# Removida: Rh L + Ar > -1.66 -> Ca kb <= 0.62 (0.4054) | Mantida: Ca kb <= 0.62 -> Rh L + Ar > -1.66 (0.7322)
# Removida: background3 > 0.14 -> Rh L + Ar > -1.66 (0.3116) | Mantida: Rh L + Ar > -1.66 -> background3 > 0.14 (1.0385)
# Removida: Rh L + Ar > -1.66 -> Fe kb > -0.44 (0.4228) | Mantida: Fe kb > -0.44 -> Rh L + Ar > -1.66 (0.4345)
# Removida: background3 > -0.62 -> Rh L + Ar > -1.66 (0.2402) | Mantida: Rh L + Ar > -1.66 -> background3 > -0.62 (0.3122)
# Removida: Ca kb > -1.81 -> background3 > 0.14 (0.2617) | Mantida: background3 > 0.14 -> Ca kb > -1.81 (0.3363)
# Removida: K > 2.15 -> background3 > 0.14 (0.3888) | Mantida: background3 > 0.14 -> K > 2.15 (0.5919)
# Removida: background3 > -0.62 -> Ca kb > -1.81 (0.7847) | Mantida: Ca kb > -1.81 -> background3 > -0.62 (1.0733)
# Removida: Ca kb > -1.81 -> K > 2.15 (0.2629) | Mantida: K > 2.15 -> Ca kb > -1.81 (0.8943)
# Removida: Compton scattering > 0.05 -> Fe ka <= 1.10 (0.1745) | Mantida: Fe ka <= 1.10 -> Compton scattering > 0.05 (0.7577)
# Removida: Ca kb <= -0.59 -> Fe ka <= 1.10 (0.2011) | Mantida: Fe ka <= 1.10 -> Ca kb <= -0.59 (0.3969)
# Removida: Compton scattering > -0.40 -> Fe ka <= 1.10 (0.1757) | Mantida: Fe ka <= 1.10 -> Compton scattering > -0.40 (0.2533)
# Removida: Fe ka <= 1.10 -> background3 > -1.28 (0.2541) | Mantida: background3 > -1.28 -> Fe ka <= 1.10 (0.4507)
# Removida: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.5073) | Mantida: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.8482)
# Removida: Ca kb <= -0.59 -> Compton scattering > 0.05 (0.2019) | Mantida: Compton scattering > 0.05 -> Ca kb <= -0.59 (0.2149)
# Removida: Ca kb <= -0.59 -> Compton scattering > -0.40 (0.1857) | Mantida: Compton scattering > -0.40 -> Ca kb <= -0.59 (0.1893)
# Removida: Compton scattering > -0.88 -> Ca kb <= -0.59 (0.3470) | Mantida: Ca kb <= -0.59 -> Compton scattering > -0.88 (0.3955)
# Removida: Compton scattering > -0.88 -> K <= -1.46 (0.1565) | Mantida: K <= -1.46 -> Compton scattering > -0.88 (0.1792)
# Removida: Al > -0.68 -> K <= -1.46 (0.1457) | Mantida: K <= -1.46 -> Al > -0.68 (0.1738)
# Removida: Rayleight scattering > -0.50 -> K <= -1.46 (0.1104) | Mantida: K <= -1.46 -> Rayleight scattering > -0.50 (0.2866)
# Removida: K <= -1.46 -> Rayleight scattering > -0.24 (0.1594) | Mantida: Rayleight scattering > -0.24 -> K <= -1.46 (0.2731)
# Removida: Rayleight scattering > 0.03 -> Rayleight scattering > -0.24 (0.2221) | Mantida: Rayleight scattering > -0.24 -> Rayleight scattering > 0.03 (0.2524)
# Removida: Rayleight scattering > 0.03 -> Al > -0.68 (0.1441) | Mantida: Al > -0.68 -> Rayleight scattering > 0.03 (0.2935)
# Removida: Rayleight scattering > 0.03 -> sum Fe > 0.07 (0.1151) | Mantida: sum Fe > 0.07 -> Rayleight scattering > 0.03 (0.1496)
# Removida: sum Fe > -0.28 -> Al <= 0.62 (0.0978) | Mantida: Al <= 0.62 -> sum Fe > -0.28 (0.1072)
# Removida: sum Fe > 0.07 -> sum Fe > -0.28 (0.1620) | Mantida: sum Fe > -0.28 -> sum Fe > 0.07 (0.2963)
# Removida: Al > -0.68 -> sum Fe > -0.28 (0.1566) | Mantida: sum Fe > -0.28 -> Al > -0.68 (0.4308)
# Removida: Ca ka > -1.50 -> Rayleight scattering > -0.24 (0.1331) | Mantida: Rayleight scattering > -0.24 -> Ca ka > -1.50 (0.2671)
# Removida: sum Fe > 0.07 -> Ca ka > -1.50 (0.1337) | Mantida: Ca ka > -1.50 -> sum Fe > 0.07 (0.2810)
# Removida: Ca ka > -1.50 -> Al > -0.68 (0.1365) | Mantida: Al > -0.68 -> Ca ka > -1.50 (0.1478)
# Removida: Rayleight scattering > -0.50 -> Al > -0.19 (0.1006) | Mantida: Al > -0.19 -> Rayleight scattering > -0.50 (0.2143)
# Removida: Ti kb > -0.32 -> Rayleight scattering > -0.50 (0.0744) | Mantida: Rayleight scattering > -0.50 -> Ti kb > -0.32 (0.1016)
# Removida: Al > -0.19 -> sum Fe > -0.60 (0.1075) | Mantida: sum Fe > -0.60 -> Al > -0.19 (0.3351)
# Removida: Ti kb > -0.32 -> Al <= 0.62 (0.1720) | Mantida: Al <= 0.62 -> Ti kb > -0.32 (0.3247)
# Removida: Ti kb > -0.32 -> P > 0.08 (0.0868) | Mantida: P > 0.08 -> Ti kb > -0.32 (0.1025)
# Removida: P > 0.08 -> P > -0.59 (0.0626) | Mantida: P > -0.59 -> P > 0.08 (0.1237)
# Removida: background2 > 0.35 -> background2 > -0.51 (0.0741) | Mantida: background2 > -0.51 -> background2 > 0.35 (0.1835)
# Removida: background2 <= -0.51 -> background2 > 0.35 (0.0195) | Mantida: background2 > 0.35 -> background2 <= -0.51 (0.0638)
# Removida: Cu <= -0.12 -> background2 > 0.35 (0.0383) | Mantida: background2 > 0.35 -> Cu <= -0.12 (0.0528)
# Removida: background2 <= -0.51 -> P > -0.59 (0.0680) | Mantida: P > -0.59 -> background2 <= -0.51 (0.1560)
# Removida: background2 <= -0.51 -> Ti kb > 0.03 (0.0719) | Mantida: Ti kb > 0.03 -> background2 <= -0.51 (0.1398)
# Removida: Ti kb > -0.14 -> background2 > -1.35 (0.0724) | Mantida: background2 > -1.35 -> Ti kb > -0.14 (0.1828)
# Removida: Ti kb > 0.03 -> Ti kb > -0.14 (0.0585) | Mantida: Ti kb > -0.14 -> Ti kb > 0.03 (0.2258)
# Removida: Mn <= 1.01 -> Ti ka <= 0.53 (0.0518) | Mantida: Ti ka <= 0.53 -> Mn <= 1.01 (0.0561)
# Removida: P <= 0.08 -> P <= -0.59 (0.0608) | Mantida: P <= -0.59 -> P <= 0.08 (0.0671)
# Removida: Ca kb > -0.59 -> P <= -0.59 (0.0538) | Mantida: P <= -0.59 -> Ca kb > -0.59 (0.0578)
# Removida: sum Fe <= -0.28 -> P <= -0.59 (0.0391) | Mantida: P <= -0.59 -> sum Fe <= -0.28 (0.0513)
# Removida: P <= 1.06 -> sum Fe <= -0.28 (0.0952) | Mantida: sum Fe <= -0.28 -> P <= 1.06 (0.1039)
# Removida: P <= 1.06 -> Ni > -0.14 (0.0324) | Mantida: Ni > -0.14 -> P <= 1.06 (0.0353)
# Removida: Cu <= -0.12 -> background3 <= -0.62 (0.0486) | Mantida: background3 <= -0.62 -> Cu <= -0.12 (0.0870)
# Removida: Ni > -0.14 -> Fe kb <= 0.33 (0.0413) | Mantida: Fe kb <= 0.33 -> Ni > -0.14 (0.0445)
# Removida: S <= -0.27 -> Fe kb <= 0.33 (0.0429) | Mantida: Fe kb <= 0.33 -> S <= -0.27 (0.0434)
# Removida: Ni > -0.14 -> Compton scattering <= -0.40 (0.0266) | Mantida: Compton scattering <= -0.40 -> Ni > -0.14 (0.0440)
# Removida: S <= 0.55 -> Ca ka > 1.77 (0.0301) | Mantida: Ca ka > 1.77 -> S <= 0.55 (0.0346)
# Removida: S <= 0.55 -> Ni <= -0.14 (0.0244) | Mantida: Ni <= -0.14 -> S <= 0.55 (0.0272)
# Removida: Rayleight scattering <= -0.24 -> Cu <= 0.09 (0.0267) | Mantida: Cu <= 0.09 -> Rayleight scattering <= -0.24 (0.0347)
# Removida: S <= -0.27 -> Al > 0.19 (0.0323) | Mantida: Al > 0.19 -> S <= -0.27 (0.0365)
# Removida: Ni <= -0.14 -> S <= -0.27 (0.0200) | Mantida: S <= -0.27 -> Ni <= -0.14 (0.0344)
# Removida: background1 > 0.11 -> Zn <= 0.34 (0.0211) | Mantida: Zn <= 0.34 -> background1 > 0.11 (0.0230)
# Removida: background1 > 0.11 -> Zn <= 0.10 (0.0149) | Mantida: Zn <= 0.10 -> background1 > 0.11 (0.0268)
# Removida: background1 > 0.11 -> Cu > -0.55 (0.0160) | Mantida: Cu > -0.55 -> background1 > 0.11 (0.0196)
# Removida: background2 <= 0.35 -> S <= 0.09 (0.0266) | Mantida: S <= 0.09 -> background2 <= 0.35 (0.0661)
# Removida: Ti kb <= 0.20 -> Al <= -0.19 (0.0135) | Mantida: Al <= -0.19 -> Ti kb <= 0.20 (0.0176)
# Removida: background1 <= 0.30 -> Al <= 0.19 (0.0144) | Mantida: Al <= 0.19 -> background1 <= 0.30 (0.0255)
# Removida: Mn > -0.41 -> Ca kb > 0.62 (0.0121) | Mantida: Ca kb > 0.62 -> Mn > -0.41 (0.0124)
# Removida: background1 <= 0.30 -> Zn <= 0.34 (0.0187) | Mantida: Zn <= 0.34 -> background1 <= 0.30 (0.0339)
# Removida: Ni > -0.60 -> Al > 0.19 (0.0148) | Mantida: Al > 0.19 -> Ni > -0.60 (0.0255)
# Removida: Rayleight scattering <= 0.03 -> Rh L + Ar <= 1.37 (0.0116) | Mantida: Rh L + Ar <= 1.37 -> Rayleight scattering <= 0.03 (0.0140)
# Removida: Zn <= 0.10 -> background1 <= 0.30 (0.0159) | Mantida: background1 <= 0.30 -> Zn <= 0.10 (0.0341)
# Removida: Zn <= -0.11 -> Ni > 0.13 (0.0106) | Mantida: Ni > 0.13 -> Zn <= -0.11 (0.0146)
# Removida: sum Fe <= 0.07 -> Si <= -0.72 (0.0218) | Mantida: Si <= -0.72 -> sum Fe <= 0.07 (0.0468)
# Removida: Zn > 0.10 -> Ni <= -0.14 (0.0090) | Mantida: Ni <= -0.14 -> Zn > 0.10 (0.0094)
# Removida: background1 <= -0.08 -> background3 <= 1.47 (0.0089) | Mantida: background3 <= 1.47 -> background1 <= -0.08 (0.0132)
# Removida: Rayleight scattering <= 0.03 -> Ca kb > 0.62 (0.0111) | Mantida: Ca kb > 0.62 -> Rayleight scattering <= 0.03 (0.0155)
# Removida: Si <= -1.67 -> Ca kb > 0.62 (0.0145) | Mantida: Ca kb > 0.62 -> Si <= -1.67 (0.0153)
# Removida: background1 > -0.08 -> Cu > -0.55 (0.0109) | Mantida: Cu > -0.55 -> background1 > -0.08 (0.0135)
# Removida: background1 > -0.08 -> Cu <= 0.56 (0.0098) | Mantida: Cu <= 0.56 -> background1 > -0.08 (0.0160)
# Removida: Cu <= 0.56 -> Zn > -0.11 (0.0122) | Mantida: Zn > -0.11 -> Cu <= 0.56 (0.0158)
# Removida: background1 <= 0.11 -> background3 <= 1.47 (0.0093) | Mantida: background3 <= 1.47 -> background1 <= 0.11 (0.0110)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 840 | Removidas: 101
# Nós predicados: 125
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 118
# Removida: Fe ka > -2.26 -> Fe ka > -3.74 (2.2748) | Mantida: Fe ka > -3.74 -> Fe ka > -2.26 (19.5113)
# Removida: Si > -1.67 -> Ca ka <= 3.95 (1.1802) | Mantida: Ca ka <= 3.95 -> Si > -1.67 (4.3919)
# Removida: Si > -1.67 -> Si > -2.51 (4.6611) | Mantida: Si > -2.51 -> Si > -1.67 (5.8484)
# Removida: K <= 6.26 -> Si > -2.51 (1.1614) | Mantida: Si > -2.51 -> K <= 6.26 (3.3814)
# Removida: K > -1.46 -> K <= 6.26 (2.9027) | Mantida: K <= 6.26 -> K > -1.46 (3.0178)
# Removida: Ca ka <= 1.77 -> K <= 6.26 (0.8842) | Mantida: K <= 6.26 -> Ca ka <= 1.77 (5.1109)
# Removida: Ca ka <= 1.77 -> K > -1.46 (2.6207) | Mantida: K > -1.46 -> Ca ka <= 1.77 (2.8436)
# Removida: Si > -0.72 -> K > -1.46 (0.7928) | Mantida: K > -1.46 -> Si > -0.72 (2.7072)
# Removida: Ca kb <= 1.57 -> Rh L + Ar > -0.77 (0.4853) | Mantida: Rh L + Ar > -0.77 -> Ca kb <= 1.57 (0.4866)
# Removida: Ca kb <= 1.57 -> Ti ka > -0.70 (0.4624) | Mantida: Ti ka > -0.70 -> Ca kb <= 1.57 (0.5398)
# Removida: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (1.2309) | Mantida: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (1.2550)
# Removida: Rh L + Ar > -0.77 -> Si <= 3.71 (0.4833) | Mantida: Si <= 3.71 -> Rh L + Ar > -0.77 (0.4921)
# Removida: Ca kb <= 0.62 -> Rh L + Ar > -0.77 (0.3864) | Mantida: Rh L + Ar > -0.77 -> Ca kb <= 0.62 (0.3993)
# Removida: Rh L + Ar > -0.77 -> K <= 2.15 (0.3191) | Mantida: K <= 2.15 -> Rh L + Ar > -0.77 (0.3384)
# Removida: Fe kb > -0.44 -> Rh L + Ar > -0.16 (0.4214) | Mantida: Rh L + Ar > -0.16 -> Fe kb > -0.44 (0.7955)
# Removida: K <= 2.15 -> Rh L + Ar > -1.66 (0.3301) | Mantida: Rh L + Ar > -1.66 -> K <= 2.15 (0.8580)
# Removida: background3 > 0.14 -> K <= 2.15 (0.3088) | Mantida: K <= 2.15 -> background3 > 0.14 (0.3270)
# Removida: Ca ka <= -1.50 -> Ti ka > -0.86 (0.4145) | Mantida: Ti ka > -0.86 -> Ca ka <= -1.50 (0.4275)
# Removida: Fe kb > -0.63 -> Ti ka > -0.86 (1.5593) | Mantida: Ti ka > -0.86 -> Fe kb > -0.63 (2.5282)
# Removida: Ti ka > -0.52 -> Ca ka <= -1.50 (0.4725) | Mantida: Ca ka <= -1.50 -> Ti ka > -0.52 (0.7997)
# Removida: Ca kb <= 0.62 -> Ca ka <= -1.50 (0.3836) | Mantida: Ca ka <= -1.50 -> Ca kb <= 0.62 (1.2542)
# Removida: Ca ka <= -1.50 -> K > 2.15 (0.3450) | Mantida: K > 2.15 -> Ca ka <= -1.50 (0.4854)
# Removida: Ti ka > -0.52 -> Fe kb > -0.63 (0.4227) | Mantida: Fe kb > -0.63 -> Ti ka > -0.52 (0.5164)
# Removida: Fe kb > -0.44 -> Ti ka > -0.52 (0.4336) | Mantida: Ti ka > -0.52 -> Fe kb > -0.44 (1.8183)
# Removida: Ti ka > -0.52 -> Ca kb <= 0.62 (0.3900) | Mantida: Ca kb <= 0.62 -> Ti ka > -0.52 (0.3917)
# Removida: Si <= 3.71 -> Ca kb <= 0.62 (0.7940) | Mantida: Ca kb <= 0.62 -> Si <= 3.71 (1.1463)
# Removida: background3 > 0.14 -> Si <= 3.71 (0.2655) | Mantida: Si <= 3.71 -> background3 > 0.14 (0.3868)
# Removida: Ca kb <= 0.62 -> Fe kb > -0.44 (0.3674) | Mantida: Fe kb > -0.44 -> Ca kb <= 0.62 (0.4064)
# Removida: background3 > 0.14 -> Ca kb > -1.81 (0.5535) | Mantida: Ca kb > -1.81 -> background3 > 0.14 (0.5611)
# Removida: background3 > -0.62 -> Ca kb > -1.81 (0.7705) | Mantida: Ca kb > -1.81 -> background3 > -0.62 (1.0700)
# Removida: background3 > 0.14 -> K > 2.15 (1.1044) | Mantida: K > 2.15 -> background3 > 0.14 (1.3997)
# Removida: background3 > -0.62 -> Fe ka <= 1.10 (0.2148) | Mantida: Fe ka <= 1.10 -> background3 > -0.62 (0.4741)
# Removida: Compton scattering > 0.05 -> Fe ka <= 1.10 (0.1986) | Mantida: Fe ka <= 1.10 -> Compton scattering > 0.05 (0.2413)
# Removida: Fe ka <= 1.10 -> background3 > -1.28 (0.2022) | Mantida: background3 > -1.28 -> Fe ka <= 1.10 (0.6505)
# Removida: Fe ka <= 1.10 -> Compton scattering > -0.40 (0.2463) | Mantida: Compton scattering > -0.40 -> Fe ka <= 1.10 (0.3807)
# Removida: Ca kb <= -0.59 -> Compton scattering > 0.05 (0.1968) | Mantida: Compton scattering > 0.05 -> Ca kb <= -0.59 (0.3498)
# Removida: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.4170) | Mantida: Compton scattering > 0.05 -> Compton scattering > -0.40 (1.1837)
# Removida: Compton scattering > -0.88 -> Ca kb <= -0.59 (0.3605) | Mantida: Ca kb <= -0.59 -> Compton scattering > -0.88 (0.3905)
# Removida: sum Fe > -0.28 -> Ca kb <= -0.59 (0.1494) | Mantida: Ca kb <= -0.59 -> sum Fe > -0.28 (0.1880)
# Removida: Ca ka > -1.50 -> K <= -1.46 (0.0778) | Mantida: K <= -1.46 -> Ca ka > -1.50 (0.1275)
# Removida: background3 > -1.28 -> Compton scattering > -0.40 (0.2193) | Mantida: Compton scattering > -0.40 -> background3 > -1.28 (0.7207)
# Removida: Al > -0.68 -> Compton scattering > -0.88 (0.1384) | Mantida: Compton scattering > -0.88 -> Al > -0.68 (0.2998)
# Removida: sum Fe > -0.28 -> Al > -0.68 (0.1483) | Mantida: Al > -0.68 -> sum Fe > -0.28 (0.3082)
# Removida: Rayleight scattering > -0.24 -> Al > -0.68 (0.1454) | Mantida: Al > -0.68 -> Rayleight scattering > -0.24 (0.4505)
# Removida: sum Fe > 0.07 -> Al > -0.68 (0.1415) | Mantida: Al > -0.68 -> sum Fe > 0.07 (0.2838)
# Removida: Compton scattering > -0.88 -> Ca ka > -1.50 (0.1203) | Mantida: Ca ka > -1.50 -> Compton scattering > -0.88 (0.1352)
# Removida: Compton scattering > -0.88 -> Rayleight scattering > 0.03 (0.1164) | Mantida: Rayleight scattering > 0.03 -> Compton scattering > -0.88 (0.2499)
# Removida: Ca ka > -1.50 -> sum Fe > -0.28 (0.1207) | Mantida: sum Fe > -0.28 -> Ca ka > -1.50 (0.1400)
# Removida: Ca ka > -1.50 -> sum Fe > 0.07 (0.1307) | Mantida: sum Fe > 0.07 -> Ca ka > -1.50 (0.1332)
# Removida: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.1083) | Mantida: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.2676)
# Removida: Rayleight scattering > 0.03 -> sum Fe > 0.07 (0.1393) | Mantida: sum Fe > 0.07 -> Rayleight scattering > 0.03 (0.3881)
# Removida: Rayleight scattering > -0.24 -> Rayleight scattering > 0.03 (0.1229) | Mantida: Rayleight scattering > 0.03 -> Rayleight scattering > -0.24 (0.3857)
# Removida: Al <= 0.62 -> Al > -0.19 (0.1050) | Mantida: Al > -0.19 -> Al <= 0.62 (0.3357)
# Removida: P > -1.23 -> Al > -0.19 (0.1164) | Mantida: Al > -0.19 -> P > -1.23 (0.1199)
# Removida: Al > -0.19 -> Rayleight scattering > -0.50 (0.2140) | Mantida: Rayleight scattering > -0.50 -> Al > -0.19 (0.3312)
# Removida: Ti kb > -0.32 -> Al > -0.19 (0.0873) | Mantida: Al > -0.19 -> Ti kb > -0.32 (0.2313)
# Removida: Rayleight scattering > -0.50 -> Al <= 0.62 (0.0907) | Mantida: Al <= 0.62 -> Rayleight scattering > -0.50 (0.1079)
# Removida: P > 0.08 -> Rayleight scattering > -0.50 (0.1049) | Mantida: Rayleight scattering > -0.50 -> P > 0.08 (0.1538)
# Removida: P > 0.08 -> P > -0.59 (0.1082) | Mantida: P > -0.59 -> P > 0.08 (0.1231)
# Removida: Rayleight scattering > -0.50 -> sum Fe > -0.60 (0.1950) | Mantida: sum Fe > -0.60 -> Rayleight scattering > -0.50 (0.3117)
# Removida: Ti kb > -0.32 -> sum Fe > -0.60 (0.0715) | Mantida: sum Fe > -0.60 -> Ti kb > -0.32 (0.3063)
# Removida: Ti kb > -0.32 -> P > -1.23 (0.0841) | Mantida: P > -1.23 -> Ti kb > -0.32 (0.1172)
# Removida: Compton scattering <= -0.40 -> Mn > 0.23 (0.0334) | Mantida: Mn > 0.23 -> Compton scattering <= -0.40 (0.0582)
# Removida: background2 <= -0.51 -> background2 > 0.35 (0.0547) | Mantida: background2 > 0.35 -> background2 <= -0.51 (0.2664)
# Removida: P <= 1.06 -> sum Fe <= -0.28 (0.0340) | Mantida: sum Fe <= -0.28 -> P <= 1.06 (0.0345)
# Removida: background2 > -1.35 -> Ti kb > -0.14 (0.0983) | Mantida: Ti kb > -0.14 -> background2 > -1.35 (0.1522)
# Removida: Ti kb > 0.03 -> background3 <= -0.62 (0.0748) | Mantida: background3 <= -0.62 -> Ti kb > 0.03 (0.0797)
# Removida: P > -0.59 -> P <= 0.08 (0.0577) | Mantida: P <= 0.08 -> P > -0.59 (0.0635)
# Removida: P <= -0.59 -> P <= 0.08 (0.0482) | Mantida: P <= 0.08 -> P <= -0.59 (0.1158)
# Removida: P <= 0.08 -> Ti ka <= 0.53 (0.0403) | Mantida: Ti ka <= 0.53 -> P <= 0.08 (0.0605)
# Removida: Ti ka <= 0.53 -> P > -0.59 (0.0622) | Mantida: P > -0.59 -> Ti ka <= 0.53 (0.0626)
# Removida: Ti ka <= 0.53 -> background2 > 0.35 (0.0500) | Mantida: background2 > 0.35 -> Ti ka <= 0.53 (0.1124)
# Removida: Cu <= -0.12 -> S <= 0.09 (0.0399) | Mantida: S <= 0.09 -> Cu <= -0.12 (0.0402)
# Removida: Cu <= -0.12 -> S <= -0.27 (0.0358) | Mantida: S <= -0.27 -> Cu <= -0.12 (0.0524)
# Removida: S <= -0.27 -> Fe kb <= 0.33 (0.0345) | Mantida: Fe kb <= 0.33 -> S <= -0.27 (0.0397)
# Removida: sum Fe <= -0.28 -> background3 <= -0.62 (0.0316) | Mantida: background3 <= -0.62 -> sum Fe <= -0.28 (0.0494)
# Removida: background3 <= -0.62 -> background2 > -1.35 (0.0822) | Mantida: background2 > -1.35 -> background3 <= -0.62 (0.0836)
# Removida: sum Fe <= -0.28 -> Ca kb > -0.59 (0.0463) | Mantida: Ca kb > -0.59 -> sum Fe <= -0.28 (0.0511)
# Removida: sum Fe <= -0.28 -> Rh L + Ar <= 1.37 (0.0256) | Mantida: Rh L + Ar <= 1.37 -> sum Fe <= -0.28 (0.0379)
# Removida: Cu <= 0.09 -> Ca kb > -0.59 (0.0268) | Mantida: Ca kb > -0.59 -> Cu <= 0.09 (0.0629)
# Removida: Compton scattering <= -0.40 -> background2 <= 0.35 (0.0586) | Mantida: background2 <= 0.35 -> Compton scattering <= -0.40 (0.1276)
# Removida: Compton scattering <= -0.40 -> Al > 0.19 (0.0286) | Mantida: Al > 0.19 -> Compton scattering <= -0.40 (0.0322)
# Removida: Rh L + Ar <= 1.37 -> Ni > -0.14 (0.0260) | Mantida: Ni > -0.14 -> Rh L + Ar <= 1.37 (0.0281)
# Removida: Ni > -0.14 -> Fe kb <= 0.33 (0.0300) | Mantida: Fe kb <= 0.33 -> Ni > -0.14 (0.0452)
# Removida: Cu <= 0.09 -> Ni > -0.14 (0.0330) | Mantida: Ni > -0.14 -> Cu <= 0.09 (0.0385)
# Removida: Si <= -0.72 -> Ni > -0.60 (0.0199) | Mantida: Ni > -0.60 -> Si <= -0.72 (0.0213)
# Removida: Ni > -0.60 -> Rayleight scattering <= 0.03 (0.0127) | Mantida: Rayleight scattering <= 0.03 -> Ni > -0.60 (0.0170)
# Removida: Ni <= 0.13 -> background3 <= 0.14 (0.0357) | Mantida: background3 <= 0.14 -> Ni <= 0.13 (0.0617)
# Removida: background2 <= 0.35 -> background3 <= 0.14 (0.0568) | Mantida: background3 <= 0.14 -> background2 <= 0.35 (0.0661)
# Removida: Ni <= 0.13 -> Fe kb <= 0.33 (0.0310) | Mantida: Fe kb <= 0.33 -> Ni <= 0.13 (0.0834)
# Removida: Ni <= 0.13 -> Mn <= 1.01 (0.0333) | Mantida: Mn <= 1.01 -> Ni <= 0.13 (0.0562)
# Removida: Fe kb <= 0.33 -> background2 <= 0.35 (0.0373) | Mantida: background2 <= 0.35 -> Fe kb <= 0.33 (0.0393)
# Removida: background2 <= 0.35 -> S <= 0.55 (0.0337) | Mantida: S <= 0.55 -> background2 <= 0.35 (0.0409)
# Removida: Cu <= 0.09 -> background2 <= 0.35 (0.0257) | Mantida: background2 <= 0.35 -> Cu <= 0.09 (0.0355)
# Removida: background3 <= 1.47 -> S <= 0.55 (0.0302) | Mantida: S <= 0.55 -> background3 <= 1.47 (0.0363)
# Removida: Mn > -0.41 -> Cu > -0.55 (0.0099) | Mantida: Cu > -0.55 -> Mn > -0.41 (0.0301)
# Removida: background1 <= 0.30 -> Cu > -0.55 (0.0144) | Mantida: Cu > -0.55 -> background1 <= 0.30 (0.0157)
# Removida: Rayleight scattering <= -0.24 -> Cu <= 0.09 (0.0273) | Mantida: Cu <= 0.09 -> Rayleight scattering <= -0.24 (0.0371)
# Removida: Ni <= -0.14 -> Si <= -0.72 (0.0177) | Mantida: Si <= -0.72 -> Ni <= -0.14 (0.0321)
# Removida: Ti kb <= 0.20 -> Si <= -0.72 (0.0208) | Mantida: Si <= -0.72 -> Ti kb <= 0.20 (0.0237)
# Removida: Ni <= -0.14 -> Zn <= 0.10 (0.0156) | Mantida: Zn <= 0.10 -> Ni <= -0.14 (0.0183)
# Removida: Zn <= -0.11 -> Mn > -1.22 (0.0136) | Mantida: Mn > -1.22 -> Zn <= -0.11 (0.0161)
# Removida: Al <= 0.19 -> Ti kb <= 0.20 (0.0258) | Mantida: Ti kb <= 0.20 -> Al <= 0.19 (0.0544)
# Removida: Ti kb <= 0.20 -> Ca ka > 1.77 (0.0181) | Mantida: Ca ka > 1.77 -> Ti kb <= 0.20 (0.0271)
# Removida: background1 > 0.11 -> Si <= -1.67 (0.0278) | Mantida: Si <= -1.67 -> background1 > 0.11 (0.0413)
# Removida: background1 > 0.11 -> Zn <= 0.34 (0.0166) | Mantida: Zn <= 0.34 -> background1 > 0.11 (0.0360)
# Removida: Cu <= 0.56 -> Zn <= 0.34 (0.0153) | Mantida: Zn <= 0.34 -> Cu <= 0.56 (0.0242)
# Removida: Rh L + Ar <= -0.77 -> Al > 0.19 (0.0293) | Mantida: Al > 0.19 -> Rh L + Ar <= -0.77 (0.0464)
# Removida: Zn <= 0.10 -> Ni <= 0.59 (0.0117) | Mantida: Ni <= 0.59 -> Zn <= 0.10 (0.0191)
# Removida: Ti kb <= 0.20 -> Al <= -0.19 (0.0106) | Mantida: Al <= -0.19 -> Ti kb <= 0.20 (0.0161)
# Removida: Ni > 0.13 -> Rh L + Ar <= -0.16 (0.0107) | Mantida: Rh L + Ar <= -0.16 -> Ni > 0.13 (0.0184)
# Removida: Ni > 0.13 -> Rayleight scattering <= 0.53 (0.0085) | Mantida: Rayleight scattering <= 0.53 -> Ni > 0.13 (0.0120)
# Removida: background1 <= 0.11 -> Al <= -0.19 (0.0104) | Mantida: Al <= -0.19 -> background1 <= 0.11 (0.0120)
# Removida: Al <= -0.19 -> Zn <= -0.11 (0.0133) | Mantida: Zn <= -0.11 -> Al <= -0.19 (0.0145)
# Removida: background1 > -0.26 -> Zn > -0.11 (0.0092) | Mantida: Zn > -0.11 -> background1 > -0.26 (0.0124)
# Removida: Ni <= 0.59 -> Ca kb > 0.62 (0.0098) | Mantida: Ca kb > 0.62 -> Ni <= 0.59 (0.0122)
# Removida: background1 <= 0.11 -> Fe ka <= -2.26 (0.0094) | Mantida: Fe ka <= -2.26 -> background1 <= 0.11 (0.0105)
# Removida: background1 <= 0.11 -> Compton scattering <= 0.87 (0.0099) | Mantida: Compton scattering <= 0.87 -> background1 <= 0.11 (0.0148)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 830 | Removidas: 118
# Nós predicados: 124
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 114
# Removida: Ca ka <= 3.95 -> K > -6.69 (1.1862) | Mantida: K > -6.69 -> Ca ka <= 3.95 (11.8674)
# Removida: K <= 6.26 -> Si > -1.67 (2.3806) | Mantida: Si > -1.67 -> K <= 6.26 (4.6174)
# Removida: Si > -1.67 -> Si > -2.51 (2.3377) | Mantida: Si > -2.51 -> Si > -1.67 (3.6252)
# Removida: K <= 6.26 -> Si > -2.51 (2.2474) | Mantida: Si > -2.51 -> K <= 6.26 (4.7298)
# Removida: K <= 6.26 -> K > -1.46 (1.0698) | Mantida: K > -1.46 -> K <= 6.26 (2.0221)
# Removida: K > -1.46 -> Ca ka <= 1.77 (0.9771) | Mantida: Ca ka <= 1.77 -> K > -1.46 (5.1850)
# Removida: Si > -0.72 -> K > -1.46 (0.8890) | Mantida: K > -1.46 -> Si > -0.72 (4.4322)
# Removida: Ca ka > -4.65 -> Si > -0.72 (0.7819) | Mantida: Si > -0.72 -> Ca ka > -4.65 (6.5487)
# Removida: Ca kb <= 1.57 -> Ti ka > -0.70 (0.4998) | Mantida: Ti ka > -0.70 -> Ca kb <= 1.57 (0.5284)
# Removida: Rh L + Ar > -1.66 -> Si <= 3.71 (0.3833) | Mantida: Si <= 3.71 -> Rh L + Ar > -1.66 (0.8230)
# Removida: Si <= 3.71 -> Ca kb <= 0.62 (0.8466) | Mantida: Ca kb <= 0.62 -> Si <= 3.71 (1.5327)
# Removida: Si <= 3.71 -> Ti ka > -0.52 (0.4790) | Mantida: Ti ka > -0.52 -> Si <= 3.71 (1.3199)
# Removida: Fe kb > -0.63 -> Ti ka > -0.86 (1.5948) | Mantida: Ti ka > -0.86 -> Fe kb > -0.63 (3.0068)
# Removida: Fe kb > -0.91 -> Fe kb > -0.63 (0.5053) | Mantida: Fe kb > -0.63 -> Fe kb > -0.91 (1.4836)
# Removida: Ti ka > -0.52 -> Fe kb > -0.44 (0.9092) | Mantida: Fe kb > -0.44 -> Ti ka > -0.52 (1.3808)
# Removida: Fe kb > -0.91 -> Ti ka > -0.52 (0.4340) | Mantida: Ti ka > -0.52 -> Fe kb > -0.91 (0.5339)
# Removida: Ti ka > -0.52 -> Rh L + Ar > -0.77 (0.4377) | Mantida: Rh L + Ar > -0.77 -> Ti ka > -0.52 (0.9103)
# Removida: Ca ka <= -1.50 -> K <= 2.15 (0.4071) | Mantida: K <= 2.15 -> Ca ka <= -1.50 (0.8882)
# Removida: Rh L + Ar > -1.66 -> K <= 2.15 (0.7625) | Mantida: K <= 2.15 -> Rh L + Ar > -1.66 (0.8198)
# Removida: Ca ka <= -1.50 -> Ca kb <= 0.62 (0.3590) | Mantida: Ca kb <= 0.62 -> Ca ka <= -1.50 (0.4053)
# Removida: Ca kb <= 0.62 -> Rh L + Ar > -0.77 (0.3851) | Mantida: Rh L + Ar > -0.77 -> Ca kb <= 0.62 (0.4124)
# Removida: K > 2.15 -> Ca kb <= 0.62 (0.3661) | Mantida: Ca kb <= 0.62 -> K > 2.15 (0.3770)
# Removida: background3 > 0.14 -> Ca kb <= 0.62 (0.3523) | Mantida: Ca kb <= 0.62 -> background3 > 0.14 (0.3846)
# Removida: Ca ka <= -1.50 -> Fe kb > -0.44 (0.8232) | Mantida: Fe kb > -0.44 -> Ca ka <= -1.50 (1.3657)
# Removida: Ca ka <= -1.50 -> Rh L + Ar > -0.16 (0.3924) | Mantida: Rh L + Ar > -0.16 -> Ca ka <= -1.50 (0.4180)
# Removida: Fe kb > -0.44 -> Rh L + Ar > -0.77 (0.3725) | Mantida: Rh L + Ar > -0.77 -> Fe kb > -0.44 (0.3970)
# Removida: Fe kb > -0.44 -> Rh L + Ar > -0.16 (0.8271) | Mantida: Rh L + Ar > -0.16 -> Fe kb > -0.44 (0.8552)
# Removida: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (0.4187) | Mantida: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (1.6391)
# Removida: background3 > 0.14 -> Rh L + Ar > -1.66 (0.3503) | Mantida: Rh L + Ar > -1.66 -> background3 > 0.14 (0.6888)
# Removida: Rh L + Ar > -1.66 -> Rh L + Ar > -0.16 (0.3702) | Mantida: Rh L + Ar > -0.16 -> Rh L + Ar > -1.66 (0.6893)
# Removida: K > 2.15 -> Ca kb > -1.81 (0.3531) | Mantida: Ca kb > -1.81 -> K > 2.15 (1.1733)
# Removida: background3 > -0.62 -> K > 2.15 (0.2688) | Mantida: K > 2.15 -> background3 > -0.62 (0.8474)
# Removida: background3 > -0.62 -> background3 > 0.14 (0.2428) | Mantida: background3 > 0.14 -> background3 > -0.62 (0.4599)
# Removida: background3 > -0.62 -> Ca kb > -1.81 (0.2500) | Mantida: Ca kb > -1.81 -> background3 > -0.62 (0.8235)
# Removida: Compton scattering > 0.05 -> Fe ka <= 1.10 (0.2136) | Mantida: Fe ka <= 1.10 -> Compton scattering > 0.05 (0.4223)
# Removida: Fe ka <= 1.10 -> Ca kb <= -0.59 (0.1953) | Mantida: Ca kb <= -0.59 -> Fe ka <= 1.10 (0.5916)
# Removida: Compton scattering > -0.40 -> Fe ka <= 1.10 (0.1692) | Mantida: Fe ka <= 1.10 -> Compton scattering > -0.40 (0.2284)
# Removida: background3 > -1.28 -> Fe ka <= 1.10 (0.3926) | Mantida: Fe ka <= 1.10 -> background3 > -1.28 (0.4044)
# Removida: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.6365) | Mantida: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.6611)
# Removida: background3 > -1.28 -> Compton scattering > 0.05 (0.2059) | Mantida: Compton scattering > 0.05 -> background3 > -1.28 (0.3150)
# Removida: K <= -1.46 -> Ca kb <= -0.59 (0.1899) | Mantida: Ca kb <= -0.59 -> K <= -1.46 (0.3745)
# Removida: Al > -0.68 -> sum Fe > 0.07 (0.1284) | Mantida: sum Fe > 0.07 -> Al > -0.68 (0.2918)
# Removida: Ca ka > -1.50 -> Al > -0.68 (0.1268) | Mantida: Al > -0.68 -> Ca ka > -1.50 (0.2956)
# Removida: Rayleight scattering > -0.24 -> sum Fe > -0.28 (0.1371) | Mantida: sum Fe > -0.28 -> Rayleight scattering > -0.24 (0.1565)
# Removida: Compton scattering > -0.88 -> Rayleight scattering > -0.24 (0.2524) | Mantida: Rayleight scattering > -0.24 -> Compton scattering > -0.88 (0.2758)
# Removida: sum Fe > 0.07 -> Rayleight scattering > -0.24 (0.1194) | Mantida: Rayleight scattering > -0.24 -> sum Fe > 0.07 (0.1419)
# Removida: K <= -1.46 -> Compton scattering > -0.88 (0.1631) | Mantida: Compton scattering > -0.88 -> K <= -1.46 (0.1689)
# Removida: sum Fe > 0.07 -> Rayleight scattering > 0.03 (0.0914) | Mantida: Rayleight scattering > 0.03 -> sum Fe > 0.07 (0.1265)
# Removida: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.2994) | Mantida: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.5533)
# Removida: sum Fe > 0.07 -> Compton scattering > -0.88 (0.1298) | Mantida: Compton scattering > -0.88 -> sum Fe > 0.07 (0.2708)
# Removida: Compton scattering > -0.88 -> sum Fe > -0.28 (0.1288) | Mantida: sum Fe > -0.28 -> Compton scattering > -0.88 (0.2810)
# Removida: Ca ka > -1.50 -> sum Fe > -0.28 (0.1231) | Mantida: sum Fe > -0.28 -> Ca ka > -1.50 (0.1253)
# Removida: Al <= 0.62 -> Al > -0.19 (0.2211) | Mantida: Al > -0.19 -> Al <= 0.62 (0.2310)
# Removida: Ti kb > -0.32 -> Al > -0.19 (0.0926) | Mantida: Al > -0.19 -> Ti kb > -0.32 (0.1084)
# Removida: Al <= 0.62 -> sum Fe > -0.60 (0.1103) | Mantida: sum Fe > -0.60 -> Al <= 0.62 (0.2086)
# Removida: Ti kb > -0.32 -> Al <= 0.62 (0.0870) | Mantida: Al <= 0.62 -> Ti kb > -0.32 (0.3145)
# Removida: Al <= 0.62 -> Rayleight scattering > -0.50 (0.1082) | Mantida: Rayleight scattering > -0.50 -> Al <= 0.62 (0.1103)
# Removida: Ti kb > -0.14 -> Al <= 0.62 (0.0813) | Mantida: Al <= 0.62 -> Ti kb > -0.14 (0.1017)
# Removida: P > -1.23 -> sum Fe > -0.60 (0.2141) | Mantida: sum Fe > -0.60 -> P > -1.23 (0.2940)
# Removida: sum Fe > -0.60 -> Rayleight scattering > -0.50 (0.0933) | Mantida: Rayleight scattering > -0.50 -> sum Fe > -0.60 (0.0947)
# Removida: sum Fe > -0.60 -> background2 <= -0.51 (0.0840) | Mantida: background2 <= -0.51 -> sum Fe > -0.60 (0.0948)
# Removida: Ti kb > -0.14 -> P > -1.23 (0.0769) | Mantida: P > -1.23 -> Ti kb > -0.14 (0.0977)
# Removida: background2 <= -0.51 -> P > -1.23 (0.0860) | Mantida: P > -1.23 -> background2 <= -0.51 (0.1084)
# Removida: Rayleight scattering > -0.50 -> Ca ka > -1.50 (0.0826) | Mantida: Ca ka > -1.50 -> Rayleight scattering > -0.50 (0.0855)
# Removida: Ti kb > -0.32 -> Rayleight scattering > -0.50 (0.0876) | Mantida: Rayleight scattering > -0.50 -> Ti kb > -0.32 (0.3010)
# Removida: Ca ka > -1.50 -> background2 > 0.35 (0.1291) | Mantida: background2 > 0.35 -> Ca ka > -1.50 (0.1340)
# Removida: P > 0.08 -> Ca kb > -0.59 (0.0501) | Mantida: Ca kb > -0.59 -> P > 0.08 (0.0504)
# Removida: P > 0.08 -> background2 <= 0.35 (0.0500) | Mantida: background2 <= 0.35 -> P > 0.08 (0.0694)
# Removida: background3 <= -0.62 -> P > -0.59 (0.0527) | Mantida: P > -0.59 -> background3 <= -0.62 (0.0794)
# Removida: background3 <= -0.62 -> Mn > 0.23 (0.0717) | Mantida: Mn > 0.23 -> background3 <= -0.62 (0.0722)
# Removida: Mn <= 1.01 -> background3 <= -0.62 (0.0453) | Mantida: background3 <= -0.62 -> Mn <= 1.01 (0.0688)
# Removida: Ti kb > -0.14 -> background2 > -0.51 (0.0736) | Mantida: background2 > -0.51 -> Ti kb > -0.14 (0.1876)
# Removida: Ti kb > 0.03 -> Ti kb > -0.14 (0.0669) | Mantida: Ti kb > -0.14 -> Ti kb > 0.03 (0.0790)
# Removida: Ti kb > 0.03 -> Compton scattering <= -0.40 (0.0652) | Mantida: Compton scattering <= -0.40 -> Ti kb > 0.03 (0.0660)
# Removida: P <= -0.59 -> Compton scattering <= -0.40 (0.0601) | Mantida: Compton scattering <= -0.40 -> P <= -0.59 (0.0615)
# Removida: Mn > 0.23 -> Ti kb > 0.03 (0.0664) | Mantida: Ti kb > 0.03 -> Mn > 0.23 (0.2699)
# Removida: Ti kb > 0.03 -> background2 > -1.35 (0.0512) | Mantida: background2 > -1.35 -> Ti kb > 0.03 (0.0787)
# Removida: background2 > -0.51 -> Mn > 0.23 (0.0651) | Mantida: Mn > 0.23 -> background2 > -0.51 (0.0685)
# Removida: Cu <= -0.12 -> S <= -0.27 (0.0888) | Mantida: S <= -0.27 -> Cu <= -0.12 (0.1038)
# Removida: S <= -0.27 -> S <= 0.55 (0.0464) | Mantida: S <= 0.55 -> S <= -0.27 (0.1021)
# Removida: Ni <= 0.13 -> S <= -0.27 (0.0331) | Mantida: S <= -0.27 -> Ni <= 0.13 (0.0357)
# Removida: Cu <= -0.12 -> Cu <= 0.09 (0.0330) | Mantida: Cu <= 0.09 -> Cu <= -0.12 (0.0433)
# Removida: P <= 0.08 -> Mn > 0.23 (0.0462) | Mantida: Mn > 0.23 -> P <= 0.08 (0.0717)
# Removida: P <= 0.08 -> P <= -0.59 (0.0660) | Mantida: P <= -0.59 -> P <= 0.08 (0.0696)
# Removida: background2 <= 0.35 -> sum Fe <= -0.28 (0.0209) | Mantida: sum Fe <= -0.28 -> background2 <= 0.35 (0.0404)
# Removida: background3 <= 0.14 -> background2 <= 0.35 (0.0251) | Mantida: background2 <= 0.35 -> background3 <= 0.14 (0.0253)
# Removida: Cu <= 0.09 -> background2 <= 0.35 (0.0212) | Mantida: background2 <= 0.35 -> Cu <= 0.09 (0.0247)
# Removida: P <= 1.06 -> Fe kb <= 0.33 (0.0345) | Mantida: Fe kb <= 0.33 -> P <= 1.06 (0.0372)
# Removida: Ni > -0.14 -> Ca kb > -0.59 (0.0291) | Mantida: Ca kb > -0.59 -> Ni > -0.14 (0.0502)
# Removida: S <= 0.55 -> P <= -0.59 (0.0305) | Mantida: P <= -0.59 -> S <= 0.55 (0.0607)
# Removida: Ca ka > 1.77 -> S <= 0.09 (0.0257) | Mantida: S <= 0.09 -> Ca ka > 1.77 (0.0323)
# Removida: background1 > 0.11 -> Ni > -0.60 (0.0126) | Mantida: Ni > -0.60 -> background1 > 0.11 (0.0237)
# Removida: background3 <= 1.47 -> Al <= -0.19 (0.0147) | Mantida: Al <= -0.19 -> background3 <= 1.47 (0.0183)
# Removida: Rh L + Ar <= -0.77 -> S > -0.27 (0.0192) | Mantida: S > -0.27 -> Rh L + Ar <= -0.77 (0.0272)
# Removida: Rh L + Ar <= -0.77 -> S <= 0.09 (0.0286) | Mantida: S <= 0.09 -> Rh L + Ar <= -0.77 (0.0411)
# Removida: Zn <= 0.10 -> Rh L + Ar <= -0.77 (0.0215) | Mantida: Rh L + Ar <= -0.77 -> Zn <= 0.10 (0.0282)
# Removida: S <= 0.09 -> background3 <= 0.14 (0.0266) | Mantida: background3 <= 0.14 -> S <= 0.09 (0.0420)
# Removida: Zn <= -0.11 -> Ni <= -0.14 (0.0104) | Mantida: Ni <= -0.14 -> Zn <= -0.11 (0.0125)
# Removida: Cu <= 0.09 -> Al <= 0.19 (0.0246) | Mantida: Al <= 0.19 -> Cu <= 0.09 (0.0258)
# Removida: background1 > 0.11 -> Al <= 0.19 (0.0190) | Mantida: Al <= 0.19 -> background1 > 0.11 (0.0263)
# Removida: Zn <= 0.34 -> Al <= 0.19 (0.0183) | Mantida: Al <= 0.19 -> Zn <= 0.34 (0.0189)
# Removida: background1 > 0.11 -> Mn > -0.41 (0.0187) | Mantida: Mn > -0.41 -> background1 > 0.11 (0.0242)
# Removida: Ti kb <= 0.20 -> background1 > 0.11 (0.0134) | Mantida: background1 > 0.11 -> Ti kb <= 0.20 (0.0176)
# Removida: background1 > 0.11 -> Al > 0.19 (0.0172) | Mantida: Al > 0.19 -> background1 > 0.11 (0.0246)
# Removida: background1 > 0.11 -> sum Fe <= 0.07 (0.0113) | Mantida: sum Fe <= 0.07 -> background1 > 0.11 (0.0233)
# Removida: Zn <= 0.10 -> Mn > -0.41 (0.0178) | Mantida: Mn > -0.41 -> Zn <= 0.10 (0.0190)
# Removida: Ni <= 0.59 -> background1 <= -0.08 (0.0104) | Mantida: background1 <= -0.08 -> Ni <= 0.59 (0.0346)
# Removida: Ni <= 0.59 -> background1 <= 0.30 (0.0184) | Mantida: background1 <= 0.30 -> Ni <= 0.59 (0.0254)
# Removida: Zn <= 0.34 -> Al > 0.19 (0.0211) | Mantida: Al > 0.19 -> Zn <= 0.34 (0.0243)
# Removida: Zn <= 0.34 -> background1 <= 0.30 (0.0149) | Mantida: background1 <= 0.30 -> Zn <= 0.34 (0.0173)
# Removida: background1 <= 0.30 -> Si <= -0.72 (0.0163) | Mantida: Si <= -0.72 -> background1 <= 0.30 (0.0266)
# Removida: background1 <= 0.11 -> Ca kb > 0.62 (0.0106) | Mantida: Ca kb > 0.62 -> background1 <= 0.11 (0.0140)
# Removida: Al <= -0.19 -> Mn <= 0.23 (0.0099) | Mantida: Mn <= 0.23 -> Al <= -0.19 (0.0138)
# Removida: S > -0.55 -> Zn > -0.37 (0.0100) | Mantida: Zn > -0.37 -> S > -0.55 (0.0108)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 834 | Removidas: 114
# Nós predicados: 126
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 108
# Removida: Fe ka > -2.26 -> Fe ka > -3.74 (2.1803) | Mantida: Fe ka > -3.74 -> Fe ka > -2.26 (19.6075)
# Removida: Si > -2.51 -> Si > -1.67 (4.7336) | Mantida: Si > -1.67 -> Si > -2.51 (5.8175)
# Removida: K <= 6.26 -> Si > -2.51 (1.1083) | Mantida: Si > -2.51 -> K <= 6.26 (4.5347)
# Removida: Ca ka <= 1.77 -> K <= 6.26 (0.8696) | Mantida: K <= 6.26 -> Ca ka <= 1.77 (6.5546)
# Removida: K > -1.46 -> Ca ka <= 1.77 (2.9772) | Mantida: Ca ka <= 1.77 -> K > -1.46 (5.3058)
# Removida: Si > -0.72 -> K > -1.46 (0.9189) | Mantida: K > -1.46 -> Si > -0.72 (5.5515)
# Removida: Ca ka > -4.65 -> Si > -0.72 (0.6720) | Mantida: Si > -0.72 -> Ca ka > -4.65 (6.5035)
# Removida: Ca kb <= 1.57 -> Fe kb > -0.91 (0.9828) | Mantida: Fe kb > -0.91 -> Ca kb <= 1.57 (0.9928)
# Removida: Fe kb > -0.44 -> Ca kb <= 1.57 (0.4666) | Mantida: Ca kb <= 1.57 -> Fe kb > -0.44 (0.4857)
# Removida: Ca kb <= 1.57 -> Ti ka > -0.86 (0.4986) | Mantida: Ti ka > -0.86 -> Ca kb <= 1.57 (1.5357)
# Removida: Rh L + Ar > -0.16 -> K <= 2.15 (0.4277) | Mantida: K <= 2.15 -> Rh L + Ar > -0.16 (0.8807)
# Removida: Ca kb <= 0.62 -> K <= 2.15 (0.3808) | Mantida: K <= 2.15 -> Ca kb <= 0.62 (0.8198)
# Removida: K <= 2.15 -> Rh L + Ar > -1.66 (0.4587) | Mantida: Rh L + Ar > -1.66 -> K <= 2.15 (1.1645)
# Removida: Si <= 3.71 -> Rh L + Ar > -1.66 (0.4005) | Mantida: Rh L + Ar > -1.66 -> Si <= 3.71 (0.4397)
# Removida: Si <= 3.71 -> Ca kb <= 0.62 (0.4935) | Mantida: Ca kb <= 0.62 -> Si <= 3.71 (1.1668)
# Removida: Rh L + Ar > -0.77 -> Si <= 3.71 (0.4025) | Mantida: Si <= 3.71 -> Rh L + Ar > -0.77 (0.4418)
# Removida: Si <= 3.71 -> Ti ka > -0.52 (0.4498) | Mantida: Ti ka > -0.52 -> Si <= 3.71 (0.4638)
# Removida: Fe kb > -0.91 -> Ti ka > -0.86 (0.5045) | Mantida: Ti ka > -0.86 -> Fe kb > -0.91 (0.9965)
# Removida: Ti ka > -0.86 -> Fe kb > -0.63 (1.0918) | Mantida: Fe kb > -0.63 -> Ti ka > -0.86 (1.4951)
# Removida: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (0.9394) | Mantida: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (1.2304)
# Removida: Rh L + Ar > -0.77 -> Ca ka <= -1.50 (0.4634) | Mantida: Ca ka <= -1.50 -> Rh L + Ar > -0.77 (0.8231)
# Removida: Fe kb > -0.63 -> Ca ka <= -1.50 (0.3970) | Mantida: Ca ka <= -1.50 -> Fe kb > -0.63 (0.4293)
# Removida: Fe kb > -0.91 -> Fe kb > -0.63 (0.4705) | Mantida: Fe kb > -0.63 -> Fe kb > -0.91 (1.5463)
# Removida: Ca kb <= 0.62 -> Ca ka <= -1.50 (0.4219) | Mantida: Ca ka <= -1.50 -> Ca kb <= 0.62 (1.8192)
# Removida: Ti ka > -0.52 -> Fe kb > -0.91 (0.5028) | Mantida: Fe kb > -0.91 -> Ti ka > -0.52 (0.8615)
# Removida: Fe kb > -0.44 -> Ti ka > -0.52 (1.2927) | Mantida: Ti ka > -0.52 -> Fe kb > -0.44 (1.3510)
# Removida: Ca kb > -1.81 -> K > 2.15 (0.2967) | Mantida: K > 2.15 -> Ca kb > -1.81 (0.3452)
# Removida: K > 2.15 -> background3 > 0.14 (0.6608) | Mantida: background3 > 0.14 -> K > 2.15 (0.6960)
# Removida: Ca kb > -1.81 -> background3 > 0.14 (0.8291) | Mantida: background3 > 0.14 -> Ca kb > -1.81 (1.1394)
# Removida: background3 > -0.62 -> Ca kb > -1.81 (0.4937) | Mantida: Ca kb > -1.81 -> background3 > -0.62 (0.8392)
# Removida: Fe ka <= 1.10 -> background3 > -0.62 (0.2291) | Mantida: background3 > -0.62 -> Fe ka <= 1.10 (1.1334)
# Removida: Compton scattering > -0.40 -> Fe ka <= 1.10 (0.1912) | Mantida: Fe ka <= 1.10 -> Compton scattering > -0.40 (0.2247)
# Removida: Compton scattering > 0.05 -> background3 > -0.62 (0.1667) | Mantida: background3 > -0.62 -> Compton scattering > 0.05 (0.1933)
# Removida: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.5617) | Mantida: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.5809)
# Removida: Compton scattering > 0.05 -> background3 > -1.28 (0.3485) | Mantida: background3 > -1.28 -> Compton scattering > 0.05 (0.4397)
# Removida: Ca kb <= -0.59 -> Compton scattering > 0.05 (0.1816) | Mantida: Compton scattering > 0.05 -> Ca kb <= -0.59 (0.2015)
# Removida: Compton scattering > -0.40 -> Ca kb <= -0.59 (0.1649) | Mantida: Ca kb <= -0.59 -> Compton scattering > -0.40 (0.1952)
# Removida: background3 > -1.28 -> Compton scattering > -0.40 (0.3950) | Mantida: Compton scattering > -0.40 -> background3 > -1.28 (0.4151)
# Removida: background3 > -1.28 -> Ca kb <= -0.59 (0.1521) | Mantida: Ca kb <= -0.59 -> background3 > -1.28 (0.3625)
# Removida: Al > -0.68 -> Ca kb <= -0.59 (0.1544) | Mantida: Ca kb <= -0.59 -> Al > -0.68 (0.3354)
# Removida: Compton scattering > -0.88 -> Ca kb <= -0.59 (0.3210) | Mantida: Ca kb <= -0.59 -> Compton scattering > -0.88 (0.3608)
# Removida: Rayleight scattering > 0.03 -> Ca kb <= -0.59 (0.1365) | Mantida: Ca kb <= -0.59 -> Rayleight scattering > 0.03 (0.1609)
# Removida: K <= -1.46 -> sum Fe > -0.28 (0.1541) | Mantida: sum Fe > -0.28 -> K <= -1.46 (0.2953)
# Removida: Compton scattering > -0.88 -> K <= -1.46 (0.1378) | Mantida: K <= -1.46 -> Compton scattering > -0.88 (0.3244)
# Removida: sum Fe > -0.28 -> Al > -0.68 (0.2762) | Mantida: Al > -0.68 -> sum Fe > -0.28 (0.3116)
# Removida: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.1448) | Mantida: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.3878)
# Removida: Rayleight scattering > -0.24 -> Al > -0.68 (0.1401) | Mantida: Al > -0.68 -> Rayleight scattering > -0.24 (0.2981)
# Removida: sum Fe > 0.07 -> P > 0.08 (0.0891) | Mantida: P > 0.08 -> sum Fe > 0.07 (0.1571)
# Removida: Rayleight scattering > -0.24 -> sum Fe > 0.07 (0.1153) | Mantida: sum Fe > 0.07 -> Rayleight scattering > -0.24 (0.1312)
# Removida: Ti kb > -0.32 -> sum Fe > 0.07 (0.0771) | Mantida: sum Fe > 0.07 -> Ti kb > -0.32 (0.1107)
# Removida: Rayleight scattering > -0.24 -> Rayleight scattering > 0.03 (0.1052) | Mantida: Rayleight scattering > 0.03 -> Rayleight scattering > -0.24 (0.4831)
# Removida: Rayleight scattering > 0.03 -> Ca ka > -1.50 (0.1320) | Mantida: Ca ka > -1.50 -> Rayleight scattering > 0.03 (0.2516)
# Removida: Al > -0.19 -> Rayleight scattering > -0.24 (0.1167) | Mantida: Rayleight scattering > -0.24 -> Al > -0.19 (0.2183)
# Removida: sum Fe > -0.60 -> Al > -0.19 (0.2144) | Mantida: Al > -0.19 -> sum Fe > -0.60 (0.2301)
# Removida: Al <= 0.62 -> Al > -0.19 (0.1181) | Mantida: Al > -0.19 -> Al <= 0.62 (0.2167)
# Removida: P > 0.08 -> Al > -0.19 (0.1152) | Mantida: Al > -0.19 -> P > 0.08 (0.1167)
# Removida: sum Fe > -0.60 -> P > -0.59 (0.1109) | Mantida: P > -0.59 -> sum Fe > -0.60 (0.1455)
# Removida: sum Fe > -0.60 -> P > 0.08 (0.0735) | Mantida: P > 0.08 -> sum Fe > -0.60 (0.1233)
# Removida: Ti kb > -0.32 -> sum Fe > -0.60 (0.0884) | Mantida: sum Fe > -0.60 -> Ti kb > -0.32 (0.2179)
# Removida: Rayleight scattering > -0.50 -> sum Fe > -0.60 (0.0593) | Mantida: sum Fe > -0.60 -> Rayleight scattering > -0.50 (0.1200)
# Removida: Al <= 0.62 -> Rayleight scattering > -0.50 (0.2952) | Mantida: Rayleight scattering > -0.50 -> Al <= 0.62 (0.2990)
# Removida: Ti kb > -0.32 -> Al <= 0.62 (0.0911) | Mantida: Al <= 0.62 -> Ti kb > -0.32 (0.2056)
# Removida: P > -0.59 -> Al <= 0.62 (0.0861) | Mantida: Al <= 0.62 -> P > -0.59 (0.1041)
# Removida: Ti kb > -0.32 -> Rayleight scattering > -0.50 (0.0860) | Mantida: Rayleight scattering > -0.50 -> Ti kb > -0.32 (0.1576)
# Removida: Rayleight scattering > -0.50 -> P > -1.23 (0.0842) | Mantida: P > -1.23 -> Rayleight scattering > -0.50 (0.2391)
# Removida: Ti kb > -0.14 -> Ca ka > -1.50 (0.0732) | Mantida: Ca ka > -1.50 -> Ti kb > -0.14 (0.0913)
# Removida: Ti kb > 0.03 -> Ca ka > -1.50 (0.0737) | Mantida: Ca ka > -1.50 -> Ti kb > 0.03 (0.0847)
# Removida: Ti kb > -0.14 -> background2 > -0.51 (0.0700) | Mantida: background2 > -0.51 -> Ti kb > -0.14 (0.0965)
# Removida: Ti kb > -0.14 -> P > -1.23 (0.0584) | Mantida: P > -1.23 -> Ti kb > -0.14 (0.1052)
# Removida: P > 0.08 -> Ti kb > -0.14 (0.0779) | Mantida: Ti kb > -0.14 -> P > 0.08 (0.1569)
# Removida: Ti kb > -0.14 -> background2 <= -0.51 (0.0803) | Mantida: background2 <= -0.51 -> Ti kb > -0.14 (0.0903)
# Removida: background2 <= -0.51 -> background2 > -1.35 (0.0830) | Mantida: background2 > -1.35 -> background2 <= -0.51 (0.1516)
# Removida: Compton scattering <= -0.40 -> Ti ka <= 0.53 (0.1121) | Mantida: Ti ka <= 0.53 -> Compton scattering <= -0.40 (0.1145)
# Removida: sum Fe <= -0.28 -> P <= 0.08 (0.0491) | Mantida: P <= 0.08 -> sum Fe <= -0.28 (0.0546)
# Removida: P <= 0.08 -> background3 <= -0.62 (0.0617) | Mantida: background3 <= -0.62 -> P <= 0.08 (0.0676)
# Removida: Mn > -1.22 -> Rh L + Ar <= -0.77 (0.0429) | Mantida: Rh L + Ar <= -0.77 -> Mn > -1.22 (0.0608)
# Removida: Ni > -0.60 -> Mn > -1.22 (0.0379) | Mantida: Mn > -1.22 -> Ni > -0.60 (0.0411)
# Removida: Fe kb <= 0.33 -> S <= 0.55 (0.0437) | Mantida: S <= 0.55 -> Fe kb <= 0.33 (0.0454)
# Removida: Ni > -0.14 -> Rh L + Ar <= -0.77 (0.0280) | Mantida: Rh L + Ar <= -0.77 -> Ni > -0.14 (0.0463)
# Removida: background1 > 0.11 -> Rh L + Ar <= -0.77 (0.0197) | Mantida: Rh L + Ar <= -0.77 -> background1 > 0.11 (0.0210)
# Removida: background2 <= 0.35 -> P <= -0.59 (0.0457) | Mantida: P <= -0.59 -> background2 <= 0.35 (0.0550)
# Removida: Cu <= -0.12 -> P <= -0.59 (0.0944) | Mantida: P <= -0.59 -> Cu <= -0.12 (0.1185)
# Removida: S > -0.55 -> Rh L + Ar <= 1.37 (0.0115) | Mantida: Rh L + Ar <= 1.37 -> S > -0.55 (0.0154)
# Removida: Ni <= 0.13 -> P > -0.59 (0.0303) | Mantida: P > -0.59 -> Ni <= 0.13 (0.0452)
# Removida: S <= 0.09 -> Mn <= 1.01 (0.0271) | Mantida: Mn <= 1.01 -> S <= 0.09 (0.0399)
# Removida: Ni > -0.14 -> S <= 0.09 (0.0271) | Mantida: S <= 0.09 -> Ni > -0.14 (0.0325)
# Removida: Ca kb > -0.59 -> S <= -0.27 (0.0350) | Mantida: S <= -0.27 -> Ca kb > -0.59 (0.0844)
# Removida: Rayleight scattering <= -0.24 -> S <= -0.27 (0.0307) | Mantida: S <= -0.27 -> Rayleight scattering <= -0.24 (0.0447)
# Removida: Ni > -0.14 -> sum Fe <= -0.28 (0.0322) | Mantida: sum Fe <= -0.28 -> Ni > -0.14 (0.0489)
# Removida: Ni > -0.14 -> Cu <= 0.09 (0.0368) | Mantida: Cu <= 0.09 -> Ni > -0.14 (0.0390)
# Removida: Ni <= 0.13 -> Ni > -0.14 (0.0368) | Mantida: Ni > -0.14 -> Ni <= 0.13 (0.0424)
# Removida: background1 > 0.11 -> Ca ka > 1.77 (0.0200) | Mantida: Ca ka > 1.77 -> background1 > 0.11 (0.0220)
# Removida: Zn <= 0.34 -> Ca ka > 1.77 (0.0219) | Mantida: Ca ka > 1.77 -> Zn <= 0.34 (0.0330)
# Removida: Ca ka > 1.77 -> Al <= 0.19 (0.0262) | Mantida: Al <= 0.19 -> Ca ka > 1.77 (0.0267)
# Removida: sum Fe <= -0.28 -> Rayleight scattering <= -0.24 (0.0352) | Mantida: Rayleight scattering <= -0.24 -> sum Fe <= -0.28 (0.0388)
# Removida: Compton scattering <= -0.40 -> Ca kb > -0.59 (0.0269) | Mantida: Ca kb > -0.59 -> Compton scattering <= -0.40 (0.1018)
# Removida: Ca kb > -0.59 -> Ni <= 0.13 (0.0363) | Mantida: Ni <= 0.13 -> Ca kb > -0.59 (0.0414)
# Removida: background1 > 0.11 -> Al <= 0.19 (0.0137) | Mantida: Al <= 0.19 -> background1 > 0.11 (0.0302)
# Removida: Ni <= 0.13 -> Cu <= -0.12 (0.0277) | Mantida: Cu <= -0.12 -> Ni <= 0.13 (0.0555)
# Removida: background2 <= 1.51 -> Si <= -0.72 (0.0229) | Mantida: Si <= -0.72 -> background2 <= 1.51 (0.0231)
# Removida: Al > 0.19 -> Zn > -0.11 (0.0226) | Mantida: Zn > -0.11 -> Al > 0.19 (0.0243)
# Removida: background1 > 0.11 -> Mn <= 1.01 (0.0184) | Mantida: Mn <= 1.01 -> background1 > 0.11 (0.0282)
# Removida: Ti kb <= 0.20 -> Cu > -0.55 (0.0369) | Mantida: Cu > -0.55 -> Ti kb <= 0.20 (0.0403)
# Removida: Ti kb <= 0.20 -> Zn <= 0.34 (0.0120) | Mantida: Zn <= 0.34 -> Ti kb <= 0.20 (0.0165)
# Removida: background1 <= 0.30 -> Cu > -0.55 (0.0156) | Mantida: Cu > -0.55 -> background1 <= 0.30 (0.0224)
# Removida: background1 <= -0.08 -> Ca kb > 0.62 (0.0085) | Mantida: Ca kb > 0.62 -> background1 <= -0.08 (0.0124)
# Removida: background3 <= 1.47 -> background1 <= 0.30 (0.0117) | Mantida: background1 <= 0.30 -> background3 <= 1.47 (0.0158)
# Removida: Zn > -0.11 -> background1 <= 0.11 (0.0090) | Mantida: background1 <= 0.11 -> Zn > -0.11 (0.0104)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 876 | Removidas: 108
# Nós predicados: 127
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#     Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0          Fe ka > -3.05        Fe ka > -3.05        Fe ka > -3.05
# 1          Fe ka > -3.74        Fe ka > -3.74        Fe ka > -3.74
# 2          Fe ka > -2.26        Fe ka > -2.26        Fe ka > -2.26
# 3              K > -6.69            K > -6.69            K > -6.69
# 4          Ca ka <= 3.95        Ca ka <= 3.95        Ca ka <= 3.95
# ..                   ...                  ...                  ...
# 124           Zn > -0.37              Class_A       sum Fe <= 0.62
# 125              Class_A              Class_B  background2 <= 1.51
# 126              Class_B                  NaN              Class_A
# 127                  NaN                  NaN              Class_B
# 128                  NaN                  NaN                  NaN
#
#     Predicate_Cov_Seed_3
# 0          Fe ka > -3.05
# 1          Fe ka > -3.74
# 2          Fe ka > -2.26
# 3              K > -6.69
# 4          Ca ka <= 3.95
# ..                   ...
# 124            Zn > 0.10
# 125          Zn <= -0.11
# 126       Fe ka <= -3.05
# 127              Class_A
# 128              Class_B
#
# [129 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                            Node  Local_Reaching_Centrality  \
# 0                 Fe ka > -3.05                  21.730280
# 1                     K > -6.69                  11.048593
# 2                 Ca ka <= 3.95                   8.618784
# 3                    Si > -2.51                   7.521654
# 4                 Ti ka > -0.70                   2.030123
# 5                 Fe kb > -0.63                   1.836228
# 6                 Ca kb <= 1.57                   1.566439
# 7             Rh L + Ar > -0.77                   1.434719
# 8            background3 > 0.14                   1.241904
# 9    Compton scattering > -0.40                   0.975374
# 10                   Al > -0.68                   0.655427
# 11  Rayleight scattering > 0.03                   0.649024
# 12                sum Fe > 0.07                   0.573064
# 13                    P > -1.23                   0.460184
# 14                Ti kb > -0.14                   0.453927
# 15         background2 <= -0.51                   0.442148
# 16                    Mn > 0.23                   0.427096
# 17                  Cu <= -0.12                   0.337172
# 18                    S <= 0.55                   0.323362
# 19                   Ni <= 0.13                   0.309545
# 20                  Zn <= -0.37                   0.298782
# 21           background1 > 0.11                   0.265277
# 22                      Class_B                   0.000000
#
#                     Zone Threshold Operator
# 0                  Fe ka     -3.05        >
# 1                      K     -6.69        >
# 2                  Ca ka      3.95       <=
# 3                     Si     -2.51        >
# 4                  Ti ka     -0.70        >
# 5                  Fe kb     -0.63        >
# 6                  Ca kb      1.57       <=
# 7              Rh L + Ar     -0.77        >
# 8            background3      0.14        >
# 9     Compton scattering     -0.40        >
# 10                    Al     -0.68        >
# 11  Rayleight scattering      0.03        >
# 12                sum Fe      0.07        >
# 13                     P     -1.23        >
# 14                 Ti kb     -0.14        >
# 15           background2     -0.51       <=
# 16                    Mn      0.23        >
# 17                    Cu     -0.12       <=
# 18                     S      0.55       <=
# 19                    Ni      0.13       <=
# 20                    Zn     -0.37       <=
# 21           background1      0.11        >
# 22                  None      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zona 'Al': VE = 95.14%, dim = 12 variáveis
# Zona 'Si': VE = 99.71%, dim = 12 variáveis
# Zona 'P': VE = 97.48%, dim = 16 variáveis
# Zona 'S': VE = 93.90%, dim = 15 variáveis
# Zona 'Rh L + Ar': VE = 96.86%, dim = 34 variáveis
# Zona 'K': VE = 99.17%, dim = 19 variáveis
# Zona 'Ca ka': VE = 93.72%, dim = 21 variáveis
# Zona 'Ca kb': VE = 98.07%, dim = 26 variáveis
# Zona 'Ti ka': VE = 98.49%, dim = 15 variáveis
# Zona 'Ti kb': VE = 76.99%, dim = 22 variáveis
# Zona 'background1': VE = 66.94%, dim = 33 variáveis
# Zona 'Mn': VE = 95.57%, dim = 20 variáveis
# Zona 'Fe ka': VE = 99.73%, dim = 34 variáveis
# Zona 'Fe kb': VE = 94.82%, dim = 23 variáveis
# Zona 'Ni': VE = 79.28%, dim = 25 variáveis
# Zona 'Cu': VE = 84.38%, dim = 39 variáveis
# Zona 'Zn': VE = 82.21%, dim = 19 variáveis
# Zona 'background2': VE = 86.54%, dim = 215 variáveis
# Zona 'sum Fe': VE = 88.64%, dim = 27 variáveis
# Zona 'background3': VE = 87.63%, dim = 219 variáveis
# Zona 'Compton scattering': VE = 89.25%, dim = 85 variáveis
# Zona 'Rayleight scattering': VE = 84.76%, dim = 55 variáveis
#                              Node  Local_Reaching_Centrality  \
# 0                   Fe ka > -3.05                  21.730280
# 1                   Fe ka > -3.74                  18.176011
# 2                   Fe ka > -2.26                  14.346492
# 3                       K > -6.69                  11.048593
# 4                   Ca ka <= 3.95                   8.618784
# ..                            ...                        ...
# 125                     Zn > 0.10                   0.221977
# 126          background1 <= -0.08                   0.215201
# 127  Rayleight scattering <= 0.53                   0.198331
# 128                       Class_B                   0.000000
# 129                       Class_A                   0.000000
#
#                      Zone Threshold Operator  Threshold_Natural  \
# 0                   Fe ka     -3.05        >         -11.993967
# 1                   Fe ka     -3.74        >         -14.394181
# 2                   Fe ka     -2.26        >          -8.585461
# 3                       K     -6.69        >         -65.671272
# 4                   Ca ka      3.95       <=          24.763583
# ..                    ...       ...      ...                ...
# 125                    Zn      0.10        >           0.231960
# 126           background1     -0.08       <=          -0.162772
# 127  Rayleight scattering      0.53       <=           0.681638
# 128                  None      None     None                NaN
# 129                  None      None     None                NaN
#
#      Reference_Sample_Index  Approximation_Error  \
# 0                     102.0             0.012499
# 1                      68.0             0.017162
# 2                      77.0             0.009247
# 3                      79.0             0.023761
# 4                      89.0             0.045885
# ..                      ...                  ...
# 125                     7.0             0.000820
# 126                     3.0             0.007259
# 127                    73.0             0.012780
# 128                     NaN                  NaN
# 129                     NaN                  NaN
#
#                          Node_Natural
# 0                  Fe ka > -11.993967
# 1                  Fe ka > -14.394181
# 2                   Fe ka > -8.585461
# 3                      K > -65.671272
# 4                  Ca ka <= 24.763583
# ..                                ...
# 125                     Zn > 0.231960
# 126          background1 <= -0.162772
# 127  Rayleight scattering <= 0.681638
# 128                              None
# 129                              None
#
# [130 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Fe ka':
#   - Dimensão: 34 variáveis espectrais
#   - Range de energias: 6.1 - 6.76
#   - Variância explicada pela PC1: 99.73%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=mlp_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graphv3_pca(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# ======================================================================
# PERTURBATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Tipo de tarefa (aim): classification
# Modo de perturbação: median
# Fonte das estatísticas: full
# Métrica: probability_shift
# Total de folds: 10
#
#
# [Bag_1] Processando 132 predicados...
#   Predicado: Al > -0.68 (n=87)
#     Zona: 12 colunas
#     Importance: 0.002615
#   Predicado: Al <= -0.19 (n=43)
#     Zona: 12 colunas
#     Importance: 0.002210
#   Predicado: Al > -0.19 (n=65)
#     Zona: 12 colunas
#     Importance: 0.002820
#   Predicado: Al <= 0.19 (n=67)
#     Zona: 12 colunas
#     Importance: 0.001781
#   Predicado: Al > 0.19 (n=41)
#     Zona: 12 colunas
#     Importance: 0.003878
#   Predicado: Al <= 0.62 (n=87)
#     Zona: 12 colunas
#     Importance: 0.002238
#   Predicado: Si > -2.51 (n=83)
#     Zona: 12 colunas
#     Importance: 0.008912
#   Predicado: Si <= -1.67 (n=45)
#     Zona: 12 colunas
#     Importance: 0.015585
#   Predicado: Si > -1.67 (n=63)
#     Zona: 12 colunas
#     Importance: 0.009223
#   Predicado: Si <= -0.72 (n=65)
#     Zona: 12 colunas
#     Importance: 0.011166
#   Predicado: Si > -0.72 (n=43)
#     Zona: 12 colunas
#     Importance: 0.012944
#   Predicado: Si <= 3.71 (n=85)
#     Zona: 12 colunas
#     Importance: 0.011602
#   Predicado: P > -1.23 (n=88)
#     Zona: 16 colunas
#     Importance: 0.004711
#   Predicado: P <= -0.59 (n=42)
#     Zona: 16 colunas
#     Importance: 0.005494
#   Predicado: P > -0.59 (n=66)
#     Zona: 16 colunas
#     Importance: 0.005002
#   Predicado: P <= 0.08 (n=63)
#     Zona: 16 colunas
#     Importance: 0.004158
#   Predicado: P > 0.08 (n=45)
#     Zona: 16 colunas
#     Importance: 0.006642
#   Predicado: P <= 1.06 (n=84)
#     Zona: 16 colunas
#     Importance: 0.004323
#   Predicado: S > -0.55 (n=86)
#     Zona: 15 colunas
#     Importance: 0.006967
#   Predicado: S <= -0.27 (n=43)
#     Zona: 15 colunas
#     Importance: 0.004163
#   Predicado: S > -0.27 (n=65)
#     Zona: 15 colunas
#     Importance: 0.008611
#   Predicado: S <= 0.09 (n=62)
#     Zona: 15 colunas
#     Importance: 0.003226
#   Predicado: S > 0.09 (n=46)
#     Zona: 15 colunas
#     Importance: 0.011711
#   Predicado: S <= 0.55 (n=84)
#     Zona: 15 colunas
#     Importance: 0.004165
#   Predicado: Rh L + Ar > -1.66 (n=90)
#     Zona: 34 colunas
#     Importance: 0.006357
#   Predicado: Rh L + Ar <= -0.77 (n=37)
#     Zona: 34 colunas
#     Importance: 0.007506
#   Predicado: Rh L + Ar > -0.77 (n=71)
#     Zona: 34 colunas
#     Importance: 0.006913
#   Predicado: Rh L + Ar <= -0.16 (n=63)
#     Zona: 34 colunas
#     Importance: 0.005086
#   Predicado: Rh L + Ar > -0.16 (n=45)
#     Zona: 34 colunas
#     Importance: 0.009959
#   Predicado: Rh L + Ar <= 1.37 (n=89)
#     Zona: 34 colunas
#     Importance: 0.005983
#   Predicado: K > -6.69 (n=87)
#     Zona: 19 colunas
#     Importance: 0.027684
#   Predicado: K <= -1.46 (n=42)
#     Zona: 19 colunas
#     Importance: 0.032802
#   Predicado: K > -1.46 (n=66)
#     Zona: 19 colunas
#     Importance: 0.027200
#   Predicado: K <= 2.15 (n=66)
#     Zona: 19 colunas
#     Importance: 0.024225
#   Predicado: K > 2.15 (n=42)
#     Zona: 19 colunas
#     Importance: 0.037478
#   Predicado: K <= 6.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.025062
#   Predicado: Ca ka > -4.65 (n=86)
#     Zona: 21 colunas
#     Importance: 0.031481
#   Predicado: Ca ka <= -1.50 (n=44)
#     Zona: 21 colunas
#     Importance: 0.041004
#   Predicado: Ca ka > -1.50 (n=64)
#     Zona: 21 colunas
#     Importance: 0.026524
#   Predicado: Ca ka <= 1.77 (n=67)
#     Zona: 21 colunas
#     Importance: 0.031893
#   Predicado: Ca ka > 1.77 (n=41)
#     Zona: 21 colunas
#     Importance: 0.033290
#   Predicado: Ca ka <= 3.95 (n=87)
#     Zona: 21 colunas
#     Importance: 0.030717
#   Predicado: Ca kb > -1.81 (n=86)
#     Zona: 26 colunas
#     Importance: 0.009046
#   Predicado: Ca kb <= -0.59 (n=45)
#     Zona: 26 colunas
#     Importance: 0.012815
#   Predicado: Ca kb > -0.59 (n=63)
#     Zona: 26 colunas
#     Importance: 0.006080
#   Predicado: Ca kb <= 0.62 (n=66)
#     Zona: 26 colunas
#     Importance: 0.010258
#   Predicado: Ca kb > 0.62 (n=42)
#     Zona: 26 colunas
#     Importance: 0.006731
#   Predicado: Ca kb <= 1.57 (n=87)
#     Zona: 26 colunas
#     Importance: 0.009310
#   Predicado: Ti ka > -0.86 (n=87)
#     Zona: 15 colunas
#     Importance: 0.003676
#   Predicado: Ti ka <= -0.70 (n=44)
#     Zona: 15 colunas
#     Importance: 0.008756
#   Predicado: Ti ka > -0.70 (n=64)
#     Zona: 15 colunas
#     Importance: 0.003404
#   Predicado: Ti ka <= -0.52 (n=63)
#     Zona: 15 colunas
#     Importance: 0.006443
#   Predicado: Ti ka > -0.52 (n=45)
#     Zona: 15 colunas
#     Importance: 0.004383
#   Predicado: Ti ka <= 0.53 (n=87)
#     Zona: 15 colunas
#     Importance: 0.005718
#   Predicado: Ti kb > -0.32 (n=88)
#     Zona: 22 colunas
#     Importance: 0.001724
#   Predicado: Ti kb <= -0.14 (n=45)
#     Zona: 22 colunas
#     Importance: 0.006045
#   Predicado: Ti kb > -0.14 (n=63)
#     Zona: 22 colunas
#     Importance: 0.001461
#   Predicado: Ti kb <= 0.03 (n=66)
#     Zona: 22 colunas
#     Importance: 0.004402
#   Predicado: Ti kb > 0.03 (n=42)
#     Zona: 22 colunas
#     Importance: 0.001751
#   Predicado: Ti kb <= 0.20 (n=86)
#     Zona: 22 colunas
#     Importance: 0.003851
#   Predicado: background1 > -0.26 (n=90)
#     Zona: 33 colunas
#     Importance: 0.001563
#   Predicado: background1 <= -0.08 (n=43)
#     Zona: 33 colunas
#     Importance: 0.002978
#   Predicado: background1 > -0.08 (n=65)
#     Zona: 33 colunas
#     Importance: 0.001544
#   Predicado: background1 <= 0.11 (n=70)
#     Zona: 33 colunas
#     Importance: 0.002073
#   Predicado: background1 > 0.11 (n=38)
#     Zona: 33 colunas
#     Importance: 0.002192
#   Predicado: background1 <= 0.30 (n=91)
#     Zona: 33 colunas
#     Importance: 0.001914
#   Predicado: Mn > -1.22 (n=88)
#     Zona: 20 colunas
#     Importance: 0.005754
#   Predicado: Mn <= -0.41 (n=43)
#     Zona: 20 colunas
#     Importance: 0.013083
#   Predicado: Mn > -0.41 (n=65)
#     Zona: 20 colunas
#     Importance: 0.005554
#   Predicado: Mn <= 0.23 (n=67)
#     Zona: 20 colunas
#     Importance: 0.009011
#   Predicado: Mn > 0.23 (n=41)
#     Zona: 20 colunas
#     Importance: 0.007801
#   Predicado: Mn <= 1.01 (n=90)
#     Zona: 20 colunas
#     Importance: 0.008069
#   Predicado: Fe ka > -3.74 (n=86)
#     Zona: 34 colunas
#     Importance: 0.013193
#   Predicado: Fe ka <= -3.05 (n=44)
#     Zona: 34 colunas
#     Importance: 0.020970
#   Predicado: Fe ka > -3.05 (n=64)
#     Zona: 34 colunas
#     Importance: 0.014450
#   Predicado: Fe ka <= -2.26 (n=63)
#     Zona: 34 colunas
#     Importance: 0.016134
#   Predicado: Fe ka > -2.26 (n=45)
#     Zona: 34 colunas
#     Importance: 0.018467
#   Predicado: Fe ka <= 1.10 (n=87)
#     Zona: 34 colunas
#     Importance: 0.015249
#   Predicado: Fe kb > -0.91 (n=87)
#     Zona: 23 colunas
#     Importance: 0.002361
#   Predicado: Fe kb <= -0.63 (n=41)
#     Zona: 23 colunas
#     Importance: 0.005824
#   Predicado: Fe kb > -0.63 (n=67)
#     Zona: 23 colunas
#     Importance: 0.002272
#   Predicado: Fe kb <= -0.44 (n=66)
#     Zona: 23 colunas
#     Importance: 0.004157
#   Predicado: Fe kb > -0.44 (n=42)
#     Zona: 23 colunas
#     Importance: 0.002778
#   Predicado: Fe kb <= 0.33 (n=87)
#     Zona: 23 colunas
#     Importance: 0.004181
#   Predicado: Ni > -0.60 (n=88)
#     Zona: 25 colunas
#     Importance: 0.003641
#   Predicado: Ni <= -0.14 (n=44)
#     Zona: 25 colunas
#     Importance: 0.002244
#   Predicado: Ni > -0.14 (n=64)
#     Zona: 25 colunas
#     Importance: 0.004245
#   Predicado: Ni <= 0.13 (n=64)
#     Zona: 25 colunas
#     Importance: 0.002548
#   Predicado: Ni > 0.13 (n=44)
#     Zona: 25 colunas
#     Importance: 0.004712
#   Predicado: Ni <= 0.59 (n=90)
#     Zona: 25 colunas
#     Importance: 0.002618
#   Predicado: Cu > -0.55 (n=89)
#     Zona: 39 colunas
#     Importance: 0.004339
#   Predicado: Cu <= -0.12 (n=44)
#     Zona: 39 colunas
#     Importance: 0.004386
#   Predicado: Cu > -0.12 (n=64)
#     Zona: 39 colunas
#     Importance: 0.004690
#   Predicado: Cu <= 0.09 (n=64)
#     Zona: 39 colunas
#     Importance: 0.003235
#   Predicado: Cu > 0.09 (n=44)
#     Zona: 39 colunas
#     Importance: 0.006502
#   Predicado: Cu <= 0.56 (n=92)
#     Zona: 39 colunas
#     Importance: 0.003515
#   Predicado: Zn > -0.37 (n=87)
#     Zona: 19 colunas
#     Importance: 0.000517
#   Predicado: Zn <= -0.11 (n=41)
#     Zona: 19 colunas
#     Importance: 0.001044
#   Predicado: Zn > -0.11 (n=67)
#     Zona: 19 colunas
#     Importance: 0.000472
#   Predicado: Zn <= 0.10 (n=66)
#     Zona: 19 colunas
#     Importance: 0.000835
#   Predicado: Zn > 0.10 (n=42)
#     Zona: 19 colunas
#     Importance: 0.000460
#   Predicado: Zn <= 0.34 (n=90)
#     Zona: 19 colunas
#     Importance: 0.000691
#   Predicado: background2 > -1.35 (n=88)
#     Zona: 215 colunas
#     Importance: 0.006488
#   Predicado: background2 <= -0.51 (n=45)
#     Zona: 215 colunas
#     Importance: 0.005068
#   Predicado: background2 > -0.51 (n=63)
#     Zona: 215 colunas
#     Importance: 0.007744
#   Predicado: background2 <= 0.35 (n=67)
#     Zona: 215 colunas
#     Importance: 0.004651
#   Predicado: background2 > 0.35 (n=41)
#     Zona: 215 colunas
#     Importance: 0.009862
#   Predicado: background2 <= 1.51 (n=89)
#     Zona: 215 colunas
#     Importance: 0.004928
#   Predicado: sum Fe > -0.60 (n=89)
#     Zona: 27 colunas
#     Importance: 0.003629
#   Predicado: sum Fe <= -0.28 (n=44)
#     Zona: 27 colunas
#     Importance: 0.004814
#   Predicado: sum Fe > -0.28 (n=64)
#     Zona: 27 colunas
#     Importance: 0.003794
#   Predicado: sum Fe <= 0.07 (n=69)
#     Zona: 27 colunas
#     Importance: 0.003563
#   Predicado: sum Fe > 0.07 (n=39)
#     Zona: 27 colunas
#     Importance: 0.005353
#   Predicado: sum Fe <= 0.62 (n=89)
#     Zona: 27 colunas
#     Importance: 0.003720
#   Predicado: background3 > -1.28 (n=88)
#     Zona: 219 colunas
#     Importance: 0.008639
#   Predicado: background3 <= -0.62 (n=42)
#     Zona: 219 colunas
#     Importance: 0.010590
#   Predicado: background3 > -0.62 (n=66)
#     Zona: 219 colunas
#     Importance: 0.008894
#   Predicado: background3 <= 0.14 (n=67)
#     Zona: 219 colunas
#     Importance: 0.007588
#   Predicado: background3 > 0.14 (n=41)
#     Zona: 219 colunas
#     Importance: 0.012766
#   Predicado: background3 <= 1.47 (n=90)
#     Zona: 219 colunas
#     Importance: 0.008326
#   Predicado: Compton scattering > -0.88 (n=86)
#     Zona: 85 colunas
#     Importance: 0.003321
#   Predicado: Compton scattering <= -0.40 (n=42)
#     Zona: 85 colunas
#     Importance: 0.003546
#   Predicado: Compton scattering > -0.40 (n=66)
#     Zona: 85 colunas
#     Importance: 0.003256
#   Predicado: Compton scattering <= 0.05 (n=68)
#     Zona: 85 colunas
#     Importance: 0.002888
#   Predicado: Compton scattering > 0.05 (n=40)
#     Zona: 85 colunas
#     Importance: 0.004186
#   Predicado: Compton scattering <= 0.87 (n=88)
#     Zona: 85 colunas
#     Importance: 0.003317
#   Predicado: Rayleight scattering > -0.50 (n=88)
#     Zona: 55 colunas
#     Importance: 0.001375
#   Predicado: Rayleight scattering <= -0.24 (n=43)
#     Zona: 55 colunas
#     Importance: 0.001829
#   Predicado: Rayleight scattering > -0.24 (n=65)
#     Zona: 55 colunas
#     Importance: 0.001057
#   Predicado: Rayleight scattering <= 0.03 (n=67)
#     Zona: 55 colunas
#     Importance: 0.001370
#   Predicado: Rayleight scattering > 0.03 (n=41)
#     Zona: 55 colunas
#     Importance: 0.001357
#   Predicado: Rayleight scattering <= 0.53 (n=89)
#     Zona: 55 colunas
#     Importance: 0.001427
#
# [Bag_2] Processando 132 predicados...
#   Predicado: Al > -0.68 (n=84)
#     Zona: 12 colunas
#     Importance: 0.003287
#   Predicado: Al <= -0.19 (n=46)
#     Zona: 12 colunas
#     Importance: 0.002358
#   Predicado: Al > -0.19 (n=62)
#     Zona: 12 colunas
#     Importance: 0.003679
#   Predicado: Al <= 0.19 (n=66)
#     Zona: 12 colunas
#     Importance: 0.001969
#   Predicado: Al > 0.19 (n=42)
#     Zona: 12 colunas
#     Importance: 0.004919
#   Predicado: Al <= 0.62 (n=86)
#     Zona: 12 colunas
#     Importance: 0.002427
#   Predicado: Si > -2.51 (n=83)
#     Zona: 12 colunas
#     Importance: 0.008147
#   Predicado: Si <= -1.67 (n=47)
#     Zona: 12 colunas
#     Importance: 0.015960
#   Predicado: Si > -1.67 (n=61)
#     Zona: 12 colunas
#     Importance: 0.008435
#   Predicado: Si <= -0.72 (n=68)
#     Zona: 12 colunas
#     Importance: 0.011412
#   Predicado: Si > -0.72 (n=40)
#     Zona: 12 colunas
#     Importance: 0.012216
#   Predicado: Si <= 3.71 (n=87)
#     Zona: 12 colunas
#     Importance: 0.011689
#   Predicado: P > -1.23 (n=84)
#     Zona: 16 colunas
#     Importance: 0.004983
#   Predicado: P <= -0.59 (n=44)
#     Zona: 16 colunas
#     Importance: 0.005675
#   Predicado: P > -0.59 (n=64)
#     Zona: 16 colunas
#     Importance: 0.005278
#   Predicado: P <= 0.08 (n=65)
#     Zona: 16 colunas
#     Importance: 0.004392
#   Predicado: P > 0.08 (n=43)
#     Zona: 16 colunas
#     Importance: 0.007022
#   Predicado: P <= 1.06 (n=87)
#     Zona: 16 colunas
#     Importance: 0.004687
#   Predicado: S > -0.55 (n=87)
#     Zona: 15 colunas
#     Importance: 0.007959
#   Predicado: S <= -0.27 (n=44)
#     Zona: 15 colunas
#     Importance: 0.003909
#   Predicado: S > -0.27 (n=64)
#     Zona: 15 colunas
#     Importance: 0.010078
#   Predicado: S <= 0.09 (n=66)
#     Zona: 15 colunas
#     Importance: 0.002931
#   Predicado: S > 0.09 (n=42)
#     Zona: 15 colunas
#     Importance: 0.014847
#   Predicado: S <= 0.55 (n=87)
#     Zona: 15 colunas
#     Importance: 0.003852
#   Predicado: Rh L + Ar > -1.66 (n=88)
#     Zona: 34 colunas
#     Importance: 0.007509
#   Predicado: Rh L + Ar <= -0.77 (n=42)
#     Zona: 34 colunas
#     Importance: 0.006861
#   Predicado: Rh L + Ar > -0.77 (n=66)
#     Zona: 34 colunas
#     Importance: 0.008648
#   Predicado: Rh L + Ar <= -0.16 (n=67)
#     Zona: 34 colunas
#     Importance: 0.004933
#   Predicado: Rh L + Ar > -0.16 (n=41)
#     Zona: 34 colunas
#     Importance: 0.012888
#   Predicado: Rh L + Ar <= 1.37 (n=90)
#     Zona: 34 colunas
#     Importance: 0.005964
#   Predicado: K > -6.69 (n=85)
#     Zona: 19 colunas
#     Importance: 0.034851
#   Predicado: K <= -1.46 (n=45)
#     Zona: 19 colunas
#     Importance: 0.037180
#   Predicado: K > -1.46 (n=63)
#     Zona: 19 colunas
#     Importance: 0.036149
#   Predicado: K <= 2.15 (n=64)
#     Zona: 19 colunas
#     Importance: 0.028893
#   Predicado: K > 2.15 (n=44)
#     Zona: 19 colunas
#     Importance: 0.047758
#   Predicado: K <= 6.26 (n=87)
#     Zona: 19 colunas
#     Importance: 0.028152
#   Predicado: Ca ka > -4.65 (n=89)
#     Zona: 21 colunas
#     Importance: 0.032784
#   Predicado: Ca ka <= -1.50 (n=41)
#     Zona: 21 colunas
#     Importance: 0.048204
#   Predicado: Ca ka > -1.50 (n=67)
#     Zona: 21 colunas
#     Importance: 0.027077
#   Predicado: Ca ka <= 1.77 (n=67)
#     Zona: 21 colunas
#     Importance: 0.035483
#   Predicado: Ca ka > 1.77 (n=41)
#     Zona: 21 colunas
#     Importance: 0.034467
#   Predicado: Ca ka <= 3.95 (n=87)
#     Zona: 21 colunas
#     Importance: 0.033334
#   Predicado: Ca kb > -1.81 (n=89)
#     Zona: 26 colunas
#     Importance: 0.009225
#   Predicado: Ca kb <= -0.59 (n=41)
#     Zona: 26 colunas
#     Importance: 0.014655
#   Predicado: Ca kb > -0.59 (n=67)
#     Zona: 26 colunas
#     Importance: 0.005925
#   Predicado: Ca kb <= 0.62 (n=66)
#     Zona: 26 colunas
#     Importance: 0.010887
#   Predicado: Ca kb > 0.62 (n=42)
#     Zona: 26 colunas
#     Importance: 0.006650
#   Predicado: Ca kb <= 1.57 (n=87)
#     Zona: 26 colunas
#     Importance: 0.009613
#   Predicado: Ti ka > -0.86 (n=84)
#     Zona: 15 colunas
#     Importance: 0.003200
#   Predicado: Ti ka <= -0.70 (n=45)
#     Zona: 15 colunas
#     Importance: 0.009931
#   Predicado: Ti ka > -0.70 (n=63)
#     Zona: 15 colunas
#     Importance: 0.002739
#   Predicado: Ti ka <= -0.52 (n=67)
#     Zona: 15 colunas
#     Importance: 0.007012
#   Predicado: Ti ka > -0.52 (n=41)
#     Zona: 15 colunas
#     Importance: 0.003650
#   Predicado: Ti ka <= 0.53 (n=88)
#     Zona: 15 colunas
#     Importance: 0.006146
#   Predicado: Ti kb > -0.32 (n=84)
#     Zona: 22 colunas
#     Importance: 0.001706
#   Predicado: Ti kb <= -0.14 (n=44)
#     Zona: 22 colunas
#     Importance: 0.007625
#   Predicado: Ti kb > -0.14 (n=64)
#     Zona: 22 colunas
#     Importance: 0.001393
#   Predicado: Ti kb <= 0.03 (n=65)
#     Zona: 22 colunas
#     Importance: 0.005423
#   Predicado: Ti kb > 0.03 (n=43)
#     Zona: 22 colunas
#     Importance: 0.001678
#   Predicado: Ti kb <= 0.20 (n=86)
#     Zona: 22 colunas
#     Importance: 0.004578
#   Predicado: background1 > -0.26 (n=89)
#     Zona: 33 colunas
#     Importance: 0.001551
#   Predicado: background1 <= -0.08 (n=44)
#     Zona: 33 colunas
#     Importance: 0.003675
#   Predicado: background1 > -0.08 (n=64)
#     Zona: 33 colunas
#     Importance: 0.001511
#   Predicado: background1 <= 0.11 (n=65)
#     Zona: 33 colunas
#     Importance: 0.002690
#   Predicado: background1 > 0.11 (n=43)
#     Zona: 33 colunas
#     Importance: 0.001943
#   Predicado: background1 <= 0.30 (n=84)
#     Zona: 33 colunas
#     Importance: 0.002313
#   Predicado: Mn > -1.22 (n=85)
#     Zona: 20 colunas
#     Importance: 0.006377
#   Predicado: Mn <= -0.41 (n=42)
#     Zona: 20 colunas
#     Importance: 0.017757
#   Predicado: Mn > -0.41 (n=66)
#     Zona: 20 colunas
#     Importance: 0.005801
#   Predicado: Mn <= 0.23 (n=66)
#     Zona: 20 colunas
#     Importance: 0.011888
#   Predicado: Mn > 0.23 (n=42)
#     Zona: 20 colunas
#     Importance: 0.008191
#   Predicado: Mn <= 1.01 (n=86)
#     Zona: 20 colunas
#     Importance: 0.010436
#   Predicado: Fe ka > -3.74 (n=85)
#     Zona: 34 colunas
#     Importance: 0.011860
#   Predicado: Fe ka <= -3.05 (n=45)
#     Zona: 34 colunas
#     Importance: 0.021880
#   Predicado: Fe ka > -3.05 (n=63)
#     Zona: 34 colunas
#     Importance: 0.012664
#   Predicado: Fe ka <= -2.26 (n=68)
#     Zona: 34 colunas
#     Importance: 0.016476
#   Predicado: Fe ka > -2.26 (n=40)
#     Zona: 34 colunas
#     Importance: 0.016553
#   Predicado: Fe ka <= 1.10 (n=89)
#     Zona: 34 colunas
#     Importance: 0.015626
#   Predicado: Fe kb > -0.91 (n=87)
#     Zona: 23 colunas
#     Importance: 0.002370
#   Predicado: Fe kb <= -0.63 (n=41)
#     Zona: 23 colunas
#     Importance: 0.007384
#   Predicado: Fe kb > -0.63 (n=67)
#     Zona: 23 colunas
#     Importance: 0.002199
#   Predicado: Fe kb <= -0.44 (n=64)
#     Zona: 23 colunas
#     Importance: 0.005256
#   Predicado: Fe kb > -0.44 (n=44)
#     Zona: 23 colunas
#     Importance: 0.002583
#   Predicado: Fe kb <= 0.33 (n=89)
#     Zona: 23 colunas
#     Importance: 0.004849
#   Predicado: Ni > -0.60 (n=87)
#     Zona: 25 colunas
#     Importance: 0.003542
#   Predicado: Ni <= -0.14 (n=42)
#     Zona: 25 colunas
#     Importance: 0.002948
#   Predicado: Ni > -0.14 (n=66)
#     Zona: 25 colunas
#     Importance: 0.004029
#   Predicado: Ni <= 0.13 (n=62)
#     Zona: 25 colunas
#     Importance: 0.002936
#   Predicado: Ni > 0.13 (n=46)
#     Zona: 25 colunas
#     Importance: 0.004516
#   Predicado: Ni <= 0.59 (n=86)
#     Zona: 25 colunas
#     Importance: 0.002974
#   Predicado: Cu > -0.55 (n=88)
#     Zona: 39 colunas
#     Importance: 0.004486
#   Predicado: Cu <= -0.12 (n=41)
#     Zona: 39 colunas
#     Importance: 0.005943
#   Predicado: Cu > -0.12 (n=67)
#     Zona: 39 colunas
#     Importance: 0.004726
#   Predicado: Cu <= 0.09 (n=61)
#     Zona: 39 colunas
#     Importance: 0.004209
#   Predicado: Cu > 0.09 (n=47)
#     Zona: 39 colunas
#     Importance: 0.006459
#   Predicado: Cu <= 0.56 (n=87)
#     Zona: 39 colunas
#     Importance: 0.004303
#   Predicado: Zn > -0.37 (n=87)
#     Zona: 19 colunas
#     Importance: 0.000538
#   Predicado: Zn <= -0.11 (n=42)
#     Zona: 19 colunas
#     Importance: 0.001187
#   Predicado: Zn > -0.11 (n=66)
#     Zona: 19 colunas
#     Importance: 0.000521
#   Predicado: Zn <= 0.10 (n=62)
#     Zona: 19 colunas
#     Importance: 0.000974
#   Predicado: Zn > 0.10 (n=46)
#     Zona: 19 colunas
#     Importance: 0.000518
#   Predicado: Zn <= 0.34 (n=87)
#     Zona: 19 colunas
#     Importance: 0.000790
#   Predicado: background2 > -1.35 (n=88)
#     Zona: 215 colunas
#     Importance: 0.006439
#   Predicado: background2 <= -0.51 (n=41)
#     Zona: 215 colunas
#     Importance: 0.006924
#   Predicado: background2 > -0.51 (n=67)
#     Zona: 215 colunas
#     Importance: 0.007357
#   Predicado: background2 <= 0.35 (n=63)
#     Zona: 215 colunas
#     Importance: 0.005793
#   Predicado: background2 > 0.35 (n=45)
#     Zona: 215 colunas
#     Importance: 0.009151
#   Predicado: background2 <= 1.51 (n=85)
#     Zona: 215 colunas
#     Importance: 0.005771
#   Predicado: sum Fe > -0.60 (n=87)
#     Zona: 27 colunas
#     Importance: 0.003758
#   Predicado: sum Fe <= -0.28 (n=40)
#     Zona: 27 colunas
#     Importance: 0.006448
#   Predicado: sum Fe > -0.28 (n=68)
#     Zona: 27 colunas
#     Importance: 0.003762
#   Predicado: sum Fe <= 0.07 (n=62)
#     Zona: 27 colunas
#     Importance: 0.004671
#   Predicado: sum Fe > 0.07 (n=46)
#     Zona: 27 colunas
#     Importance: 0.004873
#   Predicado: sum Fe <= 0.62 (n=86)
#     Zona: 27 colunas
#     Importance: 0.004333
#   Predicado: background3 > -1.28 (n=88)
#     Zona: 219 colunas
#     Importance: 0.009003
#   Predicado: background3 <= -0.62 (n=40)
#     Zona: 219 colunas
#     Importance: 0.011708
#   Predicado: background3 > -0.62 (n=68)
#     Zona: 219 colunas
#     Importance: 0.009355
#   Predicado: background3 <= 0.14 (n=61)
#     Zona: 219 colunas
#     Importance: 0.008619
#   Predicado: background3 > 0.14 (n=47)
#     Zona: 219 colunas
#     Importance: 0.012312
#   Predicado: background3 <= 1.47 (n=86)
#     Zona: 219 colunas
#     Importance: 0.008805
#   Predicado: Compton scattering > -0.88 (n=89)
#     Zona: 85 colunas
#     Importance: 0.003561
#   Predicado: Compton scattering <= -0.40 (n=40)
#     Zona: 85 colunas
#     Importance: 0.003920
#   Predicado: Compton scattering > -0.40 (n=68)
#     Zona: 85 colunas
#     Importance: 0.003408
#   Predicado: Compton scattering <= 0.05 (n=61)
#     Zona: 85 colunas
#     Importance: 0.003158
#   Predicado: Compton scattering > 0.05 (n=47)
#     Zona: 85 colunas
#     Importance: 0.004168
#   Predicado: Compton scattering <= 0.87 (n=87)
#     Zona: 85 colunas
#     Importance: 0.003463
#   Predicado: Rayleight scattering > -0.50 (n=90)
#     Zona: 55 colunas
#     Importance: 0.001503
#   Predicado: Rayleight scattering <= -0.24 (n=40)
#     Zona: 55 colunas
#     Importance: 0.002100
#   Predicado: Rayleight scattering > -0.24 (n=68)
#     Zona: 55 colunas
#     Importance: 0.001096
#   Predicado: Rayleight scattering <= 0.03 (n=60)
#     Zona: 55 colunas
#     Importance: 0.001566
#   Predicado: Rayleight scattering > 0.03 (n=48)
#     Zona: 55 colunas
#     Importance: 0.001346
#   Predicado: Rayleight scattering <= 0.53 (n=86)
#     Zona: 55 colunas
#     Importance: 0.001565
#
# [Bag_3] Processando 132 predicados...
#   Predicado: Al > -0.68 (n=86)
#     Zona: 12 colunas
#     Importance: 0.003001
#   Predicado: Al <= -0.19 (n=45)
#     Zona: 12 colunas
#     Importance: 0.002376
#   Predicado: Al > -0.19 (n=63)
#     Zona: 12 colunas
#     Importance: 0.003326
#   Predicado: Al <= 0.19 (n=68)
#     Zona: 12 colunas
#     Importance: 0.001892
#   Predicado: Al > 0.19 (n=40)
#     Zona: 12 colunas
#     Importance: 0.004694
#   Predicado: Al <= 0.62 (n=86)
#     Zona: 12 colunas
#     Importance: 0.002251
#   Predicado: Si > -2.51 (n=89)
#     Zona: 12 colunas
#     Importance: 0.007659
#   Predicado: Si <= -1.67 (n=44)
#     Zona: 12 colunas
#     Importance: 0.015247
#   Predicado: Si > -1.67 (n=64)
#     Zona: 12 colunas
#     Importance: 0.007728
#   Predicado: Si <= -0.72 (n=68)
#     Zona: 12 colunas
#     Importance: 0.010269
#   Predicado: Si > -0.72 (n=40)
#     Zona: 12 colunas
#     Importance: 0.011680
#   Predicado: Si <= 3.71 (n=87)
#     Zona: 12 colunas
#     Importance: 0.010408
#   Predicado: P > -1.23 (n=85)
#     Zona: 16 colunas
#     Importance: 0.004245
#   Predicado: P <= -0.59 (n=46)
#     Zona: 16 colunas
#     Importance: 0.005334
#   Predicado: P > -0.59 (n=62)
#     Zona: 16 colunas
#     Importance: 0.004523
#   Predicado: P <= 0.08 (n=66)
#     Zona: 16 colunas
#     Importance: 0.004223
#   Predicado: P > 0.08 (n=42)
#     Zona: 16 colunas
#     Importance: 0.005883
#   Predicado: P <= 1.06 (n=90)
#     Zona: 16 colunas
#     Importance: 0.004432
#   Predicado: S > -0.55 (n=88)
#     Zona: 15 colunas
#     Importance: 0.007396
#   Predicado: S <= -0.27 (n=46)
#     Zona: 15 colunas
#     Importance: 0.003765
#   Predicado: S > -0.27 (n=62)
#     Zona: 15 colunas
#     Importance: 0.009780
#   Predicado: S <= 0.09 (n=64)
#     Zona: 15 colunas
#     Importance: 0.003006
#   Predicado: S > 0.09 (n=44)
#     Zona: 15 colunas
#     Importance: 0.013345
#   Predicado: S <= 0.55 (n=87)
#     Zona: 15 colunas
#     Importance: 0.004065
#   Predicado: Rh L + Ar > -1.66 (n=85)
#     Zona: 34 colunas
#     Importance: 0.007954
#   Predicado: Rh L + Ar <= -0.77 (n=45)
#     Zona: 34 colunas
#     Importance: 0.007387
#   Predicado: Rh L + Ar > -0.77 (n=63)
#     Zona: 34 colunas
#     Importance: 0.009274
#   Predicado: Rh L + Ar <= -0.16 (n=64)
#     Zona: 34 colunas
#     Importance: 0.005486
#   Predicado: Rh L + Ar > -0.16 (n=44)
#     Zona: 34 colunas
#     Importance: 0.012853
#   Predicado: Rh L + Ar <= 1.37 (n=88)
#     Zona: 34 colunas
#     Importance: 0.006040
#   Predicado: K > -6.69 (n=86)
#     Zona: 19 colunas
#     Importance: 0.032206
#   Predicado: K <= -1.46 (n=45)
#     Zona: 19 colunas
#     Importance: 0.036038
#   Predicado: K > -1.46 (n=63)
#     Zona: 19 colunas
#     Importance: 0.033052
#   Predicado: K <= 2.15 (n=68)
#     Zona: 19 colunas
#     Importance: 0.026854
#   Predicado: K > 2.15 (n=40)
#     Zona: 19 colunas
#     Importance: 0.046948
#   Predicado: K <= 6.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.026346
#   Predicado: Ca ka > -4.65 (n=87)
#     Zona: 21 colunas
#     Importance: 0.033226
#   Predicado: Ca ka <= -1.50 (n=41)
#     Zona: 21 colunas
#     Importance: 0.044103
#   Predicado: Ca ka > -1.50 (n=67)
#     Zona: 21 colunas
#     Importance: 0.026730
#   Predicado: Ca ka <= 1.77 (n=66)
#     Zona: 21 colunas
#     Importance: 0.033099
#   Predicado: Ca ka > 1.77 (n=42)
#     Zona: 21 colunas
#     Importance: 0.033681
#   Predicado: Ca ka <= 3.95 (n=86)
#     Zona: 21 colunas
#     Importance: 0.032044
#   Predicado: Ca kb > -1.81 (n=87)
#     Zona: 26 colunas
#     Importance: 0.009463
#   Predicado: Ca kb <= -0.59 (n=42)
#     Zona: 26 colunas
#     Importance: 0.013662
#   Predicado: Ca kb > -0.59 (n=66)
#     Zona: 26 colunas
#     Importance: 0.005972
#   Predicado: Ca kb <= 0.62 (n=66)
#     Zona: 26 colunas
#     Importance: 0.010359
#   Predicado: Ca kb > 0.62 (n=42)
#     Zona: 26 colunas
#     Importance: 0.006769
#   Predicado: Ca kb <= 1.57 (n=86)
#     Zona: 26 colunas
#     Importance: 0.009459
#   Predicado: Ti ka > -0.86 (n=89)
#     Zona: 15 colunas
#     Importance: 0.003500
#   Predicado: Ti ka <= -0.70 (n=43)
#     Zona: 15 colunas
#     Importance: 0.008683
#   Predicado: Ti ka > -0.70 (n=65)
#     Zona: 15 colunas
#     Importance: 0.003127
#   Predicado: Ti ka <= -0.52 (n=66)
#     Zona: 15 colunas
#     Importance: 0.005995
#   Predicado: Ti ka > -0.52 (n=42)
#     Zona: 15 colunas
#     Importance: 0.004308
#   Predicado: Ti ka <= 0.53 (n=86)
#     Zona: 15 colunas
#     Importance: 0.005419
#   Predicado: Ti kb > -0.32 (n=88)
#     Zona: 22 colunas
#     Importance: 0.001707
#   Predicado: Ti kb <= -0.14 (n=43)
#     Zona: 22 colunas
#     Importance: 0.006455
#   Predicado: Ti kb > -0.14 (n=65)
#     Zona: 22 colunas
#     Importance: 0.001471
#   Predicado: Ti kb <= 0.03 (n=65)
#     Zona: 22 colunas
#     Importance: 0.004530
#   Predicado: Ti kb > 0.03 (n=43)
#     Zona: 22 colunas
#     Importance: 0.001831
#   Predicado: Ti kb <= 0.20 (n=85)
#     Zona: 22 colunas
#     Importance: 0.003957
#   Predicado: background1 > -0.26 (n=89)
#     Zona: 33 colunas
#     Importance: 0.001644
#   Predicado: background1 <= -0.08 (n=42)
#     Zona: 33 colunas
#     Importance: 0.002861
#   Predicado: background1 > -0.08 (n=66)
#     Zona: 33 colunas
#     Importance: 0.001662
#   Predicado: background1 <= 0.11 (n=64)
#     Zona: 33 colunas
#     Importance: 0.002136
#   Predicado: background1 > 0.11 (n=44)
#     Zona: 33 colunas
#     Importance: 0.002117
#   Predicado: background1 <= 0.30 (n=85)
#     Zona: 33 colunas
#     Importance: 0.001948
#   Predicado: Mn > -1.22 (n=88)
#     Zona: 20 colunas
#     Importance: 0.006013
#   Predicado: Mn <= -0.41 (n=43)
#     Zona: 20 colunas
#     Importance: 0.014903
#   Predicado: Mn > -0.41 (n=65)
#     Zona: 20 colunas
#     Importance: 0.005726
#   Predicado: Mn <= 0.23 (n=65)
#     Zona: 20 colunas
#     Importance: 0.010483
#   Predicado: Mn > 0.23 (n=43)
#     Zona: 20 colunas
#     Importance: 0.007713
#   Predicado: Mn <= 1.01 (n=87)
#     Zona: 20 colunas
#     Importance: 0.009107
#   Predicado: Fe ka > -3.74 (n=87)
#     Zona: 34 colunas
#     Importance: 0.012611
#   Predicado: Fe ka <= -3.05 (n=44)
#     Zona: 34 colunas
#     Importance: 0.019195
#   Predicado: Fe ka > -3.05 (n=64)
#     Zona: 34 colunas
#     Importance: 0.014083
#   Predicado: Fe ka <= -2.26 (n=64)
#     Zona: 34 colunas
#     Importance: 0.014866
#   Predicado: Fe ka > -2.26 (n=44)
#     Zona: 34 colunas
#     Importance: 0.018054
#   Predicado: Fe ka <= 1.10 (n=87)
#     Zona: 34 colunas
#     Importance: 0.014209
#   Predicado: Fe kb > -0.91 (n=87)
#     Zona: 23 colunas
#     Importance: 0.002379
#   Predicado: Fe kb <= -0.63 (n=40)
#     Zona: 23 colunas
#     Importance: 0.005706
#   Predicado: Fe kb > -0.63 (n=68)
#     Zona: 23 colunas
#     Importance: 0.002260
#   Predicado: Fe kb <= -0.44 (n=64)
#     Zona: 23 colunas
#     Importance: 0.004086
#   Predicado: Fe kb > -0.44 (n=44)
#     Zona: 23 colunas
#     Importance: 0.002736
#   Predicado: Fe kb <= 0.33 (n=87)
#     Zona: 23 colunas
#     Importance: 0.004088
#   Predicado: Ni > -0.60 (n=87)
#     Zona: 25 colunas
#     Importance: 0.003562
#   Predicado: Ni <= -0.14 (n=42)
#     Zona: 25 colunas
#     Importance: 0.002392
#   Predicado: Ni > -0.14 (n=66)
#     Zona: 25 colunas
#     Importance: 0.004201
#   Predicado: Ni <= 0.13 (n=63)
#     Zona: 25 colunas
#     Importance: 0.002588
#   Predicado: Ni > 0.13 (n=45)
#     Zona: 25 colunas
#     Importance: 0.004769
#   Predicado: Ni <= 0.59 (n=85)
#     Zona: 25 colunas
#     Importance: 0.002698
#   Predicado: Cu > -0.55 (n=88)
#     Zona: 39 colunas
#     Importance: 0.004510
#   Predicado: Cu <= -0.12 (n=44)
#     Zona: 39 colunas
#     Importance: 0.004398
#   Predicado: Cu > -0.12 (n=64)
#     Zona: 39 colunas
#     Importance: 0.004975
#   Predicado: Cu <= 0.09 (n=63)
#     Zona: 39 colunas
#     Importance: 0.003282
#   Predicado: Cu > 0.09 (n=45)
#     Zona: 39 colunas
#     Importance: 0.006782
#   Predicado: Cu <= 0.56 (n=87)
#     Zona: 39 colunas
#     Importance: 0.003600
#   Predicado: Zn > -0.37 (n=86)
#     Zona: 19 colunas
#     Importance: 0.000544
#   Predicado: Zn <= -0.11 (n=42)
#     Zona: 19 colunas
#     Importance: 0.001008
#   Predicado: Zn > -0.11 (n=66)
#     Zona: 19 colunas
#     Importance: 0.000514
#   Predicado: Zn <= 0.10 (n=66)
#     Zona: 19 colunas
#     Importance: 0.000823
#   Predicado: Zn > 0.10 (n=42)
#     Zona: 19 colunas
#     Importance: 0.000523
#   Predicado: Zn <= 0.34 (n=86)
#     Zona: 19 colunas
#     Importance: 0.000704
#   Predicado: background2 > -1.35 (n=88)
#     Zona: 215 colunas
#     Importance: 0.006783
#   Predicado: background2 <= -0.51 (n=43)
#     Zona: 215 colunas
#     Importance: 0.005170
#   Predicado: background2 > -0.51 (n=65)
#     Zona: 215 colunas
#     Importance: 0.007973
#   Predicado: background2 <= 0.35 (n=67)
#     Zona: 215 colunas
#     Importance: 0.004503
#   Predicado: background2 > 0.35 (n=41)
#     Zona: 215 colunas
#     Importance: 0.010703
#   Predicado: background2 <= 1.51 (n=87)
#     Zona: 215 colunas
#     Importance: 0.004924
#   Predicado: sum Fe > -0.60 (n=87)
#     Zona: 27 colunas
#     Importance: 0.003831
#   Predicado: sum Fe <= -0.28 (n=44)
#     Zona: 27 colunas
#     Importance: 0.004892
#   Predicado: sum Fe > -0.28 (n=64)
#     Zona: 27 colunas
#     Importance: 0.004045
#   Predicado: sum Fe <= 0.07 (n=67)
#     Zona: 27 colunas
#     Importance: 0.003666
#   Predicado: sum Fe > 0.07 (n=41)
#     Zona: 27 colunas
#     Importance: 0.005573
#   Predicado: sum Fe <= 0.62 (n=89)
#     Zona: 27 colunas
#     Importance: 0.003826
#   Predicado: background3 > -1.28 (n=86)
#     Zona: 219 colunas
#     Importance: 0.008888
#   Predicado: background3 <= -0.62 (n=45)
#     Zona: 219 colunas
#     Importance: 0.009075
#   Predicado: background3 > -0.62 (n=63)
#     Zona: 219 colunas
#     Importance: 0.009428
#   Predicado: background3 <= 0.14 (n=68)
#     Zona: 219 colunas
#     Importance: 0.006923
#   Predicado: background3 > 0.14 (n=40)
#     Zona: 219 colunas
#     Importance: 0.013289
#   Predicado: background3 <= 1.47 (n=90)
#     Zona: 219 colunas
#     Importance: 0.007479
#   Predicado: Compton scattering > -0.88 (n=86)
#     Zona: 85 colunas
#     Importance: 0.003523
#   Predicado: Compton scattering <= -0.40 (n=46)
#     Zona: 85 colunas
#     Importance: 0.002976
#   Predicado: Compton scattering > -0.40 (n=62)
#     Zona: 85 colunas
#     Importance: 0.003438
#   Predicado: Compton scattering <= 0.05 (n=69)
#     Zona: 85 colunas
#     Importance: 0.002603
#   Predicado: Compton scattering > 0.05 (n=39)
#     Zona: 85 colunas
#     Importance: 0.004371
#   Predicado: Compton scattering <= 0.87 (n=89)
#     Zona: 85 colunas
#     Importance: 0.002953
#   Predicado: Rayleight scattering > -0.50 (n=87)
#     Zona: 55 colunas
#     Importance: 0.001465
#   Predicado: Rayleight scattering <= -0.24 (n=47)
#     Zona: 55 colunas
#     Importance: 0.001682
#   Predicado: Rayleight scattering > -0.24 (n=61)
#     Zona: 55 colunas
#     Importance: 0.001067
#   Predicado: Rayleight scattering <= 0.03 (n=68)
#     Zona: 55 colunas
#     Importance: 0.001341
#   Predicado: Rayleight scattering > 0.03 (n=40)
#     Zona: 55 colunas
#     Importance: 0.001323
#   Predicado: Rayleight scattering <= 0.53 (n=89)
#     Zona: 55 colunas
#     Importance: 0.001364
#
# [Bag_4] Processando 132 predicados...
#   Predicado: Al > -0.68 (n=84)
#     Zona: 12 colunas
#     Importance: 0.002798
#   Predicado: Al <= -0.19 (n=48)
#     Zona: 12 colunas
#     Importance: 0.002215
#   Predicado: Al > -0.19 (n=60)
#     Zona: 12 colunas
#     Importance: 0.003079
#   Predicado: Al <= 0.19 (n=67)
#     Zona: 12 colunas
#     Importance: 0.001869
#   Predicado: Al > 0.19 (n=41)
#     Zona: 12 colunas
#     Importance: 0.004045
#   Predicado: Al <= 0.62 (n=86)
#     Zona: 12 colunas
#     Importance: 0.002054
#   Predicado: Si > -2.51 (n=87)
#     Zona: 12 colunas
#     Importance: 0.006948
#   Predicado: Si <= -1.67 (n=42)
#     Zona: 12 colunas
#     Importance: 0.014346
#   Predicado: Si > -1.67 (n=66)
#     Zona: 12 colunas
#     Importance: 0.006595
#   Predicado: Si <= -0.72 (n=66)
#     Zona: 12 colunas
#     Importance: 0.009465
#   Predicado: Si > -0.72 (n=42)
#     Zona: 12 colunas
#     Importance: 0.009837
#   Predicado: Si <= 3.71 (n=88)
#     Zona: 12 colunas
#     Importance: 0.009715
#   Predicado: P > -1.23 (n=85)
#     Zona: 16 colunas
#     Importance: 0.004653
#   Predicado: P <= -0.59 (n=42)
#     Zona: 16 colunas
#     Importance: 0.005108
#   Predicado: P > -0.59 (n=66)
#     Zona: 16 colunas
#     Importance: 0.005102
#   Predicado: P <= 0.08 (n=62)
#     Zona: 16 colunas
#     Importance: 0.003774
#   Predicado: P > 0.08 (n=46)
#     Zona: 16 colunas
#     Importance: 0.006898
#   Predicado: P <= 1.06 (n=85)
#     Zona: 16 colunas
#     Importance: 0.004190
#   Predicado: S > -0.55 (n=87)
#     Zona: 15 colunas
#     Importance: 0.007023
#   Predicado: S <= -0.27 (n=43)
#     Zona: 15 colunas
#     Importance: 0.003896
#   Predicado: S > -0.27 (n=65)
#     Zona: 15 colunas
#     Importance: 0.008805
#   Predicado: S <= 0.09 (n=65)
#     Zona: 15 colunas
#     Importance: 0.002865
#   Predicado: S > 0.09 (n=43)
#     Zona: 15 colunas
#     Importance: 0.012873
#   Predicado: S <= 0.55 (n=85)
#     Zona: 15 colunas
#     Importance: 0.003539
#   Predicado: Rh L + Ar > -1.66 (n=86)
#     Zona: 34 colunas
#     Importance: 0.007243
#   Predicado: Rh L + Ar <= -0.77 (n=44)
#     Zona: 34 colunas
#     Importance: 0.007385
#   Predicado: Rh L + Ar > -0.77 (n=64)
#     Zona: 34 colunas
#     Importance: 0.008247
#   Predicado: Rh L + Ar <= -0.16 (n=66)
#     Zona: 34 colunas
#     Importance: 0.005438
#   Predicado: Rh L + Ar > -0.16 (n=42)
#     Zona: 34 colunas
#     Importance: 0.011758
#   Predicado: Rh L + Ar <= 1.37 (n=88)
#     Zona: 34 colunas
#     Importance: 0.006275
#   Predicado: K > -6.69 (n=83)
#     Zona: 19 colunas
#     Importance: 0.029760
#   Predicado: K <= -1.46 (n=48)
#     Zona: 19 colunas
#     Importance: 0.034976
#   Predicado: K > -1.46 (n=60)
#     Zona: 19 colunas
#     Importance: 0.030298
#   Predicado: K <= 2.15 (n=67)
#     Zona: 19 colunas
#     Importance: 0.027639
#   Predicado: K > 2.15 (n=41)
#     Zona: 19 colunas
#     Importance: 0.040121
#   Predicado: K <= 6.26 (n=88)
#     Zona: 19 colunas
#     Importance: 0.027293
#   Predicado: Ca ka > -4.65 (n=87)
#     Zona: 21 colunas
#     Importance: 0.032059
#   Predicado: Ca ka <= -1.50 (n=38)
#     Zona: 21 colunas
#     Importance: 0.037332
#   Predicado: Ca ka > -1.50 (n=70)
#     Zona: 21 colunas
#     Importance: 0.028570
#   Predicado: Ca ka <= 1.77 (n=61)
#     Zona: 21 colunas
#     Importance: 0.028938
#   Predicado: Ca ka > 1.77 (n=47)
#     Zona: 21 colunas
#     Importance: 0.035177
#   Predicado: Ca ka <= 3.95 (n=85)
#     Zona: 21 colunas
#     Importance: 0.028690
#   Predicado: Ca kb > -1.81 (n=87)
#     Zona: 26 colunas
#     Importance: 0.008510
#   Predicado: Ca kb <= -0.59 (n=38)
#     Zona: 26 colunas
#     Importance: 0.011788
#   Predicado: Ca kb > -0.59 (n=70)
#     Zona: 26 colunas
#     Importance: 0.006296
#   Predicado: Ca kb <= 0.62 (n=60)
#     Zona: 26 colunas
#     Importance: 0.009074
#   Predicado: Ca kb > 0.62 (n=48)
#     Zona: 26 colunas
#     Importance: 0.007171
#   Predicado: Ca kb <= 1.57 (n=85)
#     Zona: 26 colunas
#     Importance: 0.008304
#   Predicado: Ti ka > -0.86 (n=86)
#     Zona: 15 colunas
#     Importance: 0.003299
#   Predicado: Ti ka <= -0.70 (n=45)
#     Zona: 15 colunas
#     Importance: 0.008408
#   Predicado: Ti ka > -0.70 (n=63)
#     Zona: 15 colunas
#     Importance: 0.003031
#   Predicado: Ti ka <= -0.52 (n=65)
#     Zona: 15 colunas
#     Importance: 0.006139
#   Predicado: Ti ka > -0.52 (n=43)
#     Zona: 15 colunas
#     Importance: 0.003959
#   Predicado: Ti ka <= 0.53 (n=87)
#     Zona: 15 colunas
#     Importance: 0.005422
#   Predicado: Ti kb > -0.32 (n=88)
#     Zona: 22 colunas
#     Importance: 0.001698
#   Predicado: Ti kb <= -0.14 (n=42)
#     Zona: 22 colunas
#     Importance: 0.006908
#   Predicado: Ti kb > -0.14 (n=66)
#     Zona: 22 colunas
#     Importance: 0.001452
#   Predicado: Ti kb <= 0.03 (n=63)
#     Zona: 22 colunas
#     Importance: 0.004844
#   Predicado: Ti kb > 0.03 (n=45)
#     Zona: 22 colunas
#     Importance: 0.001795
#   Predicado: Ti kb <= 0.20 (n=85)
#     Zona: 22 colunas
#     Importance: 0.004107
#   Predicado: background1 > -0.26 (n=88)
#     Zona: 33 colunas
#     Importance: 0.001517
#   Predicado: background1 <= -0.08 (n=43)
#     Zona: 33 colunas
#     Importance: 0.003448
#   Predicado: background1 > -0.08 (n=65)
#     Zona: 33 colunas
#     Importance: 0.001639
#   Predicado: background1 <= 0.11 (n=61)
#     Zona: 33 colunas
#     Importance: 0.002628
#   Predicado: background1 > 0.11 (n=47)
#     Zona: 33 colunas
#     Importance: 0.002010
#   Predicado: background1 <= 0.30 (n=84)
#     Zona: 33 colunas
#     Importance: 0.002256
#   Predicado: Mn > -1.22 (n=89)
#     Zona: 20 colunas
#     Importance: 0.006023
#   Predicado: Mn <= -0.41 (n=39)
#     Zona: 20 colunas
#     Importance: 0.017161
#   Predicado: Mn > -0.41 (n=69)
#     Zona: 20 colunas
#     Importance: 0.005409
#   Predicado: Mn <= 0.23 (n=62)
#     Zona: 20 colunas
#     Importance: 0.011271
#   Predicado: Mn > 0.23 (n=46)
#     Zona: 20 colunas
#     Importance: 0.007471
#   Predicado: Mn <= 1.01 (n=86)
#     Zona: 20 colunas
#     Importance: 0.009641
#   Predicado: Fe ka > -3.74 (n=87)
#     Zona: 34 colunas
#     Importance: 0.011666
#   Predicado: Fe ka <= -3.05 (n=44)
#     Zona: 34 colunas
#     Importance: 0.018696
#   Predicado: Fe ka > -3.05 (n=64)
#     Zona: 34 colunas
#     Importance: 0.012560
#   Predicado: Fe ka <= -2.26 (n=68)
#     Zona: 34 colunas
#     Importance: 0.013903
#   Predicado: Fe ka > -2.26 (n=40)
#     Zona: 34 colunas
#     Importance: 0.017026
#   Predicado: Fe ka <= 1.10 (n=87)
#     Zona: 34 colunas
#     Importance: 0.013425
#   Predicado: Fe kb > -0.91 (n=87)
#     Zona: 23 colunas
#     Importance: 0.002064
#   Predicado: Fe kb <= -0.63 (n=40)
#     Zona: 23 colunas
#     Importance: 0.006760
#   Predicado: Fe kb > -0.63 (n=68)
#     Zona: 23 colunas
#     Importance: 0.002035
#   Predicado: Fe kb <= -0.44 (n=64)
#     Zona: 23 colunas
#     Importance: 0.004764
#   Predicado: Fe kb > -0.44 (n=44)
#     Zona: 23 colunas
#     Importance: 0.002362
#   Predicado: Fe kb <= 0.33 (n=87)
#     Zona: 23 colunas
#     Importance: 0.004416
#   Predicado: Ni > -0.60 (n=87)
#     Zona: 25 colunas
#     Importance: 0.003420
#   Predicado: Ni <= -0.14 (n=43)
#     Zona: 25 colunas
#     Importance: 0.002696
#   Predicado: Ni > -0.14 (n=65)
#     Zona: 25 colunas
#     Importance: 0.003935
#   Predicado: Ni <= 0.13 (n=61)
#     Zona: 25 colunas
#     Importance: 0.002738
#   Predicado: Ni > 0.13 (n=47)
#     Zona: 25 colunas
#     Importance: 0.004354
#   Predicado: Ni <= 0.59 (n=85)
#     Zona: 25 colunas
#     Importance: 0.002670
#   Predicado: Cu > -0.55 (n=88)
#     Zona: 39 colunas
#     Importance: 0.003972
#   Predicado: Cu <= -0.12 (n=44)
#     Zona: 39 colunas
#     Importance: 0.005244
#   Predicado: Cu > -0.12 (n=64)
#     Zona: 39 colunas
#     Importance: 0.004437
#   Predicado: Cu <= 0.09 (n=60)
#     Zona: 39 colunas
#     Importance: 0.004081
#   Predicado: Cu > 0.09 (n=48)
#     Zona: 39 colunas
#     Importance: 0.005623
#   Predicado: Cu <= 0.56 (n=85)
#     Zona: 39 colunas
#     Importance: 0.003640
#   Predicado: Zn > -0.37 (n=88)
#     Zona: 19 colunas
#     Importance: 0.000528
#   Predicado: Zn <= -0.11 (n=41)
#     Zona: 19 colunas
#     Importance: 0.001054
#   Predicado: Zn > -0.11 (n=67)
#     Zona: 19 colunas
#     Importance: 0.000509
#   Predicado: Zn <= 0.10 (n=61)
#     Zona: 19 colunas
#     Importance: 0.000884
#   Predicado: Zn > 0.10 (n=47)
#     Zona: 19 colunas
#     Importance: 0.000498
#   Predicado: Zn <= 0.34 (n=84)
#     Zona: 19 colunas
#     Importance: 0.000721
#   Predicado: background2 > -1.35 (n=88)
#     Zona: 215 colunas
#     Importance: 0.005740
#   Predicado: background2 <= -0.51 (n=40)
#     Zona: 215 colunas
#     Importance: 0.006620
#   Predicado: background2 > -0.51 (n=68)
#     Zona: 215 colunas
#     Importance: 0.006784
#   Predicado: background2 <= 0.35 (n=63)
#     Zona: 215 colunas
#     Importance: 0.005416
#   Predicado: background2 > 0.35 (n=45)
#     Zona: 215 colunas
#     Importance: 0.008554
#   Predicado: background2 <= 1.51 (n=84)
#     Zona: 215 colunas
#     Importance: 0.004827
#   Predicado: sum Fe > -0.60 (n=87)
#     Zona: 27 colunas
#     Importance: 0.003303
#   Predicado: sum Fe <= -0.28 (n=39)
#     Zona: 27 colunas
#     Importance: 0.005946
#   Predicado: sum Fe > -0.28 (n=69)
#     Zona: 27 colunas
#     Importance: 0.003487
#   Predicado: sum Fe <= 0.07 (n=64)
#     Zona: 27 colunas
#     Importance: 0.004085
#   Predicado: sum Fe > 0.07 (n=44)
#     Zona: 27 colunas
#     Importance: 0.004796
#   Predicado: sum Fe <= 0.62 (n=87)
#     Zona: 27 colunas
#     Importance: 0.003843
#   Predicado: background3 > -1.28 (n=88)
#     Zona: 219 colunas
#     Importance: 0.008377
#   Predicado: background3 <= -0.62 (n=38)
#     Zona: 219 colunas
#     Importance: 0.011030
#   Predicado: background3 > -0.62 (n=70)
#     Zona: 219 colunas
#     Importance: 0.008810
#   Predicado: background3 <= 0.14 (n=62)
#     Zona: 219 colunas
#     Importance: 0.007703
#   Predicado: background3 > 0.14 (n=46)
#     Zona: 219 colunas
#     Importance: 0.012135
#   Predicado: background3 <= 1.47 (n=86)
#     Zona: 219 colunas
#     Importance: 0.008248
#   Predicado: Compton scattering > -0.88 (n=88)
#     Zona: 85 colunas
#     Importance: 0.003268
#   Predicado: Compton scattering <= -0.40 (n=39)
#     Zona: 85 colunas
#     Importance: 0.003716
#   Predicado: Compton scattering > -0.40 (n=69)
#     Zona: 85 colunas
#     Importance: 0.003096
#   Predicado: Compton scattering <= 0.05 (n=63)
#     Zona: 85 colunas
#     Importance: 0.002924
#   Predicado: Compton scattering > 0.05 (n=45)
#     Zona: 85 colunas
#     Importance: 0.003874
#   Predicado: Compton scattering <= 0.87 (n=86)
#     Zona: 85 colunas
#     Importance: 0.003185
#   Predicado: Rayleight scattering > -0.50 (n=89)
#     Zona: 55 colunas
#     Importance: 0.001246
#   Predicado: Rayleight scattering <= -0.24 (n=38)
#     Zona: 55 colunas
#     Importance: 0.001695
#   Predicado: Rayleight scattering > -0.24 (n=70)
#     Zona: 55 colunas
#     Importance: 0.000959
#   Predicado: Rayleight scattering <= 0.03 (n=62)
#     Zona: 55 colunas
#     Importance: 0.001227
#   Predicado: Rayleight scattering > 0.03 (n=46)
#     Zona: 55 colunas
#     Importance: 0.001206
#   Predicado: Rayleight scattering <= 0.53 (n=87)
#     Zona: 55 colunas
#     Importance: 0.001247
#
# [Bag_5] Processando 133 predicados...
#   Predicado: Al > -0.68 (n=88)
#     Zona: 12 colunas
#     Importance: 0.002903
#   Predicado: Al <= -0.19 (n=39)
#     Zona: 12 colunas
#     Importance: 0.002196
#   Predicado: Al > -0.19 (n=69)
#     Zona: 12 colunas
#     Importance: 0.003159
#   Predicado: Al <= 0.19 (n=61)
#     Zona: 12 colunas
#     Importance: 0.001732
#   Predicado: Al > 0.19 (n=47)
#     Zona: 12 colunas
#     Importance: 0.004213
#   Predicado: Al <= 0.62 (n=84)
#     Zona: 12 colunas
#     Importance: 0.002201
#   Predicado: Si > -2.51 (n=85)
#     Zona: 12 colunas
#     Importance: 0.006800
#   Predicado: Si <= -1.67 (n=43)
#     Zona: 12 colunas
#     Importance: 0.015713
#   Predicado: Si > -1.67 (n=65)
#     Zona: 12 colunas
#     Importance: 0.006807
#   Predicado: Si <= -0.72 (n=66)
#     Zona: 12 colunas
#     Importance: 0.010577
#   Predicado: Si > -0.72 (n=42)
#     Zona: 12 colunas
#     Importance: 0.010001
#   Predicado: Si <= 3.71 (n=87)
#     Zona: 12 colunas
#     Importance: 0.011368
#   Predicado: P > -1.23 (n=88)
#     Zona: 16 colunas
#     Importance: 0.004257
#   Predicado: P <= -0.59 (n=43)
#     Zona: 16 colunas
#     Importance: 0.004704
#   Predicado: P > -0.59 (n=65)
#     Zona: 16 colunas
#     Importance: 0.004683
#   Predicado: P <= 0.08 (n=68)
#     Zona: 16 colunas
#     Importance: 0.003498
#   Predicado: P > 0.08 (n=40)
#     Zona: 16 colunas
#     Importance: 0.006721
#   Predicado: P <= 1.06 (n=87)
#     Zona: 16 colunas
#     Importance: 0.004087
#   Predicado: S > -0.55 (n=86)
#     Zona: 15 colunas
#     Importance: 0.007421
#   Predicado: S <= -0.27 (n=45)
#     Zona: 15 colunas
#     Importance: 0.003623
#   Predicado: S > -0.27 (n=63)
#     Zona: 15 colunas
#     Importance: 0.009424
#   Predicado: S <= 0.09 (n=65)
#     Zona: 15 colunas
#     Importance: 0.002780
#   Predicado: S > 0.09 (n=43)
#     Zona: 15 colunas
#     Importance: 0.013397
#   Predicado: S <= 0.55 (n=84)
#     Zona: 15 colunas
#     Importance: 0.003731
#   Predicado: Rh L + Ar > -1.66 (n=87)
#     Zona: 34 colunas
#     Importance: 0.007215
#   Predicado: Rh L + Ar <= -0.77 (n=45)
#     Zona: 34 colunas
#     Importance: 0.006670
#   Predicado: Rh L + Ar > -0.77 (n=63)
#     Zona: 34 colunas
#     Importance: 0.008553
#   Predicado: Rh L + Ar <= -0.16 (n=66)
#     Zona: 34 colunas
#     Importance: 0.005081
#   Predicado: Rh L + Ar > -0.16 (n=42)
#     Zona: 34 colunas
#     Importance: 0.011992
#   Predicado: Rh L + Ar <= 1.37 (n=86)
#     Zona: 34 colunas
#     Importance: 0.005542
#   Predicado: K > -6.69 (n=89)
#     Zona: 19 colunas
#     Importance: 0.030606
#   Predicado: K <= -1.46 (n=39)
#     Zona: 19 colunas
#     Importance: 0.033332
#   Predicado: K > -1.46 (n=69)
#     Zona: 19 colunas
#     Importance: 0.031472
#   Predicado: K <= 2.15 (n=60)
#     Zona: 19 colunas
#     Importance: 0.023262
#   Predicado: K > 2.15 (n=48)
#     Zona: 19 colunas
#     Importance: 0.043246
#   Predicado: K <= 6.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.023852
#   Predicado: Ca ka > -4.65 (n=83)
#     Zona: 21 colunas
#     Importance: 0.031715
#   Predicado: Ca ka <= -1.50 (n=48)
#     Zona: 21 colunas
#     Importance: 0.043267
#   Predicado: Ca ka > -1.50 (n=60)
#     Zona: 21 colunas
#     Importance: 0.026476
#   Predicado: Ca ka <= 1.77 (n=69)
#     Zona: 21 colunas
#     Importance: 0.034082
#   Predicado: Ca ka > 1.77 (n=39)
#     Zona: 21 colunas
#     Importance: 0.033685
#   Predicado: Ca ka <= 3.95 (n=90)
#     Zona: 21 colunas
#     Importance: 0.032509
#   Predicado: Ca kb > -1.81 (n=83)
#     Zona: 26 colunas
#     Importance: 0.008897
#   Predicado: Ca kb <= -0.59 (n=47)
#     Zona: 26 colunas
#     Importance: 0.012626
#   Predicado: Ca kb > -0.59 (n=61)
#     Zona: 26 colunas
#     Importance: 0.005994
#   Predicado: Ca kb <= 0.62 (n=69)
#     Zona: 26 colunas
#     Importance: 0.009742
#   Predicado: Ca kb > 0.62 (n=39)
#     Zona: 26 colunas
# ...
# Removida: Ca kb > 0.62 -> P > 0.08 (0.0065) | Mantida: P > 0.08 -> Ca kb > 0.62 (0.0066)
# Removida: background2 > -0.51 -> Rh L + Ar <= -0.77 (0.0062) | Mantida: Rh L + Ar <= -0.77 -> background2 > -0.51 (0.0069)
# Removida: P > 0.08 -> Rh L + Ar <= -0.77 (0.0063) | Mantida: Rh L + Ar <= -0.77 -> P > 0.08 (0.0069)
# Removida: background2 > -0.51 -> Mn > -1.22 (0.0051) | Mantida: Mn > -1.22 -> background2 > -0.51 (0.0055)
# Removida: background2 > -0.51 -> Rh L + Ar <= 1.37 (0.0055) | Mantida: Rh L + Ar <= 1.37 -> background2 > -0.51 (0.0058)
# Removida: background2 > -0.51 -> P > 0.08 (0.0066) | Mantida: P > 0.08 -> background2 > -0.51 (0.0119)
# Removida: background2 > -0.51 -> Ti ka <= -0.52 (0.0052) | Mantida: Ti ka <= -0.52 -> background2 > -0.51 (0.0062)
# Removida: Fe kb <= -0.63 -> Ti kb <= -0.14 (0.0063) | Mantida: Ti kb <= -0.14 -> Fe kb <= -0.63 (0.0104)
# Removida: background2 <= -0.51 -> Fe kb <= -0.63 (0.0054) | Mantida: Fe kb <= -0.63 -> background2 <= -0.51 (0.0123)
# Removida: Ca kb > -0.59 -> background2 <= -0.51 (0.0060) | Mantida: background2 <= -0.51 -> Ca kb > -0.59 (0.0109)
# Removida: Mn > -1.22 -> background2 <= -0.51 (0.0053) | Mantida: background2 <= -0.51 -> Mn > -1.22 (0.0054)
# Removida: background2 > -1.35 -> background2 <= -0.51 (0.0055) | Mantida: background2 <= -0.51 -> background2 > -1.35 (0.0055)
# Removida: Ca kb > -0.59 -> P > 0.08 (0.0061) | Mantida: P > 0.08 -> Ca kb > -0.59 (0.0062)
# Removida: Mn > -1.22 -> Ca kb > -0.59 (0.0058) | Mantida: Ca kb > -0.59 -> Mn > -1.22 (0.0114)
# Removida: Ti ka <= 0.53 -> Ca kb > -0.59 (0.0056) | Mantida: Ca kb > -0.59 -> Ti ka <= 0.53 (0.0059)
# Removida: P > 0.08 -> Ti ka <= -0.52 (0.0061) | Mantida: Ti ka <= -0.52 -> P > 0.08 (0.0065)
# Removida: sum Fe <= -0.28 -> Rh L + Ar <= 1.37 (0.0049) | Mantida: Rh L + Ar <= 1.37 -> sum Fe <= -0.28 (0.0116)
# Removida: Cu > 0.09 -> Rh L + Ar <= 1.37 (0.0043) | Mantida: Rh L + Ar <= 1.37 -> Cu > 0.09 (0.0053)
# Removida: background2 > -1.35 -> Ti ka <= -0.52 (0.0053) | Mantida: Ti ka <= -0.52 -> background2 > -1.35 (0.0063)
# Removida: background2 > -1.35 -> background2 <= 1.51 (0.0043) | Mantida: background2 <= 1.51 -> background2 > -1.35 (0.0044)
# Removida: background2 > -1.35 -> P <= -0.59 (0.0044) | Mantida: P <= -0.59 -> background2 > -1.35 (0.0049)
# Removida: Cu > 0.09 -> Ti ka <= -0.52 (0.0049) | Mantida: Ti ka <= -0.52 -> Cu > 0.09 (0.0060)
# Removida: Mn > -1.22 -> Ti ka <= -0.52 (0.0055) | Mantida: Ti ka <= -0.52 -> Mn > -1.22 (0.0112)
# Removida: Cu > 0.09 -> Mn > -1.22 (0.0049) | Mantida: Mn > -1.22 -> Cu > 0.09 (0.0054)
# Removida: Cu > 0.09 -> sum Fe <= -0.28 (0.0048) | Mantida: sum Fe <= -0.28 -> Cu > 0.09 (0.0050)
# Removida: Cu > 0.09 -> Rh L + Ar <= -0.16 (0.0046) | Mantida: Rh L + Ar <= -0.16 -> Cu > 0.09 (0.0052)
# Removida: Ti ka <= 0.53 -> Mn > -1.22 (0.0052) | Mantida: Mn > -1.22 -> Ti ka <= 0.53 (0.0110)
# Removida: Ti ka <= 0.53 -> sum Fe <= -0.28 (0.0055) | Mantida: sum Fe <= -0.28 -> Ti ka <= 0.53 (0.0101)
# Removida: Mn > -0.41 -> Ti ka <= 0.53 (0.0052) | Mantida: Ti ka <= 0.53 -> Mn > -0.41 (0.0220)
# Removida: Rh L + Ar <= -0.16 -> Ti ka <= 0.53 (0.0052) | Mantida: Ti ka <= 0.53 -> Rh L + Ar <= -0.16 (0.0052)
# Removida: sum Fe <= -0.28 -> Rh L + Ar <= -0.16 (0.0049) | Mantida: Rh L + Ar <= -0.16 -> sum Fe <= -0.28 (0.0053)
# Removida: background2 <= 1.51 -> sum Fe <= -0.28 (0.0042) | Mantida: sum Fe <= -0.28 -> background2 <= 1.51 (0.0050)
# Removida: background2 <= 0.35 -> Rh L + Ar <= -0.16 (0.0044) | Mantida: Rh L + Ar <= -0.16 -> background2 <= 0.35 (0.0051)
# Removida: background2 <= 0.35 -> background2 <= 1.51 (0.0049) | Mantida: background2 <= 1.51 -> background2 <= 0.35 (0.0094)
# Removida: Cu <= -0.12 -> background2 <= 1.51 (0.0041) | Mantida: background2 <= 1.51 -> Cu <= -0.12 (0.0048)
# Removida: background2 <= 0.35 -> Mn > -0.41 (0.0047) | Mantida: Mn > -0.41 -> background2 <= 0.35 (0.0047)
# Removida: background2 <= 0.35 -> Cu <= -0.12 (0.0080) | Mantida: Cu <= -0.12 -> background2 <= 0.35 (0.0094)
# Removida: P <= -0.59 -> background2 <= 0.35 (0.0044) | Mantida: background2 <= 0.35 -> P <= -0.59 (0.0046)
# Removida: Cu <= -0.12 -> sum Fe > 0.07 (0.0041) | Mantida: sum Fe > 0.07 -> Cu <= -0.12 (0.0046)
# Removida: sum Fe <= 0.07 -> sum Fe > 0.07 (0.0036) | Mantida: sum Fe > 0.07 -> sum Fe <= 0.07 (0.0038)
# Removida: sum Fe > 0.07 -> P > -0.59 (0.0040) | Mantida: P > -0.59 -> sum Fe > 0.07 (0.0092)
# Removida: Cu <= -0.12 -> P > -0.59 (0.0044) | Mantida: P > -0.59 -> Cu <= -0.12 (0.0098)
# Removida: P > -0.59 -> Fe kb <= -0.44 (0.0041) | Mantida: Fe kb <= -0.44 -> P > -0.59 (0.0091)
# Removida: Ti kb <= 0.03 -> Fe kb <= -0.44 (0.0035) | Mantida: Fe kb <= -0.44 -> Ti kb <= 0.03 (0.0084)
# Removida: Fe kb <= -0.44 -> P > -1.23 (0.0044) | Mantida: P > -1.23 -> Fe kb <= -0.44 (0.0086)
# Removida: Fe kb <= -0.44 -> P <= -0.59 (0.0044) | Mantida: P <= -0.59 -> Fe kb <= -0.44 (0.0048)
# Removida: Ti kb <= 0.03 -> P > -0.59 (0.0037) | Mantida: P > -0.59 -> Ti kb <= 0.03 (0.0044)
# Removida: Ti kb <= 0.03 -> Fe kb <= 0.33 (0.0037) | Mantida: Fe kb <= 0.33 -> Ti kb <= 0.03 (0.0040)
# Removida: Ni > 0.13 -> P <= -0.59 (0.0037) | Mantida: P <= -0.59 -> Ni > 0.13 (0.0041)
# Removida: P <= 1.06 -> Al > 0.19 (0.0072) | Mantida: Al > 0.19 -> P <= 1.06 (0.0079)
# Removida: Al > 0.19 -> Fe kb <= 0.33 (0.0041) | Mantida: Fe kb <= 0.33 -> Al > 0.19 (0.0045)
# Removida: Al > 0.19 -> S <= -0.27 (0.0035) | Mantida: S <= -0.27 -> Al > 0.19 (0.0035)
# Removida: Cu > -0.12 -> Fe kb <= 0.33 (0.0038) | Mantida: Fe kb <= 0.33 -> Cu > -0.12 (0.0041)
# Removida: Cu > -0.12 -> Ni > 0.13 (0.0031) | Mantida: Ni > 0.13 -> Cu > -0.12 (0.0038)
# Removida: Cu > -0.12 -> P > -1.23 (0.0033) | Mantida: P > -1.23 -> Cu > -0.12 (0.0043)
# Removida: P > -1.23 -> Fe kb <= 0.33 (0.0042) | Mantida: Fe kb <= 0.33 -> P > -1.23 (0.0086)
# Removida: sum Fe <= 0.07 -> P > -1.23 (0.0038) | Mantida: P > -1.23 -> sum Fe <= 0.07 (0.0042)
# Removida: Ti ka > -0.52 -> sum Fe <= 0.62 (0.0040) | Mantida: sum Fe <= 0.62 -> Ti ka > -0.52 (0.0076)
# Removida: Compton scattering > 0.05 -> Cu > -0.55 (0.0034) | Mantida: Cu > -0.55 -> Compton scattering > 0.05 (0.0035)
# Removida: Cu <= 0.09 -> Compton scattering > 0.05 (0.0032) | Mantida: Compton scattering > 0.05 -> Cu <= 0.09 (0.0072)
# Removida: sum Fe > -0.28 -> Compton scattering > 0.05 (0.0035) | Mantida: Compton scattering > 0.05 -> sum Fe > -0.28 (0.0036)
# Removida: Ni > 0.13 -> sum Fe <= 0.07 (0.0031) | Mantida: sum Fe <= 0.07 -> Ni > 0.13 (0.0037)
# Removida: background1 <= -0.08 -> Ti ka > -0.52 (0.0022) | Mantida: Ti ka > -0.52 -> background1 <= -0.08 (0.0035)
# Removida: P <= 1.06 -> Cu <= 0.56 (0.0038) | Mantida: Cu <= 0.56 -> P <= 1.06 (0.0066)
# Removida: Cu <= 0.56 -> P <= 0.08 (0.0068) | Mantida: P <= 0.08 -> Cu <= 0.56 (0.0073)
# Removida: Cu <= 0.56 -> Ti kb <= 0.20 (0.0029) | Mantida: Ti kb <= 0.20 -> Cu <= 0.56 (0.0031)
# Removida: Ni > -0.14 -> Cu <= 0.56 (0.0032) | Mantida: Cu <= 0.56 -> Ni > -0.14 (0.0033)
# Removida: sum Fe > -0.28 -> Compton scattering > -0.88 (0.0033) | Mantida: Compton scattering > -0.88 -> sum Fe > -0.28 (0.0059)
# Removida: Ti ka > -0.86 -> sum Fe > -0.28 (0.0029) | Mantida: sum Fe > -0.28 -> Ti ka > -0.86 (0.0060)
# Removida: S <= 0.55 -> Cu <= 0.09 (0.0032) | Mantida: Cu <= 0.09 -> S <= 0.55 (0.0033)
# Removida: S <= 0.55 -> sum Fe > -0.60 (0.0035) | Mantida: sum Fe > -0.60 -> S <= 0.55 (0.0064)
# Removida: Ni > -0.60 -> S <= 0.55 (0.0026) | Mantida: S <= 0.55 -> Ni > -0.60 (0.0032)
# Removida: sum Fe > -0.60 -> Ni > -0.14 (0.0033) | Mantida: Ni > -0.14 -> sum Fe > -0.60 (0.0084)
# Removida: P <= 0.08 -> Ni > -0.14 (0.0037) | Mantida: Ni > -0.14 -> P <= 0.08 (0.0058)
# Removida: Compton scattering > -0.40 -> Ti ka > -0.86 (0.0031) | Mantida: Ti ka > -0.86 -> Compton scattering > -0.40 (0.0034)
# Removida: Compton scattering > -0.88 -> Compton scattering > -0.40 (0.0032) | Mantida: Compton scattering > -0.40 -> Compton scattering > -0.88 (0.0084)
# Removida: Compton scattering > -0.40 -> Ti ka > -0.70 (0.0028) | Mantida: Ti ka > -0.70 -> Compton scattering > -0.40 (0.0033)
# Removida: Ni > -0.60 -> Ti ka > -0.86 (0.0027) | Mantida: Ti ka > -0.86 -> Ni > -0.60 (0.0031)
# Removida: Ti ka > -0.86 -> Al > -0.19 (0.0028) | Mantida: Al > -0.19 -> Ti ka > -0.86 (0.0030)
# Removida: background1 <= -0.08 -> Compton scattering <= 0.87 (0.0023) | Mantida: Compton scattering <= 0.87 -> background1 <= -0.08 (0.0029)
# Removida: Ni > -0.60 -> Compton scattering > -0.88 (0.0024) | Mantida: Compton scattering > -0.88 -> Ni > -0.60 (0.0029)
# Removida: Compton scattering > -0.88 -> S <= 0.09 (0.0025) | Mantida: S <= 0.09 -> Compton scattering > -0.88 (0.0054)
# Removida: Ni <= 0.13 -> Al > -0.19 (0.0022) | Mantida: Al > -0.19 -> Ni <= 0.13 (0.0028)
# Removida: Al > -0.19 -> Compton scattering <= 0.87 (0.0028) | Mantida: Compton scattering <= 0.87 -> Al > -0.19 (0.0029)
# Removida: Ni > -0.60 -> Compton scattering <= 0.87 (0.0025) | Mantida: Compton scattering <= 0.87 -> Ni > -0.60 (0.0028)
# Removida: Al > -0.68 -> Ti ka > -0.70 (0.0024) | Mantida: Ti ka > -0.70 -> Al > -0.68 (0.0030)
# Removida: Ti ka > -0.70 -> Compton scattering <= 0.05 (0.0032) | Mantida: Compton scattering <= 0.05 -> Ti ka > -0.70 (0.0048)
# Removida: Fe kb > -0.44 -> Ti ka > -0.70 (0.0022) | Mantida: Ti ka > -0.70 -> Fe kb > -0.44 (0.0025)
# Removida: Ni <= -0.14 -> Al > -0.68 (0.0023) | Mantida: Al > -0.68 -> Ni <= -0.14 (0.0027)
# Removida: Compton scattering <= 0.05 -> Al > -0.68 (0.0024) | Mantida: Al > -0.68 -> Compton scattering <= 0.05 (0.0105)
# Removida: Ni <= 0.59 -> Al > -0.68 (0.0023) | Mantida: Al > -0.68 -> Ni <= 0.59 (0.0025)
# Removida: Ni <= 0.13 -> Al > -0.68 (0.0021) | Mantida: Al > -0.68 -> Ni <= 0.13 (0.0027)
# Removida: Ni <= 0.59 -> Ni <= -0.14 (0.0023) | Mantida: Ni <= -0.14 -> Ni <= 0.59 (0.0106)
# Removida: Ni <= -0.14 -> S <= 0.09 (0.0022) | Mantida: S <= 0.09 -> Ni <= -0.14 (0.0025)
# Removida: Ni <= -0.14 -> Ni <= 0.13 (0.0021) | Mantida: Ni <= 0.13 -> Ni <= -0.14 (0.0022)
# Removida: Compton scattering <= 0.05 -> Ni <= 0.59 (0.0027) | Mantida: Ni <= 0.59 -> Compton scattering <= 0.05 (0.0044)
# Removida: S <= 0.09 -> Ni <= 0.13 (0.0023) | Mantida: Ni <= 0.13 -> S <= 0.09 (0.0066)
# Removida: Ni <= 0.13 -> Fe kb > -0.44 (0.0019) | Mantida: Fe kb > -0.44 -> Ni <= 0.13 (0.0024)
# Removida: Al <= -0.19 -> background1 <= 0.11 (0.0022) | Mantida: background1 <= 0.11 -> Al <= -0.19 (0.0047)
# Removida: background1 <= 0.11 -> Al <= 0.62 (0.0016) | Mantida: Al <= 0.62 -> background1 <= 0.11 (0.0020)
# Removida: Al <= 0.62 -> Fe kb > -0.44 (0.0020) | Mantida: Fe kb > -0.44 -> Al <= 0.62 (0.0021)
# Removida: Al <= -0.19 -> Al <= 0.62 (0.0062) | Mantida: Al <= 0.62 -> Al <= -0.19 (0.0063)
# Removida: background1 <= 0.30 -> Al <= -0.19 (0.0015) | Mantida: Al <= -0.19 -> background1 <= 0.30 (0.0042)
# Removida: Fe kb > -0.63 -> Al <= -0.19 (0.0020) | Mantida: Al <= -0.19 -> Fe kb > -0.63 (0.0021)
# Removida: Fe kb > -0.91 -> Al <= 0.62 (0.0042) | Mantida: Al <= 0.62 -> Fe kb > -0.91 (0.0061)
# Removida: Al <= 0.62 -> background1 <= 0.30 (0.0020) | Mantida: background1 <= 0.30 -> Al <= 0.62 (0.0030)
# Removida: background1 <= 0.30 -> Fe kb > -0.91 (0.0014) | Mantida: Fe kb > -0.91 -> background1 <= 0.30 (0.0059)
# Removida: Fe kb > -0.63 -> background1 <= 0.30 (0.0021) | Mantida: background1 <= 0.30 -> Fe kb > -0.63 (0.0041)
# Removida: background1 > 0.11 -> background1 <= 0.30 (0.0014) | Mantida: background1 <= 0.30 -> background1 > 0.11 (0.0015)
# Removida: Al <= 0.19 -> Fe kb > -0.63 (0.0016) | Mantida: Fe kb > -0.63 -> Al <= 0.19 (0.0037)
# Removida: Al <= 0.19 -> background1 > 0.11 (0.0035) | Mantida: background1 > 0.11 -> Al <= 0.19 (0.0039)
# Removida: background1 > 0.11 -> Rayleight scattering <= -0.24 (0.0025) | Mantida: Rayleight scattering <= -0.24 -> background1 > 0.11 (0.0029)
# Removida: Ti kb > 0.03 -> Al <= 0.19 (0.0013) | Mantida: Al <= 0.19 -> Ti kb > 0.03 (0.0034)
# Removida: Ti kb > -0.32 -> Rayleight scattering <= -0.24 (0.0012) | Mantida: Rayleight scattering <= -0.24 -> Ti kb > -0.32 (0.0029)
# Removida: Ti kb > 0.03 -> Rayleight scattering <= -0.24 (0.0013) | Mantida: Rayleight scattering <= -0.24 -> Ti kb > 0.03 (0.0045)
# Removida: background1 > -0.08 -> Rayleight scattering <= -0.24 (0.0009) | Mantida: Rayleight scattering <= -0.24 -> background1 > -0.08 (0.0013)
# Removida: Ti kb > -0.32 -> Ti kb > 0.03 (0.0013) | Mantida: Ti kb > 0.03 -> Ti kb > -0.32 (0.0061)
# Removida: Ti kb > -0.32 -> Rayleight scattering <= 0.53 (0.0012) | Mantida: Rayleight scattering <= 0.53 -> Ti kb > -0.32 (0.0012)
# Removida: background1 > -0.08 -> Ti kb > 0.03 (0.0008) | Mantida: Ti kb > 0.03 -> background1 > -0.08 (0.0023)
# Removida: background1 > -0.26 -> background1 > -0.08 (0.0029) | Mantida: background1 > -0.08 -> background1 > -0.26 (0.0039)
# Removida: background1 > -0.08 -> Rayleight scattering > -0.50 (0.0010) | Mantida: Rayleight scattering > -0.50 -> background1 > -0.08 (0.0022)
# Removida: Rayleight scattering <= 0.53 -> background1 > -0.26 (0.0012) | Mantida: background1 > -0.26 -> Rayleight scattering <= 0.53 (0.0019)
# Removida: Rayleight scattering > -0.50 -> Rayleight scattering <= 0.03 (0.0022) | Mantida: Rayleight scattering <= 0.03 -> Rayleight scattering > -0.50 (0.0045)
# Removida: Rayleight scattering > -0.50 -> Rayleight scattering <= 0.53 (0.0012) | Mantida: Rayleight scattering <= 0.53 -> Rayleight scattering > -0.50 (0.0021)
# Removida: Rayleight scattering > -0.50 -> Rayleight scattering > 0.03 (0.0022) | Mantida: Rayleight scattering > 0.03 -> Rayleight scattering > -0.50 (0.0023)
# Removida: Rayleight scattering <= 0.53 -> Ti kb > -0.14 (0.0023) | Mantida: Ti kb > -0.14 -> Rayleight scattering <= 0.53 (0.0042)
# Removida: Zn <= -0.11 -> Ti kb > -0.14 (0.0009) | Mantida: Ti kb > -0.14 -> Zn <= -0.11 (0.0018)
# Removida: Rayleight scattering > 0.03 -> Ti kb > -0.14 (0.0011) | Mantida: Ti kb > -0.14 -> Rayleight scattering > 0.03 (0.0011)
# Removida: Rayleight scattering > 0.03 -> Rayleight scattering <= 0.53 (0.0011) | Mantida: Rayleight scattering <= 0.53 -> Rayleight scattering > 0.03 (0.0011)
# Removida: Rayleight scattering > -0.24 -> Zn <= -0.11 (0.0028) | Mantida: Zn <= -0.11 -> Rayleight scattering > -0.24 (0.0045)
# Removida: Zn > -0.11 -> Zn > -0.37 (0.0008) | Mantida: Zn > -0.37 -> Zn > -0.11 (0.0025)
# Removida: Zn > 0.10 -> Zn > -0.37 (0.0005) | Mantida: Zn > -0.37 -> Zn > 0.10 (0.0009)
# Removida: Zn > 0.10 -> Zn > -0.11 (0.0017) | Mantida: Zn > -0.11 -> Zn > 0.10 (0.0019)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 900 | Removidas: 198
# Nós predicados: 134
# Métrica: Perturbation
# Ponderação por variância explicada: ATIVADA
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#     Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0                K > 2.15              K > 2.15        Ca ka <= -1.50
# 1              K <= -1.46        Ca ka <= -1.50              K > 2.15
# 2           Ca ka <= 1.77            K <= -1.46         Ca ka <= 1.77
# 3               K > -1.46         Ca ka > -4.65             K > -1.46
# 4          Ca ka <= -1.50             K > -1.46          Ca ka > 1.77
# ..                    ...                   ...                   ...
# 131            Zn > -0.11             Zn > 0.10             Zn > 0.10
# 132             Zn > 0.10               Class_A            Zn > -0.11
# 133               Class_A               Class_B               Class_A
# 134               Class_B                   NaN               Class_B
# 135                   NaN                   NaN                   NaN
#
#     Predicate_pert_Seed_3
# 0          Ca ka <= -1.50
# 1               K > -1.46
# 2            Ca ka > 1.77
# 3                K > 2.15
# 4               K > -6.69
# ..                    ...
# 131            Zn > -0.37
# 132            Zn > -0.11
# 133             Zn > 0.10
# 134               Class_A
# 135               Class_B
#
# [136 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#           Predicate  Perturbation
# 0    Ca ka <= -1.50      0.041004
# 1          K > 2.15      0.037478
# 2      Ca ka > 1.77      0.033290
# 3        K <= -1.46      0.032802
# 4     Ca ka <= 1.77      0.031893
# ..              ...           ...
# 127      Zn <= 0.10      0.000835
# 128      Zn <= 0.34      0.000691
# 129      Zn > -0.37      0.000517
# 130      Zn > -0.11      0.000472
# 131       Zn > 0.10      0.000460
#
# [132 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                              Node  Local_Reaching_Centrality  \
# 0                        K > 2.15                   6.785412
# 1                  Ca ka <= -1.50                   6.421293
# 2                  Fe ka <= -3.05                   2.173922
# 3                     Si <= -1.67                   1.540259
# 4                     Mn <= -0.41                   1.296415
# 5                  Ca kb <= -0.59                   1.240538
# 6                        S > 0.55                   1.198419
# 7              background3 > 0.14                   1.116352
# 8               Rh L + Ar > -0.16                   0.996417
# 9                  Fe kb <= -0.91                   0.958183
# 10                 Ti ka <= -0.70                   0.943714
# 11                 Ti kb <= -0.14                   0.786772
# 12                       P > 0.08                   0.750388
# 13             background2 > 0.35                   0.739173
# 14                sum Fe <= -0.28                   0.674562
# 15                    Cu <= -0.12                   0.627001
# 16                      Al > 0.19                   0.578907
# 17      Compton scattering > 0.05                   0.546140
# 18                      Ni > 0.13                   0.536082
# 19           background1 <= -0.08                   0.473766
# 20  Rayleight scattering <= -0.24                   0.428634
# 21                    Zn <= -0.37                   0.391027
# 22                        Class_A                   0.000000
#
#                     Zone Threshold Operator
# 0                      K      2.15        >
# 1                  Ca ka     -1.50       <=
# 2                  Fe ka     -3.05       <=
# 3                     Si     -1.67       <=
# 4                     Mn     -0.41       <=
# 5                  Ca kb     -0.59       <=
# 6                      S      0.55        >
# 7            background3      0.14        >
# 8              Rh L + Ar     -0.16        >
# 9                  Fe kb     -0.91       <=
# 10                 Ti ka     -0.70       <=
# 11                 Ti kb     -0.14       <=
# 12                     P      0.08        >
# 13           background2      0.35        >
# 14                sum Fe     -0.28       <=
# 15                    Cu     -0.12       <=
# 16                    Al      0.19        >
# 17    Compton scattering      0.05        >
# 18                    Ni      0.13        >
# 19           background1     -0.08       <=
# 20  Rayleight scattering     -0.24       <=
# 21                    Zn     -0.37       <=
# 22                  None      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                Node  Local_Reaching_Centrality   Zone Threshold Operator  \
# 0          K > 2.15                   6.785412      K      2.15        >
# 1    Ca ka <= -1.50                   6.421293  Ca ka     -1.50       <=
# 2         K > -1.46                   5.136089      K     -1.46        >
# 3     Ca ka <= 1.77                   4.949388  Ca ka      1.77       <=
# 4        K <= -1.46                   4.860323      K     -1.46       <=
# ..              ...                        ...    ...       ...      ...
# 132      Zn > -0.37                   0.004708     Zn     -0.37        >
# 133      Zn > -0.11                   0.002687     Zn     -0.11        >
# 134       Zn > 0.10                   0.001628     Zn      0.10        >
# 135         Class_A                   0.000000   None      None     None
# 136         Class_B                   0.000000   None      None     None
#
#      Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0            20.676485                    90.0             0.022977
# 1            -9.476439                    94.0             0.083086
# 2           -12.506148                   111.0             0.014010
# 3            11.953266                    82.0             0.013408
# 4           -12.506148                   111.0             0.014010
# ..                 ...                     ...                  ...
# 132          -0.825949                    38.0             0.000121
# 133          -0.257461                   132.0             0.004205
# 134           0.231960                     7.0             0.000820
# 135                NaN                     NaN                  NaN
# 136                NaN                     NaN                  NaN
#
#            Node_Natural
# 0         K > 20.676485
# 1    Ca ka <= -9.476439
# 2        K > -12.506148
# 3    Ca ka <= 11.953266
# 4       K <= -12.506148
# ..                  ...
# 132      Zn > -0.825949
# 133      Zn > -0.257461
# 134       Zn > 0.231960
# 135                None
# 136                None
#
# [137 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'K':
#   - Dimensão: 19 variáveis espectrais
#   - Variância explicada pela PC1: 99.17%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = mlp_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = mlp_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance_proba                  Zone
# 0    3.36                      0.011790                     K
# 1     6.4                      0.010076                 Fe ka
# 2    3.66                      0.009841                 Ca ka
# 3    1.74                      0.004149                    Si
# 4       4                      0.004139                 Ca kb
# 5     4.5                      0.004036                 Ti ka
# 6       2                      0.003172                     P
# 7    5.86                      0.003121                    Mn
# 8    2.62                      0.003010             Rh L + Ar
# 9    7.08                      0.001923                 Fe kb
# 10   2.34                      0.001810                     S
# 11   7.24                      0.001607                    Ni
# 12   1.58                      0.001161                    Al
# 13  13.39                      0.001096                sum Fe
# 14  17.23                      0.001008           background3
# 15  11.99                      0.000999           background2
# 16   4.94                      0.000955                 Ti kb
# 17   7.85                      0.000923                    Cu
# 18  19.59                      0.000897    Compton scattering
# 19   8.65                      0.000704                    Zn
# 20  19.85                      0.000633  Rayleight scattering
# 21   5.42                      0.000513           background1
# 22  20.81                      0.000066                   NaN

# %%
import numpy as np

max_len = max(
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#                     Shap           Permutation      LRC_perturbation  \
# 0                  Ca ka                     K                     K
# 1                  Fe ka                 Fe ka                 Ca ka
# 2                      K                 Ca ka                 Fe ka
# 3                     Si                    Si                    Si
# 4                  Ca kb                 Ca kb                    Mn
# 5                  Ti ka                 Ti ka                 Ca kb
# 6              Rh L + Ar                     P                     S
# 7            background3                    Mn           background3
# 8                     Mn             Rh L + Ar             Rh L + Ar
# 9            background2                 Fe kb                 Fe kb
# 10                     P                     S                 Ti ka
# 11    Compton scattering                    Ni                 Ti kb
# 12                sum Fe                    Al                     P
# 13                 Fe kb                sum Fe           background2
# 14                     S           background3                sum Fe
# 15                    Ni           background2                    Cu
# 16                 Ti kb                 Ti kb                    Al
# 17                    Al                    Cu    Compton scattering
# 18  Rayleight scattering    Compton scattering                    Ni
# 19           background1                    Zn           background1
# 20                    Cu  Rayleight scattering  Rayleight scattering
# 21                    Zn           background1                    Zn
# 22                   NaN                   NaN                  None
#
#           LRC_covariance
# 0                  Fe ka
# 1                      K
# 2                  Ca ka
# 3                     Si
# 4                  Ti ka
# 5                  Fe kb
# 6                  Ca kb
# 7              Rh L + Ar
# 8            background3
# 9     Compton scattering
# 10                    Al
# 11  Rayleight scattering
# 12                sum Fe
# 13                     P
# 14                 Ti kb
# 15           background2
# 16                    Mn
# 17                    Cu
# 18                     S
# 19                    Ni
# 20                    Zn
# 21           background1
# 22                  None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_5140\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 3       Permutation  LRC_perturbation   0.821418
# 4       Permutation    LRC_covariance   0.631460
# 0              Shap       Permutation   0.551191
# 2              Shap    LRC_covariance   0.531470
# 1              Shap  LRC_perturbation   0.523339
# 5  LRC_perturbation    LRC_covariance   0.509926

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
