# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/milk/plsda/milk.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '2.66':'22.62']

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.66':'22.62'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.66':'22.62'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-09 05:34:28,622 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-09 05:34:28,664 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-09 05:34:28,708 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-09 05:34:28,807 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import mlp_optimized

mlp_model = mlp_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, 
                          aim='classification', 
                          hidden_layer_sizes=(64,32),
                          activation='tanh',
                          learning_rate='adaptive',
                          max_iter=10,
                          random_state=1)
mlp_model[0]
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal                CM Cal  \
# 0   MLP      0.981343         0.970238              1.0  [[100, 0], [5, 163]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred              CM Pred
# 0       0.721739             0.625          0.883721  [[38, 5], [27, 45]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('Ag La', 2.66, 3.10),
('Ag Lb', 3.10, 3.46),
('Ca', 3.46, 3.92),
('background', 3.92, 6.12),
('Fe', 6.12, 6.68),
('Cu', 6.70, 8.37),
('Zn', 8.37, 9.10),
('Bremsstrahlung', 9.10, 20.06),
('Ag compton', 20.06, 21.62),
('Ag ka', 21.48, 22.62)
]

# %% [markdown]
# ## SHAP

# %%
shap_global_importance = pd.read_csv('shap_milk.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#    energy  Mean_Abs_SHAP            Zone
# 0    3.17       0.021872           Ag Lb
# 1    3.02       0.019238           Ag La
# 2   22.28       0.016172           Ag ka
# 3    8.73       0.006672              Zn
# 4   21.18       0.004494      Ag compton
# 5   16.55       0.003386  Bremsstrahlung
# 6    6.09       0.001753      background
# 7    6.86       0.001411              Cu
# 8    6.40       0.001392              Fe
# 9    3.58       0.000174              Ca

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zona 'Ag La': VE = 84.62%, dim = 18 variáveis
# Zona 'Ag Lb': VE = 86.51%, dim = 15 variáveis
# Zona 'Ca': VE = 21.64%, dim = 19 variáveis
# Zona 'background': VE = 3.44%, dim = 87 variáveis
# Zona 'Fe': VE = 12.88%, dim = 23 variáveis
# Zona 'Cu': VE = 9.26%, dim = 66 variáveis
# Zona 'Zn': VE = 17.17%, dim = 29 variáveis
# Zona 'Bremsstrahlung': VE = 30.64%, dim = 429 variáveis
# Zona 'Ag compton': VE = 52.31%, dim = 62 variáveis
# Zona 'Ag ka': VE = 76.93%, dim = 45 variáveis
#
# Scores DataFrame shape: (268, 10)

# %%
y_pred = mlp_model[4]['MLP'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(mlp_model[4]['MLP'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graphv3_pca(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 69
# Removida: Ag Lb <= 2.36 -> Ag La <= 7.76 (5.6885) | Mantida: Ag La <= 7.76 -> Ag Lb <= 2.36 (19.8585)
# Removida: Ag Lb <= 6.48 -> Ag Lb <= 2.36 (2.5482) | Mantida: Ag Lb <= 2.36 -> Ag Lb <= 6.48 (19.2723)
# Removida: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= -1.54 (0.2571) | Mantida: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 4.15 (1.0090)
# Removida: Bremsstrahlung <= -1.54 -> Ag ka <= 5.37 (0.6917) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung <= -1.54 (0.7465)
# Removida: Bremsstrahlung <= -1.54 -> Bremsstrahlung > -9.06 (0.1594) | Mantida: Bremsstrahlung > -9.06 -> Bremsstrahlung <= -1.54 (0.1859)
# Removida: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (0.4550) | Mantida: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (1.1721)
# Removida: Bremsstrahlung <= 4.15 -> Ag ka > 5.37 (0.6248) | Mantida: Ag ka > 5.37 -> Bremsstrahlung <= 4.15 (0.7066)
# Removida: Bremsstrahlung <= 9.64 -> Ag ka > 5.37 (0.4315) | Mantida: Ag ka > 5.37 -> Bremsstrahlung <= 9.64 (0.5183)
# Removida: Bremsstrahlung <= 9.64 -> Ag ka <= 5.37 (0.3594) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung <= 9.64 (0.4668)
# Removida: Ag ka > 5.37 -> Ag ka <= 5.37 (0.5959) | Mantida: Ag ka <= 5.37 -> Ag ka > 5.37 (1.3356)
# Removida: Ag compton <= 6.52 -> Ag ka > 5.37 (0.2417) | Mantida: Ag ka > 5.37 -> Ag compton <= 6.52 (0.9051)
# Removida: Bremsstrahlung > -1.54 -> Ag compton <= 6.52 (0.1690) | Mantida: Ag compton <= 6.52 -> Bremsstrahlung > -1.54 (0.3028)
# Removida: Ag compton <= -1.09 -> Ag compton <= 6.52 (0.2633) | Mantida: Ag compton <= 6.52 -> Ag compton <= -1.09 (0.7929)
# Removida: Bremsstrahlung > -9.06 -> Ag compton <= 6.52 (0.2013) | Mantida: Ag compton <= 6.52 -> Bremsstrahlung > -9.06 (0.2822)
# Removida: Bremsstrahlung > -9.06 -> Bremsstrahlung > -1.54 (0.1599) | Mantida: Bremsstrahlung > -1.54 -> Bremsstrahlung > -9.06 (0.4179)
# Removida: Bremsstrahlung > -1.54 -> Ag compton > -6.71 (0.0948) | Mantida: Ag compton > -6.71 -> Bremsstrahlung > -1.54 (0.1356)
# Removida: Bremsstrahlung > 4.15 -> Bremsstrahlung > -1.54 (0.1712) | Mantida: Bremsstrahlung > -1.54 -> Bremsstrahlung > 4.15 (0.5496)
# Removida: Ag compton <= -1.09 -> Ag La > -18.52 (0.1781) | Mantida: Ag La > -18.52 -> Ag compton <= -1.09 (0.3568)
# Removida: Ag La > -18.52 -> Ag compton <= 2.96 (0.2821) | Mantida: Ag compton <= 2.96 -> Ag La > -18.52 (0.5304)
# Removida: Ag compton <= 2.96 -> Ag Lb > -15.87 (0.1984) | Mantida: Ag Lb > -15.87 -> Ag compton <= 2.96 (0.2098)
# Removida: Ag compton > -6.71 -> Ag La > -18.52 (0.1100) | Mantida: Ag La > -18.52 -> Ag compton > -6.71 (0.2885)
# Removida: Ag La > -18.52 -> Ag ka <= 20.95 (0.2612) | Mantida: Ag ka <= 20.95 -> Ag La > -18.52 (0.5739)
# Removida: Ag compton > -6.71 -> Ag compton > -1.09 (0.2700) | Mantida: Ag compton > -1.09 -> Ag compton > -6.71 (0.3529)
# Removida: Ag ka <= 20.95 -> Ag ka <= -7.06 (0.1831) | Mantida: Ag ka <= -7.06 -> Ag ka <= 20.95 (0.2419)
# Removida: Ag ka <= -7.06 -> Ag compton > -1.09 (0.1772) | Mantida: Ag compton > -1.09 -> Ag ka <= -7.06 (0.2499)
# Removida: Ag ka <= -7.06 -> Ag ka > -7.06 (0.1004) | Mantida: Ag ka > -7.06 -> Ag ka <= -7.06 (0.1380)
# Removida: Ag Lb > 2.36 -> Ag compton > -1.09 (0.1868) | Mantida: Ag compton > -1.09 -> Ag Lb > 2.36 (0.2714)
# Removida: Ag Lb > 2.36 -> Ag La > 2.70 (0.5502) | Mantida: Ag La > 2.70 -> Ag Lb > 2.36 (0.5691)
# Removida: Ag La > 2.70 -> Ag Lb > -15.87 (0.1622) | Mantida: Ag Lb > -15.87 -> Ag La > 2.70 (0.2510)
# Removida: Cu > 0.32 -> Ca <= -0.68 (0.0127) | Mantida: Ca <= -0.68 -> Cu > 0.32 (0.0222)
# Removida: Cu > 0.32 -> Ca > -0.68 (0.0163) | Mantida: Ca > -0.68 -> Cu > 0.32 (0.0198)
# Removida: Cu > 0.32 -> Fe > -1.18 (0.0106) | Mantida: Fe > -1.18 -> Cu > 0.32 (0.0117)
# Removida: Cu > 0.32 -> Fe > 0.31 (0.0079) | Mantida: Fe > 0.31 -> Cu > 0.32 (0.0113)
# Removida: Fe > -1.18 -> Ca <= -0.68 (0.0134) | Mantida: Ca <= -0.68 -> Fe > -1.18 (0.0212)
# Removida: Ca > -1.79 -> Ca <= -0.68 (0.0224) | Mantida: Ca <= -0.68 -> Ca > -1.79 (0.0527)
# Removida: Ca <= -0.68 -> Ag ka > -11.59 (0.0313) | Mantida: Ag ka > -11.59 -> Ca <= -0.68 (0.0859)
# Removida: Ca <= -0.68 -> Ca > -0.68 (0.0179) | Mantida: Ca > -0.68 -> Ca <= -0.68 (0.0259)
# Removida: Fe > 0.31 -> Ca > 0.46 (0.0106) | Mantida: Ca > 0.46 -> Fe > 0.31 (0.0233)
# Removida: Ca <= 0.46 -> Ca > 0.46 (0.0215) | Mantida: Ca > 0.46 -> Ca <= 0.46 (0.0219)
# Removida: Zn > 0.56 -> Ag compton > 2.96 (0.0169) | Mantida: Ag compton > 2.96 -> Zn > 0.56 (0.1469)
# Removida: Fe > -1.18 -> Zn > 0.56 (0.0109) | Mantida: Zn > 0.56 -> Fe > -1.18 (0.0155)
# Removida: Fe > 0.31 -> Ag Lb > -15.87 (0.0122) | Mantida: Ag Lb > -15.87 -> Fe > 0.31 (0.0661)
# Removida: Cu > -1.74 -> Ag La > 7.76 (0.0069) | Mantida: Ag La > 7.76 -> Cu > -1.74 (0.0157)
# Removida: background > 0.40 -> Cu > -1.74 (0.0013) | Mantida: Cu > -1.74 -> background > 0.40 (0.0017)
# Removida: Cu > -1.74 -> Ag ka > -11.59 (0.0046) | Mantida: Ag ka > -11.59 -> Cu > -1.74 (0.0219)
# Removida: Fe > 0.31 -> Ca > -1.79 (0.0133) | Mantida: Ca > -1.79 -> Fe > 0.31 (0.0390)
# Removida: Ca <= 1.81 -> Ca > -1.79 (0.0206) | Mantida: Ca > -1.79 -> Ca <= 1.81 (0.0221)
# Removida: Fe > 0.31 -> Ag compton > 2.96 (0.0268) | Mantida: Ag compton > 2.96 -> Fe > 0.31 (0.0409)
# Removida: Fe > 0.31 -> Ca > -0.68 (0.0098) | Mantida: Ca > -0.68 -> Fe > 0.31 (0.0235)
# Removida: Fe > -1.18 -> Fe > -0.36 (0.0085) | Mantida: Fe > -0.36 -> Fe > -1.18 (0.0124)
# Removida: Fe > -1.18 -> Ca > -0.68 (0.0119) | Mantida: Ca > -0.68 -> Fe > -1.18 (0.0363)
# Removida: background > -1.23 -> Cu > -0.64 (0.0004) | Mantida: Cu > -0.64 -> background > -1.23 (0.0088)
# Removida: Cu > -0.64 -> Fe <= 0.31 (0.0025) | Mantida: Fe <= 0.31 -> Cu > -0.64 (0.0092)
# Removida: Fe > -0.36 -> Ca <= 1.81 (0.0090) | Mantida: Ca <= 1.81 -> Fe > -0.36 (0.0149)
# Removida: Ca <= 1.81 -> Ag Lb > 6.48 (0.0167) | Mantida: Ag Lb > 6.48 -> Ca <= 1.81 (0.0514)
# Removida: Ca <= 1.81 -> Ca <= 0.46 (0.0342) | Mantida: Ca <= 0.46 -> Ca <= 1.81 (0.0415)
# Removida: Cu <= 1.92 -> Ca <= 0.46 (0.0056) | Mantida: Ca <= 0.46 -> Cu <= 1.92 (0.0118)
# Removida: background <= -0.46 -> Ag La > 7.76 (0.0007) | Mantida: Ag La > 7.76 -> background <= -0.46 (0.0189)
# Removida: Zn > -1.47 -> Ca > -0.68 (0.0133) | Mantida: Ca > -0.68 -> Zn > -1.47 (0.0136)
# Removida: Cu <= -0.64 -> Zn <= 0.56 (0.0018) | Mantida: Zn <= 0.56 -> Cu <= -0.64 (0.0053)
# Removida: Cu <= 0.32 -> Zn <= 1.56 (0.0034) | Mantida: Zn <= 1.56 -> Cu <= 0.32 (0.0045)
# Removida: background > -1.23 -> Ag Lb > 6.48 (0.0021) | Mantida: Ag Lb > 6.48 -> background > -1.23 (0.0385)
# Removida: Zn > -1.47 -> Ag Lb > 6.48 (0.0109) | Mantida: Ag Lb > 6.48 -> Zn > -1.47 (0.1222)
# Removida: background <= 1.29 -> Ag Lb > 6.48 (0.0020) | Mantida: Ag Lb > 6.48 -> background <= 1.29 (0.0502)
# Removida: background > -0.46 -> Cu <= 0.32 (0.0007) | Mantida: Cu <= 0.32 -> background > -0.46 (0.0036)
# Removida: Fe <= 0.31 -> Zn > -0.39 (0.0029) | Mantida: Zn > -0.39 -> Fe <= 0.31 (0.0104)
# Removida: Fe <= 1.20 -> Zn <= 0.56 (0.0029) | Mantida: Zn <= 0.56 -> Fe <= 1.20 (0.0031)
# Removida: Fe <= 1.20 -> background <= 0.40 (0.0017) | Mantida: background <= 0.40 -> Fe <= 1.20 (0.0037)
# Removida: Cu <= 0.32 -> Zn <= -0.39 (0.0023) | Mantida: Zn <= -0.39 -> Cu <= 0.32 (0.0068)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 422 | Removidas: 69
# Nós predicados: 60
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 65
# Removida: Ag Lb <= 6.48 -> Ag Lb <= 2.36 (2.5519) | Mantida: Ag Lb <= 2.36 -> Ag Lb <= 6.48 (25.1768)
# Removida: Bremsstrahlung <= -1.54 -> Ag ka <= 5.37 (0.2293) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung <= -1.54 (3.1058)
# Removida: Bremsstrahlung > -9.06 -> Ag ka <= 5.37 (0.1321) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung > -9.06 (0.3033)
# Removida: Bremsstrahlung <= -1.54 -> Bremsstrahlung > -9.06 (0.1564) | Mantida: Bremsstrahlung > -9.06 -> Bremsstrahlung <= -1.54 (0.2140)
# Removida: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= -1.54 (0.2413) | Mantida: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 4.15 (0.7696)
# Removida: Ag compton > -6.71 -> Ag ka <= -7.06 (0.1341) | Mantida: Ag ka <= -7.06 -> Ag compton > -6.71 (0.1731)
# Removida: Ag La > -18.52 -> Ag ka <= -7.06 (0.1810) | Mantida: Ag ka <= -7.06 -> Ag La > -18.52 (0.3736)
# Removida: Bremsstrahlung > 4.15 -> Ag ka <= -7.06 (0.0855) | Mantida: Ag ka <= -7.06 -> Bremsstrahlung > 4.15 (0.4004)
# Removida: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (0.4341) | Mantida: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.8395)
# Removida: Bremsstrahlung <= 4.15 -> Ag ka > 5.37 (0.4187) | Mantida: Ag ka > 5.37 -> Bremsstrahlung <= 4.15 (2.0333)
# Removida: Ca <= -0.68 -> Ag ka > -11.59 (0.0249) | Mantida: Ag ka > -11.59 -> Ca <= -0.68 (0.1070)
# Removida: Bremsstrahlung > -1.54 -> Bremsstrahlung <= 9.64 (0.1947) | Mantida: Bremsstrahlung <= 9.64 -> Bremsstrahlung > -1.54 (0.3006)
# Removida: Bremsstrahlung <= 9.64 -> Ag ka > 5.37 (0.1965) | Mantida: Ag ka > 5.37 -> Bremsstrahlung <= 9.64 (0.6424)
# Removida: Bremsstrahlung > 4.15 -> Bremsstrahlung <= 9.64 (0.1501) | Mantida: Bremsstrahlung <= 9.64 -> Bremsstrahlung > 4.15 (0.1595)
# Removida: Bremsstrahlung > -9.06 -> Bremsstrahlung > -1.54 (0.1104) | Mantida: Bremsstrahlung > -1.54 -> Bremsstrahlung > -9.06 (0.2771)
# Removida: Bremsstrahlung > -1.54 -> Bremsstrahlung > 4.15 (0.1012) | Mantida: Bremsstrahlung > 4.15 -> Bremsstrahlung > -1.54 (0.3002)
# Removida: Bremsstrahlung > -9.06 -> Ag La > -18.52 (0.1102) | Mantida: Ag La > -18.52 -> Bremsstrahlung > -9.06 (0.2753)
# Removida: Bremsstrahlung > -9.06 -> Ag ka > 5.37 (0.1987) | Mantida: Ag ka > 5.37 -> Bremsstrahlung > -9.06 (0.5790)
# Removida: Bremsstrahlung > 4.15 -> Ag compton <= 6.52 (0.1391) | Mantida: Ag compton <= 6.52 -> Bremsstrahlung > 4.15 (0.4927)
# Removida: Ag ka <= 20.95 -> Ag compton <= 2.96 (0.1243) | Mantida: Ag compton <= 2.96 -> Ag ka <= 20.95 (0.1923)
# Removida: Ag compton > -6.71 -> Ag ka <= 20.95 (0.1755) | Mantida: Ag ka <= 20.95 -> Ag compton > -6.71 (0.2179)
# Removida: Ag compton <= 6.52 -> Ag ka <= 20.95 (0.2502) | Mantida: Ag ka <= 20.95 -> Ag compton <= 6.52 (0.3072)
# Removida: Ag compton <= -1.09 -> Ag La > -18.52 (0.3482) | Mantida: Ag La > -18.52 -> Ag compton <= -1.09 (0.3493)
# Removida: Ag compton <= 2.96 -> Ag Lb > 2.36 (0.1295) | Mantida: Ag Lb > 2.36 -> Ag compton <= 2.96 (0.1835)
# Removida: Ag compton > -1.09 -> Ag Lb > 2.36 (0.1218) | Mantida: Ag Lb > 2.36 -> Ag compton > -1.09 (0.3666)
# Removida: Ag Lb > 2.36 -> Ag La > 2.70 (0.2309) | Mantida: Ag La > 2.70 -> Ag Lb > 2.36 (0.6435)
# Removida: Ag Lb > 2.36 -> Ag compton > -6.71 (0.1805) | Mantida: Ag compton > -6.71 -> Ag Lb > 2.36 (0.3635)
# Removida: Ag La > 2.70 -> Ag compton > -1.09 (0.2034) | Mantida: Ag compton > -1.09 -> Ag La > 2.70 (0.2616)
# Removida: Ag compton > -6.71 -> Ag compton > -1.09 (0.2438) | Mantida: Ag compton > -1.09 -> Ag compton > -6.71 (0.3201)
# Removida: Ag La > 2.70 -> Ag Lb > -15.87 (0.1796) | Mantida: Ag Lb > -15.87 -> Ag La > 2.70 (0.6551)
# Removida: Cu > 0.32 -> Ca > 0.46 (0.0114) | Mantida: Ca > 0.46 -> Cu > 0.32 (0.0254)
# Removida: Cu > 0.32 -> Ca <= -0.68 (0.0102) | Mantida: Ca <= -0.68 -> Cu > 0.32 (0.0249)
# Removida: Ca <= -0.68 -> Zn > 0.56 (0.0284) | Mantida: Zn > 0.56 -> Ca <= -0.68 (0.0422)
# Removida: Ca <= -0.68 -> Ca <= 0.46 (0.0231) | Mantida: Ca <= 0.46 -> Ca <= -0.68 (0.0238)
# Removida: Zn > 0.56 -> Ca > -1.79 (0.0359) | Mantida: Ca > -1.79 -> Zn > 0.56 (0.0686)
# Removida: Ca <= 1.81 -> Ca > -1.79 (0.0215) | Mantida: Ca > -1.79 -> Ca <= 1.81 (0.0233)
# Removida: Fe > 0.31 -> Ca > -1.79 (0.0137) | Mantida: Ca > -1.79 -> Fe > 0.31 (0.0402)
# Removida: Zn > 0.56 -> Fe > -1.18 (0.0184) | Mantida: Fe > -1.18 -> Zn > 0.56 (0.0264)
# Removida: Zn > 0.56 -> Ca > -0.68 (0.0179) | Mantida: Ca > -0.68 -> Zn > 0.56 (0.0506)
# Removida: Cu > 0.32 -> Fe > -1.18 (0.0106) | Mantida: Fe > -1.18 -> Cu > 0.32 (0.0138)
# Removida: Fe > -1.18 -> Ca <= 0.46 (0.0085) | Mantida: Ca <= 0.46 -> Fe > -1.18 (0.0409)
# Removida: Fe > -1.18 -> Zn > -1.47 (0.0084) | Mantida: Zn > -1.47 -> Fe > -1.18 (0.0139)
# Removida: Ca > -0.68 -> Cu > 0.32 (0.0189) | Mantida: Cu > 0.32 -> Ca > -0.68 (0.0202)
# Removida: Fe > -0.36 -> Ca > -0.68 (0.0119) | Mantida: Ca > -0.68 -> Fe > -0.36 (0.0155)
# Removida: Fe > -0.36 -> Zn > -1.47 (0.0069) | Mantida: Zn > -1.47 -> Fe > -0.36 (0.0146)
# Removida: Fe > -0.36 -> Ca <= 1.81 (0.0111) | Mantida: Ca <= 1.81 -> Fe > -0.36 (0.0153)
# Removida: Ca > -0.68 -> Ca <= 0.46 (0.0179) | Mantida: Ca <= 0.46 -> Ca > -0.68 (0.0191)
# Removida: Zn > -0.39 -> Ag compton > 2.96 (0.0112) | Mantida: Ag compton > 2.96 -> Zn > -0.39 (0.0310)
# Removida: background > -1.23 -> Zn > -1.47 (0.0024) | Mantida: Zn > -1.47 -> background > -1.23 (0.0121)
# Removida: background > -1.23 -> Fe <= 1.20 (0.0021) | Mantida: Fe <= 1.20 -> background > -1.23 (0.0040)
# Removida: background <= 1.29 -> Ca <= 0.46 (0.0018) | Mantida: Ca <= 0.46 -> background <= 1.29 (0.0127)
# Removida: Fe <= 1.20 -> Zn > -0.39 (0.0077) | Mantida: Zn > -0.39 -> Fe <= 1.20 (0.0146)
# Removida: Zn > -0.39 -> Ag Lb > 6.48 (0.0171) | Mantida: Ag Lb > 6.48 -> Zn > -0.39 (0.0536)
# Removida: background > -0.46 -> Fe <= 1.20 (0.0015) | Mantida: Fe <= 1.20 -> background > -0.46 (0.0103)
# Removida: Fe <= 1.20 -> Ag La > 7.76 (0.0021) | Mantida: Ag La > 7.76 -> Fe <= 1.20 (0.0276)
# Removida: Cu <= -0.64 -> Fe <= 1.20 (0.0016) | Mantida: Fe <= 1.20 -> Cu <= -0.64 (0.0018)
# Removida: Fe <= -0.36 -> Fe <= 1.20 (0.0022) | Mantida: Fe <= 1.20 -> Fe <= -0.36 (0.0028)
# Removida: background > 0.40 -> background > -0.46 (0.0010) | Mantida: background > -0.46 -> background > 0.40 (0.0015)
# Removida: background > -0.46 -> background <= 1.29 (0.0022) | Mantida: background <= 1.29 -> background > -0.46 (0.0030)
# Removida: Zn <= 0.56 -> Ag Lb > 6.48 (0.0065) | Mantida: Ag Lb > 6.48 -> Zn <= 0.56 (0.0395)
# Removida: Zn <= 0.56 -> Cu <= 1.92 (0.0028) | Mantida: Cu <= 1.92 -> Zn <= 0.56 (0.0047)
# Removida: background <= 0.40 -> Cu <= -0.64 (0.0007) | Mantida: Cu <= -0.64 -> background <= 0.40 (0.0026)
# Removida: background <= 0.40 -> Cu > -0.64 (0.0009) | Mantida: Cu > -0.64 -> background <= 0.40 (0.0045)
# Removida: Cu > -0.64 -> Zn <= -0.39 (0.0061) | Mantida: Zn <= -0.39 -> Cu > -0.64 (0.0141)
# Removida: background <= -0.46 -> Ag La > 7.76 (0.0015) | Mantida: Ag La > 7.76 -> background <= -0.46 (0.0379)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 393 | Removidas: 65
# Nós predicados: 60
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 66
# Removida: Ag La <= 7.76 -> Ag La <= 2.70 (3.1217) | Mantida: Ag La <= 2.70 -> Ag La <= 7.76 (28.2643)
# Removida: Ag Lb <= 6.48 -> Ag Lb <= 2.36 (2.6419) | Mantida: Ag Lb <= 2.36 -> Ag Lb <= 6.48 (25.1763)
# Removida: Bremsstrahlung > -9.06 -> Ag ka > 5.37 (0.2109) | Mantida: Ag ka > 5.37 -> Bremsstrahlung > -9.06 (1.2231)
# Removida: Bremsstrahlung <= -1.54 -> Ag ka > 5.37 (0.2668) | Mantida: Ag ka > 5.37 -> Bremsstrahlung <= -1.54 (1.7909)
# Removida: Ag ka <= 5.37 -> Ag ka > 5.37 (0.7255) | Mantida: Ag ka > 5.37 -> Ag ka <= 5.37 (0.8103)
# Removida: Bremsstrahlung > -1.54 -> Bremsstrahlung > -9.06 (0.1561) | Mantida: Bremsstrahlung > -9.06 -> Bremsstrahlung > -1.54 (0.3869)
# Removida: Bremsstrahlung > -9.06 -> Bremsstrahlung <= 9.64 (0.1743) | Mantida: Bremsstrahlung <= 9.64 -> Bremsstrahlung > -9.06 (0.3513)
# Removida: Bremsstrahlung > -9.06 -> Ag compton <= 6.52 (0.1516) | Mantida: Ag compton <= 6.52 -> Bremsstrahlung > -9.06 (0.4440)
# Removida: Bremsstrahlung > -9.06 -> Ag ka <= 5.37 (0.2201) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung > -9.06 (0.2692)
# Removida: Ag compton <= 6.52 -> Bremsstrahlung > 4.15 (0.2813) | Mantida: Bremsstrahlung > 4.15 -> Ag compton <= 6.52 (0.4011)
# Removida: Bremsstrahlung > 4.15 -> Bremsstrahlung <= 4.15 (0.1770) | Mantida: Bremsstrahlung <= 4.15 -> Bremsstrahlung > 4.15 (0.2388)
# Removida: Bremsstrahlung > 4.15 -> Ag ka <= 20.95 (0.0531) | Mantida: Ag ka <= 20.95 -> Bremsstrahlung > 4.15 (0.3964)
# Removida: Bremsstrahlung <= -1.54 -> Ag ka <= 5.37 (0.5458) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung <= -1.54 (1.4083)
# Removida: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (0.2249) | Mantida: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.8387)
# Removida: Bremsstrahlung <= 4.15 -> Ag ka <= -7.06 (0.1103) | Mantida: Ag ka <= -7.06 -> Bremsstrahlung <= 4.15 (0.9622)
# Removida: Ag compton <= 6.52 -> Bremsstrahlung <= 9.64 (0.2632) | Mantida: Bremsstrahlung <= 9.64 -> Ag compton <= 6.52 (0.2948)
# Removida: Zn <= 1.56 -> Ag ka > -11.59 (0.0058) | Mantida: Ag ka > -11.59 -> Zn <= 1.56 (0.0290)
# Removida: Ag compton > -1.09 -> Ag compton > -6.71 (0.1684) | Mantida: Ag compton > -6.71 -> Ag compton > -1.09 (0.4815)
# Removida: Ag compton <= 2.96 -> Ag compton > -6.71 (0.1545) | Mantida: Ag compton > -6.71 -> Ag compton <= 2.96 (0.1999)
# Removida: Ag compton > -6.71 -> Ag Lb > -15.87 (0.0882) | Mantida: Ag Lb > -15.87 -> Ag compton > -6.71 (0.2278)
# Removida: Ag compton > -1.09 -> Ag Lb > 2.36 (0.1038) | Mantida: Ag Lb > 2.36 -> Ag compton > -1.09 (0.2208)
# Removida: Ca > -1.79 -> Ag compton > -1.09 (0.0228) | Mantida: Ag compton > -1.09 -> Ca > -1.79 (0.1098)
# Removida: Ag La > -18.52 -> Ag compton > -1.09 (0.2516) | Mantida: Ag compton > -1.09 -> Ag La > -18.52 (0.3657)
# Removida: Ag compton <= 2.96 -> Ag compton > -1.09 (0.1887) | Mantida: Ag compton > -1.09 -> Ag compton <= 2.96 (0.2781)
# Removida: Fe > -0.36 -> Ag ka > -7.06 (0.0120) | Mantida: Ag ka > -7.06 -> Fe > -0.36 (0.0611)
# Removida: Ag compton <= -1.09 -> Ag La > 2.70 (0.1394) | Mantida: Ag La > 2.70 -> Ag compton <= -1.09 (0.2410)
# Removida: Ag Lb > 2.36 -> Ag La > 2.70 (0.3965) | Mantida: Ag La > 2.70 -> Ag Lb > 2.36 (0.7769)
# Removida: Ag La > 2.70 -> Ag Lb > -15.87 (0.1911) | Mantida: Ag Lb > -15.87 -> Ag La > 2.70 (0.4071)
# Removida: Ag compton <= 2.96 -> Ag Lb > 2.36 (0.1439) | Mantida: Ag Lb > 2.36 -> Ag compton <= 2.96 (0.1678)
# Removida: Ag ka <= 20.95 -> Ag Lb > 2.36 (0.1912) | Mantida: Ag Lb > 2.36 -> Ag ka <= 20.95 (0.2283)
# Removida: Fe > -1.18 -> Ag ka <= 20.95 (0.0192) | Mantida: Ag ka <= 20.95 -> Fe > -1.18 (0.0831)
# Removida: Ca <= -0.68 -> Ca > -1.79 (0.0471) | Mantida: Ca > -1.79 -> Ca <= -0.68 (0.0783)
# Removida: Cu > 0.32 -> Ca > -1.79 (0.0241) | Mantida: Ca > -1.79 -> Cu > 0.32 (0.0495)
# Removida: Cu > 0.32 -> Ca <= -0.68 (0.0237) | Mantida: Ca <= -0.68 -> Cu > 0.32 (0.0304)
# Removida: Zn > 0.56 -> Ca <= -0.68 (0.0219) | Mantida: Ca <= -0.68 -> Zn > 0.56 (0.0232)
# Removida: Ca <= -0.68 -> Ag compton > 2.96 (0.0251) | Mantida: Ag compton > 2.96 -> Ca <= -0.68 (0.0722)
# Removida: Ca <= 0.46 -> Ca > 0.46 (0.0177) | Mantida: Ca > 0.46 -> Ca <= 0.46 (0.0235)
# Removida: Ca > 0.46 -> Ca > -0.68 (0.0517) | Mantida: Ca > -0.68 -> Ca > 0.46 (0.0596)
# Removida: Fe > -0.36 -> Ag compton > 2.96 (0.0073) | Mantida: Ag compton > 2.96 -> Fe > -0.36 (0.0367)
# Removida: Ca > -0.68 -> Zn > 0.56 (0.0262) | Mantida: Zn > 0.56 -> Ca > -0.68 (0.0361)
# Removida: Zn > 0.56 -> Ca <= 0.46 (0.0155) | Mantida: Ca <= 0.46 -> Zn > 0.56 (0.0231)
# Removida: Zn > 0.56 -> Fe > 0.31 (0.0161) | Mantida: Fe > 0.31 -> Zn > 0.56 (0.0165)
# Removida: Fe > -1.18 -> Ca <= 0.46 (0.0129) | Mantida: Ca <= 0.46 -> Fe > -1.18 (0.0426)
# Removida: Fe > 0.31 -> Fe > -1.18 (0.0098) | Mantida: Fe > -1.18 -> Fe > 0.31 (0.0142)
# Removida: Ca <= 0.46 -> Ag ka <= -7.06 (0.0214) | Mantida: Ag ka <= -7.06 -> Ca <= 0.46 (0.0667)
# Removida: Ca <= 0.46 -> Zn > -1.47 (0.0181) | Mantida: Zn > -1.47 -> Ca <= 0.46 (0.0294)
# Removida: Zn > -1.47 -> Ca <= 1.81 (0.0143) | Mantida: Ca <= 1.81 -> Zn > -1.47 (0.0409)
# Removida: Fe > -0.36 -> Ca <= 1.81 (0.0184) | Mantida: Ca <= 1.81 -> Fe > -0.36 (0.0347)
# Removida: Fe > 0.31 -> Zn > -1.47 (0.0116) | Mantida: Zn > -1.47 -> Fe > 0.31 (0.0300)
# Removida: Fe > 0.31 -> Ag ka <= -7.06 (0.0105) | Mantida: Ag ka <= -7.06 -> Fe > 0.31 (0.0656)
# Removida: Zn > -0.39 -> Ag Lb > 6.48 (0.0230) | Mantida: Ag Lb > 6.48 -> Zn > -0.39 (0.0447)
# Removida: Cu <= 1.92 -> Zn > -0.39 (0.0038) | Mantida: Zn > -0.39 -> Cu <= 1.92 (0.0169)
# Removida: Cu > -1.74 -> Zn > -0.39 (0.0048) | Mantida: Zn > -0.39 -> Cu > -1.74 (0.0075)
# Removida: background > -1.23 -> background <= 1.29 (0.0009) | Mantida: background <= 1.29 -> background > -1.23 (0.0034)
# Removida: background <= 1.29 -> Fe <= 0.31 (0.0008) | Mantida: Fe <= 0.31 -> background <= 1.29 (0.0030)
# Removida: background > -1.23 -> Cu <= 0.32 (0.0013) | Mantida: Cu <= 0.32 -> background > -1.23 (0.0050)
# Removida: Fe <= 1.20 -> Cu <= 0.32 (0.0023) | Mantida: Cu <= 0.32 -> Fe <= 1.20 (0.0059)
# Removida: Cu <= 0.32 -> Cu <= -0.64 (0.0014) | Mantida: Cu <= -0.64 -> Cu <= 0.32 (0.0014)
# Removida: background <= 0.40 -> Fe <= 1.20 (0.0006) | Mantida: Fe <= 1.20 -> background <= 0.40 (0.0070)
# Removida: background <= 0.40 -> background > -0.46 (0.0006) | Mantida: background > -0.46 -> background <= 0.40 (0.0006)
# Removida: Cu > -0.64 -> Cu > -1.74 (0.0029) | Mantida: Cu > -1.74 -> Cu > -0.64 (0.0080)
# Removida: Cu <= 1.92 -> Zn <= 0.56 (0.0024) | Mantida: Zn <= 0.56 -> Cu <= 1.92 (0.0119)
# Removida: Fe <= -0.36 -> Zn <= -0.39 (0.0030) | Mantida: Zn <= -0.39 -> Fe <= -0.36 (0.0036)
# Removida: Cu <= -0.64 -> Zn <= -0.39 (0.0028) | Mantida: Zn <= -0.39 -> Cu <= -0.64 (0.0034)
# Removida: Cu <= -0.64 -> Fe <= 0.31 (0.0016) | Mantida: Fe <= 0.31 -> Cu <= -0.64 (0.0042)
# Removida: background > 0.40 -> background > -0.46 (0.0007) | Mantida: background > -0.46 -> background > 0.40 (0.0019)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 407 | Removidas: 66
# Nós predicados: 60
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 67
# Removida: Ag ka > 5.37 -> Ag ka <= 5.37 (0.8098) | Mantida: Ag ka <= 5.37 -> Ag ka > 5.37 (1.2787)
# Removida: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= -1.54 (0.2006) | Mantida: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 4.15 (1.0882)
# Removida: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= -1.54 (0.2166) | Mantida: Bremsstrahlung <= -1.54 -> Bremsstrahlung <= 9.64 (0.4138)
# Removida: Bremsstrahlung <= -1.54 -> Ag ka <= 5.37 (0.3824) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung <= -1.54 (1.3377)
# Removida: Bremsstrahlung <= 9.64 -> Bremsstrahlung <= 4.15 (0.1931) | Mantida: Bremsstrahlung <= 4.15 -> Bremsstrahlung <= 9.64 (0.6777)
# Removida: Bremsstrahlung <= 4.15 -> Ag ka <= 5.37 (0.1820) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung <= 4.15 (0.9032)
# Removida: Bremsstrahlung > -1.54 -> Bremsstrahlung <= 4.15 (0.1819) | Mantida: Bremsstrahlung <= 4.15 -> Bremsstrahlung > -1.54 (0.1951)
# Removida: Bremsstrahlung <= 9.64 -> Ag ka <= 5.37 (0.2022) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung <= 9.64 (0.4025)
# Removida: Bremsstrahlung <= 9.64 -> Bremsstrahlung > 4.15 (0.1032) | Mantida: Bremsstrahlung > 4.15 -> Bremsstrahlung <= 9.64 (0.1650)
# Removida: Bremsstrahlung > -9.06 -> Ag ka <= 5.37 (0.6064) | Mantida: Ag ka <= 5.37 -> Bremsstrahlung > -9.06 (0.9291)
# Removida: Bremsstrahlung > 4.15 -> Ag compton <= 6.52 (0.0907) | Mantida: Ag compton <= 6.52 -> Bremsstrahlung > 4.15 (0.4607)
# Removida: Bremsstrahlung > -1.54 -> Bremsstrahlung > -9.06 (0.1608) | Mantida: Bremsstrahlung > -9.06 -> Bremsstrahlung > -1.54 (0.4818)
# Removida: Ag compton <= -1.09 -> Bremsstrahlung > -9.06 (0.1418) | Mantida: Bremsstrahlung > -9.06 -> Ag compton <= -1.09 (0.2477)
# Removida: Bremsstrahlung > -1.54 -> Bremsstrahlung > 4.15 (0.1076) | Mantida: Bremsstrahlung > 4.15 -> Bremsstrahlung > -1.54 (0.2763)
# Removida: Bremsstrahlung > -1.54 -> Ag Lb > -15.87 (0.1257) | Mantida: Ag Lb > -15.87 -> Bremsstrahlung > -1.54 (0.1808)
# Removida: Bremsstrahlung > 4.15 -> Ag compton <= -1.09 (0.1019) | Mantida: Ag compton <= -1.09 -> Bremsstrahlung > 4.15 (0.2227)
# Removida: Bremsstrahlung > 4.15 -> Ag ka <= 20.95 (0.1236) | Mantida: Ag ka <= 20.95 -> Bremsstrahlung > 4.15 (0.2183)
# Removida: Ag compton <= -1.09 -> Ag compton > -6.71 (0.1619) | Mantida: Ag compton > -6.71 -> Ag compton <= -1.09 (0.1622)
# Removida: Ag compton <= -1.09 -> Ag compton <= 2.96 (0.1868) | Mantida: Ag compton <= 2.96 -> Ag compton <= -1.09 (0.4919)
# Removida: Ag compton <= -1.09 -> Ag Lb > 2.36 (0.1132) | Mantida: Ag Lb > 2.36 -> Ag compton <= -1.09 (0.1986)
# Removida: Ag Lb > 2.36 -> Ag compton > -6.71 (0.1465) | Mantida: Ag compton > -6.71 -> Ag Lb > 2.36 (0.5276)
# Removida: Ag compton > -6.71 -> Ag compton > -1.09 (0.0875) | Mantida: Ag compton > -1.09 -> Ag compton > -6.71 (0.1201)
# Removida: Ag compton > -6.71 -> Ag compton <= 2.96 (0.1163) | Mantida: Ag compton <= 2.96 -> Ag compton > -6.71 (0.1273)
# Removida: Ag compton > -1.09 -> Ag Lb > 2.36 (0.1517) | Mantida: Ag Lb > 2.36 -> Ag compton > -1.09 (0.4301)
# Removida: Ag Lb > 2.36 -> Ag ka <= 20.95 (0.1744) | Mantida: Ag ka <= 20.95 -> Ag Lb > 2.36 (0.3102)
# Removida: Ag ka <= 20.95 -> Ag compton > -1.09 (0.1066) | Mantida: Ag compton > -1.09 -> Ag ka <= 20.95 (0.1298)
# Removida: Ag compton <= 2.96 -> Ag ka <= 20.95 (0.3012) | Mantida: Ag ka <= 20.95 -> Ag compton <= 2.96 (0.4570)
# Removida: Ag La > 2.70 -> Ag ka <= 20.95 (0.1564) | Mantida: Ag ka <= 20.95 -> Ag La > 2.70 (0.2054)
# Removida: Ca > -0.68 -> Ag ka <= 20.95 (0.0229) | Mantida: Ag ka <= 20.95 -> Ca > -0.68 (0.0944)
# Removida: Ag La > 2.70 -> Ag compton <= 2.96 (0.2090) | Mantida: Ag compton <= 2.96 -> Ag La > 2.70 (0.2708)
# Removida: Cu <= -0.64 -> Ag ka > -11.59 (0.0014) | Mantida: Ag ka > -11.59 -> Cu <= -0.64 (0.0092)
# Removida: Zn > 0.56 -> Ag ka > -11.59 (0.0143) | Mantida: Ag ka > -11.59 -> Zn > 0.56 (0.0660)
# Removida: Cu > 0.32 -> Ag ka > -7.06 (0.0165) | Mantida: Ag ka > -7.06 -> Cu > 0.32 (0.0957)
# Removida: Cu > 0.32 -> Ca > -0.68 (0.0202) | Mantida: Ca > -0.68 -> Cu > 0.32 (0.0260)
# Removida: Cu > 0.32 -> Zn > 0.56 (0.0077) | Mantida: Zn > 0.56 -> Cu > 0.32 (0.0144)
# Removida: Fe > -0.36 -> Ca > -0.68 (0.0090) | Mantida: Ca > -0.68 -> Fe > -0.36 (0.0391)
# Removida: Ca > -0.68 -> Ca <= 0.46 (0.0216) | Mantida: Ca <= 0.46 -> Ca > -0.68 (0.0356)
# Removida: Fe > -1.18 -> Ag Lb > -15.87 (0.0118) | Mantida: Ag Lb > -15.87 -> Fe > -1.18 (0.0623)
# Removida: Ca <= 1.81 -> Ag Lb > -15.87 (0.0198) | Mantida: Ag Lb > -15.87 -> Ca <= 1.81 (0.0783)
# Removida: Ca > 0.46 -> Ca > -1.79 (0.0234) | Mantida: Ca > -1.79 -> Ca > 0.46 (0.0495)
# Removida: Zn > 0.56 -> Ca > -1.79 (0.0178) | Mantida: Ca > -1.79 -> Zn > 0.56 (0.0203)
# Removida: Fe > 0.31 -> Ca > -1.79 (0.0125) | Mantida: Ca > -1.79 -> Fe > 0.31 (0.0424)
# Removida: Fe > -1.18 -> Ca > -1.79 (0.0126) | Mantida: Ca > -1.79 -> Fe > -1.18 (0.0232)
# Removida: Zn > 0.56 -> Ag ka <= -7.06 (0.0180) | Mantida: Ag ka <= -7.06 -> Zn > 0.56 (0.0653)
# Removida: Ca <= 0.46 -> Zn > 0.56 (0.0178) | Mantida: Zn > 0.56 -> Ca <= 0.46 (0.0279)
# Removida: background <= 1.29 -> Zn > -1.47 (0.0016) | Mantida: Zn > -1.47 -> background <= 1.29 (0.0161)
# Removida: Fe > -1.18 -> Fe > 0.31 (0.0238) | Mantida: Fe > 0.31 -> Fe > -1.18 (0.0358)
# Removida: Fe > -0.36 -> Ca <= 1.81 (0.0073) | Mantida: Ca <= 1.81 -> Fe > -0.36 (0.0334)
# Removida: background > -1.23 -> Ca <= 1.81 (0.0021) | Mantida: Ca <= 1.81 -> background > -1.23 (0.0137)
# Removida: background > -1.23 -> Ag La > 7.76 (0.0020) | Mantida: Ag La > 7.76 -> background > -1.23 (0.1291)
# Removida: background <= 1.29 -> Cu <= 0.32 (0.0016) | Mantida: Cu <= 0.32 -> background <= 1.29 (0.0042)
# Removida: background <= 1.29 -> Zn > -0.39 (0.0013) | Mantida: Zn > -0.39 -> background <= 1.29 (0.0078)
# Removida: background > -0.46 -> Cu > -0.64 (0.0032) | Mantida: Cu > -0.64 -> background > -0.46 (0.0036)
# Removida: background > -0.46 -> Cu <= 0.32 (0.0016) | Mantida: Cu <= 0.32 -> background > -0.46 (0.0042)
# Removida: background <= 0.40 -> Cu > -0.64 (0.0007) | Mantida: Cu > -0.64 -> background <= 0.40 (0.0019)
# Removida: Cu <= 1.92 -> Cu > -0.64 (0.0038) | Mantida: Cu > -0.64 -> Cu <= 1.92 (0.0064)
# Removida: background > 0.40 -> Cu <= -0.64 (0.0011) | Mantida: Cu <= -0.64 -> background > 0.40 (0.0026)
# Removida: Cu > -1.74 -> Zn <= 1.56 (0.0054) | Mantida: Zn <= 1.56 -> Cu > -1.74 (0.0066)
# Removida: Cu <= 0.32 -> Cu > -1.74 (0.0039) | Mantida: Cu > -1.74 -> Cu <= 0.32 (0.0048)
# Removida: background <= 0.40 -> Cu > -1.74 (0.0006) | Mantida: Cu > -1.74 -> background <= 0.40 (0.0030)
# Removida: background <= 0.40 -> Zn > -0.39 (0.0009) | Mantida: Zn > -0.39 -> background <= 0.40 (0.0034)
# Removida: background <= 0.40 -> Zn <= -0.39 (0.0016) | Mantida: Zn <= -0.39 -> background <= 0.40 (0.0043)
# Removida: Fe <= 1.20 -> Zn <= 0.56 (0.0033) | Mantida: Zn <= 0.56 -> Fe <= 1.20 (0.0067)
# Removida: Fe <= 0.31 -> Fe <= 1.20 (0.0033) | Mantida: Fe <= 1.20 -> Fe <= 0.31 (0.0041)
# Removida: background <= -0.46 -> Fe <= 1.20 (0.0009) | Mantida: Fe <= 1.20 -> background <= -0.46 (0.0032)
# Removida: background <= -0.46 -> Cu <= -0.64 (0.0006) | Mantida: Cu <= -0.64 -> background <= -0.46 (0.0032)
# Removida: Fe <= -0.36 -> Ag La > 7.76 (0.0018) | Mantida: Ag La > 7.76 -> Fe <= -0.36 (0.0260)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 397 | Removidas: 67
# Nós predicados: 60
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#    Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0         Ag La <= 2.70        Ag La <= 2.70        Ag La <= 2.70
# 1         Ag La <= 7.76        Ag La <= 7.76        Ag La <= 7.76
# 2         Ag Lb <= 2.36        Ag Lb <= 2.36        Ag Lb <= 2.36
# 3         Ag Lb <= 6.48        Ag Lb <= 6.48        Ag Lb <= 6.48
# 4         Ag La <= 9.01        Ag La <= 9.01        Ag La <= 9.01
# ..                  ...                  ...                  ...
# 57          Cu <= -0.64           Fe <= 0.31    background > 0.40
# 58   background > -0.46         Ag La > 7.76   background <= 1.29
# 59          Fe <= -0.36    background > 0.40          Fe <= -0.36
# 60              Class_A              Class_A              Class_A
# 61              Class_B              Class_B              Class_B
#
#    Predicate_Cov_Seed_3
# 0         Ag La <= 2.70
# 1         Ag La <= 7.76
# 2         Ag Lb <= 2.36
# 3         Ag Lb <= 6.48
# 4         Ag La <= 9.01
# ..                  ...
# 57           Cu > -0.64
# 58   background <= 0.40
# 59  background <= -0.46
# 60              Class_A
# 61              Class_B
#
# [62 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 2.70                  28.218676           Ag La
# 1            Ag Lb <= 2.36                  20.990665           Ag Lb
# 2            Ag ka <= 5.37                   0.817253           Ag ka
# 3   Bremsstrahlung <= 4.15                   0.720486  Bremsstrahlung
# 4       Ag compton <= 6.52                   0.605184      Ag compton
# 5                Cu > 0.32                   0.289875              Cu
# 6              Ca <= -0.68                   0.279436              Ca
# 7      background <= -0.46                   0.251596      background
# 8               Fe > -1.18                   0.239142              Fe
# 9                Zn > 0.56                   0.228150              Zn
# 10                 Class_A                   0.000000            None
#
#    Threshold Operator
# 0       2.70       <=
# 1       2.36       <=
# 2       5.37       <=
# 3       4.15       <=
# 4       6.52       <=
# 5       0.32        >
# 6      -0.68       <=
# 7      -0.46       <=
# 8      -1.18        >
# 9       0.56        >
# 10      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zona 'Ag La': VE = 91.39%, dim = 18 variáveis
# Zona 'Ag Lb': VE = 90.27%, dim = 15 variáveis
# Zona 'Ca': VE = 27.70%, dim = 19 variáveis
# Zona 'background': VE = 3.72%, dim = 87 variáveis
# Zona 'Fe': VE = 14.68%, dim = 23 variáveis
# Zona 'Cu': VE = 15.48%, dim = 66 variáveis
# Zona 'Zn': VE = 21.60%, dim = 29 variáveis
# Zona 'Bremsstrahlung': VE = 38.87%, dim = 429 variáveis
# Zona 'Ag compton': VE = 52.69%, dim = 62 variáveis
# Zona 'Ag ka': VE = 80.83%, dim = 45 variáveis
#                  Node  Local_Reaching_Centrality        Zone Threshold  \
# 0       Ag La <= 2.70                  28.218676       Ag La      2.70
# 1       Ag La <= 7.76                  24.327379       Ag La      7.76
# 2       Ag Lb <= 2.36                  20.990665       Ag Lb      2.36
# 3       Ag Lb <= 6.48                  16.657994       Ag Lb      6.48
# 4       Ag La <= 9.01                  10.865589       Ag La      9.01
# ..                ...                        ...         ...       ...
# 57         Cu > -0.64                   0.134470          Cu     -0.64
# 58  background > 0.40                   0.128819  background      0.40
# 59        Fe <= -0.36                   0.104788          Fe     -0.36
# 60            Class_A                   0.000000        None      None
# 61            Class_B                   0.000000        None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0        <=          34.935039                    86.0             0.021418
# 1        <=         105.814886                    78.0             0.002963
# 2        <=          30.578162                     0.0             0.008013
# 3        <=          75.496450                    98.0             0.013050
# 4        <=         126.903607                   239.0             0.004801
# ..      ...                ...                     ...                  ...
# 57        >          -1.435498                    17.0             0.000042
# 58        >           4.852293                   186.0             0.003287
# 59       <=           0.719116                     9.0             0.001198
# 60     None                NaN                     NaN                  NaN
# 61     None                NaN                     NaN                  NaN
#
#              Node_Natural
# 0      Ag La <= 34.935039
# 1     Ag La <= 105.814886
# 2      Ag Lb <= 30.578162
# 3      Ag Lb <= 75.496450
# 4     Ag La <= 126.903607
# ..                    ...
# 57         Cu > -1.435498
# 58  background > 4.852293
# 59         Fe <= 0.719116
# 60                   None
# 61                   None
#
# [62 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ag La':
#   - Dimensão: 18 variáveis espectrais
#   - Range de energias: 2.66 - 3.10
#   - Variância explicada pela PC1: 91.39%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=mlp_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graphv3_pca(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# ======================================================================
# PERTURBATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Tipo de tarefa (aim): classification
# Modo de perturbação: median
# Fonte das estatísticas: full
# Métrica: probability_shift
# Total de folds: 10
#
#
# [Bag_1] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=176)
#     Zona: 18 colunas
#     Importance: 0.046839
#   Predicado: Ag La <= 2.70 (n=81)
#     Zona: 18 colunas
#     Importance: 0.218193
#   Predicado: Ag La > 2.70 (n=133)
#     Zona: 18 colunas
#     Importance: 0.024039
#   Predicado: Ag La <= 7.76 (n=130)
#     Zona: 18 colunas
#     Importance: 0.141935
#   Predicado: Ag La > 7.76 (n=84)
#     Zona: 18 colunas
#     Importance: 0.028800
#   Predicado: Ag La <= 9.01 (n=171)
#     Zona: 18 colunas
#     Importance: 0.113973
#   Predicado: Ag Lb > -15.87 (n=173)
#     Zona: 15 colunas
#     Importance: 0.029933
#   Predicado: Ag Lb <= 2.36 (n=82)
#     Zona: 15 colunas
#     Importance: 0.165061
#   Predicado: Ag Lb > 2.36 (n=132)
#     Zona: 15 colunas
#     Importance: 0.018581
#   Predicado: Ag Lb <= 6.48 (n=129)
#     Zona: 15 colunas
#     Importance: 0.109012
#   Predicado: Ag Lb > 6.48 (n=85)
#     Zona: 15 colunas
#     Importance: 0.022649
#   Predicado: Ag Lb <= 8.04 (n=170)
#     Zona: 15 colunas
#     Importance: 0.087615
#   Predicado: Ca > -1.79 (n=172)
#     Zona: 19 colunas
#     Importance: 0.011000
#   Predicado: Ca <= -0.68 (n=85)
#     Zona: 19 colunas
#     Importance: 0.010511
#   Predicado: Ca > -0.68 (n=129)
#     Zona: 19 colunas
#     Importance: 0.011332
#   Predicado: Ca <= 0.46 (n=128)
#     Zona: 19 colunas
#     Importance: 0.010288
#   Predicado: Ca > 0.46 (n=86)
#     Zona: 19 colunas
#     Importance: 0.012075
#   Predicado: Ca <= 1.81 (n=175)
#     Zona: 19 colunas
#     Importance: 0.009915
#   Predicado: background > -1.23 (n=175)
#     Zona: 87 colunas
#     Importance: 0.030481
#   Predicado: background <= -0.46 (n=84)
#     Zona: 87 colunas
#     Importance: 0.026081
#   Predicado: background > -0.46 (n=130)
#     Zona: 87 colunas
#     Importance: 0.031033
#   Predicado: background <= 0.40 (n=127)
#     Zona: 87 colunas
#     Importance: 0.029050
#   Predicado: background > 0.40 (n=87)
#     Zona: 87 colunas
#     Importance: 0.029146
#   Predicado: background <= 1.29 (n=172)
#     Zona: 87 colunas
#     Importance: 0.031007
#   Predicado: Fe > -1.18 (n=173)
#     Zona: 23 colunas
#     Importance: 0.014033
#   Predicado: Fe <= -0.36 (n=81)
#     Zona: 23 colunas
#     Importance: 0.016958
#   Predicado: Fe > -0.36 (n=133)
#     Zona: 23 colunas
#     Importance: 0.013439
#   Predicado: Fe <= 0.31 (n=122)
#     Zona: 23 colunas
#     Importance: 0.014997
#   Predicado: Fe > 0.31 (n=92)
#     Zona: 23 colunas
#     Importance: 0.014471
#   Predicado: Fe <= 1.20 (n=167)
#     Zona: 23 colunas
#     Importance: 0.014273
#   Predicado: Cu > -1.74 (n=167)
#     Zona: 66 colunas
#     Importance: 0.020876
#   Predicado: Cu <= -0.64 (n=86)
#     Zona: 66 colunas
#     Importance: 0.019464
#   Predicado: Cu > -0.64 (n=128)
#     Zona: 66 colunas
#     Importance: 0.021251
#   Predicado: Cu <= 0.32 (n=125)
#     Zona: 66 colunas
#     Importance: 0.020693
#   Predicado: Cu > 0.32 (n=89)
#     Zona: 66 colunas
#     Importance: 0.020308
#   Predicado: Cu <= 1.92 (n=167)
#     Zona: 66 colunas
#     Importance: 0.020096
#   Predicado: Zn > -1.47 (n=174)
#     Zona: 29 colunas
#     Importance: 0.024488
#   Predicado: Zn <= -0.39 (n=82)
#     Zona: 29 colunas
#     Importance: 0.022914
#   Predicado: Zn > -0.39 (n=132)
#     Zona: 29 colunas
#     Importance: 0.024530
#   Predicado: Zn <= 0.56 (n=130)
#     Zona: 29 colunas
#     Importance: 0.024096
#   Predicado: Zn > 0.56 (n=84)
#     Zona: 29 colunas
#     Importance: 0.023625
#   Predicado: Zn <= 1.56 (n=171)
#     Zona: 29 colunas
#     Importance: 0.023177
#   Predicado: Bremsstrahlung > -9.06 (n=170)
#     Zona: 429 colunas
#     Importance: 0.119050
#   Predicado: Bremsstrahlung <= -1.54 (n=84)
#     Zona: 429 colunas
#     Importance: 0.183728
#   Predicado: Bremsstrahlung > -1.54 (n=130)
#     Zona: 429 colunas
#     Importance: 0.106085
#   Predicado: Bremsstrahlung <= 4.15 (n=127)
#     Zona: 429 colunas
#     Importance: 0.151607
#   Predicado: Bremsstrahlung > 4.15 (n=87)
#     Zona: 429 colunas
#     Importance: 0.114600
#   Predicado: Bremsstrahlung <= 9.64 (n=166)
#     Zona: 429 colunas
#     Importance: 0.145160
#   Predicado: Ag compton > -6.71 (n=174)
#     Zona: 62 colunas
#     Importance: 0.030704
#   Predicado: Ag compton <= -1.09 (n=83)
#     Zona: 62 colunas
#     Importance: 0.042341
#   Predicado: Ag compton > -1.09 (n=131)
#     Zona: 62 colunas
#     Importance: 0.027992
#   Predicado: Ag compton <= 2.96 (n=127)
#     Zona: 62 colunas
#     Importance: 0.036008
#   Predicado: Ag compton > 2.96 (n=87)
#     Zona: 62 colunas
#     Importance: 0.029979
#   Predicado: Ag compton <= 6.52 (n=168)
#     Zona: 62 colunas
#     Importance: 0.033194
#   Predicado: Ag ka > -11.59 (n=174)
#     Zona: 45 colunas
#     Importance: 0.075767
#   Predicado: Ag ka <= -7.06 (n=85)
#     Zona: 45 colunas
#     Importance: 0.100687
#   Predicado: Ag ka > -7.06 (n=129)
#     Zona: 45 colunas
#     Importance: 0.073546
#   Predicado: Ag ka <= 5.37 (n=126)
#     Zona: 45 colunas
#     Importance: 0.078232
#   Predicado: Ag ka > 5.37 (n=88)
#     Zona: 45 colunas
#     Importance: 0.093052
#   Predicado: Ag ka <= 20.95 (n=168)
#     Zona: 45 colunas
#     Importance: 0.079181
#
# [Bag_2] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=170)
#     Zona: 18 colunas
#     Importance: 0.046330
#   Predicado: Ag La <= 2.70 (n=87)
#     Zona: 18 colunas
#     Importance: 0.221048
#   Predicado: Ag La > 2.70 (n=127)
#     Zona: 18 colunas
#     Importance: 0.026358
#   Predicado: Ag La <= 7.76 (n=132)
#     Zona: 18 colunas
#     Importance: 0.151037
#   Predicado: Ag La > 7.76 (n=82)
#     Zona: 18 colunas
#     Importance: 0.032217
#   Predicado: Ag La <= 9.01 (n=175)
#     Zona: 18 colunas
#     Importance: 0.120291
#   Predicado: Ag Lb > -15.87 (n=171)
#     Zona: 15 colunas
#     Importance: 0.032481
#   Predicado: Ag Lb <= 2.36 (n=87)
#     Zona: 15 colunas
#     Importance: 0.170842
#   Predicado: Ag Lb > 2.36 (n=127)
#     Zona: 15 colunas
#     Importance: 0.020041
#   Predicado: Ag Lb <= 6.48 (n=131)
#     Zona: 15 colunas
#     Importance: 0.117504
#   Predicado: Ag Lb > 6.48 (n=83)
#     Zona: 15 colunas
#     Importance: 0.024283
#   Predicado: Ag Lb <= 8.04 (n=174)
#     Zona: 15 colunas
#     Importance: 0.093570
#   Predicado: Ca > -1.79 (n=165)
#     Zona: 19 colunas
#     Importance: 0.011358
#   Predicado: Ca <= -0.68 (n=83)
#     Zona: 19 colunas
#     Importance: 0.011964
#   Predicado: Ca > -0.68 (n=131)
#     Zona: 19 colunas
#     Importance: 0.011101
#   Predicado: Ca <= 0.46 (n=128)
#     Zona: 19 colunas
#     Importance: 0.010941
#   Predicado: Ca > 0.46 (n=86)
#     Zona: 19 colunas
#     Importance: 0.012172
#   Predicado: Ca <= 1.81 (n=173)
#     Zona: 19 colunas
#     Importance: 0.010590
#   Predicado: background > -1.23 (n=168)
#     Zona: 87 colunas
#     Importance: 0.033172
#   Predicado: background <= -0.46 (n=89)
#     Zona: 87 colunas
#     Importance: 0.028466
#   Predicado: background > -0.46 (n=125)
#     Zona: 87 colunas
#     Importance: 0.033287
#   Predicado: background <= 0.40 (n=126)
#     Zona: 87 colunas
#     Importance: 0.031088
#   Predicado: background > 0.40 (n=88)
#     Zona: 87 colunas
#     Importance: 0.031560
#   Predicado: background <= 1.29 (n=172)
#     Zona: 87 colunas
#     Importance: 0.032369
#   Predicado: Fe > -1.18 (n=169)
#     Zona: 23 colunas
#     Importance: 0.014512
#   Predicado: Fe <= -0.36 (n=87)
#     Zona: 23 colunas
#     Importance: 0.015879
#   Predicado: Fe > -0.36 (n=127)
#     Zona: 23 colunas
#     Importance: 0.014002
#   Predicado: Fe <= 0.31 (n=127)
#     Zona: 23 colunas
#     Importance: 0.014959
#   Predicado: Fe > 0.31 (n=87)
#     Zona: 23 colunas
#     Importance: 0.014482
#   Predicado: Fe <= 1.20 (n=169)
#     Zona: 23 colunas
#     Importance: 0.014392
#   Predicado: Cu > -1.74 (n=166)
#     Zona: 66 colunas
#     Importance: 0.022331
#   Predicado: Cu <= -0.64 (n=90)
#     Zona: 66 colunas
#     Importance: 0.019981
#   Predicado: Cu > -0.64 (n=124)
#     Zona: 66 colunas
#     Importance: 0.022990
#   Predicado: Cu <= 0.32 (n=129)
#     Zona: 66 colunas
#     Importance: 0.022239
#   Predicado: Cu > 0.32 (n=85)
#     Zona: 66 colunas
#     Importance: 0.020944
#   Predicado: Cu <= 1.92 (n=170)
#     Zona: 66 colunas
#     Importance: 0.021397
#   Predicado: Zn > -1.47 (n=169)
#     Zona: 29 colunas
#     Importance: 0.024394
#   Predicado: Zn <= -0.39 (n=86)
#     Zona: 29 colunas
#     Importance: 0.022296
#   Predicado: Zn > -0.39 (n=128)
#     Zona: 29 colunas
#     Importance: 0.024821
#   Predicado: Zn <= 0.56 (n=132)
#     Zona: 29 colunas
#     Importance: 0.024759
#   Predicado: Zn > 0.56 (n=82)
#     Zona: 29 colunas
#     Importance: 0.022272
#   Predicado: Zn <= 1.56 (n=169)
#     Zona: 29 colunas
#     Importance: 0.024612
#   Predicado: Bremsstrahlung > -9.06 (n=173)
#     Zona: 429 colunas
#     Importance: 0.115294
#   Predicado: Bremsstrahlung <= -1.54 (n=87)
#     Zona: 429 colunas
#     Importance: 0.178263
#   Predicado: Bremsstrahlung > -1.54 (n=127)
#     Zona: 429 colunas
#     Importance: 0.102325
#   Predicado: Bremsstrahlung <= 4.15 (n=134)
#     Zona: 429 colunas
#     Importance: 0.150649
#   Predicado: Bremsstrahlung > 4.15 (n=80)
#     Zona: 429 colunas
#     Importance: 0.103964
#   Predicado: Bremsstrahlung <= 9.64 (n=170)
#     Zona: 429 colunas
#     Importance: 0.140745
#   Predicado: Ag compton > -6.71 (n=171)
#     Zona: 62 colunas
#     Importance: 0.029476
#   Predicado: Ag compton <= -1.09 (n=84)
#     Zona: 62 colunas
#     Importance: 0.041046
#   Predicado: Ag compton > -1.09 (n=130)
#     Zona: 62 colunas
#     Importance: 0.027430
#   Predicado: Ag compton <= 2.96 (n=130)
#     Zona: 62 colunas
#     Importance: 0.034715
#   Predicado: Ag compton > 2.96 (n=84)
#     Zona: 62 colunas
#     Importance: 0.029771
#   Predicado: Ag compton <= 6.52 (n=173)
#     Zona: 62 colunas
#     Importance: 0.032551
#   Predicado: Ag ka > -11.59 (n=169)
#     Zona: 45 colunas
#     Importance: 0.080847
#   Predicado: Ag ka <= -7.06 (n=84)
#     Zona: 45 colunas
#     Importance: 0.108678
#   Predicado: Ag ka > -7.06 (n=130)
#     Zona: 45 colunas
#     Importance: 0.080051
#   Predicado: Ag ka <= 5.37 (n=125)
#     Zona: 45 colunas
#     Importance: 0.086260
#   Predicado: Ag ka > 5.37 (n=89)
#     Zona: 45 colunas
#     Importance: 0.098349
#   Predicado: Ag ka <= 20.95 (n=166)
#     Zona: 45 colunas
#     Importance: 0.084013
#
# [Bag_3] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=174)
#     Zona: 18 colunas
#     Importance: 0.046753
#   Predicado: Ag La <= 2.70 (n=84)
#     Zona: 18 colunas
#     Importance: 0.196643
#   Predicado: Ag La > 2.70 (n=130)
#     Zona: 18 colunas
#     Importance: 0.025531
#   Predicado: Ag La <= 7.76 (n=128)
#     Zona: 18 colunas
#     Importance: 0.134628
#   Predicado: Ag La > 7.76 (n=86)
#     Zona: 18 colunas
#     Importance: 0.030286
#   Predicado: Ag La <= 9.01 (n=169)
#     Zona: 18 colunas
#     Importance: 0.108224
#   Predicado: Ag Lb > -15.87 (n=173)
#     Zona: 15 colunas
#     Importance: 0.031244
#   Predicado: Ag Lb <= 2.36 (n=84)
#     Zona: 15 colunas
#     Importance: 0.147580
#   Predicado: Ag Lb > 2.36 (n=130)
#     Zona: 15 colunas
#     Importance: 0.020380
#   Predicado: Ag Lb <= 6.48 (n=127)
#     Zona: 15 colunas
#     Importance: 0.101919
#   Predicado: Ag Lb > 6.48 (n=87)
#     Zona: 15 colunas
#     Importance: 0.024165
#   Predicado: Ag Lb <= 8.04 (n=169)
#     Zona: 15 colunas
#     Importance: 0.081280
#   Predicado: Ca > -1.79 (n=171)
#     Zona: 19 colunas
#     Importance: 0.010625
#   Predicado: Ca <= -0.68 (n=79)
#     Zona: 19 colunas
#     Importance: 0.012518
#   Predicado: Ca > -0.68 (n=135)
#     Zona: 19 colunas
#     Importance: 0.010126
#   Predicado: Ca <= 0.46 (n=126)
#     Zona: 19 colunas
#     Importance: 0.010748
#   Predicado: Ca > 0.46 (n=88)
#     Zona: 19 colunas
#     Importance: 0.011382
#   Predicado: Ca <= 1.81 (n=170)
#     Zona: 19 colunas
#     Importance: 0.010282
#   Predicado: background > -1.23 (n=169)
#     Zona: 87 colunas
#     Importance: 0.030963
#   Predicado: background <= -0.46 (n=89)
#     Zona: 87 colunas
#     Importance: 0.026022
#   Predicado: background > -0.46 (n=125)
#     Zona: 87 colunas
#     Importance: 0.030645
#   Predicado: background <= 0.40 (n=133)
#     Zona: 87 colunas
#     Importance: 0.028431
#   Predicado: background > 0.40 (n=81)
#     Zona: 87 colunas
#     Importance: 0.029201
#   Predicado: background <= 1.29 (n=174)
#     Zona: 87 colunas
#     Importance: 0.030022
#   Predicado: Fe > -1.18 (n=174)
#     Zona: 23 colunas
#     Importance: 0.013542
#   Predicado: Fe <= -0.36 (n=76)
#     Zona: 23 colunas
#     Importance: 0.014076
#   Predicado: Fe > -0.36 (n=138)
#     Zona: 23 colunas
#     Importance: 0.013513
#   Predicado: Fe <= 0.31 (n=124)
#     Zona: 23 colunas
#     Importance: 0.012905
#   Predicado: Fe > 0.31 (n=90)
#     Zona: 23 colunas
#     Importance: 0.014826
#   Predicado: Fe <= 1.20 (n=170)
#     Zona: 23 colunas
#     Importance: 0.012702
#   Predicado: Cu > -1.74 (n=173)
#     Zona: 66 colunas
#     Importance: 0.023567
#   Predicado: Cu <= -0.64 (n=84)
#     Zona: 66 colunas
#     Importance: 0.022375
#   Predicado: Cu > -0.64 (n=130)
#     Zona: 66 colunas
#     Importance: 0.023882
#   Predicado: Cu <= 0.32 (n=125)
#     Zona: 66 colunas
#     Importance: 0.023418
#   Predicado: Cu > 0.32 (n=89)
#     Zona: 66 colunas
#     Importance: 0.023111
#   Predicado: Cu <= 1.92 (n=171)
#     Zona: 66 colunas
#     Importance: 0.022113
#   Predicado: Zn > -1.47 (n=170)
#     Zona: 29 colunas
#     Importance: 0.023587
#   Predicado: Zn <= -0.39 (n=89)
#     Zona: 29 colunas
#     Importance: 0.021808
#   Predicado: Zn > -0.39 (n=125)
#     Zona: 29 colunas
#     Importance: 0.024466
#   Predicado: Zn <= 0.56 (n=130)
#     Zona: 29 colunas
#     Importance: 0.023842
#   Predicado: Zn > 0.56 (n=84)
#     Zona: 29 colunas
#     Importance: 0.022614
#   Predicado: Zn <= 1.56 (n=173)
#     Zona: 29 colunas
#     Importance: 0.022944
#   Predicado: Bremsstrahlung > -9.06 (n=167)
#     Zona: 429 colunas
#     Importance: 0.123802
#   Predicado: Bremsstrahlung <= -1.54 (n=84)
#     Zona: 429 colunas
#     Importance: 0.184069
#   Predicado: Bremsstrahlung > -1.54 (n=130)
#     Zona: 429 colunas
#     Importance: 0.113473
#   Predicado: Bremsstrahlung <= 4.15 (n=129)
#     Zona: 429 colunas
#     Importance: 0.156525
#   Predicado: Bremsstrahlung > 4.15 (n=85)
#     Zona: 429 colunas
#     Importance: 0.117901
#   Predicado: Bremsstrahlung <= 9.64 (n=173)
#     Zona: 429 colunas
#     Importance: 0.149717
#   Predicado: Ag compton > -6.71 (n=170)
#     Zona: 62 colunas
#     Importance: 0.029698
#   Predicado: Ag compton <= -1.09 (n=89)
#     Zona: 62 colunas
#     Importance: 0.040559
#   Predicado: Ag compton > -1.09 (n=125)
#     Zona: 62 colunas
#     Importance: 0.027530
#   Predicado: Ag compton <= 2.96 (n=132)
#     Zona: 62 colunas
#     Importance: 0.034028
#   Predicado: Ag compton > 2.96 (n=82)
#     Zona: 62 colunas
#     Importance: 0.031211
#   Predicado: Ag compton <= 6.52 (n=172)
#     Zona: 62 colunas
#     Importance: 0.032415
#   Predicado: Ag ka > -11.59 (n=168)
#     Zona: 45 colunas
#     Importance: 0.079556
#   Predicado: Ag ka <= -7.06 (n=91)
#     Zona: 45 colunas
#     Importance: 0.099685
#   Predicado: Ag ka > -7.06 (n=123)
#     Zona: 45 colunas
#     Importance: 0.079991
#   Predicado: Ag ka <= 5.37 (n=131)
#     Zona: 45 colunas
#     Importance: 0.079850
#   Predicado: Ag ka > 5.37 (n=83)
#     Zona: 45 colunas
#     Importance: 0.101805
#   Predicado: Ag ka <= 20.95 (n=173)
#     Zona: 45 colunas
#     Importance: 0.079768
#
# [Bag_4] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=172)
#     Zona: 18 colunas
#     Importance: 0.047118
#   Predicado: Ag La <= 2.70 (n=86)
#     Zona: 18 colunas
#     Importance: 0.213250
#   Predicado: Ag La > 2.70 (n=128)
#     Zona: 18 colunas
#     Importance: 0.026544
#   Predicado: Ag La <= 7.76 (n=128)
#     Zona: 18 colunas
#     Importance: 0.148749
#   Predicado: Ag La > 7.76 (n=86)
#     Zona: 18 colunas
#     Importance: 0.031364
#   Predicado: Ag La <= 9.01 (n=172)
#     Zona: 18 colunas
#     Importance: 0.117031
#   Predicado: Ag Lb > -15.87 (n=168)
#     Zona: 15 colunas
#     Importance: 0.031364
#   Predicado: Ag Lb <= 2.36 (n=88)
#     Zona: 15 colunas
#     Importance: 0.159713
#   Predicado: Ag Lb > 2.36 (n=126)
#     Zona: 15 colunas
#     Importance: 0.022378
#   Predicado: Ag Lb <= 6.48 (n=128)
#     Zona: 15 colunas
#     Importance: 0.113859
#   Predicado: Ag Lb > 6.48 (n=86)
#     Zona: 15 colunas
#     Importance: 0.026748
#   Predicado: Ag Lb <= 8.04 (n=167)
#     Zona: 15 colunas
#     Importance: 0.092617
#   Predicado: Ca > -1.79 (n=165)
#     Zona: 19 colunas
#     Importance: 0.010965
#   Predicado: Ca <= -0.68 (n=90)
#     Zona: 19 colunas
#     Importance: 0.010951
#   Predicado: Ca > -0.68 (n=124)
#     Zona: 19 colunas
#     Importance: 0.011222
#   Predicado: Ca <= 0.46 (n=129)
#     Zona: 19 colunas
#     Importance: 0.010509
#   Predicado: Ca > 0.46 (n=85)
#     Zona: 19 colunas
#     Importance: 0.012017
#   Predicado: Ca <= 1.81 (n=171)
#     Zona: 19 colunas
#     Importance: 0.010275
#   Predicado: background > -1.23 (n=170)
#     Zona: 87 colunas
#     Importance: 0.031317
#   Predicado: background <= -0.46 (n=85)
#     Zona: 87 colunas
#     Importance: 0.025256
#   Predicado: background > -0.46 (n=129)
#     Zona: 87 colunas
#     Importance: 0.032445
#   Predicado: background <= 0.40 (n=127)
#     Zona: 87 colunas
#     Importance: 0.029037
#   Predicado: background > 0.40 (n=87)
#     Zona: 87 colunas
#     Importance: 0.030397
#   Predicado: background <= 1.29 (n=171)
#     Zona: 87 colunas
#     Importance: 0.030077
#   Predicado: Fe > -1.18 (n=173)
#     Zona: 23 colunas
#     Importance: 0.013651
#   Predicado: Fe <= -0.36 (n=82)
#     Zona: 23 colunas
#     Importance: 0.015385
#   Predicado: Fe > -0.36 (n=132)
#     Zona: 23 colunas
#     Importance: 0.013628
#   Predicado: Fe <= 0.31 (n=128)
#     Zona: 23 colunas
#     Importance: 0.013771
#   Predicado: Fe > 0.31 (n=86)
#     Zona: 23 colunas
#     Importance: 0.015090
#   Predicado: Fe <= 1.20 (n=169)
#     Zona: 23 colunas
#     Importance: 0.013554
#   Predicado: Cu > -1.74 (n=169)
#     Zona: 66 colunas
#     Importance: 0.023691
#   Predicado: Cu <= -0.64 (n=89)
#     Zona: 66 colunas
#     Importance: 0.019959
#   Predicado: Cu > -0.64 (n=125)
#     Zona: 66 colunas
#     Importance: 0.025121
#   Predicado: Cu <= 0.32 (n=128)
#     Zona: 66 colunas
#     Importance: 0.022340
#   Predicado: Cu > 0.32 (n=86)
#     Zona: 66 colunas
#     Importance: 0.023917
#   Predicado: Cu <= 1.92 (n=170)
#     Zona: 66 colunas
#     Importance: 0.021708
#   Predicado: Zn > -1.47 (n=170)
#     Zona: 29 colunas
#     Importance: 0.024548
#   Predicado: Zn <= -0.39 (n=86)
#     Zona: 29 colunas
#     Importance: 0.024297
#   Predicado: Zn > -0.39 (n=128)
#     Zona: 29 colunas
#     Importance: 0.024072
#   Predicado: Zn <= 0.56 (n=132)
#     Zona: 29 colunas
#     Importance: 0.024254
#   Predicado: Zn > 0.56 (n=82)
#     Zona: 29 colunas
#     Importance: 0.024017
#   Predicado: Zn <= 1.56 (n=172)
#     Zona: 29 colunas
#     Importance: 0.023779
#   Predicado: Bremsstrahlung > -9.06 (n=173)
#     Zona: 429 colunas
#     Importance: 0.114572
#   Predicado: Bremsstrahlung <= -1.54 (n=84)
#     Zona: 429 colunas
#     Importance: 0.165699
#   Predicado: Bremsstrahlung > -1.54 (n=130)
#     Zona: 429 colunas
#     Importance: 0.104798
#   Predicado: Bremsstrahlung <= 4.15 (n=130)
#     Zona: 429 colunas
#     Importance: 0.138645
#   Predicado: Bremsstrahlung > 4.15 (n=84)
#     Zona: 429 colunas
#     Importance: 0.113317
#   Predicado: Bremsstrahlung <= 9.64 (n=174)
#     Zona: 429 colunas
#     Importance: 0.135124
#   Predicado: Ag compton > -6.71 (n=171)
#     Zona: 62 colunas
#     Importance: 0.029852
#   Predicado: Ag compton <= -1.09 (n=87)
#     Zona: 62 colunas
#     Importance: 0.040773
#   Predicado: Ag compton > -1.09 (n=127)
#     Zona: 62 colunas
#     Importance: 0.027278
#   Predicado: Ag compton <= 2.96 (n=127)
#     Zona: 62 colunas
#     Importance: 0.035382
#   Predicado: Ag compton > 2.96 (n=87)
#     Zona: 62 colunas
#     Importance: 0.028943
#   Predicado: Ag compton <= 6.52 (n=171)
#     Zona: 62 colunas
#     Importance: 0.032016
#   Predicado: Ag ka > -11.59 (n=173)
#     Zona: 45 colunas
#     Importance: 0.078094
#   Predicado: Ag ka <= -7.06 (n=86)
#     Zona: 45 colunas
#     Importance: 0.104356
#   Predicado: Ag ka > -7.06 (n=128)
#     Zona: 45 colunas
#     Importance: 0.076391
#   Predicado: Ag ka <= 5.37 (n=127)
#     Zona: 45 colunas
#     Importance: 0.083996
#   Predicado: Ag ka > 5.37 (n=87)
#     Zona: 45 colunas
#     Importance: 0.092933
#   Predicado: Ag ka <= 20.95 (n=172)
#     Zona: 45 colunas
#     Importance: 0.082732
#
# [Bag_5] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=170)
#     Zona: 18 colunas
#     Importance: 0.046032
#   Predicado: Ag La <= 2.70 (n=86)
#     Zona: 18 colunas
#     Importance: 0.215802
#   Predicado: Ag La > 2.70 (n=128)
#     Zona: 18 colunas
#     Importance: 0.026997
#   Predicado: Ag La <= 7.76 (n=129)
#     Zona: 18 colunas
#     Importance: 0.149137
#   Predicado: Ag La > 7.76 (n=85)
#     Zona: 18 colunas
#     Importance: 0.032658
#   Predicado: Ag La <= 9.01 (n=173)
#     Zona: 18 colunas
#     Importance: 0.117952
#   Predicado: Ag Lb > -15.87 (n=169)
#     Zona: 15 colunas
#     Importance: 0.032883
#   Predicado: Ag Lb <= 2.36 (n=87)
#     Zona: 15 colunas
#     Importance: 0.164468
#   Predicado: Ag Lb > 2.36 (n=127)
#     Zona: 15 colunas
#     Importance: 0.021054
#   Predicado: Ag Lb <= 6.48 (n=132)
#     Zona: 15 colunas
#     Importance: 0.112504
#   Predicado: Ag Lb > 6.48 (n=82)
#     Zona: 15 colunas
#     Importance: 0.026001
#   Predicado: Ag Lb <= 8.04 (n=174)
#     Zona: 15 colunas
#     Importance: 0.090732
#   Predicado: Ca > -1.79 (n=168)
#     Zona: 19 colunas
#     Importance: 0.011144
#   Predicado: Ca <= -0.68 (n=86)
#     Zona: 19 colunas
#     Importance: 0.011301
#   Predicado: Ca > -0.68 (n=128)
#     Zona: 19 colunas
#     Importance: 0.011285
#   Predicado: Ca <= 0.46 (n=126)
#     Zona: 19 colunas
#     Importance: 0.010842
#   Predicado: Ca > 0.46 (n=88)
#     Zona: 19 colunas
#     Importance: 0.011933
#   Predicado: Ca <= 1.81 (n=167)
#     Zona: 19 colunas
#     Importance: 0.010603
#   Predicado: background > -1.23 (n=171)
#     Zona: 87 colunas
#     Importance: 0.032635
#   Predicado: background <= -0.46 (n=87)
#     Zona: 87 colunas
#     Importance: 0.026978
#   Predicado: background > -0.46 (n=127)
#     Zona: 87 colunas
#     Importance: 0.034164
#   Predicado: background <= 0.40 (n=130)
#     Zona: 87 colunas
#     Importance: 0.030055
#   Predicado: background > 0.40 (n=84)
#     Zona: 87 colunas
#     Importance: 0.033081
#   Predicado: background <= 1.29 (n=175)
#     Zona: 87 colunas
#     Importance: 0.032690
#   Predicado: Fe > -1.18 (n=173)
#     Zona: 23 colunas
#     Importance: 0.014098
#   Predicado: Fe <= -0.36 (n=83)
#     Zona: 23 colunas
#     Importance: 0.016016
#   Predicado: Fe > -0.36 (n=131)
#     Zona: 23 colunas
#     Importance: 0.013558
#   Predicado: Fe <= 0.31 (n=127)
#     Zona: 23 colunas
#     Importance: 0.014347
#   Predicado: Fe > 0.31 (n=87)
#     Zona: 23 colunas
#     Importance: 0.014751
#   Predicado: Fe <= 1.20 (n=171)
#     Zona: 23 colunas
#     Importance: 0.013700
#   Predicado: Cu > -1.74 (n=172)
#     Zona: 66 colunas
#     Importance: 0.023631
#   Predicado: Cu <= -0.64 (n=87)
#     Zona: 66 colunas
#     Importance: 0.021514
#   Predicado: Cu > -0.64 (n=127)
#     Zona: 66 colunas
#     Importance: 0.024145
#   Predicado: Cu <= 0.32 (n=132)
#     Zona: 66 colunas
#     Importance: 0.022963
#   Predicado: Cu > 0.32 (n=82)
#     Zona: 66 colunas
#     Importance: 0.023257
#   Predicado: Cu <= 1.92 (n=173)
#     Zona: 66 colunas
#     Importance: 0.021870
#   Predicado: Zn > -1.47 (n=176)
#     Zona: 29 colunas
#     Importance: 0.025324
#   Predicado: Zn <= -0.39 (n=82)
#     Zona: 29 colunas
#     Importance: 0.024082
#   Predicado: Zn > -0.39 (n=132)
#     Zona: 29 colunas
#     Importance: 0.025038
#   Predicado: Zn <= 0.56 (n=127)
#     Zona: 29 colunas
#     Importance: 0.026114
#   Predicado: Zn > 0.56 (n=87)
#     Zona: 29 colunas
#     Importance: 0.022567
#   Predicado: Zn <= 1.56 (n=168)
#     Zona: 29 colunas
#     Importance: 0.025248
#   Predicado: Bremsstrahlung > -9.06 (n=169)
#     Zona: 429 colunas
#     Importance: 0.117739
#   Predicado: Bremsstrahlung <= -1.54 (n=87)
#     Zona: 429 colunas
#     Importance: 0.177807
#   Predicado: Bremsstrahlung > -1.54 (n=127)
#     Zona: 429 colunas
#     Importance: 0.103159
#   Predicado: Bremsstrahlung <= 4.15 (n=130)
#     Zona: 429 colunas
#     Importance: 0.148051
#   Predicado: Bremsstrahlung > 4.15 (n=84)
#     Zona: 429 colunas
#     Importance: 0.110996
#   Predicado: Bremsstrahlung <= 9.64 (n=170)
#     Zona: 429 colunas
#     Importance: 0.139878
#   Predicado: Ag compton > -6.71 (n=170)
#     Zona: 62 colunas
#     Importance: 0.030098
#   Predicado: Ag compton <= -1.09 (n=89)
#     Zona: 62 colunas
#     Importance: 0.039372
#   Predicado: Ag compton > -1.09 (n=125)
#     Zona: 62 colunas
#     Importance: 0.028593
#   Predicado: Ag compton <= 2.96 (n=129)
#     Zona: 62 colunas
#     Importance: 0.034894
#   Predicado: Ag compton > 2.96 (n=85)
#     Zona: 62 colunas
#     Importance: 0.030317
#   Predicado: Ag compton <= 6.52 (n=172)
#     Zona: 62 colunas
#     Importance: 0.032938
#   Predicado: Ag ka > -11.59 (n=171)
#     Zona: 45 colunas
#     Importance: 0.078900
#   Predicado: Ag ka <= -7.06 (n=87)
#     Zona: 45 colunas
#     Importance: 0.099647
#   Predicado: Ag ka > -7.06 (n=127)
#     Zona: 45 colunas
#     Importance: 0.079444
#   Predicado: Ag ka <= 5.37 (n=125)
#     Zona: 45 colunas
#     Importance: 0.079280
#   Predicado: Ag ka > 5.37 (n=89)
#     Zona: 45 colunas
#     Importance: 0.099423
#   Predicado: Ag ka <= 20.95 (n=167)
#     Zona: 45 colunas
#     Importance: 0.078800
#
# [Bag_6] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=170)
#     Zona: 18 colunas
#     Importance: 0.042995
#   Predicado: Ag La <= 2.70 (n=83)
#     Zona: 18 colunas
#     Importance: 0.217321
#   Predicado: Ag La > 2.70 (n=131)
#     Zona: 18 colunas
#     Importance: 0.025262
#   Predicado: Ag La <= 7.76 (n=125)
#     Zona: 18 colunas
#     Importance: 0.149951
#   Predicado: Ag La > 7.76 (n=89)
#     Zona: 18 colunas
#     Importance: 0.029249
#   Predicado: Ag La <= 9.01 (n=173)
#     Zona: 18 colunas
#     Importance: 0.115096
#   Predicado: Ag Lb > -15.87 (n=171)
#     Zona: 15 colunas
#     Importance: 0.032323
#   Predicado: Ag Lb <= 2.36 (n=83)
#     Zona: 15 colunas
#     Importance: 0.158409
#   Predicado: Ag Lb > 2.36 (n=131)
#     Zona: 15 colunas
#     Importance: 0.020193
#   Predicado: Ag Lb <= 6.48 (n=126)
#     Zona: 15 colunas
#     Importance: 0.108719
#   Predicado: Ag Lb > 6.48 (n=88)
#     Zona: 15 colunas
#     Importance: 0.023803
#   Predicado: Ag Lb <= 8.04 (n=170)
#     Zona: 15 colunas
#     Importance: 0.085345
#   Predicado: Ca > -1.79 (n=171)
#     Zona: 19 colunas
#     Importance: 0.010571
#   Predicado: Ca <= -0.68 (n=88)
#     Zona: 19 colunas
#     Importance: 0.011088
#   Predicado: Ca > -0.68 (n=126)
#     Zona: 19 colunas
#     Importance: 0.010339
#   Predicado: Ca <= 0.46 (n=131)
#     Zona: 19 colunas
#     Importance: 0.010213
#   Predicado: Ca > 0.46 (n=83)
#     Zona: 19 colunas
#     Importance: 0.011333
#   Predicado: Ca <= 1.81 (n=172)
#     Zona: 19 colunas
#     Importance: 0.009897
#   Predicado: background > -1.23 (n=167)
#     Zona: 87 colunas
#     Importance: 0.033137
#   Predicado: background <= -0.46 (n=92)
#     Zona: 87 colunas
#     Importance: 0.026824
#   Predicado: background > -0.46 (n=122)
#     Zona: 87 colunas
#     Importance: 0.034410
#   Predicado: background <= 0.40 (n=136)
#     Zona: 87 colunas
#     Importance: 0.030843
#   Predicado: background > 0.40 (n=78)
#     Zona: 87 colunas
#     Importance: 0.031682
#   Predicado: background <= 1.29 (n=178)
#     Zona: 87 colunas
#     Importance: 0.032106
#   Predicado: Fe > -1.18 (n=173)
#     Zona: 23 colunas
#     Importance: 0.014552
#   Predicado: Fe <= -0.36 (n=86)
#     Zona: 23 colunas
#     Importance: 0.017058
#   Predicado: Fe > -0.36 (n=128)
#     Zona: 23 colunas
#     Importance: 0.013798
#   Predicado: Fe <= 0.31 (n=128)
#     Zona: 23 colunas
#     Importance: 0.015269
#   Predicado: Fe > 0.31 (n=86)
#     Zona: 23 colunas
#     Importance: 0.014868
#   Predicado: Fe <= 1.20 (n=176)
#     Zona: 23 colunas
#     Importance: 0.014279
#   Predicado: Cu > -1.74 (n=175)
#     Zona: 66 colunas
#     Importance: 0.023909
#   Predicado: Cu <= -0.64 (n=82)
#     Zona: 66 colunas
#     Importance: 0.021252
#   Predicado: Cu > -0.64 (n=132)
#     Zona: 66 colunas
#     Importance: 0.023992
#   Predicado: Cu <= 0.32 (n=129)
#     Zona: 66 colunas
#     Importance: 0.022674
#   Predicado: Cu > 0.32 (n=85)
#     Zona: 66 colunas
#     Importance: 0.023349
#   Predicado: Cu <= 1.92 (n=170)
#     Zona: 66 colunas
#     Importance: 0.021888
#   Predicado: Zn > -1.47 (n=168)
#     Zona: 29 colunas
#     Importance: 0.024917
#   Predicado: Zn <= -0.39 (n=85)
#     Zona: 29 colunas
#     Importance: 0.022133
#   Predicado: Zn > -0.39 (n=129)
#     Zona: 29 colunas
#     Importance: 0.024834
#   Predicado: Zn <= 0.56 (n=131)
#     Zona: 29 colunas
#     Importance: 0.025211
#   Predicado: Zn > 0.56 (n=83)
#     Zona: 29 colunas
#     Importance: 0.021472
#   Predicado: Zn <= 1.56 (n=170)
#     Zona: 29 colunas
#     Importance: 0.023534
#   Predicado: Bremsstrahlung > -9.06 (n=168)
#     Zona: 429 colunas
#     Importance: 0.115277
#   Predicado: Bremsstrahlung <= -1.54 (n=91)
#     Zona: 429 colunas
#     Importance: 0.172829
#   Predicado: Bremsstrahlung > -1.54 (n=123)
#     Zona: 429 colunas
#     Importance: 0.104703
#   Predicado: Bremsstrahlung <= 4.15 (n=132)
#     Zona: 429 colunas
#     Importance: 0.150983
#   Predicado: Bremsstrahlung > 4.15 (n=82)
#     Zona: 429 colunas
#     Importance: 0.105807
#   Predicado: Bremsstrahlung <= 9.64 (n=177)
#     Zona: 429 colunas
#     Importance: 0.142952
#   Predicado: Ag compton > -6.71 (n=172)
#     Zona: 62 colunas
#     Importance: 0.029220
#   Predicado: Ag compton <= -1.09 (n=89)
#     Zona: 62 colunas
#     Importance: 0.036879
#   Predicado: Ag compton > -1.09 (n=125)
#     Zona: 62 colunas
#     Importance: 0.027793
#   Predicado: Ag compton <= 2.96 (n=137)
#     Zona: 62 colunas
#     Importance: 0.032268
#   Predicado: Ag compton > 2.96 (n=77)
#     Zona: 62 colunas
#     Importance: 0.030333
#   Predicado: Ag compton <= 6.52 (n=177)
#     Zona: 62 colunas
#     Importance: 0.031744
#   Predicado: Ag ka > -11.59 (n=174)
#     Zona: 45 colunas
#     Importance: 0.079914
#   Predicado: Ag ka <= -7.06 (n=83)
#     Zona: 45 colunas
#     Importance: 0.094953
#   Predicado: Ag ka > -7.06 (n=131)
#     Zona: 45 colunas
#     Importance: 0.080058
#   Predicado: Ag ka <= 5.37 (n=126)
#     Zona: 45 colunas
#     Importance: 0.075350
#   Predicado: Ag ka > 5.37 (n=88)
#     Zona: 45 colunas
#     Importance: 0.100848
#   Predicado: Ag ka <= 20.95 (n=171)
#     Zona: 45 colunas
#     Importance: 0.077691
#
# [Bag_7] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=170)
#     Zona: 18 colunas
#     Importance: 0.041503
#   Predicado: Ag La <= 2.70 (n=85)
#     Zona: 18 colunas
#     Importance: 0.214793
#   Predicado: Ag La > 2.70 (n=129)
#     Zona: 18 colunas
#     Importance: 0.024841
#   Predicado: Ag La <= 7.76 (n=130)
#     Zona: 18 colunas
#     Importance: 0.146664
#   Predicado: Ag La > 7.76 (n=84)
#     Zona: 18 colunas
#     Importance: 0.028519
#   Predicado: Ag La <= 9.01 (n=174)
#     Zona: 18 colunas
#     Importance: 0.116111
#   Predicado: Ag Lb > -15.87 (n=173)
#     Zona: 15 colunas
#     Importance: 0.033674
#   Predicado: Ag Lb <= 2.36 (n=86)
#     Zona: 15 colunas
#     Importance: 0.163500
#   Predicado: Ag Lb > 2.36 (n=128)
#     Zona: 15 colunas
#     Importance: 0.020228
#   Predicado: Ag Lb <= 6.48 (n=128)
#     Zona: 15 colunas
#     Importance: 0.113975
#   Predicado: Ag Lb > 6.48 (n=86)
#     Zona: 15 colunas
#     Importance: 0.023970
#   Predicado: Ag Lb <= 8.04 (n=170)
#     Zona: 15 colunas
#     Importance: 0.090565
#   Predicado: Ca > -1.79 (n=172)
#     Zona: 19 colunas
#     Importance: 0.011481
#   Predicado: Ca <= -0.68 (n=84)
#     Zona: 19 colunas
#     Importance: 0.011746
#   Predicado: Ca > -0.68 (n=130)
#     Zona: 19 colunas
#     Importance: 0.011460
#   Predicado: Ca <= 0.46 (n=126)
#     Zona: 19 colunas
#     Importance: 0.011103
#   Predicado: Ca > 0.46 (n=88)
#     Zona: 19 colunas
#     Importance: 0.012244
#   Predicado: Ca <= 1.81 (n=172)
#     Zona: 19 colunas
#     Importance: 0.010765
#   Predicado: background > -1.23 (n=174)
#     Zona: 87 colunas
#     Importance: 0.032845
#   Predicado: background <= -0.46 (n=81)
#     Zona: 87 colunas
#     Importance: 0.027971
#   Predicado: background > -0.46 (n=133)
#     Zona: 87 colunas
#     Importance: 0.032810
#   Predicado: background <= 0.40 (n=125)
#     Zona: 87 colunas
#     Importance: 0.030003
#   Predicado: background > 0.40 (n=89)
#     Zona: 87 colunas
#     Importance: 0.032349
#   Predicado: background <= 1.29 (n=170)
#     Zona: 87 colunas
#     Importance: 0.032559
#   Predicado: Fe > -1.18 (n=168)
#     Zona: 23 colunas
#     Importance: 0.014270
#   Predicado: Fe <= -0.36 (n=82)
#     Zona: 23 colunas
#     Importance: 0.016720
#   Predicado: Fe > -0.36 (n=132)
#     Zona: 23 colunas
#     Importance: 0.013888
#   Predicado: Fe <= 0.31 (n=126)
#     Zona: 23 colunas
#     Importance: 0.015156
#   Predicado: Fe > 0.31 (n=88)
#     Zona: 23 colunas
#     Importance: 0.014711
#   Predicado: Fe <= 1.20 (n=167)
#     Zona: 23 colunas
#     Importance: 0.014077
#   Predicado: Cu > -1.74 (n=175)
#     Zona: 66 colunas
#     Importance: 0.020799
#   Predicado: Cu <= -0.64 (n=90)
#     Zona: 66 colunas
#     Importance: 0.018712
#   Predicado: Cu > -0.64 (n=124)
#     Zona: 66 colunas
#     Importance: 0.021621
#   Predicado: Cu <= 0.32 (n=132)
#     Zona: 66 colunas
#     Importance: 0.020340
#   Predicado: Cu > 0.32 (n=82)
#     Zona: 66 colunas
#     Importance: 0.020489
#   Predicado: Cu <= 1.92 (n=172)
#     Zona: 66 colunas
#     Importance: 0.019217
#   Predicado: Zn > -1.47 (n=172)
#     Zona: 29 colunas
#     Importance: 0.024253
#   Predicado: Zn <= -0.39 (n=87)
#     Zona: 29 colunas
#     Importance: 0.022258
#   Predicado: Zn > -0.39 (n=127)
#     Zona: 29 colunas
#     Importance: 0.023898
#   Predicado: Zn <= 0.56 (n=127)
#     Zona: 29 colunas
#     Importance: 0.024113
#   Predicado: Zn > 0.56 (n=87)
#     Zona: 29 colunas
#     Importance: 0.021945
#   Predicado: Zn <= 1.56 (n=167)
#     Zona: 29 colunas
#     Importance: 0.022992
#   Predicado: Bremsstrahlung > -9.06 (n=172)
#     Zona: 429 colunas
#     Importance: 0.116542
#   Predicado: Bremsstrahlung <= -1.54 (n=81)
#     Zona: 429 colunas
#     Importance: 0.179433
#   Predicado: Bremsstrahlung > -1.54 (n=133)
#     Zona: 429 colunas
#     Importance: 0.105443
#   Predicado: Bremsstrahlung <= 4.15 (n=119)
#     Zona: 429 colunas
#     Importance: 0.156521
#   Predicado: Bremsstrahlung > 4.15 (n=95)
#     Zona: 429 colunas
#     Importance: 0.104548
#   Predicado: Bremsstrahlung <= 9.64 (n=165)
#     Zona: 429 colunas
#     Importance: 0.144278
#   Predicado: Ag compton > -6.71 (n=174)
#     Zona: 62 colunas
#     Importance: 0.029364
#   Predicado: Ag compton <= -1.09 (n=80)
#     Zona: 62 colunas
#     Importance: 0.040325
#   Predicado: Ag compton > -1.09 (n=134)
#     Zona: 62 colunas
#     Importance: 0.027852
#   Predicado: Ag compton <= 2.96 (n=121)
#     Zona: 62 colunas
#     Importance: 0.035285
#   Predicado: Ag compton > 2.96 (n=93)
#     Zona: 62 colunas
#     Importance: 0.028911
#   Predicado: Ag compton <= 6.52 (n=168)
#     Zona: 62 colunas
#     Importance: 0.033188
#   Predicado: Ag ka > -11.59 (n=171)
#     Zona: 45 colunas
#     Importance: 0.076056
#   Predicado: Ag ka <= -7.06 (n=89)
#     Zona: 45 colunas
#     Importance: 0.102626
#   Predicado: Ag ka > -7.06 (n=125)
#     Zona: 45 colunas
#     Importance: 0.075080
#   Predicado: Ag ka <= 5.37 (n=130)
#     Zona: 45 colunas
#     Importance: 0.082346
#   Predicado: Ag ka > 5.37 (n=84)
#     Zona: 45 colunas
#     Importance: 0.093020
#   Predicado: Ag ka <= 20.95 (n=174)
#     Zona: 45 colunas
#     Importance: 0.081153
#
# [Bag_8] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=168)
#     Zona: 18 colunas
#     Importance: 0.048606
#   Predicado: Ag La <= 2.70 (n=83)
#     Zona: 18 colunas
#     Importance: 0.230156
#   Predicado: Ag La > 2.70 (n=131)
#     Zona: 18 colunas
#     Importance: 0.025540
#   Predicado: Ag La <= 7.76 (n=125)
#     Zona: 18 colunas
#     Importance: 0.158426
#   Predicado: Ag La > 7.76 (n=89)
#     Zona: 18 colunas
#     Importance: 0.029724
#   Predicado: Ag La <= 9.01 (n=172)
#     Zona: 18 colunas
#     Importance: 0.122386
#   Predicado: Ag Lb > -15.87 (n=168)
#     Zona: 15 colunas
#     Importance: 0.033449
#   Predicado: Ag Lb <= 2.36 (n=83)
#     Zona: 15 colunas
#     Importance: 0.172310
#   Predicado: Ag Lb > 2.36 (n=131)
#     Zona: 15 colunas
#     Importance: 0.018768
#   Predicado: Ag Lb <= 6.48 (n=125)
#     Zona: 15 colunas
#     Importance: 0.118074
#   Predicado: Ag Lb > 6.48 (n=89)
#     Zona: 15 colunas
#     Importance: 0.022483
#   Predicado: Ag Lb <= 8.04 (n=170)
#     Zona: 15 colunas
#     Importance: 0.092017
#   Predicado: Ca > -1.79 (n=173)
#     Zona: 19 colunas
#     Importance: 0.011290
#   Predicado: Ca <= -0.68 (n=87)
#     Zona: 19 colunas
#     Importance: 0.010210
#   Predicado: Ca > -0.68 (n=127)
#     Zona: 19 colunas
#     Importance: 0.011546
#   Predicado: Ca <= 0.46 (n=121)
#     Zona: 19 colunas
#     Importance: 0.010173
#   Predicado: Ca > 0.46 (n=93)
#     Zona: 19 colunas
#     Importance: 0.012084
#   Predicado: Ca <= 1.81 (n=166)
#     Zona: 19 colunas
#     Importance: 0.009830
#   Predicado: background > -1.23 (n=167)
#     Zona: 87 colunas
#     Importance: 0.031533
#   Predicado: background <= -0.46 (n=94)
#     Zona: 87 colunas
#     Importance: 0.026634
#   Predicado: background > -0.46 (n=120)
#     Zona: 87 colunas
#     Importance: 0.031733
#   Predicado: background <= 0.40 (n=132)
#     Zona: 87 colunas
#     Importance: 0.028669
#   Predicado: background > 0.40 (n=82)
#     Zona: 87 colunas
#     Importance: 0.030820
#   Predicado: background <= 1.29 (n=171)
#     Zona: 87 colunas
#     Importance: 0.030196
#   Predicado: Fe > -1.18 (n=174)
#     Zona: 23 colunas
#     Importance: 0.013955
#   Predicado: Fe <= -0.36 (n=89)
#     Zona: 23 colunas
#     Importance: 0.015484
#   Predicado: Fe > -0.36 (n=125)
#     Zona: 23 colunas
#     Importance: 0.013400
#   Predicado: Fe <= 0.31 (n=136)
#     Zona: 23 colunas
#     Importance: 0.013635
#   Predicado: Fe > 0.31 (n=78)
#     Zona: 23 colunas
#     Importance: 0.015367
#   Predicado: Fe <= 1.20 (n=174)
#     Zona: 23 colunas
#     Importance: 0.013069
#   Predicado: Cu > -1.74 (n=170)
#     Zona: 66 colunas
#     Importance: 0.021232
#   Predicado: Cu <= -0.64 (n=89)
#     Zona: 66 colunas
#     Importance: 0.019955
#   Predicado: Cu > -0.64 (n=125)
#     Zona: 66 colunas
#     Importance: 0.021567
#   Predicado: Cu <= 0.32 (n=131)
#     Zona: 66 colunas
#     Importance: 0.020884
#   Predicado: Cu > 0.32 (n=83)
#     Zona: 66 colunas
#     Importance: 0.020916
#   Predicado: Cu <= 1.92 (n=172)
#     Zona: 66 colunas
#     Importance: 0.019946
#   Predicado: Zn > -1.47 (n=171)
#     Zona: 29 colunas
#     Importance: 0.025737
#   Predicado: Zn <= -0.39 (n=86)
#     Zona: 29 colunas
#     Importance: 0.022720
#   Predicado: Zn > -0.39 (n=128)
#     Zona: 29 colunas
#     Importance: 0.026043
#   Predicado: Zn <= 0.56 (n=135)
#     Zona: 29 colunas
#     Importance: 0.024404
#   Predicado: Zn > 0.56 (n=79)
#     Zona: 29 colunas
#     Importance: 0.025227
#   Predicado: Zn <= 1.56 (n=175)
#     Zona: 29 colunas
#     Importance: 0.023726
#   Predicado: Bremsstrahlung > -9.06 (n=171)
#     Zona: 429 colunas
#     Importance: 0.121487
#   Predicado: Bremsstrahlung <= -1.54 (n=89)
#     Zona: 429 colunas
#     Importance: 0.178386
#   Predicado: Bremsstrahlung > -1.54 (n=125)
#     Zona: 429 colunas
#     Importance: 0.107858
#   Predicado: Bremsstrahlung <= 4.15 (n=133)
#     Zona: 429 colunas
#     Importance: 0.153152
#   Predicado: Bremsstrahlung > 4.15 (n=81)
#     Zona: 429 colunas
#     Importance: 0.110980
#   Predicado: Bremsstrahlung <= 9.64 (n=174)
#     Zona: 429 colunas
#     Importance: 0.147624
#   Predicado: Ag compton > -6.71 (n=171)
#     Zona: 62 colunas
#     Importance: 0.029262
#   Predicado: Ag compton <= -1.09 (n=86)
#     Zona: 62 colunas
#     Importance: 0.041326
#   Predicado: Ag compton > -1.09 (n=128)
#     Zona: 62 colunas
#     Importance: 0.026660
#   Predicado: Ag compton <= 2.96 (n=130)
#     Zona: 62 colunas
#     Importance: 0.036037
#   Predicado: Ag compton > 2.96 (n=84)
#     Zona: 62 colunas
#     Importance: 0.027163
#   Predicado: Ag compton <= 6.52 (n=172)
#     Zona: 62 colunas
#     Importance: 0.032768
#   Predicado: Ag ka > -11.59 (n=172)
#     Zona: 45 colunas
#     Importance: 0.076635
#   Predicado: Ag ka <= -7.06 (n=85)
#     Zona: 45 colunas
#     Importance: 0.106393
#   Predicado: Ag ka > -7.06 (n=129)
#     Zona: 45 colunas
#     Importance: 0.078372
#   Predicado: Ag ka <= 5.37 (n=131)
#     Zona: 45 colunas
#     Importance: 0.081427
#   Predicado: Ag ka > 5.37 (n=83)
#     Zona: 45 colunas
#     Importance: 0.102247
#   Predicado: Ag ka <= 20.95 (n=165)
#     Zona: 45 colunas
#     Importance: 0.081611
#
# [Bag_9] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=173)
#     Zona: 18 colunas
#     Importance: 0.049933
#   Predicado: Ag La <= 2.70 (n=86)
#     Zona: 18 colunas
#     Importance: 0.213903
#   Predicado: Ag La > 2.70 (n=128)
#     Zona: 18 colunas
#     Importance: 0.025924
#   Predicado: Ag La <= 7.76 (n=133)
#     Zona: 18 colunas
#     Importance: 0.144180
#   Predicado: Ag La > 7.76 (n=81)
#     Zona: 18 colunas
#     Importance: 0.031333
#   Predicado: Ag La <= 9.01 (n=167)
#     Zona: 18 colunas
#     Importance: 0.119651
#   Predicado: Ag Lb > -15.87 (n=172)
#     Zona: 15 colunas
#     Importance: 0.034788
#   Predicado: Ag Lb <= 2.36 (n=87)
#     Zona: 15 colunas
#     Importance: 0.163965
#   Predicado: Ag Lb > 2.36 (n=127)
#     Zona: 15 colunas
#     Importance: 0.020074
#   Predicado: Ag Lb <= 6.48 (n=129)
#     Zona: 15 colunas
#     Importance: 0.114578
#   Predicado: Ag Lb > 6.48 (n=85)
#     Zona: 15 colunas
#     Importance: 0.023927
#   Predicado: Ag Lb <= 8.04 (n=168)
#     Zona: 15 colunas
#     Importance: 0.092881
#   Predicado: Ca > -1.79 (n=174)
#     Zona: 19 colunas
#     Importance: 0.011054
#   Predicado: Ca <= -0.68 (n=86)
#     Zona: 19 colunas
#     Importance: 0.011323
#   Predicado: Ca > -0.68 (n=128)
#     Zona: 19 colunas
#     Importance: 0.011223
#   Predicado: Ca <= 0.46 (n=130)
#     Zona: 19 colunas
#     Importance: 0.010661
#   Predicado: Ca > 0.46 (n=84)
#     Zona: 19 colunas
#     Importance: 0.012195
#   Predicado: Ca <= 1.81 (n=172)
#     Zona: 19 colunas
#     Importance: 0.010276
#   Predicado: background > -1.23 (n=169)
#     Zona: 87 colunas
#     Importance: 0.033397
#   Predicado: background <= -0.46 (n=84)
#     Zona: 87 colunas
#     Importance: 0.028237
#   Predicado: background > -0.46 (n=130)
#     Zona: 87 colunas
#     Importance: 0.033139
#   Predicado: background <= 0.40 (n=127)
#     Zona: 87 colunas
#     Importance: 0.029956
#   Predicado: background > 0.40 (n=87)
#     Zona: 87 colunas
#     Importance: 0.033052
#   Predicado: background <= 1.29 (n=168)
#     Zona: 87 colunas
#     Importance: 0.032543
#   Predicado: Fe > -1.18 (n=173)
#     Zona: 23 colunas
#     Importance: 0.013566
#   Predicado: Fe <= -0.36 (n=81)
#     Zona: 23 colunas
#     Importance: 0.014468
#   Predicado: Fe > -0.36 (n=133)
#     Zona: 23 colunas
#     Importance: 0.013239
#   Predicado: Fe <= 0.31 (n=128)
#     Zona: 23 colunas
#     Importance: 0.013147
#   Predicado: Fe > 0.31 (n=86)
#     Zona: 23 colunas
#     Importance: 0.014534
#   Predicado: Fe <= 1.20 (n=171)
#     Zona: 23 colunas
#     Importance: 0.012839
#   Predicado: Cu > -1.74 (n=169)
#     Zona: 66 colunas
#     Importance: 0.021608
#   Predicado: Cu <= -0.64 (n=85)
#     Zona: 66 colunas
#     Importance: 0.019399
#   Predicado: Cu > -0.64 (n=129)
#     Zona: 66 colunas
#     Importance: 0.022240
#   Predicado: Cu <= 0.32 (n=124)
#     Zona: 66 colunas
#     Importance: 0.020602
#   Predicado: Cu > 0.32 (n=90)
#     Zona: 66 colunas
#     Importance: 0.021812
#   Predicado: Cu <= 1.92 (n=166)
#     Zona: 66 colunas
#     Importance: 0.019984
#   Predicado: Zn > -1.47 (n=170)
#     Zona: 29 colunas
#     Importance: 0.024929
#   Predicado: Zn <= -0.39 (n=85)
#     Zona: 29 colunas
#     Importance: 0.021179
#   Predicado: Zn > -0.39 (n=129)
#     Zona: 29 colunas
#     Importance: 0.025681
#   Predicado: Zn <= 0.56 (n=134)
#     Zona: 29 colunas
#     Importance: 0.023619
#   Predicado: Zn > 0.56 (n=80)
#     Zona: 29 colunas
#     Importance: 0.024352
#   Predicado: Zn <= 1.56 (n=173)
#     Zona: 29 colunas
#     Importance: 0.023163
#   Predicado: Bremsstrahlung > -9.06 (n=171)
#     Zona: 429 colunas
#     Importance: 0.127981
#   Predicado: Bremsstrahlung <= -1.54 (n=84)
#     Zona: 429 colunas
#     Importance: 0.188564
#   Predicado: Bremsstrahlung > -1.54 (n=130)
#     Zona: 429 colunas
#     Importance: 0.114448
#   Predicado: Bremsstrahlung <= 4.15 (n=127)
#     Zona: 429 colunas
#     Importance: 0.158171
#   Predicado: Bremsstrahlung > 4.15 (n=87)
#     Zona: 429 colunas
#     Importance: 0.122184
#   Predicado: Bremsstrahlung <= 9.64 (n=170)
#     Zona: 429 colunas
#     Importance: 0.153201
#   Predicado: Ag compton > -6.71 (n=174)
#     Zona: 62 colunas
#     Importance: 0.031763
#   Predicado: Ag compton <= -1.09 (n=82)
#     Zona: 62 colunas
#     Importance: 0.039583
#   Predicado: Ag compton > -1.09 (n=132)
#     Zona: 62 colunas
#     Importance: 0.030020
#   Predicado: Ag compton <= 2.96 (n=126)
#     Zona: 62 colunas
#     Importance: 0.034096
#   Predicado: Ag compton > 2.96 (n=88)
#     Zona: 62 colunas
#     Importance: 0.033094
#   Predicado: Ag compton <= 6.52 (n=172)
#     Zona: 62 colunas
#     Importance: 0.032798
#   Predicado: Ag ka > -11.59 (n=168)
#     Zona: 45 colunas
#     Importance: 0.078726
#   Predicado: Ag ka <= -7.06 (n=85)
#     Zona: 45 colunas
#     Importance: 0.113219
#   Predicado: Ag ka > -7.06 (n=129)
#     Zona: 45 colunas
#     Importance: 0.074623
#   Predicado: Ag ka <= 5.37 (n=129)
#     Zona: 45 colunas
#     Importance: 0.087707
#   Predicado: Ag ka > 5.37 (n=85)
#     Zona: 45 colunas
#     Importance: 0.093363
#   Predicado: Ag ka <= 20.95 (n=171)
#     Zona: 45 colunas
#     Importance: 0.086166
#
# [Bag_10] Processando 60 predicados...
#   Predicado: Ag La > -18.52 (n=174)
#     Zona: 18 colunas
#     Importance: 0.045487
#   Predicado: Ag La <= 2.70 (n=80)
#     Zona: 18 colunas
#     Importance: 0.211965
#   Predicado: Ag La > 2.70 (n=134)
#     Zona: 18 colunas
#     Importance: 0.025338
#   Predicado: Ag La <= 7.76 (n=125)
#     Zona: 18 colunas
#     Importance: 0.141409
#   Predicado: Ag La > 7.76 (n=89)
#     Zona: 18 colunas
#     Importance: 0.030071
#   Predicado: Ag La <= 9.01 (n=169)
#     Zona: 18 colunas
#     Importance: 0.111339
#   Predicado: Ag Lb > -15.87 (n=173)
#     Zona: 15 colunas
#     Importance: 0.031483
#   Predicado: Ag Lb <= 2.36 (n=80)
#     Zona: 15 colunas
#     Importance: 0.165886
#   Predicado: Ag Lb > 2.36 (n=134)
#     Zona: 15 colunas
#     Importance: 0.019862
#   Predicado: Ag Lb <= 6.48 (n=125)
#     Zona: 15 colunas
#     Importance: 0.110378
#   Predicado: Ag Lb > 6.48 (n=89)
#     Zona: 15 colunas
#     Importance: 0.023990
#   Predicado: Ag Lb <= 8.04 (n=166)
#     Zona: 15 colunas
#     Importance: 0.087853
#   Predicado: Ca > -1.79 (n=168)
#     Zona: 19 colunas
#     Importance: 0.010437
#   Predicado: Ca <= -0.68 (n=89)
#     Zona: 19 colunas
#     Importance: 0.011636
#   Predicado: Ca > -0.68 (n=125)
#     Zona: 19 colunas
#     Importance: 0.010342
#   Predicado: Ca <= 0.46 (n=128)
#     Zona: 19 colunas
#     Importance: 0.010266
#   Predicado: Ca > 0.46 (n=86)
#     Zona: 19 colunas
#     Importance: 0.011795
#   Predicado: Ca <= 1.81 (n=175)
#     Zona: 19 colunas
#     Importance: 0.010042
#   Predicado: background > -1.23 (n=170)
#     Zona: 87 colunas
#     Importance: 0.031867
#   Predicado: background <= -0.46 (n=87)
#     Zona: 87 colunas
#     Importance: 0.025495
#   Predicado: background > -0.46 (n=127)
#     Zona: 87 colunas
#     Importance: 0.032270
#   Predicado: background <= 0.40 (n=129)
#     Zona: 87 colunas
#     Importance: 0.027869
#   Predicado: background > 0.40 (n=85)
#     Zona: 87 colunas
#     Importance: 0.032016
#   Predicado: background <= 1.29 (n=173)
#     Zona: 87 colunas
#     Importance: 0.030335
#   Predicado: Fe > -1.18 (n=175)
#     Zona: 23 colunas
#     Importance: 0.014121
#   Predicado: Fe <= -0.36 (n=77)
#     Zona: 23 colunas
#     Importance: 0.014140
#   Predicado: Fe > -0.36 (n=137)
#     Zona: 23 colunas
#     Importance: 0.013508
#   Predicado: Fe <= 0.31 (n=121)
#     Zona: 23 colunas
#     Importance: 0.012838
#   Predicado: Fe > 0.31 (n=93)
#     Zona: 23 colunas
#     Importance: 0.014902
# ...
# Removida: Ag ka <= -7.06 -> Ag Lb <= 8.04 (0.1484) | Mantida: Ag Lb <= 8.04 -> Ag ka <= -7.06 (0.1629)
# Removida: Ag ka > 5.37 -> Ag ka <= -7.06 (0.0754) | Mantida: Ag ka <= -7.06 -> Ag ka > 5.37 (0.1542)
# Removida: Ag Lb <= 8.04 -> Ag ka > 5.37 (0.0822) | Mantida: Ag ka > 5.37 -> Ag Lb <= 8.04 (0.4487)
# Removida: Ag ka <= 5.37 -> Ag Lb <= 8.04 (0.0654) | Mantida: Ag Lb <= 8.04 -> Ag ka <= 5.37 (0.1502)
# Removida: Ag ka <= 20.95 -> Ag Lb <= 8.04 (0.0663) | Mantida: Ag Lb <= 8.04 -> Ag ka <= 20.95 (0.1443)
# Removida: Ag ka <= 5.37 -> Ag ka <= 20.95 (0.1894) | Mantida: Ag ka <= 20.95 -> Ag ka <= 5.37 (0.4253)
# Removida: Ag ka > -11.59 -> Ag ka <= 20.95 (0.0593) | Mantida: Ag ka <= 20.95 -> Ag ka > -11.59 (0.0621)
# Removida: Ag ka <= 20.95 -> Ag ka > -7.06 (0.0583) | Mantida: Ag ka > -7.06 -> Ag ka <= 20.95 (0.1191)
# Removida: Ag ka > -7.06 -> Ag ka > -11.59 (0.1173) | Mantida: Ag ka > -11.59 -> Ag ka > -7.06 (0.4782)
# Removida: Ag compton <= -1.09 -> Ag La > -18.52 (0.0223) | Mantida: Ag La > -18.52 -> Ag compton <= -1.09 (0.3404)
# Removida: Ag Lb > -15.87 -> Ag compton <= 2.96 (0.0288) | Mantida: Ag compton <= 2.96 -> Ag Lb > -15.87 (0.0534)
# Removida: Ag compton <= 6.52 -> Ag Lb > -15.87 (0.0167) | Mantida: Ag Lb > -15.87 -> Ag compton <= 6.52 (0.0846)
# Removida: Ag La > 7.76 -> Ag Lb > -15.87 (0.0510) | Mantida: Ag Lb > -15.87 -> Ag La > 7.76 (0.0552)
# Removida: background > -0.46 -> Ag compton <= 6.52 (0.0024) | Mantida: Ag compton <= 6.52 -> background > -0.46 (0.0340)
# Removida: background > -0.46 -> Ag compton > -6.71 (0.0011) | Mantida: Ag compton > -6.71 -> background > -0.46 (0.0153)
# Removida: background <= 1.29 -> background > -0.46 (0.0022) | Mantida: background > -0.46 -> background <= 1.29 (0.0022)
# Removida: background <= 0.40 -> Ag compton > 2.96 (0.0031) | Mantida: Ag compton > 2.96 -> background <= 0.40 (0.0327)
# Removida: Ag compton > 2.96 -> Ag La > 7.76 (0.0162) | Mantida: Ag La > 7.76 -> Ag compton > 2.96 (0.0262)
# Removida: background > 0.40 -> background > -1.23 (0.0010) | Mantida: background > -1.23 -> background > 0.40 (0.0023)
# Removida: background > 0.40 -> background <= 1.29 (0.0012) | Mantida: background <= 1.29 -> background > 0.40 (0.0021)
# Removida: background > 0.40 -> Ag compton > -1.09 (0.0010) | Mantida: Ag compton > -1.09 -> background > 0.40 (0.0146)
# Removida: background > -1.23 -> Ag La > 7.76 (0.0010) | Mantida: Ag La > 7.76 -> background > -1.23 (0.0254)
# Removida: background <= 1.29 -> Ag La > 7.76 (0.0011) | Mantida: Ag La > 7.76 -> background <= 1.29 (0.0260)
# Removida: background <= 0.40 -> Ag La > 7.76 (0.0031) | Mantida: Ag La > 7.76 -> background <= 0.40 (0.0259)
# Removida: background <= 1.29 -> background > -1.23 (0.0022) | Mantida: background > -1.23 -> background <= 1.29 (0.0033)
# Removida: background <= 0.40 -> Ag compton > -6.71 (0.0021) | Mantida: Ag compton > -6.71 -> background <= 0.40 (0.0798)
# Removida: background <= -0.46 -> Ag compton > -1.09 (0.0020) | Mantida: Ag compton > -1.09 -> background <= -0.46 (0.0592)
# Removida: Zn <= 0.56 -> Ag La > 2.70 (0.0043) | Mantida: Ag La > 2.70 -> Zn <= 0.56 (0.0209)
# Removida: background <= -0.46 -> Ag La > 2.70 (0.0036) | Mantida: Ag La > 2.70 -> background <= -0.46 (0.0227)
# Removida: Zn > -0.39 -> Ag Lb > 6.48 (0.0042) | Mantida: Ag Lb > 6.48 -> Zn > -0.39 (0.0215)
# Removida: Zn <= 0.56 -> Zn > -0.39 (0.0041) | Mantida: Zn > -0.39 -> Zn <= 0.56 (0.0043)
# Removida: Zn <= 0.56 -> Zn > -1.47 (0.0044) | Mantida: Zn > -1.47 -> Zn <= 0.56 (0.0169)
# Removida: Cu > -0.64 -> Zn > -1.47 (0.0022) | Mantida: Zn > -1.47 -> Cu > -0.64 (0.0082)
# Removida: Zn > 0.56 -> Ag Lb > 6.48 (0.0042) | Mantida: Ag Lb > 6.48 -> Zn > 0.56 (0.0398)
# Removida: Cu > -0.64 -> Zn > 0.56 (0.0022) | Mantida: Zn > 0.56 -> Cu > -0.64 (0.0040)
# Removida: Zn <= 0.56 -> Ag Lb > 6.48 (0.0086) | Mantida: Ag Lb > 6.48 -> Zn <= 0.56 (0.0213)
# Removida: Zn <= 1.56 -> Ag Lb > 6.48 (0.0039) | Mantida: Ag Lb > 6.48 -> Zn <= 1.56 (0.0635)
# Removida: background <= -0.46 -> Ag Lb > 6.48 (0.0018) | Mantida: Ag Lb > 6.48 -> background <= -0.46 (0.0223)
# Removida: Cu > 0.32 -> Zn <= 1.56 (0.0021) | Mantida: Zn <= 1.56 -> Cu > 0.32 (0.0041)
# Removida: Cu > -1.74 -> Zn <= 1.56 (0.0021) | Mantida: Zn <= 1.56 -> Cu > -1.74 (0.0039)
# Removida: Cu > -0.64 -> Cu > 0.32 (0.0022) | Mantida: Cu > 0.32 -> Cu > -0.64 (0.0063)
# Removida: Cu > 0.32 -> Zn <= -0.39 (0.0042) | Mantida: Zn <= -0.39 -> Cu > 0.32 (0.0152)
# Removida: Zn <= -0.39 -> Cu > -0.64 (0.0039) | Mantida: Cu > -0.64 -> Zn <= -0.39 (0.0041)
# Removida: Cu > -1.74 -> Cu > -0.64 (0.0020) | Mantida: Cu > -0.64 -> Cu > -1.74 (0.0084)
# Removida: Cu > -1.74 -> Zn <= -0.39 (0.0022) | Mantida: Zn <= -0.39 -> Cu > -1.74 (0.0079)
# Removida: Cu <= 0.32 -> Cu > -1.74 (0.0021) | Mantida: Cu > -1.74 -> Cu <= 0.32 (0.0021)
# Removida: Cu <= 0.32 -> Ag Lb > 2.36 (0.0019) | Mantida: Ag Lb > 2.36 -> Cu <= 0.32 (0.0362)
# Removida: Cu <= 1.92 -> Ag Lb > 2.36 (0.0078) | Mantida: Ag Lb > 2.36 -> Cu <= 1.92 (0.0175)
# Removida: Cu <= -0.64 -> Cu <= 1.92 (0.0040) | Mantida: Cu <= 1.92 -> Cu <= -0.64 (0.0056)
# Removida: Fe > 0.31 -> Fe <= -0.36 (0.0019) | Mantida: Fe <= -0.36 -> Fe > 0.31 (0.0124)
# Removida: Fe <= 0.31 -> Fe > 0.31 (0.0037) | Mantida: Fe > 0.31 -> Fe <= 0.31 (0.0057)
# Removida: Fe > -1.18 -> Fe <= 0.31 (0.0037) | Mantida: Fe <= 0.31 -> Fe > -1.18 (0.0037)
# Removida: Fe > -0.36 -> Fe <= 0.31 (0.0018) | Mantida: Fe <= 0.31 -> Fe > -0.36 (0.0019)
# Removida: Fe <= 1.20 -> Fe <= 0.31 (0.0017) | Mantida: Fe <= 0.31 -> Fe <= 1.20 (0.0073)
# Removida: Fe > -1.18 -> Fe > 0.31 (0.0017) | Mantida: Fe > 0.31 -> Fe > -1.18 (0.0058)
# Removida: Fe > -1.18 -> Fe <= 1.20 (0.0036) | Mantida: Fe <= 1.20 -> Fe > -1.18 (0.0071)
# Removida: Fe > -0.36 -> Fe <= 1.20 (0.0035) | Mantida: Fe <= 1.20 -> Fe > -0.36 (0.0052)
# Removida: Ca <= -0.68 -> Ca > 0.46 (0.0075) | Mantida: Ca > 0.46 -> Ca <= -0.68 (0.0076)
# Removida: Ca <= -0.68 -> Ca > -1.79 (0.0024) | Mantida: Ca > -1.79 -> Ca <= -0.68 (0.0074)
# Removida: Ca <= 0.46 -> Ca > 0.46 (0.0023) | Mantida: Ca > 0.46 -> Ca <= 0.46 (0.0047)
# Removida: Ca <= 0.46 -> Ca > -1.79 (0.0023) | Mantida: Ca > -1.79 -> Ca <= 0.46 (0.0069)
# Removida: Ca > -1.79 -> Ca <= 1.81 (0.0022) | Mantida: Ca <= 1.81 -> Ca > -1.79 (0.0023)
# Removida: Ca > -1.79 -> Ca > -0.68 (0.0069) | Mantida: Ca > -0.68 -> Ca > -1.79 (0.0122)
# Removida: Ca > -0.68 -> Ca <= 1.81 (0.0022) | Mantida: Ca <= 1.81 -> Ca > -0.68 (0.0044)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 282 | Removidas: 75
# Nós predicados: 60
# Métrica: Perturbation
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 71
# Removida: Bremsstrahlung <= 4.15 -> Ag Lb <= 2.36 (0.1438) | Mantida: Ag Lb <= 2.36 -> Bremsstrahlung <= 4.15 (0.8319)
# Removida: Ag La <= 7.76 -> Bremsstrahlung <= 4.15 (0.1254) | Mantida: Bremsstrahlung <= 4.15 -> Ag La <= 7.76 (0.1831)
# Removida: Bremsstrahlung <= 9.64 -> Ag La <= 7.76 (0.1783) | Mantida: Ag La <= 7.76 -> Bremsstrahlung <= 9.64 (0.6197)
# Removida: Bremsstrahlung > 4.15 -> Ag La <= 9.01 (0.0348) | Mantida: Ag La <= 9.01 -> Bremsstrahlung > 4.15 (0.1924)
# Removida: Bremsstrahlung > -9.06 -> Ag La <= 9.01 (0.1468) | Mantida: Ag La <= 9.01 -> Bremsstrahlung > -9.06 (0.2972)
# Removida: Bremsstrahlung > -1.54 -> Ag La <= 9.01 (0.0337) | Mantida: Ag La <= 9.01 -> Bremsstrahlung > -1.54 (0.0949)
# Removida: Ag Lb <= 6.48 -> Bremsstrahlung > -9.06 (0.1004) | Mantida: Bremsstrahlung > -9.06 -> Ag Lb <= 6.48 (0.1047)
# Removida: Bremsstrahlung > -1.54 -> Ag Lb <= 6.48 (0.0326) | Mantida: Ag Lb <= 6.48 -> Bremsstrahlung > -1.54 (0.1852)
# Removida: Bremsstrahlung > 4.15 -> Ag Lb <= 6.48 (0.0343) | Mantida: Ag Lb <= 6.48 -> Bremsstrahlung > 4.15 (0.2959)
# Removida: Ag ka > 5.37 -> Ag Lb <= 6.48 (0.0800) | Mantida: Ag Lb <= 6.48 -> Ag ka > 5.37 (0.0929)
# Removida: Bremsstrahlung > 4.15 -> Ag ka <= -7.06 (0.0324) | Mantida: Ag ka <= -7.06 -> Bremsstrahlung > 4.15 (0.2493)
# Removida: Ag ka > 5.37 -> Ag ka <= -7.06 (0.1552) | Mantida: Ag ka <= -7.06 -> Ag ka > 5.37 (0.2353)
# Removida: Bremsstrahlung > -1.54 -> Ag ka <= -7.06 (0.0653) | Mantida: Ag ka <= -7.06 -> Bremsstrahlung > -1.54 (0.0801)
# Removida: Bremsstrahlung > -1.54 -> Bremsstrahlung > 4.15 (0.0315) | Mantida: Bremsstrahlung > 4.15 -> Bremsstrahlung > -1.54 (0.1979)
# Removida: Ag ka <= 5.37 -> Ag Lb <= 8.04 (0.0653) | Mantida: Ag Lb <= 8.04 -> Ag ka <= 5.37 (0.3909)
# Removida: Ag ka <= 20.95 -> Ag ka <= 5.37 (0.1847) | Mantida: Ag ka <= 5.37 -> Ag ka <= 20.95 (0.3181)
# Removida: Ag ka > -7.06 -> Ag ka <= 5.37 (0.0603) | Mantida: Ag ka <= 5.37 -> Ag ka > -7.06 (0.0605)
# Removida: Ag ka > -11.59 -> Ag ka <= 20.95 (0.1209) | Mantida: Ag ka <= 20.95 -> Ag ka > -11.59 (0.3144)
# Removida: Ag ka > -7.06 -> Ag ka > -11.59 (0.1805) | Mantida: Ag ka > -11.59 -> Ag ka > -7.06 (0.3624)
# Removida: Ag compton <= -1.09 -> Ag La > -18.52 (0.0222) | Mantida: Ag La > -18.52 -> Ag compton <= -1.09 (0.3511)
# Removida: background > -0.46 -> Ag compton <= 2.96 (0.0023) | Mantida: Ag compton <= 2.96 -> background > -0.46 (0.0708)
# Removida: background > -1.23 -> background > -0.46 (0.0010) | Mantida: background > -0.46 -> background > -1.23 (0.0023)
# Removida: background > -0.46 -> Ag compton <= 6.52 (0.0023) | Mantida: Ag compton <= 6.52 -> background > -0.46 (0.0170)
# Removida: Ag La > 7.76 -> Ag compton <= 6.52 (0.0266) | Mantida: Ag compton <= 6.52 -> Ag La > 7.76 (0.0326)
# Removida: background > 0.40 -> Ag La > 7.76 (0.0022) | Mantida: Ag La > 7.76 -> background > 0.40 (0.0263)
# Removida: background <= 0.40 -> Ag La > 7.76 (0.0022) | Mantida: Ag La > 7.76 -> background <= 0.40 (0.0258)
# Removida: background > 0.40 -> Ag compton <= 6.52 (0.0011) | Mantida: Ag compton <= 6.52 -> background > 0.40 (0.0341)
# Removida: background > -1.23 -> Ag compton > 2.96 (0.0010) | Mantida: Ag compton > 2.96 -> background > -1.23 (0.0153)
# Removida: Ag Lb > -15.87 -> Ag compton > -6.71 (0.0268) | Mantida: Ag compton > -6.71 -> Ag Lb > -15.87 (0.0319)
# Removida: background > 0.40 -> background <= 1.29 (0.0010) | Mantida: background <= 1.29 -> background > 0.40 (0.0033)
# Removida: background > 0.40 -> Ag compton > -6.71 (0.0010) | Mantida: Ag compton > -6.71 -> background > 0.40 (0.0150)
# Removida: Ag compton > -6.71 -> Ag compton > 2.96 (0.0146) | Mantida: Ag compton > 2.96 -> Ag compton > -6.71 (0.0771)
# Removida: background <= 0.40 -> Ag compton > 2.96 (0.0020) | Mantida: Ag compton > 2.96 -> background <= 0.40 (0.0164)
# Removida: background <= 0.40 -> Ag compton > -6.71 (0.0010) | Mantida: Ag compton > -6.71 -> background <= 0.40 (0.0304)
# Removida: background <= 0.40 -> Ag compton > -1.09 (0.0020) | Mantida: Ag compton > -1.09 -> background <= 0.40 (0.0146)
# Removida: Ag La > 2.70 -> Ag compton > -1.09 (0.0227) | Mantida: Ag compton > -1.09 -> Ag La > 2.70 (0.0577)
# Removida: background <= -0.46 -> Ag compton > -1.09 (0.0009) | Mantida: Ag compton > -1.09 -> background <= -0.46 (0.0288)
# Removida: Ag Lb > 6.48 -> Ag La > 2.70 (0.0221) | Mantida: Ag La > 2.70 -> Ag Lb > 6.48 (0.0452)
# Removida: Zn > -1.47 -> Ag La > 2.70 (0.0044) | Mantida: Ag La > 2.70 -> Zn > -1.47 (0.0652)
# Removida: background <= -0.46 -> Zn <= 0.56 (0.0034) | Mantida: Zn <= 0.56 -> background <= -0.46 (0.0040)
# Removida: Zn <= 0.56 -> Zn > 0.56 (0.0041) | Mantida: Zn > 0.56 -> Zn <= 0.56 (0.0083)
# Removida: Zn <= 1.56 -> Zn <= 0.56 (0.0039) | Mantida: Zn <= 0.56 -> Zn <= 1.56 (0.0042)
# Removida: Zn > 0.56 -> Ag Lb > 6.48 (0.0043) | Mantida: Ag Lb > 6.48 -> Zn > 0.56 (0.0213)
# Removida: Cu > 0.32 -> Ag Lb > 6.48 (0.0021) | Mantida: Ag Lb > 6.48 -> Cu > 0.32 (0.0210)
# Removida: Cu > -0.64 -> Zn <= -0.39 (0.0021) | Mantida: Zn <= -0.39 -> Cu > -0.64 (0.0040)
# Removida: Cu > -1.74 -> Zn <= -0.39 (0.0042) | Mantida: Zn <= -0.39 -> Cu > -1.74 (0.0077)
# Removida: Zn > -1.47 -> Cu > -0.64 (0.0040) | Mantida: Cu > -0.64 -> Zn > -1.47 (0.0042)
# Removida: Zn <= 1.56 -> Cu > -0.64 (0.0039) | Mantida: Cu > -0.64 -> Zn <= 1.56 (0.0043)
# Removida: Cu <= 0.32 -> Cu > -0.64 (0.0020) | Mantida: Cu > -0.64 -> Cu <= 0.32 (0.0063)
# Removida: Zn > -1.47 -> Zn > -0.39 (0.0081) | Mantida: Zn > -0.39 -> Zn > -1.47 (0.0169)
# Removida: Zn <= 1.56 -> Zn > -0.39 (0.0038) | Mantida: Zn > -0.39 -> Zn <= 1.56 (0.0039)
# Removida: Cu > 0.32 -> Cu <= 1.92 (0.0040) | Mantida: Cu <= 1.92 -> Cu > 0.32 (0.0059)
# Removida: Zn > 0.56 -> Cu > -1.74 (0.0039) | Mantida: Cu > -1.74 -> Zn > 0.56 (0.0042)
# Removida: Cu > -1.74 -> Cu <= 0.32 (0.0040) | Mantida: Cu <= 0.32 -> Cu > -1.74 (0.0041)
# Removida: Cu <= 1.92 -> Ag Lb > 2.36 (0.0038) | Mantida: Ag Lb > 2.36 -> Cu <= 1.92 (0.0339)
# Removida: Cu <= -0.64 -> Ag Lb > 2.36 (0.0021) | Mantida: Ag Lb > 2.36 -> Cu <= -0.64 (0.0699)
# Removida: Fe > 0.31 -> Fe <= -0.36 (0.0058) | Mantida: Fe <= -0.36 -> Fe > 0.31 (0.0081)
# Removida: Fe > -1.18 -> Fe > 0.31 (0.0035) | Mantida: Fe > 0.31 -> Fe > -1.18 (0.0057)
# Removida: Fe <= 0.31 -> Fe > 0.31 (0.0019) | Mantida: Fe > 0.31 -> Fe <= 0.31 (0.0038)
# Removida: Fe <= 1.20 -> Fe > -1.18 (0.0017) | Mantida: Fe > -1.18 -> Fe <= 1.20 (0.0071)
# Removida: Fe > -1.18 -> Fe <= 0.31 (0.0018) | Mantida: Fe <= 0.31 -> Fe > -1.18 (0.0074)
# Removida: Fe <= 1.20 -> Fe <= 0.31 (0.0018) | Mantida: Fe <= 0.31 -> Fe <= 1.20 (0.0052)
# Removida: Fe > -0.36 -> Fe <= 1.20 (0.0036) | Mantida: Fe <= 1.20 -> Fe > -0.36 (0.0053)
# Removida: Fe <= 0.31 -> Fe > -0.36 (0.0035) | Mantida: Fe > -0.36 -> Fe <= 0.31 (0.0053)
# Removida: Ca > 0.46 -> Ca <= -0.68 (0.0052) | Mantida: Ca <= -0.68 -> Ca > 0.46 (0.0075)
# Removida: Ca > -0.68 -> Ca <= -0.68 (0.0046) | Mantida: Ca <= -0.68 -> Ca > -0.68 (0.0050)
# Removida: Ca <= 1.81 -> Ca > -0.68 (0.0022) | Mantida: Ca > -0.68 -> Ca <= 1.81 (0.0070)
# Removida: Ca > -1.79 -> Ca > -0.68 (0.0070) | Mantida: Ca > -0.68 -> Ca > -1.79 (0.0099)
# Removida: Ca > -1.79 -> Ca <= -0.68 (0.0048) | Mantida: Ca <= -0.68 -> Ca > -1.79 (0.0069)
# Removida: Ca <= 0.46 -> Ca > -1.79 (0.0047) | Mantida: Ca > -1.79 -> Ca <= 0.46 (0.0092)
# Removida: Ca <= 1.81 -> Ca <= 0.46 (0.0042) | Mantida: Ca <= 0.46 -> Ca <= 1.81 (0.0134)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 291 | Removidas: 71
# Nós predicados: 60
# Métrica: Perturbation
# Ponderação por variância explicada: ATIVADA
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#       Predicate_pert_Seed_0    Predicate_pert_Seed_1    Predicate_pert_Seed_2  \
# 0             Ag La <= 2.70            Ag La <= 2.70            Ag La <= 2.70
# 1   Bremsstrahlung <= -1.54  Bremsstrahlung <= -1.54  Bremsstrahlung <= -1.54
# 2             Ag Lb <= 2.36            Ag Lb <= 2.36            Ag Lb <= 2.36
# 3    Bremsstrahlung <= 4.15            Ag La <= 7.76   Bremsstrahlung <= 4.15
# 4             Ag La <= 9.01            Ag La <= 9.01            Ag La <= 7.76
# ..                      ...                      ...                      ...
# 57              Ca <= -0.68              Ca <= -0.68                Ca > 0.46
# 58               Ca > -1.79               Ca <= 1.81               Ca > -1.79
# 59               Ca <= 1.81               Ca > -0.68               Ca <= 1.81
# 60                  Class_A                  Class_A                  Class_A
# 61                  Class_B                  Class_B                  Class_B
#
#       Predicate_pert_Seed_3
# 0             Ag La <= 2.70
# 1             Ag La <= 7.76
# 2   Bremsstrahlung <= -1.54
# 3    Bremsstrahlung <= 4.15
# 4             Ag Lb <= 2.36
# ..                      ...
# 57               Ca > -1.79
# 58               Ca <= 0.46
# 59               Ca <= 1.81
# 60                  Class_A
# 61                  Class_B
#
# [62 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#                   Predicate  Perturbation
# 0             Ag La <= 2.70      0.218193
# 1   Bremsstrahlung <= -1.54      0.183728
# 2             Ag Lb <= 2.36      0.165061
# 3    Bremsstrahlung <= 4.15      0.151607
# 4    Bremsstrahlung <= 9.64      0.145160
# 5             Ag La <= 7.76      0.141935
# 6    Bremsstrahlung > -9.06      0.119050
# 7     Bremsstrahlung > 4.15      0.114600
# 8             Ag La <= 9.01      0.113973
# 9             Ag Lb <= 6.48      0.109012
# 10   Bremsstrahlung > -1.54      0.106085
# 11           Ag ka <= -7.06      0.100687
# 12             Ag ka > 5.37      0.093052
# 13            Ag Lb <= 8.04      0.087615
# 14           Ag ka <= 20.95      0.079181
# 15            Ag ka <= 5.37      0.078232
# 16           Ag ka > -11.59      0.075767
# 17            Ag ka > -7.06      0.073546
# 18           Ag La > -18.52      0.046839
# 19      Ag compton <= -1.09      0.042341
# 20       Ag compton <= 2.96      0.036008
# 21       Ag compton <= 6.52      0.033194
# 22       background > -0.46      0.031033
# 23       background <= 1.29      0.031007
# 24       Ag compton > -6.71      0.030704
# 25       background > -1.23      0.030481
# 26        Ag compton > 2.96      0.029979
# 27           Ag Lb > -15.87      0.029933
# 28        background > 0.40      0.029146
# 29       background <= 0.40      0.029050
# 30             Ag La > 7.76      0.028800
# 31       Ag compton > -1.09      0.027992
# 32      background <= -0.46      0.026081
# 33               Zn > -0.39      0.024530
# 34               Zn > -1.47      0.024488
# 35               Zn <= 0.56      0.024096
# 36             Ag La > 2.70      0.024039
# 37                Zn > 0.56      0.023625
# 38               Zn <= 1.56      0.023177
# 39              Zn <= -0.39      0.022914
# 40             Ag Lb > 6.48      0.022649
# 41               Cu > -0.64      0.021251
# 42               Cu > -1.74      0.020876
# 43               Cu <= 0.32      0.020693
# 44                Cu > 0.32      0.020308
# 45               Cu <= 1.92      0.020096
# 46              Cu <= -0.64      0.019464
# 47             Ag Lb > 2.36      0.018581
# 48              Fe <= -0.36      0.016958
# 49               Fe <= 0.31      0.014997
# 50                Fe > 0.31      0.014471
# 51               Fe <= 1.20      0.014273
# 52               Fe > -1.18      0.014033
# 53               Fe > -0.36      0.013439
# 54                Ca > 0.46      0.012075
# 55               Ca > -0.68      0.011332
# 56               Ca > -1.79      0.011000
# 57              Ca <= -0.68      0.010511
# 58               Ca <= 0.46      0.010288
# 59               Ca <= 1.81      0.009915

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                        Node  Local_Reaching_Centrality            Zone  \
# 0             Ag La <= 2.70                   6.043251           Ag La
# 1   Bremsstrahlung <= -1.54                   3.741575  Bremsstrahlung
# 2             Ag Lb <= 2.36                   3.522829           Ag Lb
# 3              Ag ka > 5.37                   2.365298           Ag ka
# 4       Ag compton <= -1.09                   0.553964      Ag compton
# 5        background <= 1.29                   0.238849      background
# 6                Zn <= 0.56                   0.121458              Zn
# 7                Cu > -1.74                   0.107682              Cu
# 8               Fe <= -0.36                   0.021631              Fe
# 9                 Ca > 0.46                   0.013500              Ca
# 10                  Class_B                   0.000000            None
#
#    Threshold Operator
# 0       2.70       <=
# 1      -1.54       <=
# 2       2.36       <=
# 3       5.37        >
# 4      -1.09       <=
# 5       1.29       <=
# 6       0.56       <=
# 7      -1.74        >
# 8      -0.36       <=
# 9       0.46        >
# 10      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                        Node  Local_Reaching_Centrality            Zone  \
# 0             Ag La <= 2.70                   6.043251           Ag La
# 1   Bremsstrahlung <= -1.54                   3.741575  Bremsstrahlung
# 2             Ag Lb <= 2.36                   3.522829           Ag Lb
# 3             Ag La <= 7.76                   3.153507           Ag La
# 4    Bremsstrahlung <= 4.15                   3.063384  Bremsstrahlung
# ..                      ...                        ...             ...
# 57               Ca > -1.79                   0.009745              Ca
# 58               Ca > -0.68                   0.008865              Ca
# 59               Ca <= 1.81                   0.007141              Ca
# 60                  Class_B                   0.000000            None
# 61                  Class_A                   0.000000            None
#
#    Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0       2.70       <=          34.935039                    86.0
# 1      -1.54       <=         -72.079168                    60.0
# 2       2.36       <=          30.578162                     0.0
# 3       7.76       <=         105.814886                    78.0
# 4       4.15       <=          83.677742                   106.0
# ..       ...      ...                ...                     ...
# 57     -1.79        >          -9.483856                   153.0
# 58     -0.68        >          -8.742470                     9.0
# 59      1.81       <=          -2.575534                   222.0
# 60      None     None                NaN                     NaN
# 61      None     None                NaN                     NaN
#
#     Approximation_Error                  Node_Natural
# 0              0.021418            Ag La <= 34.935039
# 1              0.037184  Bremsstrahlung <= -72.079168
# 2              0.008013            Ag Lb <= 30.578162
# 3              0.002963           Ag La <= 105.814886
# 4              0.010264   Bremsstrahlung <= 83.677742
# ..                  ...                           ...
# 57             0.012409                Ca > -9.483856
# 58             0.004755                Ca > -8.742470
# 59             0.044016               Ca <= -2.575534
# 60                  NaN                          None
# 61                  NaN                          None
#
# [62 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ag La':
#   - Dimensão: 18 variáveis espectrais
#   - Variância explicada pela PC1: 91.39%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = mlp_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = mlp_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#   energy  Permutation_importance_proba            Zone
# 0  22.31                      0.032329           Ag ka
# 1   3.02                      0.022214           Ag La
# 2   3.17                      0.021363           Ag Lb
# 3  20.70                      0.011740      Ag compton
# 4   8.73                      0.010901              Zn
# 5  19.50                      0.008636  Bremsstrahlung
# 6   6.86                      0.006604              Cu
# 7   5.89                      0.006122      background
# 8   6.40                      0.005054              Fe
# 9   3.74                      0.004203              Ca

# %%
import numpy as np

max_len = max(
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#               Shap     Permutation LRC_perturbation  LRC_covariance
# 0            Ag Lb           Ag ka            Ag La           Ag La
# 1            Ag La           Ag La   Bremsstrahlung           Ag Lb
# 2            Ag ka           Ag Lb            Ag Lb           Ag ka
# 3               Zn      Ag compton            Ag ka  Bremsstrahlung
# 4       Ag compton              Zn       Ag compton      Ag compton
# 5   Bremsstrahlung  Bremsstrahlung       background              Cu
# 6       background              Cu               Zn              Ca
# 7               Cu      background               Cu      background
# 8               Fe              Fe               Fe              Fe
# 9               Ca              Ca               Ca              Zn
# 10            None            None             None            None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18128\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 5  LRC_perturbation    LRC_covariance   0.794255
# 2              Shap    LRC_covariance   0.608124
# 0              Shap       Permutation   0.535985
# 4       Permutation    LRC_covariance   0.508166
# 1              Shap  LRC_perturbation   0.469218
# 3       Permutation  LRC_perturbation   0.464176

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
