# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/bank_notes/plsda/bank_notes.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '2.74':'22.71']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.74':'22.71'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.74':'22.71'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-08 19:37:20,706 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-08 19:37:20,795 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-08 19:37:20,847 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-08 19:37:20,880 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import svm_optimized

svm_model = svm_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, aim='classification', kernel='rbf')
svm_model[0]
# Out:
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal                CM Cal  \
# 0   SVC      0.992958         0.981651              1.0  [[175, 0], [2, 107]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred             CM Pred
# 0            1.0               1.0               1.0  [[76, 0], [0, 47]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('Ar ka + Ag L', 2.76, 3.47),
('Ca ka', 3.5, 3.91),
('Ca kb', 3.93, 4.24),
('Ti ka', 4.26, 4.72),
('Ti kb', 4.75, 5.13),
('background1', 5.16, 6.12),
('Fe ka', 6.15, 6.76),
('Fe kb', 6.79, 7.32),
('background2', 7.35, 7.78),
('Cu ka', 7.81, 8.29),
('Zn ka', 8.29, 8.80),
('Cu kb', 8.80, 9.26),
('Zn kb', 9.26, 10.00),
('background3', 10.00, 21.46),
('Ag ka scattering', 21.49, 22.71)
]

# %% [markdown]
# ## Pvector and SHAP

# %%
X_sv = svm_model[3].support_vectors_            # shape (n_SV, n_features)
alpha_dual = svm_model[3].dual_coef_.ravel()    # shape (n_SV,)

# Calculando os coeficientes p usando os vetores de suporte e os multiplicadores de Lagrange
pvetor = pd.DataFrame({'energia' : Xcalclass.columns,
                       'importance': (X_sv.T) @ alpha_dual})
pvetor['importance'] = np.abs(pvetor['importance'])
pvector_df = pd.DataFrame({
    'energy': pvetor['energia'],
    'Pvector': pvetor['importance'].values
})
pvector_df = pvector_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in pvector_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
pvector_df['Zone'] = pvector_df['energy'].map(energy_to_zone_vip)
pvector_unique_df = pvector_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
pvector_unique_df
# Out:
#    energy     Pvector              Zone
# 0    6.43  180.546544             Fe ka
# 1    4.54  139.472008             Ti ka
# 2    8.09   85.907624             Cu ka
# 3   21.92   63.251649  Ag ka scattering
# 4    7.09   58.576719             Fe kb
# 5    4.93   57.959596             Ti kb
# 6     3.7   53.526321             Ca ka
# 7    8.93   29.372141             Cu kb
# 8   17.23   23.040610       background3
# 9    4.01   20.460567             Ca kb
# 10   5.79   14.852457       background1
# 11   8.77   13.313171             Zn ka
# 12   2.91   11.184570      Ar ka + Ag L
# 13   2.74   10.496748               NaN
# 14   7.58    9.978306       background2
# 15   9.64    9.883348             Zn kb

# %%
shap_global_importance = pd.read_csv('shap_bank_notes.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP              Zone
# 0     4.52       0.050138             Ti ka
# 1     3.70       0.029065             Ca ka
# 2     6.43       0.012064             Fe ka
# 3     8.03       0.002786             Cu ka
# 4     4.95       0.000787             Ti kb
# 5    21.92       0.000741  Ag ka scattering
# 6     4.01       0.000431             Ca kb
# 7     7.60       0.000326       background2
# 8     5.16       0.000317       background1
# 9    17.08       0.000261       background3
# 10    7.09       0.000252             Fe kb
# 11    9.18       0.000211             Cu kb
# 12    9.41       0.000153             Zn kb
# 13    3.19       0.000136      Ar ka + Ag L
# 14    8.47       0.000109             Zn ka
# 15    2.74       0.000000               NaN

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zona 'Ar ka + Ag L': VE = 5.85%, dim = 29 variáveis
# Zona 'Ca ka': VE = 98.41%, dim = 17 variáveis
# Zona 'Ca kb': VE = 90.24%, dim = 13 variáveis
# Zona 'Ti ka': VE = 96.36%, dim = 19 variáveis
# Zona 'Ti kb': VE = 80.62%, dim = 16 variáveis
# Zona 'background1': VE = 12.07%, dim = 39 variáveis
# Zona 'Fe ka': VE = 99.63%, dim = 25 variáveis
# Zona 'Fe kb': VE = 96.66%, dim = 22 variáveis
# Zona 'background2': VE = 8.40%, dim = 18 variáveis
# Zona 'Cu ka': VE = 97.03%, dim = 20 variáveis
# Zona 'Zn ka': VE = 20.69%, dim = 21 variáveis
# Zona 'Cu kb': VE = 63.49%, dim = 19 variáveis
# Zona 'Zn kb': VE = 5.72%, dim = 30 variáveis
# Zona 'background3': VE = 2.51%, dim = 451 variáveis
# Zona 'Ag ka scattering': VE = 27.73%, dim = 49 variáveis
#
# Scores DataFrame shape: (284, 15)

# %%
y_pred = svm_model[4]['SVC'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(svm_model[4]['SVC'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graphv3_pca(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 110
# Removida: Ca ka > -21.19 -> Ca ka > -26.11 (50.0104) | Mantida: Ca ka > -26.11 -> Ca ka > -21.19 (77.4220)
# Removida: Ti ka <= 19.85 -> Fe kb > -7.02 (16.5984) | Mantida: Fe kb > -7.02 -> Ti ka <= 19.85 (19.9912)
# Removida: Ti ka <= 19.85 -> Ca ka > -6.65 (16.4342) | Mantida: Ca ka > -6.65 -> Ti ka <= 19.85 (70.1926)
# Removida: Fe kb > -7.41 -> Ti ka > -28.53 (14.3517) | Mantida: Ti ka > -28.53 -> Fe kb > -7.41 (26.7660)
# Removida: Ti ka <= 9.34 -> Fe kb > -7.41 (18.4659) | Mantida: Fe kb > -7.41 -> Ti ka <= 9.34 (26.1398)
# Removida: Ti ka <= 9.34 -> Ti ka > -28.53 (12.9898) | Mantida: Ti ka > -28.53 -> Ti ka <= 9.34 (33.5222)
# Removida: Ca kb > -6.07 -> Ca kb > -8.59 (15.4890) | Mantida: Ca kb > -8.59 -> Ca kb > -6.07 (23.9201)
# Removida: Cu ka > -9.68 -> Cu ka > -10.68 (6.6036) | Mantida: Cu ka > -10.68 -> Cu ka > -9.68 (29.4412)
# Removida: Ti kb <= 6.95 -> Ca kb > -2.67 (7.0765) | Mantida: Ca kb > -2.67 -> Ti kb <= 6.95 (13.8031)
# Removida: Ca kb > -2.67 -> Cu ka > -8.43 (5.1336) | Mantida: Cu ka > -8.43 -> Ca kb > -2.67 (9.7044)
# Removida: Ti kb > -10.26 -> Ca kb > -2.67 (2.2509) | Mantida: Ca kb > -2.67 -> Ti kb > -10.26 (5.1151)
# Removida: Ti kb <= 6.95 -> Cu ka > -8.43 (2.3320) | Mantida: Cu ka > -8.43 -> Ti kb <= 6.95 (9.0209)
# Removida: Ti kb > -10.26 -> Cu ka > -8.43 (2.1173) | Mantida: Cu ka > -8.43 -> Ti kb > -10.26 (5.3561)
# Removida: Cu ka > -8.43 -> Ca ka <= 33.38 (2.4916) | Mantida: Ca ka <= 33.38 -> Cu ka > -8.43 (2.7922)
# Removida: Ti kb > -10.26 -> Ca ka <= 33.38 (4.2074) | Mantida: Ca ka <= 33.38 -> Ti kb > -10.26 (7.8706)
# Removida: Ti kb <= 2.45 -> Ca ka <= 33.38 (5.4007) | Mantida: Ca ka <= 33.38 -> Ti kb <= 2.45 (7.3205)
# Removida: Cu kb > -2.30 -> Ti ka <= -4.69 (0.7352) | Mantida: Ti ka <= -4.69 -> Cu kb > -2.30 (4.9014)
# Removida: Ag ka scattering <= 3.49 -> Cu kb > -2.30 (0.2853) | Mantida: Cu kb > -2.30 -> Ag ka scattering <= 3.49 (1.9806)
# Removida: Cu kb > -1.61 -> Cu kb > -2.30 (1.4394) | Mantida: Cu kb > -2.30 -> Cu kb > -1.61 (1.9598)
# Removida: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.5480) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.1837)
# Removida: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.2970) | Mantida: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (1.0283)
# Removida: Ag ka scattering <= -0.18 -> Cu kb > -2.88 (0.2547) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= -0.18 (1.1944)
# Removida: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.2740) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (0.5245)
# Removida: Cu kb > -2.88 -> Ca kb <= 12.61 (1.2021) | Mantida: Ca kb <= 12.61 -> Cu kb > -2.88 (1.6435)
# Removida: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.2414) | Mantida: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (0.8357)
# Removida: Ag ka scattering <= -0.18 -> Cu kb > -1.61 (0.2544) | Mantida: Cu kb > -1.61 -> Ag ka scattering <= -0.18 (1.2620)
# Removida: Ca ka <= -6.65 -> Ag ka scattering <= 1.67 (0.7944) | Mantida: Ag ka scattering <= 1.67 -> Ca ka <= -6.65 (1.1609)
# Removida: Ag ka scattering <= 1.67 -> Cu kb > -1.61 (0.2363) | Mantida: Cu kb > -1.61 -> Ag ka scattering <= 1.67 (1.1985)
# Removida: Cu kb > -1.61 -> Ca ka <= -6.65 (0.5304) | Mantida: Ca ka <= -6.65 -> Cu kb > -1.61 (0.8651)
# Removida: Ca ka <= -6.65 -> Ca kb <= 12.61 (0.7718) | Mantida: Ca kb <= 12.61 -> Ca ka <= -6.65 (1.5494)
# Removida: background3 <= 1.29 -> Ca kb <= 12.61 (0.0158) | Mantida: Ca kb <= 12.61 -> background3 <= 1.29 (1.9442)
# Removida: background3 <= 2.86 -> background3 <= 1.29 (0.0141) | Mantida: background3 <= 1.29 -> background3 <= 2.86 (0.0737)
# Removida: background3 <= -0.30 -> background3 <= 2.86 (0.0407) | Mantida: background3 <= 2.86 -> background3 <= -0.30 (0.0842)
# Removida: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.3283) | Mantida: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (1.6251)
# Removida: Ag ka scattering > -0.18 -> Ti kb <= -2.91 (0.0960) | Mantida: Ti kb <= -2.91 -> Ag ka scattering > -0.18 (0.8664)
# Removida: Ca kb <= -2.67 -> Ag ka scattering > -0.18 (0.2689) | Mantida: Ag ka scattering > -0.18 -> Ca kb <= -2.67 (0.3449)
# Removida: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.0631) | Mantida: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.3450)
# Removida: Zn ka > -1.75 -> Ca kb <= -2.67 (0.1157) | Mantida: Ca kb <= -2.67 -> Zn ka > -1.75 (0.8053)
# Removida: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.2513) | Mantida: Ca kb <= -2.67 -> Cu ka <= -3.28 (1.2391)
# Removida: Zn ka > -1.75 -> Cu ka <= -3.28 (0.1697) | Mantida: Cu ka <= -3.28 -> Zn ka > -1.75 (0.2586)
# Removida: background1 <= 2.08 -> Zn ka > -1.75 (0.0302) | Mantida: Zn ka > -1.75 -> background1 <= 2.08 (0.0534)
# Removida: Zn ka <= 1.38 -> Cu ka <= -3.28 (0.0433) | Mantida: Cu ka <= -3.28 -> Zn ka <= 1.38 (0.2414)
# Removida: Zn ka > -0.78 -> Cu ka <= -3.28 (0.0557) | Mantida: Cu ka <= -3.28 -> Zn ka > -0.78 (0.7702)
# Removida: background1 <= 2.08 -> Zn ka <= 1.38 (0.0220) | Mantida: Zn ka <= 1.38 -> background1 <= 2.08 (0.0913)
# Removida: Zn ka <= 1.38 -> Ca ka <= -21.19 (0.0470) | Mantida: Ca ka <= -21.19 -> Zn ka <= 1.38 (0.4189)
# Removida: Zn ka <= 1.38 -> Ti ka > -4.69 (0.1264) | Mantida: Ti ka > -4.69 -> Zn ka <= 1.38 (0.1921)
# Removida: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.0409) | Mantida: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.1126)
# Removida: background1 <= 2.08 -> Ca ka <= -21.19 (0.0259) | Mantida: Ca ka <= -21.19 -> background1 <= 2.08 (0.2233)
# Removida: Ag ka scattering > 1.67 -> background1 <= 2.08 (0.0542) | Mantida: background1 <= 2.08 -> Ag ka scattering > 1.67 (0.1278)
# Removida: Ca ka <= -21.19 -> Ti ka > -4.69 (0.1929) | Mantida: Ti ka > -4.69 -> Ca ka <= -21.19 (0.3627)
# Removida: Ag ka scattering > 1.67 -> Zn ka > -0.78 (0.0514) | Mantida: Zn ka > -0.78 -> Ag ka scattering > 1.67 (0.0965)
# Removida: Ag ka scattering > 1.67 -> Ti ka > -4.69 (0.0966) | Mantida: Ti ka > -4.69 -> Ag ka scattering > 1.67 (0.3667)
# Removida: background3 > -2.55 -> Ti ka > -4.69 (0.0032) | Mantida: Ti ka > -4.69 -> background3 > -2.55 (0.3480)
# Removida: background3 > -2.55 -> background1 <= -0.11 (0.0115) | Mantida: background1 <= -0.11 -> background3 > -2.55 (0.0166)
# Removida: background3 > -2.55 -> Zn ka <= 0.08 (0.0062) | Mantida: Zn ka <= 0.08 -> background3 > -2.55 (0.0254)
# Removida: background3 > -2.55 -> Ti kb > -2.91 (0.0035) | Mantida: Ti kb > -2.91 -> background3 > -2.55 (0.1134)
# Removida: background1 <= -0.11 -> Zn ka <= 0.08 (0.0180) | Mantida: Zn ka <= 0.08 -> background1 <= -0.11 (0.0232)
# Removida: background1 <= -0.11 -> Zn ka > 0.08 (0.0131) | Mantida: Zn ka > 0.08 -> background1 <= -0.11 (0.0392)
# Removida: background3 > 1.29 -> background1 <= -0.11 (0.0032) | Mantida: background1 <= -0.11 -> background3 > 1.29 (0.0284)
# Removida: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0047) | Mantida: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0217)
# Removida: Zn ka <= -0.78 -> Cu ka <= -8.43 (0.0420) | Mantida: Cu ka <= -8.43 -> Zn ka <= -0.78 (0.0866)
# Removida: Ar ka + Ag L <= 1.07 -> Zn ka <= -0.78 (0.0069) | Mantida: Zn ka <= -0.78 -> Ar ka + Ag L <= 1.07 (0.0205)
# Removida: Ar ka + Ag L <= 0.28 -> Ca kb <= -6.07 (0.0117) | Mantida: Ca kb <= -6.07 -> Ar ka + Ag L <= 0.28 (0.3158)
# Removida: Ar ka + Ag L <= 0.28 -> background1 > -1.87 (0.0051) | Mantida: background1 > -1.87 -> Ar ka + Ag L <= 0.28 (0.0090)
# Removida: Ar ka + Ag L <= 0.28 -> Cu ka <= -8.43 (0.0069) | Mantida: Cu ka <= -8.43 -> Ar ka + Ag L <= 0.28 (0.2651)
# Removida: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0047) | Mantida: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0061)
# Removida: background3 > 1.29 -> Ar ka + Ag L <= 1.07 (0.0027) | Mantida: Ar ka + Ag L <= 1.07 -> background3 > 1.29 (0.0057)
# Removida: Ar ka + Ag L <= 1.07 -> background2 <= -0.37 (0.0039) | Mantida: background2 <= -0.37 -> Ar ka + Ag L <= 1.07 (0.0121)
# Removida: background3 > -0.30 -> background1 > -0.11 (0.0018) | Mantida: background1 > -0.11 -> background3 > -0.30 (0.0097)
# Removida: Zn kb > 0.29 -> background1 > -0.11 (0.0048) | Mantida: background1 > -0.11 -> Zn kb > 0.29 (0.0078)
# Removida: background1 > -0.11 -> Zn ka > 0.08 (0.0076) | Mantida: Zn ka > 0.08 -> background1 > -0.11 (0.0214)
# Removida: background1 > -0.11 -> background2 <= -0.37 (0.0080) | Mantida: background2 <= -0.37 -> background1 > -0.11 (0.0101)
# Removida: Ar ka + Ag L <= -0.29 -> background1 > -0.11 (0.0041) | Mantida: background1 > -0.11 -> Ar ka + Ag L <= -0.29 (0.0085)
# Removida: Ar ka + Ag L > -1.05 -> background1 <= -1.03 (0.0036) | Mantida: background1 <= -1.03 -> Ar ka + Ag L > -1.05 (0.0100)
# Removida: background1 <= -1.03 -> Zn ka > 0.08 (0.0118) | Mantida: Zn ka > 0.08 -> background1 <= -1.03 (0.0145)
# Removida: background3 > 1.29 -> Ti kb > -2.91 (0.0021) | Mantida: Ti kb > -2.91 -> background3 > 1.29 (0.1151)
# Removida: background2 <= -0.37 -> Ti kb > -2.91 (0.0066) | Mantida: Ti kb > -2.91 -> background2 <= -0.37 (0.0588)
# Removida: background3 > -0.30 -> Ti kb > -2.91 (0.0019) | Mantida: Ti kb > -2.91 -> background3 > -0.30 (0.0590)
# Removida: Ar ka + Ag L <= -0.29 -> Zn kb > 0.29 (0.0038) | Mantida: Zn kb > 0.29 -> Ar ka + Ag L <= -0.29 (0.0095)
# Removida: background3 > -0.30 -> Ar ka + Ag L <= -0.29 (0.0020) | Mantida: Ar ka + Ag L <= -0.29 -> background3 > -0.30 (0.0047)
# Removida: background3 > -0.30 -> background2 <= -0.37 (0.0018) | Mantida: background2 <= -0.37 -> background3 > -0.30 (0.0057)
# Removida: Ar ka + Ag L > -1.05 -> background2 <= -0.37 (0.0035) | Mantida: background2 <= -0.37 -> Ar ka + Ag L > -1.05 (0.0054)
# Removida: background3 > -0.30 -> Fe ka <= -22.90 (0.0013) | Mantida: Fe ka <= -22.90 -> background3 > -0.30 (0.0516)
# Removida: Zn kb > -0.29 -> Ar ka + Ag L > -1.05 (0.0024) | Mantida: Ar ka + Ag L > -1.05 -> Zn kb > -0.29 (0.0038)
# Removida: Ar ka + Ag L > -1.05 -> Zn ka > 0.08 (0.0040) | Mantida: Zn ka > 0.08 -> Ar ka + Ag L > -1.05 (0.0128)
# Removida: Ar ka + Ag L > -1.05 -> Cu kb <= 0.18 (0.0024) | Mantida: Cu kb <= 0.18 -> Ar ka + Ag L > -1.05 (0.0461)
# Removida: Ar ka + Ag L > 0.28 -> background1 > -1.03 (0.0020) | Mantida: background1 > -1.03 -> Ar ka + Ag L > 0.28 (0.0042)
# Removida: background2 > -0.92 -> Fe ka <= -23.71 (0.0048) | Mantida: Fe ka <= -23.71 -> background2 > -0.92 (0.0327)
# Removida: Zn kb > -1.05 -> Fe ka <= -23.71 (0.0019) | Mantida: Fe ka <= -23.71 -> Zn kb > -1.05 (0.0553)
# Removida: Fe ka <= -22.90 -> Fe ka <= -23.71 (0.0525) | Mantida: Fe ka <= -23.71 -> Fe ka <= -22.90 (0.0956)
# Removida: Cu kb <= 0.18 -> Fe ka <= -23.71 (0.0369) | Mantida: Fe ka <= -23.71 -> Cu kb <= 0.18 (0.0522)
# Removida: Fe ka <= -22.90 -> Cu kb <= 0.18 (0.0430) | Mantida: Cu kb <= 0.18 -> Fe ka <= -22.90 (0.0571)
# Removida: background2 <= 0.98 -> Fe ka <= -22.90 (0.0044) | Mantida: Fe ka <= -22.90 -> background2 <= 0.98 (0.0287)
# Removida: Zn kb > -0.29 -> Fe ka <= -22.90 (0.0014) | Mantida: Fe ka <= -22.90 -> Zn kb > -0.29 (0.0519)
# Removida: background2 > 0.27 -> Ti ka > 9.34 (0.0021) | Mantida: Ti ka > 9.34 -> background2 > 0.27 (0.0236)
# Removida: background2 > 0.27 -> Cu ka <= -9.68 (0.0042) | Mantida: Cu ka <= -9.68 -> background2 > 0.27 (0.0395)
# Removida: background2 > 0.27 -> Fe kb <= -7.02 (0.0033) | Mantida: Fe kb <= -7.02 -> background2 > 0.27 (0.0287)
# Removida: Zn ka > 0.08 -> Cu ka <= -9.68 (0.0123) | Mantida: Cu ka <= -9.68 -> Zn ka > 0.08 (0.0566)
# Removida: Ar ka + Ag L > 0.28 -> Fe ka <= -24.15 (0.0026) | Mantida: Fe ka <= -24.15 -> Ar ka + Ag L > 0.28 (0.0340)
# Removida: Zn kb > -0.29 -> background2 <= 0.98 (0.0034) | Mantida: background2 <= 0.98 -> Zn kb > -0.29 (0.0042)
# Removida: background2 > -0.92 -> Fe ka <= -24.15 (0.0075) | Mantida: Fe ka <= -24.15 -> background2 > -0.92 (0.1085)
# Removida: background2 <= 0.27 -> background2 > -0.92 (0.0014) | Mantida: background2 > -0.92 -> background2 <= 0.27 (0.0033)
# Removida: Fe kb <= -7.02 -> Fe kb <= -6.37 (0.0275) | Mantida: Fe kb <= -6.37 -> Fe kb <= -7.02 (0.0572)
# Removida: Ti kb > 2.45 -> Fe kb <= -7.02 (0.0165) | Mantida: Fe kb <= -7.02 -> Ti kb > 2.45 (0.0186)
# Removida: Zn kb > -0.29 -> Ti ka > 9.34 (0.0028) | Mantida: Ti ka > 9.34 -> Zn kb > -0.29 (0.0471)
# Removida: Fe kb <= -6.37 -> Ti ka > 9.34 (0.0240) | Mantida: Ti ka > 9.34 -> Fe kb <= -6.37 (0.0470)
# Removida: Ti kb > 2.45 -> Cu kb <= -2.30 (0.0125) | Mantida: Cu kb <= -2.30 -> Ti kb > 2.45 (0.0127)
# Removida: Ar ka + Ag L > -0.29 -> Ti kb > 2.45 (0.0009) | Mantida: Ti kb > 2.45 -> Ar ka + Ag L > -0.29 (0.0399)
# Removida: Ti kb > 2.45 -> Fe kb <= -6.37 (0.0154) | Mantida: Fe kb <= -6.37 -> Ti kb > 2.45 (0.0172)
# Removida: Ar ka + Ag L > -0.29 -> Zn kb <= 0.29 (0.0008) | Mantida: Zn kb <= 0.29 -> Ar ka + Ag L > -0.29 (0.0020)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 540 | Removidas: 110
# Nós predicados: 90
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 95
# Removida: Ca ka > -21.19 -> Ca ka > -26.11 (12.7375) | Mantida: Ca ka > -26.11 -> Ca ka > -21.19 (116.2140)
# Removida: Ti ka <= 19.85 -> Fe kb > -7.02 (8.1620) | Mantida: Fe kb > -7.02 -> Ti ka <= 19.85 (37.5774)
# Removida: Ti ka <= 19.85 -> Ca ka > -6.65 (32.8673) | Mantida: Ca ka > -6.65 -> Ti ka <= 19.85 (50.7748)
# Removida: Ti ka > -28.53 -> Fe kb > -7.41 (6.8446) | Mantida: Fe kb > -7.41 -> Ti ka > -28.53 (27.5856)
# Removida: Fe kb > -7.41 -> Ti ka <= 9.34 (6.2373) | Mantida: Ti ka <= 9.34 -> Fe kb > -7.41 (31.4686)
# Removida: Ca kb > -6.07 -> Fe kb > -7.79 (3.8859) | Mantida: Fe kb > -7.79 -> Ca kb > -6.07 (9.7669)
# Removida: Ca kb > -6.07 -> Ca kb > -8.59 (7.8948) | Mantida: Ca kb > -8.59 -> Ca kb > -6.07 (31.7377)
# Removida: Cu ka > -9.68 -> Cu ka > -10.68 (7.5187) | Mantida: Cu ka > -10.68 -> Cu ka > -9.68 (28.8776)
# Removida: Ca ka <= 33.38 -> Cu ka > -8.43 (2.9899) | Mantida: Cu ka > -8.43 -> Ca ka <= 33.38 (6.3731)
# Removida: Ti kb <= 6.95 -> Ca kb > -2.67 (4.6852) | Mantida: Ca kb > -2.67 -> Ti kb <= 6.95 (16.0285)
# Removida: Ca ka <= 33.38 -> Ti kb <= 6.95 (2.9870) | Mantida: Ti kb <= 6.95 -> Ca ka <= 33.38 (4.7263)
# Removida: Ca kb > -2.67 -> Ca ka <= 33.38 (2.6257) | Mantida: Ca ka <= 33.38 -> Ca kb > -2.67 (2.9504)
# Removida: Ca kb > -2.67 -> Ti kb > -10.26 (2.5784) | Mantida: Ti kb > -10.26 -> Ca kb > -2.67 (4.2583)
# Removida: Ca ka <= 33.38 -> Ti kb > -10.26 (8.0928) | Mantida: Ti kb > -10.26 -> Ca ka <= 33.38 (8.2811)
# Removida: Cu kb > -1.61 -> Cu kb > -2.30 (0.7215) | Mantida: Cu kb > -2.30 -> Cu kb > -1.61 (2.8337)
# Removida: Ag ka scattering <= 3.49 -> Cu kb > -2.30 (0.5785) | Mantida: Cu kb > -2.30 -> Ag ka scattering <= 3.49 (1.9665)
# Removida: Cu kb > -2.30 -> Ti ka <= -4.69 (0.6245) | Mantida: Ti ka <= -4.69 -> Cu kb > -2.30 (2.3794)
# Removida: Ag ka scattering <= 3.49 -> Cu kb > -1.61 (0.2668) | Mantida: Cu kb > -1.61 -> Ag ka scattering <= 3.49 (1.3741)
# Removida: Cu kb > -2.88 -> Ca kb <= 12.61 (1.1757) | Mantida: Ca kb <= 12.61 -> Cu kb > -2.88 (2.6730)
# Removida: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.5291) | Mantida: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (1.7555)
# Removida: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.7366) | Mantida: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (0.8205)
# Removida: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.5292) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.2362)
# Removida: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.5150) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (1.1302)
# Removida: Cu kb > -2.88 -> Ti ka <= -4.69 (0.6202) | Mantida: Ti ka <= -4.69 -> Cu kb > -2.88 (0.9273)
# Removida: Ag ka scattering <= -0.18 -> Cu kb > -2.88 (0.2790) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= -0.18 (0.5830)
# Removida: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.5433) | Mantida: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (0.5445)
# Removida: Ag ka scattering <= 3.49 -> Ti ka <= -4.69 (0.5587) | Mantida: Ti ka <= -4.69 -> Ag ka scattering <= 3.49 (1.2865)
# Removida: Ca ka <= -6.65 -> Ti ka <= -4.69 (0.6884) | Mantida: Ti ka <= -4.69 -> Ca ka <= -6.65 (0.7756)
# Removida: background3 <= 2.86 -> background3 <= 1.29 (0.0312) | Mantida: background3 <= 1.29 -> background3 <= 2.86 (0.0854)
# Removida: background3 <= -0.30 -> background3 <= 2.86 (0.0293) | Mantida: background3 <= 2.86 -> background3 <= -0.30 (0.0802)
# Removida: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (0.3180) | Mantida: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.8418)
# Removida: Zn ka > -1.75 -> Cu ka <= -3.28 (0.1678) | Mantida: Cu ka <= -3.28 -> Zn ka > -1.75 (0.4943)
# Removida: Zn ka > -1.75 -> Ca kb <= -2.67 (0.3036) | Mantida: Ca kb <= -2.67 -> Zn ka > -1.75 (0.7430)
# Removida: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.2449) | Mantida: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.4866)
# Removida: Zn ka > -0.78 -> Cu ka <= -3.28 (0.1010) | Mantida: Cu ka <= -3.28 -> Zn ka > -0.78 (0.7487)
# Removida: Zn ka <= 1.38 -> Cu ka <= -3.28 (0.0428) | Mantida: Cu ka <= -3.28 -> Zn ka <= 1.38 (0.2295)
# Removida: Zn ka <= 1.38 -> Zn ka > -0.78 (0.0474) | Mantida: Zn ka > -0.78 -> Zn ka <= 1.38 (0.1466)
# Removida: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.0554) | Mantida: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.0867)
# Removida: background1 <= 2.08 -> Zn ka <= 1.38 (0.0765) | Mantida: Zn ka <= 1.38 -> background1 <= 2.08 (0.1377)
# Removida: Zn ka > -0.78 -> Ti ka > -4.69 (0.0462) | Mantida: Ti ka > -4.69 -> Zn ka > -0.78 (0.1873)
# Removida: background1 <= 2.08 -> Zn ka > -0.78 (0.0283) | Mantida: Zn ka > -0.78 -> background1 <= 2.08 (0.0504)
# Removida: Ca ka <= -21.19 -> Ti ka > -4.69 (0.2003) | Mantida: Ti ka > -4.69 -> Ca ka <= -21.19 (0.3819)
# Removida: background1 <= 2.08 -> Ti ka > -4.69 (0.0218) | Mantida: Ti ka > -4.69 -> background1 <= 2.08 (0.1842)
# Removida: background1 <= -0.11 -> Ti ka > -4.69 (0.0162) | Mantida: Ti ka > -4.69 -> background1 <= -0.11 (0.1664)
# Removida: background1 <= 2.08 -> Ca ka <= -21.19 (0.1001) | Mantida: Ca ka <= -21.19 -> background1 <= 2.08 (0.6074)
# Removida: background3 > -2.55 -> Ag ka scattering > 1.67 (0.0091) | Mantida: Ag ka scattering > 1.67 -> background3 > -2.55 (0.0532)
# Removida: background3 > -2.55 -> Ti kb > -2.91 (0.0104) | Mantida: Ti kb > -2.91 -> background3 > -2.55 (0.1219)
# Removida: background3 > -2.55 -> Zn ka <= 0.08 (0.0036) | Mantida: Zn ka <= 0.08 -> background3 > -2.55 (0.0293)
# Removida: background1 <= -0.11 -> Ti kb > -2.91 (0.0176) | Mantida: Ti kb > -2.91 -> background1 <= -0.11 (0.0919)
# Removida: background1 > -1.87 -> Ti kb > -2.91 (0.0207) | Mantida: Ti kb > -2.91 -> background1 > -1.87 (0.1092)
# Removida: Zn ka <= 0.08 -> Cu ka <= -8.43 (0.0428) | Mantida: Cu ka <= -8.43 -> Zn ka <= 0.08 (0.0952)
# Removida: background1 <= -0.11 -> Zn ka <= 0.08 (0.0191) | Mantida: Zn ka <= 0.08 -> background1 <= -0.11 (0.0270)
# Removida: background1 <= -0.11 -> Zn ka <= -0.78 (0.0155) | Mantida: Zn ka <= -0.78 -> background1 <= -0.11 (0.0237)
# Removida: background3 > -0.30 -> Zn ka <= -0.78 (0.0021) | Mantida: Zn ka <= -0.78 -> background3 > -0.30 (0.0159)
# Removida: Zn ka <= -0.78 -> Cu ka <= -8.43 (0.0265) | Mantida: Cu ka <= -8.43 -> Zn ka <= -0.78 (0.0832)
# Removida: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0062) | Mantida: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0212)
# Removida: background3 > 1.29 -> background1 <= -0.11 (0.0033) | Mantida: background1 <= -0.11 -> background3 > 1.29 (0.0137)
# Removida: background3 > 1.29 -> Ca kb <= -6.07 (0.0085) | Mantida: Ca kb <= -6.07 -> background3 > 1.29 (0.1978)
# Removida: Ar ka + Ag L > 0.28 -> background1 <= -1.03 (0.0034) | Mantida: background1 <= -1.03 -> Ar ka + Ag L > 0.28 (0.0080)
# Removida: background1 <= -1.03 -> Zn ka > 0.08 (0.0070) | Mantida: Zn ka > 0.08 -> background1 <= -1.03 (0.0164)
# Removida: Ar ka + Ag L <= -0.29 -> background1 <= -1.03 (0.0042) | Mantida: background1 <= -1.03 -> Ar ka + Ag L <= -0.29 (0.0102)
# Removida: Ca kb <= -6.07 -> Cu ka <= -8.43 (0.1788) | Mantida: Cu ka <= -8.43 -> Ca kb <= -6.07 (0.2151)
# Removida: background3 > -0.30 -> Ar ka + Ag L > -1.05 (0.0019) | Mantida: Ar ka + Ag L > -1.05 -> background3 > -0.30 (0.0050)
# Removida: background3 > -0.30 -> background1 > -1.87 (0.0017) | Mantida: background1 > -1.87 -> background3 > -0.30 (0.0110)
# Removida: Cu kb <= 0.18 -> Cu ka <= -8.43 (0.0446) | Mantida: Cu ka <= -8.43 -> Cu kb <= 0.18 (0.0868)
# Removida: Zn kb > -0.29 -> Cu kb <= 0.18 (0.0026) | Mantida: Cu kb <= 0.18 -> Zn kb > -0.29 (0.0254)
# Removida: background2 <= -0.37 -> Fe ka <= -23.71 (0.0051) | Mantida: Fe ka <= -23.71 -> background2 <= -0.37 (0.0508)
# Removida: Ar ka + Ag L <= -0.29 -> Zn kb > 0.29 (0.0045) | Mantida: Zn kb > 0.29 -> Ar ka + Ag L <= -0.29 (0.0062)
# Removida: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L > -1.05 (0.0040) | Mantida: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= 1.07 (0.0044)
# Removida: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0039) | Mantida: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0099)
# Removida: Zn ka > 0.08 -> Fe ka <= -23.71 (0.0112) | Mantida: Fe ka <= -23.71 -> Zn ka > 0.08 (0.0568)
# Removida: background1 > -1.87 -> Fe ka <= -24.15 (0.0046) | Mantida: Fe ka <= -24.15 -> background1 > -1.87 (0.0503)
# Removida: Fe ka <= -24.15 -> Cu ka <= -9.68 (0.0461) | Mantida: Cu ka <= -9.68 -> Fe ka <= -24.15 (0.0743)
# Removida: Zn kb > -0.29 -> background1 > -1.87 (0.0023) | Mantida: background1 > -1.87 -> Zn kb > -0.29 (0.0051)
# Removida: Zn kb > -0.29 -> Cu ka <= -9.68 (0.0023) | Mantida: Cu ka <= -9.68 -> Zn kb > -0.29 (0.0485)
# Removida: background1 > -1.03 -> Cu ka <= -9.68 (0.0132) | Mantida: Cu ka <= -9.68 -> background1 > -1.03 (0.0543)
# Removida: Zn kb > -0.29 -> background2 > 0.27 (0.0014) | Mantida: background2 > 0.27 -> Zn kb > -0.29 (0.0036)
# Removida: Zn kb > -0.29 -> background2 <= 0.98 (0.0015) | Mantida: background2 <= 0.98 -> Zn kb > -0.29 (0.0030)
# Removida: Zn kb > -0.29 -> background2 > -0.92 (0.0021) | Mantida: background2 > -0.92 -> Zn kb > -0.29 (0.0038)
# Removida: Ar ka + Ag L <= -0.29 -> background1 > -1.03 (0.0061) | Mantida: background1 > -1.03 -> Ar ka + Ag L <= -0.29 (0.0067)
# Removida: background2 > 0.27 -> Fe kb <= -7.02 (0.0025) | Mantida: Fe kb <= -7.02 -> background2 > 0.27 (0.0231)
# Removida: Ar ka + Ag L > 0.28 -> Zn ka > 0.08 (0.0034) | Mantida: Zn ka > 0.08 -> Ar ka + Ag L > 0.28 (0.0113)
# Removida: background2 > -0.37 -> Cu kb <= -1.61 (0.0021) | Mantida: Cu kb <= -1.61 -> background2 > -0.37 (0.0202)
# Removida: Zn kb > -1.05 -> Fe ka <= -22.90 (0.0019) | Mantida: Fe ka <= -22.90 -> Zn kb > -1.05 (0.0304)
# Removida: Ar ka + Ag L > -0.29 -> background2 <= 0.98 (0.0018) | Mantida: background2 <= 0.98 -> Ar ka + Ag L > -0.29 (0.0019)
# Removida: Ar ka + Ag L > -0.29 -> Ti kb > 2.45 (0.0011) | Mantida: Ti kb > 2.45 -> Ar ka + Ag L > -0.29 (0.0143)
# Removida: Zn kb > -1.05 -> background2 <= 0.98 (0.0013) | Mantida: background2 <= 0.98 -> Zn kb > -1.05 (0.0019)
# Removida: Zn kb > -1.05 -> Fe kb <= -6.37 (0.0009) | Mantida: Fe kb <= -6.37 -> Zn kb > -1.05 (0.0228)
# Removida: Cu kb <= -2.30 -> Ti ka > 9.34 (0.0172) | Mantida: Ti ka > 9.34 -> Cu kb <= -2.30 (0.0211)
# Removida: background2 <= 0.27 -> Ti ka > 9.34 (0.0025) | Mantida: Ti ka > 9.34 -> background2 <= 0.27 (0.0253)
# Removida: background2 <= 0.27 -> Fe kb <= -6.37 (0.0045) | Mantida: Fe kb <= -6.37 -> background2 <= 0.27 (0.0138)
# Removida: Ti ka > 9.34 -> Fe kb <= -7.02 (0.0238) | Mantida: Fe kb <= -7.02 -> Ti ka > 9.34 (0.0263)
# Removida: background2 > -0.37 -> Fe kb <= -7.02 (0.0030) | Mantida: Fe kb <= -7.02 -> background2 > -0.37 (0.0236)
# Removida: background2 > -0.37 -> Ti kb > 2.45 (0.0014) | Mantida: Ti kb > 2.45 -> background2 > -0.37 (0.0149)
# Removida: Fe kb <= -6.37 -> Ti kb > 2.45 (0.0333) | Mantida: Ti kb > 2.45 -> Fe kb <= -6.37 (0.0424)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 505 | Removidas: 95
# Nós predicados: 90
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 94
# Removida: Ca ka > -21.19 -> Ca ka > -26.11 (49.9866) | Mantida: Ca ka > -26.11 -> Ca ka > -21.19 (77.7398)
# Removida: Ca ka > -6.65 -> Fe kb > -7.02 (17.6890) | Mantida: Fe kb > -7.02 -> Ca ka > -6.65 (58.3643)
# Removida: Ti ka <= 19.85 -> Ca ka > -6.65 (16.5139) | Mantida: Ca ka > -6.65 -> Ti ka <= 19.85 (53.1957)
# Removida: Ti ka > -28.53 -> Fe kb > -7.41 (12.2906) | Mantida: Fe kb > -7.41 -> Ti ka > -28.53 (34.7023)
# Removida: Ti ka <= 9.34 -> Ti ka > -28.53 (12.6875) | Mantida: Ti ka > -28.53 -> Ti ka <= 9.34 (46.1464)
# Removida: Ca kb > -8.59 -> Fe kb > -7.79 (4.0440) | Mantida: Fe kb > -7.79 -> Ca kb > -8.59 (10.4535)
# Removida: Ca kb > -8.59 -> Ca kb > -6.07 (8.0261) | Mantida: Ca kb > -6.07 -> Ca kb > -8.59 (31.1828)
# Removida: Ti kb <= 6.95 -> Ca kb > -2.67 (7.0326) | Mantida: Ca kb > -2.67 -> Ti kb <= 6.95 (16.6711)
# Removida: Cu ka > -8.43 -> Ti kb <= 6.95 (9.1360) | Mantida: Ti kb <= 6.95 -> Cu ka > -8.43 (9.3839)
# Removida: Cu ka > -8.43 -> Ca ka <= 33.38 (5.4408) | Mantida: Ca ka <= 33.38 -> Cu ka > -8.43 (7.5012)
# Removida: Ti kb > -10.26 -> Ca ka <= 33.38 (8.0992) | Mantida: Ca ka <= 33.38 -> Ti kb > -10.26 (10.7937)
# Removida: Cu kb > -1.61 -> Ti ka <= -4.69 (0.6791) | Mantida: Ti ka <= -4.69 -> Cu kb > -1.61 (2.1209)
# Removida: Ag ka scattering <= 3.49 -> Ti ka <= -4.69 (0.2531) | Mantida: Ti ka <= -4.69 -> Ag ka scattering <= 3.49 (1.0186)
# Removida: Cu kb > -1.61 -> Cu kb > -2.30 (0.7022) | Mantida: Cu kb > -2.30 -> Cu kb > -1.61 (1.3577)
# Removida: Ag ka scattering <= -0.18 -> Cu kb > -2.30 (0.2602) | Mantida: Cu kb > -2.30 -> Ag ka scattering <= -0.18 (1.9554)
# Removida: Ag ka scattering <= -0.18 -> Cu kb > -1.61 (0.8014) | Mantida: Cu kb > -1.61 -> Ag ka scattering <= -0.18 (1.2801)
# Removida: Cu kb > -1.61 -> Cu kb > -2.88 (0.5722) | Mantida: Cu kb > -2.88 -> Cu kb > -1.61 (0.5870)
# Removida: Ag ka scattering <= 3.49 -> Cu kb > -1.61 (0.2662) | Mantida: Cu kb > -1.61 -> Ag ka scattering <= 3.49 (1.2095)
# Removida: Ag ka scattering <= -0.18 -> Cu kb > -2.88 (0.2595) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= -0.18 (0.5646)
# Removida: Cu kb > -2.88 -> Ca kb <= 12.61 (1.1225) | Mantida: Ca kb <= 12.61 -> Cu kb > -2.88 (2.3531)
# Removida: Ag ka scattering <= 3.49 -> Ca kb <= 12.61 (0.5408) | Mantida: Ca kb <= 12.61 -> Ag ka scattering <= 3.49 (1.7220)
# Removida: Ca ka <= -6.65 -> Ca kb <= 12.61 (0.8036) | Mantida: Ca kb <= 12.61 -> Ca ka <= -6.65 (1.4993)
# Removida: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.2426) | Mantida: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (0.8630)
# Removida: Ag ka scattering <= 3.49 -> Cu kb > -2.88 (0.2515) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= 3.49 (1.1241)
# Removida: background3 <= 2.86 -> background3 <= 1.29 (0.0300) | Mantida: background3 <= 1.29 -> background3 <= 2.86 (0.0746)
# Removida: background3 <= -0.30 -> background3 <= 2.86 (0.0408) | Mantida: background3 <= 2.86 -> background3 <= -0.30 (0.0582)
# Removida: background3 <= -0.30 -> Ti kb <= -2.91 (0.0656) | Mantida: Ti kb <= -2.91 -> background3 <= -0.30 (0.3587)
# Removida: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.2031) | Mantida: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (1.9286)
# Removida: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.0645) | Mantida: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.4170)
# Removida: Ag ka scattering > -0.18 -> Ca kb <= -2.67 (0.2412) | Mantida: Ca kb <= -2.67 -> Ag ka scattering > -0.18 (0.5225)
# Removida: Zn ka > -0.78 -> Zn ka > -1.75 (0.0660) | Mantida: Zn ka > -1.75 -> Zn ka > -0.78 (0.1362)
# Removida: Zn ka > -1.75 -> Ca kb <= -2.67 (0.0571) | Mantida: Ca kb <= -2.67 -> Zn ka > -1.75 (0.2587)
# Removida: Zn ka > -1.75 -> Cu ka <= -3.28 (0.2226) | Mantida: Cu ka <= -3.28 -> Zn ka > -1.75 (0.2245)
# Removida: Zn ka > -0.78 -> Ti ka > -4.69 (0.0465) | Mantida: Ti ka > -4.69 -> Zn ka > -0.78 (0.1796)
# Removida: Zn ka > -0.78 -> Zn ka <= 1.38 (0.0514) | Mantida: Zn ka <= 1.38 -> Zn ka > -0.78 (0.0928)
# Removida: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.4874) | Mantida: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.9678)
# Removida: background1 <= 2.08 -> Cu ka <= -3.28 (0.0301) | Mantida: Cu ka <= -3.28 -> background1 <= 2.08 (0.2420)
# Removida: Zn ka <= 1.38 -> Ca ka <= -21.19 (0.0921) | Mantida: Ca ka <= -21.19 -> Zn ka <= 1.38 (0.2112)
# Removida: background1 <= 2.08 -> Zn ka <= 1.38 (0.0238) | Mantida: Zn ka <= 1.38 -> background1 <= 2.08 (0.1350)
# Removida: Ag ka scattering > 1.67 -> Ca ka <= -21.19 (0.0531) | Mantida: Ca ka <= -21.19 -> Ag ka scattering > 1.67 (0.3611)
# Removida: Ca ka <= -21.19 -> Ti ka > -4.69 (0.1877) | Mantida: Ti ka > -4.69 -> Ca ka <= -21.19 (0.5231)
# Removida: background1 <= 2.08 -> Ca ka <= -21.19 (0.0486) | Mantida: Ca ka <= -21.19 -> background1 <= 2.08 (0.3995)
# Removida: background1 <= 2.08 -> Ag ka scattering > 1.67 (0.0470) | Mantida: Ag ka scattering > 1.67 -> background1 <= 2.08 (0.0557)
# Removida: Ag ka scattering > 1.67 -> Ti ka > -4.69 (0.0555) | Mantida: Ti ka > -4.69 -> Ag ka scattering > 1.67 (0.1945)
# Removida: background1 <= 2.08 -> Zn ka > 0.08 (0.0250) | Mantida: Zn ka > 0.08 -> background1 <= 2.08 (0.0386)
# Removida: background3 > -2.55 -> background1 <= 2.08 (0.0055) | Mantida: background1 <= 2.08 -> background3 > -2.55 (0.0231)
# Removida: background3 > -2.55 -> Ti ka > -4.69 (0.0045) | Mantida: Ti ka > -4.69 -> background3 > -2.55 (0.1610)
# Removida: background1 <= -0.11 -> Ti ka > -4.69 (0.0166) | Mantida: Ti ka > -4.69 -> background1 <= -0.11 (0.3728)
# Removida: background3 > -2.55 -> Ti kb > -2.91 (0.0142) | Mantida: Ti kb > -2.91 -> background3 > -2.55 (0.1153)
# Removida: background3 > -2.55 -> Zn ka <= 0.08 (0.0032) | Mantida: Zn ka <= 0.08 -> background3 > -2.55 (0.0283)
# Removida: background1 <= -0.11 -> Ti kb > -2.91 (0.0167) | Mantida: Ti kb > -2.91 -> background1 <= -0.11 (0.1096)
# Removida: Zn ka <= 0.08 -> background1 <= -0.11 (0.0261) | Mantida: background1 <= -0.11 -> Zn ka <= 0.08 (0.0298)
# Removida: background3 > 1.29 -> Zn ka <= 0.08 (0.0023) | Mantida: Zn ka <= 0.08 -> background3 > 1.29 (0.0228)
# Removida: background1 > -0.11 -> Zn ka <= 0.08 (0.0140) | Mantida: Zn ka <= 0.08 -> background1 > -0.11 (0.0192)
# Removida: background1 <= -0.11 -> background1 > -0.11 (0.0170) | Mantida: background1 > -0.11 -> background1 <= -0.11 (0.0176)
# Removida: Ar ka + Ag L <= 1.07 -> background3 > 1.29 (0.0055) | Mantida: background3 > 1.29 -> Ar ka + Ag L <= 1.07 (0.0056)
# Removida: background3 > 1.29 -> Zn kb > 0.29 (0.0025) | Mantida: Zn kb > 0.29 -> background3 > 1.29 (0.0037)
# Removida: background1 <= -1.03 -> Ca kb <= -6.07 (0.0244) | Mantida: Ca kb <= -6.07 -> background1 <= -1.03 (0.0921)
# Removida: background1 > -0.11 -> Ca kb <= -6.07 (0.0156) | Mantida: Ca kb <= -6.07 -> background1 > -0.11 (0.1073)
# Removida: background1 > -1.87 -> Ca kb <= -6.07 (0.0148) | Mantida: Ca kb <= -6.07 -> background1 > -1.87 (0.0978)
# Removida: Ar ka + Ag L <= -0.29 -> background1 <= -1.03 (0.0047) | Mantida: background1 <= -1.03 -> Ar ka + Ag L <= -0.29 (0.0086)
# Removida: Zn ka <= -0.78 -> Cu ka <= -8.43 (0.0200) | Mantida: Cu ka <= -8.43 -> Zn ka <= -0.78 (0.0840)
# Removida: Zn kb > 0.29 -> Zn ka <= -0.78 (0.0041) | Mantida: Zn ka <= -0.78 -> Zn kb > 0.29 (0.0158)
# Removida: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0046) | Mantida: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0207)
# Removida: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0055) | Mantida: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0057)
# Removida: Ar ka + Ag L > -1.05 -> Fe ka <= -22.90 (0.0028) | Mantida: Fe ka <= -22.90 -> Ar ka + Ag L > -1.05 (0.0468)
# Removida: Ar ka + Ag L > -1.05 -> Fe kb <= -7.02 (0.0026) | Mantida: Fe kb <= -7.02 -> Ar ka + Ag L > -1.05 (0.0457)
# Removida: background3 > -0.30 -> Zn kb > 0.29 (0.0039) | Mantida: Zn kb > 0.29 -> background3 > -0.30 (0.0050)
# Removida: background3 > -0.30 -> Ar ka + Ag L <= -0.29 (0.0027) | Mantida: Ar ka + Ag L <= -0.29 -> background3 > -0.30 (0.0041)
# Removida: Zn kb > 0.29 -> Cu ka <= -8.43 (0.0043) | Mantida: Cu ka <= -8.43 -> Zn kb > 0.29 (0.0849)
# Removida: Zn kb > 0.29 -> Ar ka + Ag L > 0.28 (0.0036) | Mantida: Ar ka + Ag L > 0.28 -> Zn kb > 0.29 (0.0043)
# Removida: background2 <= -0.37 -> Cu ka <= -8.43 (0.0072) | Mantida: Cu ka <= -8.43 -> background2 <= -0.37 (0.1658)
# Removida: Ar ka + Ag L <= -0.29 -> background1 > -0.11 (0.0042) | Mantida: background1 > -0.11 -> Ar ka + Ag L <= -0.29 (0.0085)
# Removida: Ar ka + Ag L <= -0.29 -> Fe ka <= -23.71 (0.0029) | Mantida: Fe ka <= -23.71 -> Ar ka + Ag L <= -0.29 (0.0540)
# Removida: Ar ka + Ag L <= -0.29 -> Cu ka <= -9.68 (0.0029) | Mantida: Cu ka <= -9.68 -> Ar ka + Ag L <= -0.29 (0.0489)
# Removida: Ar ka + Ag L > 0.28 -> Fe ka <= -24.15 (0.0034) | Mantida: Fe ka <= -24.15 -> Ar ka + Ag L > 0.28 (0.0284)
# Removida: background2 <= -0.37 -> Fe ka <= -23.71 (0.0047) | Mantida: Fe ka <= -23.71 -> background2 <= -0.37 (0.0641)
# Removida: background2 > 0.27 -> Fe ka <= -23.71 (0.0038) | Mantida: Fe ka <= -23.71 -> background2 > 0.27 (0.0561)
# Removida: Zn kb > -0.29 -> Ar ka + Ag L > -0.29 (0.0019) | Mantida: Ar ka + Ag L > -0.29 -> Zn kb > -0.29 (0.0033)
# Removida: Fe ka <= -22.90 -> Cu ka <= -9.68 (0.0381) | Mantida: Cu ka <= -9.68 -> Fe ka <= -22.90 (0.0486)
# Removida: Zn kb > -1.05 -> background2 > 0.27 (0.0023) | Mantida: background2 > 0.27 -> Zn kb > -1.05 (0.0042)
# Removida: Zn kb > -1.05 -> Cu ka <= -9.68 (0.0019) | Mantida: Cu ka <= -9.68 -> Zn kb > -1.05 (0.0205)
# Removida: Zn kb > -0.29 -> background2 > 0.27 (0.0028) | Mantida: background2 > 0.27 -> Zn kb > -0.29 (0.0038)
# Removida: Zn kb <= -0.29 -> Ti kb > 2.45 (0.0009) | Mantida: Ti kb > 2.45 -> Zn kb <= -0.29 (0.0127)
# Removida: Zn kb <= -0.29 -> Cu ka <= -9.68 (0.0024) | Mantida: Cu ka <= -9.68 -> Zn kb <= -0.29 (0.0224)
# Removida: background2 <= 0.98 -> Cu kb <= 0.18 (0.0036) | Mantida: Cu kb <= 0.18 -> background2 <= 0.98 (0.0183)
# Removida: background2 <= 0.98 -> background2 > -0.92 (0.0027) | Mantida: background2 > -0.92 -> background2 <= 0.98 (0.0037)
# Removida: background1 > -1.03 -> Cu kb <= -2.30 (0.0015) | Mantida: Cu kb <= -2.30 -> background1 > -1.03 (0.0186)
# Removida: Zn kb > -0.29 -> background2 > -0.92 (0.0032) | Mantida: background2 > -0.92 -> Zn kb > -0.29 (0.0067)
# Removida: background2 > -0.92 -> Fe kb <= -6.37 (0.0023) | Mantida: Fe kb <= -6.37 -> background2 > -0.92 (0.0152)
# Removida: Zn kb <= 0.29 -> background2 > -0.37 (0.0008) | Mantida: background2 > -0.37 -> Zn kb <= 0.29 (0.0015)
# Removida: background2 <= 0.27 -> Fe kb <= -6.37 (0.0016) | Mantida: Fe kb <= -6.37 -> background2 <= 0.27 (0.0203)
# Removida: Zn kb <= 0.29 -> Ti kb > 2.45 (0.0010) | Mantida: Ti kb > 2.45 -> Zn kb <= 0.29 (0.0114)
# Removida: background2 <= 0.27 -> Ti kb > 2.45 (0.0014) | Mantida: Ti kb > 2.45 -> background2 <= 0.27 (0.0106)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 532 | Removidas: 94
# Nós predicados: 90
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 93
# Removida: Ca ka > -21.19 -> Ca ka > -26.11 (64.7651) | Mantida: Ca ka > -26.11 -> Ca ka > -21.19 (64.8119)
# Removida: Ti ka <= 19.85 -> Ca ka > -6.65 (8.1210) | Mantida: Ca ka > -6.65 -> Ti ka <= 19.85 (69.6899)
# Removida: Ca ka > -6.65 -> Fe kb > -7.02 (9.0506) | Mantida: Fe kb > -7.02 -> Ca ka > -6.65 (65.3633)
# Removida: Ti ka <= 19.85 -> Fe kb > -7.02 (8.1726) | Mantida: Fe kb > -7.02 -> Ti ka <= 19.85 (17.2839)
# Removida: Ti ka <= 9.34 -> Ti ka > -28.53 (6.3540) | Mantida: Ti ka > -28.53 -> Ti ka <= 9.34 (45.5827)
# Removida: Fe kb > -7.41 -> Ti ka <= 9.34 (12.7678) | Mantida: Ti ka <= 9.34 -> Fe kb > -7.41 (36.6768)
# Removida: Fe kb > -7.41 -> Ti ka > -28.53 (6.6612) | Mantida: Ti ka > -28.53 -> Fe kb > -7.41 (19.8394)
# Removida: Ca kb > -8.59 -> Ca kb > -6.07 (7.9002) | Mantida: Ca kb > -6.07 -> Ca kb > -8.59 (31.7134)
# Removida: Ca kb > -8.59 -> Fe kb > -7.79 (7.9212) | Mantida: Fe kb > -7.79 -> Ca kb > -8.59 (10.5934)
# Removida: Cu ka > -9.68 -> Cu ka > -10.68 (6.9301) | Mantida: Cu ka > -10.68 -> Cu ka > -9.68 (24.4046)
# Removida: Ca kb > -2.67 -> Cu ka > -9.68 (2.9629) | Mantida: Cu ka > -9.68 -> Ca kb > -2.67 (9.3286)
# Removida: Ti kb <= 6.95 -> Ca kb > -2.67 (4.7225) | Mantida: Ca kb > -2.67 -> Ti kb <= 6.95 (13.9118)
# Removida: Ca kb > -2.67 -> Cu ka > -8.43 (5.4729) | Mantida: Cu ka > -8.43 -> Ca kb > -2.67 (6.2055)
# Removida: Cu ka > -8.43 -> Ti kb <= 6.95 (9.0449) | Mantida: Ti kb <= 6.95 -> Cu ka > -8.43 (9.4454)
# Removida: Ti kb > -10.26 -> Cu ka > -8.43 (2.1090) | Mantida: Cu ka > -8.43 -> Ti kb > -10.26 (7.9955)
# Removida: Ca ka <= 33.38 -> Ti kb > -10.26 (7.6882) | Mantida: Ti kb > -10.26 -> Ca ka <= 33.38 (10.2120)
# Removida: Ti kb <= 2.45 -> Ca ka <= 33.38 (1.7763) | Mantida: Ca ka <= 33.38 -> Ti kb <= 2.45 (13.6155)
# Removida: Cu kb > -1.61 -> Ti ka <= -4.69 (0.6574) | Mantida: Ti ka <= -4.69 -> Cu kb > -1.61 (2.2394)
# Removida: Ag ka scattering <= -0.18 -> Ti ka <= -4.69 (0.2788) | Mantida: Ti ka <= -4.69 -> Ag ka scattering <= -0.18 (2.1264)
# Removida: Ag ka scattering <= -0.18 -> Ag ka scattering <= 3.49 (0.2747) | Mantida: Ag ka scattering <= 3.49 -> Ag ka scattering <= -0.18 (0.8655)
# Removida: Cu kb > -1.61 -> Cu kb > -2.30 (0.7325) | Mantida: Cu kb > -2.30 -> Cu kb > -1.61 (2.6708)
# Removida: Ag ka scattering <= -0.18 -> Cu kb > -2.30 (0.8182) | Mantida: Cu kb > -2.30 -> Ag ka scattering <= -0.18 (1.2753)
# Removida: Ag ka scattering <= 1.67 -> Cu kb > -2.30 (0.2631) | Mantida: Cu kb > -2.30 -> Ag ka scattering <= 1.67 (0.6265)
# Removida: Ca ka <= -6.65 -> Cu kb > -1.61 (0.8320) | Mantida: Cu kb > -1.61 -> Ca ka <= -6.65 (1.0115)
# Removida: Cu kb > -2.88 -> Cu kb > -1.61 (0.5263) | Mantida: Cu kb > -1.61 -> Cu kb > -2.88 (1.7943)
# Removida: Ag ka scattering <= -0.18 -> Ca kb <= 12.61 (0.2520) | Mantida: Ca kb <= 12.61 -> Ag ka scattering <= -0.18 (0.7975)
# Removida: Ag ka scattering <= 1.67 -> Ca kb <= 12.61 (0.4775) | Mantida: Ca kb <= 12.61 -> Ag ka scattering <= 1.67 (1.6272)
# Removida: Ag ka scattering <= 1.67 -> Cu kb > -2.88 (0.4899) | Mantida: Cu kb > -2.88 -> Ag ka scattering <= 1.67 (0.5842)
# Removida: Ca ka <= -6.65 -> Cu kb > -2.88 (0.8531) | Mantida: Cu kb > -2.88 -> Ca ka <= -6.65 (1.0691)
# Removida: Ca kb <= 12.61 -> Ca ka <= -6.65 (0.7593) | Mantida: Ca ka <= -6.65 -> Ca kb <= 12.61 (1.5076)
# Removida: Ca kb <= 12.61 -> Cu kb > -2.88 (0.8437) | Mantida: Cu kb > -2.88 -> Ca kb <= 12.61 (0.9897)
# Removida: background3 <= 2.86 -> background3 <= 1.29 (0.0423) | Mantida: background3 <= 1.29 -> background3 <= 2.86 (0.1067)
# Removida: background3 <= -0.30 -> Ti kb <= -2.91 (0.0616) | Mantida: Ti kb <= -2.91 -> background3 <= -0.30 (0.3777)
# Removida: Ag ka scattering > -1.65 -> Ti kb <= -2.91 (0.3053) | Mantida: Ti kb <= -2.91 -> Ag ka scattering > -1.65 (1.5270)
# Removida: Ag ka scattering > -0.18 -> Ti kb <= -2.91 (0.0814) | Mantida: Ti kb <= -2.91 -> Ag ka scattering > -0.18 (0.2678)
# Removida: Zn ka > -1.75 -> Cu ka <= -3.28 (0.1688) | Mantida: Cu ka <= -3.28 -> Zn ka > -1.75 (0.3014)
# Removida: Zn ka > -1.75 -> Ag ka scattering > -0.18 (0.1269) | Mantida: Ag ka scattering > -0.18 -> Zn ka > -1.75 (0.1674)
# Removida: Zn ka > -1.75 -> Ca kb <= -2.67 (0.1775) | Mantida: Ca kb <= -2.67 -> Zn ka > -1.75 (0.7720)
# Removida: Zn ka > -0.78 -> Ag ka scattering > -0.18 (0.0628) | Mantida: Ag ka scattering > -0.18 -> Zn ka > -0.78 (0.1479)
# Removida: Zn ka > -0.78 -> Cu ka <= -3.28 (0.1589) | Mantida: Cu ka <= -3.28 -> Zn ka > -0.78 (0.2338)
# Removida: Zn ka > -0.78 -> Ca kb <= -2.67 (0.0615) | Mantida: Ca kb <= -2.67 -> Zn ka > -0.78 (0.9548)
# Removida: Zn ka > -0.78 -> Ag ka scattering > 1.67 (0.0435) | Mantida: Ag ka scattering > 1.67 -> Zn ka > -0.78 (0.0649)
# Removida: Ca kb <= -2.67 -> Ag ka scattering > -0.18 (0.2675) | Mantida: Ag ka scattering > -0.18 -> Ca kb <= -2.67 (0.3306)
# Removida: Ag ka scattering > -0.18 -> Cu ka <= -3.28 (0.0870) | Mantida: Cu ka <= -3.28 -> Ag ka scattering > -0.18 (0.2552)
# Removida: Cu ka <= -3.28 -> Ca kb <= -2.67 (0.2630) | Mantida: Ca kb <= -2.67 -> Cu ka <= -3.28 (0.2642)
# Removida: Zn ka <= 1.38 -> background1 <= 2.08 (0.0443) | Mantida: background1 <= 2.08 -> Zn ka <= 1.38 (0.0526)
# Removida: background1 <= 2.08 -> Ca ka <= -21.19 (0.1289) | Mantida: Ca ka <= -21.19 -> background1 <= 2.08 (0.2237)
# Removida: Ag ka scattering > 1.67 -> background1 <= 2.08 (0.0577) | Mantida: background1 <= 2.08 -> Ag ka scattering > 1.67 (0.0728)
# Removida: Zn ka <= 1.38 -> Ca ka <= -21.19 (0.0892) | Mantida: Ca ka <= -21.19 -> Zn ka <= 1.38 (0.8427)
# Removida: Zn ka <= 1.38 -> Ti ka > -4.69 (0.0863) | Mantida: Ti ka > -4.69 -> Zn ka <= 1.38 (0.2038)
# Removida: Ag ka scattering > 1.67 -> Zn ka <= 1.38 (0.0622) | Mantida: Zn ka <= 1.38 -> Ag ka scattering > 1.67 (0.1233)
# Removida: background1 <= -0.11 -> Ti ka > -4.69 (0.0170) | Mantida: Ti ka > -4.69 -> background1 <= -0.11 (0.1273)
# Removida: background3 > -2.55 -> Zn ka > 0.08 (0.0083) | Mantida: Zn ka > 0.08 -> background3 > -2.55 (0.0343)
# Removida: Zn ka > 0.08 -> Fe ka <= -23.71 (0.0131) | Mantida: Fe ka <= -23.71 -> Zn ka > 0.08 (0.0484)
# Removida: background3 > 1.29 -> Zn ka > 0.08 (0.0041) | Mantida: Zn ka > 0.08 -> background3 > 1.29 (0.0166)
# Removida: Ar ka + Ag L <= 1.07 -> Zn ka > 0.08 (0.0045) | Mantida: Zn ka > 0.08 -> Ar ka + Ag L <= 1.07 (0.0169)
# Removida: background1 > -1.87 -> Zn ka <= 0.08 (0.0161) | Mantida: Zn ka <= 0.08 -> background1 > -1.87 (0.0218)
# Removida: Zn ka <= 0.08 -> background1 <= -0.11 (0.0275) | Mantida: background1 <= -0.11 -> Zn ka <= 0.08 (0.0298)
# Removida: Zn ka <= -0.78 -> Zn ka <= 0.08 (0.0248) | Mantida: Zn ka <= 0.08 -> Zn ka <= -0.78 (0.0417)
# Removida: Ar ka + Ag L <= 0.28 -> Zn ka <= -0.78 (0.0051) | Mantida: Zn ka <= -0.78 -> Ar ka + Ag L <= 0.28 (0.0202)
# Removida: background1 <= -1.03 -> Zn ka <= -0.78 (0.0120) | Mantida: Zn ka <= -0.78 -> background1 <= -1.03 (0.0176)
# Removida: Ar ka + Ag L <= 1.07 -> Zn ka <= -0.78 (0.0051) | Mantida: Zn ka <= -0.78 -> Ar ka + Ag L <= 1.07 (0.0215)
# Removida: background3 > 1.29 -> Zn ka <= 0.08 (0.0029) | Mantida: Zn ka <= 0.08 -> background3 > 1.29 (0.0246)
# Removida: Zn ka <= 0.08 -> Ca kb <= -6.07 (0.0223) | Mantida: Ca kb <= -6.07 -> Zn ka <= 0.08 (0.2903)
# Removida: background3 > 1.29 -> Ar ka + Ag L <= 0.28 (0.0047) | Mantida: Ar ka + Ag L <= 0.28 -> background3 > 1.29 (0.0110)
# Removida: background3 > 1.29 -> Ca kb <= -6.07 (0.0061) | Mantida: Ca kb <= -6.07 -> background3 > 1.29 (0.1063)
# Removida: Ar ka + Ag L <= 0.28 -> Ar ka + Ag L <= 1.07 (0.0050) | Mantida: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L <= 0.28 (0.0057)
# Removida: Ar ka + Ag L <= 0.28 -> Cu ka <= -8.43 (0.0054) | Mantida: Cu ka <= -8.43 -> Ar ka + Ag L <= 0.28 (0.1718)
# Removida: Ca kb <= -6.07 -> Ti kb > -2.91 (0.1039) | Mantida: Ti kb > -2.91 -> Ca kb <= -6.07 (0.1947)
# Removida: Ar ka + Ag L > 0.28 -> Ar ka + Ag L <= 1.07 (0.0032) | Mantida: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L > 0.28 (0.0045)
# Removida: Ar ka + Ag L <= 1.07 -> Ar ka + Ag L > -1.05 (0.0044) | Mantida: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= 1.07 (0.0102)
# Removida: background3 > -0.30 -> Cu ka <= -8.43 (0.0024) | Mantida: Cu ka <= -8.43 -> background3 > -0.30 (0.1019)
# Removida: background1 <= -1.03 -> Cu ka <= -8.43 (0.0123) | Mantida: Cu ka <= -8.43 -> background1 <= -1.03 (0.1973)
# Removida: Zn kb > 0.29 -> background1 <= -1.03 (0.0055) | Mantida: background1 <= -1.03 -> Zn kb > 0.29 (0.0094)
# Removida: Ar ka + Ag L <= -0.29 -> background2 <= -0.37 (0.0036) | Mantida: background2 <= -0.37 -> Ar ka + Ag L <= -0.29 (0.0044)
# Removida: Ar ka + Ag L <= -0.29 -> Ar ka + Ag L > -1.05 (0.0037) | Mantida: Ar ka + Ag L > -1.05 -> Ar ka + Ag L <= -0.29 (0.0050)
# Removida: Ar ka + Ag L > -1.05 -> Zn kb > 0.29 (0.0036) | Mantida: Zn kb > 0.29 -> Ar ka + Ag L > -1.05 (0.0082)
# Removida: background2 <= -0.37 -> Cu kb <= 0.18 (0.0113) | Mantida: Cu kb <= 0.18 -> background2 <= -0.37 (0.0379)
# Removida: background2 <= -0.37 -> Cu ka <= -9.68 (0.0048) | Mantida: Cu ka <= -9.68 -> background2 <= -0.37 (0.0384)
# Removida: background2 > 0.27 -> Cu kb <= 0.18 (0.0027) | Mantida: Cu kb <= 0.18 -> background2 > 0.27 (0.0390)
# Removida: Ar ka + Ag L > -1.05 -> Fe ka <= -23.71 (0.0030) | Mantida: Fe ka <= -23.71 -> Ar ka + Ag L > -1.05 (0.0619)
# Removida: Ar ka + Ag L > -1.05 -> Fe ka <= -24.15 (0.0030) | Mantida: Fe ka <= -24.15 -> Ar ka + Ag L > -1.05 (0.0457)
# Removida: Fe ka <= -22.90 -> Fe ka <= -24.15 (0.0362) | Mantida: Fe ka <= -24.15 -> Fe ka <= -22.90 (0.0835)
# Removida: Ar ka + Ag L > -0.29 -> Fe ka <= -24.15 (0.0045) | Mantida: Fe ka <= -24.15 -> Ar ka + Ag L > -0.29 (0.0318)
# Removida: Cu ka <= -9.68 -> Fe ka <= -22.90 (0.0389) | Mantida: Fe ka <= -22.90 -> Cu ka <= -9.68 (0.0477)
# Removida: Fe ka <= -22.90 -> Fe kb <= -7.02 (0.0238) | Mantida: Fe kb <= -7.02 -> Fe ka <= -22.90 (0.0328)
# Removida: Fe kb <= -6.37 -> Fe kb <= -7.02 (0.0103) | Mantida: Fe kb <= -7.02 -> Fe kb <= -6.37 (0.0213)
# Removida: background2 <= 0.27 -> Fe kb <= -7.02 (0.0016) | Mantida: Fe kb <= -7.02 -> background2 <= 0.27 (0.0219)
# Removida: background2 > 0.27 -> Fe kb <= -7.02 (0.0019) | Mantida: Fe kb <= -7.02 -> background2 > 0.27 (0.0392)
# Removida: Zn kb <= 1.07 -> Cu kb <= -1.61 (0.0010) | Mantida: Cu kb <= -1.61 -> Zn kb <= 1.07 (0.0283)
# Removida: Ti ka > 9.34 -> Fe kb <= -6.37 (0.0215) | Mantida: Fe kb <= -6.37 -> Ti ka > 9.34 (0.0545)
# Removida: Zn kb > -1.05 -> Ti kb > 2.45 (0.0010) | Mantida: Ti kb > 2.45 -> Zn kb > -1.05 (0.0128)
# Removida: Ar ka + Ag L > -0.29 -> background2 > 0.27 (0.0007) | Mantida: background2 > 0.27 -> Ar ka + Ag L > -0.29 (0.0051)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 515 | Removidas: 93
# Nós predicados: 90
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#    Predicate_Cov_Seed_0 Predicate_Cov_Seed_1   Predicate_Cov_Seed_2  \
# 0        Fe ka > -23.71       Fe ka > -23.71         Fe ka > -23.71
# 1        Fe ka > -24.15       Fe ka > -24.15         Fe ka > -24.15
# 2        Fe ka > -24.62       Fe ka > -24.62         Fe ka > -24.62
# 3        Ca ka > -21.19       Ca ka > -26.11         Ca ka > -21.19
# 4        Ca ka > -26.11       Ca ka > -21.19         Ca ka > -26.11
# ..                  ...                  ...                    ...
# 87  background2 <= 0.27  background2 <= 0.27           Zn kb > 0.29
# 88         Ti kb > 2.45       Fe kb <= -7.41          Zn kb <= 1.07
# 89  Ar ka + Ag L > 0.28        Zn kb <= 1.07  Ar ka + Ag L <= -0.29
# 90              Class_A              Class_A                Class_A
# 91              Class_B              Class_B                Class_B
#
#      Predicate_Cov_Seed_3
# 0          Fe ka > -23.71
# 1          Fe ka > -24.15
# 2          Fe ka > -24.62
# 3          Ca ka > -21.19
# 4           Fe kb > -7.02
# ..                    ...
# 87    background2 <= 0.27
# 88  Ar ka + Ag L <= -0.29
# 89     background2 > 0.27
# 90                Class_A
# 91                Class_B
#
# [92 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                         Node  Local_Reaching_Centrality              Zone  \
# 0             Fe ka > -23.71                  16.224399             Fe ka
# 1             Ca ka > -21.19                   6.047561             Ca ka
# 2              Fe kb > -7.02                   4.990482             Fe kb
# 3             Ti ka > -28.53                   3.863937             Ti ka
# 4              Ca kb > -6.07                   2.253262             Ca kb
# 5             Cu ka > -10.68                   1.740443             Cu ka
# 6              Ti kb <= 6.95                   0.777269             Ti kb
# 7              Cu kb > -2.30                   0.161851             Cu kb
# 8   Ag ka scattering <= 3.49                   0.120730  Ag ka scattering
# 9       background3 <= -0.30                   0.044795       background3
# 10             Zn ka > -1.75                   0.027850             Zn ka
# 11       background1 <= 2.08                   0.021642       background1
# 12       background2 > -0.92                   0.010428       background2
# 13      Ar ka + Ag L <= 0.28                   0.009730      Ar ka + Ag L
# 14             Zn kb > -1.05                   0.008080             Zn kb
# 15                   Class_A                   0.000000              None
#
#    Threshold Operator
# 0     -23.71        >
# 1     -21.19        >
# 2      -7.02        >
# 3     -28.53        >
# 4      -6.07        >
# 5     -10.68        >
# 6       6.95       <=
# 7      -2.30        >
# 8       3.49       <=
# 9      -0.30       <=
# 10     -1.75        >
# 11      2.08       <=
# 12     -0.92        >
# 13      0.28       <=
# 14     -1.05        >
# 15      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zona 'Ar ka + Ag L': VE = 9.76%, dim = 29 variáveis
# Zona 'Ca ka': VE = 99.20%, dim = 17 variáveis
# Zona 'Ca kb': VE = 93.13%, dim = 13 variáveis
# Zona 'Ti ka': VE = 98.39%, dim = 19 variáveis
# Zona 'Ti kb': VE = 85.13%, dim = 16 variáveis
# Zona 'background1': VE = 12.27%, dim = 39 variáveis
# Zona 'Fe ka': VE = 99.86%, dim = 25 variáveis
# Zona 'Fe kb': VE = 97.91%, dim = 22 variáveis
# Zona 'background2': VE = 8.43%, dim = 18 variáveis
# Zona 'Cu ka': VE = 98.29%, dim = 20 variáveis
# Zona 'Zn ka': VE = 24.14%, dim = 21 variáveis
# Zona 'Cu kb': VE = 66.75%, dim = 19 variáveis
# Zona 'Zn kb': VE = 7.95%, dim = 30 variáveis
# Zona 'background3': VE = 2.98%, dim = 451 variáveis
# Zona 'Ag ka scattering': VE = 38.41%, dim = 49 variáveis
#                    Node  Local_Reaching_Centrality         Zone Threshold  \
# 0        Fe ka > -23.71                  16.224399        Fe ka    -23.71
# 1        Fe ka > -24.15                  11.451553        Fe ka    -24.15
# 2        Fe ka > -24.62                   7.875441        Fe ka    -24.62
# 3        Ca ka > -21.19                   6.047561        Ca ka    -21.19
# 4        Ca ka > -26.11                   5.969837        Ca ka    -26.11
# ..                  ...                        ...          ...       ...
# 87       Fe kb <= -7.41                   0.006363        Fe kb     -7.41
# 88  background2 <= 0.27                   0.006336  background2      0.27
# 89        Zn kb <= 1.07                   0.005680        Zn kb      1.07
# 90              Class_A                   0.000000         None      None
# 91              Class_B                   0.000000         None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0         >        -228.336686                    46.0             0.003068
# 1         >        -232.833909                   112.0             0.002150
# 2         >        -240.227437                    43.0             0.003827
# 3         >        -238.439137                   152.0             0.149595
# 4         >        -287.239935                   110.0             0.000994
# ..      ...                ...                     ...                  ...
# 87       <=         -32.289144                     4.0             0.001335
# 88       <=           0.811175                    47.0             0.000881
# 89       <=          -2.546607                   108.0             0.003444
# 90     None                NaN                     NaN                  NaN
# 91     None                NaN                     NaN                  NaN
#
#                Node_Natural
# 0       Fe ka > -228.336686
# 1       Fe ka > -232.833909
# 2       Fe ka > -240.227437
# 3       Ca ka > -238.439137
# 4       Ca ka > -287.239935
# ..                      ...
# 87      Fe kb <= -32.289144
# 88  background2 <= 0.811175
# 89       Zn kb <= -2.546607
# 90                     None
# 91                     None
#
# [92 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Fe ka':
#   - Dimensão: 25 variáveis espectrais
#   - Range de energias: 6.15 - 6.76
#   - Variância explicada pela PC1: 99.86%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=svm_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graphv3_pca(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 90 | Descartados: 30
# ======================================================================
# PERTURBATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Tipo de tarefa (aim): classification
# Modo de perturbação: median
# Fonte das estatísticas: full
# Métrica: probability_shift
# Total de folds: 10
#
#
# [Bag_1] Processando 90 predicados...
#   Predicado: Ar ka + Ag L > -1.05 (n=177)
#     Zona: 29 colunas
#     Importance: 0.000232
#   Predicado: Ar ka + Ag L <= -0.29 (n=98)
#     Zona: 29 colunas
#     Importance: 0.000366
#   Predicado: Ar ka + Ag L > -0.29 (n=129)
#     Zona: 29 colunas
#     Importance: 0.000130
#   Predicado: Ar ka + Ag L <= 0.28 (n=138)
#     Zona: 29 colunas
#     Importance: 0.000310
#   Predicado: Ar ka + Ag L > 0.28 (n=89)
#     Zona: 29 colunas
#     Importance: 0.000111
#   Predicado: Ar ka + Ag L <= 1.07 (n=183)
#     Zona: 29 colunas
#     Importance: 0.000269
#   Predicado: Ca ka > -26.11 (n=175)
#     Zona: 17 colunas
#     Importance: 0.010628
#   Predicado: Ca ka <= -21.19 (n=94)
#     Zona: 17 colunas
#     Importance: 0.013153
#   Predicado: Ca ka > -21.19 (n=133)
#     Zona: 17 colunas
#     Importance: 0.011847
#   Predicado: Ca ka <= -6.65 (n=140)
#     Zona: 17 colunas
#     Importance: 0.009189
#   Predicado: Ca ka > -6.65 (n=87)
#     Zona: 17 colunas
#     Importance: 0.017536
#   Predicado: Ca ka <= 33.38 (n=183)
#     Zona: 17 colunas
#     Importance: 0.008007
#   Predicado: Ca kb > -8.59 (n=174)
#     Zona: 13 colunas
#     Importance: 0.000328
#   Predicado: Ca kb <= -6.07 (n=94)
#     Zona: 13 colunas
#     Importance: 0.000816
#   Predicado: Ca kb > -6.07 (n=133)
#     Zona: 13 colunas
#     Importance: 0.000249
#   Predicado: Ca kb <= -2.67 (n=140)
#     Zona: 13 colunas
#     Importance: 0.000588
#   Predicado: Ca kb > -2.67 (n=87)
#     Zona: 13 colunas
#     Importance: 0.000315
#   Predicado: Ca kb <= 12.61 (n=182)
#     Zona: 13 colunas
#     Importance: 0.000534
#   Predicado: Ti ka > -28.53 (n=184)
#     Zona: 19 colunas
#     Importance: 0.072806
#   Predicado: Ti ka <= -4.69 (n=91)
#     Zona: 19 colunas
#     Importance: 0.201546
#   Predicado: Ti ka > -4.69 (n=136)
#     Zona: 19 colunas
#     Importance: 0.014615
#   Predicado: Ti ka <= 9.34 (n=136)
#     Zona: 19 colunas
#     Importance: 0.139758
#   Predicado: Ti ka > 9.34 (n=91)
#     Zona: 19 colunas
#     Importance: 0.014519
#   Predicado: Ti ka <= 19.85 (n=181)
#     Zona: 19 colunas
#     Importance: 0.108767
#   Predicado: Ti kb > -10.26 (n=182)
#     Zona: 16 colunas
#     Importance: 0.003639
#   Predicado: Ti kb <= -2.91 (n=91)
#     Zona: 16 colunas
#     Importance: 0.005876
#   Predicado: Ti kb > -2.91 (n=136)
#     Zona: 16 colunas
#     Importance: 0.002065
#   Predicado: Ti kb <= 2.45 (n=138)
#     Zona: 16 colunas
#     Importance: 0.004755
#   Predicado: Ti kb > 2.45 (n=89)
#     Zona: 16 colunas
#     Importance: 0.001791
#   Predicado: Ti kb <= 6.95 (n=185)
#     Zona: 16 colunas
#     Importance: 0.004019
#   Predicado: background1 > -1.87 (n=181)
#     Zona: 39 colunas
#     Importance: 0.000242
#   Predicado: background1 <= -1.03 (n=91)
#     Zona: 39 colunas
#     Importance: 0.000536
#   Predicado: background1 > -1.03 (n=136)
#     Zona: 39 colunas
#     Importance: 0.000240
#   Predicado: background1 <= -0.11 (n=136)
#     Zona: 39 colunas
#     Importance: 0.000431
#   Predicado: background1 > -0.11 (n=91)
#     Zona: 39 colunas
#     Importance: 0.000252
#   Predicado: background1 <= 2.08 (n=183)
#     Zona: 39 colunas
#     Importance: 0.000419
#   Predicado: Fe ka > -24.62 (n=183)
#     Zona: 25 colunas
#     Importance: 0.000690
#   Predicado: Fe ka <= -24.15 (n=86)
#     Zona: 25 colunas
#     Importance: 0.000251
#   Predicado: Fe ka > -24.15 (n=141)
#     Zona: 25 colunas
#     Importance: 0.000856
#   Predicado: Fe ka <= -23.71 (n=136)
#     Zona: 25 colunas
#     Importance: 0.000198
#   Predicado: Fe ka > -23.71 (n=91)
#     Zona: 25 colunas
#     Importance: 0.001266
#   Predicado: Fe ka <= -22.90 (n=179)
#     Zona: 25 colunas
#     Importance: 0.000172
#   Predicado: Fe kb > -7.79 (n=181)
#     Zona: 22 colunas
#     Importance: 0.001553
#   Predicado: Fe kb <= -7.41 (n=91)
#     Zona: 22 colunas
#     Importance: 0.000087
#   Predicado: Fe kb > -7.41 (n=136)
#     Zona: 22 colunas
#     Importance: 0.002048
#   Predicado: Fe kb <= -7.02 (n=135)
#     Zona: 22 colunas
#     Importance: 0.000112
#   Predicado: Fe kb > -7.02 (n=92)
#     Zona: 22 colunas
#     Importance: 0.002949
#   Predicado: Fe kb <= -6.37 (n=181)
#     Zona: 22 colunas
#     Importance: 0.000141
#   Predicado: background2 > -0.92 (n=177)
#     Zona: 18 colunas
#     Importance: 0.000119
#   Predicado: background2 <= -0.37 (n=96)
#     Zona: 18 colunas
#     Importance: 0.000130
#   Predicado: background2 > -0.37 (n=131)
#     Zona: 18 colunas
#     Importance: 0.000134
#   Predicado: background2 <= 0.27 (n=142)
#     Zona: 18 colunas
#     Importance: 0.000136
#   Predicado: background2 > 0.27 (n=85)
#     Zona: 18 colunas
#     Importance: 0.000127
#   Predicado: background2 <= 0.98 (n=186)
#     Zona: 18 colunas
#     Importance: 0.000126
#   Predicado: Cu ka > -10.68 (n=181)
#     Zona: 20 colunas
#     Importance: 0.006143
#   Predicado: Cu ka <= -9.68 (n=93)
#     Zona: 20 colunas
#     Importance: 0.001917
#   Predicado: Cu ka > -9.68 (n=134)
#     Zona: 20 colunas
#     Importance: 0.007951
#   Predicado: Cu ka <= -8.43 (n=140)
#     Zona: 20 colunas
#     Importance: 0.001339
#   Predicado: Cu ka > -8.43 (n=87)
#     Zona: 20 colunas
#     Importance: 0.012141
#   Predicado: Cu ka <= -3.28 (n=182)
#     Zona: 20 colunas
#     Importance: 0.001140
#   Predicado: Zn ka > -1.75 (n=181)
#     Zona: 21 colunas
#     Importance: 0.000171
#   Predicado: Zn ka <= -0.78 (n=89)
#     Zona: 21 colunas
#     Importance: 0.000301
#   Predicado: Zn ka > -0.78 (n=138)
#     Zona: 21 colunas
#     Importance: 0.000104
#   Predicado: Zn ka <= 0.08 (n=138)
#     Zona: 21 colunas
#     Importance: 0.000246
#   Predicado: Zn ka > 0.08 (n=89)
#     Zona: 21 colunas
#     Importance: 0.000081
#   Predicado: Zn ka <= 1.38 (n=184)
#     Zona: 21 colunas
#     Importance: 0.000205
#   Predicado: Cu kb > -2.88 (n=177)
#     Zona: 19 colunas
#     Importance: 0.000430
#   Predicado: Cu kb <= -2.30 (n=92)
#     Zona: 19 colunas
#     Importance: 0.000398
#   Predicado: Cu kb > -2.30 (n=135)
#     Zona: 19 colunas
#     Importance: 0.000505
#   Predicado: Cu kb <= -1.61 (n=137)
#     Zona: 19 colunas
#     Importance: 0.000293
#   Predicado: Cu kb > -1.61 (n=90)
#     Zona: 19 colunas
#     Importance: 0.000719
#   Predicado: Cu kb <= 0.18 (n=180)
#     Zona: 19 colunas
#     Importance: 0.000266
#   Predicado: Zn kb > -1.05 (n=182)
#     Zona: 30 colunas
#     Importance: 0.000189
#   Predicado: Zn kb <= -0.29 (n=93)
#     Zona: 30 colunas
#     Importance: 0.000271
#   Predicado: Zn kb > -0.29 (n=134)
#     Zona: 30 colunas
#     Importance: 0.000147
#   Predicado: Zn kb <= 0.29 (n=142)
#     Zona: 30 colunas
#     Importance: 0.000233
#   Predicado: Zn kb > 0.29 (n=85)
#     Zona: 30 colunas
#     Importance: 0.000140
#   Predicado: Zn kb <= 1.07 (n=182)
#     Zona: 30 colunas
#     Importance: 0.000203
#   Predicado: background3 > -2.55 (n=179)
#     Zona: 451 colunas
#     Importance: 0.001569
#   Predicado: background3 <= -0.30 (n=95)
#     Zona: 451 colunas
#     Importance: 0.006396
#   Predicado: background3 > -0.30 (n=132)
#     Zona: 451 colunas
#     Importance: 0.001169
#   Predicado: background3 <= 1.29 (n=133)
#     Zona: 451 colunas
#     Importance: 0.005102
#   Predicado: background3 > 1.29 (n=94)
#     Zona: 451 colunas
#     Importance: 0.000886
#   Predicado: background3 <= 2.86 (n=184)
#     Zona: 451 colunas
#     Importance: 0.003999
#   Predicado: Ag ka scattering > -1.65 (n=180)
#     Zona: 49 colunas
#     Importance: 0.002543
#   Predicado: Ag ka scattering <= -0.18 (n=93)
#     Zona: 49 colunas
#     Importance: 0.012853
#   Predicado: Ag ka scattering > -0.18 (n=134)
#     Zona: 49 colunas
#     Importance: 0.003208
#   Predicado: Ag ka scattering <= 1.67 (n=133)
#     Zona: 49 colunas
#     Importance: 0.009237
#   Predicado: Ag ka scattering > 1.67 (n=94)
#     Zona: 49 colunas
#     Importance: 0.004221
#   Predicado: Ag ka scattering <= 3.49 (n=180)
#     Zona: 49 colunas
#     Importance: 0.007346
#
# [Bag_2] Processando 90 predicados...
#   Predicado: Ar ka + Ag L > -1.05 (n=182)
#     Zona: 29 colunas
#     Importance: 0.000146
#   Predicado: Ar ka + Ag L <= -0.29 (n=91)
#     Zona: 29 colunas
#     Importance: 0.000262
#   Predicado: Ar ka + Ag L > -0.29 (n=136)
#     Zona: 29 colunas
#     Importance: 0.000111
#   Predicado: Ar ka + Ag L <= 0.28 (n=137)
#     Zona: 29 colunas
#     Importance: 0.000221
#   Predicado: Ar ka + Ag L > 0.28 (n=90)
#     Zona: 29 colunas
#     Importance: 0.000097
#   Predicado: Ar ka + Ag L <= 1.07 (n=181)
#     Zona: 29 colunas
#     Importance: 0.000193
#   Predicado: Ca ka > -26.11 (n=182)
#     Zona: 17 colunas
#     Importance: 0.010407
#   Predicado: Ca ka <= -21.19 (n=93)
#     Zona: 17 colunas
#     Importance: 0.012005
#   Predicado: Ca ka > -21.19 (n=134)
#     Zona: 17 colunas
#     Importance: 0.011846
#   Predicado: Ca ka <= -6.65 (n=136)
#     Zona: 17 colunas
#     Importance: 0.008553
#   Predicado: Ca ka > -6.65 (n=91)
#     Zona: 17 colunas
#     Importance: 0.016929
#   Predicado: Ca ka <= 33.38 (n=179)
#     Zona: 17 colunas
#     Importance: 0.007332
#   Predicado: Ca kb > -8.59 (n=183)
#     Zona: 13 colunas
#     Importance: 0.000293
#   Predicado: Ca kb <= -6.07 (n=93)
#     Zona: 13 colunas
#     Importance: 0.000725
#   Predicado: Ca kb > -6.07 (n=134)
#     Zona: 13 colunas
#     Importance: 0.000239
#   Predicado: Ca kb <= -2.67 (n=137)
#     Zona: 13 colunas
#     Importance: 0.000530
#   Predicado: Ca kb > -2.67 (n=90)
#     Zona: 13 colunas
#     Importance: 0.000298
#   Predicado: Ca kb <= 12.61 (n=179)
#     Zona: 13 colunas
#     Importance: 0.000470
#   Predicado: Ti ka > -28.53 (n=178)
#     Zona: 19 colunas
#     Importance: 0.065749
#   Predicado: Ti ka <= -4.69 (n=94)
#     Zona: 19 colunas
#     Importance: 0.177049
#   Predicado: Ti ka > -4.69 (n=133)
#     Zona: 19 colunas
#     Importance: 0.014284
#   Predicado: Ti ka <= 9.34 (n=134)
#     Zona: 19 colunas
#     Importance: 0.128739
#   Predicado: Ti ka > 9.34 (n=93)
#     Zona: 19 colunas
#     Importance: 0.013885
#   Predicado: Ti ka <= 19.85 (n=178)
#     Zona: 19 colunas
#     Importance: 0.100181
#   Predicado: Ti kb > -10.26 (n=182)
#     Zona: 16 colunas
#     Importance: 0.003579
#   Predicado: Ti kb <= -2.91 (n=94)
#     Zona: 16 colunas
#     Importance: 0.005087
#   Predicado: Ti kb > -2.91 (n=133)
#     Zona: 16 colunas
#     Importance: 0.002308
#   Predicado: Ti kb <= 2.45 (n=131)
#     Zona: 16 colunas
#     Importance: 0.004532
#   Predicado: Ti kb > 2.45 (n=96)
#     Zona: 16 colunas
#     Importance: 0.001994
#   Predicado: Ti kb <= 6.95 (n=179)
#     Zona: 16 colunas
#     Importance: 0.003915
#   Predicado: background1 > -1.87 (n=185)
#     Zona: 39 colunas
#     Importance: 0.000216
#   Predicado: background1 <= -1.03 (n=88)
#     Zona: 39 colunas
#     Importance: 0.000339
#   Predicado: background1 > -1.03 (n=139)
#     Zona: 39 colunas
#     Importance: 0.000230
#   Predicado: background1 <= -0.11 (n=132)
#     Zona: 39 colunas
#     Importance: 0.000293
#   Predicado: background1 > -0.11 (n=95)
#     Zona: 39 colunas
#     Importance: 0.000242
#   Predicado: background1 <= 2.08 (n=179)
#     Zona: 39 colunas
#     Importance: 0.000324
#   Predicado: Fe ka > -24.62 (n=180)
#     Zona: 25 colunas
#     Importance: 0.000631
#   Predicado: Fe ka <= -24.15 (n=91)
#     Zona: 25 colunas
#     Importance: 0.000228
#   Predicado: Fe ka > -24.15 (n=136)
#     Zona: 25 colunas
#     Importance: 0.000797
#   Predicado: Fe ka <= -23.71 (n=140)
#     Zona: 25 colunas
#     Importance: 0.000185
#   Predicado: Fe ka > -23.71 (n=87)
#     Zona: 25 colunas
#     Importance: 0.001187
#   Predicado: Fe ka <= -22.90 (n=183)
#     Zona: 25 colunas
#     Importance: 0.000163
#   Predicado: Fe kb > -7.79 (n=178)
#     Zona: 22 colunas
#     Importance: 0.001591
#   Predicado: Fe kb <= -7.41 (n=89)
#     Zona: 22 colunas
#     Importance: 0.000088
#   Predicado: Fe kb > -7.41 (n=138)
#     Zona: 22 colunas
#     Importance: 0.002037
#   Predicado: Fe kb <= -7.02 (n=136)
#     Zona: 22 colunas
#     Importance: 0.000108
#   Predicado: Fe kb > -7.02 (n=91)
#     Zona: 22 colunas
#     Importance: 0.003014
#   Predicado: Fe kb <= -6.37 (n=183)
#     Zona: 22 colunas
#     Importance: 0.000136
#   Predicado: background2 > -0.92 (n=184)
#     Zona: 18 colunas
#     Importance: 0.000097
#   Predicado: background2 <= -0.37 (n=86)
#     Zona: 18 colunas
#     Importance: 0.000146
#   Predicado: background2 > -0.37 (n=141)
#     Zona: 18 colunas
#     Importance: 0.000100
#   Predicado: background2 <= 0.27 (n=131)
#     Zona: 18 colunas
#     Importance: 0.000126
#   Predicado: background2 > 0.27 (n=96)
#     Zona: 18 colunas
#     Importance: 0.000104
#   Predicado: background2 <= 0.98 (n=184)
#     Zona: 18 colunas
#     Importance: 0.000114
#   Predicado: Cu ka > -10.68 (n=180)
#     Zona: 20 colunas
#     Importance: 0.004615
#   Predicado: Cu ka <= -9.68 (n=93)
#     Zona: 20 colunas
#     Importance: 0.001625
#   Predicado: Cu ka > -9.68 (n=134)
#     Zona: 20 colunas
#     Importance: 0.005897
#   Predicado: Cu ka <= -8.43 (n=139)
#     Zona: 20 colunas
#     Importance: 0.001153
#   Predicado: Cu ka > -8.43 (n=88)
#     Zona: 20 colunas
#     Importance: 0.008877
#   Predicado: Cu ka <= -3.28 (n=186)
#     Zona: 20 colunas
#     Importance: 0.000973
#   Predicado: Zn ka > -1.75 (n=179)
#     Zona: 21 colunas
#     Importance: 0.000160
#   Predicado: Zn ka <= -0.78 (n=95)
#     Zona: 21 colunas
#     Importance: 0.000241
#   Predicado: Zn ka > -0.78 (n=132)
#     Zona: 21 colunas
#     Importance: 0.000095
#   Predicado: Zn ka <= 0.08 (n=142)
#     Zona: 21 colunas
#     Importance: 0.000206
#   Predicado: Zn ka > 0.08 (n=85)
#     Zona: 21 colunas
#     Importance: 0.000073
#   Predicado: Zn ka <= 1.38 (n=186)
#     Zona: 21 colunas
#     Importance: 0.000176
#   Predicado: Cu kb > -2.88 (n=178)
#     Zona: 19 colunas
#     Importance: 0.000332
#   Predicado: Cu kb <= -2.30 (n=89)
#     Zona: 19 colunas
#     Importance: 0.000378
#   Predicado: Cu kb > -2.30 (n=138)
#     Zona: 19 colunas
#     Importance: 0.000374
#   Predicado: Cu kb <= -1.61 (n=139)
#     Zona: 19 colunas
#     Importance: 0.000271
#   Predicado: Cu kb > -1.61 (n=88)
#     Zona: 19 colunas
#     Importance: 0.000540
#   Predicado: Cu kb <= 0.18 (n=184)
#     Zona: 19 colunas
#     Importance: 0.000231
#   Predicado: Zn kb > -1.05 (n=183)
#     Zona: 30 colunas
#     Importance: 0.000171
#   Predicado: Zn kb <= -0.29 (n=94)
#     Zona: 30 colunas
#     Importance: 0.000271
#   Predicado: Zn kb > -0.29 (n=133)
#     Zona: 30 colunas
#     Importance: 0.000112
#   Predicado: Zn kb <= 0.29 (n=144)
#     Zona: 30 colunas
#     Importance: 0.000230
#   Predicado: Zn kb > 0.29 (n=83)
#     Zona: 30 colunas
#     Importance: 0.000088
#   Predicado: Zn kb <= 1.07 (n=189)
#     Zona: 30 colunas
#     Importance: 0.000197
#   Predicado: background3 > -2.55 (n=180)
#     Zona: 451 colunas
#     Importance: 0.001541
#   Predicado: background3 <= -0.30 (n=92)
#     Zona: 451 colunas
#     Importance: 0.005122
#   Predicado: background3 > -0.30 (n=135)
#     Zona: 451 colunas
#     Importance: 0.001195
#   Predicado: background3 <= 1.29 (n=140)
#     Zona: 451 colunas
#     Importance: 0.003980
#   Predicado: background3 > 1.29 (n=87)
#     Zona: 451 colunas
#     Importance: 0.000866
#   Predicado: background3 <= 2.86 (n=184)
#     Zona: 451 colunas
#     Importance: 0.003302
#   Predicado: Ag ka scattering > -1.65 (n=180)
#     Zona: 49 colunas
#     Importance: 0.002503
#   Predicado: Ag ka scattering <= -0.18 (n=92)
#     Zona: 49 colunas
#     Importance: 0.011255
#   Predicado: Ag ka scattering > -0.18 (n=135)
#     Zona: 49 colunas
#     Importance: 0.003157
#   Predicado: Ag ka scattering <= 1.67 (n=135)
#     Zona: 49 colunas
#     Importance: 0.007868
#   Predicado: Ag ka scattering > 1.67 (n=92)
#     Zona: 49 colunas
#     Importance: 0.004342
#   Predicado: Ag ka scattering <= 3.49 (n=180)
#     Zona: 49 colunas
#     Importance: 0.006434
#
# [Bag_3] Processando 90 predicados...
#   Predicado: Ar ka + Ag L > -1.05 (n=181)
#     Zona: 29 colunas
#     Importance: 0.000239
#   Predicado: Ar ka + Ag L <= -0.29 (n=89)
#     Zona: 29 colunas
#     Importance: 0.000336
#   Predicado: Ar ka + Ag L > -0.29 (n=138)
#     Zona: 29 colunas
#     Importance: 0.000142
#   Predicado: Ar ka + Ag L <= 0.28 (n=136)
#     Zona: 29 colunas
#     Importance: 0.000279
#   Predicado: Ar ka + Ag L > 0.28 (n=91)
#     Zona: 29 colunas
#     Importance: 0.000127
#   Predicado: Ar ka + Ag L <= 1.07 (n=180)
#     Zona: 29 colunas
#     Importance: 0.000250
#   Predicado: Ca ka > -26.11 (n=183)
#     Zona: 17 colunas
#     Importance: 0.010750
#   Predicado: Ca ka <= -21.19 (n=90)
#     Zona: 17 colunas
#     Importance: 0.014030
#   Predicado: Ca ka > -21.19 (n=137)
#     Zona: 17 colunas
#     Importance: 0.011833
#   Predicado: Ca ka <= -6.65 (n=135)
#     Zona: 17 colunas
#     Importance: 0.009647
#   Predicado: Ca ka > -6.65 (n=92)
#     Zona: 17 colunas
#     Importance: 0.017190
#   Predicado: Ca ka <= 33.38 (n=183)
#     Zona: 17 colunas
#     Importance: 0.008342
#   Predicado: Ca kb > -8.59 (n=180)
#     Zona: 13 colunas
#     Importance: 0.000374
#   Predicado: Ca kb <= -6.07 (n=91)
#     Zona: 13 colunas
#     Importance: 0.000845
#   Predicado: Ca kb > -6.07 (n=136)
#     Zona: 13 colunas
#     Importance: 0.000280
#   Predicado: Ca kb <= -2.67 (n=135)
#     Zona: 13 colunas
#     Importance: 0.000610
#   Predicado: Ca kb > -2.67 (n=92)
#     Zona: 13 colunas
#     Importance: 0.000354
#   Predicado: Ca kb <= 12.61 (n=183)
#     Zona: 13 colunas
#     Importance: 0.000545
#   Predicado: Ti ka > -28.53 (n=185)
#     Zona: 19 colunas
#     Importance: 0.076263
#   Predicado: Ti ka <= -4.69 (n=92)
#     Zona: 19 colunas
#     Importance: 0.201020
#   Predicado: Ti ka > -4.69 (n=135)
#     Zona: 19 colunas
#     Importance: 0.014600
#   Predicado: Ti ka <= 9.34 (n=138)
#     Zona: 19 colunas
#     Importance: 0.139957
#   Predicado: Ti ka > 9.34 (n=89)
#     Zona: 19 colunas
#     Importance: 0.012930
#   Predicado: Ti ka <= 19.85 (n=179)
#     Zona: 19 colunas
#     Importance: 0.111027
#   Predicado: Ti kb > -10.26 (n=182)
#     Zona: 16 colunas
#     Importance: 0.003868
#   Predicado: Ti kb <= -2.91 (n=94)
#     Zona: 16 colunas
#     Importance: 0.005826
#   Predicado: Ti kb > -2.91 (n=133)
#     Zona: 16 colunas
#     Importance: 0.002229
#   Predicado: Ti kb <= 2.45 (n=137)
#     Zona: 16 colunas
#     Importance: 0.004793
#   Predicado: Ti kb > 2.45 (n=90)
#     Zona: 16 colunas
#     Importance: 0.002083
#   Predicado: Ti kb <= 6.95 (n=182)
#     Zona: 16 colunas
#     Importance: 0.004230
#   Predicado: background1 > -1.87 (n=182)
#     Zona: 39 colunas
#     Importance: 0.000237
#   Predicado: background1 <= -1.03 (n=90)
#     Zona: 39 colunas
#     Importance: 0.000524
#   Predicado: background1 > -1.03 (n=137)
#     Zona: 39 colunas
#     Importance: 0.000245
#   Predicado: background1 <= -0.11 (n=136)
#     Zona: 39 colunas
#     Importance: 0.000405
#   Predicado: background1 > -0.11 (n=91)
#     Zona: 39 colunas
#     Importance: 0.000282
#   Predicado: background1 <= 2.08 (n=179)
#     Zona: 39 colunas
#     Importance: 0.000415
#   Predicado: Fe ka > -24.62 (n=185)
#     Zona: 25 colunas
#     Importance: 0.000628
#   Predicado: Fe ka <= -24.15 (n=93)
#     Zona: 25 colunas
#     Importance: 0.000215
#   Predicado: Fe ka > -24.15 (n=134)
#     Zona: 25 colunas
#     Importance: 0.000808
#   Predicado: Fe ka <= -23.71 (n=137)
#     Zona: 25 colunas
#     Importance: 0.000183
#   Predicado: Fe ka > -23.71 (n=90)
#     Zona: 25 colunas
#     Importance: 0.001145
#   Predicado: Fe ka <= -22.90 (n=177)
#     Zona: 25 colunas
#     Importance: 0.000163
#   Predicado: Fe kb > -7.79 (n=179)
#     Zona: 22 colunas
#     Importance: 0.001477
#   Predicado: Fe kb <= -7.41 (n=96)
#     Zona: 22 colunas
#     Importance: 0.000097
#   Predicado: Fe kb > -7.41 (n=131)
#     Zona: 22 colunas
#     Importance: 0.001995
#   Predicado: Fe kb <= -7.02 (n=143)
#     Zona: 22 colunas
#     Importance: 0.000103
#   Predicado: Fe kb > -7.02 (n=84)
#     Zona: 22 colunas
#     Importance: 0.003047
#   Predicado: Fe kb <= -6.37 (n=179)
#     Zona: 22 colunas
#     Importance: 0.000130
#   Predicado: background2 > -0.92 (n=184)
#     Zona: 18 colunas
#     Importance: 0.000107
#   Predicado: background2 <= -0.37 (n=91)
#     Zona: 18 colunas
#     Importance: 0.000133
#   Predicado: background2 > -0.37 (n=136)
#     Zona: 18 colunas
#     Importance: 0.000108
#   Predicado: background2 <= 0.27 (n=136)
#     Zona: 18 colunas
#     Importance: 0.000133
#   Predicado: background2 > 0.27 (n=91)
#     Zona: 18 colunas
#     Importance: 0.000097
#   Predicado: background2 <= 0.98 (n=181)
#     Zona: 18 colunas
#     Importance: 0.000119
#   Predicado: Cu ka > -10.68 (n=185)
#     Zona: 20 colunas
#     Importance: 0.006025
#   Predicado: Cu ka <= -9.68 (n=87)
#     Zona: 20 colunas
#     Importance: 0.002071
#   Predicado: Cu ka > -9.68 (n=140)
#     Zona: 20 colunas
#     Importance: 0.007651
#   Predicado: Cu ka <= -8.43 (n=135)
#     Zona: 20 colunas
#     Importance: 0.001410
#   Predicado: Cu ka > -8.43 (n=92)
#     Zona: 20 colunas
#     Importance: 0.011531
#   Predicado: Cu ka <= -3.28 (n=179)
#     Zona: 20 colunas
#     Importance: 0.001175
#   Predicado: Zn ka > -1.75 (n=186)
#     Zona: 21 colunas
#     Importance: 0.000182
#   Predicado: Zn ka <= -0.78 (n=85)
#     Zona: 21 colunas
#     Importance: 0.000310
#   Predicado: Zn ka > -0.78 (n=142)
#     Zona: 21 colunas
#     Importance: 0.000117
#   Predicado: Zn ka <= 0.08 (n=134)
#     Zona: 21 colunas
#     Importance: 0.000269
#   Predicado: Zn ka > 0.08 (n=93)
#     Zona: 21 colunas
#     Importance: 0.000075
#   Predicado: Zn ka <= 1.38 (n=183)
#     Zona: 21 colunas
#     Importance: 0.000216
#   Predicado: Cu kb > -2.88 (n=184)
#     Zona: 19 colunas
#     Importance: 0.000462
#   Predicado: Cu kb <= -2.30 (n=89)
#     Zona: 19 colunas
#     Importance: 0.000426
#   Predicado: Cu kb > -2.30 (n=138)
#     Zona: 19 colunas
#     Importance: 0.000529
#   Predicado: Cu kb <= -1.61 (n=139)
#     Zona: 19 colunas
#     Importance: 0.000294
#   Predicado: Cu kb > -1.61 (n=88)
#     Zona: 19 colunas
#     Importance: 0.000795
#   Predicado: Cu kb <= 0.18 (n=181)
#     Zona: 19 colunas
#     Importance: 0.000268
#   Predicado: Zn kb > -1.05 (n=184)
#     Zona: 30 colunas
#     Importance: 0.000186
#   Predicado: Zn kb <= -0.29 (n=90)
#     Zona: 30 colunas
#     Importance: 0.000271
#   Predicado: Zn kb > -0.29 (n=137)
#     Zona: 30 colunas
#     Importance: 0.000151
#   Predicado: Zn kb <= 0.29 (n=137)
#     Zona: 30 colunas
#     Importance: 0.000232
#   Predicado: Zn kb > 0.29 (n=90)
#     Zona: 30 colunas
#     Importance: 0.000149
#   Predicado: Zn kb <= 1.07 (n=179)
#     Zona: 30 colunas
#     Importance: 0.000209
#   Predicado: background3 > -2.55 (n=181)
#     Zona: 451 colunas
#     Importance: 0.001593
#   Predicado: background3 <= -0.30 (n=97)
#     Zona: 451 colunas
#     Importance: 0.006353
#   Predicado: background3 > -0.30 (n=130)
#     Zona: 451 colunas
#     Importance: 0.001186
#   Predicado: background3 <= 1.29 (n=141)
#     Zona: 451 colunas
#     Importance: 0.004976
#   Predicado: background3 > 1.29 (n=86)
#     Zona: 451 colunas
#     Importance: 0.000801
#   Predicado: background3 <= 2.86 (n=182)
#     Zona: 451 colunas
#     Importance: 0.004075
#   Predicado: Ag ka scattering > -1.65 (n=178)
#     Zona: 49 colunas
#     Importance: 0.002750
#   Predicado: Ag ka scattering <= -0.18 (n=95)
#     Zona: 49 colunas
#     Importance: 0.013624
#   Predicado: Ag ka scattering > -0.18 (n=132)
#     Zona: 49 colunas
#     Importance: 0.003465
#   Predicado: Ag ka scattering <= 1.67 (n=136)
#     Zona: 49 colunas
#     Importance: 0.009614
#   Predicado: Ag ka scattering > 1.67 (n=91)
#     Zona: 49 colunas
#     Importance: 0.004881
#   Predicado: Ag ka scattering <= 3.49 (n=180)
#     Zona: 49 colunas
#     Importance: 0.007719
#
# [Bag_4] Processando 90 predicados...
#   Predicado: Ar ka + Ag L > -1.05 (n=179)
#     Zona: 29 colunas
#     Importance: 0.000224
#   Predicado: Ar ka + Ag L <= -0.29 (n=95)
#     Zona: 29 colunas
#     Importance: 0.000386
#   Predicado: Ar ka + Ag L > -0.29 (n=132)
#     Zona: 29 colunas
#     Importance: 0.000119
#   Predicado: Ar ka + Ag L <= 0.28 (n=139)
#     Zona: 29 colunas
#     Importance: 0.000313
#   Predicado: Ar ka + Ag L > 0.28 (n=88)
#     Zona: 29 colunas
#     Importance: 0.000099
#   Predicado: Ar ka + Ag L <= 1.07 (n=183)
#     Zona: 29 colunas
#     Importance: 0.000267
#   Predicado: Ca ka > -26.11 (n=181)
#     Zona: 17 colunas
#     Importance: 0.013761
#   Predicado: Ca ka <= -21.19 (n=90)
#     Zona: 17 colunas
#     Importance: 0.014224
#   Predicado: Ca ka > -21.19 (n=137)
#     Zona: 17 colunas
#     Importance: 0.015919
#   Predicado: Ca ka <= -6.65 (n=135)
#     Zona: 17 colunas
#     Importance: 0.009883
#   Predicado: Ca ka > -6.65 (n=92)
#     Zona: 17 colunas
#     Importance: 0.023118
#   Predicado: Ca ka <= 33.38 (n=181)
#     Zona: 17 colunas
#     Importance: 0.008664
#   Predicado: Ca kb > -8.59 (n=182)
#     Zona: 13 colunas
#     Importance: 0.000374
#   Predicado: Ca kb <= -6.07 (n=90)
#     Zona: 13 colunas
#     Importance: 0.000872
#   Predicado: Ca kb > -6.07 (n=137)
#     Zona: 13 colunas
#     Importance: 0.000290
#   Predicado: Ca kb <= -2.67 (n=133)
#     Zona: 13 colunas
#     Importance: 0.000627
#   Predicado: Ca kb > -2.67 (n=94)
#     Zona: 13 colunas
#     Importance: 0.000370
#   Predicado: Ca kb <= 12.61 (n=181)
#     Zona: 13 colunas
#     Importance: 0.000557
#   Predicado: Ti ka > -28.53 (n=182)
#     Zona: 19 colunas
#     Importance: 0.068441
#   Predicado: Ti ka <= -4.69 (n=93)
#     Zona: 19 colunas
#     Importance: 0.172381
#   Predicado: Ti ka > -4.69 (n=134)
#     Zona: 19 colunas
#     Importance: 0.014904
#   Predicado: Ti ka <= 9.34 (n=140)
#     Zona: 19 colunas
#     Importance: 0.119897
#   Predicado: Ti ka > 9.34 (n=87)
#     Zona: 19 colunas
#     Importance: 0.014287
#   Predicado: Ti ka <= 19.85 (n=180)
#     Zona: 19 colunas
#     Importance: 0.096454
#   Predicado: Ti kb > -10.26 (n=185)
#     Zona: 16 colunas
#     Importance: 0.003878
#   Predicado: Ti kb <= -2.91 (n=92)
#     Zona: 16 colunas
#     Importance: 0.005599
#   Predicado: Ti kb > -2.91 (n=135)
#     Zona: 16 colunas
#     Importance: 0.002261
#   Predicado: Ti kb <= 2.45 (n=136)
#     Zona: 16 colunas
#     Importance: 0.004678
#   Predicado: Ti kb > 2.45 (n=91)
#     Zona: 16 colunas
#     Importance: 0.002024
#   Predicado: Ti kb <= 6.95 (n=182)
#     Zona: 16 colunas
#     Importance: 0.004060
#   Predicado: background1 > -1.87 (n=181)
#     Zona: 39 colunas
#     Importance: 0.000230
#   Predicado: background1 <= -1.03 (n=90)
#     Zona: 39 colunas
#     Importance: 0.000532
#   Predicado: background1 > -1.03 (n=137)
#     Zona: 39 colunas
#     Importance: 0.000221
#   Predicado: background1 <= -0.11 (n=136)
#     Zona: 39 colunas
#     Importance: 0.000396
#   Predicado: background1 > -0.11 (n=91)
#     Zona: 39 colunas
#     Importance: 0.000267
#   Predicado: background1 <= 2.08 (n=182)
#     Zona: 39 colunas
#     Importance: 0.000401
#   Predicado: Fe ka > -24.62 (n=181)
#     Zona: 25 colunas
#     Importance: 0.000599
#   Predicado: Fe ka <= -24.15 (n=94)
#     Zona: 25 colunas
#     Importance: 0.000236
#   Predicado: Fe ka > -24.15 (n=133)
#     Zona: 25 colunas
#     Importance: 0.000770
#   Predicado: Fe ka <= -23.71 (n=137)
#     Zona: 25 colunas
#     Importance: 0.000196
#   Predicado: Fe ka > -23.71 (n=90)
#     Zona: 25 colunas
#     Importance: 0.001086
#   Predicado: Fe ka <= -22.90 (n=183)
#     Zona: 25 colunas
#     Importance: 0.000170
#   Predicado: Fe kb > -7.79 (n=180)
#     Zona: 22 colunas
#     Importance: 0.001357
#   Predicado: Fe kb <= -7.41 (n=91)
#     Zona: 22 colunas
#     Importance: 0.000083
#   Predicado: Fe kb > -7.41 (n=136)
#     Zona: 22 colunas
#     Importance: 0.001779
#   Predicado: Fe kb <= -7.02 (n=138)
#     Zona: 22 colunas
#     Importance: 0.000110
#   Predicado: Fe kb > -7.02 (n=89)
#     Zona: 22 colunas
#     Importance: 0.002633
#   Predicado: Fe kb <= -6.37 (n=182)
#     Zona: 22 colunas
#     Importance: 0.000140
#   Predicado: background2 > -0.92 (n=185)
#     Zona: 18 colunas
#     Importance: 0.000116
#   Predicado: background2 <= -0.37 (n=89)
#     Zona: 18 colunas
#     Importance: 0.000149
#   Predicado: background2 > -0.37 (n=138)
#     Zona: 18 colunas
#     Importance: 0.000131
#   Predicado: background2 <= 0.27 (n=137)
#     Zona: 18 colunas
#     Importance: 0.000152
#   Predicado: background2 > 0.27 (n=90)
#     Zona: 18 colunas
#     Importance: 0.000117
#   Predicado: background2 <= 0.98 (n=182)
#     Zona: 18 colunas
#     Importance: 0.000137
#   Predicado: Cu ka > -10.68 (n=181)
#     Zona: 20 colunas
#     Importance: 0.005980
#   Predicado: Cu ka <= -9.68 (n=96)
#     Zona: 20 colunas
#     Importance: 0.001914
#   Predicado: Cu ka > -9.68 (n=131)
#     Zona: 20 colunas
#     Importance: 0.007914
#   Predicado: Cu ka <= -8.43 (n=137)
#     Zona: 20 colunas
#     Importance: 0.001411
#   Predicado: Cu ka > -8.43 (n=90)
#     Zona: 20 colunas
#     Importance: 0.011412
#   Predicado: Cu ka <= -3.28 (n=182)
#     Zona: 20 colunas
#     Importance: 0.001206
#   Predicado: Zn ka > -1.75 (n=185)
#     Zona: 21 colunas
#     Importance: 0.000168
#   Predicado: Zn ka <= -0.78 (n=83)
#     Zona: 21 colunas
#     Importance: 0.000323
#   Predicado: Zn ka > -0.78 (n=144)
#     Zona: 21 colunas
#     Importance: 0.000102
#   Predicado: Zn ka <= 0.08 (n=136)
#     Zona: 21 colunas
#     Importance: 0.000256
#   Predicado: Zn ka > 0.08 (n=91)
#     Zona: 21 colunas
#     Importance: 0.000074
#   Predicado: Zn ka <= 1.38 (n=181)
#     Zona: 21 colunas
#     Importance: 0.000212
#   Predicado: Cu kb > -2.88 (n=176)
#     Zona: 19 colunas
#     Importance: 0.000456
#   Predicado: Cu kb <= -2.30 (n=95)
#     Zona: 19 colunas
#     Importance: 0.000408
#   Predicado: Cu kb > -2.30 (n=132)
#     Zona: 19 colunas
#     Importance: 0.000538
#   Predicado: Cu kb <= -1.61 (n=140)
#     Zona: 19 colunas
#     Importance: 0.000300
#   Predicado: Cu kb > -1.61 (n=87)
#     Zona: 19 colunas
#     Importance: 0.000779
#   Predicado: Cu kb <= 0.18 (n=182)
#     Zona: 19 colunas
#     Importance: 0.000270
#   Predicado: Zn kb > -1.05 (n=184)
#     Zona: 30 colunas
#     Importance: 0.000197
#   Predicado: Zn kb <= -0.29 (n=94)
#     Zona: 30 colunas
#     Importance: 0.000287
#   Predicado: Zn kb > -0.29 (n=133)
#     Zona: 30 colunas
#     Importance: 0.000147
#   Predicado: Zn kb <= 0.29 (n=142)
#     Zona: 30 colunas
#     Importance: 0.000248
#   Predicado: Zn kb > 0.29 (n=85)
#     Zona: 30 colunas
#     Importance: 0.000134
#   Predicado: Zn kb <= 1.07 (n=186)
#     Zona: 30 colunas
#     Importance: 0.000204
#   Predicado: background3 > -2.55 (n=181)
#     Zona: 451 colunas
#     Importance: 0.001609
#   Predicado: background3 <= -0.30 (n=93)
#     Zona: 451 colunas
#     Importance: 0.006229
#   Predicado: background3 > -0.30 (n=134)
#     Zona: 451 colunas
#     Importance: 0.001267
#   Predicado: background3 <= 1.29 (n=139)
#     Zona: 451 colunas
#     Importance: 0.004863
#   Predicado: background3 > 1.29 (n=88)
#     Zona: 451 colunas
#     Importance: 0.000831
#   Predicado: background3 <= 2.86 (n=184)
#     Zona: 451 colunas
#     Importance: 0.003930
#   Predicado: Ag ka scattering > -1.65 (n=179)
#     Zona: 49 colunas
#     Importance: 0.002902
#   Predicado: Ag ka scattering <= -0.18 (n=91)
#     Zona: 49 colunas
#     Importance: 0.013215
#   Predicado: Ag ka scattering > -0.18 (n=136)
#     Zona: 49 colunas
#     Importance: 0.003604
#   Predicado: Ag ka scattering <= 1.67 (n=133)
#     Zona: 49 colunas
#     Importance: 0.009283
#   Predicado: Ag ka scattering > 1.67 (n=94)
#     Zona: 49 colunas
#     Importance: 0.004872
#   Predicado: Ag ka scattering <= 3.49 (n=177)
#     Zona: 49 colunas
#     Importance: 0.007444
#
# [Bag_5] Processando 90 predicados...
#   Predicado: Ar ka + Ag L > -1.05 (n=183)
#     Zona: 29 colunas
#     Importance: 0.000187
#   Predicado: Ar ka + Ag L <= -0.29 (n=89)
#     Zona: 29 colunas
#     Importance: 0.000273
#   Predicado: Ar ka + Ag L > -0.29 (n=138)
#     Zona: 29 colunas
#     Importance: 0.000148
#   Predicado: Ar ka + Ag L <= 0.28 (n=139)
#     Zona: 29 colunas
#     Importance: 0.000252
#   Predicado: Ar ka + Ag L > 0.28 (n=88)
#     Zona: 29 colunas
#     Importance: 0.000111
#   Predicado: Ar ka + Ag L <= 1.07 (n=183)
#     Zona: 29 colunas
#     Importance: 0.000222
#   Predicado: Ca ka > -26.11 (n=187)
#     Zona: 17 colunas
#     Importance: 0.013444
#   Predicado: Ca ka <= -21.19 (n=87)
#     Zona: 17 colunas
#     Importance: 0.011749
#   Predicado: Ca ka > -21.19 (n=140)
#     Zona: 17 colunas
#     Importance: 0.015633
#   Predicado: Ca ka <= -6.65 (n=132)
#     Zona: 17 colunas
#     Importance: 0.008158
#   Predicado: Ca ka > -6.65 (n=95)
#     Zona: 17 colunas
#     Importance: 0.022462
#   Predicado: Ca ka <= 33.38 (n=183)
#     Zona: 17 colunas
#     Importance: 0.007218
#   Predicado: Ca kb > -8.59 (n=188)
#     Zona: 13 colunas
#     Importance: 0.000334
#   Predicado: Ca kb <= -6.07 (n=87)
#     Zona: 13 colunas
#     Importance: 0.000684
#   Predicado: Ca kb > -6.07 (n=140)
#     Zona: 13 colunas
#     Importance: 0.000302
#   Predicado: Ca kb <= -2.67 (n=134)
#     Zona: 13 colunas
#     Importance: 0.000487
#   Predicado: Ca kb > -2.67 (n=93)
#     Zona: 13 colunas
#     Importance: 0.000392
#   Predicado: Ca kb <= 12.61 (n=182)
#     Zona: 13 colunas
#     Importance: 0.000463
#   Predicado: Ti ka > -28.53 (n=184)
#     Zona: 19 colunas
#     Importance: 0.055354
#   Predicado: Ti ka <= -4.69 (n=90)
#     Zona: 19 colunas
#     Importance: 0.155959
#   Predicado: Ti ka > -4.69 (n=137)
#     Zona: 19 colunas
#     Importance: 0.012329
#   Predicado: Ti ka <= 9.34 (n=136)
#     Zona: 19 colunas
#     Importance: 0.106317
#   Predicado: Ti ka > 9.34 (n=91)
#     Zona: 19 colunas
#     Importance: 0.013915
#   Predicado: Ti ka <= 19.85 (n=183)
#     Zona: 19 colunas
#     Importance: 0.082602
#   Predicado: Ti kb > -10.26 (n=183)
#     Zona: 16 colunas
#     Importance: 0.003565
#   Predicado: Ti kb <= -2.91 (n=89)
#     Zona: 16 colunas
#     Importance: 0.005656
#   Predicado: Ti kb > -2.91 (n=138)
#     Zona: 16 colunas
#     Importance: 0.001976
#   Predicado: Ti kb <= 2.45 (n=135)
#     Zona: 16 colunas
#     Importance: 0.004253
#   Predicado: Ti kb > 2.45 (n=92)
#     Zona: 16 colunas
#     Importance: 0.002194
#   Predicado: Ti kb <= 6.95 (n=181)
#     Zona: 16 colunas
#     Importance: 0.003813
#   Predicado: background1 > -1.87 (n=185)
#     Zona: 39 colunas
#     Importance: 0.000187
#   Predicado: background1 <= -1.03 (n=86)
#     Zona: 39 colunas
#     Importance: 0.000352
#   Predicado: background1 > -1.03 (n=141)
#     Zona: 39 colunas
#     Importance: 0.000165
#   Predicado: background1 <= -0.11 (n=136)
#     Zona: 39 colunas
#     Importance: 0.000297
#   Predicado: background1 > -0.11 (n=91)
#     Zona: 39 colunas
#     Importance: 0.000145
#   Predicado: background1 <= 2.08 (n=179)
#     Zona: 39 colunas
#     Importance: 0.000264
#   Predicado: Fe ka > -24.62 (n=182)
#     Zona: 25 colunas
#     Importance: 0.000655
#   Predicado: Fe ka <= -24.15 (n=87)
#     Zona: 25 colunas
#     Importance: 0.000264
#   Predicado: Fe ka > -24.15 (n=140)
#     Zona: 25 colunas
#     Importance: 0.000799
#   Predicado: Fe ka <= -23.71 (n=133)
#     Zona: 25 colunas
#     Importance: 0.000200
#   Predicado: Fe ka > -23.71 (n=94)
#     Zona: 25 colunas
#     Importance: 0.001152
#   Predicado: Fe ka <= -22.90 (n=177)
#     Zona: 25 colunas
#     Importance: 0.000176
#   Predicado: Fe kb > -7.79 (n=182)
#     Zona: 22 colunas
#     Importance: 0.001435
#   Predicado: Fe kb <= -7.41 (n=89)
#     Zona: 22 colunas
#     Importance: 0.000095
#   Predicado: Fe kb > -7.41 (n=138)
#     Zona: 22 colunas
#     Importance: 0.001873
#   Predicado: Fe kb <= -7.02 (n=138)
#     Zona: 22 colunas
#     Importance: 0.000110
#   Predicado: Fe kb > -7.02 (n=89)
#     Zona: 22 colunas
#     Importance: 0.002829
#   Predicado: Fe kb <= -6.37 (n=182)
#     Zona: 22 colunas
#     Importance: 0.000127
#   Predicado: background2 > -0.92 (n=182)
#     Zona: 18 colunas
#     Importance: 0.000110
#   Predicado: background2 <= -0.37 (n=89)
#     Zona: 18 colunas
#     Importance: 0.000149
#   Predicado: background2 > -0.37 (n=138)
#     Zona: 18 colunas
#     Importance: 0.000110
#   Predicado: background2 <= 0.27 (n=137)
#     Zona: 18 colunas
#     Importance: 0.000134
#   Predicado: background2 > 0.27 (n=90)
#     Zona: 18 colunas
#     Importance: 0.000111
#   Predicado: background2 <= 0.98 (n=180)
#     Zona: 18 colunas
#     Importance: 0.000123
#   Predicado: Cu ka > -10.68 (n=185)
#     Zona: 20 colunas
#     Importance: 0.005980
#   Predicado: Cu ka <= -9.68 (n=85)
#     Zona: 20 colunas
#     Importance: 0.001435
#   Predicado: Cu ka > -9.68 (n=142)
#     Zona: 20 colunas
#     Importance: 0.007430
#   Predicado: Cu ka <= -8.43 (n=132)
#     Zona: 20 colunas
#     Importance: 0.001003
#   Predicado: Cu ka > -8.43 (n=95)
#     Zona: 20 colunas
#     Importance: 0.010995
#   Predicado: Cu ka <= -3.28 (n=179)
#     Zona: 20 colunas
#     Importance: 0.000906
#   Predicado: Zn ka > -1.75 (n=186)
#     Zona: 21 colunas
#     Importance: 0.000144
#   Predicado: Zn ka <= -0.78 (n=84)
#     Zona: 21 colunas
#     Importance: 0.000186
#   Predicado: Zn ka > -0.78 (n=143)
#     Zona: 21 colunas
#     Importance: 0.000120
#   Predicado: Zn ka <= 0.08 (n=136)
#     Zona: 21 colunas
#     Importance: 0.000186
#   Predicado: Zn ka > 0.08 (n=91)
#     Zona: 21 colunas
#     Importance: 0.000082
#   Predicado: Zn ka <= 1.38 (n=183)
#     Zona: 21 colunas
#     Importance: 0.000159
#   Predicado: Cu kb > -2.88 (n=180)
#     Zona: 19 colunas
#     Importance: 0.000423
#   Predicado: Cu kb <= -2.30 (n=88)
#     Zona: 19 colunas
#     Importance: 0.000344
#   Predicado: Cu kb > -2.30 (n=139)
#     Zona: 19 colunas
#     Importance: 0.000485
#   Predicado: Cu kb <= -1.61 (n=135)
#     Zona: 19 colunas
#     Importance: 0.000255
#   Predicado: Cu kb > -1.61 (n=92)
#     Zona: 19 colunas
#     Importance: 0.000688
#   Predicado: Cu kb <= 0.18 (n=181)
#     Zona: 19 colunas
#     Importance: 0.000219
#   Predicado: Zn kb > -1.05 (n=183)
#     Zona: 30 colunas
#     Importance: 0.000162
#   Predicado: Zn kb <= -0.29 (n=89)
#     Zona: 30 colunas
#     Importance: 0.000222
#   Predicado: Zn kb > -0.29 (n=138)
#     Zona: 30 colunas
#     Importance: 0.000147
#   Predicado: Zn kb <= 0.29 (n=134)
#     Zona: 30 colunas
#     Importance: 0.000204
#   Predicado: Zn kb > 0.29 (n=93)
#     Zona: 30 colunas
#     Importance: 0.000137
#   Predicado: Zn kb <= 1.07 (n=181)
#     Zona: 30 colunas
#     Importance: 0.000185
#   Predicado: background3 > -2.55 (n=185)
#     Zona: 451 colunas
#     Importance: 0.001628
#   Predicado: background3 <= -0.30 (n=90)
#     Zona: 451 colunas
#     Importance: 0.004059
#   Predicado: background3 > -0.30 (n=137)
#     Zona: 451 colunas
#     Importance: 0.001265
#   Predicado: background3 <= 1.29 (n=137)
#     Zona: 451 colunas
#     Importance: 0.003318
#   Predicado: background3 > 1.29 (n=90)
#     Zona: 451 colunas
#     Importance: 0.000935
#   Predicado: background3 <= 2.86 (n=182)
#     Zona: 451 colunas
#     Importance: 0.002776
#   Predicado: Ag ka scattering > -1.65 (n=182)
#     Zona: 49 colunas
#     Importance: 0.002673
#   Predicado: Ag ka scattering <= -0.18 (n=89)
#     Zona: 49 colunas
#     Importance: 0.008924
#   Predicado: Ag ka scattering > -0.18 (n=138)
#     Zona: 49 colunas
#     Importance: 0.003246
#   Predicado: Ag ka scattering <= 1.67 (n=136)
#     Zona: 49 colunas
#     Importance: 0.006070
#   Predicado: Ag ka scattering > 1.67 (n=91)
#     Zona: 49 colunas
#     Importance: 0.004579
#   Predicado: Ag ka scattering <= 3.49 (n=182)
#     Zona: 49 colunas
#     Importance: 0.005071
#
# [Bag_6] Processando 90 predicados...
#   Predicado: Ar ka + Ag L > -1.05 (n=182)
#     Zona: 29 colunas
#     Importance: 0.000230
#   Predicado: Ar ka + Ag L <= -0.29 (n=92)
#     Zona: 29 colunas
#     Importance: 0.000386
#   Predicado: Ar ka + Ag L > -0.29 (n=135)
#     Zona: 29 colunas
#     Importance: 0.000135
#   Predicado: Ar ka + Ag L <= 0.28 (n=133)
#     Zona: 29 colunas
#     Importance: 0.000322
#   Predicado: Ar ka + Ag L > 0.28 (n=94)
#     Zona: 29 colunas
#     Importance: 0.000116
#   Predicado: Ar ka + Ag L <= 1.07 (n=178)
#     Zona: 29 colunas
#     Importance: 0.000280
#   Predicado: Ca ka > -26.11 (n=186)
#     Zona: 17 colunas
#     Importance: 0.009132
#   Predicado: Ca ka <= -21.19 (n=94)
#     Zona: 17 colunas
#     Importance: 0.012028
#   Predicado: Ca ka > -21.19 (n=133)
#     Zona: 17 colunas
#     Importance: 0.010071
#   Predicado: Ca ka <= -6.65 (n=142)
#     Zona: 17 colunas
#     Importance: 0.008204
#   Predicado: Ca ka > -6.65 (n=85)
#     Zona: 17 colunas
#     Importance: 0.015354
#   Predicado: Ca ka <= 33.38 (n=185)
#     Zona: 17 colunas
#     Importance: 0.007256
#   Predicado: Ca kb > -8.59 (n=183)
#     Zona: 13 colunas
#     Importance: 0.000319
#   Predicado: Ca kb <= -6.07 (n=94)
#     Zona: 13 colunas
#     Importance: 0.000687
#   Predicado: Ca kb > -6.07 (n=133)
#     Zona: 13 colunas
#     Importance: 0.000212
#   Predicado: Ca kb <= -2.67 (n=143)
#     Zona: 13 colunas
#     Importance: 0.000491
#   Predicado: Ca kb > -2.67 (n=84)
#     Zona: 13 colunas
#     Importance: 0.000269
#   Predicado: Ca kb <= 12.61 (n=184)
#     Zona: 13 colunas
#     Importance: 0.000455
#   Predicado: Ti ka > -28.53 (n=186)
#     Zona: 19 colunas
#     Importance: 0.068034
#   Predicado: Ti ka <= -4.69 (n=89)
#     Zona: 19 colunas
#     Importance: 0.180749
#   Predicado: Ti ka > -4.69 (n=138)
#     Zona: 19 colunas
#     Importance: 0.012270
#   Predicado: Ti ka <= 9.34 (n=136)
#     Zona: 19 colunas
#     Importance: 0.122037
#   Predicado: Ti ka > 9.34 (n=91)
#     Zona: 19 colunas
#     Importance: 0.012998
#   Predicado: Ti ka <= 19.85 (n=181)
#     Zona: 19 colunas
#     Importance: 0.094969
#   Predicado: Ti kb > -10.26 (n=182)
#     Zona: 16 colunas
#     Importance: 0.003374
#   Predicado: Ti kb <= -2.91 (n=88)
#     Zona: 16 colunas
#     Importance: 0.005320
#   Predicado: Ti kb > -2.91 (n=139)
#     Zona: 16 colunas
#     Importance: 0.001955
#   Predicado: Ti kb <= 2.45 (n=135)
#     Zona: 16 colunas
#     Importance: 0.004021
#   Predicado: Ti kb > 2.45 (n=92)
#     Zona: 16 colunas
#     Importance: 0.002143
#   Predicado: Ti kb <= 6.95 (n=179)
#     Zona: 16 colunas
#     Importance: 0.003659
#   Predicado: background1 > -1.87 (n=186)
#     Zona: 39 colunas
#     Importance: 0.000161
#   Predicado: background1 <= -1.03 (n=82)
#     Zona: 39 colunas
#     Importance: 0.000532
#   Predicado: background1 > -1.03 (n=145)
#     Zona: 39 colunas
#     Importance: 0.000150
#   Predicado: background1 <= -0.11 (n=129)
#     Zona: 39 colunas
#     Importance: 0.000401
#   Predicado: background1 > -0.11 (n=98)
#     Zona: 39 colunas
#     Importance: 0.000140
#   Predicado: background1 <= 2.08 (n=176)
#     Zona: 39 colunas
#     Importance: 0.000334
#   Predicado: Fe ka > -24.62 (n=182)
#     Zona: 25 colunas
#     Importance: 0.000625
#   Predicado: Fe ka <= -24.15 (n=87)
#     Zona: 25 colunas
#     Importance: 0.000227
#   Predicado: Fe ka > -24.15 (n=140)
#     Zona: 25 colunas
#     Importance: 0.000768
#   Predicado: Fe ka <= -23.71 (n=131)
#     Zona: 25 colunas
#     Importance: 0.000180
#   Predicado: Fe ka > -23.71 (n=96)
#     Zona: 25 colunas
#     Importance: 0.001081
#   Predicado: Fe ka <= -22.90 (n=177)
#     Zona: 25 colunas
#     Importance: 0.000159
#   Predicado: Fe kb > -7.79 (n=182)
#     Zona: 22 colunas
#     Importance: 0.001492
#   Predicado: Fe kb <= -7.41 (n=90)
#     Zona: 22 colunas
#     Importance: 0.000093
#   Predicado: Fe kb > -7.41 (n=137)
#     Zona: 22 colunas
#     Importance: 0.001960
#   Predicado: Fe kb <= -7.02 (n=139)
#     Zona: 22 colunas
#     Importance: 0.000118
#   Predicado: Fe kb > -7.02 (n=88)
#     Zona: 22 colunas
#     Importance: 0.002959
#   Predicado: Fe kb <= -6.37 (n=180)
#     Zona: 22 colunas
#     Importance: 0.000130
#   Predicado: background2 > -0.92 (n=180)
#     Zona: 18 colunas
#     Importance: 0.000110
#   Predicado: background2 <= -0.37 (n=91)
#     Zona: 18 colunas
#     Importance: 0.000136
#   Predicado: background2 > -0.37 (n=136)
#     Zona: 18 colunas
#     Importance: 0.000114
#   Predicado: background2 <= 0.27 (n=138)
#     Zona: 18 colunas
#     Importance: 0.000139
#   Predicado: background2 > 0.27 (n=89)
#     Zona: 18 colunas
#     Importance: 0.000098
#   Predicado: background2 <= 0.98 (n=182)
#     Zona: 18 colunas
#     Importance: 0.000128
#   Predicado: Cu ka > -10.68 (n=181)
#     Zona: 20 colunas
#     Importance: 0.006952
#   Predicado: Cu ka <= -9.68 (n=89)
#     Zona: 20 colunas
#     Importance: 0.001576
#   Predicado: Cu ka > -9.68 (n=138)
#     Zona: 20 colunas
#     Importance: 0.008832
#   Predicado: Cu ka <= -8.43 (n=135)
#     Zona: 20 colunas
#     Importance: 0.001112
#   Predicado: Cu ka > -8.43 (n=92)
#     Zona: 20 colunas
#     Importance: 0.013141
#   Predicado: Cu ka <= -3.28 (n=178)
#     Zona: 20 colunas
#     Importance: 0.000991
#   Predicado: Zn ka > -1.75 (n=177)
#     Zona: 21 colunas
#     Importance: 0.000134
#   Predicado: Zn ka <= -0.78 (n=91)
#     Zona: 21 colunas
#     Importance: 0.000232
#   Predicado: Zn ka > -0.78 (n=136)
#     Zona: 21 colunas
#     Importance: 0.000108
#   Predicado: Zn ka <= 0.08 (n=136)
#     Zona: 21 colunas
#     Importance: 0.000211
#   Predicado: Zn ka > 0.08 (n=91)
#     Zona: 21 colunas
#     Importance: 0.000079
#   Predicado: Zn ka <= 1.38 (n=178)
#     Zona: 21 colunas
#     Importance: 0.000179
#   Predicado: Cu kb > -2.88 (n=180)
#     Zona: 19 colunas
#     Importance: 0.000485
#   Predicado: Cu kb <= -2.30 (n=91)
#     Zona: 19 colunas
#     Importance: 0.000334
#   Predicado: Cu kb > -2.30 (n=136)
#     Zona: 19 colunas
#     Importance: 0.000569
#   Predicado: Cu kb <= -1.61 (n=135)
#     Zona: 19 colunas
#     Importance: 0.000243
#   Predicado: Cu kb > -1.61 (n=92)
#     Zona: 19 colunas
#     Importance: 0.000815
#   Predicado: Cu kb <= 0.18 (n=181)
#     Zona: 19 colunas
#     Importance: 0.000223
#   Predicado: Zn kb > -1.05 (n=181)
#     Zona: 30 colunas
#     Importance: 0.000158
#   Predicado: Zn kb <= -0.29 (n=95)
#     Zona: 30 colunas
#     Importance: 0.000218
#   Predicado: Zn kb > -0.29 (n=132)
#     Zona: 30 colunas
#     Importance: 0.000143
#   Predicado: Zn kb <= 0.29 (n=133)
#     Zona: 30 colunas
#     Importance: 0.000201
#   Predicado: Zn kb > 0.29 (n=94)
#     Zona: 30 colunas
#     Importance: 0.000136
#   Predicado: Zn kb <= 1.07 (n=180)
#     Zona: 30 colunas
#     Importance: 0.000174
#   Predicado: background3 > -2.55 (n=180)
#     Zona: 451 colunas
#     Importance: 0.001539
#   Predicado: background3 <= -0.30 (n=93)
#     Zona: 451 colunas
#     Importance: 0.004708
#   Predicado: background3 > -0.30 (n=134)
#     Zona: 451 colunas
#     Importance: 0.001333
#   Predicado: background3 <= 1.29 (n=137)
#     Zona: 451 colunas
#     Importance: 0.003850
#   Predicado: background3 > 1.29 (n=90)
#     Zona: 451 colunas
#     Importance: 0.000989
#   Predicado: background3 <= 2.86 (n=185)
#     Zona: 451 colunas
#     Importance: 0.003153
#   Predicado: Ag ka scattering > -1.65 (n=182)
#     Zona: 49 colunas
#     Importance: 0.002550
#   Predicado: Ag ka scattering <= -0.18 (n=85)
#     Zona: 49 colunas
#     Importance: 0.010553
#   Predicado: Ag ka scattering > -0.18 (n=142)
#     Zona: 49 colunas
#     Importance: 0.003094
#   Predicado: Ag ka scattering <= 1.67 (n=135)
#     Zona: 49 colunas
#     Importance: 0.006874
#   Predicado: Ag ka scattering > 1.67 (n=92)
#     Zona: 49 colunas
#     Importance: 0.004438
#   Predicado: Ag ka scattering <= 3.49 (n=181)
#     Zona: 49 colunas
#     Importance: 0.005647
#
# [Bag_7] Processando 90 predicados...
#   Predicado: Ar ka + Ag L > -1.05 (n=180)
#     Zona: 29 colunas
#     Importance: 0.000236
#   Predicado: Ar ka + Ag L <= -0.29 (n=91)
#     Zona: 29 colunas
#     Importance: 0.000325
#   Predicado: Ar ka + Ag L > -0.29 (n=136)
#     Zona: 29 colunas
#     Importance: 0.000142
#   Predicado: Ar ka + Ag L <= 0.28 (n=135)
#     Zona: 29 colunas
#     Importance: 0.000288
#   Predicado: Ar ka + Ag L > 0.28 (n=92)
#     Zona: 29 colunas
#     Importance: 0.000108
#   Predicado: Ar ka + Ag L <= 1.07 (n=177)
#     Zona: 29 colunas
#     Importance: 0.000255
#   Predicado: Ca ka > -26.11 (n=180)
#     Zona: 17 colunas
#     Importance: 0.010818
#   Predicado: Ca ka <= -21.19 (n=92)
#     Zona: 17 colunas
#     Importance: 0.012292
#   Predicado: Ca ka > -21.19 (n=135)
#     Zona: 17 colunas
#     Importance: 0.012267
#   Predicado: Ca ka <= -6.65 (n=138)
#     Zona: 17 colunas
#     Importance: 0.008527
#   Predicado: Ca ka > -6.65 (n=89)
#     Zona: 17 colunas
#     Importance: 0.018093
#   Predicado: Ca ka <= 33.38 (n=180)
#     Zona: 17 colunas
#     Importance: 0.007850
#   Predicado: Ca kb > -8.59 (n=180)
#     Zona: 13 colunas
#     Importance: 0.000329
#   Predicado: Ca kb <= -6.07 (n=92)
#     Zona: 13 colunas
#     Importance: 0.000748
#   Predicado: Ca kb > -6.07 (n=135)
#     Zona: 13 colunas
#     Importance: 0.000256
#   Predicado: Ca kb <= -2.67 (n=139)
#     Zona: 13 colunas
#     Importance: 0.000526
# ...
# Removida: Ar ka + Ag L > 0.28 -> background2 > -0.92 (0.0000) | Mantida: background2 > -0.92 -> Ar ka + Ag L > 0.28 (0.0000)
# Removida: Ar ka + Ag L > 0.28 -> Fe kb <= -7.02 (0.0000) | Mantida: Fe kb <= -7.02 -> Ar ka + Ag L > 0.28 (0.0002)
# Removida: background2 > -0.92 -> Fe kb <= -7.02 (0.0000) | Mantida: Fe kb <= -7.02 -> background2 > -0.92 (0.0001)
# Removida: Zn ka > 0.08 -> Fe kb <= -7.41 (0.0000) | Mantida: Fe kb <= -7.41 -> Zn ka > 0.08 (0.0005)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 458 | Removidas: 117
# Nós predicados: 90
# Métrica: Perturbation
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 119
# Removida: Ti ka > -4.69 -> Ti ka > 9.34 (0.0150) | Mantida: Ti ka > 9.34 -> Ti ka > -4.69 (0.0408)
# Removida: Ca ka <= -21.19 -> Ti ka > -4.69 (0.0146) | Mantida: Ti ka > -4.69 -> Ca ka <= -21.19 (0.0591)
# Removida: Ti ka > -4.69 -> Ca ka > -21.19 (0.0274) | Mantida: Ca ka > -21.19 -> Ti ka > -4.69 (0.0301)
# Removida: Ti ka > 9.34 -> Ca ka <= -21.19 (0.0136) | Mantida: Ca ka <= -21.19 -> Ti ka > 9.34 (0.0291)
# Removida: Ag ka scattering <= -0.18 -> Ti ka > 9.34 (0.0038) | Mantida: Ti ka > 9.34 -> Ag ka scattering <= -0.18 (0.0266)
# Removida: Ca ka > -21.19 -> Ti ka > 9.34 (0.0155) | Mantida: Ti ka > 9.34 -> Ca ka > -21.19 (0.0405)
# Removida: Ti ka > 9.34 -> Ca ka > -26.11 (0.0126) | Mantida: Ca ka > -26.11 -> Ti ka > 9.34 (0.0136)
# Removida: Ca ka <= -21.19 -> Ca ka > -21.19 (0.0105) | Mantida: Ca ka > -21.19 -> Ca ka <= -21.19 (0.0132)
# Removida: Cu ka > -8.43 -> Ca ka <= -21.19 (0.0117) | Mantida: Ca ka <= -21.19 -> Cu ka > -8.43 (0.0391)
# Removida: Ca ka <= -21.19 -> Ca ka > -26.11 (0.0139) | Mantida: Ca ka > -26.11 -> Ca ka <= -21.19 (0.0249)
# Removida: Ag ka scattering <= -0.18 -> Ca ka > -21.19 (0.0036) | Mantida: Ca ka > -21.19 -> Ag ka scattering <= -0.18 (0.0261)
# Removida: Ag ka scattering <= -0.18 -> Ca ka > -26.11 (0.0032) | Mantida: Ca ka > -26.11 -> Ag ka scattering <= -0.18 (0.0330)
# Removida: Cu ka > -8.43 -> Ca ka > -21.19 (0.0105) | Mantida: Ca ka > -21.19 -> Cu ka > -8.43 (0.0118)
# Removida: Ca ka > -26.11 -> Cu ka > -8.43 (0.0124) | Mantida: Cu ka > -8.43 -> Ca ka > -26.11 (0.0228)
# Removida: Ca ka <= -6.65 -> Cu ka > -8.43 (0.0101) | Mantida: Cu ka > -8.43 -> Ca ka <= -6.65 (0.0403)
# Removida: Cu ka > -9.68 -> Ca ka <= -6.65 (0.0076) | Mantida: Ca ka <= -6.65 -> Cu ka > -9.68 (0.0189)
# Removida: Ag ka scattering <= 1.67 -> Ca ka <= 33.38 (0.0074) | Mantida: Ca ka <= 33.38 -> Ag ka scattering <= 1.67 (0.0474)
# Removida: Cu ka > -9.68 -> Ca ka <= 33.38 (0.0169) | Mantida: Ca ka <= 33.38 -> Cu ka > -9.68 (0.0249)
# Removida: Ag ka scattering <= 3.49 -> Ti kb <= -2.91 (0.0017) | Mantida: Ti kb <= -2.91 -> Ag ka scattering <= 3.49 (0.0142)
# Removida: Ag ka scattering <= 3.49 -> Ti kb <= 2.45 (0.0015) | Mantida: Ti kb <= 2.45 -> Ag ka scattering <= 3.49 (0.0033)
# Removida: Ag ka scattering <= 3.49 -> Cu ka > -10.68 (0.0019) | Mantida: Cu ka > -10.68 -> Ag ka scattering <= 3.49 (0.0067)
# Removida: background3 <= -0.30 -> Cu ka > -10.68 (0.0006) | Mantida: Cu ka > -10.68 -> background3 <= -0.30 (0.0060)
# Removida: background3 <= -0.30 -> Ti kb <= -2.91 (0.0005) | Mantida: Ti kb <= -2.91 -> background3 <= -0.30 (0.0047)
# Removida: background3 <= -0.30 -> Ti kb <= 2.45 (0.0001) | Mantida: Ti kb <= 2.45 -> background3 <= -0.30 (0.0035)
# Removida: Ti kb <= -2.91 -> Cu ka > -10.68 (0.0093) | Mantida: Cu ka > -10.68 -> Ti kb <= -2.91 (0.0243)
# Removida: background3 <= 1.29 -> Ti kb <= 2.45 (0.0005) | Mantida: Ti kb <= 2.45 -> background3 <= 1.29 (0.0075)
# Removida: background3 <= 1.29 -> Ag ka scattering > 1.67 (0.0001) | Mantida: Ag ka scattering > 1.67 -> background3 <= 1.29 (0.0025)
# Removida: Ti kb <= 6.95 -> Ag ka scattering > 1.67 (0.0031) | Mantida: Ag ka scattering > 1.67 -> Ti kb <= 6.95 (0.0048)
# Removida: Ag ka scattering > 1.67 -> Ti kb > -10.26 (0.0010) | Mantida: Ti kb > -10.26 -> Ag ka scattering > 1.67 (0.0032)
# Removida: background3 <= 2.86 -> Ti kb > -10.26 (0.0003) | Mantida: Ti kb > -10.26 -> background3 <= 2.86 (0.0150)
# Removida: background3 <= 2.86 -> Ag ka scattering > -0.18 (0.0003) | Mantida: Ag ka scattering > -0.18 -> background3 <= 2.86 (0.0008)
# Removida: Ag ka scattering > -0.18 -> Ti kb > -10.26 (0.0009) | Mantida: Ti kb > -10.26 -> Ag ka scattering > -0.18 (0.0060)
# Removida: Ag ka scattering > -0.18 -> Fe kb > -7.02 (0.0025) | Mantida: Fe kb > -7.02 -> Ag ka scattering > -0.18 (0.0056)
# Removida: Ag ka scattering > -1.65 -> Ti kb > -2.91 (0.0007) | Mantida: Ti kb > -2.91 -> Ag ka scattering > -1.65 (0.0018)
# Removida: Ag ka scattering > -1.65 -> Fe kb > -7.02 (0.0028) | Mantida: Fe kb > -7.02 -> Ag ka scattering > -1.65 (0.0077)
# Removida: Ag ka scattering > -1.65 -> Fe kb > -7.41 (0.0006) | Mantida: Fe kb > -7.41 -> Ag ka scattering > -1.65 (0.0020)
# Removida: Ti kb > -2.91 -> Fe kb > -7.02 (0.0019) | Mantida: Fe kb > -7.02 -> Ti kb > -2.91 (0.0049)
# Removida: Fe kb > -7.41 -> Ti kb > -2.91 (0.0019) | Mantida: Ti kb > -2.91 -> Fe kb > -7.41 (0.0044)
# Removida: Cu ka <= -9.68 -> Ti kb > -2.91 (0.0021) | Mantida: Ti kb > -2.91 -> Cu ka <= -9.68 (0.0049)
# Removida: Ti kb > -2.91 -> Ti kb > 2.45 (0.0019) | Mantida: Ti kb > 2.45 -> Ti kb > -2.91 (0.0046)
# Removida: Ti kb > 2.45 -> Cu ka <= -9.68 (0.0034) | Mantida: Cu ka <= -9.68 -> Ti kb > 2.45 (0.0039)
# Removida: Fe kb > -7.41 -> Ti kb > 2.45 (0.0017) | Mantida: Ti kb > 2.45 -> Fe kb > -7.41 (0.0065)
# Removida: background3 > -2.55 -> Cu ka <= -9.68 (0.0001) | Mantida: Cu ka <= -9.68 -> background3 > -2.55 (0.0053)
# Removida: background3 > -2.55 -> Fe kb > -7.41 (0.0001) | Mantida: Fe kb > -7.41 -> background3 > -2.55 (0.0067)
# Removida: background3 > -2.55 -> Fe kb > -7.79 (0.0001) | Mantida: Fe kb > -7.79 -> background3 > -2.55 (0.0029)
# Removida: background3 > -0.30 -> Cu ka <= -8.43 (0.0000) | Mantida: Cu ka <= -8.43 -> background3 > -0.30 (0.0027)
# Removida: Cu ka <= -8.43 -> Fe ka > -23.71 (0.0011) | Mantida: Fe ka > -23.71 -> Cu ka <= -8.43 (0.0033)
# Removida: background3 > -0.30 -> Cu ka <= -3.28 (0.0001) | Mantida: Cu ka <= -3.28 -> background3 > -0.30 (0.0025)
# Removida: background3 > -0.30 -> Fe ka > -23.71 (0.0001) | Mantida: Fe ka > -23.71 -> background3 > -0.30 (0.0011)
# Removida: background3 > -0.30 -> Fe kb > -7.79 (0.0001) | Mantida: Fe kb > -7.79 -> background3 > -0.30 (0.0052)
# Removida: Cu ka <= -3.28 -> Fe kb > -7.79 (0.0011) | Mantida: Fe kb > -7.79 -> Cu ka <= -3.28 (0.0025)
# Removida: Fe ka > -23.71 -> Cu ka <= -3.28 (0.0010) | Mantida: Cu ka <= -3.28 -> Fe ka > -23.71 (0.0034)
# Removida: background3 > 1.29 -> Cu ka <= -3.28 (0.0000) | Mantida: Cu ka <= -3.28 -> background3 > 1.29 (0.0027)
# Removida: background3 > 1.29 -> Fe ka > -24.15 (0.0000) | Mantida: Fe ka > -24.15 -> background3 > 1.29 (0.0008)
# Removida: Fe ka > -24.15 -> Ca kb <= -6.07 (0.0015) | Mantida: Ca kb <= -6.07 -> Fe ka > -24.15 (0.0038)
# Removida: Fe ka > -24.62 -> Ca kb <= -6.07 (0.0006) | Mantida: Ca kb <= -6.07 -> Fe ka > -24.62 (0.0012)
# Removida: Cu kb > -1.61 -> Ca kb <= -6.07 (0.0005) | Mantida: Ca kb <= -6.07 -> Cu kb > -1.61 (0.0016)
# Removida: Cu kb > -1.61 -> Fe ka > -24.15 (0.0010) | Mantida: Fe ka > -24.15 -> Cu kb > -1.61 (0.0022)
# Removida: Cu kb > -1.61 -> Fe ka > -24.62 (0.0009) | Mantida: Fe ka > -24.62 -> Cu kb > -1.61 (0.0018)
# Removida: Fe ka > -24.62 -> Ca kb <= -2.67 (0.0018) | Mantida: Ca kb <= -2.67 -> Fe ka > -24.62 (0.0022)
# Removida: Cu kb > -2.30 -> Ca kb <= -2.67 (0.0003) | Mantida: Ca kb <= -2.67 -> Cu kb > -2.30 (0.0005)
# Removida: background1 <= -1.03 -> Ca kb <= 12.61 (0.0001) | Mantida: Ca kb <= 12.61 -> background1 <= -1.03 (0.0023)
# Removida: Cu kb > -2.88 -> Ca kb <= 12.61 (0.0003) | Mantida: Ca kb <= 12.61 -> Cu kb > -2.88 (0.0004)
# Removida: background1 <= -1.03 -> Cu kb > -2.30 (0.0002) | Mantida: Cu kb > -2.30 -> background1 <= -1.03 (0.0014)
# Removida: Cu kb <= -2.30 -> Cu kb > -2.88 (0.0003) | Mantida: Cu kb > -2.88 -> Cu kb <= -2.30 (0.0009)
# Removida: background1 <= 2.08 -> Cu kb <= -2.30 (0.0000) | Mantida: Cu kb <= -2.30 -> background1 <= 2.08 (0.0007)
# Removida: background1 <= -0.11 -> Cu kb <= -2.30 (0.0000) | Mantida: Cu kb <= -2.30 -> background1 <= -0.11 (0.0002)
# Removida: Cu kb <= -2.30 -> Ca kb > -8.59 (0.0002) | Mantida: Ca kb > -8.59 -> Cu kb <= -2.30 (0.0003)
# Removida: Ar ka + Ag L <= -0.29 -> Cu kb <= -2.30 (0.0000) | Mantida: Cu kb <= -2.30 -> Ar ka + Ag L <= -0.29 (0.0005)
# Removida: background1 <= -0.11 -> Cu kb > -2.88 (0.0000) | Mantida: Cu kb > -2.88 -> background1 <= -0.11 (0.0003)
# Removida: background1 <= -0.11 -> Ca kb > -8.59 (0.0001) | Mantida: Ca kb > -8.59 -> background1 <= -0.11 (0.0003)
# Removida: Ar ka + Ag L <= -0.29 -> Ca kb > -8.59 (0.0000) | Mantida: Ca kb > -8.59 -> Ar ka + Ag L <= -0.29 (0.0003)
# Removida: Ar ka + Ag L <= -0.29 -> Ca kb > -2.67 (0.0000) | Mantida: Ca kb > -2.67 -> Ar ka + Ag L <= -0.29 (0.0003)
# Removida: Ar ka + Ag L <= 0.28 -> Ca kb > -8.59 (0.0000) | Mantida: Ca kb > -8.59 -> Ar ka + Ag L <= 0.28 (0.0003)
# Removida: Zn ka <= -0.78 -> Cu kb <= 0.18 (0.0001) | Mantida: Cu kb <= 0.18 -> Zn ka <= -0.78 (0.0001)
# Removida: background1 > -0.11 -> Cu kb <= -1.61 (0.0000) | Mantida: Cu kb <= -1.61 -> background1 > -0.11 (0.0004)
# Removida: Zn kb <= -0.29 -> Cu kb <= -1.61 (0.0000) | Mantida: Cu kb <= -1.61 -> Zn kb <= -0.29 (0.0002)
# Removida: Ar ka + Ag L <= 0.28 -> background1 > -0.11 (0.0000) | Mantida: background1 > -0.11 -> Ar ka + Ag L <= 0.28 (0.0000)
# Removida: Ar ka + Ag L <= 1.07 -> background1 > -0.11 (0.0000) | Mantida: background1 > -0.11 -> Ar ka + Ag L <= 1.07 (0.0000)
# Removida: Zn ka <= 0.08 -> Cu kb <= 0.18 (0.0001) | Mantida: Cu kb <= 0.18 -> Zn ka <= 0.08 (0.0005)
# Removida: Zn kb <= -0.29 -> Zn ka <= 0.08 (0.0000) | Mantida: Zn ka <= 0.08 -> Zn kb <= -0.29 (0.0000)
# Removida: Zn kb <= -0.29 -> Cu kb <= 0.18 (0.0000) | Mantida: Cu kb <= 0.18 -> Zn kb <= -0.29 (0.0001)
# Removida: background1 > -1.03 -> Fe ka <= -22.90 (0.0000) | Mantida: Fe ka <= -22.90 -> background1 > -1.03 (0.0002)
# Removida: background2 <= 0.27 -> background1 > -1.03 (0.0000) | Mantida: background1 > -1.03 -> background2 <= 0.27 (0.0000)
# Removida: Ar ka + Ag L <= 1.07 -> Zn kb <= -0.29 (0.0000) | Mantida: Zn kb <= -0.29 -> Ar ka + Ag L <= 1.07 (0.0000)
# Removida: Ar ka + Ag L <= 1.07 -> Fe ka <= -24.15 (0.0000) | Mantida: Fe ka <= -24.15 -> Ar ka + Ag L <= 1.07 (0.0002)
# Removida: Ar ka + Ag L > -1.05 -> background1 > -1.87 (0.0000) | Mantida: background1 > -1.87 -> Ar ka + Ag L > -1.05 (0.0000)
# Removida: Zn ka <= 1.38 -> background1 > -1.87 (0.0000) | Mantida: background1 > -1.87 -> Zn ka <= 1.38 (0.0000)
# Removida: Zn kb <= 0.29 -> background1 > -1.87 (0.0000) | Mantida: background1 > -1.87 -> Zn kb <= 0.29 (0.0000)
# Removida: Zn kb <= 0.29 -> Ar ka + Ag L > -1.05 (0.0000) | Mantida: Ar ka + Ag L > -1.05 -> Zn kb <= 0.29 (0.0000)
# Removida: Ca kb > -6.07 -> Fe ka <= -24.15 (0.0002) | Mantida: Fe ka <= -24.15 -> Ca kb > -6.07 (0.0003)
# Removida: Zn kb <= 0.29 -> Fe ka <= -24.15 (0.0000) | Mantida: Fe ka <= -24.15 -> Zn kb <= 0.29 (0.0003)
# Removida: Zn ka <= 1.38 -> Fe ka <= -24.15 (0.0000) | Mantida: Fe ka <= -24.15 -> Zn ka <= 1.38 (0.0002)
# Removida: Zn kb <= 1.07 -> Zn ka <= 1.38 (0.0000) | Mantida: Zn ka <= 1.38 -> Zn kb <= 1.07 (0.0002)
# Removida: Zn kb > -1.05 -> Zn ka <= 1.38 (0.0000) | Mantida: Zn ka <= 1.38 -> Zn kb > -1.05 (0.0000)
# Removida: Zn kb <= 1.07 -> Fe ka <= -23.71 (0.0000) | Mantida: Fe ka <= -23.71 -> Zn kb <= 1.07 (0.0004)
# Removida: Zn kb <= 1.07 -> Fe ka <= -22.90 (0.0000) | Mantida: Fe ka <= -22.90 -> Zn kb <= 1.07 (0.0002)
# Removida: Zn kb > -1.05 -> Fe ka <= -22.90 (0.0000) | Mantida: Fe ka <= -22.90 -> Zn kb > -1.05 (0.0001)
# Removida: Zn kb > -1.05 -> Fe ka <= -23.71 (0.0000) | Mantida: Fe ka <= -23.71 -> Zn kb > -1.05 (0.0008)
# Removida: Zn ka > -1.75 -> Fe ka <= -23.71 (0.0000) | Mantida: Fe ka <= -23.71 -> Zn ka > -1.75 (0.0002)
# Removida: Zn kb > -0.29 -> Zn ka > -1.75 (0.0000) | Mantida: Zn ka > -1.75 -> Zn kb > -0.29 (0.0000)
# Removida: Zn kb > 0.29 -> Zn ka > -1.75 (0.0000) | Mantida: Zn ka > -1.75 -> Zn kb > 0.29 (0.0000)
# Removida: Zn ka > -1.75 -> Fe ka <= -22.90 (0.0001) | Mantida: Fe ka <= -22.90 -> Zn ka > -1.75 (0.0004)
# Removida: background2 <= -0.37 -> Zn ka > -1.75 (0.0000) | Mantida: Zn ka > -1.75 -> background2 <= -0.37 (0.0000)
# Removida: Zn kb > 0.29 -> Zn kb > -0.29 (0.0000) | Mantida: Zn kb > -0.29 -> Zn kb > 0.29 (0.0001)
# Removida: Zn kb > 0.29 -> Fe ka <= -22.90 (0.0000) | Mantida: Fe ka <= -22.90 -> Zn kb > 0.29 (0.0002)
# Removida: background2 <= -0.37 -> Fe ka <= -22.90 (0.0000) | Mantida: Fe ka <= -22.90 -> background2 <= -0.37 (0.0002)
# Removida: Ar ka + Ag L > -0.29 -> background2 <= 0.27 (0.0000) | Mantida: background2 <= 0.27 -> Ar ka + Ag L > -0.29 (0.0000)
# Removida: background2 <= -0.37 -> background2 <= 0.27 (0.0000) | Mantida: background2 <= 0.27 -> background2 <= -0.37 (0.0001)
# Removida: background2 <= 0.27 -> Fe kb <= -6.37 (0.0000) | Mantida: Fe kb <= -6.37 -> background2 <= 0.27 (0.0001)
# Removida: background2 <= 0.98 -> Fe kb <= -6.37 (0.0000) | Mantida: Fe kb <= -6.37 -> background2 <= 0.98 (0.0004)
# Removida: background2 > -0.37 -> background2 <= 0.98 (0.0000) | Mantida: background2 <= 0.98 -> background2 > -0.37 (0.0000)
# Removida: Zn ka > -0.78 -> background2 > -0.92 (0.0000) | Mantida: background2 > -0.92 -> Zn ka > -0.78 (0.0000)
# Removida: background2 > -0.92 -> Fe kb <= -7.02 (0.0000) | Mantida: Fe kb <= -7.02 -> background2 > -0.92 (0.0001)
# Removida: background2 > 0.27 -> Zn ka > -0.78 (0.0000) | Mantida: Zn ka > -0.78 -> background2 > 0.27 (0.0000)
# Removida: Zn ka > -0.78 -> Fe kb <= -7.02 (0.0000) | Mantida: Fe kb <= -7.02 -> Zn ka > -0.78 (0.0004)
# Removida: Ar ka + Ag L > 0.28 -> Fe kb <= -7.02 (0.0000) | Mantida: Fe kb <= -7.02 -> Ar ka + Ag L > 0.28 (0.0002)
# Removida: background2 > 0.27 -> Ar ka + Ag L > 0.28 (0.0000) | Mantida: Ar ka + Ag L > 0.28 -> background2 > 0.27 (0.0000)
# Removida: background2 > 0.27 -> Fe kb <= -7.02 (0.0000) | Mantida: Fe kb <= -7.02 -> background2 > 0.27 (0.0002)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 466 | Removidas: 119
# Nós predicados: 90
# Métrica: Perturbation
# Ponderação por variância explicada: ATIVADA
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#    Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0         Ti ka <= -4.69        Ti ka <= -4.69        Ti ka <= -4.69
# 1          Ti ka <= 9.34         Ti ka <= 9.34         Ti ka <= 9.34
# 2         Ti ka <= 19.85        Ti ka <= 19.85        Ti ka <= 19.85
# 3         Ti ka > -28.53        Ti ka > -28.53        Ti ka > -28.53
# 4           Ti ka > 9.34         Ca ka > -6.65         Ca ka > -6.65
# ..                   ...                   ...                   ...
# 87   background2 > -0.92   background2 <= 0.98          Zn kb > 0.29
# 88          Zn ka > 0.08         Zn kb <= 1.07    background2 > 0.27
# 89               Class_A          Zn ka > 0.08          Zn ka > 0.08
# 90               Class_B               Class_A               Class_A
# 91         Zn kb > -1.05               Class_B               Class_B
#
#    Predicate_pert_Seed_3
# 0         Ti ka <= -4.69
# 1          Ti ka <= 9.34
# 2         Ti ka <= 19.85
# 3         Ti ka > -28.53
# 4          Ca ka > -6.65
# ..                   ...
# 87         Zn kb > -1.05
# 88        Fe kb <= -7.41
# 89          Zn ka > 0.08
# 90               Class_A
# 91               Class_B
#
# [92 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#               Predicate  Perturbation
# 0        Ti ka <= -4.69      0.201546
# 1         Ti ka <= 9.34      0.139758
# 2        Ti ka <= 19.85      0.108767
# 3        Ti ka > -28.53      0.072806
# 4         Ca ka > -6.65      0.017536
# ..                  ...           ...
# 85       Fe kb <= -7.02      0.000112
# 86  Ar ka + Ag L > 0.28      0.000111
# 87        Zn ka > -0.78      0.000104
# 88       Fe kb <= -7.41      0.000087
# 89         Zn ka > 0.08      0.000081
#
# [90 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                          Node  Local_Reaching_Centrality              Zone  \
# 0              Ti ka <= -4.69                  20.474277             Ti ka
# 1               Ca ka > -6.65                   1.010520             Ca ka
# 2               Cu ka > -8.43                   0.638472             Cu ka
# 3   Ag ka scattering <= -0.18                   0.536731  Ag ka scattering
# 4               Ti kb <= 2.45                   0.289764             Ti kb
# 5        background3 <= -0.30                   0.249310       background3
# 6               Fe kb > -7.02                   0.144404             Fe kb
# 7              Fe ka > -23.71                   0.055965             Fe ka
# 8              Ca kb <= -6.07                   0.036884             Ca kb
# 9               Cu kb > -1.61                   0.032915             Cu kb
# 10       background1 <= -1.03                   0.008811       background1
# 11       Ar ka + Ag L <= 0.28                   0.006906      Ar ka + Ag L
# 12             Zn ka <= -0.78                   0.006131             Zn ka
# 13             Zn kb <= -0.29                   0.004548             Zn kb
# 14       background2 <= -0.37                   0.003275       background2
# 15                    Class_A                   0.000000              None
#
#    Threshold Operator
# 0      -4.69       <=
# 1      -6.65        >
# 2      -8.43        >
# 3      -0.18       <=
# 4       2.45       <=
# 5      -0.30       <=
# 6      -7.02        >
# 7     -23.71        >
# 8      -6.07       <=
# 9      -1.61        >
# 10     -1.03       <=
# 11      0.28       <=
# 12     -0.78       <=
# 13     -0.29       <=
# 14     -0.37       <=
# 15      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                   Node  Local_Reaching_Centrality         Zone Threshold  \
# 0       Ti ka <= -4.69                  20.474277        Ti ka     -4.69
# 1        Ti ka <= 9.34                  13.760000        Ti ka      9.34
# 2       Ti ka <= 19.85                   8.798085        Ti ka     19.85
# 3       Ti ka > -28.53                   4.300031        Ti ka    -28.53
# 4        Ca ka > -6.65                   1.010520        Ca ka     -6.65
# ..                 ...                        ...          ...       ...
# 87  background2 > 0.27                   0.002755  background2      0.27
# 88      Fe kb <= -7.41                   0.002668        Fe kb     -7.41
# 89        Zn ka > 0.08                   0.000091        Zn ka      0.08
# 90             Class_A                   0.000000         None      None
# 91             Class_B                   0.000000         None      None
#
#    Operator  Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0        <=         -49.917691                    64.0             0.070519
# 1        <=         101.580304                    11.0             0.037350
# 2        <=         207.521929                    41.0             0.066299
# 3         >        -308.117871                   246.0             0.007504
# 4         >         -72.180511                   102.0             0.000511
# ..      ...                ...                     ...                  ...
# 87        >           0.811175                    47.0             0.000881
# 88       <=         -32.289144                     4.0             0.001335
# 89        >           0.501611                     1.0             0.001115
# 90     None                NaN                     NaN                  NaN
# 91     None                NaN                     NaN                  NaN
#
#               Node_Natural
# 0      Ti ka <= -49.917691
# 1      Ti ka <= 101.580304
# 2      Ti ka <= 207.521929
# 3      Ti ka > -308.117871
# 4       Ca ka > -72.180511
# ..                     ...
# 87  background2 > 0.811175
# 88     Fe kb <= -32.289144
# 89        Zn ka > 0.501611
# 90                    None
# 91                    None
#
# [92 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Ti ka':
#   - Dimensão: 19 variáveis espectrais
#   - Variância explicada pela PC1: 98.39%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = svm_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = svm_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance_proba              Zone
# 0    6.43                      0.030117             Fe ka
# 1    4.52                      0.008501             Ti ka
# 2    3.73                      0.004085             Ca ka
# 3    8.06                      0.001287             Cu ka
# 4    4.93                      0.001100             Ti kb
# 5    7.09                      0.000962             Fe kb
# 6   21.92                      0.000841  Ag ka scattering
# 7    4.01                      0.000421             Ca kb
# 8   17.23                      0.000189       background3
# 9    8.93                      0.000182             Cu kb
# 10   5.79                      0.000110       background1
# 11   2.91                      0.000084      Ar ka + Ag L
# 12   8.52                      0.000083             Zn ka
# 13   7.58                      0.000070       background2
# 14   9.97                      0.000070             Zn kb
# 15   2.74                      0.000063               NaN

# %%
import numpy as np

max_len = max(
    len(pvector_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'SVM_pvector': pad_list(pvector_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#          SVM_pvector              Shap       Permutation  LRC_perturbation  \
# 0              Fe ka             Ti ka             Fe ka             Ti ka
# 1              Ti ka             Ca ka             Ti ka             Ca ka
# 2              Cu ka             Fe ka             Ca ka             Cu ka
# 3   Ag ka scattering             Cu ka             Cu ka  Ag ka scattering
# 4              Fe kb             Ti kb             Ti kb             Ti kb
# 5              Ti kb  Ag ka scattering             Fe kb       background3
# 6              Ca ka             Ca kb  Ag ka scattering             Fe kb
# 7              Cu kb       background2             Ca kb             Fe ka
# 8        background3       background1       background3             Ca kb
# 9              Ca kb       background3             Cu kb             Cu kb
# 10       background1             Fe kb       background1       background1
# 11             Zn ka             Cu kb      Ar ka + Ag L      Ar ka + Ag L
# 12      Ar ka + Ag L             Zn kb             Zn ka             Zn ka
# 13               NaN      Ar ka + Ag L       background2             Zn kb
# 14       background2             Zn ka             Zn kb       background2
# 15             Zn kb               NaN               NaN              None
#
#       LRC_covariance
# 0              Fe ka
# 1              Ca ka
# 2              Fe kb
# 3              Ti ka
# 4              Ca kb
# 5              Cu ka
# 6              Ti kb
# 7              Cu kb
# 8   Ag ka scattering
# 9        background3
# 10             Zn ka
# 11       background1
# 12       background2
# 13      Ar ka + Ag L
# 14             Zn kb
# 15              None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7152\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 1       SVM_pvector       Permutation   0.854802
# 5              Shap  LRC_perturbation   0.851693
# 8       Permutation    LRC_covariance   0.744760
# 3       SVM_pvector    LRC_covariance   0.661631
# 4              Shap       Permutation   0.543954
# 7       Permutation  LRC_perturbation   0.452684
# 2       SVM_pvector  LRC_perturbation   0.436356
# 0       SVM_pvector              Shap   0.435407
# 6              Shap    LRC_covariance   0.428925
# 9  LRC_perturbation    LRC_covariance   0.330692

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
