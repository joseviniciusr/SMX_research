# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' can be imported
import sys
from pathlib import Path # for path manipulations
# Move three levels up from current working directory to reach workspace root
workspace_root = Path.cwd().parent.parent.parent.resolve() 
smx_dir = workspace_root / 'smx'  # Path to smx folder
if str(smx_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(smx_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{workspace_root}/real_datasets/xrf/tomato.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '2.12':'23.08']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.12':'23.08'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.12':'23.08'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 08:53:52,188 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 08:53:52,192 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 08:53:52,205 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-27 08:53:52,210 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import svm_optimized

svm_model = svm_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, aim='classification', kernel='rbf')
svm_model[0]
# Out:
#   Model  Accuracy Cal  Sensitivity Cal  Specificity Cal             CM Cal  \
# 0   SVC      0.861111              1.0         0.642857  [[9, 5], [0, 22]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred           CM Pred
# 0          0.625               0.7               0.5  [[3, 3], [3, 7]]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('S', 2.12, 2.4),
('Cl', 2.4, 3.04),
('K ka', 3.0, 3.44),
('K kb + Ca ka', 3.44, 3.84),
('background1', 3.84, 5.7),
('Mn', 5.7, 6.04),
('Fe', 6.04, 7.3),
('Cu', 7.3, 8.32),
('Zn', 8.32, 8.84),
('background2', 8.84, 11.56),
('Br ka', 11.56, 12.5),
('Rb ka + Br kb', 12.5, 13.8),
('background3', 13.8, 17.0),
('Rh ka Compton', 17.0, 19.9),
('Rh ka Rayleigh', 19.9, 20.8),
('Rh kb Compton', 20.8, 22.3),
('Rh kb Rayleigh', 22.3, 23.08)
]

# %% [markdown]
# ## Pvector and SHAP

# %%
X_sv = svm_model[3].support_vectors_            # shape (n_SV, n_features)
alpha_dual = svm_model[3].dual_coef_.ravel()    # shape (n_SV,)

# Calculando os coeficientes p usando os vetores de suporte e os multiplicadores de Lagrange
pvetor = pd.DataFrame({'energia' : Xcalclass.columns,
                       'importance': (X_sv.T) @ alpha_dual})
pvetor['importance'] = np.abs(pvetor['importance'])
pvector_df = pd.DataFrame({
    'energy': pvetor['energia'],
    'Pvector': pvetor['importance'].values
})
pvector_df = pvector_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in pvector_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
pvector_df['Zone'] = pvector_df['energy'].map(energy_to_zone_vip)
pvector_unique_df = pvector_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
pvector_unique_df
# Out:
#    energy   Pvector            Zone
# 0    13.3  0.452578   Rb ka + Br kb
# 1     8.6  0.368908              Zn
# 2      16  0.319403     background3
# 3    2.56  0.309445              Cl
# 4    19.6  0.301037   Rh ka Compton
# 5    7.72  0.293146              Cu
# 6   22.36  0.286657  Rh kb Rayleigh
# 7   21.46  0.286334   Rh kb Compton
# 8    3.68  0.282620    K kb + Ca ka
# 9     9.3  0.273228     background2
# 10  12.42  0.268656           Br ka
# 11      4  0.241791     background1
# 12   7.06  0.211813              Fe
# 13  20.38  0.200383  Rh ka Rayleigh
# 14   3.38  0.194017            K ka
# 15   5.88  0.177285              Mn
# 16   2.24  0.155001               S

# %%
shap_global_importance = pd.read_csv('shap_tomato.csv', sep=';') # loading previously saved shap_unique_df
# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df = shap_unique_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP            Zone
# 0     3.28       0.000724            K ka
# 1    13.38       0.000512   Rb ka + Br kb
# 2     2.58       0.000207              Cl
# 3    19.16       0.000083   Rh ka Compton
# 4     3.66       0.000032    K kb + Ca ka
# 5    16.00       0.000031     background3
# 6    12.42       0.000029           Br ka
# 7    21.46       0.000029   Rh kb Compton
# 8     8.60       0.000028              Zn
# 9     6.94       0.000025              Fe
# 10    9.32       0.000021     background2
# 11   20.04       0.000015  Rh ka Rayleigh
# 12    5.48       0.000012     background1
# 13    7.76       0.000010              Cu
# 14    2.12       0.000000               S
# 15   22.50       0.000000  Rh kb Rayleigh
# 16    5.80       0.000000              Mn

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zone 'S': VE = 52.67%, dim = 15 variables
# Zone 'Cl': VE = 79.94%, dim = 33 variables
# Zone 'K ka': VE = 98.21%, dim = 23 variables
# Zone 'K kb + Ca ka': VE = 63.19%, dim = 21 variables
# Zone 'background1': VE = 17.34%, dim = 94 variables
# Zone 'Mn': VE = 56.93%, dim = 18 variables
# Zone 'Fe': VE = 57.33%, dim = 64 variables
# Zone 'Cu': VE = 53.40%, dim = 52 variables
# Zone 'Zn': VE = 60.08%, dim = 27 variables
# Zone 'background2': VE = 68.69%, dim = 137 variables
# Zone 'Br ka': VE = 65.01%, dim = 48 variables
# Zone 'Rb ka + Br kb': VE = 74.53%, dim = 66 variables
# Zone 'background3': VE = 70.02%, dim = 161 variables
# Zone 'Rh ka Compton': VE = 88.63%, dim = 146 variables
# Zone 'Rh ka Rayleigh': VE = 82.31%, dim = 46 variables
# Zone 'Rh kb Compton': VE = 81.75%, dim = 76 variables
# Zone 'Rh kb Rayleigh': VE = 69.11%, dim = 40 variables
#
# Scores DataFrame shape: (36, 17)

# %%
y_pred = svm_model[4]['SVC'].values # using the continuous predictions from SVM, extracting as 1D array
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_pred = pd.Series(svm_model[4]['SVC'].values) # using the continuous predictions from SVM, extracting as 1D array

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 112 | Discarded: 24
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 114 | Discarded: 22
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 114 | Discarded: 22
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total bidirectional pairs found: 4
# Removed: Rh ka Compton > 0.14 -> K ka <= 0.20 (0.0107) | Kept: K ka <= 0.20 -> Rh ka Compton > 0.14 (0.0122)
# Removed: K ka <= 0.20 -> K ka <= 0.44 (0.0160) | Kept: K ka <= 0.44 -> K ka <= 0.20 (0.0281)
# Removed: K ka <= 0.20 -> Rh ka Compton <= 0.45 (0.0124) | Kept: Rh ka Compton <= 0.45 -> K ka <= 0.20 (0.0233)
# Removed: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.0106) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.0116)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 32 | Removed: 4
# Predicate nodes: 11
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total bidirectional pairs found: 7
# Removed: K ka > -0.16 -> Rh ka Compton <= 0.45 (0.0125) | Kept: Rh ka Compton <= 0.45 -> K ka > -0.16 (0.0475)
# Removed: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.0109) | Kept: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.0125)
# Removed: Rh ka Compton > 0.14 -> Rh ka Compton <= 0.45 (0.0125) | Kept: Rh ka Compton <= 0.45 -> Rh ka Compton > 0.14 (0.0137)
# Removed: K ka > -0.16 -> K ka <= 0.20 (0.0124) | Kept: K ka <= 0.20 -> K ka > -0.16 (0.0137)
# Removed: K ka <= 0.44 -> K ka <= 0.20 (0.0130) | Kept: K ka <= 0.20 -> K ka <= 0.44 (0.0232)
# Removed: Rh ka Compton <= -0.05 -> K ka <= 0.20 (0.0099) | Kept: K ka <= 0.20 -> Rh ka Compton <= -0.05 (0.0124)
# Removed: Rh ka Compton <= -0.05 -> K ka <= 0.44 (0.0122) | Kept: K ka <= 0.44 -> Rh ka Compton <= -0.05 (0.0122)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 35 | Removed: 7
# Predicate nodes: 10
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 5
# Removed: Fe > 0.09 -> K ka <= 0.44 (0.0064) | Kept: K ka <= 0.44 -> Fe > 0.09 (0.0111)
# Removed: K ka <= 0.20 -> K ka <= 0.44 (0.0280) | Kept: K ka <= 0.44 -> K ka <= 0.20 (0.0426)
# Removed: Rh ka Compton > 0.14 -> K ka <= 0.44 (0.0106) | Kept: K ka <= 0.44 -> Rh ka Compton > 0.14 (0.0128)
# Removed: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.0106) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.0256)
# Removed: Rh ka Compton <= 0.14 -> Rh ka Compton > 0.45 (0.0104) | Kept: Rh ka Compton > 0.45 -> Rh ka Compton <= 0.14 (0.0200)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 34 | Removed: 5
# Predicate nodes: 11
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 8
# Removed: K ka > -0.16 -> Rh ka Compton > 0.14 (0.0101) | Kept: Rh ka Compton > 0.14 -> K ka > -0.16 (0.0146)
# Removed: Rh ka Compton > 0.45 -> Rh ka Compton > 0.14 (0.0107) | Kept: Rh ka Compton > 0.14 -> Rh ka Compton > 0.45 (0.0116)
# Removed: Rh ka Compton > 0.14 -> K ka <= 0.20 (0.0107) | Kept: K ka <= 0.20 -> Rh ka Compton > 0.14 (0.0151)
# Removed: K ka <= 0.20 -> Rh ka Compton <= 0.45 (0.0116) | Kept: Rh ka Compton <= 0.45 -> K ka <= 0.20 (0.0279)
# Removed: K ka <= 0.44 -> K ka <= 0.20 (0.0249) | Kept: K ka <= 0.20 -> K ka <= 0.44 (0.0287)
# Removed: Rh ka Compton <= 0.45 -> K ka > 0.20 (0.0104) | Kept: K ka > 0.20 -> Rh ka Compton <= 0.45 (0.0113)
# Removed: K ka <= 0.44 -> Rh ka Compton <= 0.45 (0.0142) | Kept: Rh ka Compton <= 0.45 -> K ka <= 0.44 (0.0242)
# Removed: Rh ka Compton <= 0.45 -> Rh ka Compton > 0.45 (0.0097) | Kept: Rh ka Compton > 0.45 -> Rh ka Compton <= 0.45 (0.0107)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 38 | Removed: 8
# Predicate nodes: 10
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#       Predicate_Cov_Seed_0    Predicate_Cov_Seed_1    Predicate_Cov_Seed_2  \
# 0     Rh ka Compton > 0.14            K ka <= 0.44  Rh ka Compton <= -0.05
# 1             K ka <= 0.44            K ka <= 0.20   Rh ka Compton <= 0.14
# 2    Rh ka Compton <= 0.45   Rh ka Compton <= 0.45   Rh ka Compton <= 0.45
# 3             K ka <= 0.20    Rh ka Compton > 0.45            K ka <= 0.44
# 4             K ka > -0.16   Rh ka Compton <= 0.14    Rh ka Compton > 0.45
# 5   Rh ka Compton <= -0.05             K ka > 0.20            K ka <= 0.20
# 6     Rh ka Compton > 0.45    Rh ka Compton > 0.14             K ka > 0.20
# 7                Fe > 0.09  Rh ka Compton <= -0.05    Rh ka Compton > 0.14
# 8              K ka > 0.20            K ka > -0.16               Fe > 0.09
# 9    Rh ka Compton <= 0.14               Fe > 0.09   Rh kb Compton <= 0.00
# 10     background3 <= 0.19                 Class_A     background3 <= 0.19
# 11                 Class_A                 Class_B                 Class_A
# 12                 Class_B                     NaN                 Class_B
#
#       Predicate_Cov_Seed_3
# 0   Rh ka Compton <= -0.05
# 1    Rh ka Compton <= 0.45
# 2     Rh ka Compton > 0.45
# 3             K ka <= 0.20
# 4             K ka <= 0.44
# 5              K ka > 0.20
# 6             K ka > -0.16
# 7    Rh ka Compton <= 0.14
# 8     Rh ka Compton > 0.14
# 9    Rh kb Compton <= 0.00
# 10                 Class_A
# 11                 Class_B
# 12                     NaN

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                      Node  Local_Reaching_Centrality           Zone Threshold  \
# 0  Rh ka Compton <= -0.05                   1.200414  Rh ka Compton     -0.05
# 1            K ka <= 0.44                   1.073480           K ka      0.44
# 2               Fe > 0.09                   0.646585             Fe      0.09
# 3   Rh kb Compton <= 0.00                   0.045702  Rh kb Compton      0.00
# 4     background3 <= 0.19                   0.041034    background3      0.19
# 5                 Class_A                   0.000000           None      None
#
#   Operator
# 0       <=
# 1       <=
# 2        >
# 3       <=
# 4       <=
# 5     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zone 'S': VE = 57.86%, dim = 15 variables
# Zone 'Cl': VE = 86.73%, dim = 33 variables
# Zone 'K ka': VE = 99.30%, dim = 23 variables
# Zone 'K kb + Ca ka': VE = 73.64%, dim = 21 variables
# Zone 'background1': VE = 21.46%, dim = 94 variables
# Zone 'Mn': VE = 58.45%, dim = 18 variables
# Zone 'Fe': VE = 62.13%, dim = 64 variables
# Zone 'Cu': VE = 55.31%, dim = 52 variables
# Zone 'Zn': VE = 60.70%, dim = 27 variables
# Zone 'background2': VE = 69.36%, dim = 137 variables
# Zone 'Br ka': VE = 64.96%, dim = 48 variables
# Zone 'Rb ka + Br kb': VE = 79.32%, dim = 66 variables
# Zone 'background3': VE = 69.90%, dim = 161 variables
# Zone 'Rh ka Compton': VE = 92.92%, dim = 146 variables
# Zone 'Rh ka Rayleigh': VE = 85.65%, dim = 46 variables
# Zone 'Rh kb Compton': VE = 83.08%, dim = 76 variables
# Zone 'Rh kb Rayleigh': VE = 69.80%, dim = 40 variables
#                       Node  Local_Reaching_Centrality           Zone  \
# 0   Rh ka Compton <= -0.05                   1.200414  Rh ka Compton
# 1    Rh ka Compton <= 0.45                   1.115511  Rh ka Compton
# 2             K ka <= 0.44                   1.073480           K ka
# 3             K ka <= 0.20                   0.972087           K ka
# 4     Rh ka Compton > 0.45                   0.914209  Rh ka Compton
# 5     Rh ka Compton > 0.14                   0.904340  Rh ka Compton
# 6             K ka > -0.16                   0.793494           K ka
# 7    Rh ka Compton <= 0.14                   0.705441  Rh ka Compton
# 8              K ka > 0.20                   0.657099           K ka
# 9                Fe > 0.09                   0.646585             Fe
# 10   Rh kb Compton <= 0.00                   0.045702  Rh kb Compton
# 11     background3 <= 0.19                   0.041034    background3
# 12                 Class_A                   0.000000           None
# 13                 Class_B                   0.000000           None
#
#    Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0      -0.05       <=          -0.043040                    26.0
# 1       0.45       <=           0.421114                     2.0
# 2       0.44       <=           0.522114                    34.0
# 3       0.20       <=           0.254042                    24.0
# 4       0.45        >           0.421114                     2.0
# 5       0.14        >           0.128749                     0.0
# 6      -0.16        >          -0.188342                    19.0
# 7       0.14       <=           0.128749                     0.0
# 8       0.20        >           0.254042                    24.0
# 9       0.09        >           0.019943                    13.0
# 10      0.00       <=           0.004147                     8.0
# 11      0.19       <=           0.078536                    29.0
# 12      None     None                NaN                     NaN
# 13      None     None                NaN                     NaN
#
#     Approximation_Error                Node_Natural
# 0              0.001277  Rh ka Compton <= -0.043040
# 1              0.002152   Rh ka Compton <= 0.421114
# 2              0.001978            K ka <= 0.522114
# 3              0.004192            K ka <= 0.254042
# 4              0.002152    Rh ka Compton > 0.421114
# 5              0.002250    Rh ka Compton > 0.128749
# 6              0.000301            K ka > -0.188342
# 7              0.002250   Rh ka Compton <= 0.128749
# 8              0.004192             K ka > 0.254042
# 9              0.000332               Fe > 0.019943
# 10             0.003256   Rh kb Compton <= 0.004147
# 11             0.003343     background3 <= 0.078536
# 12                  NaN                        None
# 13                  NaN                        None

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Rh ka Compton':
#   - Dimensão: 146 variáveis espectrais
#   - Range de energias: 17 - 19.9
#   - Variância explicada pela PC1: 92.92%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=svm_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 112 | Discarded: 24
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# ======================================================================
# PERTURBATION IMPORTANCE FOR PREDICATES
# ======================================================================
# Task type (aim): classification
# Perturbation mode: median
# Statistics source: full
# Metric: probability_shift
# Total folds: 10
#
#
# [Bag_1] Processing 110 predicates...
#   Predicate: S > -0.07 (n=22)
#     Zone: 15 columns
#     Importance: 0.000386
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.000368
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.000375
#   Predicate: S <= 0.01 (n=17)
#     Zone: 15 columns
#     Importance: 0.000336
#   Predicate: S > 0.01 (n=11)
#     Zone: 15 columns
#     Importance: 0.000429
#   Predicate: S <= 0.05 (n=22)
#     Zone: 15 columns
#     Importance: 0.000362
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.003046
#   Predicate: Cl <= -0.04 (n=11)
#     Zone: 33 columns
#     Importance: 0.005367
#   Predicate: Cl > -0.04 (n=17)
#     Zone: 33 columns
#     Importance: 0.003194
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.004049
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.004045
#   Predicate: Cl <= 0.16 (n=21)
#     Zone: 33 columns
#     Importance: 0.003765
#   Predicate: Cl > 0.16 (n=7)
#     Zone: 33 columns
#     Importance: 0.004895
#   Predicate: K ka <= -0.48 (n=7)
#     Zone: 23 columns
#     Importance: 0.028093
#   Predicate: K ka > -0.48 (n=21)
#     Zone: 23 columns
#     Importance: 0.014210
#   Predicate: K ka <= -0.16 (n=12)
#     Zone: 23 columns
#     Importance: 0.027019
#   Predicate: K ka > -0.16 (n=16)
#     Zone: 23 columns
#     Importance: 0.010677
#   Predicate: K ka <= 0.20 (n=16)
#     Zone: 23 columns
#     Importance: 0.021391
#   Predicate: K ka > 0.20 (n=12)
#     Zone: 23 columns
#     Importance: 0.012734
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.018675
#   Predicate: K kb + Ca ka <= -0.14 (n=7)
#     Zone: 21 columns
#     Importance: 0.004389
#   Predicate: K kb + Ca ka > -0.14 (n=21)
#     Zone: 21 columns
#     Importance: 0.003085
#   Predicate: K kb + Ca ka <= -0.02 (n=11)
#     Zone: 21 columns
#     Importance: 0.003441
#   Predicate: K kb + Ca ka > -0.02 (n=17)
#     Zone: 21 columns
#     Importance: 0.003391
#   Predicate: K kb + Ca ka <= 0.11 (n=16)
#     Zone: 21 columns
#     Importance: 0.002983
#   Predicate: K kb + Ca ka > 0.11 (n=12)
#     Zone: 21 columns
#     Importance: 0.003982
#   Predicate: K kb + Ca ka <= 0.16 (n=22)
#     Zone: 21 columns
#     Importance: 0.003518
#   Predicate: background1 > -0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.002343
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.001353
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.002662
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.001697
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.002827
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.001698
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.000551
#   Predicate: Mn <= -0.03 (n=10)
#     Zone: 18 columns
#     Importance: 0.000400
#   Predicate: Mn > -0.03 (n=18)
#     Zone: 18 columns
#     Importance: 0.000600
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.000413
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.000662
#   Predicate: Mn <= 0.02 (n=21)
#     Zone: 18 columns
#     Importance: 0.000367
#   Predicate: Mn > 0.02 (n=7)
#     Zone: 18 columns
#     Importance: 0.001015
#   Predicate: Fe > -0.12 (n=22)
#     Zone: 64 columns
#     Importance: 0.002584
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.002110
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.002919
#   Predicate: Fe <= -0.01 (n=16)
#     Zone: 64 columns
#     Importance: 0.001838
#   Predicate: Fe > -0.01 (n=12)
#     Zone: 64 columns
#     Importance: 0.003484
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.001717
#   Predicate: Cu > -0.13 (n=22)
#     Zone: 52 columns
#     Importance: 0.001604
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.002738
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.001562
#   Predicate: Cu <= 0.01 (n=16)
#     Zone: 52 columns
#     Importance: 0.002394
#   Predicate: Cu > 0.01 (n=12)
#     Zone: 52 columns
#     Importance: 0.001629
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.002194
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.001683
#   Predicate: Zn <= -0.10 (n=7)
#     Zone: 27 columns
#     Importance: 0.004095
#   Predicate: Zn > -0.10 (n=21)
#     Zone: 27 columns
#     Importance: 0.001781
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.003083
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.001891
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.002520
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.002145
#   Predicate: Zn <= 0.07 (n=21)
#     Zone: 27 columns
#     Importance: 0.002410
#   Predicate: Zn > 0.07 (n=7)
#     Zone: 27 columns
#     Importance: 0.002207
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.004427
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.008930
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.004287
#   Predicate: background2 <= 0.06 (n=17)
#     Zone: 137 columns
#     Importance: 0.006681
#   Predicate: background2 > 0.06 (n=11)
#     Zone: 137 columns
#     Importance: 0.005230
#   Predicate: background2 <= 0.18 (n=21)
#     Zone: 137 columns
#     Importance: 0.005921
#   Predicate: background2 > 0.18 (n=7)
#     Zone: 137 columns
#     Importance: 0.006681
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.003060
#   Predicate: Br ka <= -0.05 (n=11)
#     Zone: 48 columns
#     Importance: 0.003313
#   Predicate: Br ka > -0.05 (n=17)
#     Zone: 48 columns
#     Importance: 0.003017
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.002625
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.003920
#   Predicate: Br ka <= 0.17 (n=22)
#     Zone: 48 columns
#     Importance: 0.002610
#   Predicate: Rb ka + Br kb > -0.28 (n=23)
#     Zone: 66 columns
#     Importance: 0.015712
#   Predicate: Rb ka + Br kb <= -0.12 (n=10)
#     Zone: 66 columns
#     Importance: 0.012898
#   Predicate: Rb ka + Br kb > -0.12 (n=18)
#     Zone: 66 columns
#     Importance: 0.017593
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.009936
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.025158
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.010301
#   Predicate: background3 > -0.26 (n=22)
#     Zone: 161 columns
#     Importance: 0.004932
#   Predicate: background3 <= -0.04 (n=11)
#     Zone: 161 columns
#     Importance: 0.007653
#   Predicate: background3 > -0.04 (n=17)
#     Zone: 161 columns
#     Importance: 0.005267
#   Predicate: background3 <= 0.08 (n=16)
#     Zone: 161 columns
#     Importance: 0.006393
#   Predicate: background3 > 0.08 (n=12)
#     Zone: 161 columns
#     Importance: 0.005954
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.005412
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.007168
#   Predicate: Rh ka Compton <= -0.05 (n=11)
#     Zone: 146 columns
#     Importance: 0.015006
#   Predicate: Rh ka Compton > -0.05 (n=17)
#     Zone: 146 columns
#     Importance: 0.006593
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.010234
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.009295
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.009153
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.001574
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.002442
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.001494
#   Predicate: Rh ka Rayleigh <= 0.09 (n=18)
#     Zone: 46 columns
#     Importance: 0.001879
#   Predicate: Rh ka Rayleigh > 0.09 (n=10)
#     Zone: 46 columns
#     Importance: 0.001940
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.001819
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.002559
#   Predicate: Rh kb Compton <= 0.00 (n=11)
#     Zone: 76 columns
#     Importance: 0.004456
#   Predicate: Rh kb Compton > 0.00 (n=17)
#     Zone: 76 columns
#     Importance: 0.002465
#   Predicate: Rh kb Compton <= 0.10 (n=18)
#     Zone: 76 columns
#     Importance: 0.003139
#   Predicate: Rh kb Compton > 0.10 (n=10)
#     Zone: 76 columns
#     Importance: 0.003442
#   Predicate: Rh kb Compton <= 0.25 (n=23)
#     Zone: 76 columns
#     Importance: 0.002951
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.000990
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.000971
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.001143
#   Predicate: Rh kb Rayleigh <= 0.06 (n=19)
#     Zone: 40 columns
#     Importance: 0.000910
#   Predicate: Rh kb Rayleigh > 0.06 (n=9)
#     Zone: 40 columns
#     Importance: 0.001405
#   Predicate: Rh kb Rayleigh <= 0.12 (n=23)
#     Zone: 40 columns
#     Importance: 0.000912
#
# [Bag_2] Processing 110 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.000195
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.000388
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.000318
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.000355
#   Predicate: S <= 0.01 (n=18)
#     Zone: 15 columns
#     Importance: 0.000321
#   Predicate: S > 0.01 (n=10)
#     Zone: 15 columns
#     Importance: 0.000373
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.000330
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.000368
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.003502
#   Predicate: Cl <= -0.04 (n=10)
#     Zone: 33 columns
#     Importance: 0.005103
#   Predicate: Cl > -0.04 (n=18)
#     Zone: 33 columns
#     Importance: 0.003374
#   Predicate: Cl <= 0.03 (n=15)
#     Zone: 33 columns
#     Importance: 0.004021
#   Predicate: Cl > 0.03 (n=13)
#     Zone: 33 columns
#     Importance: 0.003957
#   Predicate: Cl <= 0.16 (n=20)
#     Zone: 33 columns
#     Importance: 0.003865
#   Predicate: Cl > 0.16 (n=8)
#     Zone: 33 columns
#     Importance: 0.004307
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.013716
#   Predicate: K ka <= -0.16 (n=11)
#     Zone: 23 columns
#     Importance: 0.025851
#   Predicate: K ka > -0.16 (n=17)
#     Zone: 23 columns
#     Importance: 0.009571
#   Predicate: K ka <= 0.20 (n=16)
#     Zone: 23 columns
#     Importance: 0.019337
#   Predicate: K ka > 0.20 (n=12)
#     Zone: 23 columns
#     Importance: 0.011473
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.016494
#   Predicate: K kb + Ca ka <= -0.14 (n=8)
#     Zone: 21 columns
#     Importance: 0.003549
#   Predicate: K kb + Ca ka > -0.14 (n=20)
#     Zone: 21 columns
#     Importance: 0.001777
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.002753
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.001876
#   Predicate: K kb + Ca ka <= 0.11 (n=19)
#     Zone: 21 columns
#     Importance: 0.002215
#   Predicate: K kb + Ca ka > 0.11 (n=9)
#     Zone: 21 columns
#     Importance: 0.002427
#   Predicate: K kb + Ca ka <= 0.16 (n=23)
#     Zone: 21 columns
#     Importance: 0.002064
#   Predicate: background1 <= -0.06 (n=7)
#     Zone: 94 columns
#     Importance: 0.000836
#   Predicate: background1 > -0.06 (n=21)
#     Zone: 94 columns
#     Importance: 0.002385
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.001085
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.002683
#   Predicate: background1 <= 0.01 (n=19)
#     Zone: 94 columns
#     Importance: 0.001539
#   Predicate: background1 > 0.01 (n=9)
#     Zone: 94 columns
#     Importance: 0.002965
#   Predicate: background1 <= 0.06 (n=24)
#     Zone: 94 columns
#     Importance: 0.001736
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.000472
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.000368
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.000509
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.000363
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.000579
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.000333
#   Predicate: Fe <= -0.12 (n=7)
#     Zone: 64 columns
#     Importance: 0.002172
#   Predicate: Fe > -0.12 (n=21)
#     Zone: 64 columns
#     Importance: 0.002488
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.001988
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.002774
#   Predicate: Fe <= -0.01 (n=18)
#     Zone: 64 columns
#     Importance: 0.001598
#   Predicate: Fe > -0.01 (n=10)
#     Zone: 64 columns
#     Importance: 0.003868
#   Predicate: Fe <= 0.09 (n=24)
#     Zone: 64 columns
#     Importance: 0.001600
#   Predicate: Cu > -0.13 (n=22)
#     Zone: 52 columns
#     Importance: 0.001536
#   Predicate: Cu <= -0.05 (n=13)
#     Zone: 52 columns
#     Importance: 0.002221
#   Predicate: Cu > -0.05 (n=15)
#     Zone: 52 columns
#     Importance: 0.001717
#   Predicate: Cu <= 0.01 (n=16)
#     Zone: 52 columns
#     Importance: 0.002141
#   Predicate: Cu > 0.01 (n=12)
#     Zone: 52 columns
#     Importance: 0.001698
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.002071
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.001591
#   Predicate: Zn <= -0.10 (n=7)
#     Zone: 27 columns
#     Importance: 0.003626
#   Predicate: Zn > -0.10 (n=21)
#     Zone: 27 columns
#     Importance: 0.001457
#   Predicate: Zn <= -0.03 (n=12)
#     Zone: 27 columns
#     Importance: 0.002492
#   Predicate: Zn > -0.03 (n=16)
#     Zone: 27 columns
#     Importance: 0.001630
#   Predicate: Zn <= 0.02 (n=18)
#     Zone: 27 columns
#     Importance: 0.002037
#   Predicate: Zn > 0.02 (n=10)
#     Zone: 27 columns
#     Importance: 0.001933
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.001965
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.003997
#   Predicate: background2 <= -0.07 (n=12)
#     Zone: 137 columns
#     Importance: 0.007189
#   Predicate: background2 > -0.07 (n=16)
#     Zone: 137 columns
#     Importance: 0.004272
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.005596
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.005388
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.005068
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.003157
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.003220
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.003302
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.002689
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.004160
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.002548
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.014241
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.013581
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.016354
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.010711
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.022303
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.010873
#   Predicate: background3 > -0.26 (n=23)
#     Zone: 161 columns
#     Importance: 0.004622
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.005909
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.005295
#   Predicate: background3 <= 0.08 (n=17)
#     Zone: 161 columns
#     Importance: 0.005236
#   Predicate: background3 > 0.08 (n=11)
#     Zone: 161 columns
#     Importance: 0.006057
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.004610
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.007371
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.011575
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.006724
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.008561
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.009237
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.008030
#   Predicate: Rh ka Rayleigh > -0.15 (n=22)
#     Zone: 46 columns
#     Importance: 0.001483
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.002240
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.001495
#   Predicate: Rh ka Rayleigh <= 0.09 (n=18)
#     Zone: 46 columns
#     Importance: 0.001744
#   Predicate: Rh ka Rayleigh > 0.09 (n=10)
#     Zone: 46 columns
#     Importance: 0.001941
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.001677
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.002635
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.003575
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.002595
#   Predicate: Rh kb Compton <= 0.10 (n=18)
#     Zone: 76 columns
#     Importance: 0.002717
#   Predicate: Rh kb Compton > 0.10 (n=10)
#     Zone: 76 columns
#     Importance: 0.003552
#   Predicate: Rh kb Compton <= 0.25 (n=22)
#     Zone: 76 columns
#     Importance: 0.002620
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.001011
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.000903
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.001171
#   Predicate: Rh kb Rayleigh <= 0.06 (n=19)
#     Zone: 40 columns
#     Importance: 0.000868
#   Predicate: Rh kb Rayleigh > 0.06 (n=9)
#     Zone: 40 columns
#     Importance: 0.001455
#   Predicate: Rh kb Rayleigh <= 0.12 (n=22)
#     Zone: 40 columns
#     Importance: 0.000906
#
# [Bag_3] Processing 113 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.000195
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.000336
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.000264
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.000329
#   Predicate: S <= 0.01 (n=18)
#     Zone: 15 columns
#     Importance: 0.000285
#   Predicate: S > 0.01 (n=10)
#     Zone: 15 columns
#     Importance: 0.000330
#   Predicate: S <= 0.05 (n=23)
#     Zone: 15 columns
#     Importance: 0.000312
#   Predicate: Cl <= -0.20 (n=8)
#     Zone: 33 columns
#     Importance: 0.006527
#   Predicate: Cl > -0.20 (n=20)
#     Zone: 33 columns
#     Importance: 0.002938
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.005711
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.002652
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.004701
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.002822
#   Predicate: Cl <= 0.16 (n=22)
#     Zone: 33 columns
#     Importance: 0.004180
#   Predicate: K ka > -0.48 (n=22)
#     Zone: 23 columns
#     Importance: 0.013537
#   Predicate: K ka <= -0.16 (n=11)
#     Zone: 23 columns
#     Importance: 0.026776
#   Predicate: K ka > -0.16 (n=17)
#     Zone: 23 columns
#     Importance: 0.009897
#   Predicate: K ka <= 0.20 (n=17)
#     Zone: 23 columns
#     Importance: 0.020044
#   Predicate: K ka > 0.20 (n=11)
#     Zone: 23 columns
#     Importance: 0.011093
#   Predicate: K ka <= 0.44 (n=23)
#     Zone: 23 columns
#     Importance: 0.017446
#   Predicate: K kb + Ca ka <= -0.14 (n=9)
#     Zone: 21 columns
#     Importance: 0.004056
#   Predicate: K kb + Ca ka > -0.14 (n=19)
#     Zone: 21 columns
#     Importance: 0.001584
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.003124
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.001733
#   Predicate: K kb + Ca ka <= 0.11 (n=18)
#     Zone: 21 columns
#     Importance: 0.002552
#   Predicate: K kb + Ca ka > 0.11 (n=10)
#     Zone: 21 columns
#     Importance: 0.002067
#   Predicate: K kb + Ca ka <= 0.16 (n=22)
#     Zone: 21 columns
#     Importance: 0.002332
#   Predicate: background1 <= -0.06 (n=7)
#     Zone: 94 columns
#     Importance: 0.000836
#   Predicate: background1 > -0.06 (n=21)
#     Zone: 94 columns
#     Importance: 0.002268
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.001049
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.002555
#   Predicate: background1 <= 0.01 (n=17)
#     Zone: 94 columns
#     Importance: 0.001392
#   Predicate: background1 > 0.01 (n=11)
#     Zone: 94 columns
#     Importance: 0.002710
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.001561
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.000459
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.000387
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.000493
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.000364
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.000570
#   Predicate: Mn <= 0.02 (n=23)
#     Zone: 18 columns
#     Importance: 0.000315
#   Predicate: Fe <= -0.12 (n=7)
#     Zone: 64 columns
#     Importance: 0.002172
#   Predicate: Fe > -0.12 (n=21)
#     Zone: 64 columns
#     Importance: 0.002358
#   Predicate: Fe <= -0.07 (n=11)
#     Zone: 64 columns
#     Importance: 0.001756
#   Predicate: Fe > -0.07 (n=17)
#     Zone: 64 columns
#     Importance: 0.002671
#   Predicate: Fe <= -0.01 (n=17)
#     Zone: 64 columns
#     Importance: 0.001473
#   Predicate: Fe > -0.01 (n=11)
#     Zone: 64 columns
#     Importance: 0.003608
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.001431
#   Predicate: Cu > -0.13 (n=23)
#     Zone: 52 columns
#     Importance: 0.001508
#   Predicate: Cu <= -0.05 (n=10)
#     Zone: 52 columns
#     Importance: 0.002030
#   Predicate: Cu > -0.05 (n=18)
#     Zone: 52 columns
#     Importance: 0.001583
#   Predicate: Cu <= 0.01 (n=15)
#     Zone: 52 columns
#     Importance: 0.001835
#   Predicate: Cu > 0.01 (n=13)
#     Zone: 52 columns
#     Importance: 0.001636
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.001793
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.001591
#   Predicate: Zn > -0.10 (n=22)
#     Zone: 27 columns
#     Importance: 0.001428
#   Predicate: Zn <= -0.03 (n=10)
#     Zone: 27 columns
#     Importance: 0.002597
#   Predicate: Zn > -0.03 (n=18)
#     Zone: 27 columns
#     Importance: 0.001523
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.001969
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.001824
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.001847
#   Predicate: background2 > -0.23 (n=23)
#     Zone: 137 columns
#     Importance: 0.004220
#   Predicate: background2 <= -0.07 (n=10)
#     Zone: 137 columns
#     Importance: 0.006767
#   Predicate: background2 > -0.07 (n=18)
#     Zone: 137 columns
#     Importance: 0.004332
#   Predicate: background2 <= 0.06 (n=16)
#     Zone: 137 columns
#     Importance: 0.005101
#   Predicate: background2 > 0.06 (n=12)
#     Zone: 137 columns
#     Importance: 0.005335
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.004518
#   Predicate: Br ka > -0.15 (n=23)
#     Zone: 48 columns
#     Importance: 0.002943
#   Predicate: Br ka <= -0.05 (n=10)
#     Zone: 48 columns
#     Importance: 0.002998
#   Predicate: Br ka > -0.05 (n=18)
#     Zone: 48 columns
#     Importance: 0.003037
#   Predicate: Br ka <= 0.04 (n=15)
#     Zone: 48 columns
#     Importance: 0.002502
#   Predicate: Br ka > 0.04 (n=13)
#     Zone: 48 columns
#     Importance: 0.003624
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.002413
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.013596
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.013902
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.015311
#   Predicate: Rb ka + Br kb <= -0.02 (n=18)
#     Zone: 66 columns
#     Importance: 0.009904
#   Predicate: Rb ka + Br kb > -0.02 (n=10)
#     Zone: 66 columns
#     Importance: 0.023495
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.010256
#   Predicate: background3 > -0.26 (n=24)
#     Zone: 161 columns
#     Importance: 0.004744
#   Predicate: background3 <= -0.04 (n=10)
#     Zone: 161 columns
#     Importance: 0.006314
#   Predicate: background3 > -0.04 (n=18)
#     Zone: 161 columns
#     Importance: 0.005516
#   Predicate: background3 <= 0.08 (n=15)
#     Zone: 161 columns
#     Importance: 0.005416
#   Predicate: background3 > 0.08 (n=13)
#     Zone: 161 columns
#     Importance: 0.006246
#   Predicate: background3 <= 0.19 (n=20)
#     Zone: 161 columns
#     Importance: 0.004664
#   Predicate: background3 > 0.19 (n=8)
#     Zone: 161 columns
#     Importance: 0.008644
#   Predicate: Rh ka Compton > -0.39 (n=23)
#     Zone: 146 columns
#     Importance: 0.007667
#   Predicate: Rh ka Compton <= -0.05 (n=11)
#     Zone: 146 columns
#     Importance: 0.012361
#   Predicate: Rh ka Compton > -0.05 (n=17)
#     Zone: 146 columns
#     Importance: 0.007162
#   Predicate: Rh ka Compton <= 0.14 (n=16)
#     Zone: 146 columns
#     Importance: 0.009284
#   Predicate: Rh ka Compton > 0.14 (n=12)
#     Zone: 146 columns
#     Importance: 0.009098
#   Predicate: Rh ka Compton <= 0.45 (n=20)
#     Zone: 146 columns
#     Importance: 0.008483
#   Predicate: Rh ka Compton > 0.45 (n=8)
#     Zone: 146 columns
#     Importance: 0.011009
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.001586
#   Predicate: Rh ka Rayleigh <= -0.02 (n=11)
#     Zone: 46 columns
#     Importance: 0.002106
#   Predicate: Rh ka Rayleigh > -0.02 (n=17)
#     Zone: 46 columns
#     Importance: 0.001633
#   Predicate: Rh ka Rayleigh <= 0.09 (n=16)
#     Zone: 46 columns
#     Importance: 0.001640
#   Predicate: Rh ka Rayleigh > 0.09 (n=12)
#     Zone: 46 columns
#     Importance: 0.002057
#   Predicate: Rh ka Rayleigh <= 0.21 (n=21)
#     Zone: 46 columns
#     Importance: 0.001606
#   Predicate: Rh ka Rayleigh > 0.21 (n=7)
#     Zone: 46 columns
#     Importance: 0.002456
#   Predicate: Rh kb Compton > -0.20 (n=23)
#     Zone: 76 columns
#     Importance: 0.002768
#   Predicate: Rh kb Compton <= 0.00 (n=11)
#     Zone: 76 columns
#     Importance: 0.003800
#   Predicate: Rh kb Compton > 0.00 (n=17)
#     Zone: 76 columns
#     Importance: 0.002778
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.002812
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.003747
#   Predicate: Rh kb Compton <= 0.25 (n=20)
#     Zone: 76 columns
#     Importance: 0.002712
#   Predicate: Rh kb Compton > 0.25 (n=8)
#     Zone: 76 columns
#     Importance: 0.004348
#   Predicate: Rh kb Rayleigh > -0.08 (n=23)
#     Zone: 40 columns
#     Importance: 0.001007
#   Predicate: Rh kb Rayleigh <= -0.02 (n=11)
#     Zone: 40 columns
#     Importance: 0.000791
#   Predicate: Rh kb Rayleigh > -0.02 (n=17)
#     Zone: 40 columns
#     Importance: 0.001157
#   Predicate: Rh kb Rayleigh <= 0.06 (n=18)
#     Zone: 40 columns
#     Importance: 0.000884
#   Predicate: Rh kb Rayleigh > 0.06 (n=10)
#     Zone: 40 columns
#     Importance: 0.001246
#   Predicate: Rh kb Rayleigh <= 0.12 (n=21)
#     Zone: 40 columns
#     Importance: 0.000862
#   Predicate: Rh kb Rayleigh > 0.12 (n=7)
#     Zone: 40 columns
#     Importance: 0.001467
#
# [Bag_4] Processing 108 predicates...
#   Predicate: S > -0.07 (n=23)
#     Zone: 15 columns
#     Importance: 0.000582
#   Predicate: S <= -0.02 (n=11)
#     Zone: 15 columns
#     Importance: 0.000347
#   Predicate: S > -0.02 (n=17)
#     Zone: 15 columns
#     Importance: 0.000641
#   Predicate: S <= 0.01 (n=14)
#     Zone: 15 columns
#     Importance: 0.000298
#   Predicate: S > 0.01 (n=14)
#     Zone: 15 columns
#     Importance: 0.000753
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.000578
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.000368
#   Predicate: Cl > -0.20 (n=23)
#     Zone: 33 columns
#     Importance: 0.003180
#   Predicate: Cl <= -0.04 (n=11)
#     Zone: 33 columns
#     Importance: 0.005644
#   Predicate: Cl > -0.04 (n=17)
#     Zone: 33 columns
#     Importance: 0.002919
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.004146
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.003747
#   Predicate: Cl <= 0.16 (n=22)
#     Zone: 33 columns
#     Importance: 0.003696
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.014414
#   Predicate: K ka <= -0.16 (n=10)
#     Zone: 23 columns
#     Importance: 0.023167
#   Predicate: K ka > -0.16 (n=18)
#     Zone: 23 columns
#     Importance: 0.012242
#   Predicate: K ka <= 0.20 (n=14)
#     Zone: 23 columns
#     Importance: 0.018810
#   Predicate: K ka > 0.20 (n=14)
#     Zone: 23 columns
#     Importance: 0.013478
#   Predicate: K ka <= 0.44 (n=21)
#     Zone: 23 columns
#     Importance: 0.016256
#   Predicate: K ka > 0.44 (n=7)
#     Zone: 23 columns
#     Importance: 0.015808
#   Predicate: K kb + Ca ka > -0.14 (n=22)
#     Zone: 21 columns
#     Importance: 0.002980
#   Predicate: K kb + Ca ka <= -0.02 (n=9)
#     Zone: 21 columns
#     Importance: 0.002811
#   Predicate: K kb + Ca ka > -0.02 (n=19)
#     Zone: 21 columns
#     Importance: 0.003163
#   Predicate: K kb + Ca ka <= 0.11 (n=15)
#     Zone: 21 columns
#     Importance: 0.002442
#   Predicate: K kb + Ca ka > 0.11 (n=13)
#     Zone: 21 columns
#     Importance: 0.003750
#   Predicate: K kb + Ca ka <= 0.16 (n=21)
#     Zone: 21 columns
#     Importance: 0.003157
#   Predicate: K kb + Ca ka > 0.16 (n=7)
#     Zone: 21 columns
#     Importance: 0.002727
#   Predicate: background1 > -0.06 (n=22)
#     Zone: 94 columns
#     Importance: 0.002050
#   Predicate: background1 <= -0.02 (n=13)
#     Zone: 94 columns
#     Importance: 0.001374
#   Predicate: background1 > -0.02 (n=15)
#     Zone: 94 columns
#     Importance: 0.002173
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.001661
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.002056
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.001670
#   Predicate: Mn > -0.05 (n=22)
#     Zone: 18 columns
#     Importance: 0.000491
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.000418
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.000527
#   Predicate: Mn <= -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.000425
#   Predicate: Mn > -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.000559
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.000356
#   Predicate: Fe > -0.12 (n=22)
#     Zone: 64 columns
#     Importance: 0.002703
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.001963
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.003093
#   Predicate: Fe <= -0.01 (n=17)
#     Zone: 64 columns
#     Importance: 0.001693
#   Predicate: Fe > -0.01 (n=11)
#     Zone: 64 columns
#     Importance: 0.003921
#   Predicate: Fe <= 0.09 (n=23)
#     Zone: 64 columns
#     Importance: 0.001816
#   Predicate: Cu > -0.13 (n=23)
#     Zone: 52 columns
#     Importance: 0.001496
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.002567
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.001483
#   Predicate: Cu <= 0.01 (n=18)
#     Zone: 52 columns
#     Importance: 0.002126
#   Predicate: Cu > 0.01 (n=10)
#     Zone: 52 columns
#     Importance: 0.001627
#   Predicate: Cu <= 0.11 (n=22)
#     Zone: 52 columns
#     Importance: 0.002019
#   Predicate: Zn > -0.10 (n=22)
#     Zone: 27 columns
#     Importance: 0.001845
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.002450
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.002036
#   Predicate: Zn <= 0.02 (n=18)
#     Zone: 27 columns
#     Importance: 0.002130
#   Predicate: Zn > 0.02 (n=10)
#     Zone: 27 columns
#     Importance: 0.002323
#   Predicate: Zn <= 0.07 (n=23)
#     Zone: 27 columns
#     Importance: 0.002114
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.004044
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.008485
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.004079
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.006160
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.005178
#   Predicate: background2 <= 0.18 (n=23)
#     Zone: 137 columns
#     Importance: 0.005525
#   Predicate: Br ka <= -0.15 (n=7)
#     Zone: 48 columns
#     Importance: 0.003415
#   Predicate: Br ka > -0.15 (n=21)
#     Zone: 48 columns
#     Importance: 0.002955
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.003161
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.003002
#   Predicate: Br ka <= 0.04 (n=18)
#     Zone: 48 columns
#     Importance: 0.002655
#   Predicate: Br ka > 0.04 (n=10)
#     Zone: 48 columns
#     Importance: 0.003818
#   Predicate: Br ka <= 0.17 (n=24)
#     Zone: 48 columns
#     Importance: 0.002681
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.014698
#   Predicate: Rb ka + Br kb <= -0.12 (n=10)
#     Zone: 66 columns
#     Importance: 0.016316
#   Predicate: Rb ka + Br kb > -0.12 (n=18)
#     Zone: 66 columns
#     Importance: 0.015828
#   Predicate: Rb ka + Br kb <= -0.02 (n=18)
#     Zone: 66 columns
#     Importance: 0.011580
#   Predicate: Rb ka + Br kb > -0.02 (n=10)
#     Zone: 66 columns
#     Importance: 0.023961
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.011947
#   Predicate: background3 > -0.26 (n=22)
#     Zone: 161 columns
#     Importance: 0.004616
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.007124
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.005081
#   Predicate: background3 <= 0.08 (n=17)
#     Zone: 161 columns
#     Importance: 0.006143
#   Predicate: background3 > 0.08 (n=11)
#     Zone: 161 columns
#     Importance: 0.005669
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.005469
#   Predicate: Rh ka Compton <= -0.39 (n=7)
#     Zone: 146 columns
#     Importance: 0.017709
#   Predicate: Rh ka Compton > -0.39 (n=21)
#     Zone: 146 columns
#     Importance: 0.006822
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.014368
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.005925
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.010329
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.008129
#   Predicate: Rh ka Compton <= 0.45 (n=23)
#     Zone: 146 columns
#     Importance: 0.009115
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.001679
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.002374
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.001664
#   Predicate: Rh ka Rayleigh <= 0.09 (n=17)
#     Zone: 46 columns
#     Importance: 0.001882
#   Predicate: Rh ka Rayleigh > 0.09 (n=11)
#     Zone: 46 columns
#     Importance: 0.002103
#   Predicate: Rh ka Rayleigh <= 0.21 (n=23)
#     Zone: 46 columns
#     Importance: 0.001933
#   Predicate: Rh kb Compton <= -0.20 (n=7)
#     Zone: 76 columns
#     Importance: 0.005276
#   Predicate: Rh kb Compton > -0.20 (n=21)
#     Zone: 76 columns
#     Importance: 0.002583
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.004344
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.002440
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.003293
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.003198
#   Predicate: Rh kb Compton <= 0.25 (n=24)
#     Zone: 76 columns
#     Importance: 0.003057
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.001223
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.000985
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.001434
#   Predicate: Rh kb Rayleigh <= 0.06 (n=20)
#     Zone: 40 columns
#     Importance: 0.001147
#   Predicate: Rh kb Rayleigh > 0.06 (n=8)
#     Zone: 40 columns
#     Importance: 0.001478
#   Predicate: Rh kb Rayleigh <= 0.12 (n=23)
#     Zone: 40 columns
#     Importance: 0.001121
#
# [Bag_5] Processing 107 predicates...
#   Predicate: S > -0.07 (n=22)
#     Zone: 15 columns
#     Importance: 0.000360
#   Predicate: S <= -0.02 (n=11)
#     Zone: 15 columns
#     Importance: 0.000286
#   Predicate: S > -0.02 (n=17)
#     Zone: 15 columns
#     Importance: 0.000360
#   Predicate: S <= 0.01 (n=16)
#     Zone: 15 columns
#     Importance: 0.000277
#   Predicate: S > 0.01 (n=12)
#     Zone: 15 columns
#     Importance: 0.000402
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.000319
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.000368
#   Predicate: Cl <= -0.20 (n=8)
#     Zone: 33 columns
#     Importance: 0.006527
#   Predicate: Cl > -0.20 (n=20)
#     Zone: 33 columns
#     Importance: 0.003553
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.005711
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.003422
#   Predicate: Cl <= 0.03 (n=16)
#     Zone: 33 columns
#     Importance: 0.004501
#   Predicate: Cl > 0.03 (n=12)
#     Zone: 33 columns
#     Importance: 0.004271
#   Predicate: Cl <= 0.16 (n=21)
#     Zone: 33 columns
#     Importance: 0.004239
#   Predicate: Cl > 0.16 (n=7)
#     Zone: 33 columns
#     Importance: 0.004895
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.014761
#   Predicate: K ka <= -0.16 (n=12)
#     Zone: 23 columns
#     Importance: 0.025043
#   Predicate: K ka > -0.16 (n=16)
#     Zone: 23 columns
#     Importance: 0.010662
#   Predicate: K ka <= 0.20 (n=17)
#     Zone: 23 columns
#     Importance: 0.018883
#   Predicate: K ka > 0.20 (n=11)
#     Zone: 23 columns
#     Importance: 0.013646
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.017586
#   Predicate: K kb + Ca ka <= -0.14 (n=8)
#     Zone: 21 columns
#     Importance: 0.003549
#   Predicate: K kb + Ca ka > -0.14 (n=20)
#     Zone: 21 columns
#     Importance: 0.001838
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.002753
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.001956
#   Predicate: K kb + Ca ka <= 0.11 (n=19)
#     Zone: 21 columns
#     Importance: 0.002447
#   Predicate: K kb + Ca ka > 0.11 (n=9)
#     Zone: 21 columns
#     Importance: 0.002072
#   Predicate: K kb + Ca ka <= 0.16 (n=23)
#     Zone: 21 columns
#     Importance: 0.002255
#   Predicate: background1 > -0.06 (n=22)
#     Zone: 94 columns
#     Importance: 0.002003
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.001295
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.002119
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.001570
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.002118
#   Predicate: background1 <= 0.06 (n=25)
#     Zone: 94 columns
#     Importance: 0.001675
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.000475
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.000349
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.000522
#   Predicate: Mn <= -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.000354
#   Predicate: Mn > -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.000578
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.000336
#   Predicate: Fe > -0.12 (n=23)
#     Zone: 64 columns
#     Importance: 0.002490
#   Predicate: Fe <= -0.07 (n=11)
#     Zone: 64 columns
#     Importance: 0.001778
#   Predicate: Fe > -0.07 (n=17)
#     Zone: 64 columns
#     Importance: 0.002694
#   Predicate: Fe <= -0.01 (n=16)
#     Zone: 64 columns
#     Importance: 0.001405
#   Predicate: Fe > -0.01 (n=12)
#     Zone: 64 columns
#     Importance: 0.003573
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.001460
#   Predicate: Cu > -0.13 (n=24)
#     Zone: 52 columns
#     Importance: 0.001515
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.002402
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.001555
#   Predicate: Cu <= 0.01 (n=15)
#     Zone: 52 columns
#     Importance: 0.002166
#   Predicate: Cu > 0.01 (n=13)
#     Zone: 52 columns
#     Importance: 0.001632
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.002027
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.001591
#   Predicate: Zn > -0.10 (n=23)
#     Zone: 27 columns
#     Importance: 0.001603
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.002228
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.001735
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.001808
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.002089
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.001875
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.003473
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.007758
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.003811
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.005597
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.004938
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.004864
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.002968
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.003081
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.003043
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.002441
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.004015
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.002295
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.014319
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.014574
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.016118
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.011117
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.022303
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.011174
#   Predicate: background3 > -0.26 (n=23)
#     Zone: 161 columns
#     Importance: 0.004144
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.005885
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.004609
#   Predicate: background3 <= 0.08 (n=16)
#     Zone: 161 columns
#     Importance: 0.005264
#   Predicate: background3 > 0.08 (n=12)
#     Zone: 161 columns
#     Importance: 0.005011
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.004500
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.007147
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.011966
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.006416
#   Predicate: Rh ka Compton <= 0.14 (n=17)
#     Zone: 146 columns
#     Importance: 0.009010
#   Predicate: Rh ka Compton > 0.14 (n=11)
#     Zone: 146 columns
#     Importance: 0.008462
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.008288
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.001572
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.002130
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.001475
#   Predicate: Rh ka Rayleigh <= 0.09 (n=17)
#     Zone: 46 columns
#     Importance: 0.001710
#   Predicate: Rh ka Rayleigh > 0.09 (n=11)
#     Zone: 46 columns
#     Importance: 0.001827
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.001655
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.002652
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.003570
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.002618
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.002702
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.003528
#   Predicate: Rh kb Compton <= 0.25 (n=22)
#     Zone: 76 columns
#     Importance: 0.002605
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.000807
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.000911
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.000892
#   Predicate: Rh kb Rayleigh <= 0.06 (n=18)
#     Zone: 40 columns
#     Importance: 0.000833
#   Predicate: Rh kb Rayleigh > 0.06 (n=10)
#     Zone: 40 columns
#     Importance: 0.001020
#   Predicate: Rh kb Rayleigh <= 0.12 (n=22)
#     Zone: 40 columns
#     Importance: 0.000848
#
# [Bag_6] Processing 106 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.000276
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.000604
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.000311
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.000680
#   Predicate: S <= 0.01 (n=16)
#     Zone: 15 columns
#     Importance: 0.000293
#   Predicate: S > 0.01 (n=12)
#     Zone: 15 columns
#     Importance: 0.000827
#   Predicate: S <= 0.05 (n=22)
#     Zone: 15 columns
#     Importance: 0.000549
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.003603
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.006221
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.003484
#   Predicate: Cl <= 0.03 (n=16)
#     Zone: 33 columns
#     Importance: 0.004988
#   Predicate: Cl > 0.03 (n=12)
#     Zone: 33 columns
#     Importance: 0.004215
#   Predicate: Cl <= 0.16 (n=20)
#     Zone: 33 columns
#     Importance: 0.004796
#   Predicate: Cl > 0.16 (n=8)
#     Zone: 33 columns
#     Importance: 0.004307
#   Predicate: K ka > -0.48 (n=24)
#     Zone: 23 columns
#     Importance: 0.014171
#   Predicate: K ka <= -0.16 (n=9)
#     Zone: 23 columns
# ...
# Removed: K ka > -0.48 -> Rb ka + Br kb > -0.12 (0.0152) | Kept: Rb ka + Br kb > -0.12 -> K ka > -0.48 (0.0440)
# Removed: Rh ka Compton <= -0.05 -> Rb ka + Br kb > -0.12 (0.0136) | Kept: Rb ka + Br kb > -0.12 -> Rh ka Compton <= -0.05 (0.0258)
# Removed: Rb ka + Br kb > -0.12 -> K ka > 0.20 (0.0115) | Kept: K ka > 0.20 -> Rb ka + Br kb > -0.12 (0.0139)
# Removed: Rb ka + Br kb <= -0.12 -> K ka <= 0.44 (0.0117) | Kept: K ka <= 0.44 -> Rb ka + Br kb <= -0.12 (0.0325)
# Removed: Rb ka + Br kb <= -0.28 -> K ka <= 0.44 (0.0135) | Kept: K ka <= 0.44 -> Rb ka + Br kb <= -0.28 (0.0170)
# Removed: Rb ka + Br kb > -0.28 -> Rh ka Compton <= -0.05 (0.0095) | Kept: Rh ka Compton <= -0.05 -> Rb ka + Br kb > -0.28 (0.0532)
# Removed: K ka > -0.48 -> Rh ka Compton <= -0.05 (0.0289) | Kept: Rh ka Compton <= -0.05 -> K ka > -0.48 (0.0403)
# Removed: Rb ka + Br kb > -0.28 -> K ka > -0.48 (0.0110) | Kept: K ka > -0.48 -> Rb ka + Br kb > -0.28 (0.0424)
# Removed: K ka > 0.20 -> Rb ka + Br kb > -0.28 (0.0135) | Kept: Rb ka + Br kb > -0.28 -> K ka > 0.20 (0.0216)
# Removed: Rb ka + Br kb <= -0.12 -> Rb ka + Br kb > -0.28 (0.0107) | Kept: Rb ka + Br kb > -0.28 -> Rb ka + Br kb <= -0.12 (0.0325)
# Removed: K ka > 0.20 -> Rb ka + Br kb <= -0.12 (0.0274) | Kept: Rb ka + Br kb <= -0.12 -> K ka > 0.20 (0.0392)
# Removed: Rb ka + Br kb <= -0.12 -> K ka > -0.16 (0.0096) | Kept: K ka > -0.16 -> Rb ka + Br kb <= -0.12 (0.0108)
# Removed: Rb ka + Br kb <= 0.14 -> Rh ka Compton <= 0.14 (0.0074) | Kept: Rh ka Compton <= 0.14 -> Rb ka + Br kb <= 0.14 (0.0470)
# Removed: Rh ka Compton > 0.14 -> Rh ka Compton <= 0.14 (0.0074) | Kept: Rh ka Compton <= 0.14 -> Rh ka Compton > 0.14 (0.0077)
# Removed: K ka > -0.16 -> Rh ka Compton <= 0.14 (0.0115) | Kept: Rh ka Compton <= 0.14 -> K ka > -0.16 (0.0298)
# Removed: Rb ka + Br kb <= 0.14 -> Rh ka Compton <= 0.45 (0.0078) | Kept: Rh ka Compton <= 0.45 -> Rb ka + Br kb <= 0.14 (0.0170)
# Removed: Rb ka + Br kb <= 0.14 -> Rh ka Compton > 0.45 (0.0074) | Kept: Rh ka Compton > 0.45 -> Rb ka + Br kb <= 0.14 (0.0098)
# Removed: Rb ka + Br kb <= -0.02 -> Rb ka + Br kb <= 0.14 (0.0079) | Kept: Rb ka + Br kb <= 0.14 -> Rb ka + Br kb <= -0.02 (0.0147)
# Removed: Rh ka Compton <= 0.45 -> Rb ka + Br kb <= -0.02 (0.0090) | Kept: Rb ka + Br kb <= -0.02 -> Rh ka Compton <= 0.45 (0.0148)
# Removed: background2 <= -0.07 -> Rh ka Compton <= 0.45 (0.0063) | Kept: Rh ka Compton <= 0.45 -> background2 <= -0.07 (0.0156)
# Removed: Rh ka Compton > 0.14 -> Rh ka Compton <= 0.45 (0.0072) | Kept: Rh ka Compton <= 0.45 -> Rh ka Compton > 0.14 (0.0245)
# Removed: Rh ka Compton > 0.14 -> background2 <= -0.07 (0.0151) | Kept: background2 <= -0.07 -> Rh ka Compton > 0.14 (0.0222)
# Removed: background3 <= -0.04 -> background2 <= -0.07 (0.0051) | Kept: background2 <= -0.07 -> background3 <= -0.04 (0.0163)
# Removed: Rh ka Compton > -0.39 -> background3 <= -0.04 (0.0067) | Kept: background3 <= -0.04 -> Rh ka Compton > -0.39 (0.0159)
# Removed: Rh ka Compton > -0.39 -> Rh ka Compton > -0.05 (0.0056) | Kept: Rh ka Compton > -0.05 -> Rh ka Compton > -0.39 (0.0057)
# Removed: Rh ka Compton > -0.05 -> background3 <= -0.04 (0.0055) | Kept: background3 <= -0.04 -> Rh ka Compton > -0.05 (0.0100)
# Removed: Rh ka Compton > -0.05 -> background3 <= 0.08 (0.0060) | Kept: background3 <= 0.08 -> Rh ka Compton > -0.05 (0.0136)
# Removed: background3 <= 0.19 -> Rh ka Compton > -0.05 (0.0040) | Kept: Rh ka Compton > -0.05 -> background3 <= 0.19 (0.0054)
# Removed: background3 > 0.08 -> Rh ka Compton > -0.05 (0.0046) | Kept: Rh ka Compton > -0.05 -> background3 > 0.08 (0.0057)
# Removed: background2 <= 0.06 -> background3 <= 0.08 (0.0042) | Kept: background3 <= 0.08 -> background2 <= 0.06 (0.0137)
# Removed: background3 > -0.04 -> background2 <= 0.06 (0.0035) | Kept: background2 <= 0.06 -> background3 > -0.04 (0.0079)
# Removed: background3 > 0.08 -> background2 <= 0.06 (0.0040) | Kept: background2 <= 0.06 -> background3 > 0.08 (0.0047)
# Removed: background2 <= 0.18 -> background3 <= 0.19 (0.0031) | Kept: background3 <= 0.19 -> background2 <= 0.18 (0.0042)
# Removed: background2 > 0.06 -> background3 <= 0.19 (0.0078) | Kept: background3 <= 0.19 -> background2 > 0.06 (0.0080)
# Removed: background2 <= 0.18 -> background3 > 0.08 (0.0038) | Kept: background3 > 0.08 -> background2 <= 0.18 (0.0077)
# Removed: background3 > 0.08 -> background2 > 0.06 (0.0038) | Kept: background2 > 0.06 -> background3 > 0.08 (0.0079)
# Removed: background3 > -0.04 -> background2 <= 0.18 (0.0037) | Kept: background2 <= 0.18 -> background3 > -0.04 (0.0112)
# Removed: background2 <= 0.18 -> Cl <= -0.20 (0.0040) | Kept: Cl <= -0.20 -> background2 <= 0.18 (0.0046)
# Removed: background2 > 0.06 -> background3 > -0.04 (0.0036) | Kept: background3 > -0.04 -> background2 > 0.06 (0.0116)
# Removed: background3 > -0.04 -> Rh kb Compton <= 0.00 (0.0066) | Kept: Rh kb Compton <= 0.00 -> background3 > -0.04 (0.0084)
# Removed: background3 > -0.26 -> Rh kb Compton <= 0.00 (0.0036) | Kept: Rh kb Compton <= 0.00 -> background3 > -0.26 (0.0075)
# Removed: background2 > -0.23 -> background3 > -0.26 (0.0029) | Kept: background3 > -0.26 -> background2 > -0.23 (0.0100)
# Removed: Br ka > 0.04 -> Cl <= 0.03 (0.0025) | Kept: Cl <= 0.03 -> Br ka > 0.04 (0.0064)
# Removed: Cl > 0.03 -> Br ka > 0.04 (0.0033) | Kept: Br ka > 0.04 -> Cl > 0.03 (0.0049)
# Removed: Br ka > 0.04 -> Cl <= 0.16 (0.0027) | Kept: Cl <= 0.16 -> Br ka > 0.04 (0.0030)
# Removed: K kb + Ca ka > 0.11 -> background2 > -0.23 (0.0028) | Kept: background2 > -0.23 -> K kb + Ca ka > 0.11 (0.0030)
# Removed: background2 > -0.07 -> background2 > -0.23 (0.0033) | Kept: background2 > -0.23 -> background2 > -0.07 (0.0126)
# Removed: Fe > -0.01 -> Cl <= 0.16 (0.0021) | Kept: Cl <= 0.16 -> Fe > -0.01 (0.0032)
# Removed: K kb + Ca ka > -0.02 -> Rh kb Compton <= 0.10 (0.0020) | Kept: Rh kb Compton <= 0.10 -> K kb + Ca ka > -0.02 (0.0028)
# Removed: K kb + Ca ka > 0.11 -> K kb + Ca ka <= -0.14 (0.0027) | Kept: K kb + Ca ka <= -0.14 -> K kb + Ca ka > 0.11 (0.0027)
# Removed: K kb + Ca ka <= -0.14 -> Cl <= 0.03 (0.0027) | Kept: Cl <= 0.03 -> K kb + Ca ka <= -0.14 (0.0032)
# Removed: Cl <= 0.16 -> Cl <= 0.03 (0.0023) | Kept: Cl <= 0.03 -> Cl <= 0.16 (0.0035)
# Removed: Rh kb Compton > 0.10 -> Cl > 0.03 (0.0029) | Kept: Cl > 0.03 -> Rh kb Compton > 0.10 (0.0059)
# Removed: K kb + Ca ka <= -0.02 -> Rh kb Compton > 0.10 (0.0022) | Kept: Rh kb Compton > 0.10 -> K kb + Ca ka <= -0.02 (0.0027)
# Removed: K kb + Ca ka <= 0.16 -> Rh kb Compton > 0.10 (0.0021) | Kept: Rh kb Compton > 0.10 -> K kb + Ca ka <= 0.16 (0.0028)
# Removed: Rh kb Compton > 0.25 -> Cl > 0.03 (0.0034) | Kept: Cl > 0.03 -> Rh kb Compton > 0.25 (0.0035)
# Removed: Br ka <= 0.04 -> Rh kb Compton <= 0.25 (0.0019) | Kept: Rh kb Compton <= 0.25 -> Br ka <= 0.04 (0.0023)
# Removed: Br ka > -0.05 -> Rh kb Compton <= 0.25 (0.0023) | Kept: Rh kb Compton <= 0.25 -> Br ka > -0.05 (0.0028)
# Removed: K kb + Ca ka <= 0.16 -> Br ka <= -0.05 (0.0020) | Kept: Br ka <= -0.05 -> K kb + Ca ka <= 0.16 (0.0062)
# Removed: K kb + Ca ka > -0.02 -> Br ka <= -0.05 (0.0019) | Kept: Br ka <= -0.05 -> K kb + Ca ka > -0.02 (0.0021)
# Removed: Br ka > -0.05 -> Br ka <= -0.05 (0.0021) | Kept: Br ka <= -0.05 -> Br ka > -0.05 (0.0022)
# Removed: K kb + Ca ka > 0.11 -> Cl <= 0.16 (0.0030) | Kept: Cl <= 0.16 -> K kb + Ca ka > 0.11 (0.0032)
# Removed: Cl > -0.20 -> Cl > -0.04 (0.0049) | Kept: Cl > -0.04 -> Cl > -0.20 (0.0081)
# Removed: K kb + Ca ka > -0.02 -> Cl > -0.20 (0.0022) | Kept: Cl > -0.20 -> K kb + Ca ka > -0.02 (0.0027)
# Removed: Zn > -0.03 -> Fe > -0.07 (0.0011) | Kept: Fe > -0.07 -> Zn > -0.03 (0.0012)
# Removed: Cl > -0.04 -> K kb + Ca ka <= 0.16 (0.0029) | Kept: K kb + Ca ka <= 0.16 -> Cl > -0.04 (0.0042)
# Removed: Rh kb Compton > 0.00 -> Rh kb Compton > -0.20 (0.0064) | Kept: Rh kb Compton > -0.20 -> Rh kb Compton > 0.00 (0.0091)
# Removed: Br ka > -0.15 -> Br ka > -0.05 (0.0038) | Kept: Br ka > -0.05 -> Br ka > -0.15 (0.0045)
# Removed: Fe > -0.12 -> Rh kb Compton > -0.20 (0.0015) | Kept: Rh kb Compton > -0.20 -> Fe > -0.12 (0.0022)
# Removed: Zn <= -0.03 -> Rh ka Rayleigh > 0.09 (0.0013) | Kept: Rh ka Rayleigh > 0.09 -> Zn <= -0.03 (0.0018)
# Removed: K kb + Ca ka <= 0.11 -> Zn <= -0.03 (0.0017) | Kept: Zn <= -0.03 -> K kb + Ca ka <= 0.11 (0.0019)
# Removed: Fe > -0.12 -> Br ka <= 0.04 (0.0015) | Kept: Br ka <= 0.04 -> Fe > -0.12 (0.0018)
# Removed: K kb + Ca ka > -0.14 -> Br ka <= 0.04 (0.0036) | Kept: Br ka <= 0.04 -> K kb + Ca ka > -0.14 (0.0037)
# Removed: Br ka <= 0.17 -> Rh ka Rayleigh <= -0.02 (0.0035) | Kept: Rh ka Rayleigh <= -0.02 -> Br ka <= 0.17 (0.0042)
# Removed: background1 > -0.02 -> Rh ka Rayleigh <= -0.02 (0.0008) | Kept: Rh ka Rayleigh <= -0.02 -> background1 > -0.02 (0.0020)
# Removed: Fe > -0.12 -> Br ka <= 0.17 (0.0015) | Kept: Br ka <= 0.17 -> Fe > -0.12 (0.0017)
# Removed: background1 > -0.02 -> Cu <= -0.05 (0.0004) | Kept: Cu <= -0.05 -> background1 > -0.02 (0.0014)
# Removed: background1 > -0.02 -> K kb + Ca ka <= 0.11 (0.0005) | Kept: K kb + Ca ka <= 0.11 -> background1 > -0.02 (0.0016)
# Removed: background1 > 0.01 -> K kb + Ca ka <= 0.11 (0.0009) | Kept: K kb + Ca ka <= 0.11 -> background1 > 0.01 (0.0034)
# Removed: Cu <= 0.01 -> Rh ka Rayleigh <= 0.09 (0.0009) | Kept: Rh ka Rayleigh <= 0.09 -> Cu <= 0.01 (0.0017)
# Removed: Cu <= 0.01 -> Cu <= 0.11 (0.0011) | Kept: Cu <= 0.11 -> Cu <= 0.01 (0.0011)
# Removed: Cu <= 0.01 -> Zn > 0.02 (0.0011) | Kept: Zn > 0.02 -> Cu <= 0.01 (0.0013)
# Removed: background1 > -0.06 -> Cu <= 0.01 (0.0004) | Kept: Cu <= 0.01 -> background1 > -0.06 (0.0011)
# Removed: Zn > 0.02 -> Rh ka Rayleigh > 0.09 (0.0013) | Kept: Rh ka Rayleigh > 0.09 -> Zn > 0.02 (0.0034)
# Removed: Zn > 0.02 -> Zn > -0.03 (0.0011) | Kept: Zn > -0.03 -> Zn > 0.02 (0.0012)
# Removed: background1 > -0.06 -> Zn <= 0.07 (0.0004) | Kept: Zn <= 0.07 -> background1 > -0.06 (0.0026)
# Removed: Rh ka Rayleigh <= 0.09 -> Zn <= 0.07 (0.0019) | Kept: Zn <= 0.07 -> Rh ka Rayleigh <= 0.09 (0.0024)
# Removed: Cu <= 0.11 -> Zn <= 0.07 (0.0010) | Kept: Zn <= 0.07 -> Cu <= 0.11 (0.0013)
# Removed: Cu <= 0.11 -> Rh ka Rayleigh <= 0.09 (0.0011) | Kept: Rh ka Rayleigh <= 0.09 -> Cu <= 0.11 (0.0018)
# Removed: Rh ka Rayleigh > 0.09 -> Cu <= 0.11 (0.0017) | Kept: Cu <= 0.11 -> Rh ka Rayleigh > 0.09 (0.0023)
# Removed: Zn > -0.10 -> Rh ka Rayleigh <= 0.21 (0.0011) | Kept: Rh ka Rayleigh <= 0.21 -> Zn > -0.10 (0.0015)
# Removed: Rh ka Rayleigh > 0.09 -> Rh ka Rayleigh > 0.21 (0.0018) | Kept: Rh ka Rayleigh > 0.21 -> Rh ka Rayleigh > 0.09 (0.0019)
# Removed: Zn > -0.03 -> Fe <= -0.07 (0.0011) | Kept: Fe <= -0.07 -> Zn > -0.03 (0.0011)
# Removed: Zn > -0.10 -> Fe <= -0.07 (0.0011) | Kept: Fe <= -0.07 -> Zn > -0.10 (0.0021)
# Removed: Zn > -0.10 -> Rh ka Rayleigh > -0.15 (0.0010) | Kept: Rh ka Rayleigh > -0.15 -> Zn > -0.10 (0.0031)
# Removed: Cu > -0.13 -> Zn > -0.10 (0.0009) | Kept: Zn > -0.10 -> Cu > -0.13 (0.0010)
# Removed: Fe <= -0.01 -> Rh ka Rayleigh > -0.15 (0.0011) | Kept: Rh ka Rayleigh > -0.15 -> Fe <= -0.01 (0.0014)
# Removed: background1 <= 0.01 -> background1 <= 0.06 (0.0005) | Kept: background1 <= 0.06 -> background1 <= 0.01 (0.0006)
# Removed: background1 <= 0.01 -> Fe <= 0.09 (0.0005) | Kept: Fe <= 0.09 -> background1 <= 0.01 (0.0009)
# Removed: background1 <= 0.01 -> Cu > 0.01 (0.0003) | Kept: Cu > 0.01 -> background1 <= 0.01 (0.0010)
# Removed: background1 <= 0.01 -> Rh kb Rayleigh > 0.06 (0.0003) | Kept: Rh kb Rayleigh > 0.06 -> background1 <= 0.01 (0.0011)
# Removed: background1 <= 0.06 -> Fe <= -0.01 (0.0006) | Kept: Fe <= -0.01 -> background1 <= 0.06 (0.0009)
# Removed: Cu > 0.01 -> Fe <= -0.01 (0.0008) | Kept: Fe <= -0.01 -> Cu > 0.01 (0.0028)
# Removed: Fe <= -0.01 -> Fe <= 0.09 (0.0009) | Kept: Fe <= 0.09 -> Fe <= -0.01 (0.0012)
# Removed: Fe <= -0.01 -> Rh ka Rayleigh > -0.02 (0.0011) | Kept: Rh ka Rayleigh > -0.02 -> Fe <= -0.01 (0.0016)
# Removed: Cu > -0.13 -> Cu > -0.05 (0.0017) | Kept: Cu > -0.05 -> Cu > -0.13 (0.0033)
# Removed: Cu > -0.13 -> Rh ka Rayleigh > -0.02 (0.0008) | Kept: Rh ka Rayleigh > -0.02 -> Cu > -0.13 (0.0014)
# Removed: Cu > -0.13 -> Rh kb Rayleigh > -0.02 (0.0007) | Kept: Rh kb Rayleigh > -0.02 -> Cu > -0.13 (0.0011)
# Removed: Rh kb Rayleigh > 0.12 -> Cu > -0.13 (0.0011) | Kept: Cu > -0.13 -> Rh kb Rayleigh > 0.12 (0.0016)
# Removed: background1 <= -0.02 -> Rh kb Rayleigh > -0.08 (0.0009) | Kept: Rh kb Rayleigh > -0.08 -> background1 <= -0.02 (0.0009)
# Removed: Rh kb Rayleigh > -0.02 -> Rh kb Rayleigh <= -0.08 (0.0010) | Kept: Rh kb Rayleigh <= -0.08 -> Rh kb Rayleigh > -0.02 (0.0019)
# Removed: S > 0.01 -> Rh kb Rayleigh <= -0.02 (0.0004) | Kept: Rh kb Rayleigh <= -0.02 -> S > 0.01 (0.0028)
# Removed: Mn > 0.02 -> Rh kb Rayleigh <= -0.02 (0.0005) | Kept: Rh kb Rayleigh <= -0.02 -> Mn > 0.02 (0.0008)
# Removed: Rh kb Rayleigh <= 0.06 -> Rh kb Rayleigh > 0.06 (0.0010) | Kept: Rh kb Rayleigh > 0.06 -> Rh kb Rayleigh <= 0.06 (0.0034)
# Removed: Rh kb Rayleigh > -0.08 -> Rh kb Rayleigh > 0.06 (0.0009) | Kept: Rh kb Rayleigh > 0.06 -> Rh kb Rayleigh > -0.08 (0.0009)
# Removed: Rh kb Rayleigh > -0.02 -> Rh kb Rayleigh > 0.06 (0.0009) | Kept: Rh kb Rayleigh > 0.06 -> Rh kb Rayleigh > -0.02 (0.0010)
# Removed: Rh kb Rayleigh > -0.08 -> Rh kb Rayleigh <= 0.12 (0.0009) | Kept: Rh kb Rayleigh <= 0.12 -> Rh kb Rayleigh > -0.08 (0.0025)
# Removed: Mn > -0.02 -> S > -0.02 (0.0004) | Kept: S > -0.02 -> Mn > -0.02 (0.0007)
# Removed: Mn > -0.02 -> S > -0.07 (0.0003) | Kept: S > -0.07 -> Mn > -0.02 (0.0006)
# Removed: Mn <= -0.02 -> Mn > -0.02 (0.0002) | Kept: Mn > -0.02 -> Mn <= -0.02 (0.0003)
# Removed: Mn > -0.05 -> Mn > -0.03 (0.0002) | Kept: Mn > -0.03 -> Mn > -0.05 (0.0017)
# Removed: S <= 0.05 -> Mn > -0.03 (0.0003) | Kept: Mn > -0.03 -> S <= 0.05 (0.0006)
# Removed: Mn > -0.03 -> S > -0.07 (0.0003) | Kept: S > -0.07 -> Mn > -0.03 (0.0006)
# Removed: Mn > -0.05 -> S <= 0.05 (0.0003) | Kept: S <= 0.05 -> Mn > -0.05 (0.0009)
# Removed: Mn <= 0.02 -> Mn > -0.05 (0.0002) | Kept: Mn > -0.05 -> Mn <= 0.02 (0.0003)
# Removed: S > 0.01 -> Mn > 0.02 (0.0005) | Kept: Mn > 0.02 -> S > 0.01 (0.0011)
# Removed: Mn <= -0.02 -> Mn <= -0.03 (0.0004) | Kept: Mn <= -0.03 -> Mn <= -0.02 (0.0016)
# Removed: S > -0.07 -> S > -0.02 (0.0002) | Kept: S > -0.02 -> S > -0.07 (0.0018)
# Removed: Mn <= -0.02 -> S > -0.07 (0.0002) | Kept: S > -0.07 -> Mn <= -0.02 (0.0003)
# Removed: S <= 0.05 -> S > -0.07 (0.0003) | Kept: S > -0.07 -> S <= 0.05 (0.0010)
# Removed: S <= -0.02 -> S <= 0.01 (0.0006) | Kept: S <= 0.01 -> S <= -0.02 (0.0008)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 799 | Removed: 137
# Predicate nodes: 131
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#      Predicate_pert_Seed_0   Predicate_pert_Seed_1   Predicate_pert_Seed_2  \
# 0            K ka <= -0.48           K ka <= -0.48           K ka <= -0.48
# 1            K ka <= -0.16           K ka <= -0.16   Rb ka + Br kb > -0.02
# 2    Rb ka + Br kb > -0.02            K ka <= 0.44           K ka <= -0.16
# 3             K ka <= 0.20   Rb ka + Br kb > -0.02            K ka <= 0.20
# 4             K ka <= 0.44  Rh ka Compton <= -0.05  Rh ka Compton <= -0.05
# ..                     ...                     ...                     ...
# 128              S <= 0.05               S <= 0.01              S <= -0.07
# 129              S <= 0.01              S <= -0.02                 Class_A
# 130             S <= -0.07              S <= -0.07                 Class_B
# 131                Class_A                 Class_A                     NaN
# 132                Class_B                 Class_B                     NaN
#
#       Predicate_pert_Seed_3
# 0             K ka <= -0.16
# 1             K ka <= -0.48
# 2     Rb ka + Br kb > -0.02
# 3    Rb ka + Br kb <= -0.28
# 4              K ka <= 0.20
# ..                      ...
# 128              Mn <= 0.02
# 129              S <= -0.02
# 130              S <= -0.07
# 131                 Class_A
# 132                 Class_B
#
# [133 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#                  Predicate  Perturbation
# 0            K ka <= -0.48      0.028093
# 1            K ka <= -0.16      0.027019
# 2    Rb ka + Br kb > -0.02      0.025158
# 3             K ka <= 0.20      0.021391
# 4             K ka <= 0.44      0.018675
# ..                     ...           ...
# 105              S > -0.02      0.000375
# 106             S <= -0.02      0.000368
# 107             Mn <= 0.02      0.000367
# 108              S <= 0.05      0.000362
# 109              S <= 0.01      0.000336
#
# [110 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                        Node  Local_Reaching_Centrality            Zone  \
# 0             K ka <= -0.48                   7.424045            K ka
# 1     Rb ka + Br kb > -0.02                   5.659027   Rb ka + Br kb
# 2    Rh ka Compton <= -0.05                   3.361567   Rh ka Compton
# 3      background2 <= -0.23                   2.429171     background2
# 4      background3 <= -0.26                   2.278043     background3
# 5               Cl <= -0.20                   1.346391              Cl
# 6    Rh kb Compton <= -0.20                   1.198458   Rh kb Compton
# 7              Br ka > 0.17                   1.164091           Br ka
# 8                 Fe > 0.09                   1.031601              Fe
# 9       K kb + Ca ka > 0.11                   0.941502    K kb + Ca ka
# 10              Zn <= -0.10                   0.805670              Zn
# 11              Cu <= -0.13                   0.740977              Cu
# 12  Rh ka Rayleigh <= -0.15                   0.738629  Rh ka Rayleigh
# 13       background1 > 0.06                   0.679720     background1
# 14    Rh kb Rayleigh > 0.12                   0.555547  Rh kb Rayleigh
# 15                Mn > 0.02                   0.244461              Mn
# 16                 S > 0.01                   0.125739               S
# 17                  Class_A                   0.000000            None
#
#    Threshold Operator
# 0      -0.48       <=
# 1      -0.02        >
# 2      -0.05       <=
# 3      -0.23       <=
# 4      -0.26       <=
# 5      -0.20       <=
# 6      -0.20       <=
# 7       0.17        >
# 8       0.09        >
# 9       0.11        >
# 10     -0.10       <=
# 11     -0.13       <=
# 12     -0.15       <=
# 13      0.06        >
# 14      0.12        >
# 15      0.02        >
# 16      0.01        >
# 17      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                       Node  Local_Reaching_Centrality           Zone  \
# 0            K ka <= -0.48                   7.424045           K ka
# 1            K ka <= -0.16                   6.825208           K ka
# 2    Rb ka + Br kb > -0.02                   5.659027  Rb ka + Br kb
# 3             K ka <= 0.20                   4.401873           K ka
# 4             K ka <= 0.44                   3.839986           K ka
# ..                     ...                        ...            ...
# 131              S <= 0.01                   0.008249              S
# 132             S <= -0.02                   0.003615              S
# 133             S <= -0.07                   0.000801              S
# 134                Class_A                   0.000000           None
# 135                Class_B                   0.000000           None
#
#     Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0       -0.48       <=          -0.553004                    18.0
# 1       -0.16       <=          -0.188342                    19.0
# 2       -0.02        >          -0.003744                    27.0
# 3        0.20       <=           0.254042                    24.0
# 4        0.44       <=           0.522114                    34.0
# ..        ...      ...                ...                     ...
# 131      0.01       <=           0.001823                    33.0
# 132     -0.02       <=          -0.004244                     7.0
# 133     -0.07       <=          -0.016015                    30.0
# 134      None     None                NaN                     NaN
# 135      None     None                NaN                     NaN
#
#      Approximation_Error               Node_Natural
# 0               0.004092          K ka <= -0.553004
# 1               0.000301          K ka <= -0.188342
# 2               0.000729  Rb ka + Br kb > -0.003744
# 3               0.004192           K ka <= 0.254042
# 4               0.001978           K ka <= 0.522114
# ..                   ...                        ...
# 131             0.002263              S <= 0.001823
# 132             0.000106             S <= -0.004244
# 133             0.000596             S <= -0.016015
# 134                  NaN                       None
# 135                  NaN                       None
#
# [136 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'K ka':
#   - Dimensão: 23 variáveis espectrais
#   - Variância explicada pela PC1: 99.30%

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = svm_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = svm_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance_proba            Zone
# 0    3.28                      0.005028            K ka
# 1   13.38                      0.002948   Rb ka + Br kb
# 2    2.58                      0.001679              Cl
# 3   19.16                      0.000738   Rh ka Compton
# 4    3.56                      0.000689    K kb + Ca ka
# 5   11.88                      0.000675           Br ka
# 6     8.6                      0.000472              Zn
# 7      16                      0.000464     background3
# 8   21.34                      0.000426   Rh kb Compton
# 9    20.1                      0.000348  Rh ka Rayleigh
# 10  22.36                      0.000347  Rh kb Rayleigh
# 11   6.42                      0.000344              Fe
# 12  10.24                      0.000321     background2
# 13    8.1                      0.000252              Cu
# 14   5.06                      0.000211     background1
# 15   2.26                      0.000201               S
# 16   5.88                      0.000164              Mn

# %%
import numpy as np

max_len = max(
    len(pvector_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'SVM_pvector': pad_list(pvector_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#        SVM_pvector            Shap     Permutation LRC_perturbation  \
# 0    Rb ka + Br kb            K ka            K ka             K ka
# 1               Zn   Rb ka + Br kb   Rb ka + Br kb    Rb ka + Br kb
# 2      background3              Cl              Cl    Rh ka Compton
# 3               Cl   Rh ka Compton   Rh ka Compton      background2
# 4    Rh ka Compton    K kb + Ca ka    K kb + Ca ka      background3
# 5               Cu     background3           Br ka               Cl
# 6   Rh kb Rayleigh           Br ka              Zn    Rh kb Compton
# 7    Rh kb Compton   Rh kb Compton     background3            Br ka
# 8     K kb + Ca ka              Zn   Rh kb Compton               Fe
# 9      background2              Fe  Rh ka Rayleigh     K kb + Ca ka
# 10           Br ka     background2  Rh kb Rayleigh               Zn
# 11     background1  Rh ka Rayleigh              Fe               Cu
# 12              Fe     background1     background2   Rh ka Rayleigh
# 13  Rh ka Rayleigh              Cu              Cu      background1
# 14            K ka               S     background1   Rh kb Rayleigh
# 15              Mn  Rh kb Rayleigh               S               Mn
# 16               S              Mn              Mn                S
# 17            None            None            None             None
#
#    LRC_covariance
# 0   Rh ka Compton
# 1            K ka
# 2              Fe
# 3   Rh kb Compton
# 4     background3
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2508\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 4              Shap       Permutation   0.954008
# 5              Shap  LRC_perturbation   0.841586
# 7       Permutation  LRC_perturbation   0.823841
# 0       SVM_pvector              Shap   0.339817
# 1       SVM_pvector       Permutation   0.331414
# 2       SVM_pvector  LRC_perturbation   0.310249
# 9  LRC_perturbation    LRC_covariance   0.297668
# 6              Shap    LRC_covariance   0.234262
# 8       Permutation    LRC_covariance   0.234262
# 3       SVM_pvector    LRC_covariance   0.028812

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
