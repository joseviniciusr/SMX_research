# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' can be imported
import sys
from pathlib import Path # for path manipulations
# Move three levels up from current working directory to reach workspace root
workspace_root = Path.cwd().parent.parent.parent.resolve() 
smx_dir = workspace_root / 'smx'  # Path to smx folder
if str(smx_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(smx_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{workspace_root}/real_datasets/xrf/tomato.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '2.12':'23.08']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.12':'23.08'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.12':'23.08'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 2026-02-27 07:44:13,775 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 2026-02-27 07:44:13,780 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 2026-02-27 07:44:13,810 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 2026-02-27 07:44:13,818 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
Xcalclass.T.plot()

# %%
# PLS-DA with optimized latent variables
from modeling import pls_optimized

plsda_results = pls_optimized(
    Xcalclass_prep, 
    ycalclass,
    LVmax=2,
    Xpred=Xpredclass_prep,
    ypred=ypredclass,
    aim='classification',
    cv=10
)

# Convenience references used later
pls_model = plsda_results[3]               # fitted PLS model
vip_scores_mat = plsda_results[4]          # VIP scores matrix (features × LV)
y_pred_cont = plsda_results[5].iloc[:, -1] # continuous predictions for Xcalclass (used for MI/Cov)

# plotando o vip scores rapidamente
vip_scores_mat.T.plot()
#plsda_results[0]

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('S', 2.12, 2.4),
('Cl', 2.4, 3.04),
('K ka', 3.0, 3.44),
('K kb + Ca ka', 3.44, 3.84),
('background1', 3.84, 5.7),
('Mn', 5.7, 6.04),
('Fe', 6.04, 7.3),
('Cu', 7.3, 8.32),
('Zn', 8.32, 8.84),
('background2', 8.84, 11.56),
('Br ka', 11.56, 12.5),
('Rb ka + Br kb', 12.5, 13.8),
('background3', 13.8, 17.0),
('Rh ka Compton', 17.0, 19.9),
('Rh ka Rayleigh', 19.9, 20.8),
('Rh kb Compton', 20.8, 22.3),
('Rh kb Rayleigh', 22.3, 23.08)
]

# %% [markdown]
# ## VIP, Regression Coefficients e SHAP (como no original)

# %%
# VIP scores por energia
vip_scores_df = pd.DataFrame({
    'energy': vip_scores_mat.T.index,
    'VIP_Score': vip_scores_mat.T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in vip_scores_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip)
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# Coeficientes de regressão do PLS
reg_vet = pd.DataFrame(pls_model.coef_, columns=pls_model.feature_names_in_).T
reg_vet.insert(0, 'energy', reg_vet.index)
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy','Reg_coef']
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs()
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
energy_to_zone_reg = {}
for zone_name, start, end in spectral_cuts:
    for e in reg_vet['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_reg[e] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg)
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)

# %%
# shap_global_importance = pd.read_csv('shap_tomato.csv', sep=';') # loading previously saved shap_unique_df

# # vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
# energy_to_zone_shap = {}
# for zone_name, start, end in spectral_cuts:
#     for i in shap_global_importance['energy']:
#         i_float = float(i)
#         if start <= i_float <= end:
#             energy_to_zone_shap[i] = zone_name
# shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# # agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
# shap_unique_df = shap_global_importance.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
# shap_unique_df = shap_unique_df.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
# shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP              Zone
# 0     4.52       0.053898             Ti ka
# 1     3.73       0.019426             Ca ka
# 2     8.06       0.004351             Cu ka
# 3     6.46       0.002868             Fe ka
# 4     4.95       0.001924             Ti kb
# 5    21.92       0.000429  Ag ka scattering
# 6     4.03       0.000019             Ca kb
# 7    17.23       0.000007       background3
# 8     2.76       0.000000      Ar ka + Ag L
# 9     6.79       0.000000             Fe kb
# 10    5.89       0.000000       background1
# 11    7.75       0.000000       background2
# 12    8.29       0.000000             Zn ka
# 13    2.74       0.000000               NaN
# 14    9.18       0.000000             Cu kb
# 15    9.26       0.000000             Zn kb

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zone 'S': VE = 52.67%, dim = 15 variables
# Zone 'Cl': VE = 79.94%, dim = 33 variables
# Zone 'K ka': VE = 98.21%, dim = 23 variables
# Zone 'K kb + Ca ka': VE = 63.19%, dim = 21 variables
# Zone 'background1': VE = 17.34%, dim = 94 variables
# Zone 'Mn': VE = 56.93%, dim = 18 variables
# Zone 'Fe': VE = 57.33%, dim = 64 variables
# Zone 'Cu': VE = 53.40%, dim = 52 variables
# Zone 'Zn': VE = 60.08%, dim = 27 variables
# Zone 'background2': VE = 68.69%, dim = 137 variables
# Zone 'Br ka': VE = 65.01%, dim = 48 variables
# Zone 'Rb ka + Br kb': VE = 74.53%, dim = 66 variables
# Zone 'background3': VE = 70.02%, dim = 161 variables
# Zone 'Rh ka Compton': VE = 88.63%, dim = 146 variables
# Zone 'Rh ka Rayleigh': VE = 82.31%, dim = 46 variables
# Zone 'Rh kb Compton': VE = 81.75%, dim = 76 variables
# Zone 'Rh kb Rayleigh': VE = 69.11%, dim = 40 variables
#
# Scores DataFrame shape: (36, 17)

# %%
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred_cont
)

# %%
# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_pred_conticted_numeric = pd.Series(y_pred_cont) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred_conticted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 112 | Discarded: 24
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 114 | Discarded: 22
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 115 | Discarded: 21
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 114 | Discarded: 22
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 109 | Discarded: 27
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 111 | Discarded: 25
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 118 | Discarded: 18
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Computing Covariance for Predicates
# Metric: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total bidirectional pairs found: 27
# Removed: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.28 (0.1814) | Kept: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.12 (0.3898)
# Removed: K ka <= 0.20 -> Rh ka Compton <= 0.45 (0.0507) | Kept: Rh ka Compton <= 0.45 -> K ka <= 0.20 (0.3251)
# Removed: Rh ka Compton <= 0.45 -> K ka <= 0.44 (0.0349) | Kept: K ka <= 0.44 -> Rh ka Compton <= 0.45 (0.0950)
# Removed: Rh kb Compton <= 0.00 -> K ka <= 0.44 (0.0309) | Kept: K ka <= 0.44 -> Rh kb Compton <= 0.00 (0.1107)
# Removed: Rh ka Rayleigh <= 0.21 -> K ka <= 0.44 (0.0598) | Kept: K ka <= 0.44 -> Rh ka Rayleigh <= 0.21 (0.0734)
# Removed: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.0647) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.1677)
# Removed: Rh kb Compton <= 0.25 -> Rh ka Compton <= 0.14 (0.0181) | Kept: Rh ka Compton <= 0.14 -> Rh kb Compton <= 0.25 (0.1466)
# Removed: K ka <= -0.16 -> background3 > -0.26 (0.0198) | Kept: background3 > -0.26 -> K ka <= -0.16 (0.0335)
# Removed: Rh ka Rayleigh <= 0.21 -> K ka <= -0.16 (0.0213) | Kept: K ka <= -0.16 -> Rh ka Rayleigh <= 0.21 (0.0230)
# Removed: Cl > -0.20 -> Rh ka Compton > -0.05 (0.0160) | Kept: Rh ka Compton > -0.05 -> Cl > -0.20 (0.0597)
# Removed: Rh kb Compton <= 0.25 -> Rh ka Rayleigh <= 0.21 (0.0854) | Kept: Rh ka Rayleigh <= 0.21 -> Rh kb Compton <= 0.25 (0.1185)
# Removed: Rh ka Rayleigh <= 0.21 -> Rh kb Compton <= 0.00 (0.0303) | Kept: Rh kb Compton <= 0.00 -> Rh ka Rayleigh <= 0.21 (0.0553)
# Removed: K kb + Ca ka <= 0.16 -> Cl > 0.03 (0.0090) | Kept: Cl > 0.03 -> K kb + Ca ka <= 0.16 (0.0121)
# Removed: Cl > -0.04 -> Cl > 0.03 (0.0140) | Kept: Cl > 0.03 -> Cl > -0.04 (0.0289)
# Removed: Cl > 0.16 -> Rh ka Compton > -0.39 (0.0155) | Kept: Rh ka Compton > -0.39 -> Cl > 0.16 (0.0315)
# Removed: Rh ka Compton > -0.39 -> Rh kb Rayleigh <= 0.06 (0.0156) | Kept: Rh kb Rayleigh <= 0.06 -> Rh ka Compton > -0.39 (0.0241)
# Removed: Rh kb Rayleigh <= -0.02 -> Cl > -0.04 (0.0121) | Kept: Cl > -0.04 -> Rh kb Rayleigh <= -0.02 (0.0286)
# Removed: background3 <= 0.19 -> Cl > -0.04 (0.0124) | Kept: Cl > -0.04 -> background3 <= 0.19 (0.0164)
# Removed: Rh ka Rayleigh <= -0.02 -> Rh kb Compton <= 0.00 (0.0176) | Kept: Rh kb Compton <= 0.00 -> Rh ka Rayleigh <= -0.02 (0.0957)
# Removed: Cl > -0.20 -> Rh kb Compton <= 0.10 (0.0188) | Kept: Rh kb Compton <= 0.10 -> Cl > -0.20 (0.0219)
# Removed: background2 > 0.06 -> Rh ka Rayleigh > -0.15 (0.0091) | Kept: Rh ka Rayleigh > -0.15 -> background2 > 0.06 (0.0104)
# Removed: Rh kb Compton > -0.20 -> Rh ka Rayleigh > -0.15 (0.0144) | Kept: Rh ka Rayleigh > -0.15 -> Rh kb Compton > -0.20 (0.0323)
# Removed: K kb + Ca ka <= -0.14 -> Rh kb Compton > -0.20 (0.0072) | Kept: Rh kb Compton > -0.20 -> K kb + Ca ka <= -0.14 (0.0088)
# Removed: Cu > 0.11 -> background3 <= 0.19 (0.0056) | Kept: background3 <= 0.19 -> Cu > 0.11 (0.0102)
# Removed: Cu > 0.11 -> Rh kb Compton > 0.00 (0.0070) | Kept: Rh kb Compton > 0.00 -> Cu > 0.11 (0.0110)
# Removed: Rh kb Rayleigh <= 0.06 -> Rh kb Rayleigh <= -0.02 (0.0115) | Kept: Rh kb Rayleigh <= -0.02 -> Rh kb Rayleigh <= 0.06 (0.0116)
# Removed: Cu > -0.13 -> K ka > -0.16 (0.0068) | Kept: K ka > -0.16 -> Cu > -0.13 (0.0148)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 269 | Removed: 27
# Predicate nodes: 60
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total bidirectional pairs found: 30
# Removed: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.02 (0.1184) | Kept: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.28 (0.1899)
# Removed: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.02 (0.0476) | Kept: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.12 (0.3071)
# Removed: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.28 (0.1736) | Kept: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.12 (0.2490)
# Removed: Rh ka Compton <= 0.45 -> Rb ka + Br kb > -0.28 (0.0397) | Kept: Rb ka + Br kb > -0.28 -> Rh ka Compton <= 0.45 (0.0571)
# Removed: Rh ka Compton <= 0.45 -> K ka <= 0.20 (0.0994) | Kept: K ka <= 0.20 -> Rh ka Compton <= 0.45 (0.1798)
# Removed: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.0976) | Kept: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.1919)
# Removed: K ka <= 0.20 -> Rh ka Compton <= -0.05 (0.0507) | Kept: Rh ka Compton <= -0.05 -> K ka <= 0.20 (0.1009)
# Removed: Rh ka Compton <= 0.14 -> K ka <= 0.20 (0.0404) | Kept: K ka <= 0.20 -> Rh ka Compton <= 0.14 (0.0958)
# Removed: Rh ka Compton <= 0.14 -> Rh ka Compton <= -0.05 (0.0396) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.14 (0.1303)
# Removed: Rh ka Compton > -0.05 -> Rh ka Compton <= -0.05 (0.0236) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton > -0.05 (0.0327)
# Removed: Rh kb Compton <= 0.25 -> K ka <= 0.44 (0.0289) | Kept: K ka <= 0.44 -> Rh kb Compton <= 0.25 (0.0675)
# Removed: Rh kb Compton <= 0.00 -> K ka <= 0.44 (0.0241) | Kept: K ka <= 0.44 -> Rh kb Compton <= 0.00 (0.0323)
# Removed: Rh kb Compton <= 0.25 -> Rh ka Rayleigh <= 0.21 (0.0723) | Kept: Rh ka Rayleigh <= 0.21 -> Rh kb Compton <= 0.25 (0.1638)
# Removed: Rh ka Rayleigh <= 0.21 -> K ka <= -0.16 (0.0203) | Kept: K ka <= -0.16 -> Rh ka Rayleigh <= 0.21 (0.0337)
# Removed: Rh kb Compton <= 0.00 -> Rh ka Compton > -0.05 (0.0481) | Kept: Rh ka Compton > -0.05 -> Rh kb Compton <= 0.00 (0.0515)
# Removed: background3 <= 0.19 -> Rh ka Compton > -0.05 (0.0158) | Kept: Rh ka Compton > -0.05 -> background3 <= 0.19 (0.0176)
# Removed: Rh ka Compton > -0.05 -> K ka <= -0.16 (0.0226) | Kept: K ka <= -0.16 -> Rh ka Compton > -0.05 (0.0231)
# Removed: Rh kb Compton <= 0.00 -> Rh ka Compton > -0.39 (0.0207) | Kept: Rh ka Compton > -0.39 -> Rh kb Compton <= 0.00 (0.0293)
# Removed: Rh ka Compton > -0.39 -> background3 > -0.26 (0.0178) | Kept: background3 > -0.26 -> Rh ka Compton > -0.39 (0.0223)
# Removed: Cl > -0.20 -> Rh ka Compton > -0.39 (0.0149) | Kept: Rh ka Compton > -0.39 -> Cl > -0.20 (0.0182)
# Removed: Rh ka Rayleigh <= -0.02 -> K ka <= -0.16 (0.0178) | Kept: K ka <= -0.16 -> Rh ka Rayleigh <= -0.02 (0.0737)
# Removed: Rh ka Rayleigh <= -0.02 -> Cl > -0.04 (0.0172) | Kept: Cl > -0.04 -> Rh ka Rayleigh <= -0.02 (0.0183)
# Removed: Rh ka Rayleigh <= 0.09 -> Rh ka Rayleigh <= -0.02 (0.0210) | Kept: Rh ka Rayleigh <= -0.02 -> Rh ka Rayleigh <= 0.09 (0.0414)
# Removed: background3 <= 0.19 -> background3 > -0.26 (0.0151) | Kept: background3 > -0.26 -> background3 <= 0.19 (0.0349)
# Removed: background3 <= 0.19 -> Rh ka Rayleigh <= 0.09 (0.0157) | Kept: Rh ka Rayleigh <= 0.09 -> background3 <= 0.19 (0.0412)
# Removed: Cu > 0.11 -> background3 > -0.26 (0.0080) | Kept: background3 > -0.26 -> Cu > 0.11 (0.0106)
# Removed: Cl > -0.20 -> Cl > -0.04 (0.0145) | Kept: Cl > -0.04 -> Cl > -0.20 (0.0284)
# Removed: Rh kb Compton > 0.00 -> Rh kb Rayleigh <= 0.06 (0.0095) | Kept: Rh kb Rayleigh <= 0.06 -> Rh kb Compton > 0.00 (0.0098)
# Removed: background2 > 0.06 -> K ka > -0.48 (0.0150) | Kept: K ka > -0.48 -> background2 > 0.06 (0.0312)
# Removed: Rh kb Rayleigh <= -0.02 -> Cu > 0.11 (0.0094) | Kept: Cu > 0.11 -> Rh kb Rayleigh <= -0.02 (0.0229)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 300 | Removed: 30
# Predicate nodes: 64
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total bidirectional pairs found: 36
# Removed: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.02 (0.0306) | Kept: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.28 (0.0572)
# Removed: Rh ka Compton <= 0.45 -> Rb ka + Br kb > -0.02 (0.0672) | Kept: Rb ka + Br kb > -0.02 -> Rh ka Compton <= 0.45 (0.0863)
# Removed: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.12 (0.0536) | Kept: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.28 (0.3252)
# Removed: Rh ka Compton <= -0.05 -> Rb ka + Br kb > -0.12 (0.0590) | Kept: Rb ka + Br kb > -0.12 -> Rh ka Compton <= -0.05 (0.1075)
# Removed: Rh ka Compton <= -0.05 -> Rb ka + Br kb > -0.28 (0.0623) | Kept: Rb ka + Br kb > -0.28 -> Rh ka Compton <= -0.05 (0.0955)
# Removed: Rh ka Compton <= 0.14 -> K ka <= 0.20 (0.1448) | Kept: K ka <= 0.20 -> Rh ka Compton <= 0.14 (0.2338)
# Removed: Rh ka Rayleigh <= -0.02 -> K ka <= 0.44 (0.0218) | Kept: K ka <= 0.44 -> Rh ka Rayleigh <= -0.02 (0.0236)
# Removed: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.1062) | Kept: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.1068)
# Removed: Rh kb Compton <= 0.10 -> K ka <= -0.16 (0.0177) | Kept: K ka <= -0.16 -> Rh kb Compton <= 0.10 (0.0310)
# Removed: Rh ka Rayleigh <= 0.09 -> K ka <= -0.16 (0.0262) | Kept: K ka <= -0.16 -> Rh ka Rayleigh <= 0.09 (0.0292)
# Removed: K ka <= -0.16 -> background3 <= 0.08 (0.0303) | Kept: background3 <= 0.08 -> K ka <= -0.16 (0.0316)
# Removed: Rh ka Compton <= 0.14 -> Rh ka Compton <= -0.05 (0.0499) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.14 (0.0930)
# Removed: Rh kb Compton <= 0.00 -> Rh ka Rayleigh <= 0.21 (0.0293) | Kept: Rh ka Rayleigh <= 0.21 -> Rh kb Compton <= 0.00 (0.0596)
# Removed: Rh ka Rayleigh <= 0.21 -> Rh kb Compton <= 0.25 (0.1054) | Kept: Rh kb Compton <= 0.25 -> Rh ka Rayleigh <= 0.21 (0.1584)
# Removed: Rh ka Rayleigh <= -0.02 -> Rh ka Rayleigh <= 0.21 (0.0185) | Kept: Rh ka Rayleigh <= 0.21 -> Rh ka Rayleigh <= -0.02 (0.0305)
# Removed: Rh kb Compton <= 0.25 -> Rh kb Compton <= 0.00 (0.0179) | Kept: Rh kb Compton <= 0.00 -> Rh kb Compton <= 0.25 (0.0315)
# Removed: background3 <= 0.08 -> Rh kb Compton <= 0.00 (0.0239) | Kept: Rh kb Compton <= 0.00 -> background3 <= 0.08 (0.0308)
# Removed: Cl > 0.16 -> Rh ka Compton > -0.39 (0.0123) | Kept: Rh ka Compton > -0.39 -> Cl > 0.16 (0.0177)
# Removed: Rh kb Compton <= 0.10 -> Rh ka Compton > -0.39 (0.0170) | Kept: Rh ka Compton > -0.39 -> Rh kb Compton <= 0.10 (0.0209)
# Removed: Rh ka Compton > -0.39 -> K kb + Ca ka <= 0.16 (0.0108) | Kept: K kb + Ca ka <= 0.16 -> Rh ka Compton > -0.39 (0.0116)
# Removed: Cl > -0.04 -> Cl > -0.20 (0.0155) | Kept: Cl > -0.20 -> Cl > -0.04 (0.0311)
# Removed: Rh ka Rayleigh <= 0.09 -> Rh ka Rayleigh <= -0.02 (0.0225) | Kept: Rh ka Rayleigh <= -0.02 -> Rh ka Rayleigh <= 0.09 (0.0286)
# Removed: Rh ka Rayleigh <= 0.09 -> background3 <= 0.19 (0.0216) | Kept: background3 <= 0.19 -> Rh ka Rayleigh <= 0.09 (0.0222)
# Removed: Br ka <= -0.05 -> Rh ka Rayleigh > -0.15 (0.0081) | Kept: Rh ka Rayleigh > -0.15 -> Br ka <= -0.05 (0.0217)
# Removed: background3 > -0.26 -> background3 <= 0.19 (0.0141) | Kept: background3 <= 0.19 -> background3 > -0.26 (0.0147)
# Removed: background3 > -0.26 -> K ka > -0.16 (0.0124) | Kept: K ka > -0.16 -> background3 > -0.26 (0.0176)
# Removed: Rh kb Rayleigh <= 0.12 -> Rh kb Rayleigh <= 0.06 (0.0116) | Kept: Rh kb Rayleigh <= 0.06 -> Rh kb Rayleigh <= 0.12 (0.0703)
# Removed: Cu > 0.11 -> Cu > -0.13 (0.0060) | Kept: Cu > -0.13 -> Cu > 0.11 (0.0062)
# Removed: Rh kb Rayleigh <= -0.02 -> K kb + Ca ka <= 0.11 (0.0105) | Kept: K kb + Ca ka <= 0.11 -> Rh kb Rayleigh <= -0.02 (0.0155)
# Removed: K kb + Ca ka <= 0.11 -> K ka > 0.20 (0.0083) | Kept: K ka > 0.20 -> K kb + Ca ka <= 0.11 (0.0106)
# Removed: K kb + Ca ka <= -0.02 -> Rh kb Rayleigh <= -0.02 (0.0078) | Kept: Rh kb Rayleigh <= -0.02 -> K kb + Ca ka <= -0.02 (0.0117)
# Removed: background3 <= -0.04 -> background3 <= 0.08 (0.0180) | Kept: background3 <= 0.08 -> background3 <= -0.04 (0.0251)
# Removed: background3 <= 0.19 -> background3 <= -0.04 (0.0190) | Kept: background3 <= -0.04 -> background3 <= 0.19 (0.0238)
# Removed: background3 <= 0.19 -> Rh kb Compton <= 0.10 (0.0183) | Kept: Rh kb Compton <= 0.10 -> background3 <= 0.19 (0.0203)
# Removed: K ka > -0.16 -> K ka > -0.48 (0.0170) | Kept: K ka > -0.48 -> K ka > -0.16 (0.0195)
# Removed: background3 <= -0.04 -> K ka > -0.16 (0.0118) | Kept: K ka > -0.16 -> background3 <= -0.04 (0.0151)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 281 | Removed: 36
# Predicate nodes: 62
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total bidirectional pairs found: 31
# Removed: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.02 (0.0665) | Kept: Rb ka + Br kb > -0.02 -> Rb ka + Br kb > -0.12 (0.2272)
# Removed: K ka <= 0.20 -> Rb ka + Br kb > -0.02 (0.0429) | Kept: Rb ka + Br kb > -0.02 -> K ka <= 0.20 (0.0647)
# Removed: Rh ka Compton <= 0.45 -> Rb ka + Br kb > -0.02 (0.0575) | Kept: Rb ka + Br kb > -0.02 -> Rh ka Compton <= 0.45 (0.0675)
# Removed: Rb ka + Br kb > -0.28 -> Rb ka + Br kb > -0.12 (0.2274) | Kept: Rb ka + Br kb > -0.12 -> Rb ka + Br kb > -0.28 (0.2321)
# Removed: K ka <= 0.20 -> Rb ka + Br kb > -0.28 (0.1121) | Kept: Rb ka + Br kb > -0.28 -> K ka <= 0.20 (0.2247)
# Removed: Rb ka + Br kb > -0.12 -> Rh ka Compton <= 0.45 (0.0552) | Kept: Rh ka Compton <= 0.45 -> Rb ka + Br kb > -0.12 (0.0655)
# Removed: Rh ka Compton <= 0.14 -> Rb ka + Br kb > -0.12 (0.0342) | Kept: Rb ka + Br kb > -0.12 -> Rh ka Compton <= 0.14 (0.0822)
# Removed: Rb ka + Br kb > -0.12 -> Rh ka Compton <= -0.05 (0.0569) | Kept: Rh ka Compton <= -0.05 -> Rb ka + Br kb > -0.12 (0.0708)
# Removed: K ka <= 0.20 -> Rh ka Compton <= 0.45 (0.1196) | Kept: Rh ka Compton <= 0.45 -> K ka <= 0.20 (0.1987)
# Removed: Rh ka Compton <= 0.45 -> Rh ka Compton <= -0.05 (0.0718) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.45 (0.2316)
# Removed: Rh ka Compton <= 0.14 -> K ka <= 0.20 (0.0519) | Kept: K ka <= 0.20 -> Rh ka Compton <= 0.14 (0.0980)
# Removed: Rh ka Compton <= 0.14 -> Rh ka Compton <= -0.05 (0.0394) | Kept: Rh ka Compton <= -0.05 -> Rh ka Compton <= 0.14 (0.0426)
# Removed: Rh ka Compton <= -0.05 -> K ka <= -0.16 (0.0280) | Kept: K ka <= -0.16 -> Rh ka Compton <= -0.05 (0.0599)
# Removed: Rh ka Rayleigh <= 0.21 -> Rh kb Compton <= 0.25 (0.0802) | Kept: Rh kb Compton <= 0.25 -> Rh ka Rayleigh <= 0.21 (0.0847)
# Removed: Rh ka Compton > -0.39 -> Rh ka Rayleigh <= 0.21 (0.0231) | Kept: Rh ka Rayleigh <= 0.21 -> Rh ka Compton > -0.39 (0.0250)
# Removed: Rh ka Rayleigh <= 0.09 -> Rh ka Rayleigh <= -0.02 (0.0238) | Kept: Rh ka Rayleigh <= -0.02 -> Rh ka Rayleigh <= 0.09 (0.0339)
# Removed: Cl > -0.20 -> Rh ka Rayleigh <= -0.02 (0.0150) | Kept: Rh ka Rayleigh <= -0.02 -> Cl > -0.20 (0.0161)
# Removed: background3 <= 0.19 -> Rh ka Rayleigh <= -0.02 (0.0196) | Kept: Rh ka Rayleigh <= -0.02 -> background3 <= 0.19 (0.0234)
# Removed: Rh kb Compton <= 0.00 -> K ka <= 0.44 (0.0440) | Kept: K ka <= 0.44 -> Rh kb Compton <= 0.00 (0.0578)
# Removed: background3 <= 0.19 -> background3 <= 0.08 (0.0220) | Kept: background3 <= 0.08 -> background3 <= 0.19 (0.0363)
# Removed: background3 <= -0.04 -> background3 <= 0.19 (0.0170) | Kept: background3 <= 0.19 -> background3 <= -0.04 (0.0173)
# Removed: Rh ka Rayleigh <= 0.09 -> Cl > -0.20 (0.0178) | Kept: Cl > -0.20 -> Rh ka Rayleigh <= 0.09 (0.0280)
# Removed: Rh ka Rayleigh <= 0.09 -> Rh ka Rayleigh > -0.15 (0.0120) | Kept: Rh ka Rayleigh > -0.15 -> Rh ka Rayleigh <= 0.09 (0.0136)
# Removed: K ka <= -0.16 -> Rh kb Compton <= 0.10 (0.0197) | Kept: Rh kb Compton <= 0.10 -> K ka <= -0.16 (0.0414)
# Removed: Rh ka Compton > -0.39 -> background3 > -0.26 (0.0114) | Kept: background3 > -0.26 -> Rh ka Compton > -0.39 (0.0308)
# Removed: K kb + Ca ka <= 0.16 -> background3 > -0.26 (0.0073) | Kept: background3 > -0.26 -> K kb + Ca ka <= 0.16 (0.0091)
# Removed: Rh kb Rayleigh <= -0.02 -> Rh kb Compton > -0.20 (0.0087) | Kept: Rh kb Compton > -0.20 -> Rh kb Rayleigh <= -0.02 (0.0118)
# Removed: Rh kb Rayleigh <= -0.02 -> K kb + Ca ka <= 0.11 (0.0095) | Kept: K kb + Ca ka <= 0.11 -> Rh kb Rayleigh <= -0.02 (0.0106)
# Removed: Rh kb Rayleigh <= 0.12 -> Rh kb Rayleigh <= 0.06 (0.0101) | Kept: Rh kb Rayleigh <= 0.06 -> Rh kb Rayleigh <= 0.12 (0.0259)
# Removed: Rh ka Rayleigh > -0.15 -> Rh kb Compton > -0.20 (0.0116) | Kept: Rh kb Compton > -0.20 -> Rh ka Rayleigh > -0.15 (0.0379)
# Removed: K kb + Ca ka <= 0.16 -> K kb + Ca ka <= 0.11 (0.0076) | Kept: K kb + Ca ka <= 0.11 -> K kb + Ca ka <= 0.16 (0.0171)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 309 | Removed: 31
# Predicate nodes: 66
# Metric: Covariance
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#       Predicate_Cov_Seed_0    Predicate_Cov_Seed_1   Predicate_Cov_Seed_2  \
# 0    Rb ka + Br kb > -0.02   Rb ka + Br kb > -0.02  Rb ka + Br kb > -0.02
# 1    Rb ka + Br kb > -0.28   Rh ka Compton <= 0.45  Rb ka + Br kb > -0.12
# 2    Rh ka Compton <= 0.45   Rb ka + Br kb > -0.28  Rb ka + Br kb > -0.28
# 3   Rh ka Compton <= -0.05   Rh ka Compton <= 0.14  Rh ka Compton <= 0.45
# 4    Rb ka + Br kb > -0.12            K ka <= 0.20           K ka <= 0.20
# ..                     ...                     ...                    ...
# 63                     NaN  Rh kb Rayleigh > -0.08                Class_B
# 64                     NaN                 Class_A                    NaN
# 65                     NaN                 Class_B                    NaN
# 66                     NaN                     NaN                    NaN
# 67                     NaN                     NaN                    NaN
#
#       Predicate_Cov_Seed_3
# 0    Rb ka + Br kb > -0.28
# 1    Rb ka + Br kb > -0.02
# 2   Rh ka Compton <= -0.05
# 3    Rb ka + Br kb > -0.12
# 4    Rh ka Compton <= 0.45
# ..                     ...
# 63           Br ka > -0.05
# 64              Fe > -0.07
# 65      background2 > 0.18
# 66                 Class_A
# 67                 Class_B
#
# [68 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0    Rb ka + Br kb > -0.02                   5.512661   Rb ka + Br kb
# 1    Rh ka Compton <= 0.45                   3.843443   Rh ka Compton
# 2             K ka <= 0.20                   3.171713            K ka
# 3               Cu <= 0.01                   1.887485              Cu
# 4   Rh ka Rayleigh <= 0.21                   1.849225  Rh ka Rayleigh
# 5     background3 <= -0.04                   1.733370     background3
# 6    Rh kb Compton <= 0.25                   1.665174   Rh kb Compton
# 7            Br ka <= 0.04                   1.198415           Br ka
# 8               Cl <= 0.16                   1.100757              Cl
# 9   Rh kb Rayleigh <= 0.06                   1.012714  Rh kb Rayleigh
# 10    K kb + Ca ka <= 0.16                   0.912360    K kb + Ca ka
# 11      background2 > 0.06                   0.811391     background2
# 12              Fe > -0.01                   0.807579              Fe
# 13                 Class_A                   0.000000            None
#
#    Threshold Operator
# 0      -0.02        >
# 1       0.45       <=
# 2       0.20       <=
# 3       0.01       <=
# 4       0.21       <=
# 5      -0.04       <=
# 6       0.25       <=
# 7       0.04       <=
# 8       0.16       <=
# 9       0.06       <=
# 10      0.16       <=
# 11      0.06        >
# 12     -0.01        >
# 13      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zone 'S': VE = 57.86%, dim = 15 variables
# Zone 'Cl': VE = 86.73%, dim = 33 variables
# Zone 'K ka': VE = 99.30%, dim = 23 variables
# Zone 'K kb + Ca ka': VE = 73.64%, dim = 21 variables
# Zone 'background1': VE = 21.46%, dim = 94 variables
# Zone 'Mn': VE = 58.45%, dim = 18 variables
# Zone 'Fe': VE = 62.13%, dim = 64 variables
# Zone 'Cu': VE = 55.31%, dim = 52 variables
# Zone 'Zn': VE = 60.70%, dim = 27 variables
# Zone 'background2': VE = 69.36%, dim = 137 variables
# Zone 'Br ka': VE = 64.96%, dim = 48 variables
# Zone 'Rb ka + Br kb': VE = 79.32%, dim = 66 variables
# Zone 'background3': VE = 69.90%, dim = 161 variables
# Zone 'Rh ka Compton': VE = 92.92%, dim = 146 variables
# Zone 'Rh ka Rayleigh': VE = 85.65%, dim = 46 variables
# Zone 'Rh kb Compton': VE = 83.08%, dim = 76 variables
# Zone 'Rh kb Rayleigh': VE = 69.80%, dim = 40 variables
#                       Node  Local_Reaching_Centrality            Zone  \
# 0    Rb ka + Br kb > -0.02                   5.512661   Rb ka + Br kb
# 1    Rb ka + Br kb > -0.28                   4.258175   Rb ka + Br kb
# 2    Rh ka Compton <= 0.45                   3.843443   Rh ka Compton
# 3    Rb ka + Br kb > -0.12                   3.829498   Rb ka + Br kb
# 4             K ka <= 0.20                   3.171713            K ka
# ..                     ...                        ...             ...
# 69  Rh kb Rayleigh > -0.08                   0.368798  Rh kb Rayleigh
# 70             K ka > 0.44                   0.277886            K ka
# 71             Cl <= -0.04                   0.004421              Cl
# 72                 Class_A                   0.000000            None
# 73                 Class_B                   0.000000            None
#
#    Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0      -0.02        >          -0.003744                    27.0
# 1      -0.28        >          -0.136523                     0.0
# 2       0.45       <=           0.421114                     2.0
# 3      -0.12        >          -0.062361                     9.0
# 4       0.20       <=           0.254042                    24.0
# ..       ...      ...                ...                     ...
# 69     -0.08        >          -0.029851                    25.0
# 70      0.44        >           0.522114                    34.0
# 71     -0.04       <=          -0.015929                    14.0
# 72      None     None                NaN                     NaN
# 73      None     None                NaN                     NaN
#
#     Approximation_Error                Node_Natural
# 0              0.000729   Rb ka + Br kb > -0.003744
# 1              0.000198   Rb ka + Br kb > -0.136523
# 2              0.002152   Rh ka Compton <= 0.421114
# 3              0.002081   Rb ka + Br kb > -0.062361
# 4              0.004192            K ka <= 0.254042
# ..                  ...                         ...
# 69             0.002858  Rh kb Rayleigh > -0.029851
# 70             0.001978             K ka > 0.522114
# 71             0.003224             Cl <= -0.015929
# 72                  NaN                        None
# 73                  NaN                        None
#
# [74 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Rb ka + Br kb':
#   - Dimensão: 66 variáveis espectrais
#   - Range de energias: 12.5 - 13.8
#   - Variância explicada pela PC1: 79.32%

# %%
# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_pred_conticted_numeric = pd.Series(y_pred_cont) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred_conticted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=pls_model,
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='regression',
        metric='mean_abs_diff', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_2 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# Bag_3 | Samples: Yes | Predicates: No (All) | Valid: 113 | Discarded: 23
# Bag_4 | Samples: Yes | Predicates: No (All) | Valid: 108 | Discarded: 28
# Bag_5 | Samples: Yes | Predicates: No (All) | Valid: 107 | Discarded: 29
# Bag_6 | Samples: Yes | Predicates: No (All) | Valid: 106 | Discarded: 30
# Bag_7 | Samples: Yes | Predicates: No (All) | Valid: 116 | Discarded: 20
# Bag_8 | Samples: Yes | Predicates: No (All) | Valid: 119 | Discarded: 17
# Bag_9 | Samples: Yes | Predicates: No (All) | Valid: 112 | Discarded: 24
# Bag_10 | Samples: Yes | Predicates: No (All) | Valid: 110 | Discarded: 26
# ======================================================================
# PERTURBATION IMPORTANCE FOR PREDICATES
# ======================================================================
# Task type (aim): regression
# Perturbation mode: median
# Statistics source: full
# Metric: mean_abs_diff
# Total folds: 10
#
#
# [Bag_1] Processing 110 predicates...
#   Predicate: S > -0.07 (n=22)
#     Zone: 15 columns
#     Importance: 0.001456
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.001436
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.001668
#   Predicate: S <= 0.01 (n=17)
#     Zone: 15 columns
#     Importance: 0.001219
#   Predicate: S > 0.01 (n=11)
#     Zone: 15 columns
#     Importance: 0.002109
#   Predicate: S <= 0.05 (n=22)
#     Zone: 15 columns
#     Importance: 0.001161
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.020705
#   Predicate: Cl <= -0.04 (n=11)
#     Zone: 33 columns
#     Importance: 0.030578
#   Predicate: Cl > -0.04 (n=17)
#     Zone: 33 columns
#     Importance: 0.022507
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.021468
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.032185
#   Predicate: Cl <= 0.16 (n=21)
#     Zone: 33 columns
#     Importance: 0.020000
#   Predicate: Cl > 0.16 (n=7)
#     Zone: 33 columns
#     Importance: 0.042713
#   Predicate: K ka <= -0.48 (n=7)
#     Zone: 23 columns
#     Importance: 0.104479
#   Predicate: K ka > -0.48 (n=21)
#     Zone: 23 columns
#     Importance: 0.045637
#   Predicate: K ka <= -0.16 (n=12)
#     Zone: 23 columns
#     Importance: 0.078341
#   Predicate: K ka > -0.16 (n=16)
#     Zone: 23 columns
#     Importance: 0.046852
#   Predicate: K ka <= 0.20 (n=16)
#     Zone: 23 columns
#     Importance: 0.060935
#   Predicate: K ka > 0.20 (n=12)
#     Zone: 23 columns
#     Importance: 0.059564
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.054117
#   Predicate: K kb + Ca ka <= -0.14 (n=7)
#     Zone: 21 columns
#     Importance: 0.056553
#   Predicate: K kb + Ca ka > -0.14 (n=21)
#     Zone: 21 columns
#     Importance: 0.029168
#   Predicate: K kb + Ca ka <= -0.02 (n=11)
#     Zone: 21 columns
#     Importance: 0.045123
#   Predicate: K kb + Ca ka > -0.02 (n=17)
#     Zone: 21 columns
#     Importance: 0.030120
#   Predicate: K kb + Ca ka <= 0.11 (n=16)
#     Zone: 21 columns
#     Importance: 0.037860
#   Predicate: K kb + Ca ka > 0.11 (n=12)
#     Zone: 21 columns
#     Importance: 0.033553
#   Predicate: K kb + Ca ka <= 0.16 (n=22)
#     Zone: 21 columns
#     Importance: 0.035675
#   Predicate: background1 > -0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.006474
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.006757
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.006850
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.006073
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.008136
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.005783
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.000903
#   Predicate: Mn <= -0.03 (n=10)
#     Zone: 18 columns
#     Importance: 0.000718
#   Predicate: Mn > -0.03 (n=18)
#     Zone: 18 columns
#     Importance: 0.000979
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.000909
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.000859
#   Predicate: Mn <= 0.02 (n=21)
#     Zone: 18 columns
#     Importance: 0.000798
#   Predicate: Mn > 0.02 (n=7)
#     Zone: 18 columns
#     Importance: 0.001151
#   Predicate: Fe > -0.12 (n=22)
#     Zone: 64 columns
#     Importance: 0.008132
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.004438
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.010268
#   Predicate: Fe <= -0.01 (n=16)
#     Zone: 64 columns
#     Importance: 0.004227
#   Predicate: Fe > -0.01 (n=12)
#     Zone: 64 columns
#     Importance: 0.012007
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.004081
#   Predicate: Cu > -0.13 (n=22)
#     Zone: 52 columns
#     Importance: 0.006510
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.005192
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.007431
#   Predicate: Cu <= 0.01 (n=16)
#     Zone: 52 columns
#     Importance: 0.004715
#   Predicate: Cu > 0.01 (n=12)
#     Zone: 52 columns
#     Importance: 0.008813
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.005614
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.009045
#   Predicate: Zn <= -0.10 (n=7)
#     Zone: 27 columns
#     Importance: 0.007986
#   Predicate: Zn > -0.10 (n=21)
#     Zone: 27 columns
#     Importance: 0.006499
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.006802
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.006915
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.005393
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.008841
#   Predicate: Zn <= 0.07 (n=21)
#     Zone: 27 columns
#     Importance: 0.005435
#   Predicate: Zn > 0.07 (n=7)
#     Zone: 27 columns
#     Importance: 0.011179
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.006492
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.005068
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.006946
#   Predicate: background2 <= 0.06 (n=17)
#     Zone: 137 columns
#     Importance: 0.005636
#   Predicate: background2 > 0.06 (n=11)
#     Zone: 137 columns
#     Importance: 0.007093
#   Predicate: background2 <= 0.18 (n=21)
#     Zone: 137 columns
#     Importance: 0.005606
#   Predicate: background2 > 0.18 (n=7)
#     Zone: 137 columns
#     Importance: 0.008014
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.003844
#   Predicate: Br ka <= -0.05 (n=11)
#     Zone: 48 columns
#     Importance: 0.004184
#   Predicate: Br ka > -0.05 (n=17)
#     Zone: 48 columns
#     Importance: 0.003117
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.003854
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.003047
#   Predicate: Br ka <= 0.17 (n=22)
#     Zone: 48 columns
#     Importance: 0.003729
#   Predicate: Rb ka + Br kb > -0.28 (n=23)
#     Zone: 66 columns
#     Importance: 0.086479
#   Predicate: Rb ka + Br kb <= -0.12 (n=10)
#     Zone: 66 columns
#     Importance: 0.056102
#   Predicate: Rb ka + Br kb > -0.12 (n=18)
#     Zone: 66 columns
#     Importance: 0.101974
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.040019
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.156021
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.042327
#   Predicate: background3 > -0.26 (n=22)
#     Zone: 161 columns
#     Importance: 0.015179
#   Predicate: background3 <= -0.04 (n=11)
#     Zone: 161 columns
#     Importance: 0.022547
#   Predicate: background3 > -0.04 (n=17)
#     Zone: 161 columns
#     Importance: 0.015895
#   Predicate: background3 <= 0.08 (n=16)
#     Zone: 161 columns
#     Importance: 0.019193
#   Predicate: background3 > 0.08 (n=12)
#     Zone: 161 columns
#     Importance: 0.017595
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.015972
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.039389
#   Predicate: Rh ka Compton <= -0.05 (n=11)
#     Zone: 146 columns
#     Importance: 0.070818
#   Predicate: Rh ka Compton > -0.05 (n=17)
#     Zone: 146 columns
#     Importance: 0.041139
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.045477
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.065978
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.041019
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.010708
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.020653
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.010184
#   Predicate: Rh ka Rayleigh <= 0.09 (n=18)
#     Zone: 46 columns
#     Importance: 0.014550
#   Predicate: Rh ka Rayleigh > 0.09 (n=10)
#     Zone: 46 columns
#     Importance: 0.014887
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.013077
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.014276
#   Predicate: Rh kb Compton <= 0.00 (n=11)
#     Zone: 76 columns
#     Importance: 0.027106
#   Predicate: Rh kb Compton > 0.00 (n=17)
#     Zone: 76 columns
#     Importance: 0.014786
#   Predicate: Rh kb Compton <= 0.10 (n=18)
#     Zone: 76 columns
#     Importance: 0.017670
#   Predicate: Rh kb Compton > 0.10 (n=10)
#     Zone: 76 columns
#     Importance: 0.023149
#   Predicate: Rh kb Compton <= 0.25 (n=23)
#     Zone: 76 columns
#     Importance: 0.016188
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.002134
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.003171
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.002243
#   Predicate: Rh kb Rayleigh <= 0.06 (n=19)
#     Zone: 40 columns
#     Importance: 0.002696
#   Predicate: Rh kb Rayleigh > 0.06 (n=9)
#     Zone: 40 columns
#     Importance: 0.002525
#   Predicate: Rh kb Rayleigh <= 0.12 (n=23)
#     Zone: 40 columns
#     Importance: 0.002823
#
# [Bag_2] Processing 110 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.001996
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.001469
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.001466
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.001702
#   Predicate: S <= 0.01 (n=18)
#     Zone: 15 columns
#     Importance: 0.001205
#   Predicate: S > 0.01 (n=10)
#     Zone: 15 columns
#     Importance: 0.002314
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.001159
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.002927
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.022612
#   Predicate: Cl <= -0.04 (n=10)
#     Zone: 33 columns
#     Importance: 0.030489
#   Predicate: Cl > -0.04 (n=18)
#     Zone: 33 columns
#     Importance: 0.024517
#   Predicate: Cl <= 0.03 (n=15)
#     Zone: 33 columns
#     Importance: 0.021819
#   Predicate: Cl > 0.03 (n=13)
#     Zone: 33 columns
#     Importance: 0.032224
#   Predicate: Cl <= 0.16 (n=20)
#     Zone: 33 columns
#     Importance: 0.020546
#   Predicate: Cl > 0.16 (n=8)
#     Zone: 33 columns
#     Importance: 0.041911
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.044046
#   Predicate: K ka <= -0.16 (n=11)
#     Zone: 23 columns
#     Importance: 0.073233
#   Predicate: K ka > -0.16 (n=17)
#     Zone: 23 columns
#     Importance: 0.043566
#   Predicate: K ka <= 0.20 (n=16)
#     Zone: 23 columns
#     Importance: 0.053320
#   Predicate: K ka > 0.20 (n=12)
#     Zone: 23 columns
#     Importance: 0.057755
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.047592
#   Predicate: K kb + Ca ka <= -0.14 (n=8)
#     Zone: 21 columns
#     Importance: 0.050511
#   Predicate: K kb + Ca ka > -0.14 (n=20)
#     Zone: 21 columns
#     Importance: 0.023338
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.039526
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.023800
#   Predicate: K kb + Ca ka <= 0.11 (n=19)
#     Zone: 21 columns
#     Importance: 0.032362
#   Predicate: K kb + Ca ka > 0.11 (n=9)
#     Zone: 21 columns
#     Importance: 0.028441
#   Predicate: K kb + Ca ka <= 0.16 (n=23)
#     Zone: 21 columns
#     Importance: 0.029759
#   Predicate: background1 <= -0.06 (n=7)
#     Zone: 94 columns
#     Importance: 0.008389
#   Predicate: background1 > -0.06 (n=21)
#     Zone: 94 columns
#     Importance: 0.005562
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.007097
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.005648
#   Predicate: background1 <= 0.01 (n=19)
#     Zone: 94 columns
#     Importance: 0.006140
#   Predicate: background1 > 0.01 (n=9)
#     Zone: 94 columns
#     Importance: 0.006540
#   Predicate: background1 <= 0.06 (n=24)
#     Zone: 94 columns
#     Importance: 0.005780
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.000889
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.000675
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.000969
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.000804
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.000956
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.000753
#   Predicate: Fe <= -0.12 (n=7)
#     Zone: 64 columns
#     Importance: 0.005970
#   Predicate: Fe > -0.12 (n=21)
#     Zone: 64 columns
#     Importance: 0.007524
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.004853
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.009114
#   Predicate: Fe <= -0.01 (n=18)
#     Zone: 64 columns
#     Importance: 0.004266
#   Predicate: Fe > -0.01 (n=10)
#     Zone: 64 columns
#     Importance: 0.012301
#   Predicate: Fe <= 0.09 (n=24)
#     Zone: 64 columns
#     Importance: 0.004107
#   Predicate: Cu > -0.13 (n=22)
#     Zone: 52 columns
#     Importance: 0.007686
#   Predicate: Cu <= -0.05 (n=13)
#     Zone: 52 columns
#     Importance: 0.005393
#   Predicate: Cu > -0.05 (n=15)
#     Zone: 52 columns
#     Importance: 0.009193
#   Predicate: Cu <= 0.01 (n=16)
#     Zone: 52 columns
#     Importance: 0.005191
#   Predicate: Cu > 0.01 (n=12)
#     Zone: 52 columns
#     Importance: 0.010413
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.006014
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.011674
#   Predicate: Zn <= -0.10 (n=7)
#     Zone: 27 columns
#     Importance: 0.007786
#   Predicate: Zn > -0.10 (n=21)
#     Zone: 27 columns
#     Importance: 0.005705
#   Predicate: Zn <= -0.03 (n=12)
#     Zone: 27 columns
#     Importance: 0.006335
#   Predicate: Zn > -0.03 (n=16)
#     Zone: 27 columns
#     Importance: 0.006143
#   Predicate: Zn <= 0.02 (n=18)
#     Zone: 27 columns
#     Importance: 0.004926
#   Predicate: Zn > 0.02 (n=10)
#     Zone: 27 columns
#     Importance: 0.008564
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.004827
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.006084
#   Predicate: background2 <= -0.07 (n=12)
#     Zone: 137 columns
#     Importance: 0.004877
#   Predicate: background2 > -0.07 (n=16)
#     Zone: 137 columns
#     Importance: 0.006317
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.004996
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.006966
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.005084
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.003908
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.004658
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.003161
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.004270
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.003080
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.004067
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.082649
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.060624
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.098579
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.045867
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.142088
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.046650
#   Predicate: background3 > -0.26 (n=23)
#     Zone: 161 columns
#     Importance: 0.015461
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.023898
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.016156
#   Predicate: background3 <= 0.08 (n=17)
#     Zone: 161 columns
#     Importance: 0.020344
#   Predicate: background3 > 0.08 (n=11)
#     Zone: 161 columns
#     Importance: 0.018129
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.017511
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.038855
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.079139
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.041824
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.054481
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.063819
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.049544
#   Predicate: Rh ka Rayleigh > -0.15 (n=22)
#     Zone: 46 columns
#     Importance: 0.010369
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.025110
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.010062
#   Predicate: Rh ka Rayleigh <= 0.09 (n=18)
#     Zone: 46 columns
#     Importance: 0.017522
#   Predicate: Rh ka Rayleigh > 0.09 (n=10)
#     Zone: 46 columns
#     Importance: 0.014692
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.015588
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.014281
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.030665
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.015345
#   Predicate: Rh kb Compton <= 0.10 (n=18)
#     Zone: 76 columns
#     Importance: 0.021329
#   Predicate: Rh kb Compton > 0.10 (n=10)
#     Zone: 76 columns
#     Importance: 0.022957
#   Predicate: Rh kb Compton <= 0.25 (n=22)
#     Zone: 76 columns
#     Importance: 0.019413
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.002171
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.003819
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.002195
#   Predicate: Rh kb Rayleigh <= 0.06 (n=19)
#     Zone: 40 columns
#     Importance: 0.003105
#   Predicate: Rh kb Rayleigh > 0.06 (n=9)
#     Zone: 40 columns
#     Importance: 0.002440
#   Predicate: Rh kb Rayleigh <= 0.12 (n=22)
#     Zone: 40 columns
#     Importance: 0.003134
#
# [Bag_3] Processing 113 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.001996
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.001226
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.001572
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.001304
#   Predicate: S <= 0.01 (n=18)
#     Zone: 15 columns
#     Importance: 0.001276
#   Predicate: S > 0.01 (n=10)
#     Zone: 15 columns
#     Importance: 0.001676
#   Predicate: S <= 0.05 (n=23)
#     Zone: 15 columns
#     Importance: 0.001191
#   Predicate: Cl <= -0.20 (n=8)
#     Zone: 33 columns
#     Importance: 0.040470
#   Predicate: Cl > -0.20 (n=20)
#     Zone: 33 columns
#     Importance: 0.020463
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.031660
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.022070
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.023666
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.030064
#   Predicate: Cl <= 0.16 (n=22)
#     Zone: 33 columns
#     Importance: 0.022024
#   Predicate: K ka > -0.48 (n=22)
#     Zone: 23 columns
#     Importance: 0.041383
#   Predicate: K ka <= -0.16 (n=11)
#     Zone: 23 columns
#     Importance: 0.077268
#   Predicate: K ka > -0.16 (n=17)
#     Zone: 23 columns
#     Importance: 0.039233
#   Predicate: K ka <= 0.20 (n=17)
#     Zone: 23 columns
#     Importance: 0.053930
#   Predicate: K ka > 0.20 (n=11)
#     Zone: 23 columns
#     Importance: 0.054555
#   Predicate: K ka <= 0.44 (n=23)
#     Zone: 23 columns
#     Importance: 0.048752
#   Predicate: K kb + Ca ka <= -0.14 (n=9)
#     Zone: 21 columns
#     Importance: 0.053208
#   Predicate: K kb + Ca ka > -0.14 (n=19)
#     Zone: 21 columns
#     Importance: 0.024534
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.044638
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.024316
#   Predicate: K kb + Ca ka <= 0.11 (n=18)
#     Zone: 21 columns
#     Importance: 0.036337
#   Predicate: K kb + Ca ka > 0.11 (n=10)
#     Zone: 21 columns
#     Importance: 0.029095
#   Predicate: K kb + Ca ka <= 0.16 (n=22)
#     Zone: 21 columns
#     Importance: 0.032894
#   Predicate: background1 <= -0.06 (n=7)
#     Zone: 94 columns
#     Importance: 0.008389
#   Predicate: background1 > -0.06 (n=21)
#     Zone: 94 columns
#     Importance: 0.006142
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.007987
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.005741
#   Predicate: background1 <= 0.01 (n=17)
#     Zone: 94 columns
#     Importance: 0.007042
#   Predicate: background1 > 0.01 (n=11)
#     Zone: 94 columns
#     Importance: 0.006181
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.006383
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.000994
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.000599
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.001095
#   Predicate: Mn <= -0.02 (n=15)
#     Zone: 18 columns
#     Importance: 0.000897
#   Predicate: Mn > -0.02 (n=13)
#     Zone: 18 columns
#     Importance: 0.000980
#   Predicate: Mn <= 0.02 (n=23)
#     Zone: 18 columns
#     Importance: 0.000797
#   Predicate: Fe <= -0.12 (n=7)
#     Zone: 64 columns
#     Importance: 0.005970
#   Predicate: Fe > -0.12 (n=21)
#     Zone: 64 columns
#     Importance: 0.007760
#   Predicate: Fe <= -0.07 (n=11)
#     Zone: 64 columns
#     Importance: 0.004970
#   Predicate: Fe > -0.07 (n=17)
#     Zone: 64 columns
#     Importance: 0.008828
#   Predicate: Fe <= -0.01 (n=17)
#     Zone: 64 columns
#     Importance: 0.004369
#   Predicate: Fe > -0.01 (n=11)
#     Zone: 64 columns
#     Importance: 0.011860
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.004180
#   Predicate: Cu > -0.13 (n=23)
#     Zone: 52 columns
#     Importance: 0.007184
#   Predicate: Cu <= -0.05 (n=10)
#     Zone: 52 columns
#     Importance: 0.005852
#   Predicate: Cu > -0.05 (n=18)
#     Zone: 52 columns
#     Importance: 0.008000
#   Predicate: Cu <= 0.01 (n=15)
#     Zone: 52 columns
#     Importance: 0.004992
#   Predicate: Cu > 0.01 (n=13)
#     Zone: 52 columns
#     Importance: 0.009818
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.005752
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.011674
#   Predicate: Zn > -0.10 (n=22)
#     Zone: 27 columns
#     Importance: 0.005793
#   Predicate: Zn <= -0.03 (n=10)
#     Zone: 27 columns
#     Importance: 0.007001
#   Predicate: Zn > -0.03 (n=18)
#     Zone: 27 columns
#     Importance: 0.005973
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.005068
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.008035
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.004972
#   Predicate: background2 > -0.23 (n=23)
#     Zone: 137 columns
#     Importance: 0.006609
#   Predicate: background2 <= -0.07 (n=10)
#     Zone: 137 columns
#     Importance: 0.004294
#   Predicate: background2 > -0.07 (n=18)
#     Zone: 137 columns
#     Importance: 0.006930
#   Predicate: background2 <= 0.06 (n=16)
#     Zone: 137 columns
#     Importance: 0.004891
#   Predicate: background2 > 0.06 (n=12)
#     Zone: 137 columns
#     Importance: 0.007451
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.004988
#   Predicate: Br ka > -0.15 (n=23)
#     Zone: 48 columns
#     Importance: 0.004082
#   Predicate: Br ka <= -0.05 (n=10)
#     Zone: 48 columns
#     Importance: 0.004966
#   Predicate: Br ka > -0.05 (n=18)
#     Zone: 48 columns
#     Importance: 0.003479
#   Predicate: Br ka <= 0.04 (n=15)
#     Zone: 48 columns
#     Importance: 0.004394
#   Predicate: Br ka > 0.04 (n=13)
#     Zone: 48 columns
#     Importance: 0.003567
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.004197
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.080119
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.061694
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.094613
#   Predicate: Rb ka + Br kb <= -0.02 (n=18)
#     Zone: 66 columns
#     Importance: 0.042069
#   Predicate: Rb ka + Br kb > -0.02 (n=10)
#     Zone: 66 columns
#     Importance: 0.152982
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.044230
#   Predicate: background3 > -0.26 (n=24)
#     Zone: 161 columns
#     Importance: 0.016393
#   Predicate: background3 <= -0.04 (n=10)
#     Zone: 161 columns
#     Importance: 0.025319
#   Predicate: background3 > -0.04 (n=18)
#     Zone: 161 columns
#     Importance: 0.017166
#   Predicate: background3 <= 0.08 (n=15)
#     Zone: 161 columns
#     Importance: 0.020818
#   Predicate: background3 > 0.08 (n=13)
#     Zone: 161 columns
#     Importance: 0.019224
#   Predicate: background3 <= 0.19 (n=20)
#     Zone: 161 columns
#     Importance: 0.018245
#   Predicate: background3 > 0.19 (n=8)
#     Zone: 161 columns
#     Importance: 0.024658
#   Predicate: Rh ka Compton > -0.39 (n=23)
#     Zone: 146 columns
#     Importance: 0.045834
#   Predicate: Rh ka Compton <= -0.05 (n=11)
#     Zone: 146 columns
#     Importance: 0.077290
#   Predicate: Rh ka Compton > -0.05 (n=17)
#     Zone: 146 columns
#     Importance: 0.051091
#   Predicate: Rh ka Compton <= 0.14 (n=16)
#     Zone: 146 columns
#     Importance: 0.054841
#   Predicate: Rh ka Compton > 0.14 (n=12)
#     Zone: 146 columns
#     Importance: 0.070106
#   Predicate: Rh ka Compton <= 0.45 (n=20)
#     Zone: 146 columns
#     Importance: 0.049772
#   Predicate: Rh ka Compton > 0.45 (n=8)
#     Zone: 146 columns
#     Importance: 0.090413
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.011773
#   Predicate: Rh ka Rayleigh <= -0.02 (n=11)
#     Zone: 46 columns
#     Importance: 0.024373
#   Predicate: Rh ka Rayleigh > -0.02 (n=17)
#     Zone: 46 columns
#     Importance: 0.011980
#   Predicate: Rh ka Rayleigh <= 0.09 (n=16)
#     Zone: 46 columns
#     Importance: 0.017591
#   Predicate: Rh ka Rayleigh > 0.09 (n=12)
#     Zone: 46 columns
#     Importance: 0.015859
#   Predicate: Rh ka Rayleigh <= 0.21 (n=21)
#     Zone: 46 columns
#     Importance: 0.015281
#   Predicate: Rh ka Rayleigh > 0.21 (n=7)
#     Zone: 46 columns
#     Importance: 0.021553
#   Predicate: Rh kb Compton > -0.20 (n=23)
#     Zone: 76 columns
#     Importance: 0.016716
#   Predicate: Rh kb Compton <= 0.00 (n=11)
#     Zone: 76 columns
#     Importance: 0.030241
#   Predicate: Rh kb Compton > 0.00 (n=17)
#     Zone: 76 columns
#     Importance: 0.018576
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.020506
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.027259
#   Predicate: Rh kb Compton <= 0.25 (n=20)
#     Zone: 76 columns
#     Importance: 0.019310
#   Predicate: Rh kb Compton > 0.25 (n=8)
#     Zone: 76 columns
#     Importance: 0.032780
#   Predicate: Rh kb Rayleigh > -0.08 (n=23)
#     Zone: 40 columns
#     Importance: 0.002423
#   Predicate: Rh kb Rayleigh <= -0.02 (n=11)
#     Zone: 40 columns
#     Importance: 0.004059
#   Predicate: Rh kb Rayleigh > -0.02 (n=17)
#     Zone: 40 columns
#     Importance: 0.002535
#   Predicate: Rh kb Rayleigh <= 0.06 (n=18)
#     Zone: 40 columns
#     Importance: 0.003193
#   Predicate: Rh kb Rayleigh > 0.06 (n=10)
#     Zone: 40 columns
#     Importance: 0.003027
#   Predicate: Rh kb Rayleigh <= 0.12 (n=21)
#     Zone: 40 columns
#     Importance: 0.003329
#   Predicate: Rh kb Rayleigh > 0.12 (n=7)
#     Zone: 40 columns
#     Importance: 0.002548
#
# [Bag_4] Processing 108 predicates...
#   Predicate: S > -0.07 (n=23)
#     Zone: 15 columns
#     Importance: 0.001479
#   Predicate: S <= -0.02 (n=11)
#     Zone: 15 columns
#     Importance: 0.001461
#   Predicate: S > -0.02 (n=17)
#     Zone: 15 columns
#     Importance: 0.001687
#   Predicate: S <= 0.01 (n=14)
#     Zone: 15 columns
#     Importance: 0.001257
#   Predicate: S > 0.01 (n=14)
#     Zone: 15 columns
#     Importance: 0.001940
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.001155
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.002927
#   Predicate: Cl > -0.20 (n=23)
#     Zone: 33 columns
#     Importance: 0.020251
#   Predicate: Cl <= -0.04 (n=11)
#     Zone: 33 columns
#     Importance: 0.029055
#   Predicate: Cl > -0.04 (n=17)
#     Zone: 33 columns
#     Importance: 0.022260
#   Predicate: Cl <= 0.03 (n=17)
#     Zone: 33 columns
#     Importance: 0.020378
#   Predicate: Cl > 0.03 (n=11)
#     Zone: 33 columns
#     Importance: 0.031964
#   Predicate: Cl <= 0.16 (n=22)
#     Zone: 33 columns
#     Importance: 0.019166
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.046749
#   Predicate: K ka <= -0.16 (n=10)
#     Zone: 23 columns
#     Importance: 0.071151
#   Predicate: K ka > -0.16 (n=18)
#     Zone: 23 columns
#     Importance: 0.046835
#   Predicate: K ka <= 0.20 (n=14)
#     Zone: 23 columns
#     Importance: 0.054314
#   Predicate: K ka > 0.20 (n=14)
#     Zone: 23 columns
#     Importance: 0.056724
#   Predicate: K ka <= 0.44 (n=21)
#     Zone: 23 columns
#     Importance: 0.047381
#   Predicate: K ka > 0.44 (n=7)
#     Zone: 23 columns
#     Importance: 0.079934
#   Predicate: K kb + Ca ka > -0.14 (n=22)
#     Zone: 21 columns
#     Importance: 0.031118
#   Predicate: K kb + Ca ka <= -0.02 (n=9)
#     Zone: 21 columns
#     Importance: 0.047043
#   Predicate: K kb + Ca ka > -0.02 (n=19)
#     Zone: 21 columns
#     Importance: 0.031488
#   Predicate: K kb + Ca ka <= 0.11 (n=15)
#     Zone: 21 columns
#     Importance: 0.036165
#   Predicate: K kb + Ca ka > 0.11 (n=13)
#     Zone: 21 columns
#     Importance: 0.036860
#   Predicate: K kb + Ca ka <= 0.16 (n=21)
#     Zone: 21 columns
#     Importance: 0.034360
#   Predicate: K kb + Ca ka > 0.16 (n=7)
#     Zone: 21 columns
#     Importance: 0.042870
#   Predicate: background1 > -0.06 (n=22)
#     Zone: 94 columns
#     Importance: 0.006549
#   Predicate: background1 <= -0.02 (n=13)
#     Zone: 94 columns
#     Importance: 0.006538
#   Predicate: background1 > -0.02 (n=15)
#     Zone: 94 columns
#     Importance: 0.007193
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.006037
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.008423
#   Predicate: background1 <= 0.06 (n=23)
#     Zone: 94 columns
#     Importance: 0.005755
#   Predicate: Mn > -0.05 (n=22)
#     Zone: 18 columns
#     Importance: 0.000884
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.000720
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.000901
#   Predicate: Mn <= -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.000924
#   Predicate: Mn > -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.000762
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.000791
#   Predicate: Fe > -0.12 (n=22)
#     Zone: 64 columns
#     Importance: 0.008268
#   Predicate: Fe <= -0.07 (n=13)
#     Zone: 64 columns
#     Importance: 0.004874
#   Predicate: Fe > -0.07 (n=15)
#     Zone: 64 columns
#     Importance: 0.010467
#   Predicate: Fe <= -0.01 (n=17)
#     Zone: 64 columns
#     Importance: 0.004464
#   Predicate: Fe > -0.01 (n=11)
#     Zone: 64 columns
#     Importance: 0.013135
#   Predicate: Fe <= 0.09 (n=23)
#     Zone: 64 columns
#     Importance: 0.004321
#   Predicate: Cu > -0.13 (n=23)
#     Zone: 52 columns
#     Importance: 0.007076
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.004966
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.008392
#   Predicate: Cu <= 0.01 (n=18)
#     Zone: 52 columns
#     Importance: 0.004329
#   Predicate: Cu > 0.01 (n=10)
#     Zone: 52 columns
#     Importance: 0.011594
#   Predicate: Cu <= 0.11 (n=22)
#     Zone: 52 columns
#     Importance: 0.005311
#   Predicate: Zn > -0.10 (n=22)
#     Zone: 27 columns
#     Importance: 0.006203
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.006153
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.006610
#   Predicate: Zn <= 0.02 (n=18)
#     Zone: 27 columns
#     Importance: 0.004872
#   Predicate: Zn > 0.02 (n=10)
#     Zone: 27 columns
#     Importance: 0.009235
#   Predicate: Zn <= 0.07 (n=23)
#     Zone: 27 columns
#     Importance: 0.005024
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.006159
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.005113
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.006486
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.005445
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.006850
#   Predicate: background2 <= 0.18 (n=23)
#     Zone: 137 columns
#     Importance: 0.005431
#   Predicate: Br ka <= -0.15 (n=7)
#     Zone: 48 columns
#     Importance: 0.002868
#   Predicate: Br ka > -0.15 (n=21)
#     Zone: 48 columns
#     Importance: 0.003895
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.004291
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.003149
#   Predicate: Br ka <= 0.04 (n=18)
#     Zone: 48 columns
#     Importance: 0.003915
#   Predicate: Br ka > 0.04 (n=10)
#     Zone: 48 columns
#     Importance: 0.003139
#   Predicate: Br ka <= 0.17 (n=24)
#     Zone: 48 columns
#     Importance: 0.003654
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.081378
#   Predicate: Rb ka + Br kb <= -0.12 (n=10)
#     Zone: 66 columns
#     Importance: 0.063764
#   Predicate: Rb ka + Br kb > -0.12 (n=18)
#     Zone: 66 columns
#     Importance: 0.092400
#   Predicate: Rb ka + Br kb <= -0.02 (n=18)
#     Zone: 66 columns
#     Importance: 0.042633
#   Predicate: Rb ka + Br kb > -0.02 (n=10)
#     Zone: 66 columns
#     Importance: 0.153344
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.043278
#   Predicate: background3 > -0.26 (n=22)
#     Zone: 161 columns
#     Importance: 0.015442
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.023212
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.015342
#   Predicate: background3 <= 0.08 (n=17)
#     Zone: 161 columns
#     Importance: 0.020477
#   Predicate: background3 > 0.08 (n=11)
#     Zone: 161 columns
#     Importance: 0.015992
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.017668
#   Predicate: Rh ka Compton <= -0.39 (n=7)
#     Zone: 146 columns
#     Importance: 0.100225
#   Predicate: Rh ka Compton > -0.39 (n=21)
#     Zone: 146 columns
#     Importance: 0.037193
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.069903
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.040238
#   Predicate: Rh ka Compton <= 0.14 (n=18)
#     Zone: 146 columns
#     Importance: 0.048416
#   Predicate: Rh ka Compton > 0.14 (n=10)
#     Zone: 146 columns
#     Importance: 0.061115
#   Predicate: Rh ka Compton <= 0.45 (n=23)
#     Zone: 146 columns
#     Importance: 0.043217
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.010469
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.021460
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.010337
#   Predicate: Rh ka Rayleigh <= 0.09 (n=17)
#     Zone: 46 columns
#     Importance: 0.015973
#   Predicate: Rh ka Rayleigh > 0.09 (n=11)
#     Zone: 46 columns
#     Importance: 0.013761
#   Predicate: Rh ka Rayleigh <= 0.21 (n=23)
#     Zone: 46 columns
#     Importance: 0.013795
#   Predicate: Rh kb Compton <= -0.20 (n=7)
#     Zone: 76 columns
#     Importance: 0.039156
#   Predicate: Rh kb Compton > -0.20 (n=21)
#     Zone: 76 columns
#     Importance: 0.013904
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.027349
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.014868
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.019911
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.020689
#   Predicate: Rh kb Compton <= 0.25 (n=24)
#     Zone: 76 columns
#     Importance: 0.017414
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.001989
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.003392
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.002125
#   Predicate: Rh kb Rayleigh <= 0.06 (n=20)
#     Zone: 40 columns
#     Importance: 0.002773
#   Predicate: Rh kb Rayleigh > 0.06 (n=8)
#     Zone: 40 columns
#     Importance: 0.002406
#   Predicate: Rh kb Rayleigh <= 0.12 (n=23)
#     Zone: 40 columns
#     Importance: 0.002856
#
# [Bag_5] Processing 107 predicates...
#   Predicate: S > -0.07 (n=22)
#     Zone: 15 columns
#     Importance: 0.001489
#   Predicate: S <= -0.02 (n=11)
#     Zone: 15 columns
#     Importance: 0.001537
#   Predicate: S > -0.02 (n=17)
#     Zone: 15 columns
#     Importance: 0.001676
#   Predicate: S <= 0.01 (n=16)
#     Zone: 15 columns
#     Importance: 0.001254
#   Predicate: S > 0.01 (n=12)
#     Zone: 15 columns
#     Importance: 0.002110
#   Predicate: S <= 0.05 (n=21)
#     Zone: 15 columns
#     Importance: 0.001186
#   Predicate: S > 0.05 (n=7)
#     Zone: 15 columns
#     Importance: 0.002927
#   Predicate: Cl <= -0.20 (n=8)
#     Zone: 33 columns
#     Importance: 0.040470
#   Predicate: Cl > -0.20 (n=20)
#     Zone: 33 columns
#     Importance: 0.022691
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.031660
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.024854
#   Predicate: Cl <= 0.03 (n=16)
#     Zone: 33 columns
#     Importance: 0.024685
#   Predicate: Cl > 0.03 (n=12)
#     Zone: 33 columns
#     Importance: 0.031885
#   Predicate: Cl <= 0.16 (n=21)
#     Zone: 33 columns
#     Importance: 0.022790
#   Predicate: Cl > 0.16 (n=7)
#     Zone: 33 columns
#     Importance: 0.042713
#   Predicate: K ka > -0.48 (n=23)
#     Zone: 23 columns
#     Importance: 0.044427
#   Predicate: K ka <= -0.16 (n=12)
#     Zone: 23 columns
#     Importance: 0.069980
#   Predicate: K ka > -0.16 (n=16)
#     Zone: 23 columns
#     Importance: 0.044699
#   Predicate: K ka <= 0.20 (n=17)
#     Zone: 23 columns
#     Importance: 0.051739
#   Predicate: K ka > 0.20 (n=11)
#     Zone: 23 columns
#     Importance: 0.061398
#   Predicate: K ka <= 0.44 (n=22)
#     Zone: 23 columns
#     Importance: 0.047990
#   Predicate: K kb + Ca ka <= -0.14 (n=8)
#     Zone: 21 columns
#     Importance: 0.050511
#   Predicate: K kb + Ca ka > -0.14 (n=20)
#     Zone: 21 columns
#     Importance: 0.023263
#   Predicate: K kb + Ca ka <= -0.02 (n=13)
#     Zone: 21 columns
#     Importance: 0.039526
#   Predicate: K kb + Ca ka > -0.02 (n=15)
#     Zone: 21 columns
#     Importance: 0.023700
#   Predicate: K kb + Ca ka <= 0.11 (n=19)
#     Zone: 21 columns
#     Importance: 0.032671
#   Predicate: K kb + Ca ka > 0.11 (n=9)
#     Zone: 21 columns
#     Importance: 0.027621
#   Predicate: K kb + Ca ka <= 0.16 (n=23)
#     Zone: 21 columns
#     Importance: 0.030015
#   Predicate: background1 > -0.06 (n=22)
#     Zone: 94 columns
#     Importance: 0.005632
#   Predicate: background1 <= -0.02 (n=12)
#     Zone: 94 columns
#     Importance: 0.006614
#   Predicate: background1 > -0.02 (n=16)
#     Zone: 94 columns
#     Importance: 0.005835
#   Predicate: background1 <= 0.01 (n=18)
#     Zone: 94 columns
#     Importance: 0.005829
#   Predicate: background1 > 0.01 (n=10)
#     Zone: 94 columns
#     Importance: 0.006780
#   Predicate: background1 <= 0.06 (n=25)
#     Zone: 94 columns
#     Importance: 0.005553
#   Predicate: Mn > -0.05 (n=23)
#     Zone: 18 columns
#     Importance: 0.001051
#   Predicate: Mn <= -0.03 (n=9)
#     Zone: 18 columns
#     Importance: 0.000723
#   Predicate: Mn > -0.03 (n=19)
#     Zone: 18 columns
#     Importance: 0.001142
#   Predicate: Mn <= -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.001004
#   Predicate: Mn > -0.02 (n=14)
#     Zone: 18 columns
#     Importance: 0.001010
#   Predicate: Mn <= 0.02 (n=22)
#     Zone: 18 columns
#     Importance: 0.000922
#   Predicate: Fe > -0.12 (n=23)
#     Zone: 64 columns
#     Importance: 0.007453
#   Predicate: Fe <= -0.07 (n=11)
#     Zone: 64 columns
#     Importance: 0.005267
#   Predicate: Fe > -0.07 (n=17)
#     Zone: 64 columns
#     Importance: 0.008722
#   Predicate: Fe <= -0.01 (n=16)
#     Zone: 64 columns
#     Importance: 0.004478
#   Predicate: Fe > -0.01 (n=12)
#     Zone: 64 columns
#     Importance: 0.011215
#   Predicate: Fe <= 0.09 (n=22)
#     Zone: 64 columns
#     Importance: 0.004247
#   Predicate: Cu > -0.13 (n=24)
#     Zone: 52 columns
#     Importance: 0.007180
#   Predicate: Cu <= -0.05 (n=12)
#     Zone: 52 columns
#     Importance: 0.004475
#   Predicate: Cu > -0.05 (n=16)
#     Zone: 52 columns
#     Importance: 0.008806
#   Predicate: Cu <= 0.01 (n=15)
#     Zone: 52 columns
#     Importance: 0.004369
#   Predicate: Cu > 0.01 (n=13)
#     Zone: 52 columns
#     Importance: 0.009928
#   Predicate: Cu <= 0.11 (n=21)
#     Zone: 52 columns
#     Importance: 0.005375
#   Predicate: Cu > 0.11 (n=7)
#     Zone: 52 columns
#     Importance: 0.011674
#   Predicate: Zn > -0.10 (n=23)
#     Zone: 27 columns
#     Importance: 0.005852
#   Predicate: Zn <= -0.03 (n=11)
#     Zone: 27 columns
#     Importance: 0.005461
#   Predicate: Zn > -0.03 (n=17)
#     Zone: 27 columns
#     Importance: 0.006360
#   Predicate: Zn <= 0.02 (n=16)
#     Zone: 27 columns
#     Importance: 0.004241
#   Predicate: Zn > 0.02 (n=12)
#     Zone: 27 columns
#     Importance: 0.008361
#   Predicate: Zn <= 0.07 (n=22)
#     Zone: 27 columns
#     Importance: 0.004549
#   Predicate: background2 > -0.23 (n=22)
#     Zone: 137 columns
#     Importance: 0.006246
#   Predicate: background2 <= -0.07 (n=11)
#     Zone: 137 columns
#     Importance: 0.005443
#   Predicate: background2 > -0.07 (n=17)
#     Zone: 137 columns
#     Importance: 0.006385
#   Predicate: background2 <= 0.06 (n=18)
#     Zone: 137 columns
#     Importance: 0.005554
#   Predicate: background2 > 0.06 (n=10)
#     Zone: 137 columns
#     Importance: 0.006845
#   Predicate: background2 <= 0.18 (n=22)
#     Zone: 137 columns
#     Importance: 0.005486
#   Predicate: Br ka > -0.15 (n=22)
#     Zone: 48 columns
#     Importance: 0.004228
#   Predicate: Br ka <= -0.05 (n=12)
#     Zone: 48 columns
#     Importance: 0.004472
#   Predicate: Br ka > -0.05 (n=16)
#     Zone: 48 columns
#     Importance: 0.003600
#   Predicate: Br ka <= 0.04 (n=17)
#     Zone: 48 columns
#     Importance: 0.004095
#   Predicate: Br ka > 0.04 (n=11)
#     Zone: 48 columns
#     Importance: 0.003787
#   Predicate: Br ka <= 0.17 (n=23)
#     Zone: 48 columns
#     Importance: 0.004276
#   Predicate: Rb ka + Br kb > -0.28 (n=22)
#     Zone: 66 columns
#     Importance: 0.083487
#   Predicate: Rb ka + Br kb <= -0.12 (n=11)
#     Zone: 66 columns
#     Importance: 0.060203
#   Predicate: Rb ka + Br kb > -0.12 (n=17)
#     Zone: 66 columns
#     Importance: 0.099111
#   Predicate: Rb ka + Br kb <= -0.02 (n=17)
#     Zone: 66 columns
#     Importance: 0.046127
#   Predicate: Rb ka + Br kb > -0.02 (n=11)
#     Zone: 66 columns
#     Importance: 0.142088
#   Predicate: Rb ka + Br kb <= 0.14 (n=23)
#     Zone: 66 columns
#     Importance: 0.046842
#   Predicate: background3 > -0.26 (n=23)
#     Zone: 161 columns
#     Importance: 0.016268
#   Predicate: background3 <= -0.04 (n=12)
#     Zone: 161 columns
#     Importance: 0.020484
#   Predicate: background3 > -0.04 (n=16)
#     Zone: 161 columns
#     Importance: 0.017315
#   Predicate: background3 <= 0.08 (n=16)
#     Zone: 161 columns
#     Importance: 0.018709
#   Predicate: background3 > 0.08 (n=12)
#     Zone: 161 columns
#     Importance: 0.018625
#   Predicate: background3 <= 0.19 (n=23)
#     Zone: 161 columns
#     Importance: 0.015982
#   Predicate: Rh ka Compton > -0.39 (n=22)
#     Zone: 146 columns
#     Importance: 0.040091
#   Predicate: Rh ka Compton <= -0.05 (n=12)
#     Zone: 146 columns
#     Importance: 0.064933
#   Predicate: Rh ka Compton > -0.05 (n=16)
#     Zone: 146 columns
#     Importance: 0.043524
#   Predicate: Rh ka Compton <= 0.14 (n=17)
#     Zone: 146 columns
#     Importance: 0.047251
#   Predicate: Rh ka Compton > 0.14 (n=11)
#     Zone: 146 columns
#     Importance: 0.061120
#   Predicate: Rh ka Compton <= 0.45 (n=22)
#     Zone: 146 columns
#     Importance: 0.042745
#   Predicate: Rh ka Rayleigh > -0.15 (n=23)
#     Zone: 46 columns
#     Importance: 0.011243
#   Predicate: Rh ka Rayleigh <= -0.02 (n=12)
#     Zone: 46 columns
#     Importance: 0.020988
#   Predicate: Rh ka Rayleigh > -0.02 (n=16)
#     Zone: 46 columns
#     Importance: 0.010815
#   Predicate: Rh ka Rayleigh <= 0.09 (n=17)
#     Zone: 46 columns
#     Importance: 0.015639
#   Predicate: Rh ka Rayleigh > 0.09 (n=11)
#     Zone: 46 columns
#     Importance: 0.014457
#   Predicate: Rh ka Rayleigh <= 0.21 (n=22)
#     Zone: 46 columns
#     Importance: 0.013789
#   Predicate: Rh kb Compton > -0.20 (n=22)
#     Zone: 76 columns
#     Importance: 0.014852
#   Predicate: Rh kb Compton <= 0.00 (n=12)
#     Zone: 76 columns
#     Importance: 0.024825
#   Predicate: Rh kb Compton > 0.00 (n=16)
#     Zone: 76 columns
#     Importance: 0.016129
#   Predicate: Rh kb Compton <= 0.10 (n=17)
#     Zone: 76 columns
#     Importance: 0.018146
#   Predicate: Rh kb Compton > 0.10 (n=11)
#     Zone: 76 columns
#     Importance: 0.022499
#   Predicate: Rh kb Compton <= 0.25 (n=22)
#     Zone: 76 columns
#     Importance: 0.016489
#   Predicate: Rh kb Rayleigh > -0.08 (n=22)
#     Zone: 40 columns
#     Importance: 0.002374
#   Predicate: Rh kb Rayleigh <= -0.02 (n=12)
#     Zone: 40 columns
#     Importance: 0.003520
#   Predicate: Rh kb Rayleigh > -0.02 (n=16)
#     Zone: 40 columns
#     Importance: 0.002474
#   Predicate: Rh kb Rayleigh <= 0.06 (n=18)
#     Zone: 40 columns
#     Importance: 0.003001
#   Predicate: Rh kb Rayleigh > 0.06 (n=10)
#     Zone: 40 columns
#     Importance: 0.002780
#   Predicate: Rh kb Rayleigh <= 0.12 (n=22)
#     Zone: 40 columns
#     Importance: 0.003078
#
# [Bag_6] Processing 106 predicates...
#   Predicate: S <= -0.07 (n=7)
#     Zone: 15 columns
#     Importance: 0.001997
#   Predicate: S > -0.07 (n=21)
#     Zone: 15 columns
#     Importance: 0.001480
#   Predicate: S <= -0.02 (n=12)
#     Zone: 15 columns
#     Importance: 0.001520
#   Predicate: S > -0.02 (n=16)
#     Zone: 15 columns
#     Importance: 0.001676
#   Predicate: S <= 0.01 (n=16)
#     Zone: 15 columns
#     Importance: 0.001291
#   Predicate: S > 0.01 (n=12)
#     Zone: 15 columns
#     Importance: 0.002034
#   Predicate: S <= 0.05 (n=22)
#     Zone: 15 columns
#     Importance: 0.001168
#   Predicate: Cl > -0.20 (n=22)
#     Zone: 33 columns
#     Importance: 0.022792
#   Predicate: Cl <= -0.04 (n=12)
#     Zone: 33 columns
#     Importance: 0.028760
#   Predicate: Cl > -0.04 (n=16)
#     Zone: 33 columns
#     Importance: 0.025879
#   Predicate: Cl <= 0.03 (n=16)
#     Zone: 33 columns
#     Importance: 0.022435
#   Predicate: Cl > 0.03 (n=12)
#     Zone: 33 columns
#     Importance: 0.033352
#   Predicate: Cl <= 0.16 (n=20)
#     Zone: 33 columns
#     Importance: 0.021195
#   Predicate: Cl > 0.16 (n=8)
#     Zone: 33 columns
#     Importance: 0.041911
#   Predicate: K ka > -0.48 (n=24)
#     Zone: 23 columns
#     Importance: 0.044543
#   Predicate: K ka <= -0.16 (n=9)
#     Zone: 23 columns
# ...
# Removed: K ka > 0.20 -> Rh ka Compton <= 0.14 (0.0586) | Kept: Rh ka Compton <= 0.14 -> K ka > 0.20 (0.1041)
# Removed: K kb + Ca ka <= -0.14 -> Rh ka Compton <= 0.14 (0.0359) | Kept: Rh ka Compton <= 0.14 -> K kb + Ca ka <= -0.14 (0.0515)
# Removed: Rh ka Compton <= 0.14 -> K ka <= 0.44 (0.0479) | Kept: K ka <= 0.44 -> Rh ka Compton <= 0.14 (0.0523)
# Removed: K ka <= 0.20 -> K ka > 0.20 (0.0541) | Kept: K ka > 0.20 -> K ka <= 0.20 (0.2255)
# Removed: Rh ka Compton <= 0.45 -> Rb ka + Br kb <= 0.14 (0.0445) | Kept: Rb ka + Br kb <= 0.14 -> Rh ka Compton <= 0.45 (0.1006)
# Removed: K kb + Ca ka <= -0.14 -> K ka <= 0.20 (0.0690) | Kept: K ka <= 0.20 -> K kb + Ca ka <= -0.14 (0.1168)
# Removed: Rh ka Compton > -0.05 -> K ka > -0.48 (0.0763) | Kept: K ka > -0.48 -> Rh ka Compton > -0.05 (0.0827)
# Removed: Rb ka + Br kb <= 0.14 -> K ka <= 0.44 (0.0690) | Kept: K ka <= 0.44 -> Rb ka + Br kb <= 0.14 (0.0931)
# Removed: Rb ka + Br kb <= -0.02 -> K ka <= 0.44 (0.0375) | Kept: K ka <= 0.44 -> Rb ka + Br kb <= -0.02 (0.0898)
# Removed: K kb + Ca ka <= -0.02 -> K ka <= 0.44 (0.0292) | Kept: K ka <= 0.44 -> K kb + Ca ka <= -0.02 (0.1028)
# Removed: Rb ka + Br kb <= 0.14 -> Rb ka + Br kb <= -0.02 (0.0332) | Kept: Rb ka + Br kb <= -0.02 -> Rb ka + Br kb <= 0.14 (0.0334)
# Removed: Rh ka Compton > -0.39 -> K ka > -0.48 (0.0352) | Kept: K ka > -0.48 -> Rh ka Compton > -0.39 (0.0428)
# Removed: K ka > -0.48 -> K ka > -0.16 (0.1175) | Kept: K ka > -0.16 -> K ka > -0.48 (0.1310)
# Removed: Rh ka Compton > -0.39 -> K ka > -0.16 (0.0382) | Kept: K ka > -0.16 -> Rh ka Compton > -0.39 (0.0767)
# Removed: Rh ka Compton > -0.39 -> K kb + Ca ka > 0.11 (0.0351) | Kept: K kb + Ca ka > 0.11 -> Rh ka Compton > -0.39 (0.0498)
# Removed: Rh ka Compton > -0.39 -> K kb + Ca ka <= -0.02 (0.0338) | Kept: K kb + Ca ka <= -0.02 -> Rh ka Compton > -0.39 (0.0543)
# Removed: K kb + Ca ka <= -0.02 -> K ka > -0.16 (0.0612) | Kept: K ka > -0.16 -> K kb + Ca ka <= -0.02 (0.0832)
# Removed: K kb + Ca ka <= 0.11 -> Cl > 0.03 (0.0203) | Kept: Cl > 0.03 -> K kb + Ca ka <= 0.11 (0.0519)
# Removed: K kb + Ca ka <= 0.16 -> K kb + Ca ka <= 0.11 (0.0212) | Kept: K kb + Ca ka <= 0.11 -> K kb + Ca ka <= 0.16 (0.0883)
# Removed: Rh kb Compton <= 0.00 -> Cl > 0.03 (0.0272) | Kept: Cl > 0.03 -> Rh kb Compton <= 0.00 (0.0520)
# Removed: Cl <= -0.04 -> Rh kb Compton <= 0.00 (0.0442) | Kept: Rh kb Compton <= 0.00 -> Cl <= -0.04 (0.0754)
# Removed: K kb + Ca ka > -0.02 -> Rh kb Compton <= 0.00 (0.0205) | Kept: Rh kb Compton <= 0.00 -> K kb + Ca ka > -0.02 (0.0287)
# Removed: Rh kb Compton <= 0.00 -> K kb + Ca ka <= 0.16 (0.0283) | Kept: K kb + Ca ka <= 0.16 -> Rh kb Compton <= 0.00 (0.0450)
# Removed: K kb + Ca ka > -0.14 -> Cl <= -0.04 (0.0172) | Kept: Cl <= -0.04 -> K kb + Ca ka > -0.14 (0.0480)
# Removed: K kb + Ca ka <= 0.16 -> K kb + Ca ka > 0.11 (0.0182) | Kept: K kb + Ca ka > 0.11 -> K kb + Ca ka <= 0.16 (0.0234)
# Removed: K kb + Ca ka > -0.02 -> K kb + Ca ka <= 0.16 (0.0190) | Kept: K kb + Ca ka <= 0.16 -> K kb + Ca ka > -0.02 (0.0411)
# Removed: background3 <= -0.04 -> Rh ka Rayleigh <= -0.02 (0.0358) | Kept: Rh ka Rayleigh <= -0.02 -> background3 <= -0.04 (0.0418)
# Removed: Rh kb Compton > 0.10 -> background3 <= -0.04 (0.0213) | Kept: background3 <= -0.04 -> Rh kb Compton > 0.10 (0.0331)
# Removed: Cl > -0.04 -> background3 <= -0.04 (0.0207) | Kept: background3 <= -0.04 -> Cl > -0.04 (0.0339)
# Removed: Rh kb Compton <= 0.10 -> Rh ka Rayleigh <= -0.02 (0.0206) | Kept: Rh ka Rayleigh <= -0.02 -> Rh kb Compton <= 0.10 (0.0613)
# Removed: Rh ka Rayleigh <= -0.02 -> Rh kb Compton > 0.10 (0.0189) | Kept: Rh kb Compton > 0.10 -> Rh ka Rayleigh <= -0.02 (0.0192)
# Removed: Cl <= 0.16 -> Rh ka Rayleigh <= -0.02 (0.0164) | Kept: Rh ka Rayleigh <= -0.02 -> Cl <= 0.16 (0.0167)
# Removed: Rh kb Compton <= 0.10 -> Cl <= 0.03 (0.0179) | Kept: Cl <= 0.03 -> Rh kb Compton <= 0.10 (0.0181)
# Removed: background3 <= 0.08 -> Rh kb Compton <= 0.10 (0.0134) | Kept: Rh kb Compton <= 0.10 -> background3 <= 0.08 (0.0339)
# Removed: Rh kb Compton <= 0.10 -> Rh kb Compton > 0.10 (0.0187) | Kept: Rh kb Compton > 0.10 -> Rh kb Compton <= 0.10 (0.0365)
# Removed: background3 <= 0.08 -> Cl > -0.04 (0.0144) | Kept: Cl > -0.04 -> background3 <= 0.08 (0.0178)
# Removed: background3 <= 0.08 -> Rh kb Compton > 0.10 (0.0161) | Kept: Rh kb Compton > 0.10 -> background3 <= 0.08 (0.0187)
# Removed: background3 > 0.19 -> Rh kb Compton > 0.10 (0.0173) | Kept: Rh kb Compton > 0.10 -> background3 > 0.19 (0.0204)
# Removed: K kb + Ca ka > -0.14 -> K kb + Ca ka > -0.02 (0.0331) | Kept: K kb + Ca ka > -0.02 -> K kb + Ca ka > -0.14 (0.0601)
# Removed: K kb + Ca ka > -0.02 -> Rh kb Compton > 0.25 (0.0213) | Kept: Rh kb Compton > 0.25 -> K kb + Ca ka > -0.02 (0.0268)
# Removed: background3 <= 0.08 -> Cl > -0.20 (0.0156) | Kept: Cl > -0.20 -> background3 <= 0.08 (0.0158)
# Removed: background3 <= 0.08 -> Cl <= 0.16 (0.0144) | Kept: Cl <= 0.16 -> background3 <= 0.08 (0.0167)
# Removed: background3 <= 0.08 -> Cl <= 0.03 (0.0157) | Kept: Cl <= 0.03 -> background3 <= 0.08 (0.0167)
# Removed: Rh kb Compton <= 0.25 -> Cl > -0.20 (0.0322) | Kept: Cl > -0.20 -> Rh kb Compton <= 0.25 (0.0487)
# Removed: Cl > -0.20 -> Cl <= 0.03 (0.0157) | Kept: Cl <= 0.03 -> Cl > -0.20 (0.0320)
# Removed: Cl <= 0.16 -> Cl > -0.20 (0.0162) | Kept: Cl > -0.20 -> Cl <= 0.16 (0.0166)
# Removed: Rh kb Compton > 0.00 -> background3 > 0.08 (0.0136) | Kept: background3 > 0.08 -> Rh kb Compton > 0.00 (0.0258)
# Removed: background3 > 0.08 -> background3 <= 0.19 (0.0120) | Kept: background3 <= 0.19 -> background3 > 0.08 (0.0509)
# Removed: Rh ka Rayleigh > 0.21 -> Cl <= 0.03 (0.0170) | Kept: Cl <= 0.03 -> Rh ka Rayleigh > 0.21 (0.0173)
# Removed: Rh kb Compton > 0.00 -> background3 > -0.04 (0.0278) | Kept: background3 > -0.04 -> Rh kb Compton > 0.00 (0.0466)
# Removed: background3 > -0.04 -> Rh ka Rayleigh <= 0.21 (0.0229) | Kept: Rh ka Rayleigh <= 0.21 -> background3 > -0.04 (0.0267)
# Removed: background3 > -0.04 -> Rh ka Rayleigh > 0.09 (0.0107) | Kept: Rh ka Rayleigh > 0.09 -> background3 > -0.04 (0.0135)
# Removed: Rh ka Rayleigh <= 0.21 -> Rh kb Compton > 0.00 (0.0129) | Kept: Rh kb Compton > 0.00 -> Rh ka Rayleigh <= 0.21 (0.0133)
# Removed: Rh ka Rayleigh <= 0.21 -> background3 > -0.26 (0.0130) | Kept: background3 > -0.26 -> Rh ka Rayleigh <= 0.21 (0.0237)
# Removed: Rh ka Rayleigh > 0.09 -> background3 > -0.26 (0.0124) | Kept: background3 > -0.26 -> Rh ka Rayleigh > 0.09 (0.0323)
# Removed: background3 > -0.26 -> Rh kb Compton > -0.20 (0.0214) | Kept: Rh kb Compton > -0.20 -> background3 > -0.26 (0.0383)
# Removed: Rh ka Rayleigh > 0.09 -> Rh kb Compton > -0.20 (0.0124) | Kept: Rh kb Compton > -0.20 -> Rh ka Rayleigh > 0.09 (0.0378)
# Removed: Fe > -0.01 -> Rh ka Rayleigh > -0.15 (0.0069) | Kept: Rh ka Rayleigh > -0.15 -> Fe > -0.01 (0.0289)
# Removed: Zn > 0.02 -> Fe > -0.01 (0.0050) | Kept: Fe > -0.01 -> Zn > 0.02 (0.0050)
# Removed: Rh ka Rayleigh > -0.15 -> Rh ka Rayleigh > -0.02 (0.0186) | Kept: Rh ka Rayleigh > -0.02 -> Rh ka Rayleigh > -0.15 (0.0777)
# Removed: Cu > 0.01 -> Fe > -0.07 (0.0110) | Kept: Fe > -0.07 -> Cu > 0.01 (0.0208)
# Removed: Zn > 0.02 -> Fe > -0.07 (0.0047) | Kept: Fe > -0.07 -> Zn > 0.02 (0.0054)
# Removed: Fe > -0.07 -> Cu > 0.11 (0.0053) | Kept: Cu > 0.11 -> Fe > -0.07 (0.0057)
# Removed: background1 > 0.01 -> Cu > -0.05 (0.0028) | Kept: Cu > -0.05 -> background1 > 0.01 (0.0041)
# Removed: Zn > 0.02 -> Zn <= -0.10 (0.0047) | Kept: Zn <= -0.10 -> Zn > 0.02 (0.0052)
# Removed: Fe > -0.12 -> Zn <= -0.10 (0.0044) | Kept: Zn <= -0.10 -> Fe > -0.12 (0.0047)
# Removed: background1 > 0.01 -> Zn > 0.02 (0.0043) | Kept: Zn > 0.02 -> background1 > 0.01 (0.0100)
# Removed: Cu > -0.13 -> background2 > 0.06 (0.0072) | Kept: background2 > 0.06 -> Cu > -0.13 (0.0094)
# Removed: background1 > 0.01 -> Fe > -0.12 (0.0014) | Kept: Fe > -0.12 -> background1 > 0.01 (0.0046)
# Removed: background1 > -0.06 -> Fe > -0.12 (0.0011) | Kept: Fe > -0.12 -> background1 > -0.06 (0.0035)
# Removed: background1 <= -0.02 -> Fe > -0.12 (0.0011) | Kept: Fe > -0.12 -> background1 <= -0.02 (0.0043)
# Removed: background1 > -0.02 -> background2 > 0.06 (0.0025) | Kept: background2 > 0.06 -> background1 > -0.02 (0.0051)
# Removed: Zn <= -0.03 -> background2 > 0.06 (0.0041) | Kept: background2 > 0.06 -> Zn <= -0.03 (0.0098)
# Removed: background1 <= -0.02 -> Zn <= -0.03 (0.0013) | Kept: Zn <= -0.03 -> background1 <= -0.02 (0.0078)
# Removed: background1 <= -0.02 -> background2 > -0.07 (0.0034) | Kept: background2 > -0.07 -> background1 <= -0.02 (0.0049)
# Removed: background1 <= -0.02 -> Zn > -0.03 (0.0023) | Kept: Zn > -0.03 -> background1 <= -0.02 (0.0040)
# Removed: background1 > -0.06 -> background1 <= -0.02 (0.0012) | Kept: background1 <= -0.02 -> background1 > -0.06 (0.0013)
# Removed: Zn <= -0.03 -> background2 > -0.23 (0.0036) | Kept: background2 > -0.23 -> Zn <= -0.03 (0.0040)
# Removed: background1 > -0.06 -> Zn <= -0.03 (0.0023) | Kept: Zn <= -0.03 -> background1 > -0.06 (0.0039)
# Removed: background1 > -0.02 -> background2 > -0.07 (0.0013) | Kept: background2 > -0.07 -> background1 > -0.02 (0.0092)
# Removed: background1 <= 0.01 -> background2 > -0.23 (0.0011) | Kept: background2 > -0.23 -> background1 <= 0.01 (0.0086)
# Removed: background2 > -0.23 -> Zn > -0.03 (0.0042) | Kept: Zn > -0.03 -> background2 > -0.23 (0.0115)
# Removed: background1 <= 0.06 -> Zn > -0.03 (0.0010) | Kept: Zn > -0.03 -> background1 <= 0.06 (0.0036)
# Removed: background2 > -0.23 -> Zn > -0.10 (0.0040) | Kept: Zn > -0.10 -> background2 > -0.23 (0.0109)
# Removed: background1 <= 0.06 -> Cu <= 0.11 (0.0021) | Kept: Cu <= 0.11 -> background1 <= 0.06 (0.0028)
# Removed: Cu <= 0.11 -> Zn > -0.10 (0.0032) | Kept: Zn > -0.10 -> Cu <= 0.11 (0.0033)
# Removed: Zn <= 0.02 -> Cu <= 0.11 (0.0033) | Kept: Cu <= 0.11 -> Zn <= 0.02 (0.0058)
# Removed: background2 <= 0.18 -> Cu <= 0.11 (0.0073) | Kept: Cu <= 0.11 -> background2 <= 0.18 (0.0081)
# Removed: background1 > -0.06 -> background1 > -0.02 (0.0013) | Kept: background1 > -0.02 -> background1 > -0.06 (0.0023)
# Removed: Cu <= -0.05 -> Zn <= 0.07 (0.0027) | Kept: Zn <= 0.07 -> Cu <= -0.05 (0.0031)
# Removed: Cu <= -0.05 -> background2 <= -0.07 (0.0026) | Kept: background2 <= -0.07 -> Cu <= -0.05 (0.0069)
# Removed: Zn <= 0.02 -> Zn <= 0.07 (0.0090) | Kept: Zn <= 0.07 -> Zn <= 0.02 (0.0094)
# Removed: Fe <= -0.07 -> Zn <= 0.02 (0.0027) | Kept: Zn <= 0.02 -> Fe <= -0.07 (0.0058)
# Removed: Fe <= -0.01 -> Cu <= 0.01 (0.0026) | Kept: Cu <= 0.01 -> Fe <= -0.01 (0.0068)
# Removed: Cu <= 0.01 -> background2 <= -0.07 (0.0027) | Kept: background2 <= -0.07 -> Cu <= 0.01 (0.0034)
# Removed: Cu <= 0.01 -> Fe <= 0.09 (0.0024) | Kept: Fe <= 0.09 -> Cu <= 0.01 (0.0025)
# Removed: Rh kb Rayleigh <= -0.08 -> background2 <= 0.18 (0.0036) | Kept: background2 <= 0.18 -> Rh kb Rayleigh <= -0.08 (0.0037)
# Removed: background2 <= 0.18 -> background2 <= 0.06 (0.0101) | Kept: background2 <= 0.06 -> background2 <= 0.18 (0.0187)
# Removed: background2 <= 0.06 -> background2 <= -0.07 (0.0035) | Kept: background2 <= -0.07 -> background2 <= 0.06 (0.0038)
# Removed: Fe <= -0.07 -> background2 <= -0.07 (0.0026) | Kept: background2 <= -0.07 -> Fe <= -0.07 (0.0034)
# Removed: background2 <= -0.23 -> background2 <= -0.07 (0.0032) | Kept: background2 <= -0.07 -> background2 <= -0.23 (0.0033)
# Removed: Br ka > -0.15 -> background2 <= -0.07 (0.0026) | Kept: background2 <= -0.07 -> Br ka > -0.15 (0.0031)
# Removed: Br ka > -0.15 -> Fe <= 0.09 (0.0027) | Kept: Fe <= 0.09 -> Br ka > -0.15 (0.0046)
# Removed: Br ka <= -0.05 -> Fe <= -0.01 (0.0028) | Kept: Fe <= -0.01 -> Br ka <= -0.05 (0.0048)
# Removed: Fe <= 0.09 -> Fe <= -0.01 (0.0024) | Kept: Fe <= -0.01 -> Fe <= 0.09 (0.0096)
# Removed: Br ka <= 0.17 -> Fe <= 0.09 (0.0026) | Kept: Fe <= 0.09 -> Br ka <= 0.17 (0.0047)
# Removed: Br ka <= 0.17 -> Br ka <= 0.04 (0.0023) | Kept: Br ka <= 0.04 -> Br ka <= 0.17 (0.0052)
# Removed: Br ka > 0.04 -> Br ka <= 0.17 (0.0024) | Kept: Br ka <= 0.17 -> Br ka > 0.04 (0.0100)
# Removed: Br ka <= 0.04 -> Rh kb Rayleigh <= -0.02 (0.0024) | Kept: Rh kb Rayleigh <= -0.02 -> Br ka <= 0.04 (0.0027)
# Removed: Rh kb Rayleigh <= -0.02 -> Br ka > -0.05 (0.0025) | Kept: Br ka > -0.05 -> Rh kb Rayleigh <= -0.02 (0.0071)
# Removed: Br ka <= 0.04 -> Br ka > 0.04 (0.0025) | Kept: Br ka > 0.04 -> Br ka <= 0.04 (0.0050)
# Removed: Br ka > -0.05 -> Br ka <= 0.04 (0.0023) | Kept: Br ka <= 0.04 -> Br ka > -0.05 (0.0050)
# Removed: Br ka <= 0.04 -> Rh kb Rayleigh <= 0.06 (0.0022) | Kept: Rh kb Rayleigh <= 0.06 -> Br ka <= 0.04 (0.0022)
# Removed: Br ka > -0.05 -> Br ka > 0.04 (0.0046) | Kept: Br ka > 0.04 -> Br ka > -0.05 (0.0093)
# Removed: Rh kb Rayleigh <= 0.06 -> Rh kb Rayleigh <= 0.12 (0.0040) | Kept: Rh kb Rayleigh <= 0.12 -> Rh kb Rayleigh <= 0.06 (0.0173)
# Removed: Br ka <= -0.15 -> Rh kb Rayleigh <= 0.06 (0.0019) | Kept: Rh kb Rayleigh <= 0.06 -> Br ka <= -0.15 (0.0043)
# Removed: Rh kb Rayleigh > 0.06 -> Br ka <= -0.15 (0.0019) | Kept: Br ka <= -0.15 -> Rh kb Rayleigh > 0.06 (0.0072)
# Removed: Rh kb Rayleigh > -0.02 -> Rh kb Rayleigh > 0.12 (0.0017) | Kept: Rh kb Rayleigh > 0.12 -> Rh kb Rayleigh > -0.02 (0.0033)
# Removed: S > 0.01 -> Rh kb Rayleigh > -0.08 (0.0022) | Kept: Rh kb Rayleigh > -0.08 -> S > 0.01 (0.0076)
# Removed: Rh kb Rayleigh > 0.12 -> Rh kb Rayleigh > -0.08 (0.0016) | Kept: Rh kb Rayleigh > -0.08 -> Rh kb Rayleigh > 0.12 (0.0031)
# Removed: S > 0.01 -> S <= -0.07 (0.0011) | Kept: S <= -0.07 -> S > 0.01 (0.0032)
# Removed: S > -0.02 -> S <= -0.02 (0.0017) | Kept: S <= -0.02 -> S > -0.02 (0.0043)
# Removed: S <= -0.02 -> S > -0.07 (0.0015) | Kept: S > -0.07 -> S <= -0.02 (0.0023)
# Removed: S <= 0.01 -> S > -0.07 (0.0007) | Kept: S > -0.07 -> S <= 0.01 (0.0044)
# Removed: S <= 0.05 -> Mn > 0.02 (0.0007) | Kept: Mn > 0.02 -> S <= 0.05 (0.0014)
# Removed: Mn <= -0.02 -> Mn > -0.03 (0.0006) | Kept: Mn > -0.03 -> Mn <= -0.02 (0.0017)
# Removed: Mn > -0.02 -> Mn > -0.03 (0.0005) | Kept: Mn > -0.03 -> Mn > -0.02 (0.0010)
# Removed: Mn <= -0.02 -> Mn > -0.05 (0.0016) | Kept: Mn > -0.05 -> Mn <= -0.02 (0.0020)
# Removed: Mn <= -0.02 -> Mn > -0.02 (0.0005) | Kept: Mn > -0.02 -> Mn <= -0.02 (0.0010)
# Removed: Mn > -0.02 -> Mn > -0.05 (0.0010) | Kept: Mn > -0.05 -> Mn > -0.02 (0.0016)
# Removed: Mn > -0.02 -> Mn <= 0.02 (0.0010) | Kept: Mn <= 0.02 -> Mn > -0.02 (0.0015)
# Removed: S <= -0.07 -> Rh kb Rayleigh > 0.12 (0.0011) | Kept: Rh kb Rayleigh > 0.12 -> S <= -0.07 (0.0016)
#
# ======================================================================
# CONSTRUCTED GRAPH SUMMARY
# ======================================================================
# Initial edges: 712 | Removed: 147
# Predicate nodes: 131
# Metric: Perturbation
# Weighting by explained variance: ENABLED
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#
# Processing graph LRC...
#       Predicate_pert_Seed_0  Predicate_pert_Seed_1   Predicate_pert_Seed_2  \
# 0     Rb ka + Br kb > -0.02  Rb ka + Br kb > -0.02           K ka <= -0.48
# 1    Rh ka Compton <= -0.39  Rb ka + Br kb > -0.12   Rb ka + Br kb > -0.02
# 2             K ka <= -0.48  Rb ka + Br kb > -0.28             K ka > 0.20
# 3     Rb ka + Br kb > -0.12   Rh ka Compton > 0.45    Rh ka Compton > 0.14
# 4      Rh ka Compton > 0.45          K ka <= -0.48  Rh ka Compton <= -0.39
# ..                      ...                    ...                     ...
# 128              Mn <= 0.02             Mn > -0.02             Mn <= -0.03
# 129              Mn > -0.02             Mn <= 0.02                 Class_A
# 130             Mn <= -0.03            Mn <= -0.03                 Class_B
# 131                 Class_A                Class_A                     NaN
# 132                 Class_B                Class_B                     NaN
#
#       Predicate_pert_Seed_3
# 0     Rb ka + Br kb > -0.02
# 1    Rh ka Compton <= -0.39
# 2     Rb ka + Br kb > -0.12
# 3             K ka <= -0.48
# 4             K ka <= -0.16
# ..                      ...
# 128              Mn <= 0.02
# 129              Mn > -0.02
# 130             Mn <= -0.03
# 131                 Class_A
# 132                 Class_B
#
# [133 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#                  Predicate  Perturbation
# 0    Rb ka + Br kb > -0.02      0.156021
# 1            K ka <= -0.48      0.104479
# 2    Rb ka + Br kb > -0.12      0.101974
# 3    Rb ka + Br kb > -0.28      0.086479
# 4            K ka <= -0.16      0.078341
# ..                     ...           ...
# 105            Mn <= -0.02      0.000909
# 106             Mn > -0.05      0.000903
# 107             Mn > -0.02      0.000859
# 108             Mn <= 0.02      0.000798
# 109            Mn <= -0.03      0.000718
#
# [110 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                        Node  Local_Reaching_Centrality            Zone  \
# 0     Rb ka + Br kb > -0.02                   4.903362   Rb ka + Br kb
# 1             K ka <= -0.48                   3.878167            K ka
# 2    Rh ka Compton <= -0.39                   3.863308   Rh ka Compton
# 3     K kb + Ca ka <= -0.14                   1.745503    K kb + Ca ka
# 4               Cl <= -0.20                   1.472292              Cl
# 5    Rh kb Compton <= -0.20                   1.423690   Rh kb Compton
# 6   Rh ka Rayleigh <= -0.15                   1.115642  Rh ka Rayleigh
# 7        background3 > 0.19                   1.096380     background3
# 8                 Fe > 0.09                   0.752956              Fe
# 9                 Cu > 0.11                   0.224926              Cu
# 10                Zn > 0.07                   0.144809              Zn
# 11   Rh kb Rayleigh <= 0.12                   0.134095  Rh kb Rayleigh
# 12      background2 > -0.23                   0.132896     background2
# 13       background1 > 0.06                   0.126401     background1
# 14             Br ka > 0.04                   0.126296           Br ka
# 15                 S > 0.05                   0.087797               S
# 16               Mn > -0.03                   0.004673              Mn
# 17                  Class_A                   0.000000            None
#
#    Threshold Operator
# 0      -0.02        >
# 1      -0.48       <=
# 2      -0.39       <=
# 3      -0.14       <=
# 4      -0.20       <=
# 5      -0.20       <=
# 6      -0.15       <=
# 7       0.19        >
# 8       0.09        >
# 9       0.11        >
# 10      0.07        >
# 11      0.12       <=
# 12     -0.23        >
# 13      0.06        >
# 14      0.04        >
# 15      0.05        >
# 16     -0.03        >
# 17      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                        Node  Local_Reaching_Centrality           Zone  \
# 0     Rb ka + Br kb > -0.02                   4.903362  Rb ka + Br kb
# 1             K ka <= -0.48                   3.878167           K ka
# 2    Rh ka Compton <= -0.39                   3.863308  Rh ka Compton
# 3     Rb ka + Br kb > -0.12                   3.597328  Rb ka + Br kb
# 4      Rh ka Compton > 0.45                   3.165872  Rh ka Compton
# ..                      ...                        ...            ...
# 131              Mn <= 0.02                   0.002601             Mn
# 132              Mn > -0.02                   0.002551             Mn
# 133             Mn <= -0.03                   0.000911             Mn
# 134                 Class_A                   0.000000           None
# 135                 Class_B                   0.000000           None
#
#     Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0       -0.02        >          -0.003744                    27.0
# 1       -0.48       <=          -0.553004                    18.0
# 2       -0.39       <=          -0.345973                    25.0
# 3       -0.12        >          -0.062361                     9.0
# 4        0.45        >           0.421114                     2.0
# ..        ...      ...                ...                     ...
# 131      0.02       <=           0.003812                     0.0
# 132     -0.02        >          -0.003958                    18.0
# 133     -0.03       <=          -0.005294                     5.0
# 134      None     None                NaN                     NaN
# 135      None     None                NaN                     NaN
#
#      Approximation_Error                Node_Natural
# 0               0.000729   Rb ka + Br kb > -0.003744
# 1               0.004092           K ka <= -0.553004
# 2               0.002620  Rh ka Compton <= -0.345973
# 3               0.002081   Rb ka + Br kb > -0.062361
# 4               0.002152    Rh ka Compton > 0.421114
# ..                   ...                         ...
# 131             0.000531              Mn <= 0.003812
# 132             0.000109              Mn > -0.003958
# 133             0.000226             Mn <= -0.005294
# 134                  NaN                        None
# 135                  NaN                        None
#
# [136 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Rb ka + Br kb':
#   - Dimensão: 66 variáveis espectrais
#   - Variância explicada pela PC1: 79.32%

# %%
# Permutation importance baseado em mudança nas predições do modelo PLS
# Medimos a média da diferença absoluta entre as predições originais e as predições
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Predições base do modelo PLS
baseline_pred = pls_model.predict(Xcalclass_prep)
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_pred = pls_model.predict(X_perm)
        diffs.append(np.mean(np.abs(baseline_pred - perm_pred)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance': importance_list
})
permutation_df.sort_values(by='Permutation_importance', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance            Zone
# 0   13.34                0.015082   Rb ka + Br kb
# 1    3.24                0.010099            K ka
# 2    3.68                0.009469    K kb + Ca ka
# 3    2.58                0.006944              Cl
# 4   19.32                0.004321   Rh ka Compton
# 5      16                0.002150     background3
# 6   21.34                0.002100   Rh kb Compton
# 7    20.1                0.002022  Rh ka Rayleigh
# 8       4                0.001969     background1
# 9   11.88                0.001910           Br ka
# 10    6.4                0.001795              Fe
# 11   8.06                0.001736              Cu
# 12   8.62                0.001725              Zn
# 13  22.36                0.001359  Rh kb Rayleigh
# 14  10.24                0.001357     background2
# 15   5.96                0.001000              Mn
# 16   2.24                0.000721               S

# %%
import numpy as np

max_len = max(
    len(vip_scores_unique_df['Zone']),
    len(reg_vet_unique_df['Zone']),
    #len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'VIP_Score': pad_list(vip_scores_unique_df['Zone'], max_len),
    'Reg_Coefficient' : pad_list(reg_vet_unique_df['Zone'], max_len),
    #'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#          VIP_Score Reg_Coefficient     Permutation LRC_perturbation  \
# 0    Rb ka + Br kb   Rb ka + Br kb   Rb ka + Br kb    Rb ka + Br kb
# 1     K kb + Ca ka    K kb + Ca ka            K ka             K ka
# 2             K ka              Cl    K kb + Ca ka    Rh ka Compton
# 3    Rh ka Compton     background1              Cl     K kb + Ca ka
# 4               Cl     background3   Rh ka Compton               Cl
# 5      background1            K ka     background3    Rh kb Compton
# 6               Cu              Zn   Rh kb Compton   Rh ka Rayleigh
# 7      background3              Cu  Rh ka Rayleigh      background3
# 8      background2   Rh ka Compton     background1               Fe
# 9               Zn  Rh kb Rayleigh           Br ka               Cu
# 10           Br ka   Rh kb Compton              Fe               Zn
# 11              Fe     background2              Cu   Rh kb Rayleigh
# 12  Rh kb Rayleigh           Br ka              Zn      background2
# 13   Rh kb Compton              Fe  Rh kb Rayleigh      background1
# 14  Rh ka Rayleigh  Rh ka Rayleigh     background2            Br ka
# 15              Mn              Mn              Mn                S
# 16               S               S               S               Mn
# 17            None            None            None             None
#
#     LRC_covariance
# 0    Rb ka + Br kb
# 1    Rh ka Compton
# 2             K ka
# 3               Cu
# 4   Rh ka Rayleigh
# 5      background3
# 6    Rh kb Compton
# 7            Br ka
# 8               Cl
# 9   Rh kb Rayleigh
# 10    K kb + Ca ka
# 11     background2
# 12              Fe
# 13            None
# 14            None
# 15            None
# 16            None
# 17            None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_15524\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 7       Permutation  LRC_perturbation   0.879239
# 0         VIP_Score   Reg_Coefficient   0.817782
# 1         VIP_Score       Permutation   0.808888
# 2         VIP_Score  LRC_perturbation   0.783692
# 9  LRC_perturbation    LRC_covariance   0.764480
# 4   Reg_Coefficient       Permutation   0.727988
# 3         VIP_Score    LRC_covariance   0.703007
# 8       Permutation    LRC_covariance   0.698158
# 5   Reg_Coefficient  LRC_perturbation   0.637896
# 6   Reg_Coefficient    LRC_covariance   0.566825

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
