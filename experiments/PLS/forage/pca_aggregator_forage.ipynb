# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/forage/plsda/forage.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '1.4':'20.81']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '1.4':'20.81'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '1.4':'20.81'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-10 07:04:43,463 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-10 07:04:43,472 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-10 07:04:43,496 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-02-10 07:04:43,526 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import pls_optimized

plsda_results = pls_optimized(
    Xcalclass_prep, 
    ycalclass,
    LVmax=3,
    Xpred=Xpredclass_prep,
    ypred=ypredclass,
    aim='classification',
    cv=10
)

# Convenience references used later
pls_model = plsda_results[3]               # fitted PLS model
vip_scores_mat = plsda_results[4]          # VIP scores matrix (features × LV)
y_pred_cont = plsda_results[5].iloc[:, -1] # continuous predictions for Xcalclass (used for MI/Cov)

# plotando o vip scores rapidamente
vip_scores_mat.T.plot()

# %% [markdown]
# ## Definição das Zonas Espectrais

# %%
spectral_cuts = [
('Al', 1.40, 1.63),
('Si', 1.63, 1.86),
('P', 1.86, 2.16),
('S', 2.16, 2.44),
('Rh L + Ar', 2.44, 3.10),
('K', 3.10, 3.46),
('Ca ka', 3.46, 3.86),
('Ca kb', 3.86, 4.37),
('Ti ka', 4.37, 4.66),
('Ti kb', 4.66, 5.08),
('background1', 5.08, 5.72),
('Mn', 5.72, 6.10),
('Fe ka', 6.10, 6.76),
('Fe kb', 6.76, 7.20),
('Ni', 7.20, 7.69),
('Cu', 7.69, 8.45),
('Zn', 8.45, 8.81),
('background2', 8.81, 13.10),
('sum Fe' , 13.10, 13.63),
('background3', 13.63, 18.0),
('Compton scattering', 18.0, 19.70),
('Rayleight scattering', 19.70, 20.81)
]

# %% [markdown]
# ## VIP, Regression Coefficients e SHAP (como no original)

# %%
# VIP scores por energia
vip_scores_df = pd.DataFrame({
    'energy': vip_scores_mat.T.index,
    'VIP_Score': vip_scores_mat.T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in vip_scores_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip)
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# Coeficientes de regressão do PLS
reg_vet = pd.DataFrame(pls_model.coef_, columns=pls_model.feature_names_in_).T
reg_vet.insert(0, 'energy', reg_vet.index)
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy','Reg_coef']
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs()
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
energy_to_zone_reg = {}
for zone_name, start, end in spectral_cuts:
    for e in reg_vet['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_reg[e] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg)
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)

# %%
shap_global_importance = pd.read_csv('shap_forage.csv', sep=';') # loading previously saved shap_unique_df

# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df = shap_unique_df.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
shap_unique_df
# Out:
#     energy  Mean_Abs_SHAP                  Zone
# 0     1.74       0.047022                    Si
# 1     3.70       0.041039                 Ca ka
# 2     2.62       0.001321             Rh L + Ar
# 3     3.28       0.001253                     K
# 4     4.04       0.000292                 Ca kb
# 5     6.44       0.000022                 Fe ka
# 6     5.08       0.000000           background1
# 7     7.69       0.000000                    Cu
# 8     7.36       0.000000                    Ni
# 9     6.76       0.000000                 Fe kb
# 10    2.14       0.000000                     P
# 11    5.72       0.000000                    Mn
# 12    4.42       0.000000                 Ti ka
# 13    2.24       0.000000                     S
# 14    5.00       0.000000                 Ti kb
# 15    1.60       0.000000                    Al
# 16   20.25       0.000000  Rayleight scattering
# 17   19.07       0.000000    Compton scattering
# 18   13.47       0.000000                sum Fe
# 19   12.09       0.000000           background2
# 20   14.49       0.000000           background3
# 21    8.55       0.000000                    Zn

# %% [markdown]
# ## Funções de Agregação por PCA
#
# Aqui implementamos as funções para agregar zonas espectrais usando PCA com 1 componente principal.

# %%
import explaining as exp

# Extração das zonas espectrais
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_scores_df, pca_info_dict = exp.aggregate_spectral_zones_pca(spectral_zones_class) # apca aggregation
print(f"\nScores DataFrame shape: {zone_scores_df.shape}")
# Out:
# Zona 'Al': VE = 92.81%, dim = 12 variáveis
# Zona 'Si': VE = 99.42%, dim = 12 variáveis
# Zona 'P': VE = 94.16%, dim = 16 variáveis
# Zona 'S': VE = 89.31%, dim = 15 variáveis
# Zona 'Rh L + Ar': VE = 95.85%, dim = 34 variáveis
# Zona 'K': VE = 98.44%, dim = 19 variáveis
# Zona 'Ca ka': VE = 89.46%, dim = 21 variáveis
# Zona 'Ca kb': VE = 96.25%, dim = 26 variáveis
# Zona 'Ti ka': VE = 98.15%, dim = 15 variáveis
# Zona 'Ti kb': VE = 76.25%, dim = 22 variáveis
# Zona 'background1': VE = 66.63%, dim = 33 variáveis
# Zona 'Mn': VE = 94.16%, dim = 20 variáveis
# Zona 'Fe ka': VE = 99.38%, dim = 34 variáveis
# Zona 'Fe kb': VE = 94.04%, dim = 23 variáveis
# Zona 'Ni': VE = 77.76%, dim = 25 variáveis
# Zona 'Cu': VE = 84.25%, dim = 39 variáveis
# Zona 'Zn': VE = 82.20%, dim = 19 variáveis
# Zona 'background2': VE = 86.56%, dim = 215 variáveis
# Zona 'sum Fe': VE = 88.47%, dim = 27 variáveis
# Zona 'background3': VE = 87.92%, dim = 219 variáveis
# Zona 'Compton scattering': VE = 88.73%, dim = 85 variáveis
# Zona 'Rayleight scattering': VE = 84.40%, dim = 56 variáveis
#
# Scores DataFrame shape: (135, 22)

# %%
predicates_quantiles = exp.predicates_by_quantiles(zone_scores_df, [0.2, 0.4, 0.6, 0.8])
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_scores_df,
    y_predicted_numeric=y_pred_cont
)

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_pred_conticted_numeric = pd.Series(y_pred_cont) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred_conticted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graphv3_pca(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 134 | Descartados: 42
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 109
# Removida: Fe ka > -2.26 -> Fe ka > -3.74 (7.6013) | Mantida: Fe ka > -3.74 -> Fe ka > -2.26 (17.2010)
# Removida: Si > -2.51 -> Ca ka <= 3.95 (3.6906) | Mantida: Ca ka <= 3.95 -> Si > -2.51 (4.6227)
# Removida: Si > -2.51 -> K <= 6.26 (1.1843) | Mantida: K <= 6.26 -> Si > -2.51 (1.2409)
# Removida: Si > -1.67 -> Si > -2.51 (3.6752) | Mantida: Si > -2.51 -> Si > -1.67 (6.2927)
# Removida: Ca ka <= 3.95 -> Si > -1.67 (1.1032) | Mantida: Si > -1.67 -> Ca ka <= 3.95 (2.4698)
# Removida: Ca ka <= 3.95 -> K > -6.69 (1.1466) | Mantida: K > -6.69 -> Ca ka <= 3.95 (4.0051)
# Removida: K > -6.69 -> Si > -1.67 (2.4717) | Mantida: Si > -1.67 -> K > -6.69 (2.4912)
# Removida: K <= 6.26 -> K > -6.69 (1.1310) | Mantida: K > -6.69 -> K <= 6.26 (2.4148)
# Removida: K <= 6.26 -> K > -1.46 (1.9964) | Mantida: K > -1.46 -> K <= 6.26 (2.0269)
# Removida: Ca ka <= 1.77 -> K <= 6.26 (0.8970) | Mantida: K <= 6.26 -> Ca ka <= 1.77 (4.1190)
# Removida: Ca ka <= 1.77 -> K > -1.46 (0.9096) | Mantida: K > -1.46 -> Ca ka <= 1.77 (0.9566)
# Removida: K > -1.46 -> Si > -0.72 (1.7799) | Mantida: Si > -0.72 -> K > -1.46 (2.5521)
# Removida: K > -1.46 -> Ca ka > -4.65 (0.9097) | Mantida: Ca ka > -4.65 -> K > -1.46 (1.6513)
# Removida: Ca ka > -4.65 -> Ca ka <= 1.77 (0.8220) | Mantida: Ca ka <= 1.77 -> Ca ka > -4.65 (5.2115)
# Removida: Si > -0.72 -> Ca ka > -4.65 (0.8655) | Mantida: Ca ka > -4.65 -> Si > -0.72 (4.0692)
# Removida: Ti ka > -0.70 -> Si > -0.72 (0.6908) | Mantida: Si > -0.72 -> Ti ka > -0.70 (3.8783)
# Removida: Ca ka <= -1.50 -> Ca kb <= 1.57 (0.4529) | Mantida: Ca kb <= 1.57 -> Ca ka <= -1.50 (1.4452)
# Removida: Ca kb <= 1.57 -> Si <= 3.71 (0.9964) | Mantida: Si <= 3.71 -> Ca kb <= 1.57 (1.0203)
# Removida: Fe kb > -0.63 -> Ti ka > -0.86 (1.1562) | Mantida: Ti ka > -0.86 -> Fe kb > -0.63 (1.6052)
# Removida: Fe kb > -0.63 -> Rh L + Ar > -0.16 (0.4701) | Mantida: Rh L + Ar > -0.16 -> Fe kb > -0.63 (0.6454)
# Removida: Fe kb > -0.44 -> Fe kb > -0.63 (0.4514) | Mantida: Fe kb > -0.63 -> Fe kb > -0.44 (1.6950)
# Removida: K <= 2.15 -> Rh L + Ar > -0.16 (0.4273) | Mantida: Rh L + Ar > -0.16 -> K <= 2.15 (1.0133)
# Removida: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (0.4159) | Mantida: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (0.8891)
# Removida: Si <= 3.71 -> Rh L + Ar > -0.16 (0.3388) | Mantida: Rh L + Ar > -0.16 -> Si <= 3.71 (0.5113)
# Removida: K <= 2.15 -> Rh L + Ar > -0.77 (0.9868) | Mantida: Rh L + Ar > -0.77 -> K <= 2.15 (1.0074)
# Removida: background3 > 0.14 -> K <= 2.15 (0.3145) | Mantida: K <= 2.15 -> background3 > 0.14 (0.4235)
# Removida: Ti ka > -0.52 -> Fe kb > -0.91 (0.4654) | Mantida: Fe kb > -0.91 -> Ti ka > -0.52 (1.0866)
# Removida: Ti ka > -0.52 -> Fe kb > -0.44 (1.0349) | Mantida: Fe kb > -0.44 -> Ti ka > -0.52 (1.0983)
# Removida: Ca ka <= -1.50 -> Rh L + Ar > -0.77 (0.4169) | Mantida: Rh L + Ar > -0.77 -> Ca ka <= -1.50 (0.4606)
# Removida: Rh L + Ar > -1.66 -> Ca ka <= -1.50 (0.4469) | Mantida: Ca ka <= -1.50 -> Rh L + Ar > -1.66 (0.8358)
# Removida: Ca ka <= -1.50 -> Si <= 3.71 (0.4379) | Mantida: Si <= 3.71 -> Ca ka <= -1.50 (0.4773)
# Removida: Si <= 3.71 -> Rh L + Ar > -0.77 (0.4450) | Mantida: Rh L + Ar > -0.77 -> Si <= 3.71 (0.8765)
# Removida: background3 > 0.14 -> Ca kb > -1.81 (0.3400) | Mantida: Ca kb > -1.81 -> background3 > 0.14 (0.7282)
# Removida: background3 > 0.14 -> Ca kb <= 0.62 (0.3575) | Mantida: Ca kb <= 0.62 -> background3 > 0.14 (0.8020)
# Removida: Ca ka > -1.50 -> background3 > 0.14 (0.3158) | Mantida: background3 > 0.14 -> Ca ka > -1.50 (0.6457)
# Removida: background3 > 0.14 -> Rh L + Ar > -1.66 (0.3364) | Mantida: Rh L + Ar > -1.66 -> background3 > 0.14 (0.6766)
# Removida: Ca ka > -1.50 -> Si <= 3.71 (0.3514) | Mantida: Si <= 3.71 -> Ca ka > -1.50 (0.4122)
# Removida: Ca ka > -1.50 -> background3 > -0.62 (0.3301) | Mantida: background3 > -0.62 -> Ca ka > -1.50 (0.5905)
# Removida: background3 > -0.62 -> K <= -1.46 (0.2131) | Mantida: K <= -1.46 -> background3 > -0.62 (0.6300)
# Removida: background3 > -1.28 -> K <= -1.46 (0.2622) | Mantida: K <= -1.46 -> background3 > -1.28 (0.2725)
# Removida: background3 > -0.62 -> Ca ka > 1.77 (0.2251) | Mantida: Ca ka > 1.77 -> background3 > -0.62 (0.2331)
# Removida: K > 2.15 -> Ca ka > 1.77 (0.2380) | Mantida: Ca ka > 1.77 -> K > 2.15 (0.2407)
# Removida: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.1992) | Mantida: Compton scattering > -0.40 -> Compton scattering > 0.05 (0.9278)
# Removida: background3 > -1.28 -> Compton scattering > -0.40 (0.2503) | Mantida: Compton scattering > -0.40 -> background3 > -1.28 (0.5180)
# Removida: Ca ka > 1.77 -> Compton scattering > -0.40 (0.2133) | Mantida: Compton scattering > -0.40 -> Ca ka > 1.77 (0.2356)
# Removida: Ca ka > 1.77 -> Compton scattering > 0.05 (0.2151) | Mantida: Compton scattering > 0.05 -> Ca ka > 1.77 (0.6859)
# Removida: sum Fe > -0.28 -> Ca ka > 1.77 (0.1512) | Mantida: Ca ka > 1.77 -> sum Fe > -0.28 (0.1604)
# Removida: Fe ka <= 1.10 -> background3 > -1.28 (0.2144) | Mantida: background3 > -1.28 -> Fe ka <= 1.10 (0.2171)
# Removida: background3 > -1.28 -> Ca kb <= -0.59 (0.2107) | Mantida: Ca kb <= -0.59 -> background3 > -1.28 (0.3685)
# Removida: Ca kb <= -0.59 -> Fe ka <= 1.10 (0.2042) | Mantida: Fe ka <= 1.10 -> Ca kb <= -0.59 (0.2300)
# Removida: Compton scattering > -0.88 -> Fe ka <= 1.10 (0.1987) | Mantida: Fe ka <= 1.10 -> Compton scattering > -0.88 (0.3953)
# Removida: Ca kb <= -0.59 -> Compton scattering > -0.88 (0.2068) | Mantida: Compton scattering > -0.88 -> Ca kb <= -0.59 (0.3877)
# Removida: sum Fe > -0.28 -> Compton scattering > -0.88 (0.1008) | Mantida: Compton scattering > -0.88 -> sum Fe > -0.28 (0.1529)
# Removida: Rayleight scattering > -0.25 -> Al > -0.68 (0.1209) | Mantida: Al > -0.68 -> Rayleight scattering > -0.25 (0.1365)
# Removida: Rayleight scattering > -0.25 -> sum Fe > -0.28 (0.1476) | Mantida: sum Fe > -0.28 -> Rayleight scattering > -0.25 (0.1516)
# Removida: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.1648) | Mantida: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.4135)
# Removida: Rayleight scattering > 0.03 -> Al > -0.68 (0.1413) | Mantida: Al > -0.68 -> Rayleight scattering > 0.03 (0.4124)
# Removida: sum Fe > -0.28 -> sum Fe > 0.07 (0.1567) | Mantida: sum Fe > 0.07 -> sum Fe > -0.28 (0.3351)
# Removida: sum Fe > -0.60 -> sum Fe > 0.07 (0.1263) | Mantida: sum Fe > 0.07 -> sum Fe > -0.60 (0.2227)
# Removida: sum Fe > 0.07 -> Rayleight scattering > -0.50 (0.1258) | Mantida: Rayleight scattering > -0.50 -> sum Fe > 0.07 (0.1280)
# Removida: Al > -0.19 -> Ca kb > -0.59 (0.1194) | Mantida: Ca kb > -0.59 -> Al > -0.19 (0.2531)
# Removida: Ca kb > -0.59 -> Ti kb > -0.32 (0.1272) | Mantida: Ti kb > -0.32 -> Ca kb > -0.59 (0.1955)
# Removida: Al > -0.68 -> P > -1.23 (0.1399) | Mantida: P > -1.23 -> Al > -0.68 (0.2849)
# Removida: Rayleight scattering > -0.50 -> P > 0.08 (0.1169) | Mantida: P > 0.08 -> Rayleight scattering > -0.50 (0.1406)
# Removida: Al > -0.19 -> background2 > 0.35 (0.0978) | Mantida: background2 > 0.35 -> Al > -0.19 (0.1218)
# Removida: Ti kb > -0.32 -> Al > -0.19 (0.0930) | Mantida: Al > -0.19 -> Ti kb > -0.32 (0.1225)
# Removida: Ti kb > -0.14 -> P > -0.59 (0.0763) | Mantida: P > -0.59 -> Ti kb > -0.14 (0.1177)
# Removida: background2 > -0.51 -> background2 > -1.35 (0.0360) | Mantida: background2 > -1.35 -> background2 > -0.51 (0.1051)
# Removida: background2 > 0.35 -> Al <= 0.62 (0.1019) | Mantida: Al <= 0.62 -> background2 > 0.35 (0.1108)
# Removida: Ti kb > -0.14 -> Al <= 0.62 (0.0880) | Mantida: Al <= 0.62 -> Ti kb > -0.14 (0.2940)
# Removida: background2 <= -0.51 -> Ti kb > 0.03 (0.1031) | Mantida: Ti kb > 0.03 -> background2 <= -0.51 (0.1633)
# Removida: Ti kb > -0.14 -> Mn > 0.23 (0.0658) | Mantida: Mn > 0.23 -> Ti kb > -0.14 (0.1018)
# Removida: Ti kb > 0.03 -> Ti kb > -0.14 (0.1549) | Mantida: Ti kb > -0.14 -> Ti kb > 0.03 (0.2512)
# Removida: Ti ka <= 0.53 -> Ni > -0.14 (0.0378) | Mantida: Ni > -0.14 -> Ti ka <= 0.53 (0.0402)
# Removida: S <= -0.27 -> Ti ka <= 0.53 (0.0355) | Mantida: Ti ka <= 0.53 -> S <= -0.27 (0.1055)
# Removida: Mn <= 1.01 -> S <= 0.55 (0.0549) | Mantida: S <= 0.55 -> Mn <= 1.01 (0.0603)
# Removida: S <= 0.55 -> P <= -0.59 (0.0700) | Mantida: P <= -0.59 -> S <= 0.55 (0.0719)
# Removida: Compton scattering <= -0.40 -> Ni <= 0.13 (0.0708) | Mantida: Ni <= 0.13 -> Compton scattering <= -0.40 (0.1009)
# Removida: background2 <= 0.35 -> P <= 0.08 (0.0292) | Mantida: P <= 0.08 -> background2 <= 0.35 (0.0467)
# Removida: P <= 0.08 -> background3 <= 0.14 (0.0494) | Mantida: background3 <= 0.14 -> P <= 0.08 (0.0584)
# Removida: Ni <= 0.13 -> S <= 0.55 (0.0565) | Mantida: S <= 0.55 -> Ni <= 0.13 (0.1017)
# Removida: S <= 0.55 -> Mn > -1.22 (0.0407) | Mantida: Mn > -1.22 -> S <= 0.55 (0.0457)
# Removida: Cu <= -0.12 -> Ni <= 0.13 (0.0304) | Mantida: Ni <= 0.13 -> Cu <= -0.12 (0.0533)
# Removida: sum Fe <= -0.28 -> Fe kb <= 0.33 (0.0372) | Mantida: Fe kb <= 0.33 -> sum Fe <= -0.28 (0.0469)
# Removida: Ni <= 0.59 -> Fe kb <= 0.33 (0.0732) | Mantida: Fe kb <= 0.33 -> Ni <= 0.59 (0.0814)
# Removida: Cu <= -0.12 -> Fe kb <= 0.33 (0.0195) | Mantida: Fe kb <= 0.33 -> Cu <= -0.12 (0.0341)
# Removida: sum Fe <= -0.28 -> background3 <= 0.14 (0.0261) | Mantida: background3 <= 0.14 -> sum Fe <= -0.28 (0.0484)
# Removida: S <= 0.09 -> S <= -0.27 (0.0477) | Mantida: S <= -0.27 -> S <= 0.09 (0.0707)
# Removida: S <= 0.09 -> Cu <= 0.09 (0.0464) | Mantida: Cu <= 0.09 -> S <= 0.09 (0.0722)
# Removida: Al <= 0.19 -> Al <= -0.19 (0.0193) | Mantida: Al <= -0.19 -> Al <= 0.19 (0.0626)
# Removida: background1 <= -0.08 -> P <= 1.06 (0.0167) | Mantida: P <= 1.06 -> background1 <= -0.08 (0.0480)
# Removida: Ti kb <= 0.20 -> Al <= 0.19 (0.0187) | Mantida: Al <= 0.19 -> Ti kb <= 0.20 (0.0869)
# Removida: background2 <= 0.35 -> Mn > -0.41 (0.0274) | Mantida: Mn > -0.41 -> background2 <= 0.35 (0.0656)
# Removida: background1 <= 0.30 -> background1 <= -0.08 (0.0189) | Mantida: background1 <= -0.08 -> background1 <= 0.30 (0.0404)
# Removida: background1 <= 0.30 -> Rh L + Ar <= -0.77 (0.0238) | Mantida: Rh L + Ar <= -0.77 -> background1 <= 0.30 (0.0299)
# Removida: background3 <= 1.47 -> Cu > -0.12 (0.0133) | Mantida: Cu > -0.12 -> background3 <= 1.47 (0.0172)
# Removida: Ni > 0.13 -> background3 <= 1.47 (0.0122) | Mantida: background3 <= 1.47 -> Ni > 0.13 (0.0179)
# Removida: Ni <= -0.14 -> Ni <= 0.59 (0.0121) | Mantida: Ni <= 0.59 -> Ni <= -0.14 (0.0210)
# Removida: Zn <= 0.10 -> Ni <= -0.14 (0.0129) | Mantida: Ni <= -0.14 -> Zn <= 0.10 (0.0455)
# Removida: Zn <= 0.34 -> Ni <= -0.14 (0.0275) | Mantida: Ni <= -0.14 -> Zn <= 0.34 (0.0288)
# Removida: background1 <= 0.11 -> Mn <= -0.41 (0.0129) | Mantida: Mn <= -0.41 -> background1 <= 0.11 (0.0224)
# Removida: background1 <= 0.11 -> Zn <= -0.11 (0.0153) | Mantida: Zn <= -0.11 -> background1 <= 0.11 (0.0230)
# Removida: Fe ka <= -2.26 -> background1 <= 0.11 (0.0196) | Mantida: background1 <= 0.11 -> Fe ka <= -2.26 (0.0341)
# Removida: Cu > -0.12 -> Fe ka <= -3.05 (0.0095) | Mantida: Fe ka <= -3.05 -> Cu > -0.12 (0.0109)
# Removida: Cu > -0.12 -> sum Fe <= 0.07 (0.0115) | Mantida: sum Fe <= 0.07 -> Cu > -0.12 (0.0126)
# Removida: Compton scattering <= 0.87 -> background3 <= 0.14 (0.0136) | Mantida: background3 <= 0.14 -> Compton scattering <= 0.87 (0.0157)
# Removida: Cu <= 0.56 -> Mn <= 0.23 (0.0131) | Mantida: Mn <= 0.23 -> Cu <= 0.56 (0.0553)
# Removida: Cu <= 0.56 -> Zn > 0.10 (0.0141) | Mantida: Zn > 0.10 -> Cu <= 0.56 (0.0155)
# Removida: Zn > -0.11 -> sum Fe <= 0.07 (0.0144) | Mantida: sum Fe <= 0.07 -> Zn > -0.11 (0.0299)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 862 | Removidas: 109
# Nós predicados: 128
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 135
# Removida: Fe ka > -2.26 -> Fe ka > -3.74 (5.2898) | Mantida: Fe ka > -3.74 -> Fe ka > -2.26 (19.6002)
# Removida: Ca ka <= 3.95 -> Si > -1.67 (1.0933) | Mantida: Si > -1.67 -> Ca ka <= 3.95 (2.4012)
# Removida: Ca ka <= 3.95 -> K > -6.69 (1.1506) | Mantida: K > -6.69 -> Ca ka <= 3.95 (3.9490)
# Removida: Si > -1.67 -> Si > -2.51 (1.1761) | Mantida: Si > -2.51 -> Si > -1.67 (8.6342)
# Removida: Si > -1.67 -> K <= 6.26 (1.1549) | Mantida: K <= 6.26 -> Si > -1.67 (1.1580)
# Removida: Si > -2.51 -> K > -6.69 (2.3176) | Mantida: K > -6.69 -> Si > -2.51 (2.4964)
# Removida: Ca ka <= 1.77 -> K <= 6.26 (0.9012) | Mantida: K <= 6.26 -> Ca ka <= 1.77 (4.0078)
# Removida: K <= 6.26 -> K > -1.46 (1.8674) | Mantida: K > -1.46 -> K <= 6.26 (1.9024)
# Removida: Ca ka > -4.65 -> K <= 6.26 (0.7390) | Mantida: K <= 6.26 -> Ca ka > -4.65 (0.9225)
# Removida: K > -1.46 -> Ca ka <= 1.77 (0.9452) | Mantida: Ca ka <= 1.77 -> K > -1.46 (4.2662)
# Removida: Ca ka > -4.65 -> Ca ka <= 1.77 (0.8242) | Mantida: Ca ka <= 1.77 -> Ca ka > -4.65 (2.6084)
# Removida: Ca ka > -4.65 -> K > -1.46 (0.8132) | Mantida: K > -1.46 -> Ca ka > -4.65 (2.5640)
# Removida: Si > -0.72 -> K > -1.46 (1.6527) | Mantida: K > -1.46 -> Si > -0.72 (2.5169)
# Removida: Si > -0.72 -> Ca ka > -4.65 (1.7136) | Mantida: Ca ka > -4.65 -> Si > -0.72 (3.1293)
# Removida: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (0.7756) | Mantida: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (1.9427)
# Removida: Ca kb <= 1.57 -> Rh L + Ar > -0.16 (0.5089) | Mantida: Rh L + Ar > -0.16 -> Ca kb <= 1.57 (0.5147)
# Removida: Rh L + Ar > -0.16 -> Ca kb > -1.81 (0.3196) | Mantida: Ca kb > -1.81 -> Rh L + Ar > -0.16 (0.3469)
# Removida: Fe kb > -0.44 -> Rh L + Ar > -0.16 (0.5084) | Mantida: Rh L + Ar > -0.16 -> Fe kb > -0.44 (0.5780)
# Removida: Ca ka <= -1.50 -> Rh L + Ar > -0.16 (0.4709) | Mantida: Rh L + Ar > -0.16 -> Ca ka <= -1.50 (0.4824)
# Removida: Ca kb <= 0.62 -> Rh L + Ar > -0.77 (0.3868) | Mantida: Rh L + Ar > -0.77 -> Ca kb <= 0.62 (0.4393)
# Removida: background3 > 0.14 -> Rh L + Ar > -0.77 (0.3325) | Mantida: Rh L + Ar > -0.77 -> background3 > 0.14 (0.7076)
# Removida: Si <= 3.71 -> Ca kb <= 1.57 (0.5235) | Mantida: Ca kb <= 1.57 -> Si <= 3.71 (0.9919)
# Removida: Ca kb <= 1.57 -> Ti ka > -0.52 (0.4835) | Mantida: Ti ka > -0.52 -> Ca kb <= 1.57 (0.5380)
# Removida: Rh L + Ar > -1.66 -> K <= 2.15 (0.7956) | Mantida: K <= 2.15 -> Rh L + Ar > -1.66 (0.9164)
# Removida: Ca ka <= -1.50 -> Rh L + Ar > -1.66 (0.4059) | Mantida: Rh L + Ar > -1.66 -> Ca ka <= -1.50 (0.4588)
# Removida: Ca kb <= 0.62 -> Rh L + Ar > -1.66 (0.3855) | Mantida: Rh L + Ar > -1.66 -> Ca kb <= 0.62 (1.2529)
# Removida: Rh L + Ar > -1.66 -> Si <= 3.71 (0.3595) | Mantida: Si <= 3.71 -> Rh L + Ar > -1.66 (0.4481)
# Removida: Ca ka > -1.50 -> K <= 2.15 (0.2828) | Mantida: K <= 2.15 -> Ca ka > -1.50 (0.3189)
# Removida: K <= 2.15 -> Si <= 3.71 (0.4778) | Mantida: Si <= 3.71 -> K <= 2.15 (0.9265)
# Removida: Ti ka > -0.86 -> Ti ka > -0.52 (0.5681) | Mantida: Ti ka > -0.52 -> Ti ka > -0.86 (1.0789)
# Removida: Ti ka > -0.52 -> Fe kb > -0.44 (0.4451) | Mantida: Fe kb > -0.44 -> Ti ka > -0.52 (1.6743)
# Removida: Ti ka > -0.86 -> Fe kb > -0.63 (0.4496) | Mantida: Fe kb > -0.63 -> Ti ka > -0.86 (3.4160)
# Removida: Ca kb <= 0.62 -> Ca ka <= -1.50 (0.3900) | Mantida: Ca ka <= -1.50 -> Ca kb <= 0.62 (0.8021)
# Removida: Fe kb > -0.44 -> Ca ka <= -1.50 (0.4220) | Mantida: Ca ka <= -1.50 -> Fe kb > -0.44 (0.4288)
# Removida: background3 > 0.14 -> Si <= 3.71 (0.2960) | Mantida: Si <= 3.71 -> background3 > 0.14 (0.3674)
# Removida: Ca kb <= 0.62 -> Si <= 3.71 (0.3848) | Mantida: Si <= 3.71 -> Ca kb <= 0.62 (0.4116)
# Removida: Fe kb > -0.44 -> Fe kb > -0.91 (0.9964) | Mantida: Fe kb > -0.91 -> Fe kb > -0.44 (1.4801)
# Removida: K > 2.15 -> Ca kb <= 0.62 (0.3967) | Mantida: Ca kb <= 0.62 -> K > 2.15 (0.4022)
# Removida: Ca kb > -1.81 -> background3 > 0.14 (0.6512) | Mantida: background3 > 0.14 -> Ca kb > -1.81 (0.9580)
# Removida: background3 > 0.14 -> Ca ka > -1.50 (0.5822) | Mantida: Ca ka > -1.50 -> background3 > 0.14 (0.6101)
# Removida: background3 > 0.14 -> K > 2.15 (0.3182) | Mantida: K > 2.15 -> background3 > 0.14 (0.3596)
# Removida: background3 > -0.62 -> Ca ka > -1.50 (0.5573) | Mantida: Ca ka > -1.50 -> background3 > -0.62 (0.5745)
# Removida: Compton scattering > -0.40 -> K <= -1.46 (0.2116) | Mantida: K <= -1.46 -> Compton scattering > -0.40 (0.2602)
# Removida: Compton scattering > 0.05 -> K <= -1.46 (0.1955) | Mantida: K <= -1.46 -> Compton scattering > 0.05 (0.2285)
# Removida: K <= -1.46 -> background3 > -1.28 (0.1625) | Mantida: background3 > -1.28 -> K <= -1.46 (0.2350)
# Removida: Ca kb <= -0.59 -> Fe ka <= 1.10 (0.1884) | Mantida: Fe ka <= 1.10 -> Ca kb <= -0.59 (0.2071)
# Removida: P > -1.23 -> Fe ka <= 1.10 (0.1862) | Mantida: Fe ka <= 1.10 -> P > -1.23 (0.2190)
# Removida: Ca ka > 1.77 -> background3 > -0.62 (0.1973) | Mantida: background3 > -0.62 -> Ca ka > 1.77 (0.2402)
# Removida: background3 > -1.28 -> Ca ka > 1.77 (0.1589) | Mantida: Ca ka > 1.77 -> background3 > -1.28 (0.2036)
# Removida: background3 > -0.62 -> K > 2.15 (0.1924) | Mantida: K > 2.15 -> background3 > -0.62 (0.5300)
# Removida: Compton scattering > 0.05 -> K > 2.15 (0.4568) | Mantida: K > 2.15 -> Compton scattering > 0.05 (0.4606)
# Removida: Compton scattering > 0.05 -> Compton scattering > -0.40 (0.3557) | Mantida: Compton scattering > -0.40 -> Compton scattering > 0.05 (1.0903)
# Removida: Compton scattering > 0.05 -> background3 > -1.28 (0.1972) | Mantida: background3 > -1.28 -> Compton scattering > 0.05 (0.2167)
# Removida: Compton scattering > 0.05 -> Ca kb <= -0.59 (0.1820) | Mantida: Ca kb <= -0.59 -> Compton scattering > 0.05 (0.2038)
# Removida: background3 > -1.28 -> Compton scattering > -0.40 (0.2563) | Mantida: Compton scattering > -0.40 -> background3 > -1.28 (0.3912)
# Removida: Compton scattering > -0.88 -> Ca kb <= -0.59 (0.3460) | Mantida: Ca kb <= -0.59 -> Compton scattering > -0.88 (0.3890)
# Removida: P > -1.23 -> Ca kb <= -0.59 (0.1871) | Mantida: Ca kb <= -0.59 -> P > -1.23 (0.2048)
# Removida: Rayleight scattering > 0.03 -> Ca kb <= -0.59 (0.1546) | Mantida: Ca kb <= -0.59 -> Rayleight scattering > 0.03 (0.1647)
# Removida: Compton scattering > -0.88 -> sum Fe > 0.07 (0.1314) | Mantida: sum Fe > 0.07 -> Compton scattering > -0.88 (0.1375)
# Removida: Al > -0.68 -> Compton scattering > -0.88 (0.1417) | Mantida: Compton scattering > -0.88 -> Al > -0.68 (0.1504)
# Removida: sum Fe > -0.28 -> Compton scattering > -0.88 (0.3141) | Mantida: Compton scattering > -0.88 -> sum Fe > -0.28 (0.3200)
# Removida: sum Fe > 0.07 -> Al > -0.68 (0.1429) | Mantida: Al > -0.68 -> sum Fe > 0.07 (0.2959)
# Removida: Rayleight scattering > 0.03 -> sum Fe > 0.07 (0.1389) | Mantida: sum Fe > 0.07 -> Rayleight scattering > 0.03 (0.1428)
# Removida: Rayleight scattering > -0.50 -> sum Fe > 0.07 (0.1178) | Mantida: sum Fe > 0.07 -> Rayleight scattering > -0.50 (0.1293)
# Removida: sum Fe > -0.28 -> Al > -0.68 (0.1367) | Mantida: Al > -0.68 -> sum Fe > -0.28 (0.1389)
# Removida: Rayleight scattering > -0.25 -> Al > -0.68 (0.1155) | Mantida: Al > -0.68 -> Rayleight scattering > -0.25 (0.1509)
# Removida: Rayleight scattering > 0.03 -> Rayleight scattering > -0.25 (0.1169) | Mantida: Rayleight scattering > -0.25 -> Rayleight scattering > 0.03 (0.4047)
# Removida: Rayleight scattering > 0.03 -> Al > -0.68 (0.1292) | Mantida: Al > -0.68 -> Rayleight scattering > 0.03 (0.2594)
# Removida: Al > -0.68 -> sum Fe > -0.60 (0.1439) | Mantida: sum Fe > -0.60 -> Al > -0.68 (0.2835)
# Removida: Al > -0.19 -> Ca kb > -0.59 (0.1173) | Mantida: Ca kb > -0.59 -> Al > -0.19 (0.2408)
# Removida: Ti kb > -0.14 -> Ca kb > -0.59 (0.0784) | Mantida: Ca kb > -0.59 -> Ti kb > -0.14 (0.2387)
# Removida: Ti kb > -0.14 -> Al > -0.19 (0.0934) | Mantida: Al > -0.19 -> Ti kb > -0.14 (0.1013)
# Removida: background2 > 0.35 -> Al > -0.19 (0.1107) | Mantida: Al > -0.19 -> background2 > 0.35 (0.1118)
# Removida: P > 0.08 -> P > -0.59 (0.0926) | Mantida: P > -0.59 -> P > 0.08 (0.0976)
# Removida: Ti kb > -0.14 -> Al <= 0.62 (0.0821) | Mantida: Al <= 0.62 -> Ti kb > -0.14 (0.1033)
# Removida: Al <= 0.62 -> P > -0.59 (0.0894) | Mantida: P > -0.59 -> Al <= 0.62 (0.0955)
# Removida: sum Fe > -0.60 -> Rayleight scattering > -0.50 (0.1256) | Mantida: Rayleight scattering > -0.50 -> sum Fe > -0.60 (0.2025)
# Removida: Ti kb > -0.32 -> Rayleight scattering > -0.50 (0.1709) | Mantida: Rayleight scattering > -0.50 -> Ti kb > -0.32 (0.2147)
# Removida: P > -1.23 -> sum Fe > -0.60 (0.1388) | Mantida: sum Fe > -0.60 -> P > -1.23 (0.1494)
# Removida: Ca kb > 0.62 -> Mn > 0.23 (0.0690) | Mantida: Mn > 0.23 -> Ca kb > 0.62 (0.1777)
# Removida: Ca kb > 0.62 -> Ni <= 0.13 (0.0593) | Mantida: Ni <= 0.13 -> Ca kb > 0.62 (0.0624)
# Removida: Ca kb > 0.62 -> Ti kb > 0.03 (0.0701) | Mantida: Ti kb > 0.03 -> Ca kb > 0.62 (0.0736)
# Removida: Cu <= -0.12 -> Ca kb > 0.62 (0.0684) | Mantida: Ca kb > 0.62 -> Cu <= -0.12 (0.0752)
# Removida: background2 <= -0.51 -> Ti kb > -0.32 (0.0778) | Mantida: Ti kb > -0.32 -> background2 <= -0.51 (0.0899)
# Removida: Al > 0.19 -> background2 <= -0.51 (0.0329) | Mantida: background2 <= -0.51 -> Al > 0.19 (0.0350)
# Removida: Ti kb > -0.32 -> P > -1.23 (0.0682) | Mantida: P > -1.23 -> Ti kb > -0.32 (0.1281)
# Removida: Ti kb > 0.03 -> background2 > 0.35 (0.0914) | Mantida: background2 > 0.35 -> Ti kb > 0.03 (0.2642)
# Removida: Ti kb > 0.03 -> Ti kb > -0.14 (0.1410) | Mantida: Ti kb > -0.14 -> Ti kb > 0.03 (0.2696)
# Removida: Cu <= -0.12 -> background3 <= -0.62 (0.0605) | Mantida: background3 <= -0.62 -> Cu <= -0.12 (0.0625)
# Removida: background3 <= -0.62 -> Ti ka <= 0.53 (0.0587) | Mantida: Ti ka <= 0.53 -> background3 <= -0.62 (0.0677)
# Removida: Ti ka <= 0.53 -> Cu <= 0.09 (0.0428) | Mantida: Cu <= 0.09 -> Ti ka <= 0.53 (0.0546)
# Removida: background3 <= -0.62 -> S <= -0.27 (0.0198) | Mantida: S <= -0.27 -> background3 <= -0.62 (0.0376)
# Removida: Compton scattering <= -0.40 -> S <= -0.27 (0.0512) | Mantida: S <= -0.27 -> Compton scattering <= -0.40 (0.0513)
# Removida: Ni <= 0.59 -> S <= -0.27 (0.0329) | Mantida: S <= -0.27 -> Ni <= 0.59 (0.0358)
# Removida: S <= -0.27 -> Cu <= 0.09 (0.0201) | Mantida: Cu <= 0.09 -> S <= -0.27 (0.0391)
# Removida: Compton scattering <= -0.40 -> Ni <= 0.13 (0.0470) | Mantida: Ni <= 0.13 -> Compton scattering <= -0.40 (0.0508)
# Removida: Compton scattering <= -0.40 -> background2 <= 0.35 (0.0696) | Mantida: background2 <= 0.35 -> Compton scattering <= -0.40 (0.1054)
# Removida: Ni <= 0.13 -> background2 <= 0.35 (0.0473) | Mantida: background2 <= 0.35 -> Ni <= 0.13 (0.0752)
# Removida: Ni <= 0.13 -> P <= -0.59 (0.0470) | Mantida: P <= -0.59 -> Ni <= 0.13 (0.1734)
# Removida: background2 <= 0.35 -> S <= 0.55 (0.0444) | Mantida: S <= 0.55 -> background2 <= 0.35 (0.0563)
# Removida: background2 <= 0.35 -> Ni <= 0.59 (0.0215) | Mantida: Ni <= 0.59 -> background2 <= 0.35 (0.0293)
# Removida: S <= 0.09 -> Ni <= -0.14 (0.0445) | Mantida: Ni <= -0.14 -> S <= 0.09 (0.0687)
# Removida: Ni <= -0.14 -> Ni <= 0.59 (0.0382) | Mantida: Ni <= 0.59 -> Ni <= -0.14 (0.0665)
# Removida: Cu <= 0.09 -> Ni <= -0.14 (0.0359) | Mantida: Ni <= -0.14 -> Cu <= 0.09 (0.0386)
# Removida: sum Fe <= -0.28 -> S <= 0.09 (0.0370) | Mantida: S <= 0.09 -> sum Fe <= -0.28 (0.0439)
# Removida: sum Fe <= -0.28 -> background3 <= 0.14 (0.0428) | Mantida: background3 <= 0.14 -> sum Fe <= -0.28 (0.0454)
# Removida: background1 <= 0.30 -> sum Fe <= -0.28 (0.0222) | Mantida: sum Fe <= -0.28 -> background1 <= 0.30 (0.0378)
# Removida: Fe kb <= 0.33 -> Ni > -0.14 (0.0427) | Mantida: Ni > -0.14 -> Fe kb <= 0.33 (0.0710)
# Removida: Ni > -0.14 -> Zn <= 0.10 (0.0192) | Mantida: Zn <= 0.10 -> Ni > -0.14 (0.0194)
# Removida: Ni > -0.14 -> Zn <= 0.34 (0.0173) | Mantida: Zn <= 0.34 -> Ni > -0.14 (0.0312)
# Removida: Ni > -0.60 -> Zn > 0.10 (0.0127) | Mantida: Zn > 0.10 -> Ni > -0.60 (0.0171)
# Removida: Cu <= 0.09 -> background2 <= 1.51 (0.0392) | Mantida: background2 <= 1.51 -> Cu <= 0.09 (0.1025)
# Removida: Mn > -0.41 -> P <= -0.59 (0.0354) | Mantida: P <= -0.59 -> Mn > -0.41 (0.0558)
# Removida: Mn <= 1.01 -> background2 > -0.51 (0.0349) | Mantida: background2 > -0.51 -> Mn <= 1.01 (0.0912)
# Removida: Rh L + Ar <= -0.77 -> Mn <= 1.01 (0.0600) | Mantida: Mn <= 1.01 -> Rh L + Ar <= -0.77 (0.0643)
# Removida: Al <= -0.19 -> Rh L + Ar <= 1.37 (0.0155) | Mantida: Rh L + Ar <= 1.37 -> Al <= -0.19 (0.0215)
# Removida: Zn <= 0.34 -> Al <= -0.19 (0.0181) | Mantida: Al <= -0.19 -> Zn <= 0.34 (0.0196)
# Removida: Al <= -0.19 -> Mn <= -0.41 (0.0154) | Mantida: Mn <= -0.41 -> Al <= -0.19 (0.0217)
# Removida: Zn <= 0.34 -> Rayleight scattering <= -0.25 (0.0278) | Mantida: Rayleight scattering <= -0.25 -> Zn <= 0.34 (0.0570)
# Removida: Zn > -0.11 -> Cu > -0.55 (0.0115) | Mantida: Cu > -0.55 -> Zn > -0.11 (0.0129)
# Removida: Cu > -0.55 -> sum Fe <= 0.62 (0.0117) | Mantida: sum Fe <= 0.62 -> Cu > -0.55 (0.0120)
# Removida: Cu > -0.55 -> Cu > -0.12 (0.0114) | Mantida: Cu > -0.12 -> Cu > -0.55 (0.0159)
# Removida: Zn <= 0.34 -> Rh L + Ar <= 1.37 (0.0234) | Mantida: Rh L + Ar <= 1.37 -> Zn <= 0.34 (0.0333)
# Removida: Zn <= 0.34 -> background3 <= 1.47 (0.0170) | Mantida: background3 <= 1.47 -> Zn <= 0.34 (0.0390)
# Removida: background1 <= 0.30 -> Zn <= -0.11 (0.0180) | Mantida: Zn <= -0.11 -> background1 <= 0.30 (0.0266)
# Removida: background1 <= 0.30 -> Ti kb <= 0.20 (0.0179) | Mantida: Ti kb <= 0.20 -> background1 <= 0.30 (0.0252)
# Removida: Zn <= -0.11 -> S > -0.55 (0.0194) | Mantida: S > -0.55 -> Zn <= -0.11 (0.0490)
# Removida: Ti kb <= 0.20 -> S > -0.27 (0.0218) | Mantida: S > -0.27 -> Ti kb <= 0.20 (0.0250)
# Removida: background1 <= -0.08 -> background1 > 0.11 (0.0164) | Mantida: background1 > 0.11 -> background1 <= -0.08 (0.0171)
# Removida: background1 > 0.11 -> Cu <= 0.56 (0.0164) | Mantida: Cu <= 0.56 -> background1 > 0.11 (0.0225)
# Removida: background1 > 0.11 -> S > -0.27 (0.0134) | Mantida: S > -0.27 -> background1 > 0.11 (0.0248)
# Removida: S > -0.27 -> background1 <= -0.08 (0.0159) | Mantida: background1 <= -0.08 -> S > -0.27 (0.0161)
# Removida: background1 <= 0.11 -> Fe ka <= -2.26 (0.0153) | Mantida: Fe ka <= -2.26 -> background1 <= 0.11 (0.0671)
# Removida: Ti kb <= 0.03 -> sum Fe <= 0.62 (0.0108) | Mantida: sum Fe <= 0.62 -> Ti kb <= 0.03 (0.0182)
# Removida: Cu > -0.12 -> sum Fe <= 0.07 (0.0107) | Mantida: sum Fe <= 0.07 -> Cu > -0.12 (0.0133)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 870 | Removidas: 135
# Nós predicados: 126
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 114
# Removida: Fe ka > -2.26 -> Fe ka > -3.74 (8.5112) | Mantida: Fe ka > -3.74 -> Fe ka > -2.26 (17.5676)
# Removida: K > -6.69 -> Ca ka <= 3.95 (1.2881) | Mantida: Ca ka <= 3.95 -> K > -6.69 (2.2430)
# Removida: Si > -1.67 -> Ca ka <= 3.95 (2.5239) | Mantida: Ca ka <= 3.95 -> Si > -1.67 (3.4178)
# Removida: Ca ka <= 3.95 -> Si > -2.51 (3.5242) | Mantida: Si > -2.51 -> Ca ka <= 3.95 (3.8322)
# Removida: Si > -2.51 -> K > -6.69 (1.2649) | Mantida: K > -6.69 -> Si > -2.51 (3.9122)
# Removida: K > -6.69 -> K <= 6.26 (2.2675) | Mantida: K <= 6.26 -> K > -6.69 (2.4065)
# Removida: Si > -1.67 -> K > -6.69 (2.4546) | Mantida: K > -6.69 -> Si > -1.67 (2.4703)
# Removida: Si > -1.67 -> Si > -2.51 (2.4541) | Mantida: Si > -2.51 -> Si > -1.67 (4.9553)
# Removida: Ca ka <= 1.77 -> K <= 6.26 (1.7865) | Mantida: K <= 6.26 -> Ca ka <= 1.77 (2.0279)
# Removida: Ca ka > -4.65 -> K <= 6.26 (0.9443) | Mantida: K <= 6.26 -> Ca ka > -4.65 (4.2059)
# Removida: K > -1.46 -> Ca ka <= 1.77 (1.9465) | Mantida: Ca ka <= 1.77 -> K > -1.46 (3.5297)
# Removida: Ca ka <= 1.77 -> Ca ka > -4.65 (1.7112) | Mantida: Ca ka > -4.65 -> Ca ka <= 1.77 (2.8136)
# Removida: Ca ka <= 1.77 -> Si > -0.72 (0.8057) | Mantida: Si > -0.72 -> Ca ka <= 1.77 (0.9032)
# Removida: Ti ka > -0.70 -> K > -1.46 (0.7125) | Mantida: K > -1.46 -> Ti ka > -0.70 (1.5755)
# Removida: Si > -0.72 -> K > -1.46 (1.6563) | Mantida: K > -1.46 -> Si > -0.72 (2.6164)
# Removida: Ca kb <= 1.57 -> Ti ka > -0.52 (0.5005) | Mantida: Ti ka > -0.52 -> Ca kb <= 1.57 (0.5468)
# Removida: Rh L + Ar > -0.16 -> Ca kb <= 1.57 (0.5095) | Mantida: Ca kb <= 1.57 -> Rh L + Ar > -0.16 (1.4465)
# Removida: Ca kb <= 1.57 -> Rh L + Ar > -0.77 (0.9917) | Mantida: Rh L + Ar > -0.77 -> Ca kb <= 1.57 (1.0150)
# Removida: Ca kb <= 1.57 -> K <= 2.15 (0.5045) | Mantida: K <= 2.15 -> Ca kb <= 1.57 (1.1335)
# Removida: Ca ka <= -1.50 -> Ca kb <= 1.57 (0.4749) | Mantida: Ca kb <= 1.57 -> Ca ka <= -1.50 (0.4764)
# Removida: Fe kb > -0.44 -> Ca kb <= 1.57 (0.4696) | Mantida: Ca kb <= 1.57 -> Fe kb > -0.44 (0.5233)
# Removida: Ti ka > -0.52 -> Fe kb > -0.63 (0.4945) | Mantida: Fe kb > -0.63 -> Ti ka > -0.52 (1.2419)
# Removida: Fe kb > -0.91 -> Ti ka > -0.52 (0.5474) | Mantida: Ti ka > -0.52 -> Fe kb > -0.91 (1.6126)
# Removida: Ti ka > -0.52 -> Fe kb > -0.44 (0.6579) | Mantida: Fe kb > -0.44 -> Ti ka > -0.52 (1.6396)
# Removida: Ti ka > -0.86 -> Ti ka > -0.52 (0.5363) | Mantida: Ti ka > -0.52 -> Ti ka > -0.86 (0.6168)
# Removida: Ti ka > -0.52 -> Rh L + Ar > -0.16 (0.5225) | Mantida: Rh L + Ar > -0.16 -> Ti ka > -0.52 (0.5306)
# Removida: Fe kb > -0.63 -> Fe kb > -0.44 (0.5827) | Mantida: Fe kb > -0.44 -> Fe kb > -0.63 (1.2015)
# Removida: K <= 2.15 -> Si <= 3.71 (0.4968) | Mantida: Si <= 3.71 -> K <= 2.15 (0.4972)
# Removida: Ca kb <= 0.62 -> Si <= 3.71 (0.3983) | Mantida: Si <= 3.71 -> Ca kb <= 0.62 (1.2479)
# Removida: Rh L + Ar > -1.66 -> Si <= 3.71 (0.3953) | Mantida: Si <= 3.71 -> Rh L + Ar > -1.66 (1.3465)
# Removida: Ca ka <= -1.50 -> Si <= 3.71 (0.4331) | Mantida: Si <= 3.71 -> Ca ka <= -1.50 (0.4735)
# Removida: Rh L + Ar > -0.77 -> Si <= 3.71 (0.8901) | Mantida: Si <= 3.71 -> Rh L + Ar > -0.77 (0.8989)
# Removida: K <= 2.15 -> Ti ka > -0.86 (0.4856) | Mantida: Ti ka > -0.86 -> K <= 2.15 (0.5918)
# Removida: Rh L + Ar > -0.16 -> K <= 2.15 (0.4901) | Mantida: K <= 2.15 -> Rh L + Ar > -0.16 (0.4925)
# Removida: Ti ka > -0.86 -> Fe kb > -0.44 (1.0450) | Mantida: Fe kb > -0.44 -> Ti ka > -0.86 (1.1993)
# Removida: Fe kb > -0.44 -> Fe kb > -0.91 (0.4511) | Mantida: Fe kb > -0.91 -> Fe kb > -0.44 (1.6406)
# Removida: Ca kb <= 0.62 -> Ca ka <= -1.50 (0.4037) | Mantida: Ca ka <= -1.50 -> Ca kb <= 0.62 (0.4133)
# Removida: Ca kb > -1.81 -> Ca kb <= 0.62 (0.3886) | Mantida: Ca kb <= 0.62 -> Ca kb > -1.81 (1.1611)
# Removida: Ca ka > -1.50 -> Ca kb <= 0.62 (0.3496) | Mantida: Ca kb <= 0.62 -> Ca ka > -1.50 (1.1409)
# Removida: Ca ka <= -1.50 -> Rh L + Ar > -1.66 (0.4092) | Mantida: Rh L + Ar > -1.66 -> Ca ka <= -1.50 (0.4405)
# Removida: Rh L + Ar > -0.16 -> Rh L + Ar > -0.77 (0.4635) | Mantida: Rh L + Ar > -0.77 -> Rh L + Ar > -0.16 (1.1971)
# Removida: background3 > 0.14 -> Rh L + Ar > -1.66 (0.2778) | Mantida: Rh L + Ar > -1.66 -> background3 > 0.14 (0.7619)
# Removida: Rh L + Ar > -1.66 -> Ca kb > -1.81 (0.3497) | Mantida: Ca kb > -1.81 -> Rh L + Ar > -1.66 (0.8140)
# Removida: Ca ka > -1.50 -> Rh L + Ar > -1.66 (0.3288) | Mantida: Rh L + Ar > -1.66 -> Ca ka > -1.50 (0.4071)
# Removida: Ca kb > -1.81 -> background3 > 0.14 (0.6851) | Mantida: background3 > 0.14 -> Ca kb > -1.81 (0.7205)
# Removida: background3 > 0.14 -> K > 2.15 (0.3083) | Mantida: K > 2.15 -> background3 > 0.14 (0.3150)
# Removida: background3 > 0.14 -> Ca ka > -1.50 (0.3336) | Mantida: Ca ka > -1.50 -> background3 > 0.14 (0.6430)
# Removida: K <= -1.46 -> background3 > -0.62 (0.3351) | Mantida: background3 > -0.62 -> K <= -1.46 (0.7999)
# Removida: background3 > -0.62 -> K > 2.15 (0.1958) | Mantida: K > 2.15 -> background3 > -0.62 (0.6301)
# Removida: Compton scattering > -0.40 -> K > 2.15 (0.2426) | Mantida: K > 2.15 -> Compton scattering > -0.40 (0.2796)
# Removida: background3 > -1.28 -> K > 2.15 (0.1677) | Mantida: K > 2.15 -> background3 > -1.28 (0.2352)
# Removida: Compton scattering > 0.05 -> Ca ka > 1.77 (0.2118) | Mantida: Ca ka > 1.77 -> Compton scattering > 0.05 (0.8787)
# Removida: Ca kb <= -0.59 -> Compton scattering > 0.05 (0.1859) | Mantida: Compton scattering > 0.05 -> Ca kb <= -0.59 (0.7887)
# Removida: background3 > -1.28 -> Compton scattering > 0.05 (0.2074) | Mantida: Compton scattering > 0.05 -> background3 > -1.28 (0.4591)
# Removida: Ca ka > 1.77 -> background3 > -1.28 (0.4368) | Mantida: background3 > -1.28 -> Ca ka > 1.77 (0.4709)
# Removida: Ca kb <= -0.59 -> background3 > -1.28 (0.1939) | Mantida: background3 > -1.28 -> Ca kb <= -0.59 (0.4057)
# Removida: Fe ka <= 1.10 -> Rayleight scattering > 0.03 (0.1561) | Mantida: Rayleight scattering > 0.03 -> Fe ka <= 1.10 (0.2912)
# Removida: Compton scattering > -0.88 -> Fe ka <= 1.10 (0.1656) | Mantida: Fe ka <= 1.10 -> Compton scattering > -0.88 (0.2147)
# Removida: Compton scattering > -0.88 -> Rayleight scattering > -0.25 (0.3522) | Mantida: Rayleight scattering > -0.25 -> Compton scattering > -0.88 (0.4645)
# Removida: Rayleight scattering > -0.25 -> sum Fe > -0.28 (0.1467) | Mantida: sum Fe > -0.28 -> Rayleight scattering > -0.25 (0.4547)
# Removida: Rayleight scattering > 0.03 -> Compton scattering > -0.88 (0.2747) | Mantida: Compton scattering > -0.88 -> Rayleight scattering > 0.03 (0.3303)
# Removida: Compton scattering > -0.88 -> sum Fe > -0.28 (0.1254) | Mantida: sum Fe > -0.28 -> Compton scattering > -0.88 (0.1674)
# Removida: sum Fe > -0.28 -> sum Fe > 0.07 (0.1358) | Mantida: sum Fe > 0.07 -> sum Fe > -0.28 (0.2823)
# Removida: sum Fe > 0.07 -> Ca kb > -0.59 (0.2582) | Mantida: Ca kb > -0.59 -> sum Fe > 0.07 (0.2854)
# Removida: sum Fe > 0.07 -> Rayleight scattering > -0.50 (0.1213) | Mantida: Rayleight scattering > -0.50 -> sum Fe > 0.07 (0.1221)
# Removida: Rayleight scattering > 0.03 -> Al > -0.68 (0.1319) | Mantida: Al > -0.68 -> Rayleight scattering > 0.03 (0.1534)
# Removida: Al > -0.68 -> P > -1.23 (0.1387) | Mantida: P > -1.23 -> Al > -0.68 (0.3197)
# Removida: sum Fe > -0.60 -> Al > -0.68 (0.1430) | Mantida: Al > -0.68 -> sum Fe > -0.60 (0.3903)
# Removida: Rayleight scattering > -0.50 -> Al > -0.68 (0.1098) | Mantida: Al > -0.68 -> Rayleight scattering > -0.50 (0.1449)
# Removida: sum Fe > -0.60 -> P > -1.23 (0.1300) | Mantida: P > -1.23 -> sum Fe > -0.60 (0.1386)
# Removida: sum Fe > -0.60 -> Ca kb > -0.59 (0.2292) | Mantida: Ca kb > -0.59 -> sum Fe > -0.60 (0.2780)
# Removida: sum Fe > -0.60 -> Al > -0.19 (0.1083) | Mantida: Al > -0.19 -> sum Fe > -0.60 (0.2426)
# Removida: Rayleight scattering > -0.50 -> Al > -0.19 (0.2259) | Mantida: Al > -0.19 -> Rayleight scattering > -0.50 (0.2482)
# Removida: Al <= 0.62 -> Ti kb > -0.14 (0.1072) | Mantida: Ti kb > -0.14 -> Al <= 0.62 (0.1742)
# Removida: Al <= 0.62 -> Ca kb > 0.62 (0.1003) | Mantida: Ca kb > 0.62 -> Al <= 0.62 (0.2046)
# Removida: P > -0.59 -> background2 > -1.35 (0.0839) | Mantida: background2 > -1.35 -> P > -0.59 (0.0912)
# Removida: Ca kb > 0.62 -> P > -0.59 (0.0959) | Mantida: P > -0.59 -> Ca kb > 0.62 (0.1043)
# Removida: background2 > 0.35 -> P <= 0.08 (0.0620) | Mantida: P <= 0.08 -> background2 > 0.35 (0.0793)
# Removida: P > 0.08 -> Ca kb > 0.62 (0.0949) | Mantida: Ca kb > 0.62 -> P > 0.08 (0.1856)
# Removida: Compton scattering <= -0.40 -> Ca kb > 0.62 (0.0484) | Mantida: Ca kb > 0.62 -> Compton scattering <= -0.40 (0.0943)
# Removida: background2 > -0.51 -> Ti kb > 0.03 (0.0735) | Mantida: Ti kb > 0.03 -> background2 > -0.51 (0.0759)
# Removida: Mn > 0.23 -> background2 > -0.51 (0.0816) | Mantida: background2 > -0.51 -> Mn > 0.23 (0.1626)
# Removida: Ti kb > 0.03 -> Ti kb > -0.14 (0.0916) | Mantida: Ti kb > -0.14 -> Ti kb > 0.03 (0.5118)
# Removida: S <= 0.55 -> Mn <= 1.01 (0.0669) | Mantida: Mn <= 1.01 -> S <= 0.55 (0.1484)
# Removida: Ti ka <= 0.53 -> Mn <= 1.01 (0.0588) | Mantida: Mn <= 1.01 -> Ti ka <= 0.53 (0.0659)
# Removida: Compton scattering <= -0.40 -> background3 <= -0.62 (0.0417) | Mantida: background3 <= -0.62 -> Compton scattering <= -0.40 (0.0601)
# Removida: Ti ka <= 0.53 -> background3 <= -0.62 (0.0575) | Mantida: background3 <= -0.62 -> Ti ka <= 0.53 (0.0626)
# Removida: Cu <= 0.09 -> Compton scattering <= -0.40 (0.0403) | Mantida: Compton scattering <= -0.40 -> Cu <= 0.09 (0.1043)
# Removida: Compton scattering <= -0.40 -> P <= -0.59 (0.0572) | Mantida: P <= -0.59 -> Compton scattering <= -0.40 (0.0638)
# Removida: S <= -0.27 -> Ni > -0.14 (0.0488) | Mantida: Ni > -0.14 -> S <= -0.27 (0.0791)
# Removida: Ni <= 0.13 -> S <= -0.27 (0.0438) | Mantida: S <= -0.27 -> Ni <= 0.13 (0.0504)
# Removida: Rayleight scattering <= -0.25 -> Ni <= 0.59 (0.0337) | Mantida: Ni <= 0.59 -> Rayleight scattering <= -0.25 (0.0340)
# Removida: Ti kb <= 0.20 -> Rayleight scattering <= -0.25 (0.0135) | Mantida: Rayleight scattering <= -0.25 -> Ti kb <= 0.20 (0.0223)
# Removida: P <= -0.59 -> Ni <= 0.13 (0.0535) | Mantida: Ni <= 0.13 -> P <= -0.59 (0.0625)
# Removida: Zn > -0.11 -> Ni <= -0.14 (0.0172) | Mantida: Ni <= -0.14 -> Zn > -0.11 (0.0214)
# Removida: Mn > -0.41 -> Ni <= -0.14 (0.0281) | Mantida: Ni <= -0.14 -> Mn > -0.41 (0.0301)
# Removida: background2 <= 0.35 -> sum Fe <= -0.28 (0.0316) | Mantida: sum Fe <= -0.28 -> background2 <= 0.35 (0.0476)
# Removida: Zn <= -0.11 -> Fe kb <= 0.33 (0.0215) | Mantida: Fe kb <= 0.33 -> Zn <= -0.11 (0.0324)
# Removida: Al <= -0.19 -> background1 <= 0.30 (0.0252) | Mantida: background1 <= 0.30 -> Al <= -0.19 (0.0455)
# Removida: background1 <= 0.30 -> Zn <= 0.10 (0.0169) | Mantida: Zn <= 0.10 -> background1 <= 0.30 (0.0292)
# Removida: background1 <= 0.30 -> Zn <= -0.11 (0.0226) | Mantida: Zn <= -0.11 -> background1 <= 0.30 (0.0242)
# Removida: Ni > -0.60 -> S <= 0.09 (0.0258) | Mantida: S <= 0.09 -> Ni > -0.60 (0.0298)
# Removida: Zn <= 0.34 -> Al <= 0.19 (0.0170) | Mantida: Al <= 0.19 -> Zn <= 0.34 (0.0252)
# Removida: Al <= 0.19 -> Ti kb <= 0.20 (0.0182) | Mantida: Ti kb <= 0.20 -> Al <= 0.19 (0.0396)
# Removida: Ni > -0.60 -> Al <= -0.19 (0.0254) | Mantida: Al <= -0.19 -> Ni > -0.60 (0.0301)
# Removida: Zn <= 0.10 -> Al <= -0.19 (0.0270) | Mantida: Al <= -0.19 -> Zn <= 0.10 (0.0282)
# Removida: Zn <= 0.34 -> Zn <= 0.10 (0.0445) | Mantida: Zn <= 0.10 -> Zn <= 0.34 (0.0507)
# Removida: Fe ka <= -2.26 -> Ti kb <= 0.20 (0.0235) | Mantida: Ti kb <= 0.20 -> Fe ka <= -2.26 (0.0411)
# Removida: Al > 0.19 -> Zn <= -0.11 (0.0185) | Mantida: Zn <= -0.11 -> Al > 0.19 (0.0277)
# Removida: background1 <= 0.11 -> Cu <= 0.56 (0.0202) | Mantida: Cu <= 0.56 -> background1 <= 0.11 (0.0323)
# Removida: Ni > 0.13 -> Mn <= 0.23 (0.0132) | Mantida: Mn <= 0.23 -> Ni > 0.13 (0.0199)
# Removida: Ti kb <= 0.03 -> Cu > -0.55 (0.0117) | Mantida: Cu > -0.55 -> Ti kb <= 0.03 (0.0140)
# Removida: Ti kb <= 0.03 -> Cu > 0.09 (0.0090) | Mantida: Cu > 0.09 -> Ti kb <= 0.03 (0.0126)
# Removida: Zn > -0.11 -> P <= 1.06 (0.0098) | Mantida: P <= 1.06 -> Zn > -0.11 (0.0205)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 846 | Removidas: 114
# Nós predicados: 130
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 117
# Removida: Fe ka > -2.26 -> Fe ka > -3.74 (12.4125) | Mantida: Fe ka > -3.74 -> Fe ka > -2.26 (12.9581)
# Removida: Si > -2.51 -> Ca ka <= 3.95 (2.5058) | Mantida: Ca ka <= 3.95 -> Si > -2.51 (6.9386)
# Removida: Si > -1.67 -> Si > -2.51 (2.3389) | Mantida: Si > -2.51 -> Si > -1.67 (6.1895)
# Removida: K > -6.69 -> Si > -1.67 (1.2348) | Mantida: Si > -1.67 -> K > -6.69 (3.6676)
# Removida: K <= 6.26 -> K > -6.69 (1.1449) | Mantida: K > -6.69 -> K <= 6.26 (2.3251)
# Removida: Ca ka <= 1.77 -> K <= 6.26 (1.8096) | Mantida: K <= 6.26 -> Ca ka <= 1.77 (6.5123)
# Removida: Ca ka > -4.65 -> Ca ka <= 1.77 (0.9158) | Mantida: Ca ka <= 1.77 -> Ca ka > -4.65 (5.2326)
# Removida: Ca ka <= 1.77 -> K > -1.46 (0.9668) | Mantida: K > -1.46 -> Ca ka <= 1.77 (0.9686)
# Removida: K > -1.46 -> Ca ka > -4.65 (2.8080) | Mantida: Ca ka > -4.65 -> K > -1.46 (4.1910)
# Removida: Si > -0.72 -> K > -1.46 (1.7822) | Mantida: K > -1.46 -> Si > -0.72 (4.2882)
# Removida: Ca kb <= 0.62 -> Si <= 3.71 (0.3918) | Mantida: Si <= 3.71 -> Ca kb <= 0.62 (0.4312)
# Removida: Rh L + Ar > -0.77 -> Si <= 3.71 (0.9403) | Mantida: Si <= 3.71 -> Rh L + Ar > -0.77 (1.0014)
# Removida: Rh L + Ar > -0.16 -> K <= 2.15 (0.9640) | Mantida: K <= 2.15 -> Rh L + Ar > -0.16 (1.0661)
# Removida: Rh L + Ar > -1.66 -> K <= 2.15 (0.4497) | Mantida: K <= 2.15 -> Rh L + Ar > -1.66 (1.3465)
# Removida: Rh L + Ar > -0.77 -> K <= 2.15 (0.4542) | Mantida: K <= 2.15 -> Rh L + Ar > -0.77 (0.5069)
# Removida: Ca ka <= -1.50 -> K <= 2.15 (0.3738) | Mantida: K <= 2.15 -> Ca ka <= -1.50 (0.4416)
# Removida: Ca kb <= 1.57 -> K <= 2.15 (0.4848) | Mantida: K <= 2.15 -> Ca kb <= 1.57 (0.5147)
# Removida: Rh L + Ar > -0.16 -> Ca kb <= 1.57 (0.4970) | Mantida: Ca kb <= 1.57 -> Rh L + Ar > -0.16 (1.4948)
# Removida: Fe kb > -0.44 -> Ti ka > -0.86 (0.5416) | Mantida: Ti ka > -0.86 -> Fe kb > -0.44 (1.2247)
# Removida: Ti ka > -0.52 -> Fe kb > -0.44 (0.5800) | Mantida: Fe kb > -0.44 -> Ti ka > -0.52 (1.7497)
# Removida: Ca kb <= 1.57 -> Ti ka > -0.86 (0.4801) | Mantida: Ti ka > -0.86 -> Ca kb <= 1.57 (0.4897)
# Removida: Ca kb <= 1.57 -> Rh L + Ar > -0.77 (0.4866) | Mantida: Rh L + Ar > -0.77 -> Ca kb <= 1.57 (0.5082)
# Removida: Ca kb <= 1.57 -> Ti ka > -0.52 (0.4961) | Mantida: Ti ka > -0.52 -> Ca kb <= 1.57 (0.5755)
# Removida: Ti ka > -0.86 -> Fe kb > -0.63 (0.4856) | Mantida: Fe kb > -0.63 -> Ti ka > -0.86 (2.3104)
# Removida: Fe kb > -0.91 -> Ti ka > -0.86 (0.5768) | Mantida: Ti ka > -0.86 -> Fe kb > -0.91 (2.2351)
# Removida: Ti ka > -0.86 -> Ti ka > -0.52 (0.5905) | Mantida: Ti ka > -0.52 -> Ti ka > -0.86 (1.1096)
# Removida: Rh L + Ar > -0.77 -> Ti ka > -0.86 (0.5451) | Mantida: Ti ka > -0.86 -> Rh L + Ar > -0.77 (0.6012)
# Removida: Ti ka > -0.52 -> Fe kb > -0.63 (0.5782) | Mantida: Fe kb > -0.63 -> Ti ka > -0.52 (0.9520)
# Removida: Fe kb > -0.63 -> Rh L + Ar > -0.77 (0.5392) | Mantida: Rh L + Ar > -0.77 -> Fe kb > -0.63 (1.0711)
# Removida: Ti ka > -0.52 -> Fe kb > -0.91 (0.6118) | Mantida: Fe kb > -0.91 -> Ti ka > -0.52 (1.6178)
# Removida: Ca kb <= 0.62 -> Ca ka <= -1.50 (1.2110) | Mantida: Ca ka <= -1.50 -> Ca kb <= 0.62 (1.8745)
# Removida: Ca ka <= -1.50 -> Rh L + Ar > -1.66 (0.4257) | Mantida: Rh L + Ar > -1.66 -> Ca ka <= -1.50 (0.4337)
# Removida: Ca kb > -1.81 -> Ca kb <= 0.62 (0.3820) | Mantida: Ca kb <= 0.62 -> Ca kb > -1.81 (0.3877)
# Removida: Ca kb > -1.81 -> Rh L + Ar > -1.66 (0.7323) | Mantida: Rh L + Ar > -1.66 -> Ca kb > -1.81 (1.0971)
# Removida: Ca kb > -1.81 -> Ca ka > -1.50 (0.3249) | Mantida: Ca ka > -1.50 -> Ca kb > -1.81 (1.0092)
# Removida: background3 > 0.14 -> Ca kb > -1.81 (0.6902) | Mantida: Ca kb > -1.81 -> background3 > 0.14 (1.0680)
# Removida: background3 > 0.14 -> Ca ka > -1.50 (0.6104) | Mantida: Ca ka > -1.50 -> background3 > 0.14 (0.8687)
# Removida: background3 > -0.62 -> Ca ka > -1.50 (0.2466) | Mantida: Ca ka > -1.50 -> background3 > -0.62 (0.3135)
# Removida: background3 > -0.62 -> K > 2.15 (0.2864) | Mantida: K > 2.15 -> background3 > -0.62 (0.2881)
# Removida: Ca ka > 1.77 -> background3 > -0.62 (0.2139) | Mantida: background3 > -0.62 -> Ca ka > 1.77 (0.2343)
# Removida: background3 > -0.62 -> K <= -1.46 (0.5001) | Mantida: K <= -1.46 -> background3 > -0.62 (0.5969)
# Removida: Fe ka <= 1.10 -> K > 2.15 (0.1627) | Mantida: K > 2.15 -> Fe ka <= 1.10 (0.2194)
# Removida: Ca kb <= -0.59 -> Fe ka <= 1.10 (0.1832) | Mantida: Fe ka <= 1.10 -> Ca kb <= -0.59 (0.3920)
# Removida: Compton scattering > -0.40 -> K <= -1.46 (0.2531) | Mantida: K <= -1.46 -> Compton scattering > -0.40 (0.4806)
# Removida: background3 > -1.28 -> K <= -1.46 (0.2071) | Mantida: K <= -1.46 -> background3 > -1.28 (0.5643)
# Removida: K > 2.15 -> Compton scattering > -0.40 (0.5282) | Mantida: Compton scattering > -0.40 -> K > 2.15 (0.6021)
# Removida: Compton scattering > -0.40 -> background3 > -1.28 (0.1863) | Mantida: background3 > -1.28 -> Compton scattering > -0.40 (0.2423)
# Removida: Compton scattering > -0.40 -> Ca kb <= -0.59 (0.1754) | Mantida: Ca kb <= -0.59 -> Compton scattering > -0.40 (0.1953)
# Removida: Ca ka > 1.77 -> background3 > -1.28 (0.4284) | Mantida: background3 > -1.28 -> Ca ka > 1.77 (0.4303)
# Removida: Ca kb <= -0.59 -> Ca ka > 1.77 (0.1732) | Mantida: Ca ka > 1.77 -> Ca kb <= -0.59 (0.1783)
# Removida: sum Fe > 0.07 -> sum Fe > -0.28 (0.2538) | Mantida: sum Fe > -0.28 -> sum Fe > 0.07 (0.3873)
# Removida: sum Fe > -0.28 -> Rayleight scattering > -0.25 (0.1693) | Mantida: Rayleight scattering > -0.25 -> sum Fe > -0.28 (0.4497)
# Removida: sum Fe > -0.28 -> Rayleight scattering > 0.03 (0.1494) | Mantida: Rayleight scattering > 0.03 -> sum Fe > -0.28 (0.2567)
# Removida: sum Fe > 0.07 -> Compton scattering > -0.88 (0.1371) | Mantida: Compton scattering > -0.88 -> sum Fe > 0.07 (0.1544)
# Removida: Al > -0.68 -> Rayleight scattering > -0.25 (0.1293) | Mantida: Rayleight scattering > -0.25 -> Al > -0.68 (0.2581)
# Removida: sum Fe > -0.60 -> Al > -0.68 (0.1376) | Mantida: Al > -0.68 -> sum Fe > -0.60 (0.2924)
# Removida: Rayleight scattering > -0.25 -> Al > -0.19 (0.1100) | Mantida: Al > -0.19 -> Rayleight scattering > -0.25 (0.1189)
# Removida: Rayleight scattering > -0.25 -> Rayleight scattering > 0.03 (0.1079) | Mantida: Rayleight scattering > 0.03 -> Rayleight scattering > -0.25 (0.2607)
# Removida: Rayleight scattering > -0.25 -> P > -0.59 (0.1278) | Mantida: P > -0.59 -> Rayleight scattering > -0.25 (0.1518)
# Removida: sum Fe > -0.60 -> Rayleight scattering > 0.03 (0.1168) | Mantida: Rayleight scattering > 0.03 -> sum Fe > -0.60 (0.2622)
# Removida: Rayleight scattering > 0.03 -> Ca kb > -0.59 (0.1225) | Mantida: Ca kb > -0.59 -> Rayleight scattering > 0.03 (0.1418)
# Removida: Rayleight scattering > -0.50 -> P > -1.23 (0.0823) | Mantida: P > -1.23 -> Rayleight scattering > -0.50 (0.2497)
# Removida: P > 0.08 -> Rayleight scattering > -0.50 (0.1077) | Mantida: Rayleight scattering > -0.50 -> P > 0.08 (0.1286)
# Removida: Al <= 0.62 -> Ti kb > -0.32 (0.1118) | Mantida: Ti kb > -0.32 -> Al <= 0.62 (0.1697)
# Removida: Ti kb > -0.14 -> Ca kb > -0.59 (0.0904) | Mantida: Ca kb > -0.59 -> Ti kb > -0.14 (0.1012)
# Removida: Ti kb > 0.03 -> Ca kb > -0.59 (0.0822) | Mantida: Ca kb > -0.59 -> Ti kb > 0.03 (0.1123)
# Removida: P > 0.08 -> Ca kb > -0.59 (0.1351) | Mantida: Ca kb > -0.59 -> P > 0.08 (0.1419)
# Removida: Ti kb > 0.03 -> Ti kb > -0.32 (0.0828) | Mantida: Ti kb > -0.32 -> Ti kb > 0.03 (0.1585)
# Removida: Ti kb > -0.32 -> background2 > -0.51 (0.0909) | Mantida: background2 > -0.51 -> Ti kb > -0.32 (0.1142)
# Removida: Ti kb > 0.03 -> background2 > -1.35 (0.0817) | Mantida: background2 > -1.35 -> Ti kb > 0.03 (0.0993)
# Removida: Ti kb > -0.14 -> background2 > -0.51 (0.0797) | Mantida: background2 > -0.51 -> Ti kb > -0.14 (0.0830)
# Removida: Ca kb > 0.62 -> background2 > -0.51 (0.0892) | Mantida: background2 > -0.51 -> Ca kb > 0.62 (0.1896)
# Removida: Ti kb > -0.14 -> background2 <= -0.51 (0.1480) | Mantida: background2 <= -0.51 -> Ti kb > -0.14 (0.2091)
# Removida: Ti kb > -0.14 -> background2 > -1.35 (0.0888) | Mantida: background2 > -1.35 -> Ti kb > -0.14 (0.0922)
# Removida: background2 <= -0.51 -> P > -0.59 (0.0683) | Mantida: P > -0.59 -> background2 <= -0.51 (0.1155)
# Removida: S <= 0.55 -> background3 <= -0.62 (0.0633) | Mantida: background3 <= -0.62 -> S <= 0.55 (0.0690)
# Removida: S <= 0.55 -> Compton scattering <= -0.40 (0.0559) | Mantida: Compton scattering <= -0.40 -> S <= 0.55 (0.1302)
# Removida: S <= -0.27 -> S <= 0.55 (0.0302) | Mantida: S <= 0.55 -> S <= -0.27 (0.0566)
# Removida: Ca kb > 0.62 -> P > -0.59 (0.0683) | Mantida: P > -0.59 -> Ca kb > 0.62 (0.1011)
# Removida: Cu <= -0.12 -> Ti ka <= 0.53 (0.0597) | Mantida: Ti ka <= 0.53 -> Cu <= -0.12 (0.1103)
# Removida: P <= 0.08 -> Ti ka <= 0.53 (0.0580) | Mantida: Ti ka <= 0.53 -> P <= 0.08 (0.0609)
# Removida: Ni <= 0.13 -> Ti ka <= 0.53 (0.0507) | Mantida: Ti ka <= 0.53 -> Ni <= 0.13 (0.0648)
# Removida: Ti ka <= 0.53 -> Mn <= 1.01 (0.0750) | Mantida: Mn <= 1.01 -> Ti ka <= 0.53 (0.1172)
# Removida: Cu <= -0.12 -> P <= -0.59 (0.0506) | Mantida: P <= -0.59 -> Cu <= -0.12 (0.0643)
# Removida: background1 > 0.11 -> Rh L + Ar <= -0.77 (0.0138) | Mantida: Rh L + Ar <= -0.77 -> background1 > 0.11 (0.0266)
# Removida: S <= 0.09 -> P <= 0.08 (0.0401) | Mantida: P <= 0.08 -> S <= 0.09 (0.0493)
# Removida: Ni <= -0.14 -> P <= 0.08 (0.0426) | Mantida: P <= 0.08 -> Ni <= -0.14 (0.0447)
# Removida: sum Fe <= -0.28 -> P <= 0.08 (0.0453) | Mantida: P <= 0.08 -> sum Fe <= -0.28 (0.0515)
# Removida: S <= -0.27 -> P <= 0.08 (0.0563) | Mantida: P <= 0.08 -> S <= -0.27 (0.0615)
# Removida: Fe kb <= 0.33 -> Ni <= 0.59 (0.0357) | Mantida: Ni <= 0.59 -> Fe kb <= 0.33 (0.0383)
# Removida: background2 <= 1.51 -> S <= -0.27 (0.0519) | Mantida: S <= -0.27 -> background2 <= 1.51 (0.0553)
# Removida: Cu <= -0.12 -> Compton scattering <= -0.40 (0.0772) | Mantida: Compton scattering <= -0.40 -> Cu <= -0.12 (0.1295)
# Removida: Cu <= -0.12 -> Mn <= 1.01 (0.0457) | Mantida: Mn <= 1.01 -> Cu <= -0.12 (0.0609)
# Removida: Cu <= -0.12 -> Ni <= 0.13 (0.0541) | Mantida: Ni <= 0.13 -> Cu <= -0.12 (0.0645)
# Removida: Mn <= -0.41 -> Mn > -1.22 (0.0158) | Mantida: Mn > -1.22 -> Mn <= -0.41 (0.0468)
# Removida: S > 0.09 -> Fe kb <= -0.63 (0.0112) | Mantida: Fe kb <= -0.63 -> S > 0.09 (0.0126)
# Removida: Ti kb <= 0.20 -> Zn <= 0.10 (0.0168) | Mantida: Zn <= 0.10 -> Ti kb <= 0.20 (0.0412)
# Removida: Ti kb <= 0.20 -> background1 > 0.11 (0.0193) | Mantida: background1 > 0.11 -> Ti kb <= 0.20 (0.0388)
# Removida: Cu <= 0.09 -> Mn <= 1.01 (0.0461) | Mantida: Mn <= 1.01 -> Cu <= 0.09 (0.0520)
# Removida: Al <= 0.19 -> Al <= -0.19 (0.0244) | Mantida: Al <= -0.19 -> Al <= 0.19 (0.0294)
# Removida: Al <= 0.19 -> background1 > 0.11 (0.0185) | Mantida: background1 > 0.11 -> Al <= 0.19 (0.0230)
# Removida: Ni > 0.13 -> Rh L + Ar <= 1.37 (0.0114) | Mantida: Rh L + Ar <= 1.37 -> Ni > 0.13 (0.0199)
# Removida: Ni <= 0.59 -> sum Fe <= -0.28 (0.0189) | Mantida: sum Fe <= -0.28 -> Ni <= 0.59 (0.0425)
# Removida: Ni <= 0.59 -> Mn <= -0.41 (0.0294) | Mantida: Mn <= -0.41 -> Ni <= 0.59 (0.0426)
# Removida: Al > 0.19 -> Ni <= 0.59 (0.0294) | Mantida: Ni <= 0.59 -> Al > 0.19 (0.0373)
# Removida: sum Fe <= -0.28 -> Ni <= -0.14 (0.0324) | Mantida: Ni <= -0.14 -> sum Fe <= -0.28 (0.0709)
# Removida: Ti kb <= 0.03 -> Mn > -0.41 (0.0155) | Mantida: Mn > -0.41 -> Ti kb <= 0.03 (0.0278)
# Removida: Cu > -0.12 -> Mn > -0.41 (0.0112) | Mantida: Mn > -0.41 -> Cu > -0.12 (0.0171)
# Removida: background2 <= 0.35 -> background3 <= -0.62 (0.0465) | Mantida: background3 <= -0.62 -> background2 <= 0.35 (0.1485)
# Removida: Cu > -0.55 -> Rh L + Ar <= 1.37 (0.0249) | Mantida: Rh L + Ar <= 1.37 -> Cu > -0.55 (0.0558)
# Removida: Fe ka <= -2.26 -> Ni > -0.60 (0.0152) | Mantida: Ni > -0.60 -> Fe ka <= -2.26 (0.0190)
# Removida: Ti kb <= 0.03 -> sum Fe <= 0.07 (0.0214) | Mantida: sum Fe <= 0.07 -> Ti kb <= 0.03 (0.0297)
# Removida: background1 <= 0.11 -> background1 <= -0.08 (0.0101) | Mantida: background1 <= -0.08 -> background1 <= 0.11 (0.0189)
# Removida: Cu > -0.12 -> P <= 1.06 (0.0149) | Mantida: P <= 1.06 -> Cu > -0.12 (0.0347)
# Removida: Compton scattering <= 0.05 -> Cu <= 0.56 (0.0101) | Mantida: Cu <= 0.56 -> Compton scattering <= 0.05 (0.0207)
# Removida: background1 > -0.08 -> Fe ka <= -3.05 (0.0073) | Mantida: Fe ka <= -3.05 -> background1 > -0.08 (0.0152)
# Removida: Mn <= 0.23 -> S > -0.27 (0.0152) | Mantida: S > -0.27 -> Mn <= 0.23 (0.0206)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 869 | Removidas: 117
# Nós predicados: 130
# Métrica: Covariance
# Ponderação por variância explicada: ATIVADA
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#     Predicate_Cov_Seed_0 Predicate_Cov_Seed_1          Predicate_Cov_Seed_2  \
# 0          Fe ka > -3.05        Fe ka > -3.05                 Fe ka > -3.74
# 1          Fe ka > -3.74        Fe ka > -3.74                 Fe ka > -3.05
# 2          Fe ka > -2.26        Ca ka <= 3.95                 Fe ka > -2.26
# 3          Ca ka <= 3.95        Fe ka > -2.26                 Ca ka <= 3.95
# 4              K <= 6.26           Si > -2.51                     K > -6.69
# ..                   ...                  ...                           ...
# 127          Si <= -1.67              Class_B                Fe kb <= -0.63
# 128              Class_A                  NaN  Rayleight scattering <= 0.53
# 129              Class_B                  NaN                Fe kb <= -0.44
# 130                  NaN                  NaN                       Class_A
# 131                  NaN                  NaN                       Class_B
#
#            Predicate_Cov_Seed_3
# 0                 Fe ka > -3.05
# 1                 Fe ka > -2.26
# 2                    Si > -2.51
# 3                 Fe ka > -3.74
# 4                 Ca ka <= 3.95
# ..                          ...
# 127                 Si <= -1.67
# 128              sum Fe <= 0.07
# 129  Compton scattering <= 0.87
# 130                     Class_A
# 131                     Class_B
#
# [132 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_cov = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_cov = lrc_summed_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df_cov.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
#lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                             Node  Local_Reaching_Centrality  \
# 0                  Fe ka > -3.05                  13.808155
# 1                  Ca ka <= 3.95                   7.345147
# 2                     Si > -2.51                   6.678307
# 3                      K > -6.69                   5.803163
# 4                  Ti ka > -0.70                   2.647399
# 5                  Fe kb > -0.63                   1.884427
# 6              Rh L + Ar > -1.66                   1.514639
# 7                  Ca kb <= 1.57                   1.454267
# 8             background3 > 0.14                   1.048758
# 9     Compton scattering > -0.40                   1.019011
# 10  Rayleight scattering > -0.25                   0.656406
# 11                    Al > -0.68                   0.633200
# 12                sum Fe > -0.28                   0.608054
# 13                     P > -1.23                   0.573764
# 14                 Ti kb > -0.14                   0.504139
# 15          background2 <= -0.51                   0.499733
# 16                     Mn > 0.23                   0.440488
# 17                     S <= 0.55                   0.377873
# 18                   Cu <= -0.12                   0.349278
# 19                    Ni > -0.14                   0.339258
# 20           background1 > -0.26                   0.313916
# 21                    Zn <= 0.34                   0.298292
# 22                       Class_B                   0.000000
#
#                     Zone Threshold Operator
# 0                  Fe ka     -3.05        >
# 1                  Ca ka      3.95       <=
# 2                     Si     -2.51        >
# 3                      K     -6.69        >
# 4                  Ti ka     -0.70        >
# 5                  Fe kb     -0.63        >
# 6              Rh L + Ar     -1.66        >
# 7                  Ca kb      1.57       <=
# 8            background3      0.14        >
# 9     Compton scattering     -0.40        >
# 10  Rayleight scattering     -0.25        >
# 11                    Al     -0.68        >
# 12                sum Fe     -0.28        >
# 13                     P     -1.23        >
# 14                 Ti kb     -0.14        >
# 15           background2     -0.51       <=
# 16                    Mn      0.23        >
# 17                     S      0.55       <=
# 18                    Cu     -0.12       <=
# 19                    Ni     -0.14        >
# 20           background1     -0.26        >
# 21                    Zn      0.34       <=
# 22                  None      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zones_original = exp.aggregate_spectral_zones_pca(spectral_zones_original) # apca aggregation

# Aplicar o mapeamento
lrc_summed_df_cov_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_cov,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_cov_natural
# Out:
# Zona 'Al': VE = 95.14%, dim = 12 variáveis
# Zona 'Si': VE = 99.71%, dim = 12 variáveis
# Zona 'P': VE = 97.48%, dim = 16 variáveis
# Zona 'S': VE = 93.90%, dim = 15 variáveis
# Zona 'Rh L + Ar': VE = 96.86%, dim = 34 variáveis
# Zona 'K': VE = 99.17%, dim = 19 variáveis
# Zona 'Ca ka': VE = 93.72%, dim = 21 variáveis
# Zona 'Ca kb': VE = 98.07%, dim = 26 variáveis
# Zona 'Ti ka': VE = 98.49%, dim = 15 variáveis
# Zona 'Ti kb': VE = 76.99%, dim = 22 variáveis
# Zona 'background1': VE = 66.94%, dim = 33 variáveis
# Zona 'Mn': VE = 95.57%, dim = 20 variáveis
# Zona 'Fe ka': VE = 99.73%, dim = 34 variáveis
# Zona 'Fe kb': VE = 94.82%, dim = 23 variáveis
# Zona 'Ni': VE = 79.28%, dim = 25 variáveis
# Zona 'Cu': VE = 84.38%, dim = 39 variáveis
# Zona 'Zn': VE = 82.21%, dim = 19 variáveis
# Zona 'background2': VE = 86.54%, dim = 215 variáveis
# Zona 'sum Fe': VE = 88.64%, dim = 27 variáveis
# Zona 'background3': VE = 87.63%, dim = 219 variáveis
# Zona 'Compton scattering': VE = 89.25%, dim = 85 variáveis
# Zona 'Rayleight scattering': VE = 84.72%, dim = 56 variáveis
#                Node  Local_Reaching_Centrality   Zone Threshold Operator  \
# 0     Fe ka > -3.05                  13.808155  Fe ka     -3.05        >
# 1     Fe ka > -3.74                  10.962825  Fe ka     -3.74        >
# 2     Fe ka > -2.26                   7.516280  Fe ka     -2.26        >
# 3     Ca ka <= 3.95                   7.345147  Ca ka      3.95       <=
# 4        Si > -2.51                   6.678307     Si     -2.51        >
# ..              ...                        ...    ...       ...      ...
# 129     Si <= -0.72                   0.241893     Si     -0.72       <=
# 130     Zn <= -0.37                   0.227920     Zn     -0.37       <=
# 131  Fe kb <= -0.44                   0.131883  Fe kb     -0.44       <=
# 132         Class_B                   0.000000   None      None     None
# 133         Class_A                   0.000000   None      None     None
#
#      Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0           -11.993967                   102.0             0.012499
# 1           -14.394181                    68.0             0.017162
# 2            -8.585461                    77.0             0.009247
# 3            24.763583                    89.0             0.045885
# 4            -6.726367                    45.0             0.014243
# ..                 ...                     ...                  ...
# 129          -2.087044                   129.0             0.038926
# 130          -0.825949                    38.0             0.000121
# 131          -1.196874                   106.0             0.000033
# 132                NaN                     NaN                  NaN
# 133                NaN                     NaN                  NaN
#
#            Node_Natural
# 0    Fe ka > -11.993967
# 1    Fe ka > -14.394181
# 2     Fe ka > -8.585461
# 3    Ca ka <= 24.763583
# 4        Si > -6.726367
# ..                  ...
# 129     Si <= -2.087044
# 130     Zn <= -0.825949
# 131  Fe kb <= -1.196874
# 132                None
# 133                None
#
# [134 rows x 9 columns]

# %% [markdown]
# ## Reconstrução de Thresholds Multivariados
#
# Agora vamos pegar os thresholds dos predicados mais importantes e reconstruí-los como espectros completos.

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_cov_natural.iloc[n]['Zone']
threshold_score = float(lrc_summed_df_cov_natural.iloc[n]['Threshold_Natural'])  # Corrigido: usa n em vez de 7

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
print(f"  - Range de energias: {threshold_spectrum.index[0]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_cov_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Fe ka':
#   - Dimensão: 34 variáveis espectrais
#   - Range de energias: 6.1 - 6.76
#   - Variância explicada pela PC1: 99.73%

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_pred_conticted_numeric = pd.Series(y_pred_cont) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_scores_df,
        y_predicted_numeric=y_pred_conticted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=pls_model,
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='median', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='regression',
        metric='mean_abs_diff', 
        verbose=True
    )

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente (sem predicates_df - extraído da regra)
    DG = exp.build_predicate_graphv3_pca(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',
        random_state=seed,
        show_details=True,
        var_exp=True,
        pca_info_dict=pca_info_dict
    )

    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 133 | Descartados: 43
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 132 | Descartados: 44
# ======================================================================
# PERTURBATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Tipo de tarefa (aim): regression
# Modo de perturbação: median
# Fonte das estatísticas: full
# Métrica: mean_abs_diff
# Total de folds: 10
#
#
# [Bag_1] Processando 132 predicados...
#   Predicado: Al > -0.68 (n=87)
#     Zona: 12 colunas
#     Importance: 0.000357
#   Predicado: Al <= -0.19 (n=43)
#     Zona: 12 colunas
#     Importance: 0.000355
#   Predicado: Al > -0.19 (n=65)
#     Zona: 12 colunas
#     Importance: 0.000403
#   Predicado: Al <= 0.19 (n=67)
#     Zona: 12 colunas
#     Importance: 0.000283
#   Predicado: Al > 0.19 (n=41)
#     Zona: 12 colunas
#     Importance: 0.000551
#   Predicado: Al <= 0.62 (n=87)
#     Zona: 12 colunas
#     Importance: 0.000312
#   Predicado: Si > -2.51 (n=83)
#     Zona: 12 colunas
#     Importance: 0.200761
#   Predicado: Si <= -1.67 (n=45)
#     Zona: 12 colunas
#     Importance: 0.100917
#   Predicado: Si > -1.67 (n=63)
#     Zona: 12 colunas
#     Importance: 0.245000
#   Predicado: Si <= -0.72 (n=65)
#     Zona: 12 colunas
#     Importance: 0.074636
#   Predicado: Si > -0.72 (n=43)
#     Zona: 12 colunas
#     Importance: 0.351742
#   Predicado: Si <= 3.71 (n=85)
#     Zona: 12 colunas
#     Importance: 0.106329
#   Predicado: P > -1.23 (n=88)
#     Zona: 16 colunas
#     Importance: 0.005181
#   Predicado: P <= -0.59 (n=42)
#     Zona: 16 colunas
#     Importance: 0.003974
#   Predicado: P > -0.59 (n=66)
#     Zona: 16 colunas
#     Importance: 0.006228
#   Predicado: P <= 0.08 (n=63)
#     Zona: 16 colunas
#     Importance: 0.003234
#   Predicado: P > 0.08 (n=45)
#     Zona: 16 colunas
#     Importance: 0.008316
#   Predicado: P <= 1.06 (n=84)
#     Zona: 16 colunas
#     Importance: 0.003484
#   Predicado: S > -0.55 (n=86)
#     Zona: 15 colunas
#     Importance: 0.003729
#   Predicado: S <= -0.27 (n=43)
#     Zona: 15 colunas
#     Importance: 0.003642
#   Predicado: S > -0.27 (n=65)
#     Zona: 15 colunas
#     Importance: 0.004274
#   Predicado: S <= 0.09 (n=62)
#     Zona: 15 colunas
#     Importance: 0.002738
#   Predicado: S > 0.09 (n=46)
#     Zona: 15 colunas
#     Importance: 0.005752
#   Predicado: S <= 0.55 (n=84)
#     Zona: 15 colunas
#     Importance: 0.002832
#   Predicado: Rh L + Ar > -1.66 (n=90)
#     Zona: 34 colunas
#     Importance: 0.022425
#   Predicado: Rh L + Ar <= -0.77 (n=37)
#     Zona: 34 colunas
#     Importance: 0.021767
#   Predicado: Rh L + Ar > -0.77 (n=71)
#     Zona: 34 colunas
#     Importance: 0.024973
#   Predicado: Rh L + Ar <= -0.16 (n=63)
#     Zona: 34 colunas
#     Importance: 0.014046
#   Predicado: Rh L + Ar > -0.16 (n=45)
#     Zona: 34 colunas
#     Importance: 0.037634
#   Predicado: Rh L + Ar <= 1.37 (n=89)
#     Zona: 34 colunas
#     Importance: 0.014850
#   Predicado: K > -6.69 (n=87)
#     Zona: 19 colunas
#     Importance: 0.011474
#   Predicado: K <= -1.46 (n=42)
#     Zona: 19 colunas
#     Importance: 0.015322
#   Predicado: K > -1.46 (n=66)
#     Zona: 19 colunas
#     Importance: 0.012206
#   Predicado: K <= 2.15 (n=66)
#     Zona: 19 colunas
#     Importance: 0.012772
#   Predicado: K > 2.15 (n=42)
#     Zona: 19 colunas
#     Importance: 0.014432
#   Predicado: K <= 6.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.011676
#   Predicado: Ca ka > -4.65 (n=86)
#     Zona: 21 colunas
#     Importance: 0.138840
#   Predicado: Ca ka <= -1.50 (n=44)
#     Zona: 21 colunas
#     Importance: 0.195041
#   Predicado: Ca ka > -1.50 (n=64)
#     Zona: 21 colunas
#     Importance: 0.139570
#   Predicado: Ca ka <= 1.77 (n=67)
#     Zona: 21 colunas
#     Importance: 0.143454
#   Predicado: Ca ka > 1.77 (n=41)
#     Zona: 21 colunas
#     Importance: 0.192754
#   Predicado: Ca ka <= 3.95 (n=87)
#     Zona: 21 colunas
#     Importance: 0.133382
#   Predicado: Ca kb > -1.81 (n=86)
#     Zona: 26 colunas
#     Importance: 0.021911
#   Predicado: Ca kb <= -0.59 (n=45)
#     Zona: 26 colunas
#     Importance: 0.032699
#   Predicado: Ca kb > -0.59 (n=63)
#     Zona: 26 colunas
#     Importance: 0.021776
#   Predicado: Ca kb <= 0.62 (n=66)
#     Zona: 26 colunas
#     Importance: 0.023873
#   Predicado: Ca kb > 0.62 (n=42)
#     Zona: 26 colunas
#     Importance: 0.030184
#   Predicado: Ca kb <= 1.57 (n=87)
#     Zona: 26 colunas
#     Importance: 0.021721
#   Predicado: Ti ka > -0.86 (n=87)
#     Zona: 15 colunas
#     Importance: 0.003964
#   Predicado: Ti ka <= -0.70 (n=44)
#     Zona: 15 colunas
#     Importance: 0.001505
#   Predicado: Ti ka > -0.70 (n=64)
#     Zona: 15 colunas
#     Importance: 0.005080
#   Predicado: Ti ka <= -0.52 (n=63)
#     Zona: 15 colunas
#     Importance: 0.001133
#   Predicado: Ti ka > -0.52 (n=45)
#     Zona: 15 colunas
#     Importance: 0.007111
#   Predicado: Ti ka <= 0.53 (n=87)
#     Zona: 15 colunas
#     Importance: 0.001334
#   Predicado: Ti kb > -0.32 (n=88)
#     Zona: 22 colunas
#     Importance: 0.000893
#   Predicado: Ti kb <= -0.14 (n=45)
#     Zona: 22 colunas
#     Importance: 0.001063
#   Predicado: Ti kb > -0.14 (n=63)
#     Zona: 22 colunas
#     Importance: 0.001017
#   Predicado: Ti kb <= 0.03 (n=66)
#     Zona: 22 colunas
#     Importance: 0.000791
#   Predicado: Ti kb > 0.03 (n=42)
#     Zona: 22 colunas
#     Importance: 0.001422
#   Predicado: Ti kb <= 0.20 (n=86)
#     Zona: 22 colunas
#     Importance: 0.000760
#   Predicado: background1 > -0.26 (n=90)
#     Zona: 33 colunas
#     Importance: 0.000458
#   Predicado: background1 <= -0.08 (n=43)
#     Zona: 33 colunas
#     Importance: 0.000735
#   Predicado: background1 > -0.08 (n=65)
#     Zona: 33 colunas
#     Importance: 0.000482
#   Predicado: background1 <= 0.11 (n=70)
#     Zona: 33 colunas
#     Importance: 0.000503
#   Predicado: background1 > 0.11 (n=38)
#     Zona: 33 colunas
#     Importance: 0.000731
#   Predicado: background1 <= 0.30 (n=91)
#     Zona: 33 colunas
#     Importance: 0.000486
#   Predicado: Mn > -1.22 (n=88)
#     Zona: 20 colunas
#     Importance: 0.004110
#   Predicado: Mn <= -0.41 (n=43)
#     Zona: 20 colunas
#     Importance: 0.005210
#   Predicado: Mn > -0.41 (n=65)
#     Zona: 20 colunas
#     Importance: 0.004529
#   Predicado: Mn <= 0.23 (n=67)
#     Zona: 20 colunas
#     Importance: 0.003650
#   Predicado: Mn > 0.23 (n=41)
#     Zona: 20 colunas
#     Importance: 0.006681
#   Predicado: Mn <= 1.01 (n=90)
#     Zona: 20 colunas
#     Importance: 0.003742
#   Predicado: Fe ka > -3.74 (n=86)
#     Zona: 34 colunas
#     Importance: 0.012418
#   Predicado: Fe ka <= -3.05 (n=44)
#     Zona: 34 colunas
#     Importance: 0.004048
#   Predicado: Fe ka > -3.05 (n=64)
#     Zona: 34 colunas
#     Importance: 0.015935
#   Predicado: Fe ka <= -2.26 (n=63)
#     Zona: 34 colunas
#     Importance: 0.003064
#   Predicado: Fe ka > -2.26 (n=45)
#     Zona: 34 colunas
#     Importance: 0.022332
#   Predicado: Fe ka <= 1.10 (n=87)
#     Zona: 34 colunas
#     Importance: 0.003635
#   Predicado: Fe kb > -0.91 (n=87)
#     Zona: 23 colunas
#     Importance: 0.000231
#   Predicado: Fe kb <= -0.63 (n=41)
#     Zona: 23 colunas
#     Importance: 0.000140
#   Predicado: Fe kb > -0.63 (n=67)
#     Zona: 23 colunas
#     Importance: 0.000267
#   Predicado: Fe kb <= -0.44 (n=66)
#     Zona: 23 colunas
#     Importance: 0.000125
#   Predicado: Fe kb > -0.44 (n=42)
#     Zona: 23 colunas
#     Importance: 0.000367
#   Predicado: Fe kb <= 0.33 (n=87)
#     Zona: 23 colunas
#     Importance: 0.000129
#   Predicado: Ni > -0.60 (n=88)
#     Zona: 25 colunas
#     Importance: 0.001473
#   Predicado: Ni <= -0.14 (n=44)
#     Zona: 25 colunas
#     Importance: 0.001563
#   Predicado: Ni > -0.14 (n=64)
#     Zona: 25 colunas
#     Importance: 0.001487
#   Predicado: Ni <= 0.13 (n=64)
#     Zona: 25 colunas
#     Importance: 0.001489
#   Predicado: Ni > 0.13 (n=44)
#     Zona: 25 colunas
#     Importance: 0.001561
#   Predicado: Ni <= 0.59 (n=90)
#     Zona: 25 colunas
#     Importance: 0.001521
#   Predicado: Cu > -0.55 (n=89)
#     Zona: 39 colunas
#     Importance: 0.000209
#   Predicado: Cu <= -0.12 (n=44)
#     Zona: 39 colunas
#     Importance: 0.000300
#   Predicado: Cu > -0.12 (n=64)
#     Zona: 39 colunas
#     Importance: 0.000226
#   Predicado: Cu <= 0.09 (n=64)
#     Zona: 39 colunas
#     Importance: 0.000238
#   Predicado: Cu > 0.09 (n=44)
#     Zona: 39 colunas
#     Importance: 0.000283
#   Predicado: Cu <= 0.56 (n=92)
#     Zona: 39 colunas
#     Importance: 0.000222
#   Predicado: Zn > -0.37 (n=87)
#     Zona: 19 colunas
#     Importance: 0.000578
#   Predicado: Zn <= -0.11 (n=41)
#     Zona: 19 colunas
#     Importance: 0.000951
#   Predicado: Zn > -0.11 (n=67)
#     Zona: 19 colunas
#     Importance: 0.000598
#   Predicado: Zn <= 0.10 (n=66)
#     Zona: 19 colunas
#     Importance: 0.000651
#   Predicado: Zn > 0.10 (n=42)
#     Zona: 19 colunas
#     Importance: 0.000859
#   Predicado: Zn <= 0.34 (n=90)
#     Zona: 19 colunas
#     Importance: 0.000601
#   Predicado: background2 > -1.35 (n=88)
#     Zona: 215 colunas
#     Importance: 0.001034
#   Predicado: background2 <= -0.51 (n=45)
#     Zona: 215 colunas
#     Importance: 0.001288
#   Predicado: background2 > -0.51 (n=63)
#     Zona: 215 colunas
#     Importance: 0.001137
#   Predicado: background2 <= 0.35 (n=67)
#     Zona: 215 colunas
#     Importance: 0.000940
#   Predicado: background2 > 0.35 (n=41)
#     Zona: 215 colunas
#     Importance: 0.001624
#   Predicado: background2 <= 1.51 (n=89)
#     Zona: 215 colunas
#     Importance: 0.000912
#   Predicado: sum Fe > -0.60 (n=89)
#     Zona: 27 colunas
#     Importance: 0.000790
#   Predicado: sum Fe <= -0.28 (n=44)
#     Zona: 27 colunas
#     Importance: 0.000909
#   Predicado: sum Fe > -0.28 (n=64)
#     Zona: 27 colunas
#     Importance: 0.000911
#   Predicado: sum Fe <= 0.07 (n=69)
#     Zona: 27 colunas
#     Importance: 0.000624
#   Predicado: sum Fe > 0.07 (n=39)
#     Zona: 27 colunas
#     Importance: 0.001417
#   Predicado: sum Fe <= 0.62 (n=89)
#     Zona: 27 colunas
#     Importance: 0.000617
#   Predicado: background3 > -1.28 (n=88)
#     Zona: 219 colunas
#     Importance: 0.002293
#   Predicado: background3 <= -0.62 (n=42)
#     Zona: 219 colunas
#     Importance: 0.003164
#   Predicado: background3 > -0.62 (n=66)
#     Zona: 219 colunas
#     Importance: 0.002540
#   Predicado: background3 <= 0.14 (n=67)
#     Zona: 219 colunas
#     Importance: 0.002157
#   Predicado: background3 > 0.14 (n=41)
#     Zona: 219 colunas
#     Importance: 0.003805
#   Predicado: background3 <= 1.47 (n=90)
#     Zona: 219 colunas
#     Importance: 0.002018
#   Predicado: Compton scattering > -0.88 (n=86)
#     Zona: 85 colunas
#     Importance: 0.001893
#   Predicado: Compton scattering <= -0.40 (n=42)
#     Zona: 85 colunas
#     Importance: 0.002228
#   Predicado: Compton scattering > -0.40 (n=66)
#     Zona: 85 colunas
#     Importance: 0.002092
#   Predicado: Compton scattering <= 0.05 (n=68)
#     Zona: 85 colunas
#     Importance: 0.001728
#   Predicado: Compton scattering > 0.05 (n=40)
#     Zona: 85 colunas
#     Importance: 0.002853
#   Predicado: Compton scattering <= 0.87 (n=88)
#     Zona: 85 colunas
#     Importance: 0.001713
#   Predicado: Rayleight scattering > -0.50 (n=86)
#     Zona: 56 colunas
#     Importance: 0.000469
#   Predicado: Rayleight scattering <= -0.25 (n=43)
#     Zona: 56 colunas
#     Importance: 0.000572
#   Predicado: Rayleight scattering > -0.25 (n=65)
#     Zona: 56 colunas
#     Importance: 0.000521
#   Predicado: Rayleight scattering <= 0.03 (n=67)
#     Zona: 56 colunas
#     Importance: 0.000434
#   Predicado: Rayleight scattering > 0.03 (n=41)
#     Zona: 56 colunas
#     Importance: 0.000717
#   Predicado: Rayleight scattering <= 0.53 (n=89)
#     Zona: 56 colunas
#     Importance: 0.000408
#
# [Bag_2] Processando 132 predicados...
#   Predicado: Al > -0.68 (n=84)
#     Zona: 12 colunas
#     Importance: 0.000364
#   Predicado: Al <= -0.19 (n=46)
#     Zona: 12 colunas
#     Importance: 0.000361
#   Predicado: Al > -0.19 (n=62)
#     Zona: 12 colunas
#     Importance: 0.000415
#   Predicado: Al <= 0.19 (n=66)
#     Zona: 12 colunas
#     Importance: 0.000291
#   Predicado: Al > 0.19 (n=42)
#     Zona: 12 colunas
#     Importance: 0.000552
#   Predicado: Al <= 0.62 (n=86)
#     Zona: 12 colunas
#     Importance: 0.000322
#   Predicado: Si > -2.51 (n=83)
#     Zona: 12 colunas
#     Importance: 0.187864
#   Predicado: Si <= -1.67 (n=47)
#     Zona: 12 colunas
#     Importance: 0.100169
#   Predicado: Si > -1.67 (n=61)
#     Zona: 12 colunas
#     Importance: 0.233085
#   Predicado: Si <= -0.72 (n=68)
#     Zona: 12 colunas
#     Importance: 0.073492
#   Predicado: Si > -0.72 (n=40)
#     Zona: 12 colunas
#     Importance: 0.348216
#   Predicado: Si <= 3.71 (n=87)
#     Zona: 12 colunas
#     Importance: 0.098073
#   Predicado: P > -1.23 (n=84)
#     Zona: 16 colunas
#     Importance: 0.005049
#   Predicado: P <= -0.59 (n=44)
#     Zona: 16 colunas
#     Importance: 0.004382
#   Predicado: P > -0.59 (n=64)
#     Zona: 16 colunas
#     Importance: 0.005897
#   Predicado: P <= 0.08 (n=65)
#     Zona: 16 colunas
#     Importance: 0.003494
#   Predicado: P > 0.08 (n=43)
#     Zona: 16 colunas
#     Importance: 0.007980
#   Predicado: P <= 1.06 (n=87)
#     Zona: 16 colunas
#     Importance: 0.003594
#   Predicado: S > -0.55 (n=87)
#     Zona: 15 colunas
#     Importance: 0.003451
#   Predicado: S <= -0.27 (n=44)
#     Zona: 15 colunas
#     Importance: 0.003467
#   Predicado: S > -0.27 (n=64)
#     Zona: 15 colunas
#     Importance: 0.003941
#   Predicado: S <= 0.09 (n=66)
#     Zona: 15 colunas
#     Importance: 0.002547
#   Predicado: S > 0.09 (n=42)
#     Zona: 15 colunas
#     Importance: 0.005635
#   Predicado: S <= 0.55 (n=87)
#     Zona: 15 colunas
#     Importance: 0.002676
#   Predicado: Rh L + Ar > -1.66 (n=88)
#     Zona: 34 colunas
#     Importance: 0.020795
#   Predicado: Rh L + Ar <= -0.77 (n=42)
#     Zona: 34 colunas
#     Importance: 0.021019
#   Predicado: Rh L + Ar > -0.77 (n=66)
#     Zona: 34 colunas
#     Importance: 0.023255
#   Predicado: Rh L + Ar <= -0.16 (n=67)
#     Zona: 34 colunas
#     Importance: 0.014375
#   Predicado: Rh L + Ar > -0.16 (n=41)
#     Zona: 34 colunas
#     Importance: 0.035476
#   Predicado: Rh L + Ar <= 1.37 (n=90)
#     Zona: 34 colunas
#     Importance: 0.015073
#   Predicado: K > -6.69 (n=85)
#     Zona: 19 colunas
#     Importance: 0.011883
#   Predicado: K <= -1.46 (n=45)
#     Zona: 19 colunas
#     Importance: 0.016245
#   Predicado: K > -1.46 (n=63)
#     Zona: 19 colunas
#     Importance: 0.012456
#   Predicado: K <= 2.15 (n=64)
#     Zona: 19 colunas
#     Importance: 0.013501
#   Predicado: K > 2.15 (n=44)
#     Zona: 19 colunas
#     Importance: 0.014810
#   Predicado: K <= 6.26 (n=87)
#     Zona: 19 colunas
#     Importance: 0.011976
#   Predicado: Ca ka > -4.65 (n=89)
#     Zona: 21 colunas
#     Importance: 0.131703
#   Predicado: Ca ka <= -1.50 (n=41)
#     Zona: 21 colunas
#     Importance: 0.194156
#   Predicado: Ca ka > -1.50 (n=67)
#     Zona: 21 colunas
#     Importance: 0.129169
#   Predicado: Ca ka <= 1.77 (n=67)
#     Zona: 21 colunas
#     Importance: 0.135602
#   Predicado: Ca ka > 1.77 (n=41)
#     Zona: 21 colunas
#     Importance: 0.183644
#   Predicado: Ca ka <= 3.95 (n=87)
#     Zona: 21 colunas
#     Importance: 0.126830
#   Predicado: Ca kb > -1.81 (n=89)
#     Zona: 26 colunas
#     Importance: 0.021314
#   Predicado: Ca kb <= -0.59 (n=41)
#     Zona: 26 colunas
#     Importance: 0.033298
#   Predicado: Ca kb > -0.59 (n=67)
#     Zona: 26 colunas
#     Importance: 0.020527
#   Predicado: Ca kb <= 0.62 (n=66)
#     Zona: 26 colunas
#     Importance: 0.022773
#   Predicado: Ca kb > 0.62 (n=42)
#     Zona: 26 colunas
#     Importance: 0.029465
#   Predicado: Ca kb <= 1.57 (n=87)
#     Zona: 26 colunas
#     Importance: 0.020953
#   Predicado: Ti ka > -0.86 (n=84)
#     Zona: 15 colunas
#     Importance: 0.004084
#   Predicado: Ti ka <= -0.70 (n=45)
#     Zona: 15 colunas
#     Importance: 0.001594
#   Predicado: Ti ka > -0.70 (n=63)
#     Zona: 15 colunas
#     Importance: 0.005146
#   Predicado: Ti ka <= -0.52 (n=67)
#     Zona: 15 colunas
#     Importance: 0.001162
#   Predicado: Ti ka > -0.52 (n=41)
#     Zona: 15 colunas
#     Importance: 0.007757
#   Predicado: Ti ka <= 0.53 (n=88)
#     Zona: 15 colunas
#     Importance: 0.001273
#   Predicado: Ti kb > -0.32 (n=84)
#     Zona: 22 colunas
#     Importance: 0.000940
#   Predicado: Ti kb <= -0.14 (n=44)
#     Zona: 22 colunas
#     Importance: 0.001167
#   Predicado: Ti kb > -0.14 (n=64)
#     Zona: 22 colunas
#     Importance: 0.001052
#   Predicado: Ti kb <= 0.03 (n=65)
#     Zona: 22 colunas
#     Importance: 0.000856
#   Predicado: Ti kb > 0.03 (n=43)
#     Zona: 22 colunas
#     Importance: 0.001466
#   Predicado: Ti kb <= 0.20 (n=86)
#     Zona: 22 colunas
#     Importance: 0.000810
#   Predicado: background1 > -0.26 (n=89)
#     Zona: 33 colunas
#     Importance: 0.000527
#   Predicado: background1 <= -0.08 (n=44)
#     Zona: 33 colunas
#     Importance: 0.000766
#   Predicado: background1 > -0.08 (n=64)
#     Zona: 33 colunas
#     Importance: 0.000577
#   Predicado: background1 <= 0.11 (n=65)
#     Zona: 33 colunas
#     Importance: 0.000561
#   Predicado: background1 > 0.11 (n=43)
#     Zona: 33 colunas
#     Importance: 0.000794
#   Predicado: background1 <= 0.30 (n=84)
#     Zona: 33 colunas
#     Importance: 0.000534
#   Predicado: Mn > -1.22 (n=85)
#     Zona: 20 colunas
#     Importance: 0.004664
#   Predicado: Mn <= -0.41 (n=42)
#     Zona: 20 colunas
#     Importance: 0.005865
#   Predicado: Mn > -0.41 (n=66)
#     Zona: 20 colunas
#     Importance: 0.005098
#   Predicado: Mn <= 0.23 (n=66)
#     Zona: 20 colunas
#     Importance: 0.004038
#   Predicado: Mn > 0.23 (n=42)
#     Zona: 20 colunas
#     Importance: 0.007531
#   Predicado: Mn <= 1.01 (n=86)
#     Zona: 20 colunas
#     Importance: 0.004056
#   Predicado: Fe ka > -3.74 (n=85)
#     Zona: 34 colunas
#     Importance: 0.012568
#   Predicado: Fe ka <= -3.05 (n=45)
#     Zona: 34 colunas
#     Importance: 0.004136
#   Predicado: Fe ka > -3.05 (n=63)
#     Zona: 34 colunas
#     Importance: 0.016214
#   Predicado: Fe ka <= -2.26 (n=68)
#     Zona: 34 colunas
#     Importance: 0.003006
#   Predicado: Fe ka > -2.26 (n=40)
#     Zona: 34 colunas
#     Importance: 0.025080
#   Predicado: Fe ka <= 1.10 (n=89)
#     Zona: 34 colunas
#     Importance: 0.003499
#   Predicado: Fe kb > -0.91 (n=87)
#     Zona: 23 colunas
#     Importance: 0.000241
#   Predicado: Fe kb <= -0.63 (n=41)
#     Zona: 23 colunas
#     Importance: 0.000147
#   Predicado: Fe kb > -0.63 (n=67)
#     Zona: 23 colunas
#     Importance: 0.000275
#   Predicado: Fe kb <= -0.44 (n=64)
#     Zona: 23 colunas
#     Importance: 0.000132
#   Predicado: Fe kb > -0.44 (n=44)
#     Zona: 23 colunas
#     Importance: 0.000365
#   Predicado: Fe kb <= 0.33 (n=89)
#     Zona: 23 colunas
#     Importance: 0.000133
#   Predicado: Ni > -0.60 (n=87)
#     Zona: 25 colunas
#     Importance: 0.001474
#   Predicado: Ni <= -0.14 (n=42)
#     Zona: 25 colunas
#     Importance: 0.001604
#   Predicado: Ni > -0.14 (n=66)
#     Zona: 25 colunas
#     Importance: 0.001472
#   Predicado: Ni <= 0.13 (n=62)
#     Zona: 25 colunas
#     Importance: 0.001484
#   Predicado: Ni > 0.13 (n=46)
#     Zona: 25 colunas
#     Importance: 0.001577
#   Predicado: Ni <= 0.59 (n=86)
#     Zona: 25 colunas
#     Importance: 0.001485
#   Predicado: Cu > -0.55 (n=88)
#     Zona: 39 colunas
#     Importance: 0.000219
#   Predicado: Cu <= -0.12 (n=41)
#     Zona: 39 colunas
#     Importance: 0.000305
#   Predicado: Cu > -0.12 (n=67)
#     Zona: 39 colunas
#     Importance: 0.000239
#   Predicado: Cu <= 0.09 (n=61)
#     Zona: 39 colunas
#     Importance: 0.000236
#   Predicado: Cu > 0.09 (n=47)
#     Zona: 39 colunas
#     Importance: 0.000300
#   Predicado: Cu <= 0.56 (n=87)
#     Zona: 39 colunas
#     Importance: 0.000216
#   Predicado: Zn > -0.37 (n=87)
#     Zona: 19 colunas
#     Importance: 0.000632
#   Predicado: Zn <= -0.11 (n=42)
#     Zona: 19 colunas
#     Importance: 0.000970
#   Predicado: Zn > -0.11 (n=66)
#     Zona: 19 colunas
#     Importance: 0.000677
#   Predicado: Zn <= 0.10 (n=62)
#     Zona: 19 colunas
#     Importance: 0.000710
#   Predicado: Zn > 0.10 (n=46)
#     Zona: 19 colunas
#     Importance: 0.000900
#   Predicado: Zn <= 0.34 (n=87)
#     Zona: 19 colunas
#     Importance: 0.000631
#   Predicado: background2 > -1.35 (n=88)
#     Zona: 215 colunas
#     Importance: 0.001100
#   Predicado: background2 <= -0.51 (n=41)
#     Zona: 215 colunas
#     Importance: 0.001404
#   Predicado: background2 > -0.51 (n=67)
#     Zona: 215 colunas
#     Importance: 0.001175
#   Predicado: background2 <= 0.35 (n=63)
#     Zona: 215 colunas
#     Importance: 0.001020
#   Predicado: background2 > 0.35 (n=45)
#     Zona: 215 colunas
#     Importance: 0.001602
#   Predicado: background2 <= 1.51 (n=85)
#     Zona: 215 colunas
#     Importance: 0.000959
#   Predicado: sum Fe > -0.60 (n=87)
#     Zona: 27 colunas
#     Importance: 0.000797
#   Predicado: sum Fe <= -0.28 (n=40)
#     Zona: 27 colunas
#     Importance: 0.000970
#   Predicado: sum Fe > -0.28 (n=68)
#     Zona: 27 colunas
#     Importance: 0.000882
#   Predicado: sum Fe <= 0.07 (n=62)
#     Zona: 27 colunas
#     Importance: 0.000671
#   Predicado: sum Fe > 0.07 (n=46)
#     Zona: 27 colunas
#     Importance: 0.001242
#   Predicado: sum Fe <= 0.62 (n=86)
#     Zona: 27 colunas
#     Importance: 0.000653
#   Predicado: background3 > -1.28 (n=88)
#     Zona: 219 colunas
#     Importance: 0.002380
#   Predicado: background3 <= -0.62 (n=40)
#     Zona: 219 colunas
#     Importance: 0.003002
#   Predicado: background3 > -0.62 (n=68)
#     Zona: 219 colunas
#     Importance: 0.002686
#   Predicado: background3 <= 0.14 (n=61)
#     Zona: 219 colunas
#     Importance: 0.002129
#   Predicado: background3 > 0.14 (n=47)
#     Zona: 219 colunas
#     Importance: 0.003679
#   Predicado: background3 <= 1.47 (n=86)
#     Zona: 219 colunas
#     Importance: 0.001997
#   Predicado: Compton scattering > -0.88 (n=89)
#     Zona: 85 colunas
#     Importance: 0.001921
#   Predicado: Compton scattering <= -0.40 (n=40)
#     Zona: 85 colunas
#     Importance: 0.002135
#   Predicado: Compton scattering > -0.40 (n=68)
#     Zona: 85 colunas
#     Importance: 0.002139
#   Predicado: Compton scattering <= 0.05 (n=61)
#     Zona: 85 colunas
#     Importance: 0.001708
#   Predicado: Compton scattering > 0.05 (n=47)
#     Zona: 85 colunas
#     Importance: 0.002696
#   Predicado: Compton scattering <= 0.87 (n=87)
#     Zona: 85 colunas
#     Importance: 0.001699
#   Predicado: Rayleight scattering > -0.50 (n=89)
#     Zona: 56 colunas
#     Importance: 0.000460
#   Predicado: Rayleight scattering <= -0.25 (n=40)
#     Zona: 56 colunas
#     Importance: 0.000536
#   Predicado: Rayleight scattering > -0.25 (n=68)
#     Zona: 56 colunas
#     Importance: 0.000516
#   Predicado: Rayleight scattering <= 0.03 (n=60)
#     Zona: 56 colunas
#     Importance: 0.000418
#   Predicado: Rayleight scattering > 0.03 (n=48)
#     Zona: 56 colunas
#     Importance: 0.000655
#   Predicado: Rayleight scattering <= 0.53 (n=86)
#     Zona: 56 colunas
#     Importance: 0.000393
#
# [Bag_3] Processando 132 predicados...
#   Predicado: Al > -0.68 (n=86)
#     Zona: 12 colunas
#     Importance: 0.000356
#   Predicado: Al <= -0.19 (n=45)
#     Zona: 12 colunas
#     Importance: 0.000360
#   Predicado: Al > -0.19 (n=63)
#     Zona: 12 colunas
#     Importance: 0.000406
#   Predicado: Al <= 0.19 (n=68)
#     Zona: 12 colunas
#     Importance: 0.000285
#   Predicado: Al > 0.19 (n=40)
#     Zona: 12 colunas
#     Importance: 0.000559
#   Predicado: Al <= 0.62 (n=86)
#     Zona: 12 colunas
#     Importance: 0.000312
#   Predicado: Si > -2.51 (n=89)
#     Zona: 12 colunas
#     Importance: 0.179299
#   Predicado: Si <= -1.67 (n=44)
#     Zona: 12 colunas
#     Importance: 0.093521
#   Predicado: Si > -1.67 (n=64)
#     Zona: 12 colunas
#     Importance: 0.223780
#   Predicado: Si <= -0.72 (n=68)
#     Zona: 12 colunas
#     Importance: 0.065495
#   Predicado: Si > -0.72 (n=40)
#     Zona: 12 colunas
#     Importance: 0.349579
#   Predicado: Si <= 3.71 (n=87)
#     Zona: 12 colunas
#     Importance: 0.096042
#   Predicado: P > -1.23 (n=85)
#     Zona: 16 colunas
#     Importance: 0.004401
#   Predicado: P <= -0.59 (n=46)
#     Zona: 16 colunas
#     Importance: 0.004105
#   Predicado: P > -0.59 (n=62)
#     Zona: 16 colunas
#     Importance: 0.005241
#   Predicado: P <= 0.08 (n=66)
#     Zona: 16 colunas
#     Importance: 0.003241
#   Predicado: P > 0.08 (n=42)
#     Zona: 16 colunas
#     Importance: 0.007138
#   Predicado: P <= 1.06 (n=90)
#     Zona: 16 colunas
#     Importance: 0.003508
#   Predicado: S > -0.55 (n=88)
#     Zona: 15 colunas
#     Importance: 0.003522
#   Predicado: S <= -0.27 (n=46)
#     Zona: 15 colunas
#     Importance: 0.003492
#   Predicado: S > -0.27 (n=62)
#     Zona: 15 colunas
#     Importance: 0.004148
#   Predicado: S <= 0.09 (n=64)
#     Zona: 15 colunas
#     Importance: 0.002697
#   Predicado: S > 0.09 (n=44)
#     Zona: 15 colunas
#     Importance: 0.005573
#   Predicado: S <= 0.55 (n=87)
#     Zona: 15 colunas
#     Importance: 0.002803
#   Predicado: Rh L + Ar > -1.66 (n=85)
#     Zona: 34 colunas
#     Importance: 0.023411
#   Predicado: Rh L + Ar <= -0.77 (n=45)
#     Zona: 34 colunas
#     Importance: 0.021567
#   Predicado: Rh L + Ar > -0.77 (n=63)
#     Zona: 34 colunas
#     Importance: 0.026892
#   Predicado: Rh L + Ar <= -0.16 (n=64)
#     Zona: 34 colunas
#     Importance: 0.016014
#   Predicado: Rh L + Ar > -0.16 (n=44)
#     Zona: 34 colunas
#     Importance: 0.037269
#   Predicado: Rh L + Ar <= 1.37 (n=88)
#     Zona: 34 colunas
#     Importance: 0.016233
#   Predicado: K > -6.69 (n=86)
#     Zona: 19 colunas
#     Importance: 0.011541
#   Predicado: K <= -1.46 (n=45)
#     Zona: 19 colunas
#     Importance: 0.016252
#   Predicado: K > -1.46 (n=63)
#     Zona: 19 colunas
#     Importance: 0.012194
#   Predicado: K <= 2.15 (n=68)
#     Zona: 19 colunas
#     Importance: 0.013603
#   Predicado: K > 2.15 (n=40)
#     Zona: 19 colunas
#     Importance: 0.014364
#   Predicado: K <= 6.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.011891
#   Predicado: Ca ka > -4.65 (n=87)
#     Zona: 21 colunas
#     Importance: 0.133757
#   Predicado: Ca ka <= -1.50 (n=41)
#     Zona: 21 colunas
#     Importance: 0.196537
#   Predicado: Ca ka > -1.50 (n=67)
#     Zona: 21 colunas
#     Importance: 0.132036
#   Predicado: Ca ka <= 1.77 (n=66)
#     Zona: 21 colunas
#     Importance: 0.138289
#   Predicado: Ca ka > 1.77 (n=42)
#     Zona: 21 colunas
#     Importance: 0.185175
#   Predicado: Ca ka <= 3.95 (n=86)
#     Zona: 21 colunas
#     Importance: 0.129780
#   Predicado: Ca kb > -1.81 (n=87)
#     Zona: 26 colunas
#     Importance: 0.021725
#   Predicado: Ca kb <= -0.59 (n=42)
#     Zona: 26 colunas
#     Importance: 0.033096
#   Predicado: Ca kb > -0.59 (n=66)
#     Zona: 26 colunas
#     Importance: 0.021358
#   Predicado: Ca kb <= 0.62 (n=66)
#     Zona: 26 colunas
#     Importance: 0.023058
#   Predicado: Ca kb > 0.62 (n=42)
#     Zona: 26 colunas
#     Importance: 0.030424
#   Predicado: Ca kb <= 1.57 (n=86)
#     Zona: 26 colunas
#     Importance: 0.021519
#   Predicado: Ti ka > -0.86 (n=89)
#     Zona: 15 colunas
#     Importance: 0.003982
#   Predicado: Ti ka <= -0.70 (n=43)
#     Zona: 15 colunas
#     Importance: 0.001411
#   Predicado: Ti ka > -0.70 (n=65)
#     Zona: 15 colunas
#     Importance: 0.005121
#   Predicado: Ti ka <= -0.52 (n=66)
#     Zona: 15 colunas
#     Importance: 0.001007
#   Predicado: Ti ka > -0.52 (n=42)
#     Zona: 15 colunas
#     Importance: 0.007788
#   Predicado: Ti ka <= 0.53 (n=86)
#     Zona: 15 colunas
#     Importance: 0.001149
#   Predicado: Ti kb > -0.32 (n=88)
#     Zona: 22 colunas
#     Importance: 0.000942
#   Predicado: Ti kb <= -0.14 (n=43)
#     Zona: 22 colunas
#     Importance: 0.000969
#   Predicado: Ti kb > -0.14 (n=65)
#     Zona: 22 colunas
#     Importance: 0.001074
#   Predicado: Ti kb <= 0.03 (n=65)
#     Zona: 22 colunas
#     Importance: 0.000713
#   Predicado: Ti kb > 0.03 (n=43)
#     Zona: 22 colunas
#     Importance: 0.001514
#   Predicado: Ti kb <= 0.20 (n=85)
#     Zona: 22 colunas
#     Importance: 0.000703
#   Predicado: background1 > -0.26 (n=89)
#     Zona: 33 colunas
#     Importance: 0.000513
#   Predicado: background1 <= -0.08 (n=42)
#     Zona: 33 colunas
#     Importance: 0.000672
#   Predicado: background1 > -0.08 (n=66)
#     Zona: 33 colunas
#     Importance: 0.000559
#   Predicado: background1 <= 0.11 (n=64)
#     Zona: 33 colunas
#     Importance: 0.000482
#   Predicado: background1 > 0.11 (n=44)
#     Zona: 33 colunas
#     Importance: 0.000778
#   Predicado: background1 <= 0.30 (n=85)
#     Zona: 33 colunas
#     Importance: 0.000471
#   Predicado: Mn > -1.22 (n=88)
#     Zona: 20 colunas
#     Importance: 0.004520
#   Predicado: Mn <= -0.41 (n=43)
#     Zona: 20 colunas
#     Importance: 0.005356
#   Predicado: Mn > -0.41 (n=65)
#     Zona: 20 colunas
#     Importance: 0.004967
#   Predicado: Mn <= 0.23 (n=65)
#     Zona: 20 colunas
#     Importance: 0.003781
#   Predicado: Mn > 0.23 (n=43)
#     Zona: 20 colunas
#     Importance: 0.007149
#   Predicado: Mn <= 1.01 (n=87)
#     Zona: 20 colunas
#     Importance: 0.003828
#   Predicado: Fe ka > -3.74 (n=87)
#     Zona: 34 colunas
#     Importance: 0.012520
#   Predicado: Fe ka <= -3.05 (n=44)
#     Zona: 34 colunas
#     Importance: 0.003890
#   Predicado: Fe ka > -3.05 (n=64)
#     Zona: 34 colunas
#     Importance: 0.016261
#   Predicado: Fe ka <= -2.26 (n=64)
#     Zona: 34 colunas
#     Importance: 0.002915
#   Predicado: Fe ka > -2.26 (n=44)
#     Zona: 34 colunas
#     Importance: 0.023303
#   Predicado: Fe ka <= 1.10 (n=87)
#     Zona: 34 colunas
#     Importance: 0.003407
#   Predicado: Fe kb > -0.91 (n=87)
#     Zona: 23 colunas
#     Importance: 0.000229
#   Predicado: Fe kb <= -0.63 (n=40)
#     Zona: 23 colunas
#     Importance: 0.000125
#   Predicado: Fe kb > -0.63 (n=68)
#     Zona: 23 colunas
#     Importance: 0.000264
#   Predicado: Fe kb <= -0.44 (n=64)
#     Zona: 23 colunas
#     Importance: 0.000111
#   Predicado: Fe kb > -0.44 (n=44)
#     Zona: 23 colunas
#     Importance: 0.000359
#   Predicado: Fe kb <= 0.33 (n=87)
#     Zona: 23 colunas
#     Importance: 0.000119
#   Predicado: Ni > -0.60 (n=87)
#     Zona: 25 colunas
#     Importance: 0.001355
#   Predicado: Ni <= -0.14 (n=42)
#     Zona: 25 colunas
#     Importance: 0.001330
#   Predicado: Ni > -0.14 (n=66)
#     Zona: 25 colunas
#     Importance: 0.001378
#   Predicado: Ni <= 0.13 (n=63)
#     Zona: 25 colunas
#     Importance: 0.001267
#   Predicado: Ni > 0.13 (n=45)
#     Zona: 25 colunas
#     Importance: 0.001489
#   Predicado: Ni <= 0.59 (n=85)
#     Zona: 25 colunas
#     Importance: 0.001306
#   Predicado: Cu > -0.55 (n=88)
#     Zona: 39 colunas
#     Importance: 0.000216
#   Predicado: Cu <= -0.12 (n=44)
#     Zona: 39 colunas
#     Importance: 0.000256
#   Predicado: Cu > -0.12 (n=64)
#     Zona: 39 colunas
#     Importance: 0.000243
#   Predicado: Cu <= 0.09 (n=63)
#     Zona: 39 colunas
#     Importance: 0.000208
#   Predicado: Cu > 0.09 (n=45)
#     Zona: 39 colunas
#     Importance: 0.000306
#   Predicado: Cu <= 0.56 (n=87)
#     Zona: 39 colunas
#     Importance: 0.000198
#   Predicado: Zn > -0.37 (n=86)
#     Zona: 19 colunas
#     Importance: 0.000617
#   Predicado: Zn <= -0.11 (n=42)
#     Zona: 19 colunas
#     Importance: 0.000913
#   Predicado: Zn > -0.11 (n=66)
#     Zona: 19 colunas
#     Importance: 0.000650
#   Predicado: Zn <= 0.10 (n=66)
#     Zona: 19 colunas
#     Importance: 0.000645
#   Predicado: Zn > 0.10 (n=42)
#     Zona: 19 colunas
#     Importance: 0.000921
#   Predicado: Zn <= 0.34 (n=86)
#     Zona: 19 colunas
#     Importance: 0.000594
#   Predicado: background2 > -1.35 (n=88)
#     Zona: 215 colunas
#     Importance: 0.001050
#   Predicado: background2 <= -0.51 (n=43)
#     Zona: 215 colunas
#     Importance: 0.001211
#   Predicado: background2 > -0.51 (n=65)
#     Zona: 215 colunas
#     Importance: 0.001140
#   Predicado: background2 <= 0.35 (n=67)
#     Zona: 215 colunas
#     Importance: 0.000879
#   Predicado: background2 > 0.35 (n=41)
#     Zona: 215 colunas
#     Importance: 0.001642
#   Predicado: background2 <= 1.51 (n=87)
#     Zona: 215 colunas
#     Importance: 0.000858
#   Predicado: sum Fe > -0.60 (n=87)
#     Zona: 27 colunas
#     Importance: 0.000786
#   Predicado: sum Fe <= -0.28 (n=44)
#     Zona: 27 colunas
#     Importance: 0.000857
#   Predicado: sum Fe > -0.28 (n=64)
#     Zona: 27 colunas
#     Importance: 0.000893
#   Predicado: sum Fe <= 0.07 (n=67)
#     Zona: 27 colunas
#     Importance: 0.000606
#   Predicado: sum Fe > 0.07 (n=41)
#     Zona: 27 colunas
#     Importance: 0.001324
#   Predicado: sum Fe <= 0.62 (n=89)
#     Zona: 27 colunas
#     Importance: 0.000613
#   Predicado: background3 > -1.28 (n=86)
#     Zona: 219 colunas
#     Importance: 0.002194
#   Predicado: background3 <= -0.62 (n=45)
#     Zona: 219 colunas
#     Importance: 0.002791
#   Predicado: background3 > -0.62 (n=63)
#     Zona: 219 colunas
#     Importance: 0.002469
#   Predicado: background3 <= 0.14 (n=68)
#     Zona: 219 colunas
#     Importance: 0.001997
#   Predicado: background3 > 0.14 (n=40)
#     Zona: 219 colunas
#     Importance: 0.003632
#   Predicado: background3 <= 1.47 (n=90)
#     Zona: 219 colunas
#     Importance: 0.001913
#   Predicado: Compton scattering > -0.88 (n=86)
#     Zona: 85 colunas
#     Importance: 0.001812
#   Predicado: Compton scattering <= -0.40 (n=46)
#     Zona: 85 colunas
#     Importance: 0.002035
#   Predicado: Compton scattering > -0.40 (n=62)
#     Zona: 85 colunas
#     Importance: 0.002042
#   Predicado: Compton scattering <= 0.05 (n=69)
#     Zona: 85 colunas
#     Importance: 0.001662
#   Predicado: Compton scattering > 0.05 (n=39)
#     Zona: 85 colunas
#     Importance: 0.002706
#   Predicado: Compton scattering <= 0.87 (n=89)
#     Zona: 85 colunas
#     Importance: 0.001619
#   Predicado: Rayleight scattering > -0.50 (n=86)
#     Zona: 56 colunas
#     Importance: 0.000431
#   Predicado: Rayleight scattering <= -0.25 (n=47)
#     Zona: 56 colunas
#     Importance: 0.000510
#   Predicado: Rayleight scattering > -0.25 (n=61)
#     Zona: 56 colunas
#     Importance: 0.000490
#   Predicado: Rayleight scattering <= 0.03 (n=68)
#     Zona: 56 colunas
#     Importance: 0.000409
#   Predicado: Rayleight scattering > 0.03 (n=40)
#     Zona: 56 colunas
#     Importance: 0.000652
#   Predicado: Rayleight scattering <= 0.53 (n=89)
#     Zona: 56 colunas
#     Importance: 0.000385
#
# [Bag_4] Processando 132 predicados...
#   Predicado: Al > -0.68 (n=84)
#     Zona: 12 colunas
#     Importance: 0.000363
#   Predicado: Al <= -0.19 (n=48)
#     Zona: 12 colunas
#     Importance: 0.000363
#   Predicado: Al > -0.19 (n=60)
#     Zona: 12 colunas
#     Importance: 0.000419
#   Predicado: Al <= 0.19 (n=67)
#     Zona: 12 colunas
#     Importance: 0.000297
#   Predicado: Al > 0.19 (n=41)
#     Zona: 12 colunas
#     Importance: 0.000553
#   Predicado: Al <= 0.62 (n=86)
#     Zona: 12 colunas
#     Importance: 0.000318
#   Predicado: Si > -2.51 (n=87)
#     Zona: 12 colunas
#     Importance: 0.180212
#   Predicado: Si <= -1.67 (n=42)
#     Zona: 12 colunas
#     Importance: 0.098779
#   Predicado: Si > -1.67 (n=66)
#     Zona: 12 colunas
#     Importance: 0.216553
#   Predicado: Si <= -0.72 (n=66)
#     Zona: 12 colunas
#     Importance: 0.068105
#   Predicado: Si > -0.72 (n=42)
#     Zona: 12 colunas
#     Importance: 0.332055
#   Predicado: Si <= 3.71 (n=88)
#     Zona: 12 colunas
#     Importance: 0.100647
#   Predicado: P > -1.23 (n=85)
#     Zona: 16 colunas
#     Importance: 0.005176
#   Predicado: P <= -0.59 (n=42)
#     Zona: 16 colunas
#     Importance: 0.004425
#   Predicado: P > -0.59 (n=66)
#     Zona: 16 colunas
#     Importance: 0.006024
#   Predicado: P <= 0.08 (n=62)
#     Zona: 16 colunas
#     Importance: 0.003507
#   Predicado: P > 0.08 (n=46)
#     Zona: 16 colunas
#     Importance: 0.007956
#   Predicado: P <= 1.06 (n=85)
#     Zona: 16 colunas
#     Importance: 0.003684
#   Predicado: S > -0.55 (n=87)
#     Zona: 15 colunas
#     Importance: 0.003496
#   Predicado: S <= -0.27 (n=43)
#     Zona: 15 colunas
#     Importance: 0.003550
#   Predicado: S > -0.27 (n=65)
#     Zona: 15 colunas
#     Importance: 0.004005
#   Predicado: S <= 0.09 (n=65)
#     Zona: 15 colunas
#     Importance: 0.002561
#   Predicado: S > 0.09 (n=43)
#     Zona: 15 colunas
#     Importance: 0.005733
#   Predicado: S <= 0.55 (n=85)
#     Zona: 15 colunas
#     Importance: 0.002695
#   Predicado: Rh L + Ar > -1.66 (n=86)
#     Zona: 34 colunas
#     Importance: 0.023913
#   Predicado: Rh L + Ar <= -0.77 (n=44)
#     Zona: 34 colunas
#     Importance: 0.022275
#   Predicado: Rh L + Ar > -0.77 (n=64)
#     Zona: 34 colunas
#     Importance: 0.027307
#   Predicado: Rh L + Ar <= -0.16 (n=66)
#     Zona: 34 colunas
#     Importance: 0.015934
#   Predicado: Rh L + Ar > -0.16 (n=42)
#     Zona: 34 colunas
#     Importance: 0.039908
#   Predicado: Rh L + Ar <= 1.37 (n=88)
#     Zona: 34 colunas
#     Importance: 0.016215
#   Predicado: K > -6.69 (n=83)
#     Zona: 19 colunas
#     Importance: 0.011530
#   Predicado: K <= -1.46 (n=48)
#     Zona: 19 colunas
#     Importance: 0.015966
#   Predicado: K > -1.46 (n=60)
#     Zona: 19 colunas
#     Importance: 0.012240
#   Predicado: K <= 2.15 (n=67)
#     Zona: 19 colunas
#     Importance: 0.013388
#   Predicado: K > 2.15 (n=41)
#     Zona: 19 colunas
#     Importance: 0.014727
#   Predicado: K <= 6.26 (n=88)
#     Zona: 19 colunas
#     Importance: 0.011895
#   Predicado: Ca ka > -4.65 (n=87)
#     Zona: 21 colunas
#     Importance: 0.135578
#   Predicado: Ca ka <= -1.50 (n=38)
#     Zona: 21 colunas
#     Importance: 0.199971
#   Predicado: Ca ka > -1.50 (n=70)
#     Zona: 21 colunas
#     Importance: 0.134846
#   Predicado: Ca ka <= 1.77 (n=61)
#     Zona: 21 colunas
#     Importance: 0.139950
#   Predicado: Ca ka > 1.77 (n=47)
#     Zona: 21 colunas
#     Importance: 0.180876
#   Predicado: Ca ka <= 3.95 (n=85)
#     Zona: 21 colunas
#     Importance: 0.129197
#   Predicado: Ca kb > -1.81 (n=87)
#     Zona: 26 colunas
#     Importance: 0.021735
#   Predicado: Ca kb <= -0.59 (n=38)
#     Zona: 26 colunas
#     Importance: 0.034157
#   Predicado: Ca kb > -0.59 (n=70)
#     Zona: 26 colunas
#     Importance: 0.021335
#   Predicado: Ca kb <= 0.62 (n=60)
#     Zona: 26 colunas
#     Importance: 0.023548
#   Predicado: Ca kb > 0.62 (n=48)
#     Zona: 26 colunas
#     Importance: 0.028719
#   Predicado: Ca kb <= 1.57 (n=85)
#     Zona: 26 colunas
#     Importance: 0.021170
#   Predicado: Ti ka > -0.86 (n=86)
#     Zona: 15 colunas
#     Importance: 0.003857
#   Predicado: Ti ka <= -0.70 (n=45)
#     Zona: 15 colunas
#     Importance: 0.001499
#   Predicado: Ti ka > -0.70 (n=63)
#     Zona: 15 colunas
#     Importance: 0.004954
#   Predicado: Ti ka <= -0.52 (n=65)
#     Zona: 15 colunas
#     Importance: 0.001133
#   Predicado: Ti ka > -0.52 (n=43)
#     Zona: 15 colunas
#     Importance: 0.007115
#   Predicado: Ti ka <= 0.53 (n=87)
#     Zona: 15 colunas
#     Importance: 0.001276
#   Predicado: Ti kb > -0.32 (n=88)
#     Zona: 22 colunas
#     Importance: 0.000908
#   Predicado: Ti kb <= -0.14 (n=42)
#     Zona: 22 colunas
#     Importance: 0.001137
#   Predicado: Ti kb > -0.14 (n=66)
#     Zona: 22 colunas
#     Importance: 0.001024
#   Predicado: Ti kb <= 0.03 (n=63)
#     Zona: 22 colunas
#     Importance: 0.000831
#   Predicado: Ti kb > 0.03 (n=45)
#     Zona: 22 colunas
#     Importance: 0.001398
#   Predicado: Ti kb <= 0.20 (n=85)
#     Zona: 22 colunas
#     Importance: 0.000786
#   Predicado: background1 > -0.26 (n=88)
#     Zona: 33 colunas
#     Importance: 0.000536
#   Predicado: background1 <= -0.08 (n=43)
#     Zona: 33 colunas
#     Importance: 0.000778
#   Predicado: background1 > -0.08 (n=65)
#     Zona: 33 colunas
#     Importance: 0.000593
#   Predicado: background1 <= 0.11 (n=61)
#     Zona: 33 colunas
#     Importance: 0.000582
#   Predicado: background1 > 0.11 (n=47)
#     Zona: 33 colunas
#     Importance: 0.000776
#   Predicado: background1 <= 0.30 (n=84)
#     Zona: 33 colunas
#     Importance: 0.000548
#   Predicado: Mn > -1.22 (n=89)
#     Zona: 20 colunas
#     Importance: 0.004756
#   Predicado: Mn <= -0.41 (n=39)
#     Zona: 20 colunas
#     Importance: 0.005891
#   Predicado: Mn > -0.41 (n=69)
#     Zona: 20 colunas
#     Importance: 0.005102
#   Predicado: Mn <= 0.23 (n=62)
#     Zona: 20 colunas
#     Importance: 0.004007
#   Predicado: Mn > 0.23 (n=46)
#     Zona: 20 colunas
#     Importance: 0.007246
#   Predicado: Mn <= 1.01 (n=86)
#     Zona: 20 colunas
#     Importance: 0.003989
#   Predicado: Fe ka > -3.74 (n=87)
#     Zona: 34 colunas
#     Importance: 0.011597
#   Predicado: Fe ka <= -3.05 (n=44)
#     Zona: 34 colunas
#     Importance: 0.003995
#   Predicado: Fe ka > -3.05 (n=64)
#     Zona: 34 colunas
#     Importance: 0.014983
#   Predicado: Fe ka <= -2.26 (n=68)
#     Zona: 34 colunas
#     Importance: 0.002868
#   Predicado: Fe ka > -2.26 (n=40)
#     Zona: 34 colunas
#     Importance: 0.023490
#   Predicado: Fe ka <= 1.10 (n=87)
#     Zona: 34 colunas
#     Importance: 0.003337
#   Predicado: Fe kb > -0.91 (n=87)
#     Zona: 23 colunas
#     Importance: 0.000223
#   Predicado: Fe kb <= -0.63 (n=40)
#     Zona: 23 colunas
#     Importance: 0.000137
#   Predicado: Fe kb > -0.63 (n=68)
#     Zona: 23 colunas
#     Importance: 0.000257
#   Predicado: Fe kb <= -0.44 (n=64)
#     Zona: 23 colunas
#     Importance: 0.000124
#   Predicado: Fe kb > -0.44 (n=44)
#     Zona: 23 colunas
#     Importance: 0.000341
#   Predicado: Fe kb <= 0.33 (n=87)
#     Zona: 23 colunas
#     Importance: 0.000124
#   Predicado: Ni > -0.60 (n=87)
#     Zona: 25 colunas
#     Importance: 0.001434
#   Predicado: Ni <= -0.14 (n=43)
#     Zona: 25 colunas
#     Importance: 0.001611
#   Predicado: Ni > -0.14 (n=65)
#     Zona: 25 colunas
#     Importance: 0.001460
#   Predicado: Ni <= 0.13 (n=61)
#     Zona: 25 colunas
#     Importance: 0.001484
#   Predicado: Ni > 0.13 (n=47)
#     Zona: 25 colunas
#     Importance: 0.001567
#   Predicado: Ni <= 0.59 (n=85)
#     Zona: 25 colunas
#     Importance: 0.001522
#   Predicado: Cu > -0.55 (n=88)
#     Zona: 39 colunas
#     Importance: 0.000217
#   Predicado: Cu <= -0.12 (n=44)
#     Zona: 39 colunas
#     Importance: 0.000289
#   Predicado: Cu > -0.12 (n=64)
#     Zona: 39 colunas
#     Importance: 0.000253
#   Predicado: Cu <= 0.09 (n=60)
#     Zona: 39 colunas
#     Importance: 0.000236
#   Predicado: Cu > 0.09 (n=48)
#     Zona: 39 colunas
#     Importance: 0.000308
#   Predicado: Cu <= 0.56 (n=85)
#     Zona: 39 colunas
#     Importance: 0.000220
#   Predicado: Zn > -0.37 (n=88)
#     Zona: 19 colunas
#     Importance: 0.000647
#   Predicado: Zn <= -0.11 (n=41)
#     Zona: 19 colunas
#     Importance: 0.000966
#   Predicado: Zn > -0.11 (n=67)
#     Zona: 19 colunas
#     Importance: 0.000706
#   Predicado: Zn <= 0.10 (n=61)
#     Zona: 19 colunas
#     Importance: 0.000703
#   Predicado: Zn > 0.10 (n=47)
#     Zona: 19 colunas
#     Importance: 0.000937
#   Predicado: Zn <= 0.34 (n=84)
#     Zona: 19 colunas
#     Importance: 0.000639
#   Predicado: background2 > -1.35 (n=88)
#     Zona: 215 colunas
#     Importance: 0.001132
#   Predicado: background2 <= -0.51 (n=40)
#     Zona: 215 colunas
#     Importance: 0.001454
#   Predicado: background2 > -0.51 (n=68)
#     Zona: 215 colunas
#     Importance: 0.001230
#   Predicado: background2 <= 0.35 (n=63)
#     Zona: 215 colunas
#     Importance: 0.001031
#   Predicado: background2 > 0.35 (n=45)
#     Zona: 215 colunas
#     Importance: 0.001707
#   Predicado: background2 <= 1.51 (n=84)
#     Zona: 215 colunas
#     Importance: 0.000995
#   Predicado: sum Fe > -0.60 (n=87)
#     Zona: 27 colunas
#     Importance: 0.000793
#   Predicado: sum Fe <= -0.28 (n=39)
#     Zona: 27 colunas
#     Importance: 0.000960
#   Predicado: sum Fe > -0.28 (n=69)
#     Zona: 27 colunas
#     Importance: 0.000892
#   Predicado: sum Fe <= 0.07 (n=64)
#     Zona: 27 colunas
#     Importance: 0.000632
#   Predicado: sum Fe > 0.07 (n=44)
#     Zona: 27 colunas
#     Importance: 0.001330
#   Predicado: sum Fe <= 0.62 (n=87)
#     Zona: 27 colunas
#     Importance: 0.000636
#   Predicado: background3 > -1.28 (n=88)
#     Zona: 219 colunas
#     Importance: 0.002457
#   Predicado: background3 <= -0.62 (n=38)
#     Zona: 219 colunas
#     Importance: 0.003240
#   Predicado: background3 > -0.62 (n=70)
#     Zona: 219 colunas
#     Importance: 0.002705
#   Predicado: background3 <= 0.14 (n=62)
#     Zona: 219 colunas
#     Importance: 0.002143
#   Predicado: background3 > 0.14 (n=46)
#     Zona: 219 colunas
#     Importance: 0.003905
#   Predicado: background3 <= 1.47 (n=86)
#     Zona: 219 colunas
#     Importance: 0.002033
#   Predicado: Compton scattering > -0.88 (n=88)
#     Zona: 85 colunas
#     Importance: 0.002038
#   Predicado: Compton scattering <= -0.40 (n=39)
#     Zona: 85 colunas
#     Importance: 0.002349
#   Predicado: Compton scattering > -0.40 (n=69)
#     Zona: 85 colunas
#     Importance: 0.002213
#   Predicado: Compton scattering <= 0.05 (n=63)
#     Zona: 85 colunas
#     Importance: 0.001789
#   Predicado: Compton scattering > 0.05 (n=45)
#     Zona: 85 colunas
#     Importance: 0.002924
#   Predicado: Compton scattering <= 0.87 (n=86)
#     Zona: 85 colunas
#     Importance: 0.001798
#   Predicado: Rayleight scattering > -0.50 (n=87)
#     Zona: 56 colunas
#     Importance: 0.000477
#   Predicado: Rayleight scattering <= -0.25 (n=38)
#     Zona: 56 colunas
#     Importance: 0.000605
#   Predicado: Rayleight scattering > -0.25 (n=70)
#     Zona: 56 colunas
#     Importance: 0.000519
#   Predicado: Rayleight scattering <= 0.03 (n=62)
#     Zona: 56 colunas
#     Importance: 0.000439
#   Predicado: Rayleight scattering > 0.03 (n=46)
#     Zona: 56 colunas
#     Importance: 0.000698
#   Predicado: Rayleight scattering <= 0.53 (n=87)
#     Zona: 56 colunas
#     Importance: 0.000416
#
# [Bag_5] Processando 133 predicados...
#   Predicado: Al > -0.68 (n=88)
#     Zona: 12 colunas
#     Importance: 0.000378
#   Predicado: Al <= -0.19 (n=39)
#     Zona: 12 colunas
#     Importance: 0.000343
#   Predicado: Al > -0.19 (n=69)
#     Zona: 12 colunas
#     Importance: 0.000425
#   Predicado: Al <= 0.19 (n=61)
#     Zona: 12 colunas
#     Importance: 0.000271
#   Predicado: Al > 0.19 (n=47)
#     Zona: 12 colunas
#     Importance: 0.000556
#   Predicado: Al <= 0.62 (n=84)
#     Zona: 12 colunas
#     Importance: 0.000310
#   Predicado: Si > -2.51 (n=85)
#     Zona: 12 colunas
#     Importance: 0.198640
#   Predicado: Si <= -1.67 (n=43)
#     Zona: 12 colunas
#     Importance: 0.102605
#   Predicado: Si > -1.67 (n=65)
#     Zona: 12 colunas
#     Importance: 0.240008
#   Predicado: Si <= -0.72 (n=66)
#     Zona: 12 colunas
#     Importance: 0.072184
#   Predicado: Si > -0.72 (n=42)
#     Zona: 12 colunas
#     Importance: 0.363057
#   Predicado: Si <= 3.71 (n=87)
#     Zona: 12 colunas
#     Importance: 0.112655
#   Predicado: P > -1.23 (n=88)
#     Zona: 16 colunas
#     Importance: 0.004942
#   Predicado: P <= -0.59 (n=43)
#     Zona: 16 colunas
#     Importance: 0.003947
#   Predicado: P > -0.59 (n=65)
#     Zona: 16 colunas
#     Importance: 0.005907
#   Predicado: P <= 0.08 (n=68)
#     Zona: 16 colunas
#     Importance: 0.003127
#   Predicado: P > 0.08 (n=40)
#     Zona: 16 colunas
#     Importance: 0.008525
#   Predicado: P <= 1.06 (n=87)
#     Zona: 16 colunas
#     Importance: 0.003388
#   Predicado: S > -0.55 (n=86)
#     Zona: 15 colunas
#     Importance: 0.003647
#   Predicado: S <= -0.27 (n=45)
#     Zona: 15 colunas
#     Importance: 0.003762
#   Predicado: S > -0.27 (n=63)
#     Zona: 15 colunas
#     Importance: 0.004199
#   Predicado: S <= 0.09 (n=65)
#     Zona: 15 colunas
#     Importance: 0.002828
#   Predicado: S > 0.09 (n=43)
#     Zona: 15 colunas
#     Importance: 0.005816
#   Predicado: S <= 0.55 (n=84)
#     Zona: 15 colunas
#     Importance: 0.002885
#   Predicado: Rh L + Ar > -1.66 (n=87)
#     Zona: 34 colunas
#     Importance: 0.024481
#   Predicado: Rh L + Ar <= -0.77 (n=45)
#     Zona: 34 colunas
#     Importance: 0.022073
#   Predicado: Rh L + Ar > -0.77 (n=63)
#     Zona: 34 colunas
#     Importance: 0.028390
#   Predicado: Rh L + Ar <= -0.16 (n=66)
#     Zona: 34 colunas
#     Importance: 0.016009
#   Predicado: Rh L + Ar > -0.16 (n=42)
#     Zona: 34 colunas
#     Importance: 0.041078
#   Predicado: Rh L + Ar <= 1.37 (n=86)
#     Zona: 34 colunas
#     Importance: 0.016242
#   Predicado: K > -6.69 (n=89)
#     Zona: 19 colunas
#     Importance: 0.012468
#   Predicado: K <= -1.46 (n=39)
#     Zona: 19 colunas
#     Importance: 0.016104
#   Predicado: K > -1.46 (n=69)
#     Zona: 19 colunas
#     Importance: 0.013049
#   Predicado: K <= 2.15 (n=60)
#     Zona: 19 colunas
#     Importance: 0.013311
#   Predicado: K > 2.15 (n=48)
#     Zona: 19 colunas
#     Importance: 0.015203
#   Predicado: K <= 6.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.011623
#   Predicado: Ca ka > -4.65 (n=83)
#     Zona: 21 colunas
#     Importance: 0.135639
#   Predicado: Ca ka <= -1.50 (n=48)
#     Zona: 21 colunas
#     Importance: 0.199106
#   Predicado: Ca ka > -1.50 (n=60)
#     Zona: 21 colunas
#     Importance: 0.134158
#   Predicado: Ca ka <= 1.77 (n=69)
#     Zona: 21 colunas
#     Importance: 0.150412
#   Predicado: Ca ka > 1.77 (n=39)
#     Zona: 21 colunas
#     Importance: 0.185337
#   Predicado: Ca ka <= 3.95 (n=90)
#     Zona: 21 colunas
#     Importance: 0.139746
#   Predicado: Ca kb > -1.81 (n=83)
#     Zona: 26 colunas
#     Importance: 0.021164
#   Predicado: Ca kb <= -0.59 (n=47)
#     Zona: 26 colunas
#     Importance: 0.034504
#   Predicado: Ca kb > -0.59 (n=61)
#     Zona: 26 colunas
#     Importance: 0.020242
#   Predicado: Ca kb <= 0.62 (n=69)
#     Zona: 26 colunas
#     Importance: 0.025138
#   Predicado: Ca kb > 0.62 (n=39)
#     Zona: 26 colunas
#     Importance: 0.028769
# ...
# Removida: K > -1.46 -> Fe ka > -3.74 (0.0126) | Mantida: Fe ka > -3.74 -> K > -1.46 (0.0416)
# Removida: K > -6.69 -> K <= 6.26 (0.0492) | Mantida: K <= 6.26 -> K > -6.69 (0.0718)
# Removida: Fe ka > -3.74 -> K <= 6.26 (0.0123) | Mantida: K <= 6.26 -> Fe ka > -3.74 (0.0127)
# Removida: Mn <= -0.41 -> S > 0.09 (0.0109) | Mantida: S > 0.09 -> Mn <= -0.41 (0.0310)
# Removida: S > 0.09 -> P > -0.59 (0.0107) | Mantida: P > -0.59 -> S > 0.09 (0.0112)
# Removida: Mn > -0.41 -> Mn <= -0.41 (0.0053) | Mantida: Mn <= -0.41 -> Mn > -0.41 (0.0207)
# Removida: Ti ka > -0.70 -> P > -0.59 (0.0062) | Mantida: P > -0.59 -> Ti ka > -0.70 (0.0332)
# Removida: Mn > -0.41 -> Ti ka > -0.70 (0.0049) | Mantida: Ti ka > -0.70 -> Mn > -0.41 (0.0099)
# Removida: Mn > -1.22 -> P > -1.23 (0.0045) | Mantida: P > -1.23 -> Mn > -1.22 (0.0286)
# Removida: S > -0.27 -> Mn > -1.22 (0.0039) | Mantida: Mn > -1.22 -> S > -0.27 (0.0044)
# Removida: S > -0.27 -> Ti ka > -0.86 (0.0042) | Mantida: Ti ka > -0.86 -> S > -0.27 (0.0046)
# Removida: S > -0.27 -> background3 > 0.14 (0.0038) | Mantida: background3 > 0.14 -> S > -0.27 (0.0072)
# Removida: S > -0.27 -> Fe ka <= -3.05 (0.0035) | Mantida: Fe ka <= -3.05 -> S > -0.27 (0.0081)
# Removida: S > -0.27 -> S <= -0.27 (0.0035) | Mantida: S <= -0.27 -> S > -0.27 (0.0035)
# Removida: P <= -0.59 -> S > -0.27 (0.0039) | Mantida: S > -0.27 -> P <= -0.59 (0.0077)
# Removida: Ti ka > -0.86 -> Mn > -1.22 (0.0090) | Mantida: Mn > -1.22 -> Ti ka > -0.86 (0.0226)
# Removida: Fe ka <= -3.05 -> P <= -0.59 (0.0081) | Mantida: P <= -0.59 -> Fe ka <= -3.05 (0.0155)
# Removida: background3 > 0.14 -> P <= -0.59 (0.0071) | Mantida: P <= -0.59 -> background3 > 0.14 (0.0076)
# Removida: P <= -0.59 -> Mn <= 0.23 (0.0039) | Mantida: Mn <= 0.23 -> P <= -0.59 (0.0039)
# Removida: Ti ka > -0.86 -> Fe ka <= -3.05 (0.0044) | Mantida: Fe ka <= -3.05 -> Ti ka > -0.86 (0.0079)
# Removida: Mn <= 1.01 -> Mn <= 0.23 (0.0073) | Mantida: Mn <= 0.23 -> Mn <= 1.01 (0.0268)
# Removida: background3 > 0.14 -> Mn <= 0.23 (0.0036) | Mantida: Mn <= 0.23 -> background3 > 0.14 (0.0037)
# Removida: background3 > 0.14 -> Mn <= 1.01 (0.0034) | Mantida: Mn <= 1.01 -> background3 > 0.14 (0.0077)
# Removida: S > -0.55 -> background3 > 0.14 (0.0034) | Mantida: background3 > 0.14 -> S > -0.55 (0.0034)
# Removida: S <= -0.27 -> S > -0.55 (0.0034) | Mantida: S > -0.55 -> S <= -0.27 (0.0061)
# Removida: S > -0.55 -> P <= 1.06 (0.0098) | Mantida: P <= 1.06 -> S > -0.55 (0.0100)
# Removida: S > -0.55 -> P <= 0.08 (0.0030) | Mantida: P <= 0.08 -> S > -0.55 (0.0032)
# Removida: S > -0.55 -> Fe ka <= 1.10 (0.0033) | Mantida: Fe ka <= 1.10 -> S > -0.55 (0.0036)
# Removida: S <= -0.27 -> P <= 1.06 (0.0033) | Mantida: P <= 1.06 -> S <= -0.27 (0.0068)
# Removida: P <= 1.06 -> Fe ka <= 1.10 (0.0034) | Mantida: Fe ka <= 1.10 -> P <= 1.06 (0.0143)
# Removida: P <= 0.08 -> Fe ka <= 1.10 (0.0032) | Mantida: Fe ka <= 1.10 -> P <= 0.08 (0.0137)
# Removida: Fe ka <= -2.26 -> P <= 0.08 (0.0033) | Mantida: P <= 0.08 -> Fe ka <= -2.26 (0.0093)
# Removida: background3 <= -0.62 -> P <= 0.08 (0.0030) | Mantida: P <= 0.08 -> background3 <= -0.62 (0.0125)
# Removida: Fe ka <= -2.26 -> background3 <= -0.62 (0.0030) | Mantida: background3 <= -0.62 -> Fe ka <= -2.26 (0.0082)
# Removida: Fe ka <= -2.26 -> Compton scattering > 0.05 (0.0059) | Mantida: Compton scattering > 0.05 -> Fe ka <= -2.26 (0.0078)
# Removida: S <= 0.55 -> background3 <= -0.62 (0.0025) | Mantida: background3 <= -0.62 -> S <= 0.55 (0.0080)
# Removida: background3 <= -0.62 -> background3 > -0.62 (0.0025) | Mantida: background3 > -0.62 -> background3 <= -0.62 (0.0025)
# Removida: background3 > -0.62 -> S <= 0.55 (0.0050) | Mantida: S <= 0.55 -> background3 > -0.62 (0.0052)
# Removida: S <= 0.55 -> Compton scattering > 0.05 (0.0049) | Mantida: Compton scattering > 0.05 -> S <= 0.55 (0.0051)
# Removida: Compton scattering > 0.05 -> S <= 0.09 (0.0049) | Mantida: S <= 0.09 -> Compton scattering > 0.05 (0.0051)
# Removida: S <= 0.09 -> background3 > -0.62 (0.0022) | Mantida: background3 > -0.62 -> S <= 0.09 (0.0074)
# Removida: background3 > -1.28 -> S <= 0.09 (0.0021) | Mantida: S <= 0.09 -> background3 > -1.28 (0.0147)
# Removida: background3 > -0.62 -> Compton scattering > 0.05 (0.0025) | Mantida: Compton scattering > 0.05 -> background3 > -0.62 (0.0074)
# Removida: Compton scattering <= -0.40 -> background3 > -1.28 (0.0020) | Mantida: background3 > -1.28 -> Compton scattering <= -0.40 (0.0065)
# Removida: background3 <= 0.14 -> Compton scattering <= -0.40 (0.0081) | Mantida: Compton scattering <= -0.40 -> background3 <= 0.14 (0.0098)
# Removida: Compton scattering > -0.40 -> Compton scattering <= -0.40 (0.0020) | Mantida: Compton scattering <= -0.40 -> Compton scattering > -0.40 (0.0041)
# Removida: Compton scattering > -0.40 -> background3 <= 0.14 (0.0019) | Mantida: background3 <= 0.14 -> Compton scattering > -0.40 (0.0077)
# Removida: background3 <= 1.47 -> Compton scattering > -0.40 (0.0020) | Mantida: Compton scattering > -0.40 -> background3 <= 1.47 (0.0114)
# Removida: Compton scattering <= 0.87 -> Compton scattering <= 0.05 (0.0015) | Mantida: Compton scattering <= 0.05 -> Compton scattering <= 0.87 (0.0126)
# Removida: background2 > 0.35 -> Compton scattering <= 0.87 (0.0015) | Mantida: Compton scattering <= 0.87 -> background2 > 0.35 (0.0031)
# Removida: background2 > 0.35 -> Compton scattering <= 0.05 (0.0015) | Mantida: Compton scattering <= 0.05 -> background2 > 0.35 (0.0015)
# Removida: Ni > 0.13 -> background2 > 0.35 (0.0026) | Mantida: background2 > 0.35 -> Ni > 0.13 (0.0043)
# Removida: Ti kb > 0.03 -> background2 > 0.35 (0.0013) | Mantida: background2 > 0.35 -> Ti kb > 0.03 (0.0029)
# Removida: Ni <= -0.14 -> background2 > 0.35 (0.0013) | Mantida: background2 > 0.35 -> Ni <= -0.14 (0.0014)
# Removida: Ni > 0.13 -> Ti ka <= -0.70 (0.0012) | Mantida: Ti ka <= -0.70 -> Ni > 0.13 (0.0016)
# Removida: Ti kb > 0.03 -> Ni > 0.13 (0.0012) | Mantida: Ni > 0.13 -> Ti kb > 0.03 (0.0037)
# Removida: Ni > -0.14 -> Ti ka <= -0.70 (0.0012) | Mantida: Ti ka <= -0.70 -> Ni > -0.14 (0.0015)
# Removida: Ni > -0.60 -> Ti ka <= -0.70 (0.0011) | Mantida: Ti ka <= -0.70 -> Ni > -0.60 (0.0029)
# Removida: Ti ka <= -0.70 -> Ti kb > 0.03 (0.0015) | Mantida: Ti kb > 0.03 -> Ti ka <= -0.70 (0.0025)
# Removida: Ni <= 0.13 -> Ti ka <= -0.70 (0.0012) | Mantida: Ti ka <= -0.70 -> Ni <= 0.13 (0.0015)
# Removida: Ti ka <= -0.70 -> Ni <= 0.59 (0.0016) | Mantida: Ni <= 0.59 -> Ti ka <= -0.70 (0.0024)
# Removida: Ni > -0.60 -> Ni > -0.14 (0.0011) | Mantida: Ni > -0.14 -> Ni > -0.60 (0.0069)
# Removida: Ni <= 0.59 -> Ni > -0.14 (0.0011) | Mantida: Ni > -0.14 -> Ni <= 0.59 (0.0012)
# Removida: sum Fe > 0.07 -> Ni > -0.60 (0.0013) | Mantida: Ni > -0.60 -> sum Fe > 0.07 (0.0023)
# Removida: Ni > -0.60 -> background2 <= -0.51 (0.0011) | Mantida: background2 <= -0.51 -> Ni > -0.60 (0.0012)
# Removida: background2 <= -0.51 -> sum Fe > 0.07 (0.0013) | Mantida: sum Fe > 0.07 -> background2 <= -0.51 (0.0026)
# Removida: Ti ka <= 0.53 -> sum Fe > 0.07 (0.0025) | Mantida: sum Fe > 0.07 -> Ti ka <= 0.53 (0.0025)
# Removida: sum Fe > 0.07 -> Ni <= 0.13 (0.0013) | Mantida: Ni <= 0.13 -> sum Fe > 0.07 (0.0022)
# Removida: Ni <= -0.14 -> Ti kb > 0.03 (0.0025) | Mantida: Ti kb > 0.03 -> Ni <= -0.14 (0.0035)
# Removida: Ni <= 0.59 -> background2 <= -0.51 (0.0022) | Mantida: background2 <= -0.51 -> Ni <= 0.59 (0.0025)
# Removida: Ni <= 0.13 -> background2 <= -0.51 (0.0010) | Mantida: background2 <= -0.51 -> Ni <= 0.13 (0.0012)
# Removida: Ti ka <= 0.53 -> Ni <= 0.13 (0.0013) | Mantida: Ni <= 0.13 -> Ti ka <= 0.53 (0.0022)
# Removida: Ti ka <= -0.52 -> background2 > -0.51 (0.0011) | Mantida: background2 > -0.51 -> Ti ka <= -0.52 (0.0022)
# Removida: Ti ka <= -0.52 -> Ti kb <= -0.14 (0.0034) | Mantida: Ti kb <= -0.14 -> Ti ka <= -0.52 (0.0035)
# Removida: background2 > -1.35 -> Ti ka <= -0.52 (0.0020) | Mantida: Ti ka <= -0.52 -> background2 > -1.35 (0.0034)
# Removida: Ti kb > -0.14 -> Ti ka <= -0.52 (0.0017) | Mantida: Ti ka <= -0.52 -> Ti kb > -0.14 (0.0023)
# Removida: Ti kb <= -0.14 -> Ti kb > -0.14 (0.0009) | Mantida: Ti kb > -0.14 -> Ti kb <= -0.14 (0.0026)
# Removida: background2 <= 0.35 -> background2 > -1.35 (0.0010) | Mantida: background2 > -1.35 -> background2 <= 0.35 (0.0019)
# Removida: Ti kb > -0.14 -> background2 > -1.35 (0.0008) | Mantida: background2 > -1.35 -> Ti kb > -0.14 (0.0020)
# Removida: background2 <= 0.35 -> sum Fe > -0.28 (0.0009) | Mantida: sum Fe > -0.28 -> background2 <= 0.35 (0.0018)
# Removida: Zn > 0.10 -> sum Fe > -0.28 (0.0007) | Mantida: sum Fe > -0.28 -> Zn > 0.10 (0.0009)
# Removida: Zn <= -0.11 -> sum Fe > -0.28 (0.0008) | Mantida: sum Fe > -0.28 -> Zn <= -0.11 (0.0026)
# Removida: sum Fe > -0.28 -> Ti kb > -0.32 (0.0009) | Mantida: Ti kb > -0.32 -> sum Fe > -0.28 (0.0015)
# Removida: background2 <= 0.35 -> Ti kb > -0.14 (0.0009) | Mantida: Ti kb > -0.14 -> background2 <= 0.35 (0.0009)
# Removida: Ti kb > -0.32 -> background2 <= 0.35 (0.0008) | Mantida: background2 <= 0.35 -> Ti kb > -0.32 (0.0027)
# Removida: Zn <= -0.11 -> background2 <= 0.35 (0.0008) | Mantida: background2 <= 0.35 -> Zn <= -0.11 (0.0027)
# Removida: background2 <= 1.51 -> Zn <= -0.11 (0.0008) | Mantida: Zn <= -0.11 -> background2 <= 1.51 (0.0017)
# Removida: Zn > 0.10 -> background2 <= 1.51 (0.0008) | Mantida: background2 <= 1.51 -> Zn > 0.10 (0.0017)
# Removida: Ti kb > -0.32 -> background2 <= 1.51 (0.0015) | Mantida: background2 <= 1.51 -> Ti kb > -0.32 (0.0027)
# Removida: sum Fe <= -0.28 -> Zn <= -0.11 (0.0009) | Mantida: Zn <= -0.11 -> sum Fe <= -0.28 (0.0016)
# Removida: Ti kb > -0.32 -> sum Fe <= -0.28 (0.0015) | Mantida: sum Fe <= -0.28 -> Ti kb > -0.32 (0.0016)
# Removida: Zn > 0.10 -> sum Fe <= -0.28 (0.0008) | Mantida: sum Fe <= -0.28 -> Zn > 0.10 (0.0025)
# Removida: sum Fe > -0.60 -> sum Fe <= -0.28 (0.0008) | Mantida: sum Fe <= -0.28 -> sum Fe > -0.60 (0.0008)
# Removida: Ti kb > -0.32 -> Zn > 0.10 (0.0008) | Mantida: Zn > 0.10 -> Ti kb > -0.32 (0.0008)
# Removida: sum Fe > -0.60 -> Zn > 0.10 (0.0008) | Mantida: Zn > 0.10 -> sum Fe > -0.60 (0.0030)
# Removida: Ti kb <= 0.03 -> sum Fe > -0.60 (0.0013) | Mantida: sum Fe > -0.60 -> Ti kb <= 0.03 (0.0032)
# Removida: background1 > 0.11 -> Ti kb <= 0.03 (0.0005) | Mantida: Ti kb <= 0.03 -> background1 > 0.11 (0.0006)
# Removida: background1 <= -0.08 -> Ti kb <= 0.20 (0.0021) | Mantida: Ti kb <= 0.20 -> background1 <= -0.08 (0.0024)
# Removida: background1 > 0.11 -> Ti kb <= 0.20 (0.0016) | Mantida: Ti kb <= 0.20 -> background1 > 0.11 (0.0018)
# Removida: Zn <= 0.10 -> Rayleight scattering > 0.03 (0.0012) | Mantida: Rayleight scattering > 0.03 -> Zn <= 0.10 (0.0025)
# Removida: Zn > -0.11 -> Zn <= 0.10 (0.0006) | Mantida: Zn <= 0.10 -> Zn > -0.11 (0.0030)
# Removida: Rayleight scattering > 0.03 -> Zn > -0.11 (0.0006) | Mantida: Zn > -0.11 -> Rayleight scattering > 0.03 (0.0011)
# Removida: Zn <= 0.34 -> sum Fe <= 0.07 (0.0011) | Mantida: sum Fe <= 0.07 -> Zn <= 0.34 (0.0012)
# Removida: sum Fe <= 0.62 -> sum Fe <= 0.07 (0.0006) | Mantida: sum Fe <= 0.07 -> sum Fe <= 0.62 (0.0042)
# Removida: Zn <= 0.34 -> sum Fe <= 0.62 (0.0005) | Mantida: sum Fe <= 0.62 -> Zn <= 0.34 (0.0023)
# Removida: Zn > -0.37 -> Zn <= 0.34 (0.0005) | Mantida: Zn <= 0.34 -> Zn > -0.37 (0.0021)
# Removida: Zn > -0.11 -> sum Fe <= 0.62 (0.0005) | Mantida: sum Fe <= 0.62 -> Zn > -0.11 (0.0011)
# Removida: background1 <= 0.11 -> Al > 0.19 (0.0004) | Mantida: Al > 0.19 -> background1 <= 0.11 (0.0021)
# Removida: background1 > -0.08 -> background1 <= 0.11 (0.0007) | Mantida: background1 <= 0.11 -> background1 > -0.08 (0.0019)
# Removida: background1 <= 0.11 -> Rayleight scattering <= -0.25 (0.0004) | Mantida: Rayleight scattering <= -0.25 -> background1 <= 0.11 (0.0005)
# Removida: Al > 0.19 -> Rayleight scattering <= -0.25 (0.0016) | Mantida: Rayleight scattering <= -0.25 -> Al > 0.19 (0.0020)
# Removida: background1 <= 0.30 -> Rayleight scattering <= -0.25 (0.0004) | Mantida: Rayleight scattering <= -0.25 -> background1 <= 0.30 (0.0005)
# Removida: Rayleight scattering > -0.25 -> Rayleight scattering <= -0.25 (0.0004) | Mantida: Rayleight scattering <= -0.25 -> Rayleight scattering > -0.25 (0.0005)
# Removida: Rayleight scattering > -0.25 -> background1 > -0.08 (0.0005) | Mantida: background1 > -0.08 -> Rayleight scattering > -0.25 (0.0015)
# Removida: background1 <= 0.30 -> Rayleight scattering > -0.25 (0.0004) | Mantida: Rayleight scattering > -0.25 -> background1 <= 0.30 (0.0018)
# Removida: background1 > -0.26 -> background1 <= 0.30 (0.0003) | Mantida: background1 <= 0.30 -> background1 > -0.26 (0.0018)
# Removida: background1 > -0.26 -> Rayleight scattering > -0.25 (0.0003) | Mantida: Rayleight scattering > -0.25 -> background1 > -0.26 (0.0013)
# Removida: Al > -0.19 -> Rayleight scattering > -0.50 (0.0004) | Mantida: Rayleight scattering > -0.50 -> Al > -0.19 (0.0004)
# Removida: Rayleight scattering <= 0.03 -> Fe kb > -0.44 (0.0003) | Mantida: Fe kb > -0.44 -> Rayleight scattering <= 0.03 (0.0004)
# Removida: Al > -0.19 -> Rayleight scattering <= 0.03 (0.0004) | Mantida: Rayleight scattering <= 0.03 -> Al > -0.19 (0.0019)
# Removida: Rayleight scattering <= 0.53 -> Al > -0.19 (0.0010) | Mantida: Al > -0.19 -> Rayleight scattering <= 0.53 (0.0016)
# Removida: Fe kb > -0.44 -> Rayleight scattering <= 0.53 (0.0008) | Mantida: Rayleight scattering <= 0.53 -> Fe kb > -0.44 (0.0014)
# Removida: Al <= -0.19 -> Al > -0.68 (0.0007) | Mantida: Al > -0.68 -> Al <= -0.19 (0.0024)
# Removida: Al > -0.68 -> Fe kb > -0.44 (0.0007) | Mantida: Fe kb > -0.44 -> Al > -0.68 (0.0019)
# Removida: Al <= 0.62 -> Cu <= -0.12 (0.0006) | Mantida: Cu <= -0.12 -> Al <= 0.62 (0.0008)
# Removida: Cu > 0.09 -> Al <= 0.62 (0.0003) | Mantida: Al <= 0.62 -> Cu > 0.09 (0.0009)
# Removida: Cu <= -0.12 -> Cu > 0.09 (0.0010) | Mantida: Cu > 0.09 -> Cu <= -0.12 (0.0011)
# Removida: Cu <= -0.12 -> Fe kb > -0.63 (0.0003) | Mantida: Fe kb > -0.63 -> Cu <= -0.12 (0.0003)
# Removida: Cu > 0.09 -> Al <= 0.19 (0.0002) | Mantida: Al <= 0.19 -> Cu > 0.09 (0.0003)
# Removida: Fe kb > -0.63 -> Cu > 0.09 (0.0003) | Mantida: Cu > 0.09 -> Fe kb > -0.63 (0.0008)
# Removida: Al <= 0.19 -> Fe kb > -0.63 (0.0008) | Mantida: Fe kb > -0.63 -> Al <= 0.19 (0.0014)
# Removida: Cu > -0.12 -> Cu <= 0.09 (0.0008) | Mantida: Cu <= 0.09 -> Cu > -0.12 (0.0010)
# Removida: Cu > -0.12 -> Fe kb > -0.91 (0.0004) | Mantida: Fe kb > -0.91 -> Cu > -0.12 (0.0005)
# Removida: Cu <= 0.09 -> Fe kb > -0.91 (0.0004) | Mantida: Fe kb > -0.91 -> Cu <= 0.09 (0.0012)
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Arestas iniciais: 562 | Removidas: 157
# Nós predicados: 135
# Métrica: Perturbation
# Ponderação por variância explicada: ATIVADA
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#     Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0              Si > -0.72            Si > -0.72            Si > -0.72
# 1              Si > -1.67            Si > -1.67            Si > -1.67
# 2          Ca ka <= -1.50        Ca ka <= -1.50        Ca ka <= -1.50
# 3              Si > -2.51            Si > -2.51            Si > -2.51
# 4            Ca ka > 1.77          Ca ka > 1.77          Ca ka > 1.77
# ..                    ...                   ...                   ...
# 132        Fe kb <= -0.44               Class_A        Fe kb <= -0.44
# 133               Class_A               Class_B               Class_A
# 134               Class_B                   NaN               Class_B
# 135                   NaN                   NaN                   NaN
# 136                   NaN                   NaN                   NaN
#
#     Predicate_pert_Seed_3
# 0              Si > -0.72
# 1              Si > -1.67
# 2          Ca ka <= -1.50
# 3            Ca ka > 1.77
# 4              Si > -2.51
# ..                    ...
# 132        Fe kb <= -0.91
# 133         Fe kb <= 0.33
# 134        Fe kb <= -0.44
# 135               Class_A
# 136               Class_B
#
# [137 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_1']
# Out:
#           Predicate  Perturbation
# 0        Si > -0.72      0.351742
# 1        Si > -1.67      0.245000
# 2        Si > -2.51      0.200761
# 3    Ca ka <= -1.50      0.195041
# 4      Ca ka > 1.77      0.192754
# ..              ...           ...
# 127      Cu <= 0.56      0.000222
# 128      Cu > -0.55      0.000209
# 129  Fe kb <= -0.63      0.000140
# 130   Fe kb <= 0.33      0.000129
# 131  Fe kb <= -0.44      0.000125
#
# [132 rows x 2 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df_pert = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df_pert = lrc_summed_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df_pert.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                            Node  Local_Reaching_Centrality  \
# 0                    Si > -0.72                   9.827576
# 1                Ca ka <= -1.50                   5.982351
# 2             Rh L + Ar > -0.16                   1.343308
# 3                Ca kb <= -0.59                   1.039111
# 4                 Fe ka > -2.26                   0.764955
# 5                    K <= -1.46                   0.472870
# 6                 Ti ka > -0.52                   0.253940
# 7                      P > 0.08                   0.222088
# 8                      S > 0.55                   0.186147
# 9                     Mn > 0.23                   0.178655
# 10           background3 > 0.14                   0.105282
# 11    Compton scattering > 0.05                   0.065192
# 12                    Ni > 0.13                   0.026558
# 13           background2 > 0.35                   0.026532
# 14                 Ti kb > 0.03                   0.025527
# 15                sum Fe > 0.07                   0.025172
# 16                  Zn <= -0.37                   0.016721
# 17           background1 > 0.11                   0.010253
# 18  Rayleight scattering > 0.03                   0.009714
# 19                    Al > 0.19                   0.005558
# 20                Fe kb > -0.44                   0.003254
# 21                    Cu > 0.09                   0.001631
# 22                      Class_B                   0.000000
#
#                     Zone Threshold Operator
# 0                     Si     -0.72        >
# 1                  Ca ka     -1.50       <=
# 2              Rh L + Ar     -0.16        >
# 3                  Ca kb     -0.59       <=
# 4                  Fe ka     -2.26        >
# 5                      K     -1.46       <=
# 6                  Ti ka     -0.52        >
# 7                      P      0.08        >
# 8                      S      0.55        >
# 9                     Mn      0.23        >
# 10           background3      0.14        >
# 11    Compton scattering      0.05        >
# 12                    Ni      0.13        >
# 13           background2      0.35        >
# 14                 Ti kb      0.03        >
# 15                sum Fe      0.07        >
# 16                    Zn     -0.37       <=
# 17           background1      0.11        >
# 18  Rayleight scattering      0.03        >
# 19                    Al      0.19        >
# 20                 Fe kb     -0.44        >
# 21                    Cu      0.09        >
# 22                  None      None     None

# %%
# Aplicar o mapeamento
lrc_summed_df_pert_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_df_pert,
    zone_sums_preprocessed=zone_scores_df,
    zone_sums_natural=zones_original[0]
)

lrc_summed_df_pert_natural
# Out:
#                Node  Local_Reaching_Centrality   Zone Threshold Operator  \
# 0        Si > -0.72                   9.827576     Si     -0.72        >
# 1        Si > -1.67                   7.101716     Si     -1.67        >
# 2    Ca ka <= -1.50                   5.982351  Ca ka     -1.50       <=
# 3        Si > -2.51                   5.454311     Si     -2.51        >
# 4      Ca ka > 1.77                   5.036615  Ca ka      1.77        >
# ..              ...                        ...    ...       ...      ...
# 133  Fe kb <= -0.91                   0.000342  Fe kb     -0.91       <=
# 134   Fe kb <= 0.33                   0.000295  Fe kb      0.33       <=
# 135  Fe kb <= -0.44                   0.000147  Fe kb     -0.44       <=
# 136         Class_B                   0.000000   None      None     None
# 137         Class_A                   0.000000   None      None     None
#
#      Threshold_Natural  Reference_Sample_Index  Approximation_Error  \
# 0            -2.087044                   129.0             0.038926
# 1            -4.200922                   133.0             0.023527
# 2            -9.476439                    94.0             0.083086
# 3            -6.726367                    45.0             0.014243
# 4            11.953266                    82.0             0.013408
# ..                 ...                     ...                  ...
# 133          -2.342070                   115.0             0.002004
# 134           0.821719                    11.0             0.005205
# 135          -1.196874                   106.0             0.000033
# 136                NaN                     NaN                  NaN
# 137                NaN                     NaN                  NaN
#
#            Node_Natural
# 0        Si > -2.087044
# 1        Si > -4.200922
# 2    Ca ka <= -9.476439
# 3        Si > -6.726367
# 4     Ca ka > 11.953266
# ..                  ...
# 133  Fe kb <= -2.342070
# 134   Fe kb <= 0.821719
# 135  Fe kb <= -1.196874
# 136                None
# 137                None
#
# [138 rows x 9 columns]

# %%
import plotly.graph_objects as go

n = 0
zone_name = lrc_summed_df_pert_natural.iloc[n]['Zone'] # o n indica a linha do dataframe lrc_summed_df_pert_natural que queremos acessar para pegar o nome da zona espectral (coluna 'Zone')
threshold_score = float(lrc_summed_df_pert_natural.iloc[n]['Threshold_Natural']) # o iloc acessa a linha n e a coluna 'Threshold_Natural' para pegar o valor do threshold já mapeado para o espaço natural (não pré-processado)

# Usar pca_info_dict dos dados ORIGINAIS (zones_original[1])
pca_info_dict_original = zones_original[1]

# Reconstrução: τ = mean + threshold * loadings (no espaço original)
threshold_spectrum = exp.reconstruct_threshold_to_spectrum(
    threshold_value=threshold_score,
    zone_name=zone_name,
    pca_info_dict=pca_info_dict_original
)
print(f"\nEspectro de threshold reconstruído para zona '{zone_name}':")
print(f"  - Dimensão: {len(threshold_spectrum)} variáveis espectrais")
#print(f"  - Range de energias: {threshold_spectrum.index[n]} - {threshold_spectrum.index[-1]}")
print(f"  - Variância explicada pela PC1: {pca_info_dict_original[zone_name]['variance_explained']:.2%}")

# Usar dados ORIGINAIS para plotar (spectral_zones_original)
zone_df = spectral_zones_original[zone_name]

# Plotar zona com threshold (inline)
fig = go.Figure()
x_values = pd.to_numeric(zone_df.columns, errors='coerce')

# Plotar espectros das amostras coloridas por classe
colors = {'A': 'gold', 'B': 'blue'}
for idx, row in zone_df.iterrows():
    class_label = ycalclass.iloc[idx] if idx < len(ycalclass) else 'Unknown'
    fig.add_trace(go.Scatter(
        x=x_values,
        y=row.values,
        mode='lines',
        line=dict(color=colors.get(class_label, 'rgba(128,128,128,0.3)'), width=0.5),
        name=f'Class {class_label}',
        showlegend=False,
        hoverinfo='skip'
    ))

# Plotar espectro de threshold (destaque)
fig.add_trace(go.Scatter(
    x=x_values,
    y=threshold_spectrum.values,
    mode='lines',
    line=dict(color='red', width=4, dash='dash'),
    name=f'Threshold Spectrum ({threshold_spectrum.name})'
))

# Layout do gráfico
fig.update_layout(
    title=f"Zona '{zone_name}' com Threshold Multivariado (Predicado: {lrc_summed_df_pert_natural.iloc[n]['Node_Natural']})",
    xaxis_title='Energia / Comprimento de Onda',
    yaxis_title='Intensidade',
    template='plotly_white',
    showlegend=True,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()
# Out:
# Espectro de threshold reconstruído para zona 'Si':
#   - Dimensão: 12 variáveis espectrais
#   - Variância explicada pela PC1: 99.71%

# %%
# Permutation importance baseado em mudança nas predições do modelo PLS
# Medimos a média da diferença absoluta entre as predições originais e as predições
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Predições base do modelo PLS
baseline_pred = pls_model.predict(Xcalclass_prep)
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_pred = pls_model.predict(X_perm)
        diffs.append(np.mean(np.abs(baseline_pred - perm_pred)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance': importance_list
})
permutation_df.sort_values(by='Permutation_importance', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance', ascending=False)
permutation_unique_df
# Out:
#    energy  Permutation_importance                  Zone
# 0    1.74                0.048290                    Si
# 1     3.7                0.044434                 Ca ka
# 2     3.3                0.011805                     K
# 3    2.62                0.008049             Rh L + Ar
# 4       4                0.006293                 Ca kb
# 5    6.46                0.003731                 Fe ka
# 6    2.04                0.001391                     P
# 7    5.92                0.001269                    Mn
# 8     2.3                0.001210                     S
# 9     4.5                0.000936                 Ti ka
# 10   1.62                0.000573                    Al
# 11   7.52                0.000403                    Ni
# 12  11.99                0.000223           background2
# 13   4.92                0.000199                 Ti kb
# 14  18.85                0.000196    Compton scattering
# 15   7.08                0.000185                 Fe kb
# 16  13.39                0.000160                sum Fe
# 17   8.67                0.000152                    Zn
# 18  14.11                0.000108           background3
# 19   8.31                0.000089                    Cu
# 20  20.33                0.000077  Rayleight scattering
# 21   5.18                0.000060           background1

# %%
import numpy as np

max_len = max(
    len(vip_scores_unique_df['Zone']),
    len(reg_vet_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'VIP_Score': pad_list(vip_scores_unique_df['Zone'], max_len),
    'Reg_Coefficient' : pad_list(reg_vet_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation' : pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#                VIP_Score       Reg_Coefficient                  Shap  \
# 0                  Fe ka                    Si                    Si
# 1                      K                 Ca ka                 Ca ka
# 2                     Si             Rh L + Ar             Rh L + Ar
# 3                  Ca ka                 Ca kb                     K
# 4                  Ca kb                     P                 Ca kb
# 5                  Ti ka                     K                 Fe ka
# 6                  Fe kb                     S           background1
# 7              Rh L + Ar                    Mn                    Cu
# 8                      P                    Al                    Ni
# 9                     Al                    Ni                 Fe kb
# 10                    Mn                 Fe ka                     P
# 11                     S                 Ti ka                    Mn
# 12                 Ti kb                 Ti kb                 Ti ka
# 13                sum Fe           background2                     S
# 14                    Ni                    Zn                 Ti kb
# 15    Compton scattering    Compton scattering                    Al
# 16           background2                 Fe kb  Rayleight scattering
# 17  Rayleight scattering           background1    Compton scattering
# 18           background3                sum Fe                sum Fe
# 19                    Zn                    Cu           background2
# 20                    Cu           background3           background3
# 21           background1  Rayleight scattering                    Zn
# 22                  None                  None                  None
#
#              Permutation      LRC_perturbation        LRC_covariance
# 0                     Si                    Si                 Fe ka
# 1                  Ca ka                 Ca ka                 Ca ka
# 2                      K             Rh L + Ar                    Si
# 3              Rh L + Ar                 Ca kb                     K
# 4                  Ca kb                 Fe ka                 Ti ka
# 5                  Fe ka                     K                 Fe kb
# 6                      P                 Ti ka             Rh L + Ar
# 7                     Mn                     P                 Ca kb
# 8                      S                     S           background3
# 9                  Ti ka                    Mn    Compton scattering
# 10                    Al           background3  Rayleight scattering
# 11                    Ni    Compton scattering                    Al
# 12           background2                    Ni                sum Fe
# 13                 Ti kb           background2                     P
# 14    Compton scattering                 Ti kb                 Ti kb
# 15                 Fe kb                sum Fe           background2
# 16                sum Fe                    Zn                    Mn
# 17                    Zn           background1                     S
# 18           background3  Rayleight scattering                    Cu
# 19                    Cu                    Al                    Ni
# 20  Rayleight scattering                 Fe kb           background1
# 21           background1                    Cu                    Zn
# 22                  None                  None                  None

# %%
import rbo
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from the lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Truncate both lists to the same length (minimum of both)
        min_len = min(len(list_1), len(list_2))
        list_1_trunc = list_1[:min_len]
        list_2_trunc = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trunc, list_2_trunc).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_25464\3097109587.py:16: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#             Method_1          Method_2  RBO_Score
# 7    Reg_Coefficient  LRC_perturbation   0.926418
# 10              Shap  LRC_perturbation   0.909796
# 9               Shap       Permutation   0.900927
# 5    Reg_Coefficient              Shap   0.891340
# 12       Permutation  LRC_perturbation   0.872569
# 6    Reg_Coefficient       Permutation   0.861745
# 4          VIP_Score    LRC_covariance   0.785558
# 11              Shap    LRC_covariance   0.420751
# 13       Permutation    LRC_covariance   0.420751
# 14  LRC_perturbation    LRC_covariance   0.405078
# 8    Reg_Coefficient    LRC_covariance   0.359743
# 2          VIP_Score       Permutation   0.341693
# 1          VIP_Score              Shap   0.289561
# 3          VIP_Score  LRC_perturbation   0.277020
# 0          VIP_Score   Reg_Coefficient   0.232896

# %%
lrc_summed_df_cov_natural.to_csv('lrc_cov_natural.csv', index=False, sep=';')
lrc_summed_df_pert_natural.to_csv('lrc_pert_natural.csv', index=False, sep=';')
